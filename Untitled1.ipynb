# %%
import numpy as np
import pandas as pd
import polars as pl
import sys
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px


pd.set_option('display.max_columns',None)
import psycopg2


#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Algorithms to use
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

#Metrics to evaluate the model
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve

import warnings
warnings.filterwarnings("ignore")

#importing PCA and TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
vcf = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/KHHSPTGPCSP14_final.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
vcf.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']

sample_cols = vcf['SAMPLE'].str.split(':', expand=True)
sample_cols.columns = ['GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RBQ', 'ABQ', 'RDF', 'RDR', 'ADF', 'ADR']

# Assign the values to the newly created columns
vcf = pd.concat([vcf, sample_cols], axis=1)
vcf = vcf[['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL','RDF', 'RDR', 'ADF', 'ADR']]
vcf
# Out:
#       CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 1      chr1     69511    rs2691305   A   G    .   PASS
# 2      chr1     69761  rs200505207   A   T    .   PASS
# 3      chr1     69897  rs200676709   T   C    .   PASS
# 4      chr1    924533  rs112703963   A   G    .   PASS
# ...     ...       ...          ...  ..  ..  ...    ...
# 39695  chrY  23190581            .   T   C    .   PASS
# 39696  chrY  23191171            .   C   T    .   PASS
# 39697  chrY  23227961            .   A   G    .   PASS
# 39698  chrY  24842348            .   A   G    .   PASS
# 39699  chrY  24853196            .   A   G    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=254;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  255  254  254
# 1      ADP=385;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  385  385
# 2      ADP=194;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9633,0...  0/1  148  194  194
# 3      ADP=134;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0...  0/1  218  134  134
# 4      ADP=20;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....  1/1  111   20   20
# ...                                                  ...  ...  ...  ...  ...
# 39695  ADP=100;WT=0;HET=1;HOM=0;NC=0;CSQ=C|synonymous...  0/1   68  100  100
# 39696  ADP=56;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intron_vari...  0/1   46   56   56
# 39697  ADP=91;WT=0;HET=1;HOM=0;NC=0;CSQ=G|synonymous_...  0/1   68   91   91
# 39698  ADP=100;WT=0;HET=1;HOM=0;NC=0;CSQ=G|synonymous...  0/1  109  100  100
# 39699  ADP=100;WT=0;HET=1;HOM=0;NC=0;CSQ=G|synonymous...  0/1   82  100  100
#
#         RD   AD    FREQ         PVAL  RDF RDR  ADF ADR
# 0      133  121  47.64%   2.0053E-45  100  33   96  25
# 1        0  385    100%  5.6021E-231    0   0  303  82
# 2      149   45   23.2%   1.5792E-15  100  49   23  22
# 3       74   60  44.78%   1.5837E-22   50  24   37  23
# 4        0   20    100%   7.2544E-12    0   0   18   2
# ...    ...  ...     ...          ...  ...  ..  ...  ..
# 39695   79   21     21%    1.4763E-7   51  28   13   8
# 39696   42   14     25%     2.416E-5   26  16   10   4
# 39697   70   21  23.08%    1.2946E-7   58  12   15   6
# 39698   68   32     32%   1.2053E-11   54  14   28   4
# 39699   75   25     25%    5.3634E-9   63  12   21   4
#
# [39700 rows x 20 columns]
