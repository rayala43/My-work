# %%
import numpy as np
import pandas as pd
import polars as pl
import sys
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px


pd.set_option('display.max_columns',None)
import psycopg2


#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Algorithms to use
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

#Metrics to evaluate the model
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve

import warnings
warnings.filterwarnings("ignore")

#importing PCA and TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
main = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/clinicalAnnotations/clinical_ann_alleles.tsv', sep='\t')
main
# Out:
#        Clinical Annotation ID Genotype/Allele  \
# 0                   981755803              AA
# 1                   981755803              AG
# 2                   981755803              GG
# 3                  1449311190              CC
# 4                  1449311190              CT
# ...                       ...             ...
# 15648              1449000354             *64
# 15649              1449000354             *65
# 15650              1449000354             *70
# 15651              1449000354             *71
# 15652              1449000354            *114
#
#                                          Annotation Text     Allele Function
# 0      Patients with the rs75527207 AA genotype (two ...                 NaN
# 1      Patients with the rs75527207 AG genotype (one ...                 NaN
# 2      Patients with the rs75527207 GG genotype (do n...                 NaN
# 3      Patients with the CC genotype and Precursor Ce...                 NaN
# 4      Patients with the CT genotype and Precursor Ce...                 NaN
# ...                                                  ...                 ...
# 15648  Patients with the CYP2D6*64 allele may have de...  Uncertain function
# 15649  Patients with the CYP2D6*65 allele may have de...  Uncertain function
# 15650  Patients with the CYP2D6*70 allele may have de...  Uncertain function
# 15651  Patients with the CYP2D6*71 allele may have de...  Uncertain function
# 15652  Patients with the CYP2D6*114 allele may have d...         No function
#
# [15653 rows x 4 columns]

# %%
map_1 = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/clinicalAnnotations/clinical_ann_evidence.tsv', sep='\t')
map_1.dropna(subset=['PMID'], inplace=True)
map_1['PMID'] = map_1['PMID'].astype('int64')
map_1
# Out:
#        Clinical Annotation ID Evidence ID  \
# 2                   981755803   981755665
# 3                   981755803   981755678
# 4                   981755803   982009991
# 5                   981755803  1043737620
# 6                   981755803  1043737636
# ...                       ...         ...
# 15025              1449000354  1446899430
# 15026              1449000354  1447959334
# 15027              1449000354  1448616567
# 15028              1449000354  1448616608
# 15029              1449000354  1447959237
#
#                              Evidence Type  \
# 2                  Variant Drug Annotation
# 3                  Variant Drug Annotation
# 4                  Variant Drug Annotation
# 5      Variant Functional Assay Annotation
# 6      Variant Functional Assay Annotation
# ...                                    ...
# 15025  Variant Functional Assay Annotation
# 15026  Variant Functional Assay Annotation
# 15027  Variant Functional Assay Annotation
# 15028  Variant Functional Assay Annotation
# 15029  Variant Functional Assay Annotation
#
#                                             Evidence URL      PMID  \
# 2      https://www.pharmgkb.org/variantAnnotation/981...  21083385
# 3      https://www.pharmgkb.org/variantAnnotation/981...  22047557
# 4      https://www.pharmgkb.org/variantAnnotation/982...  23590265
# 5      https://www.pharmgkb.org/variantAnnotation/104...  23757361
# 6      https://www.pharmgkb.org/variantAnnotation/104...  23891399
# ...                                                  ...       ...
# 15025  https://www.pharmgkb.org/variantAnnotation/144...  24647041
# 15026  https://www.pharmgkb.org/variantAnnotation/144...  24647041
# 15027  https://www.pharmgkb.org/variantAnnotation/144...  24647041
# 15028  https://www.pharmgkb.org/variantAnnotation/144...  24647041
# 15029  https://www.pharmgkb.org/variantAnnotation/144...  24647041
#
#                                                  Summary Score
# 2      Genotypes AA + AG are associated with response...  0.25
# 3      Genotypes AA + AG are associated with response...     2
# 4      Allele A is associated with response to ivacaf...  2.25
# 5      Allele A is associated with increased activity...     0
# 6      Allele A is associated with activity of CFTR w...     0
# ...                                                  ...   ...
# 15025  CYP2D6 *53 is associated with increased cleara...     0
# 15026  CYP2D6 *10 + *14 + *17 + *18 + *29 + *30 + *35...     0
# 15027  CYP2D6 *22 + *23 + *24 + *27 + *33 + *49 are n...     0
# 15028  CYP2D6 *39 + *48 are associated with decreased...     0
# 15029  CYP2D6 *7 + *12 + *114 + *31 + *36 + *37 + *40...     0
#
# [14557 rows x 7 columns]

# %%
map_1 = map_1.groupby('Clinical Annotation ID')['PMID'].agg(lambda x: ', '.join(x.dropna().astype(str).unique())).reset_index()
map_1
# Out:
#       Clinical Annotation ID  \
# 0                  613976757
# 1                  613976848
# 2                  613977037
# 3                  613977064
# 4                  613978931
# ...                      ...
# 5068              1452050380
# 5069              1452050405
# 5070              1452050600
# 5071              1452050620
# 5072              1452138940
#
#                                                    PMID
# 0     23252947, 19620853, 22188362, 15692831, 254954...
# 1                                              16538176
# 2                                              16538175
# 3                                              15790597
# 4     26555147, 26314341, 22292851, 22591328, 221883...
# ...                                                 ...
# 5068                       16710319, 22612784, 16874005
# 5069             27445478, 33548906, 22480177, 19937159
# 5070                       24192302, 19937159, 19590397
# 5071                       31066578, 24192302, 19937159
# 5072                                 28940218, 26086347
#
# [5073 rows x 2 columns]

# %%
map_2 = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/clinicalAnnotations/clinical_ann_history.tsv', sep='\t')
map_2
# Out:
#        Clinical Annotation ID Date (YYYY-MM-DD)    Type  \
# 0                   981755803        2018-03-28  Update
# 1                   981755803        2018-11-28  Update
# 2                   981755803        2020-11-04  Update
# 3                   981755803        2021-02-02  Update
# 4                   981755803        2021-02-02  Update
# ...                       ...               ...     ...
# 13311              1449000354        2017-10-16  Create
# 13312              1449000354        2017-10-17  Update
# 13313              1449000354        2018-11-14  Update
# 13314              1449000354        2021-03-24  Update
# 13315              1449000354        2023-08-31  Update
#
#                                                  Comment
# 0                        Added PMID 25145599 to evidence
# 1                        Added PMID 23628510 to evidence
# 2      Updated text to match new format. Added guidel...
# 3      Attached CPIC guideline and FDA label for ivac...
# 4                  Small edit to text to match template.
# ...                                                  ...
# 13311                                                NaN
# 13312                                                NaN
# 13313  re-assigned *14A to *114 and *14B to *14 accor...
# 13314  CA score added as part of scoring system relea...
# 13315  *57 was re-assigned to CYP2D6*36.005 by PharmV...
#
# [13316 rows x 4 columns]

# %%
# Convert the 'Date' column to a datetime object
map_2['Date (YYYY-MM-DD)'] = pd.to_datetime(map_2['Date (YYYY-MM-DD)'])

# Group by 'ID' and select the maximum date within each group
map_2 = map_2.groupby('Clinical Annotation ID')['Date (YYYY-MM-DD)'].max().reset_index()
map_2
# Out:
#       Clinical Annotation ID Date (YYYY-MM-DD)
# 0                  613976757        2021-03-24
# 1                  613976848        2021-03-24
# 2                  613977037        2021-03-24
# 3                  613977064        2021-03-24
# 4                  613978931        2021-03-24
# ...                      ...               ...
# 5068              1452050380        2023-03-27
# 5069              1452050405        2023-03-27
# 5070              1452050600        2023-03-27
# 5071              1452050620        2023-03-27
# 5072              1452138940        2023-06-23
#
# [5073 rows x 2 columns]

# %%
map_2[map_2['Clinical Annotation ID'] == 981755803]
# Out:
#      Clinical Annotation ID Date (YYYY-MM-DD)
# 540               981755803        2021-03-24

# %%
map_3 = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/clinicalAnnotations/clinical_annotations.tsv', sep='\t')
map_3
# Out:
#       Clinical Annotation ID  \
# 0                  981755803
# 1                 1449311190
# 2                  981204774
# 3                 1449191690
# 4                 1449191746
# ...                      ...
# 5068              1452018886
# 5069              1451566760
# 5070              1451567040
# 5071              1184757183
# 5072              1449000354
#
#                                      Variant/Haplotypes        Gene  \
# 0                                            rs75527207        CFTR
# 1                                             rs4149056     SLCO1B1
# 2                                             rs1799971       OPRM1
# 3                                           rs141033578        CFTR
# 4                                            rs78769542        CFTR
# ...                                                 ...         ...
# 5068                                          rs2874116         NaN
# 5069                                          rs1800497  ANKK1;DRD2
# 5070  CYP3A4*1, CYP3A4*2, CYP3A4*3, CYP3A4*4, CYP3A4...      CYP3A4
# 5071  CYP2D6*1, CYP2D6*7, CYP2D6*10, CYP2D6*12, CYP2...      CYP2D6
# 5072  CYP2D6*1, CYP2D6*7, CYP2D6*9, CYP2D6*10, CYP2D...      CYP2D6
#
#      Level of Evidence Level Override           Level Modifiers    Score  \
# 0                   1A            NaN  Rare Variant; Tier 1 VIP  234.875
# 1                    3            NaN                Tier 1 VIP    2.000
# 2                    4            NaN                       NaN   -2.000
# 3                   1A            NaN  Rare Variant; Tier 1 VIP  200.000
# 4                   1A            NaN  Rare Variant; Tier 1 VIP  200.000
# ...                ...            ...                       ...      ...
# 5068                 3            NaN                       NaN    3.000
# 5069                 3            NaN                Tier 1 VIP    1.500
# 5070                 3            NaN                Tier 1 VIP    2.500
# 5071                 3            NaN                Tier 1 VIP    0.000
# 5072                 3            NaN                Tier 1 VIP    0.000
#
#      Phenotype Category  PMID Count  Evidence Count  \
# 0              Efficacy          28              30
# 1                Dosage           1               1
# 2              Efficacy           2               3
# 3              Efficacy           1               3
# 4              Efficacy           1               3
# ...                 ...         ...             ...
# 5068           Efficacy           1               1
# 5069           Efficacy           1               1
# 5070      Metabolism/PK           2               3
# 5071              Other          14              43
# 5072      Metabolism/PK           1               6
#
#                                          Drug(s)  \
# 0                                      ivacaftor
# 1                    mercaptopurine;methotrexate
# 2     Drugs used in nicotine dependence;nicotine
# 3                                      ivacaftor
# 4                                      ivacaftor
# ...                                          ...
# 5068                                cyclosporine
# 5069                        bupropion;naltrexone
# 5070                                   oxycodone
# 5071                  bufuralol;dextromethorphan
# 5072                        n-desmethyltamoxifen
#
#                                         Phenotype(s)  \
# 0                                    Cystic Fibrosis
# 1     Precursor Cell Lymphoblastic Leukemia-Lymphoma
# 2                               Tobacco Use Disorder
# 3                                    Cystic Fibrosis
# 4                                    Cystic Fibrosis
# ...                                              ...
# 5068                                             NaN
# 5069                                         Obesity
# 5070                                             NaN
# 5071                                             NaN
# 5072                                             NaN
#
#      Latest History Date (YYYY-MM-DD)  \
# 0                          2021-03-24
# 1                          2021-03-24
# 2                          2021-03-24
# 3                          2021-03-24
# 4                          2021-03-24
# ...                               ...
# 5068                       2023-02-24
# 5069                       2021-10-29
# 5070                       2022-01-13
# 5071                       2023-08-31
# 5072                       2023-08-31
#
#                                                     URL Specialty Population
# 0     https://www.pharmgkb.org/clinicalAnnotation/98...            Pediatric
# 1     https://www.pharmgkb.org/clinicalAnnotation/14...            Pediatric
# 2     https://www.pharmgkb.org/clinicalAnnotation/98...                  NaN
# 3     https://www.pharmgkb.org/clinicalAnnotation/14...                  NaN
# 4     https://www.pharmgkb.org/clinicalAnnotation/14...                  NaN
# ...                                                 ...                  ...
# 5068  https://www.pharmgkb.org/clinicalAnnotation/14...                  NaN
# 5069  https://www.pharmgkb.org/clinicalAnnotation/14...                  NaN
# 5070  https://www.pharmgkb.org/clinicalAnnotation/14...                  NaN
# 5071  https://www.pharmgkb.org/clinicalAnnotation/11...                  NaN
# 5072  https://www.pharmgkb.org/clinicalAnnotation/14...                  NaN
#
# [5073 rows x 15 columns]

# %%
merge_1 = pd.merge(main, map_1, on = 'Clinical Annotation ID', how = 'left', sort = False)
merge_1
# Out:
#        Clinical Annotation ID Genotype/Allele  \
# 0                   981755803              AA
# 1                   981755803              AG
# 2                   981755803              GG
# 3                  1449311190              CC
# 4                  1449311190              CT
# ...                       ...             ...
# 15648              1449000354             *64
# 15649              1449000354             *65
# 15650              1449000354             *70
# 15651              1449000354             *71
# 15652              1449000354            *114
#
#                                          Annotation Text     Allele Function  \
# 0      Patients with the rs75527207 AA genotype (two ...                 NaN
# 1      Patients with the rs75527207 AG genotype (one ...                 NaN
# 2      Patients with the rs75527207 GG genotype (do n...                 NaN
# 3      Patients with the CC genotype and Precursor Ce...                 NaN
# 4      Patients with the CT genotype and Precursor Ce...                 NaN
# ...                                                  ...                 ...
# 15648  Patients with the CYP2D6*64 allele may have de...  Uncertain function
# 15649  Patients with the CYP2D6*65 allele may have de...  Uncertain function
# 15650  Patients with the CYP2D6*70 allele may have de...  Uncertain function
# 15651  Patients with the CYP2D6*71 allele may have de...  Uncertain function
# 15652  Patients with the CYP2D6*114 allele may have d...         No function
#
#                                                     PMID
# 0      21083385, 22047557, 23590265, 23757361, 238913...
# 1      21083385, 22047557, 23590265, 23757361, 238913...
# 2      21083385, 22047557, 23590265, 23757361, 238913...
# 3                                               29683944
# 4                                               29683944
# ...                                                  ...
# 15648                                           24647041
# 15649                                           24647041
# 15650                                           24647041
# 15651                                           24647041
# 15652                                           24647041
#
# [15653 rows x 5 columns]

# %%
merge_2 = pd.merge(merge_1, map_3, on = 'Clinical Annotation ID', how = 'left', sort=False)
merge_2
# Out:
#        Clinical Annotation ID Genotype/Allele  \
# 0                   981755803              AA
# 1                   981755803              AG
# 2                   981755803              GG
# 3                  1449311190              CC
# 4                  1449311190              CT
# ...                       ...             ...
# 15648              1449000354             *64
# 15649              1449000354             *65
# 15650              1449000354             *70
# 15651              1449000354             *71
# 15652              1449000354            *114
#
#                                          Annotation Text     Allele Function  \
# 0      Patients with the rs75527207 AA genotype (two ...                 NaN
# 1      Patients with the rs75527207 AG genotype (one ...                 NaN
# 2      Patients with the rs75527207 GG genotype (do n...                 NaN
# 3      Patients with the CC genotype and Precursor Ce...                 NaN
# 4      Patients with the CT genotype and Precursor Ce...                 NaN
# ...                                                  ...                 ...
# 15648  Patients with the CYP2D6*64 allele may have de...  Uncertain function
# 15649  Patients with the CYP2D6*65 allele may have de...  Uncertain function
# 15650  Patients with the CYP2D6*70 allele may have de...  Uncertain function
# 15651  Patients with the CYP2D6*71 allele may have de...  Uncertain function
# 15652  Patients with the CYP2D6*114 allele may have d...         No function
#
#                                                     PMID  \
# 0      21083385, 22047557, 23590265, 23757361, 238913...
# 1      21083385, 22047557, 23590265, 23757361, 238913...
# 2      21083385, 22047557, 23590265, 23757361, 238913...
# 3                                               29683944
# 4                                               29683944
# ...                                                  ...
# 15648                                           24647041
# 15649                                           24647041
# 15650                                           24647041
# 15651                                           24647041
# 15652                                           24647041
#
#                                       Variant/Haplotypes     Gene  \
# 0                                             rs75527207     CFTR
# 1                                             rs75527207     CFTR
# 2                                             rs75527207     CFTR
# 3                                              rs4149056  SLCO1B1
# 4                                              rs4149056  SLCO1B1
# ...                                                  ...      ...
# 15648  CYP2D6*1, CYP2D6*7, CYP2D6*9, CYP2D6*10, CYP2D...   CYP2D6
# 15649  CYP2D6*1, CYP2D6*7, CYP2D6*9, CYP2D6*10, CYP2D...   CYP2D6
# 15650  CYP2D6*1, CYP2D6*7, CYP2D6*9, CYP2D6*10, CYP2D...   CYP2D6
# 15651  CYP2D6*1, CYP2D6*7, CYP2D6*9, CYP2D6*10, CYP2D...   CYP2D6
# 15652  CYP2D6*1, CYP2D6*7, CYP2D6*9, CYP2D6*10, CYP2D...   CYP2D6
#
#       Level of Evidence Level Override           Level Modifiers    Score  \
# 0                    1A            NaN  Rare Variant; Tier 1 VIP  234.875
# 1                    1A            NaN  Rare Variant; Tier 1 VIP  234.875
# 2                    1A            NaN  Rare Variant; Tier 1 VIP  234.875
# 3                     3            NaN                Tier 1 VIP    2.000
# 4                     3            NaN                Tier 1 VIP    2.000
# ...                 ...            ...                       ...      ...
# 15648                 3            NaN                Tier 1 VIP    0.000
# 15649                 3            NaN                Tier 1 VIP    0.000
# 15650                 3            NaN                Tier 1 VIP    0.000
# 15651                 3            NaN                Tier 1 VIP    0.000
# 15652                 3            NaN                Tier 1 VIP    0.000
#
#       Phenotype Category  PMID Count  Evidence Count  \
# 0               Efficacy          28              30
# 1               Efficacy          28              30
# 2               Efficacy          28              30
# 3                 Dosage           1               1
# 4                 Dosage           1               1
# ...                  ...         ...             ...
# 15648      Metabolism/PK           1               6
# 15649      Metabolism/PK           1               6
# 15650      Metabolism/PK           1               6
# 15651      Metabolism/PK           1               6
# 15652      Metabolism/PK           1               6
#
#                            Drug(s)  \
# 0                        ivacaftor
# 1                        ivacaftor
# 2                        ivacaftor
# 3      mercaptopurine;methotrexate
# 4      mercaptopurine;methotrexate
# ...                            ...
# 15648         n-desmethyltamoxifen
# 15649         n-desmethyltamoxifen
# 15650         n-desmethyltamoxifen
# 15651         n-desmethyltamoxifen
# 15652         n-desmethyltamoxifen
#
#                                          Phenotype(s)  \
# 0                                     Cystic Fibrosis
# 1                                     Cystic Fibrosis
# 2                                     Cystic Fibrosis
# 3      Precursor Cell Lymphoblastic Leukemia-Lymphoma
# 4      Precursor Cell Lymphoblastic Leukemia-Lymphoma
# ...                                               ...
# 15648                                             NaN
# 15649                                             NaN
# 15650                                             NaN
# 15651                                             NaN
# 15652                                             NaN
#
#       Latest History Date (YYYY-MM-DD)  \
# 0                           2021-03-24
# 1                           2021-03-24
# 2                           2021-03-24
# 3                           2021-03-24
# 4                           2021-03-24
# ...                                ...
# 15648                       2023-08-31
# 15649                       2023-08-31
# 15650                       2023-08-31
# 15651                       2023-08-31
# 15652                       2023-08-31
#
#                                                      URL Specialty Population
# 0      https://www.pharmgkb.org/clinicalAnnotation/98...            Pediatric
# 1      https://www.pharmgkb.org/clinicalAnnotation/98...            Pediatric
# 2      https://www.pharmgkb.org/clinicalAnnotation/98...            Pediatric
# 3      https://www.pharmgkb.org/clinicalAnnotation/14...            Pediatric
# 4      https://www.pharmgkb.org/clinicalAnnotation/14...            Pediatric
# ...                                                  ...                  ...
# 15648  https://www.pharmgkb.org/clinicalAnnotation/14...                  NaN
# 15649  https://www.pharmgkb.org/clinicalAnnotation/14...                  NaN
# 15650  https://www.pharmgkb.org/clinicalAnnotation/14...                  NaN
# 15651  https://www.pharmgkb.org/clinicalAnnotation/14...                  NaN
# 15652  https://www.pharmgkb.org/clinicalAnnotation/14...                  NaN
#
# [15653 rows x 19 columns]

# %%
merge_2.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/clinicalAnnotations/mapped_pmid.xlsx', index=False)
