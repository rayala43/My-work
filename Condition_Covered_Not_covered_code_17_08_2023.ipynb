# %%
import numpy as np
import pandas as pd
import polars as pl
import sys
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px


pd.set_option('display.max_columns',None)
import psycopg2


#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Algorithms to use
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

#Metrics to evaluate the model
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve

import warnings
warnings.filterwarnings("ignore")

#importing PCA and TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE


x = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Reproductivehealth_Male_Lit_final_Positions_hg38_hg37.xlsx')
x['chrom'] = x['Chrom-pos-Ref-Alt_38'].str.split(',')
x = x.explode('chrom')

x['CHROM'] = x['chrom'].str.split('-').str[0]

# Function to add 'chr' prefix conditionally
def add_chr_prefix(chrom):
    if pd.notnull(chrom) and chrom.strip() != '':
        return 'chr' + str(chrom)
    else:
        return chrom

# Applying the function to the 'chromosome' column
x['CHROM'] = x['CHROM'].apply(add_chr_prefix)
x['CHROM'] = x['CHROM'].str.strip()
x['CHROM'] = x['CHROM'].str.replace(r'\s+', '')
x['POS'] = x['chrom'].str.split('-').str[1]

x.dropna(subset=['CHROM'], inplace=True)
# Drop rows with empty cells after removing leading and trailing whitespaces
x['CHROM'] = x['CHROM'].str.strip()
x['POS'] = x['POS'].str.strip()
# Dropping rows with empty cells and NaN values in both 'chromosome' and 'position' columns
x.dropna(subset=['CHROM', 'POS'], inplace=True)
df_3 = x[['Gene', 'CHROM', 'POS']]
df_3['Literature'] = 'Yes'
df_3.drop_duplicates(subset='POS', inplace=True)
df_3['POS'] = df_3['POS'].astype('int64')
df_3 = df_3.reset_index()
df_3 = df_3[['Gene', 'CHROM', 'POS', 'Literature']]

df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/KAPA HyperExome_hg38_capture_targets (1).bed', sep = '\t', header = None)
df.columns = ['chromosome', 'Start_pos', 'End_pos', 'INFO']

df['Extended_Start_pos'] = df['Start_pos'] - 20
df['Extended_End_pos'] = df['End_pos'] + 20

df['gene_symbol'] = df['INFO'].str.extract(r'gene_symbol=([^;]+)')
df = df[['chromosome', 'Extended_Start_pos', 'Extended_End_pos', 'INFO', 'gene_symbol']]


# Step 1: Create a dictionary from the df DataFrame
chromosome_dict = {}
for _, row in df.iterrows():
    chromosome = row['chromosome']
    start_pos = row['Extended_Start_pos']
    end_pos = row['Extended_End_pos']
    if chromosome not in chromosome_dict:
        chromosome_dict[chromosome] = []
    chromosome_dict[chromosome].append((start_pos, end_pos))

# Step 2: Define a function to check coverage
def check_coverage(row):
    pos = row['POS']
    chromosome = row['CHROM']
    if chromosome in chromosome_dict:
        ranges = chromosome_dict[chromosome]
        for start, end in ranges:
            if start <= pos <= end:
                return 'Covered'
    return 'Not_Covered'

# Step 3: Apply the function to create the new column in dataset2
df_3['Covered/Not_Covered'] = df_3.apply(check_coverage, axis=1)
df_3.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Condition_lit_CHROM_POS_Covered_Not_covered/Reproductivehealth_Male_Lit_final_Positions.xlsx', index=False)
df_3
# Out:
#       Gene  CHROM        POS Literature Covered/Not_Covered
# 0    SYCP3  chr12  101728759        Yes             Covered
# 1    SYCP3  chr12  101729212        Yes             Covered
# 2    SYCP3  chr12  101737510        Yes         Not_Covered
# 3    SYCP3  chr12  101728656        Yes             Covered
# 4    SYCP3  chr12  101729109        Yes             Covered
# ..     ...    ...        ...        ...                 ...
# 447    WT1  chr11   32388694        Yes         Not_Covered
# 448    WT1  chr11   32388759        Yes         Not_Covered
# 449    WT1  chr11   32388568        Yes         Not_Covered
# 450    WT1  chr11   32392036        Yes             Covered
# 451    WT1  chr11   32392670        Yes             Covered
#
# [452 rows x 5 columns]

# %%
data = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/Metabolic_myopathy_Lit_final_Positions_hg38_hg37 (1).csv', sep = '\t')
data
# Out:
#       Gene     Change Uploaded_variant_hg38 Uploaded_variant_hg37  \
# 0     PGM1  rs2749097             rs2749097             rs2749097
# 1     PGM1  c.405delT        PGM1:c.405delT        PGM1:c.405delT
# 2     PGM1  c.1547T>C        PGM1:c.1547T>C        PGM1:c.1547T>C
# 3     PGM1   c.988G>C         PGM1:c.988G>C         PGM1:c.988G>C
# 4     PGM1  c.1129G>A        PGM1:c.1129G>A        PGM1:c.1129G>A
# ..     ...        ...                   ...                   ...
# 343  ECHS1   c.538A>G        ECHS1:c.538A>G        ECHS1:c.538A>G
# 344  ECHS1   c.713C>T        ECHS1:c.713C>T        ECHS1:c.713C>T
# 345  ECHS1   c.476A>G        ECHS1:c.476A>G        ECHS1:c.476A>G
# 346  ECHS1     c.8C>A          ECHS1:c.8C>A          ECHS1:c.8C>A
# 347  ECHS1   c.389T>A        ECHS1:c.389T>A        ECHS1:c.389T>A
#
#                                   Chrom-pos-Ref-Alt_38    rsID_hg38  \
# 0                                       1-63661797-C-G    rs2749097
# 1    1-63629582-AT-A, 1-63629528-GT-G, 1-63651758-A...          NaN
# 2                                       1-63654414-T-C  rs587777401
# 3                       1-63636348-G-C, 1-63636294-G-C  rs777164338
# 4                                       1-63638785-G-A          NaN
# ..                                                 ...          ...
# 343                                   10-133366970-T-C  rs557128093
# 344                                   10-133366002-G-A  rs200584793
# 345                                   10-133368961-T-C  rs375032130
# 346                                   10-133373326-G-T  rs372408822
# 347                                                NaN          NaN
#
#                                   Chrom-pos-Ref-Alt_37    rsID_hg37
# 0                                       1-64127468-C-G    rs2749097
# 1    1-64095253-AT-A, 1-64095199-GT-G, 1-64117429-A...          NaN
# 2                                       1-64120085-T-C  rs587777401
# 3                       1-64102019-G-C, 1-64101965-G-C  rs777164338
# 4                                       1-64104456-G-A          NaN
# ..                                                 ...          ...
# 343                                   10-135180474-T-C  rs557128093
# 344                                   10-135179506-G-A  rs200584793
# 345                                   10-135182465-T-C  rs375032130
# 346                                   10-135186830-G-T  rs372408822
# 347                                                NaN          NaN
#
# [348 rows x 8 columns]

# %%
data.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Metabolic_myopathy_Lit_final_Positions_hg38_hg37.xlsx', index=False)

# %%
df_3['Covered/Not_Covered'].value_counts()
# Out:
# Covered        108
# Not_Covered     20
# Name: Covered/Not_Covered, dtype: int64

# %%
y = df_3[df_3['Covered/Not_Covered'] == 'Not_Covered']
y.Gene.value_counts()
# Out:
# EPM2A      38
# KCNT1      30
# SCN2A      13
# SCN1B       8
# SCN1A       7
# EFHC1       5
# RBFOX1      4
# SPTAN1      2
# GABRG2      2
# GOSR2       2
# CSTB        1
# GABRA1      1
# CACNA1H     1
# Name: Gene, dtype: int64

# %%
z = df_3[df_3['Covered/Not_Covered'] == 'Covered']
z.Gene.value_counts()
# Out:
# KCNT1      156
# SCN2A      145
# SCN1A       84
# EPM2A       62
# SPTAN1      28
# EFHC1       28
# SCN1B       26
# CACNA1H     26
# GABRG2      22
# RBFOX1      15
# GABRA1      12
# KCTD7        7
# GOSR2        6
# TBC1D24      4
# PCDH19       3
# CSTB         3
# KCNC1        1
# Name: Gene, dtype: int64

# %%
df_pall = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/Answers(2023-05-22).csv')
#df_pall = df_pall[['tutor_id', 'student_rating']]
df_pall
# Out:
#       no  task_id task_state review_state tutor_admin_id  student_rating  \
# 0      1  6844329     CLOSED         TODO     Unassigned               1
# 1      2  6845537     CLOSED         TODO     Unassigned               3
# 2      3  6845783     CLOSED         TODO     Unassigned               1
# 3      4  6846091     CLOSED         TODO     Unassigned               2
# 4      5  6846238     CLOSED         TODO     Unassigned               1
# ..   ...      ...        ...          ...            ...             ...
# 158  159  6861731     CLOSED         TODO     Unassigned               1
# 159  160  6861883     CLOSED         TODO     Unassigned               1
# 160  161  6861888     CLOSED         TODO     Unassigned               2
# 161  162  6861894     CLOSED         TODO     Unassigned               1
# 162  163  6861899     CLOSED         TODO     Unassigned               1
#
#      admin_rating  admin_comment  \
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN
# ..            ...            ...
# 158           NaN            NaN
# 159           NaN            NaN
# 160           NaN            NaN
# 161           NaN            NaN
# 162           NaN            NaN
#
#                                          chat_room_url  \
# 0    sendbird_group_channel_170904867_8af8e7453b6b9...
# 1    sendbird_group_channel_178747312_1f67a3457fd11...
# 2    sendbird_group_channel_229694720_9a5feba80b62c...
# 3    sendbird_group_channel_212267434_23c1c3db36044...
# 4    sendbird_group_channel_170904867_6d26e51a4513b...
# ..                                                 ...
# 158  sendbird_group_channel_213607036_7baa0af464d2d...
# 159  sendbird_group_channel_102230683_82bf4cc0f348e...
# 160  sendbird_group_channel_168764795_4ab16331cf7f0...
# 161  sendbird_group_channel_168764795_6d78296f9638e...
# 162  sendbird_group_channel_255504360_8126b71c1815f...
#
#                  retake_request_reason  retake_request_reason_detail  \
# 0    RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 1    RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 2    RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 3    RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 4    RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# ..                                 ...                           ...
# 158  RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 159  RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 160  RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 161  RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 162  RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
#
#                                student_id  \
# 0    c5f8d8a1-fab3-4b35-a81f-382620061bc6
# 1    8e94a0b1-9a79-4217-84fb-29e8c4dfe96e
# 2    11e3872e-6ee5-4bfc-ba68-4ca0b57bb207
# 3    35133269-3b13-49ec-892e-08071ba47fe1
# 4    f110d474-7323-4df1-ae74-402292af20bf
# ..                                    ...
# 158  e4873ed3-2bce-450f-aaad-7b813ec0c839
# 159  ba23520a-c896-4538-b310-bdf7c7e2afed
# 160  9d7c8eec-e930-4d18-8eba-a29398cc43ae
# 161  9d7c8eec-e930-4d18-8eba-a29398cc43ae
# 162  0fd166f2-58e2-4a54-ae2e-b4742e4beb09
#
#                               queried_image_object_key  task_result_id  \
# 0    app-server-student/2023/5/4/69837fb6-0838-4312...         6050107
# 1    app-server-student/2023/5/5/e99666ea-0ff4-4d3d...         6051197
# 2    app-server-student/2023/5/5/11f1d724-86bc-4ef3...         6051466
# 3    app-server-student/2023/5/5/1fa0a6ce-f3c5-4533...         6051776
# 4    app-server-student/2023/5/5/6f0e89be-059a-453b...         6051963
# ..                                                 ...             ...
# 158  app-server-student/2023/5/20/2bf62e3b-b37e-4a7...         6066521
# 159  app-server-student/2023/5/20/49e3c55c-4b44-4ef...         6066660
# 160  app-server-student/2023/5/20/6aba52b3-0057-4ea...         6066664
# 161  app-server-student/2023/5/20/319c94c3-a911-4b3...         6066673
# 162  app-server-student/2023/5/20/62292b2a-eee8-405...         6066713
#
#     last_message_sent_at last_completion_request_sent_at           created_at  \
# 0    2023-05-04 13:15:13                             NaN  2023-05-04 12:10:59
# 1    2023-05-05 02:20:54                             NaN  2023-05-05 01:51:54
# 2    2023-05-05 06:26:12                             NaN  2023-05-05 05:43:02
# 3    2023-05-05 17:23:25                             NaN  2023-05-05 16:35:45
# 4    2023-05-05 19:45:31                             NaN  2023-05-05 18:53:30
# ..                   ...                             ...                  ...
# 158  2023-05-20 05:29:11                             NaN  2023-05-20 05:04:47
# 159  2023-05-20 23:10:21                             NaN  2023-05-20 22:55:30
# 160  2023-05-20 23:17:18                             NaN  2023-05-20 23:13:40
# 161  2023-05-21 00:00:10                             NaN  2023-05-20 23:44:38
# 162  2023-05-21 01:12:36                             NaN  2023-05-20 23:47:36
#
#               updated_at                                  queried_image_url  \
# 0    1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 1    1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 2    1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 3    1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 4    1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# ..                   ...                                                ...
# 158  1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 159  1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 160  1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 161  1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 162  1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
#
#      review_id                           tutor_email  is_valid_retake  \
# 0           -1        leena.dawar@triviumservice.com              NaN
# 1           -1      reema.agarwal@triviumservice.com              NaN
# 2           -1      daljeet.kaur1@triviumservice.com              NaN
# 3           -1  sudip.chakraborty@triviumservice.com              NaN
# 4           -1        leena.dawar@triviumservice.com              NaN
# ..         ...                                   ...              ...
# 158         -1     swati.upadhyay@triviumservice.com              NaN
# 159         -1     swati.upadhyay@triviumservice.com              NaN
# 160         -1         salma.rani@triviumservice.com              NaN
# 161         -1         salma.rani@triviumservice.com              NaN
# 162         -1         mohit.garg@triviumservice.com              NaN
#
#      is_valid_report           started_at            closed_at  \
# 0                NaN  2023-05-04 13:13:55  2023-05-04 13:16:30
# 1                NaN  2023-05-05 02:00:10  2023-05-05 02:25:39
# 2                NaN  2023-05-05 06:24:47  2023-05-05 21:01:39
# 3                NaN  2023-05-05 17:15:08  2023-05-05 21:12:55
# 4                NaN  2023-05-05 19:24:16  2023-05-05 19:52:09
# ..               ...                  ...                  ...
# 158              NaN  2023-05-20 05:04:52  2023-05-20 05:41:32
# 159              NaN  2023-05-20 23:01:05  2023-05-20 23:12:20
# 160              NaN  2023-05-20 23:13:51  2023-05-20 23:26:51
# 161              NaN  2023-05-20 23:44:42  2023-05-21 00:12:48
# 162              NaN  2023-05-21 00:47:25  2023-05-21 01:14:11
#
#                solved_at     subject_tagged_by_tutor channel_leave_status  \
# 0    2023-05-04 13:15:13                    CALCULUS            NOT_LEAVE
# 1    2023-05-05 02:20:54                     ALGEBRA            NOT_LEAVE
# 2    2023-05-05 06:26:12                    CALCULUS            NOT_LEAVE
# 3    2023-05-05 17:23:24                     ALGEBRA            NOT_LEAVE
# 4    2023-05-05 19:45:30  STATISTICS_AND_PROBABILITY            NOT_LEAVE
# ..                   ...                         ...                  ...
# 158  2023-05-20 05:29:11                     ALGEBRA            NOT_LEAVE
# 159  2023-05-20 23:05:42                     ALGEBRA            NOT_LEAVE
# 160  2023-05-20 23:17:18                    CALCULUS            NOT_LEAVE
# 161  2023-05-21 00:00:10                    GEOMETRY            NOT_LEAVE
# 162  2023-05-21 01:12:36                     ALGEBRA                LEAVE
#
#      tutor_center_id          tutor_center_name  keycloak_email  \
# 0                  4  backoffice.center.trivium             NaN
# 1                  4  backoffice.center.trivium             NaN
# 2                  4  backoffice.center.trivium             NaN
# 3                  4  backoffice.center.trivium             NaN
# 4                  4  backoffice.center.trivium             NaN
# ..               ...                        ...             ...
# 158                4  backoffice.center.trivium             NaN
# 159                4  backoffice.center.trivium             NaN
# 160                4  backoffice.center.trivium             NaN
# 161                4  backoffice.center.trivium             NaN
# 162                4  backoffice.center.trivium             NaN
#
#                                     solution_image_url  reporter_id  \
# 0    https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 1    https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 2    https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 3    https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 4    https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# ..                                                 ...          ...
# 158  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 159  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 160  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 161  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 162  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
#
#             reporter_type pick_duration                        student_email  \
# 0    REPORTER_UNSPECIFIED      01:02:55                 anagp92003@gmail.com
# 1    REPORTER_UNSPECIFIED      00:08:16          unicornzslayyy101@gmail.com
# 2    REPORTER_UNSPECIFIED      00:41:45  xpxxzn2w6j@privaterelay.appleid.com
# 3    REPORTER_UNSPECIFIED      00:39:22                   anulpi26@gmail.com
# 4    REPORTER_UNSPECIFIED      00:30:45  8cnp7b456t@privaterelay.appleid.com
# ..                    ...           ...                                  ...
# 158  REPORTER_UNSPECIFIED      00:00:05  kdrc7bmfmn@privaterelay.appleid.com
# 159  REPORTER_UNSPECIFIED      00:05:35                 drkaminker@gmail.com
# 160  REPORTER_UNSPECIFIED      00:00:10  9ph56rmmnj@privaterelay.appleid.com
# 161  REPORTER_UNSPECIFIED      00:00:04  9ph56rmmnj@privaterelay.appleid.com
# 162  REPORTER_UNSPECIFIED      00:59:48  d8kxh94hrw@privaterelay.appleid.com
#
#     chatroom_report_reason  chat_report_reason_detail  \
# 0              UNSPECIFIED                        NaN
# 1              UNSPECIFIED                        NaN
# 2              UNSPECIFIED                        NaN
# 3              UNSPECIFIED                        NaN
# 4              UNSPECIFIED                        NaN
# ..                     ...                        ...
# 158            UNSPECIFIED                        NaN
# 159            UNSPECIFIED                        NaN
# 160            UNSPECIFIED                        NaN
# 161            UNSPECIFIED                        NaN
# 162            UNSPECIFIED                        NaN
#
#                                   auth_id  tutor_id  reviewer_email  \
# 0    3e210a9c-f2a1-48c0-98ff-8d0cfb2ba2c9      4999             NaN
# 1    5ac49aa2-2721-4446-8a6e-eddc516fac62      6439             NaN
# 2    16e7b590-58ca-4f1d-a0c1-99db8adb3e6d      3986             NaN
# 3    2defedfb-6db2-410d-be4f-3bbe3a06836b      6290             NaN
# 4    3e210a9c-f2a1-48c0-98ff-8d0cfb2ba2c9      4999             NaN
# ..                                    ...       ...             ...
# 158  ced21275-8aa6-4259-b2f6-2748c925db71      7801             NaN
# 159  ced21275-8aa6-4259-b2f6-2748c925db71      7801             NaN
# 160  31f302ad-374d-4386-8f54-bd3d69a951f6      4928             NaN
# 161  31f302ad-374d-4386-8f54-bd3d69a951f6      4928             NaN
# 162  f1897792-7684-4816-adf7-62d4ffe22acf      5262             NaN
#
#            reason  reposted_at engine_status
# 0    WRONG_ANSWER          NaN        SEARCH
# 1    WRONG_ANSWER          NaN        SEARCH
# 2    WRONG_ANSWER          NaN        SEARCH
# 3    WRONG_ANSWER          NaN        SEARCH
# 4    WRONG_ANSWER          NaN        SEARCH
# ..            ...          ...           ...
# 158  WRONG_ANSWER          NaN        SEARCH
# 159  WRONG_ANSWER          NaN        SEARCH
# 160  WRONG_ANSWER          NaN        SEARCH
# 161  WRONG_ANSWER          NaN        SEARCH
# 162  WRONG_ANSWER          NaN        SEARCH
#
# [163 rows x 44 columns]

# %%
df_pall = df_pall.sort_values('tutor_id')
df_pall
# Out:
#       no  task_id task_state review_state tutor_admin_id  student_rating  \
# 143  144  6859644     CLOSED         TODO     Unassigned               1
# 34    35  6848620     CLOSED         TODO     Unassigned               2
# 155  156  6861555     CLOSED         TODO     Unassigned               1
# 153  154  6861530     CLOSED         TODO     Unassigned               1
# 107  108  6856028     CLOSED         TODO     Unassigned               1
# ..   ...      ...        ...          ...            ...             ...
# 70    71  6852884     CLOSED         TODO     Unassigned               1
# 51    52  6850963     CLOSED         TODO     Unassigned               1
# 63    64  6851881     CLOSED         TODO     Unassigned               2
# 129  130  6857843     CLOSED         TODO     Unassigned               1
# 73    74  6853040     CLOSED         TODO     Unassigned               2
#
#      admin_rating  admin_comment  \
# 143           NaN            NaN
# 34            NaN            NaN
# 155           NaN            NaN
# 153           NaN            NaN
# 107           NaN            NaN
# ..            ...            ...
# 70            NaN            NaN
# 51            NaN            NaN
# 63            NaN            NaN
# 129           NaN            NaN
# 73            NaN            NaN
#
#                                          chat_room_url  \
# 143  sendbird_group_channel_102230683_c64c394b4a629...
# 34   sendbird_group_channel_102230683_352d7a2923d0a...
# 155  sendbird_group_channel_102230683_3e1a35a71d460...
# 153  sendbird_group_channel_102230683_7da13a8264e67...
# 107  sendbird_group_channel_102230683_81f661ca32b8b...
# ..                                                 ...
# 70   sendbird_group_channel_172018090_e7fdf74ac541d...
# 51   sendbird_group_channel_212855081_9464036b1a34f...
# 63   sendbird_group_channel_217344995_f7b1a7b48abfc...
# 129  sendbird_group_channel_219682263_241a250a5ae49...
# 73   sendbird_group_channel_173230962_e06fb0e670e2c...
#
#                  retake_request_reason  retake_request_reason_detail  \
# 143  RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 34   RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 155  RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 153  RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 107  RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# ..                                 ...                           ...
# 70   RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 51   RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 63   RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 129  RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
# 73   RETAKE_REQUEST_REASON_UNSPECIFIED                           NaN
#
#                                student_id  \
# 143  ef4f661c-e7cd-4ee2-bb9a-27171cc54099
# 34   904241c3-2c88-44bc-ac40-45f00b85a7b4
# 155  9d7c8eec-e930-4d18-8eba-a29398cc43ae
# 153  e4873ed3-2bce-450f-aaad-7b813ec0c839
# 107  9c45836e-58dc-4d00-9886-4b22e396f15e
# ..                                    ...
# 70   253be3fa-0148-4745-979d-fe9957fb1d44
# 51   35a94b7e-ac65-4215-a979-6b7ad479bd71
# 63   81f71d4f-0534-4bf0-a2e4-7ed940c4f75a
# 129  fedb54ad-049c-444a-8d27-3579e287d406
# 73   06955604-4774-4e0e-9e3e-3bc2e7865165
#
#                               queried_image_object_key  task_result_id  \
# 143  app-server-student/2023/5/18/71ac9d5b-466f-48b...         6064550
# 34   app-server-student/2023/5/8/e34665b5-fb32-486c...         6054236
# 155  app-server-student/2023/5/19/726dbe35-4d3a-494...         6066341
# 153  app-server-student/2023/5/19/5d4cceee-7887-4da...         6066315
# 107  app-server-student/2023/5/15/6a0f4de8-594d-492...         6061149
# ..                                                 ...             ...
# 70   app-server-student/2023/5/11/022c2e5f-8b3b-4d7...         6058170
# 51   app-server-student/2023/5/10/892828ab-e2c5-412...         6056384
# 63   app-server-student/2023/5/11/8d5fca1f-b98f-4bd...         6057283
# 129  app-server-student/2023/5/16/6569d0b1-4219-467...         6062876
# 73   app-server-student/2023/5/11/14723c10-9ad2-4d1...         6058330
#
#     last_message_sent_at last_completion_request_sent_at           created_at  \
# 143  2023-05-18 01:25:25                             NaN  2023-05-18 01:14:45
# 34   2023-05-08 23:31:56                             NaN  2023-05-08 22:34:14
# 155  2023-05-19 23:08:49                             NaN  2023-05-19 22:51:49
# 153  2023-05-19 22:37:44                             NaN  2023-05-19 22:15:10
# 107  2023-05-15 05:18:12                             NaN  2023-05-15 04:37:22
# ..                   ...                             ...                  ...
# 70   2023-05-11 19:04:11                             NaN  2023-05-11 19:02:19
# 51   2023-05-10 16:07:49                             NaN  2023-05-10 15:30:55
# 63   2023-05-11 02:36:06                             NaN  2023-05-11 01:33:15
# 129  2023-05-16 17:56:15                             NaN  2023-05-16 17:48:00
# 73   2023-05-11 21:23:57                             NaN  2023-05-11 20:53:57
#
#               updated_at                                  queried_image_url  \
# 143  1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 34   1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 155  1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 153  1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 107  1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# ..                   ...                                                ...
# 70   1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 51   1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 63   1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 129  1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
# 73   1970-01-01 00:00:00  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...
#
#      review_id                           tutor_email  is_valid_retake  \
# 143         -1      rajesh.maurya@triviumservice.com              NaN
# 34          -1      rajesh.maurya@triviumservice.com              NaN
# 155         -1      rajesh.maurya@triviumservice.com              NaN
# 153         -1      rajesh.maurya@triviumservice.com              NaN
# 107         -1      rajesh.maurya@triviumservice.com              NaN
# ..         ...                                   ...              ...
# 70          -1    jayesh.savaliya@triviumservice.com              NaN
# 51          -1    jayesh.savaliya@triviumservice.com              NaN
# 63          -1  meenakshi.narula1@triviumservice.com              NaN
# 129         -1       aniket.ghara@triviumservice.com              NaN
# 73          -1       aniket.ghara@triviumservice.com              NaN
#
#      is_valid_report           started_at            closed_at  \
# 143              NaN  2023-05-18 01:16:15  2023-05-18 01:29:49
# 34               NaN  2023-05-08 23:28:05  2023-05-09 01:42:43
# 155              NaN  2023-05-19 22:58:42  2023-05-19 23:16:46
# 153              NaN  2023-05-19 22:33:18  2023-05-19 22:39:47
# 107              NaN  2023-05-15 04:37:56  2023-05-15 05:32:53
# ..               ...                  ...                  ...
# 70               NaN  2023-05-11 19:02:23  2023-05-11 19:07:16
# 51               NaN  2023-05-10 16:02:00  2023-05-10 16:33:57
# 63               NaN  2023-05-11 02:31:32  2023-05-11 03:13:02
# 129              NaN  2023-05-16 17:53:25  2023-05-16 17:58:31
# 73               NaN  2023-05-11 20:55:13  2023-05-11 21:24:09
#
#                solved_at     subject_tagged_by_tutor channel_leave_status  \
# 143  2023-05-18 01:25:25                     ALGEBRA            NOT_LEAVE
# 34   2023-05-08 23:31:56  STATISTICS_AND_PROBABILITY            NOT_LEAVE
# 155  2023-05-19 23:08:49                     ALGEBRA            NOT_LEAVE
# 153  2023-05-19 22:37:44  STATISTICS_AND_PROBABILITY            NOT_LEAVE
# 107  2023-05-15 04:51:15                     ALGEBRA            NOT_LEAVE
# ..                   ...                         ...                  ...
# 70   2023-05-11 19:04:11  STATISTICS_AND_PROBABILITY            NOT_LEAVE
# 51   2023-05-10 16:07:37                    GEOMETRY            NOT_LEAVE
# 63   2023-05-11 02:36:06                    GEOMETRY            NOT_LEAVE
# 129  2023-05-16 17:56:06  STATISTICS_AND_PROBABILITY            NOT_LEAVE
# 73   2023-05-11 21:21:24                    GEOMETRY            NOT_LEAVE
#
#      tutor_center_id          tutor_center_name  keycloak_email  \
# 143                4  backoffice.center.trivium             NaN
# 34                 4  backoffice.center.trivium             NaN
# 155                4  backoffice.center.trivium             NaN
# 153                4  backoffice.center.trivium             NaN
# 107                4  backoffice.center.trivium             NaN
# ..               ...                        ...             ...
# 70                 4  backoffice.center.trivium             NaN
# 51                 4  backoffice.center.trivium             NaN
# 63                 4  backoffice.center.trivium             NaN
# 129                4  backoffice.center.trivium             NaN
# 73                 4  backoffice.center.trivium             NaN
#
#                                     solution_image_url  reporter_id  \
# 143  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 34   https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 155  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 153  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 107  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# ..                                                 ...          ...
# 70   https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 51   https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 63   https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 129  https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
# 73   https://d3hlidq5bf9vg0.cloudfront.net/app-serv...          NaN
#
#             reporter_type pick_duration                        student_email  \
# 143  REPORTER_UNSPECIFIED      00:01:30                  samsro240@gmail.com
# 34   REPORTER_UNSPECIFIED      00:53:50  hpdt52px2g@privaterelay.appleid.com
# 155  REPORTER_UNSPECIFIED      00:06:53  9ph56rmmnj@privaterelay.appleid.com
# 153  REPORTER_UNSPECIFIED      00:18:08  kdrc7bmfmn@privaterelay.appleid.com
# 107  REPORTER_UNSPECIFIED      00:00:34                najirjones2@gmail.com
# ..                    ...           ...                                  ...
# 70   REPORTER_UNSPECIFIED      00:00:04             allisahslanier@yahoo.com
# 51   REPORTER_UNSPECIFIED      00:31:04               mariahs1303@icloud.com
# 63   REPORTER_UNSPECIFIED      00:58:16     s543235@student.roundrockisd.org
# 129  REPORTER_UNSPECIFIED      00:05:25          armandorojodavid@icloud.com
# 73   REPORTER_UNSPECIFIED      00:01:16              chuysalinas27@gmail.com
#
#     chatroom_report_reason  chat_report_reason_detail  \
# 143            UNSPECIFIED                        NaN
# 34             UNSPECIFIED                        NaN
# 155            UNSPECIFIED                        NaN
# 153            UNSPECIFIED                        NaN
# 107            UNSPECIFIED                        NaN
# ..                     ...                        ...
# 70             UNSPECIFIED                        NaN
# 51             UNSPECIFIED                        NaN
# 63             UNSPECIFIED                        NaN
# 129            UNSPECIFIED                        NaN
# 73             UNSPECIFIED                        NaN
#
#                                   auth_id  tutor_id  reviewer_email  \
# 143  5b01b061-9316-49ea-a5bb-06382107aa06      3979             NaN
# 34   5b01b061-9316-49ea-a5bb-06382107aa06      3979             NaN
# 155  5b01b061-9316-49ea-a5bb-06382107aa06      3979             NaN
# 153  5b01b061-9316-49ea-a5bb-06382107aa06      3979             NaN
# 107  5b01b061-9316-49ea-a5bb-06382107aa06      3979             NaN
# ..                                    ...       ...             ...
# 70   e6ac33e7-3a7c-4c9b-9ad5-d6958e147d3e      7924             NaN
# 51   e6ac33e7-3a7c-4c9b-9ad5-d6958e147d3e      7924             NaN
# 63   fa19ea3d-9a1a-4059-b36d-9d79e2c8e8ae      7970             NaN
# 129  7a606a7a-311e-4e31-8176-21d1bdad257c      8210             NaN
# 73   7a606a7a-311e-4e31-8176-21d1bdad257c      8210             NaN
#
#                         reason  reposted_at engine_status
# 143           POOR_HANDWRITING          NaN        SEARCH
# 34                WRONG_ANSWER          NaN        SEARCH
# 155               WRONG_ANSWER          NaN        SEARCH
# 153               WRONG_ANSWER          NaN        SEARCH
# 107               WRONG_ANSWER          NaN        SEARCH
# ..                         ...          ...           ...
# 70                WRONG_ANSWER          NaN        SEARCH
# 51   NO_EXPLANATION_WORK_SHOWN          NaN        SEARCH
# 63                WRONG_ANSWER          NaN        SEARCH
# 129               WRONG_ANSWER          NaN        SEARCH
# 73                WRONG_ANSWER          NaN           ASK
#
# [163 rows x 44 columns]

# %%
grp1 = df_pall.groupby(['tutor_id']).agg({'student_rating': lambda x: ','.join(str(i) for i in x.unique())}).reset_index()
grp1
# Out:
#     tutor_id student_rating
# 0       3979            1,2
# 1       3986          1,3,2
# 2       3996            1,2
# 3       4927              1
# 4       4928          1,3,2
# 5       4966          1,2,3
# 6       4980            1,3
# 7       4983              1
# 8       4986            3,1
# 9       4999            3,1
# 10      5262              1
# 11      5301            3,1
# 12      5343            1,3
# 13      5437              1
# 14      5575            1,3
# 15      5577              3
# 16      5590              1
# 17      5714              1
# 18      5808              1
# 19      5810            1,3
# 20      5822              3
# 21      6064              3
# 22      6089          1,3,2
# 23      6290            2,1
# 24      6439          1,2,3
# 25      6451            2,1
# 26      6594          3,1,2
# 27      6793              1
# 28      6797              1
# 29      6877              3
# 30      7362              1
# 31      7801          2,1,3
# 32      7810          3,1,2
# 33      7833              3
# 34      7835              1
# 35      7836              3
# 36      7923            1,3
# 37      7924              1
# 38      7970              2
# 39      8210            1,2

# %%
# Split the comma-separated values into a list of integers
grp1['value_list'] = grp1['student_rating'].apply(lambda x: [int(val) for val in x.split(',')])

# Calculate the maximum for each row and create a new column
grp1['max_value'] = grp1['value_list'].apply(max)
grp1 = grp1[['tutor_id', 'student_rating', 'max_value']]
grp1
# Out:
#     tutor_id student_rating  max_value
# 0       3979            2,1          2
# 1       3986          1,2,3          3
# 2       3996            1,2          2
# 3       4927              1          1
# 4       4928          1,3,2          3
# 5       4966          1,2,3          3
# 6       4980            1,3          3
# 7       4983              1          1
# 8       4986            3,1          3
# 9       4999            1,3          3
# 10      5262              1          1
# 11      5301            3,1          3
# 12      5343            1,3          3
# 13      5437              1          1
# 14      5575            3,1          3
# 15      5577              3          3
# 16      5590              1          1
# 17      5714              1          1
# 18      5808              1          1
# 19      5810            3,1          3
# 20      5822              3          3
# 21      6064              3          3
# 22      6089          2,3,1          3
# 23      6290            2,1          2
# 24      6439          3,1,2          3
# 25      6451            2,1          2
# 26      6594          1,2,3          3
# 27      6793              1          1
# 28      6797              1          1
# 29      6877              3          3
# 30      7362              1          1
# 31      7801          3,1,2          3
# 32      7810          1,3,2          3
# 33      7833              3          3
# 34      7835              1          1
# 35      7836              3          3
# 36      7923            1,3          3
# 37      7924              1          1
# 38      7970              2          2
# 39      8210            2,1          2
