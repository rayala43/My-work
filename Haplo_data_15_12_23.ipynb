# %%
import numpy as np
import pandas as pd
import polars as pl
import sys
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px


pd.set_option('display.max_columns',None)
import psycopg2


#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Algorithms to use
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

#Metrics to evaluate the model
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve

import warnings
warnings.filterwarnings("ignore")

#importing PCA and TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/KHAIGPRX959_final_DP.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
df.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
df['HET'] = df['INFO'].str.extract(r'HET=(\d)')
df['HOM'] = df['INFO'].str.extract(r'HOM=(\d)')
# Create a new column 'Zygosity' based on conditions
df['Zygosity'] = ''
df.loc[df['HOM'] == '1', 'Zygosity'] = 'Homozygous'
df.loc[df['HET'] == '1', 'Zygosity'] = 'Heterozygous'
df = df.drop(columns=['HET', 'HOM'], axis = 1)
data = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/RSIDS_POSITION_DBSNP.xlsx')
df = pd.merge(df, data, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'inner', sort = False)
df2 = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/13_Genes_Key_Variants_Coordinates.csv', sep = '\t')
df2 = df2[['CHROM', 'POS', 'REF', 'ALT', 'Haplotype']]
merged = pd.merge(df, df2, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'left', sort = False)
madhu = merged.copy()
madhu['rsID_mapped'] = madhu.groupby('Haplotype')['rsID'].transform(lambda x: ','.join(set(x)))
madhu['Zygosity_mapped'] = madhu.groupby(['Haplotype'])['Zygosity'].transform(lambda x: ','.join(x))
madhu.drop_duplicates(subset='Haplotype', inplace=True)
madhu
# Out:
#     CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0    chr8  18400285    rs1041983   C   T    .   PASS
# 1    chr8  18400285    rs1041983   C   T    .   PASS
# 2    chr8  18400285    rs1041983   C   T    .   PASS
# 3    chr8  18400285    rs1041983   C   T    .   PASS
# 4    chr8  18400285    rs1041983   C   T    .   PASS
# 5    chr8  18400285    rs1041983   C   T    .   PASS
# 6    chr8  18400285    rs1041983   C   T    .   PASS
# 9    chr8  18400593    rs1799930   G   A    .   PASS
# 13   chr8  18400806       rs1208   G   A    .   PASS
# 14   chr8  18400806       rs1208   G   A    .   PASS
# 15   chr8  18400806       rs1208   G   A    .   PASS
# 18   chr8  18400860    rs1799931   G   A    .   PASS
# 21  chr10  94775367   rs12769205   A   G    .   PASS
# 23  chr13  48045719  rs116855232   C   T    .   PASS
# 24  chr13  48045719  rs116855232   C   T    .   PASS
# 25  chr19  41009358    rs2279343   A   G    .   PASS
# 26  chr19  41009358    rs2279343   A   G    .   PASS
# 27  chr19  41009358    rs2279343   A   G    .   PASS
#
#                                                  INFO  \
# 0   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 1   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 2   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 3   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 4   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 5   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 6   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 9   ADP=28;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.735,0.2...
# 13  ADP=44;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.3229,0....
# 14  ADP=44;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.3229,0....
# 15  ADP=44;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.3229,0....
# 18  ADP=41;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9227,0....
# 21  ADP=53;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.7716,0....
# 23  ADP=24;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9605,0....
# 24  ADP=24;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9605,0....
# 25  ADP=18;WT=0;HET=0;HOM=1;NC=0;ASP;G5;G5A;GENEIN...
# 26  ADP=18;WT=0;HET=0;HOM=1;NC=0;ASP;G5;G5A;GENEIN...
# 27  ADP=18;WT=0;HET=0;HOM=1;NC=0;ASP;G5;G5A;GENEIN...
#
#                                                FORMAT  \
# 0   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 5   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 6   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 9   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 13  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 14  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 15  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 18  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 21  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 23  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 24  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 25  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 26  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 27  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                SAMPLE      Zygosity  \
# 0    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 1    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 2    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 3    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 4    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 5    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 6    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 9   0/1:38:28:28:17:11:39.29%:1.4422E-4:67:60:14:3...  Heterozygous
# 13   1/1:254:44:44:0:44:100%:3.8097E-26:0:63:0:0:39:5    Homozygous
# 14   1/1:254:44:44:0:44:100%:3.8097E-26:0:63:0:0:39:5    Homozygous
# 15   1/1:254:44:44:0:44:100%:3.8097E-26:0:63:0:0:39:5    Homozygous
# 18  0/1:44:41:41:27:13:31.71%:3.8184E-5:68:59:24:3...  Heterozygous
# 21  0/1:86:53:53:29:24:45.28%:2.005E-9:66:56:26:3:...  Heterozygous
# 23   0/1:44:24:24:12:12:50%:3.8815E-5:68:61:12:0:11:1  Heterozygous
# 24   0/1:44:24:24:12:12:50%:3.8815E-5:68:61:12:0:11:1  Heterozygous
# 25    1/1:99:18:18:0:18:100%:1.1019E-10:0:55:0:0:13:5    Homozygous
# 26    1/1:99:18:18:0:18:100%:1.1019E-10:0:55:0:0:13:5    Homozygous
# 27    1/1:99:18:18:0:18:100%:1.1019E-10:0:55:0:0:13:5    Homozygous
#
#    rsID_updated  Haplotype                           rsID_mapped  \
# 0     rs1041983     NAT2*4  rs1799930,rs1041983,rs1208,rs1799931
# 1     rs1041983    NAT2*6A                   rs1799930,rs1041983
# 2     rs1041983    NAT2*6J         rs1799930,rs1041983,rs1799931
# 3     rs1041983    NAT2*6O                   rs1799930,rs1041983
# 4     rs1041983    NAT2*7B                   rs1041983,rs1799931
# 5     rs1041983    NAT2*7G                   rs1041983,rs1799931
# 6     rs1041983   NAT2*13A                             rs1041983
# 9     rs1799930    NAT2*6B                             rs1799930
# 13       rs1208    NAT2*5B                                rs1208
# 14       rs1208    NAT2*5C                                rs1208
# 15       rs1208   NAT2*12A                                rs1208
# 18    rs1799931    NAT2*7A                             rs1799931
# 21   rs12769205  CYP2C19*2                  rs12769205,rs4244285
# 23  rs116855232   NUDT15*2                           rs116855232
# 24  rs116855232   NUDT15*3                           rs116855232
# 25    rs2279343   CYP2B6*4                             rs2279343
# 26    rs2279343   CYP2B6*6                             rs2279343
# 27    rs2279343  CYP2B6*26                             rs2279343
#
#                                     Zygosity_mapped
# 0   Homozygous,Heterozygous,Homozygous,Heterozygous
# 1                           Homozygous,Heterozygous
# 2              Homozygous,Heterozygous,Heterozygous
# 3                           Homozygous,Heterozygous
# 4                           Homozygous,Heterozygous
# 5                           Homozygous,Heterozygous
# 6                                        Homozygous
# 9                                      Heterozygous
# 13                                       Homozygous
# 14                                       Homozygous
# 15                                       Homozygous
# 18                                     Heterozygous
# 21                        Heterozygous,Heterozygous
# 23                                     Heterozygous
# 24                                     Heterozygous
# 25                                       Homozygous
# 26                                       Homozygous
# 27                                       Homozygous

# %%
madhu['rsID_mapped_sorted'] = madhu['rsID_mapped'].apply(lambda x: ','.join(sorted(x.split(','))))
madhu
# Out:
#     CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0    chr8  18400285    rs1041983   C   T    .   PASS
# 1    chr8  18400285    rs1041983   C   T    .   PASS
# 2    chr8  18400285    rs1041983   C   T    .   PASS
# 3    chr8  18400285    rs1041983   C   T    .   PASS
# 4    chr8  18400285    rs1041983   C   T    .   PASS
# 5    chr8  18400285    rs1041983   C   T    .   PASS
# 6    chr8  18400285    rs1041983   C   T    .   PASS
# 9    chr8  18400593    rs1799930   G   A    .   PASS
# 13   chr8  18400806       rs1208   G   A    .   PASS
# 14   chr8  18400806       rs1208   G   A    .   PASS
# 15   chr8  18400806       rs1208   G   A    .   PASS
# 18   chr8  18400860    rs1799931   G   A    .   PASS
# 21  chr10  94775367   rs12769205   A   G    .   PASS
# 23  chr13  48045719  rs116855232   C   T    .   PASS
# 24  chr13  48045719  rs116855232   C   T    .   PASS
# 25  chr19  41009358    rs2279343   A   G    .   PASS
# 26  chr19  41009358    rs2279343   A   G    .   PASS
# 27  chr19  41009358    rs2279343   A   G    .   PASS
#
#                                                  INFO  \
# 0   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 1   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 2   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 3   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 4   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 5   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 6   ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6026,0....
# 9   ADP=28;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.735,0.2...
# 13  ADP=44;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.3229,0....
# 14  ADP=44;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.3229,0....
# 15  ADP=44;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.3229,0....
# 18  ADP=41;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9227,0....
# 21  ADP=53;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.7716,0....
# 23  ADP=24;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9605,0....
# 24  ADP=24;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9605,0....
# 25  ADP=18;WT=0;HET=0;HOM=1;NC=0;ASP;G5;G5A;GENEIN...
# 26  ADP=18;WT=0;HET=0;HOM=1;NC=0;ASP;G5;G5A;GENEIN...
# 27  ADP=18;WT=0;HET=0;HOM=1;NC=0;ASP;G5;G5A;GENEIN...
#
#                                                FORMAT  \
# 0   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 5   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 6   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 9   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 13  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 14  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 15  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 18  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 21  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 23  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 24  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 25  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 26  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 27  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                SAMPLE      Zygosity  \
# 0    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 1    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 2    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 3    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 4    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 5    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 6    1/1:182:33:32:0:32:100%:5.4567E-19:0:57:0:0:24:8    Homozygous
# 9   0/1:38:28:28:17:11:39.29%:1.4422E-4:67:60:14:3...  Heterozygous
# 13   1/1:254:44:44:0:44:100%:3.8097E-26:0:63:0:0:39:5    Homozygous
# 14   1/1:254:44:44:0:44:100%:3.8097E-26:0:63:0:0:39:5    Homozygous
# 15   1/1:254:44:44:0:44:100%:3.8097E-26:0:63:0:0:39:5    Homozygous
# 18  0/1:44:41:41:27:13:31.71%:3.8184E-5:68:59:24:3...  Heterozygous
# 21  0/1:86:53:53:29:24:45.28%:2.005E-9:66:56:26:3:...  Heterozygous
# 23   0/1:44:24:24:12:12:50%:3.8815E-5:68:61:12:0:11:1  Heterozygous
# 24   0/1:44:24:24:12:12:50%:3.8815E-5:68:61:12:0:11:1  Heterozygous
# 25    1/1:99:18:18:0:18:100%:1.1019E-10:0:55:0:0:13:5    Homozygous
# 26    1/1:99:18:18:0:18:100%:1.1019E-10:0:55:0:0:13:5    Homozygous
# 27    1/1:99:18:18:0:18:100%:1.1019E-10:0:55:0:0:13:5    Homozygous
#
#    rsID_updated  Haplotype                           rsID_mapped  \
# 0     rs1041983     NAT2*4  rs1799930,rs1041983,rs1208,rs1799931
# 1     rs1041983    NAT2*6A                   rs1799930,rs1041983
# 2     rs1041983    NAT2*6J         rs1799930,rs1041983,rs1799931
# 3     rs1041983    NAT2*6O                   rs1799930,rs1041983
# 4     rs1041983    NAT2*7B                   rs1041983,rs1799931
# 5     rs1041983    NAT2*7G                   rs1041983,rs1799931
# 6     rs1041983   NAT2*13A                             rs1041983
# 9     rs1799930    NAT2*6B                             rs1799930
# 13       rs1208    NAT2*5B                                rs1208
# 14       rs1208    NAT2*5C                                rs1208
# 15       rs1208   NAT2*12A                                rs1208
# 18    rs1799931    NAT2*7A                             rs1799931
# 21   rs12769205  CYP2C19*2                  rs12769205,rs4244285
# 23  rs116855232   NUDT15*2                           rs116855232
# 24  rs116855232   NUDT15*3                           rs116855232
# 25    rs2279343   CYP2B6*4                             rs2279343
# 26    rs2279343   CYP2B6*6                             rs2279343
# 27    rs2279343  CYP2B6*26                             rs2279343
#
#                                     Zygosity_mapped  \
# 0   Homozygous,Heterozygous,Homozygous,Heterozygous
# 1                           Homozygous,Heterozygous
# 2              Homozygous,Heterozygous,Heterozygous
# 3                           Homozygous,Heterozygous
# 4                           Homozygous,Heterozygous
# 5                           Homozygous,Heterozygous
# 6                                        Homozygous
# 9                                      Heterozygous
# 13                                       Homozygous
# 14                                       Homozygous
# 15                                       Homozygous
# 18                                     Heterozygous
# 21                        Heterozygous,Heterozygous
# 23                                     Heterozygous
# 24                                     Heterozygous
# 25                                       Homozygous
# 26                                       Homozygous
# 27                                       Homozygous
#
#                       rsID_mapped_sorted
# 0   rs1041983,rs1208,rs1799930,rs1799931
# 1                    rs1041983,rs1799930
# 2          rs1041983,rs1799930,rs1799931
# 3                    rs1041983,rs1799930
# 4                    rs1041983,rs1799931
# 5                    rs1041983,rs1799931
# 6                              rs1041983
# 9                              rs1799930
# 13                                rs1208
# 14                                rs1208
# 15                                rs1208
# 18                             rs1799931
# 21                  rs12769205,rs4244285
# 23                           rs116855232
# 24                           rs116855232
# 25                             rs2279343
# 26                             rs2279343
# 27                             rs2279343

# %%
df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/KHAIGPRX959_final_DP.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
df.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
df['HET'] = df['INFO'].str.extract(r'HET=(\d)')
df['HOM'] = df['INFO'].str.extract(r'HOM=(\d)')
# Create a new column 'Zygosity' based on conditions
df['Zygosity'] = ''
df.loc[df['HOM'] == '1', 'Zygosity'] = 'Homozygous'
df.loc[df['HET'] == '1', 'Zygosity'] = 'Heterozygous'
df = df.drop(columns=['HET', 'HOM'], axis = 1)
data = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/RSIDS_POSITION_DBSNP.xlsx')
df = pd.merge(df, data, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'inner', sort = False)
df2 = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/13_Genes_Key_Variants_Coordinates.csv', sep = '\t')
df2 = df2[['CHROM', 'POS', 'REF', 'ALT', 'Haplotype']]
merged = pd.merge(df, df2, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'left', sort = False)
madhu = merged.copy()
madhu['rsID_mapped'] = madhu.groupby('Haplotype')['rsID'].transform(lambda x: ','.join(set(x)))
madhu['Zygosity_mapped'] = madhu.groupby(['Haplotype'])['Zygosity'].transform(lambda x: ','.join(x))
madhu.drop_duplicates(subset='Haplotype', inplace=True)

madhu['rsID_mapped_sorted'] = madhu['rsID_mapped'].apply(lambda x: ','.join(sorted(x.split(','))))
madhu = madhu.drop(columns=['rsID_updated', 'Haplotype'], axis=1)
data = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Multiple_Positions.xlsx')
data = data.rename({'Haplotype':'Haplotype_updated', 'rsID':'rsID_mapped'}, axis = 1)
data['rsID_mapped_sorted'] = data['rsID_mapped'].apply(lambda x: ','.join(sorted(x.split(','))))
data = data.drop(columns=['rsID_mapped'], axis=1)
mapped_df = pd.merge(madhu, data, on = 'rsID_mapped_sorted', how = 'inner', sort = False)
mapped_df.drop_duplicates(subset='Haplotype_updated', inplace=True)
mapped_df = mapped_df.drop(columns=['Zygosity'], axis=1)
mapped_df = mapped_df[['rsID_mapped_sorted', 'Zygosity_mapped', 'Haplotype_updated']]
mapped_df
# Out:
#               rsID_mapped_sorted                       Zygosity_mapped  \
# 0            rs1041983,rs1799930               Homozygous,Heterozygous
# 2  rs1041983,rs1799930,rs1799931  Homozygous,Heterozygous,Heterozygous
# 3            rs1041983,rs1799931               Homozygous,Heterozygous
# 5           rs12769205,rs4244285             Heterozygous,Heterozygous
#
#   Haplotype_updated
# 0           NAT2*6A
# 2           NAT2*6J
# 3           NAT2*7B
# 5         CYP2C19*2

# %% [markdown]
# ## check the sorting

# %%
df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/KHAIGPRX959_final_DP.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
df.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
df['HET'] = df['INFO'].str.extract(r'HET=(\d)')
df['HOM'] = df['INFO'].str.extract(r'HOM=(\d)')
# Create a new column 'Zygosity' based on conditions
df['Zygosity'] = ''
df.loc[df['HOM'] == '1', 'Zygosity'] = 'Homozygous'
df.loc[df['HET'] == '1', 'Zygosity'] = 'Heterozygous'
df = df.drop(columns=['HET', 'HOM'], axis = 1)
data = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/RSIDS_POSITION_DBSNP.xlsx')
df = pd.merge(df, data, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'inner', sort = False)
df2 = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/13_Genes_Key_Variants_Coordinates.csv', sep = '\t')
df2 = df2[['CHROM', 'POS', 'REF', 'ALT', 'Haplotype']]
merged = pd.merge(df, df2, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'left', sort = False)
madhu = merged.copy()
madhu['rsID_mapped'] = madhu.groupby('Haplotype')['rsID'].transform(lambda x: ','.join(set(x)))
madhu['Zygosity_mapped'] = madhu.groupby(['Haplotype'])['Zygosity'].transform(lambda x: ','.join(x))
madhu.drop_duplicates(subset='Haplotype', inplace=True)

madhu['rsID_mapped_sorted'] = madhu['rsID_mapped'].apply(lambda x: ','.join(sorted(x.split(','))))
madhu = madhu.drop(columns=['rsID_updated', 'Haplotype'], axis=1)
data = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Multiple_Positions.xlsx')
data = data.rename({'Haplotype':'Haplotype_updated', 'rsID':'rsID_mapped'}, axis = 1)
data['rsID_mapped_sorted'] = data['rsID_mapped'].apply(lambda x: ','.join(sorted(x.split(','))))
data = data.drop(columns=['rsID_mapped'], axis=1)
mapped_df = pd.merge(madhu, data, on = 'rsID_mapped_sorted', how = 'inner', sort = False)
mapped_df.drop_duplicates(subset='Haplotype_updated', inplace=True)
mapped_df = mapped_df.drop(columns=['Zygosity'], axis=1)
mapped_df = mapped_df[['rsID_mapped', 'Zygosity_mapped', 'Haplotype_updated']]
mapped_df
# Out:
#                      rsID_mapped                       Zygosity_mapped  \
# 0            rs1799930,rs1041983               Homozygous,Heterozygous
# 2  rs1799930,rs1041983,rs1799931  Homozygous,Heterozygous,Heterozygous
# 3            rs1041983,rs1799931               Homozygous,Heterozygous
# 5           rs12769205,rs4244285             Heterozygous,Heterozygous
#
#   Haplotype_updated
# 0           NAT2*6A
# 2           NAT2*6J
# 3           NAT2*7B
# 5         CYP2C19*2

# %%
df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/KHAIGPRX959_final_DP.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
df.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
df['HET'] = df['INFO'].str.extract(r'HET=(\d)')
df['HOM'] = df['INFO'].str.extract(r'HOM=(\d)')
# Create a new column 'Zygosity' based on conditions
df['Zygosity'] = ''
df.loc[df['HOM'] == '1', 'Zygosity'] = 'Homozygous'
df.loc[df['HET'] == '1', 'Zygosity'] = 'Heterozygous'
df = df.drop(columns=['HET', 'HOM'], axis = 1)
data = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/RSIDS_POSITION_DBSNP.xlsx')
df = pd.merge(df, data, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'inner', sort = False)
df[df['rsID_updated'] == 'rs1799930']
# Out:
#   CHROM       POS       rsID REF ALT QUAL FILTER  \
# 1  chr8  18400593  rs1799930   G   A    .   PASS
#
#                                                 INFO  \
# 1  ADP=28;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.735,0.2...
#
#                                               FORMAT  \
# 1  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                               SAMPLE      Zygosity  \
# 1  0/1:38:28:28:17:11:39.29%:1.4422E-4:67:60:14:3...  Heterozygous
#
#   rsID_updated
# 1    rs1799930

# %%
df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/KHAIGPRX981_final_DP.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
df.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
df['HET'] = df['INFO'].str.extract(r'HET=(\d)')
df['HOM'] = df['INFO'].str.extract(r'HOM=(\d)')
# Create a new column 'Zygosity' based on conditions
df['Zygosity'] = ''
df.loc[df['HOM'] == '1', 'Zygosity'] = 'Homozygous'
df.loc[df['HET'] == '1', 'Zygosity'] = 'Heterozygous'
df = df.drop(columns=['HET', 'HOM'], axis = 1)
data = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/RSIDS_POSITION_DBSNP.xlsx')
df = pd.merge(df, data, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'inner', sort = False)
df
# Out:
#    CHROM       POS        rsID REF ALT QUAL FILTER  \
# 0   chr8  18400285   rs1041983   C   T    .   PASS
# 1   chr8  18400593   rs1799930   G   A    .   PASS
# 2  chr10  94775367  rs12769205   A   G    .   PASS
# 3  chr19  41006936   rs3745274   G   T    .   PASS
# 4  chr19  41009358   rs2279343   A   G    .   PASS
#
#                                                 INFO  \
# 0  ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 1  ADP=35;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.735,0.2...
# 2  ADP=51;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.7716,0....
# 3  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.684...
# 4  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEIN...
#
#                                               FORMAT  \
# 0  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                               SAMPLE      Zygosity  \
# 0  0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 1  0/1:57:35:35:19:16:45.71%:1.637E-6:60:54:15:4:...  Heterozygous
# 2  1/1:255:51:51:1:50:98.04%:1.3013E-28:74:51:1:0...    Homozygous
# 3  0/1:35:22:22:12:10:45.45%:2.6061E-4:61:55:11:1...  Heterozygous
# 4  0/1:31:22:22:13:9:40.91%:7.0165E-4:60:52:12:1:4:5  Heterozygous
#
#   rsID_updated
# 0    rs1041983
# 1    rs1799930
# 2   rs12769205
# 3    rs3745274
# 4    rs2279343

# %%
df2 = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/13_Genes_Key_Variants_Coordinates.csv', sep = '\t')
df2 = df2[['CHROM', 'POS', 'REF', 'ALT', 'Haplotype']]
df2
# Out:
#      CHROM          POS REF ALT              Haplotype
# 0    chr19   40848628.0   A   T               CYP2A6*2
# 1    chr19   40843869.0   A   G               CYP2A6*7
# 2    chr19   40843749.0  CC   C               CYP2A6*7
# 3    chr19   40843746.0   T   C               CYP2A6*7
# 4    chr19   40843742.0   G   A               CYP2A6*7
# ..     ...          ...  ..  ..                    ...
# 724   chrX  154536019.0   G   A         G6PD*Musashino
# 725   chrX  154536151.0   G   A            G6PD*Kambos
# 726   chrX  154532258.0   G   A  G6PD*Kamiube, Keelung
# 727   chrX  154546116.0   C   T             G6PD*Lages
# 728   chrX  154533004.0   C   T            G6PD*Insuli
#
# [729 rows x 5 columns]

# %%
merged = pd.merge(df, df2, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'left', sort = False)
merged
# Out:
#     CHROM       POS        rsID REF ALT QUAL FILTER  \
# 0    chr8  18400285   rs1041983   C   T    .   PASS
# 1    chr8  18400285   rs1041983   C   T    .   PASS
# 2    chr8  18400285   rs1041983   C   T    .   PASS
# 3    chr8  18400285   rs1041983   C   T    .   PASS
# 4    chr8  18400285   rs1041983   C   T    .   PASS
# 5    chr8  18400285   rs1041983   C   T    .   PASS
# 6    chr8  18400285   rs1041983   C   T    .   PASS
# 7    chr8  18400593   rs1799930   G   A    .   PASS
# 8    chr8  18400593   rs1799930   G   A    .   PASS
# 9    chr8  18400593   rs1799930   G   A    .   PASS
# 10   chr8  18400593   rs1799930   G   A    .   PASS
# 11   chr8  18400593   rs1799930   G   A    .   PASS
# 12  chr10  94775367  rs12769205   A   G    .   PASS
# 13  chr19  41006936   rs3745274   G   T    .   PASS
# 14  chr19  41006936   rs3745274   G   T    .   PASS
# 15  chr19  41006936   rs3745274   G   T    .   PASS
# 16  chr19  41009358   rs2279343   A   G    .   PASS
# 17  chr19  41009358   rs2279343   A   G    .   PASS
# 18  chr19  41009358   rs2279343   A   G    .   PASS
#
#                                                  INFO  \
# 0   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 1   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 2   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 3   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 4   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 5   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 6   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 7   ADP=35;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.735,0.2...
# 8   ADP=35;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.735,0.2...
# 9   ADP=35;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.735,0.2...
# 10  ADP=35;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.735,0.2...
# 11  ADP=35;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.735,0.2...
# 12  ADP=51;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.7716,0....
# 13  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.684...
# 14  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.684...
# 15  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.684...
# 16  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEIN...
# 17  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEIN...
# 18  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEIN...
#
#                                                FORMAT  \
# 0   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 5   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 6   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 7   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 8   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 9   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 10  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 11  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 12  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 13  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 14  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 15  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 16  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 17  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 18  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                SAMPLE      Zygosity  \
# 0   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 1   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 2   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 3   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 4   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 5   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 6   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 7   0/1:57:35:35:19:16:45.71%:1.637E-6:60:54:15:4:...  Heterozygous
# 8   0/1:57:35:35:19:16:45.71%:1.637E-6:60:54:15:4:...  Heterozygous
# 9   0/1:57:35:35:19:16:45.71%:1.637E-6:60:54:15:4:...  Heterozygous
# 10  0/1:57:35:35:19:16:45.71%:1.637E-6:60:54:15:4:...  Heterozygous
# 11  0/1:57:35:35:19:16:45.71%:1.637E-6:60:54:15:4:...  Heterozygous
# 12  1/1:255:51:51:1:50:98.04%:1.3013E-28:74:51:1:0...    Homozygous
# 13  0/1:35:22:22:12:10:45.45%:2.6061E-4:61:55:11:1...  Heterozygous
# 14  0/1:35:22:22:12:10:45.45%:2.6061E-4:61:55:11:1...  Heterozygous
# 15  0/1:35:22:22:12:10:45.45%:2.6061E-4:61:55:11:1...  Heterozygous
# 16  0/1:31:22:22:13:9:40.91%:7.0165E-4:60:52:12:1:4:5  Heterozygous
# 17  0/1:31:22:22:13:9:40.91%:7.0165E-4:60:52:12:1:4:5  Heterozygous
# 18  0/1:31:22:22:13:9:40.91%:7.0165E-4:60:52:12:1:4:5  Heterozygous
#
#    rsID_updated  Haplotype
# 0     rs1041983     NAT2*4
# 1     rs1041983    NAT2*6A
# 2     rs1041983    NAT2*6J
# 3     rs1041983    NAT2*6O
# 4     rs1041983    NAT2*7B
# 5     rs1041983    NAT2*7G
# 6     rs1041983   NAT2*13A
# 7     rs1799930     NAT2*4
# 8     rs1799930    NAT2*6A
# 9     rs1799930    NAT2*6B
# 10    rs1799930    NAT2*6J
# 11    rs1799930    NAT2*6O
# 12   rs12769205  CYP2C19*2
# 13    rs3745274   CYP2B6*6
# 14    rs3745274   CYP2B6*9
# 15    rs3745274  CYP2B6*26
# 16    rs2279343   CYP2B6*4
# 17    rs2279343   CYP2B6*6
# 18    rs2279343  CYP2B6*26

# %%
madhu = merged.copy()
madhu['rsID_mapped'] = madhu.groupby('Haplotype')['rsID'].transform(lambda x: ','.join(set(x)))
madhu['Zygosity_mapped'] = madhu.groupby(['Haplotype'])['Zygosity'].transform(lambda x: ','.join(x))
madhu.drop_duplicates(subset='Haplotype', inplace=True)
madhu
# Out:
#     CHROM       POS        rsID REF ALT QUAL FILTER  \
# 0    chr8  18400285   rs1041983   C   T    .   PASS
# 1    chr8  18400285   rs1041983   C   T    .   PASS
# 2    chr8  18400285   rs1041983   C   T    .   PASS
# 3    chr8  18400285   rs1041983   C   T    .   PASS
# 4    chr8  18400285   rs1041983   C   T    .   PASS
# 5    chr8  18400285   rs1041983   C   T    .   PASS
# 6    chr8  18400285   rs1041983   C   T    .   PASS
# 9    chr8  18400593   rs1799930   G   A    .   PASS
# 12  chr10  94775367  rs12769205   A   G    .   PASS
# 13  chr19  41006936   rs3745274   G   T    .   PASS
# 14  chr19  41006936   rs3745274   G   T    .   PASS
# 15  chr19  41006936   rs3745274   G   T    .   PASS
# 16  chr19  41009358   rs2279343   A   G    .   PASS
#
#                                                  INFO  \
# 0   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 1   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 2   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 3   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 4   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 5   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 6   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 9   ADP=35;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.735,0.2...
# 12  ADP=51;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.7716,0....
# 13  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.684...
# 14  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.684...
# 15  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.684...
# 16  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEIN...
#
#                                                FORMAT  \
# 0   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 5   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 6   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 9   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 12  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 13  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 14  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 15  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 16  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                SAMPLE      Zygosity  \
# 0   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 1   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 2   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 3   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 4   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 5   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 6   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 9   0/1:57:35:35:19:16:45.71%:1.637E-6:60:54:15:4:...  Heterozygous
# 12  1/1:255:51:51:1:50:98.04%:1.3013E-28:74:51:1:0...    Homozygous
# 13  0/1:35:22:22:12:10:45.45%:2.6061E-4:61:55:11:1...  Heterozygous
# 14  0/1:35:22:22:12:10:45.45%:2.6061E-4:61:55:11:1...  Heterozygous
# 15  0/1:35:22:22:12:10:45.45%:2.6061E-4:61:55:11:1...  Heterozygous
# 16  0/1:31:22:22:13:9:40.91%:7.0165E-4:60:52:12:1:4:5  Heterozygous
#
#    rsID_updated  Haplotype          rsID_mapped            Zygosity_mapped
# 0     rs1041983     NAT2*4  rs1799930,rs1041983  Heterozygous,Heterozygous
# 1     rs1041983    NAT2*6A  rs1799930,rs1041983  Heterozygous,Heterozygous
# 2     rs1041983    NAT2*6J  rs1799930,rs1041983  Heterozygous,Heterozygous
# 3     rs1041983    NAT2*6O  rs1799930,rs1041983  Heterozygous,Heterozygous
# 4     rs1041983    NAT2*7B            rs1041983               Heterozygous
# 5     rs1041983    NAT2*7G            rs1041983               Heterozygous
# 6     rs1041983   NAT2*13A            rs1041983               Heterozygous
# 9     rs1799930    NAT2*6B            rs1799930               Heterozygous
# 12   rs12769205  CYP2C19*2           rs12769205                 Homozygous
# 13    rs3745274   CYP2B6*6  rs2279343,rs3745274  Heterozygous,Heterozygous
# 14    rs3745274   CYP2B6*9            rs3745274               Heterozygous
# 15    rs3745274  CYP2B6*26  rs2279343,rs3745274  Heterozygous,Heterozygous
# 16    rs2279343   CYP2B6*4            rs2279343               Heterozygous

# %%
madhu['rsID_mapped_sorted'] = madhu['rsID_mapped'].apply(lambda x: ','.join(sorted(x.split(','))))
madhu = madhu.drop(columns=['rsID_mapped', 'rsID_updated', 'Haplotype'], axis=1)
madhu
# Out:
#     CHROM       POS        rsID REF ALT QUAL FILTER  \
# 0    chr8  18400285   rs1041983   C   T    .   PASS
# 1    chr8  18400285   rs1041983   C   T    .   PASS
# 2    chr8  18400285   rs1041983   C   T    .   PASS
# 3    chr8  18400285   rs1041983   C   T    .   PASS
# 4    chr8  18400285   rs1041983   C   T    .   PASS
# 5    chr8  18400285   rs1041983   C   T    .   PASS
# 6    chr8  18400285   rs1041983   C   T    .   PASS
# 9    chr8  18400593   rs1799930   G   A    .   PASS
# 12  chr10  94775367  rs12769205   A   G    .   PASS
# 13  chr19  41006936   rs3745274   G   T    .   PASS
# 14  chr19  41006936   rs3745274   G   T    .   PASS
# 15  chr19  41006936   rs3745274   G   T    .   PASS
# 16  chr19  41009358   rs2279343   A   G    .   PASS
#
#                                                  INFO  \
# 0   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 1   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 2   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 3   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 4   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 5   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 6   ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 9   ADP=35;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.735,0.2...
# 12  ADP=51;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.7716,0....
# 13  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.684...
# 14  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.684...
# 15  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.684...
# 16  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEIN...
#
#                                                FORMAT  \
# 0   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 5   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 6   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 9   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 12  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 13  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 14  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 15  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 16  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                SAMPLE      Zygosity  \
# 0   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 1   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 2   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 3   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 4   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 5   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 6   0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...  Heterozygous
# 9   0/1:57:35:35:19:16:45.71%:1.637E-6:60:54:15:4:...  Heterozygous
# 12  1/1:255:51:51:1:50:98.04%:1.3013E-28:74:51:1:0...    Homozygous
# 13  0/1:35:22:22:12:10:45.45%:2.6061E-4:61:55:11:1...  Heterozygous
# 14  0/1:35:22:22:12:10:45.45%:2.6061E-4:61:55:11:1...  Heterozygous
# 15  0/1:35:22:22:12:10:45.45%:2.6061E-4:61:55:11:1...  Heterozygous
# 16  0/1:31:22:22:13:9:40.91%:7.0165E-4:60:52:12:1:4:5  Heterozygous
#
#               Zygosity_mapped   rsID_mapped_sorted
# 0   Heterozygous,Heterozygous  rs1041983,rs1799930
# 1   Heterozygous,Heterozygous  rs1041983,rs1799930
# 2   Heterozygous,Heterozygous  rs1041983,rs1799930
# 3   Heterozygous,Heterozygous  rs1041983,rs1799930
# 4                Heterozygous            rs1041983
# 5                Heterozygous            rs1041983
# 6                Heterozygous            rs1041983
# 9                Heterozygous            rs1799930
# 12                 Homozygous           rs12769205
# 13  Heterozygous,Heterozygous  rs2279343,rs3745274
# 14               Heterozygous            rs3745274
# 15  Heterozygous,Heterozygous  rs2279343,rs3745274
# 16               Heterozygous            rs2279343

# %%
data = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Multiple_Positions.xlsx')
data = data.rename({'Haplotype':'Haplotype_updated', 'rsID':'rsID_mapped'}, axis = 1)
data['rsID_mapped_sorted'] = data['rsID_mapped'].apply(lambda x: ','.join(sorted(x.split(','))))
data = data.drop(columns=['rsID_mapped'], axis=1)
data
# Out:
#    Haplotype_updated                     rsID_mapped_sorted
# 0            NAT2*7B                    rs1041983,rs1799931
# 1            NAT2*7G  chr8_18400229_T_G,rs1041983,rs1799931
# 2          CYP2D6*10          rs1058164,rs1065852,rs1135840
# 3           CYP2D6*2            rs1058164,rs1135840,rs16947
# 4            NAT2*6A                    rs1041983,rs1799930
# 5            NAT2*6J          rs1041983,rs1799930,rs1799931
# 6            NAT2*6O         rs1041983,rs1799930,rs56393504
# 7            TPMT*3A                    rs1142345,rs1800460
# 8            NAT2*5C                       rs1208,rs1801280
# 9            NAT2*5A                    rs1799929,rs1801280
# 10           NAT2*5B             rs1208,rs1799929,rs1801280
# 11        SLCO1B1*14                   rs11045819,rs2306283
# 12        SLCO1B1*15                    rs2306283,rs4149056
# 13          CYP2A6*9                   rs28399433,rs7248240
# 14         CYP2A6*25                   rs28399440,rs7248240
# 15          CYP2B6*6                    rs2279343,rs3745274
# 16         CYP2B6*26                    rs2279343,rs3745274
# 17         CYP2C19*2                   rs12769205,rs4244285
# 18         CYP2A6*23                   rs56256500,rs7248240
# 19          NUDT15*2                rs116855232,rs746071566

# %%
mapped_df = pd.merge(madhu, data, on = 'rsID_mapped_sorted', how = 'inner', sort = False)
mapped_df.drop_duplicates(subset='Haplotype_updated', inplace=True)
mapped_df = mapped_df.drop(columns=['Zygosity'], axis=1)
mapped_df
# Out:
#    CHROM       POS       rsID REF ALT QUAL FILTER  \
# 0   chr8  18400285  rs1041983   C   T    .   PASS
# 4  chr19  41006936  rs3745274   G   T    .   PASS
# 5  chr19  41006936  rs3745274   G   T    .   PASS
#
#                                                 INFO  \
# 0  ADP=34;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6026,0....
# 4  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.684...
# 5  ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.684...
#
#                                               FORMAT  \
# 0  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 5  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                               SAMPLE  \
# 0  0/1:77:34:34:14:20:58.82%:1.6951E-8:58:56:13:1...
# 4  0/1:35:22:22:12:10:45.45%:2.6061E-4:61:55:11:1...
# 5  0/1:35:22:22:12:10:45.45%:2.6061E-4:61:55:11:1...
#
#              Zygosity_mapped   rsID_mapped_sorted Haplotype_updated
# 0  Heterozygous,Heterozygous  rs1041983,rs1799930           NAT2*6A
# 4  Heterozygous,Heterozygous  rs2279343,rs3745274          CYP2B6*6
# 5  Heterozygous,Heterozygous  rs2279343,rs3745274         CYP2B6*26

# %% [markdown]
# # zygosity classes excel files

# %%
import pandas as pd
import os
import sys

# Assuming df is your DataFrame with 'Zygosity' column
# You may need to replace 'your_data.csv' with your actual data file
df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/All_1232_updated_haplo_data_16_12_2023.xlsx')

# Get unique values in the 'Zygosity' column
zygosity_values = df['Zygosity_mapped'].unique()

# Create a folder to save the Excel files
output_folder = r'C:/Users/GenepoweRx_Madhu/Downloads/new_haplo_data_16_12_2023/'
os.makedirs(output_folder, exist_ok=True)

# Iterate through unique zygosity values
for zygosity_value in zygosity_values:
    # Create a subset DataFrame for each zygosity value
    subset_df = df[df['Zygosity_mapped'] == zygosity_value]

    # Save the subset as an Excel file
    output_filename = os.path.join(output_folder, f'{zygosity_value}.xlsx')
    subset_df.to_excel(output_filename, index=False)

print("Excel files saved successfully.")
# Out:
# Excel files saved successfully.

# %%
df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/All_1232_updated_haplo_data_16_12_2023.xlsx')
df
# Out:
#               rsID_mapped_sorted                         Zygosity_mapped  \
# 0            rs1041983,rs1799931               Heterozygous,Heterozygous
# 1            rs1799929,rs1801280               Heterozygous,Heterozygous
# 2     rs1208,rs1799929,rs1801280  Heterozygous,Heterozygous,Heterozygous
# 3               rs1208,rs1801280               Heterozygous,Heterozygous
# 4            rs1041983,rs1799930               Heterozygous,Heterozygous
# ...                          ...                                     ...
# 3763        rs12769205,rs4244285               Heterozygous,Heterozygous
# 3764         rs1799929,rs1801280                   Homozygous,Homozygous
# 3765         rs1041983,rs1799931               Heterozygous,Heterozygous
# 3766         rs1041983,rs1799930               Heterozygous,Heterozygous
# 3767         rs1799929,rs1801280               Heterozygous,Heterozygous
#
#      Haplotype_updated        Sample
# 0              NAT2*7B     KHAIGPRX9
# 1              NAT2*5A     KHAIGPRX9
# 2              NAT2*5B     KHAIGPRX9
# 3              NAT2*5C     KHAIGPRX9
# 4              NAT2*6A    KHAIGPRX99
# ...                ...           ...
# 3763         CYP2C19*2  KHAIGPRX1005
# 3764           NAT2*5A  KHAIGPRX1002
# 3765           NAT2*7B  KHAIGPRX1001
# 3766           NAT2*6A  KHAIGPRX1000
# 3767           NAT2*5A  KHAIGPRX1000
#
# [3768 rows x 4 columns]

# %%
new_df = df.copy()
new_df['rsID_new'] = new_df['rsID_mapped_sorted'].str.split(',')
new_df['Zygosity_new'] = new_df['Zygosity_mapped'].str.split(',')
# Explode the lists into separate rows
new_df = new_df.explode('rsID_new')
new_df = new_df.explode('Zygosity_new')
new_df.drop_duplicates(subset=['rsID_new', 'Zygosity_new', 'Sample'], inplace=True)
new_df
# Out:
#               rsID_mapped_sorted                         Zygosity_mapped  \
# 0            rs1041983,rs1799931               Heterozygous,Heterozygous
# 0            rs1041983,rs1799931               Heterozygous,Heterozygous
# 1            rs1799929,rs1801280               Heterozygous,Heterozygous
# 1            rs1799929,rs1801280               Heterozygous,Heterozygous
# 2     rs1208,rs1799929,rs1801280  Heterozygous,Heterozygous,Heterozygous
# ...                          ...                                     ...
# 3765         rs1041983,rs1799931               Heterozygous,Heterozygous
# 3766         rs1041983,rs1799930               Heterozygous,Heterozygous
# 3766         rs1041983,rs1799930               Heterozygous,Heterozygous
# 3767         rs1799929,rs1801280               Heterozygous,Heterozygous
# 3767         rs1799929,rs1801280               Heterozygous,Heterozygous
#
#      Haplotype_updated        Sample   rsID_new  Zygosity_new
# 0              NAT2*7B     KHAIGPRX9  rs1041983  Heterozygous
# 0              NAT2*7B     KHAIGPRX9  rs1799931  Heterozygous
# 1              NAT2*5A     KHAIGPRX9  rs1799929  Heterozygous
# 1              NAT2*5A     KHAIGPRX9  rs1801280  Heterozygous
# 2              NAT2*5B     KHAIGPRX9     rs1208  Heterozygous
# ...                ...           ...        ...           ...
# 3765           NAT2*7B  KHAIGPRX1001  rs1799931  Heterozygous
# 3766           NAT2*6A  KHAIGPRX1000  rs1041983  Heterozygous
# 3766           NAT2*6A  KHAIGPRX1000  rs1799930  Heterozygous
# 3767           NAT2*5A  KHAIGPRX1000  rs1799929  Heterozygous
# 3767           NAT2*5A  KHAIGPRX1000  rs1801280  Heterozygous
#
# [5649 rows x 6 columns]

# %%
grouped_new = new_df.groupby(['rsID_new', 'Zygosity_new', 'Haplotype_updated']).agg({'Sample': lambda x: ','.join(x.unique())}).reset_index()
grouped_new['Sample_count'] = grouped_new['Sample'].apply(lambda x: len(x.split(',')))
grouped_new
# Out:
#       rsID_new  Zygosity_new Haplotype_updated  \
# 0    rs1041983  Heterozygous           NAT2*6A
# 1    rs1041983  Heterozygous           NAT2*6J
# 2    rs1041983  Heterozygous           NAT2*7B
# 3    rs1041983    Homozygous           NAT2*6A
# 4    rs1041983    Homozygous           NAT2*6J
# 5    rs1041983    Homozygous           NAT2*7B
# 6   rs11045819  Heterozygous        SLCO1B1*14
# 7   rs11045819    Homozygous        SLCO1B1*14
# 8    rs1142345  Heterozygous           TPMT*3A
# 9       rs1208  Heterozygous           NAT2*5B
# 10      rs1208  Heterozygous           NAT2*5C
# 11      rs1208    Homozygous           NAT2*5B
# 12      rs1208    Homozygous           NAT2*5C
# 13  rs12769205  Heterozygous         CYP2C19*2
# 14  rs12769205    Homozygous         CYP2C19*2
# 15   rs1799929  Heterozygous           NAT2*5A
# 16   rs1799929  Heterozygous           NAT2*5B
# 17   rs1799929    Homozygous           NAT2*5A
# 18   rs1799929    Homozygous           NAT2*5B
# 19   rs1799930  Heterozygous           NAT2*6A
# 20   rs1799930  Heterozygous           NAT2*6J
# 21   rs1799930    Homozygous           NAT2*6A
# 22   rs1799930    Homozygous           NAT2*6J
# 23   rs1799931  Heterozygous           NAT2*6J
# 24   rs1799931  Heterozygous           NAT2*7B
# 25   rs1799931    Homozygous           NAT2*6J
# 26   rs1799931    Homozygous           NAT2*7B
# 27   rs1800460  Heterozygous           TPMT*3A
# 28   rs1801280  Heterozygous           NAT2*5A
# 29   rs1801280  Heterozygous           NAT2*5B
# 30   rs1801280  Heterozygous           NAT2*5C
# 31   rs1801280    Homozygous           NAT2*5A
# 32   rs1801280    Homozygous           NAT2*5B
# 33   rs1801280    Homozygous           NAT2*5C
# 34   rs2279343  Heterozygous          CYP2B6*6
# 35   rs2279343    Homozygous          CYP2B6*6
# 36   rs2306283  Heterozygous        SLCO1B1*14
# 37   rs2306283  Heterozygous        SLCO1B1*15
# 38   rs2306283    Homozygous        SLCO1B1*14
# 39   rs2306283    Homozygous        SLCO1B1*15
# 40   rs3745274  Heterozygous          CYP2B6*6
# 41   rs3745274    Homozygous          CYP2B6*6
# 42   rs4149056  Heterozygous        SLCO1B1*15
# 43   rs4149056    Homozygous        SLCO1B1*15
# 44   rs4244285  Heterozygous         CYP2C19*2
# 45   rs4244285    Homozygous         CYP2C19*2
# 46  rs56393504  Heterozygous           NAT2*6O
#
#                                                Sample  Sample_count
# 0   KHAIGPRX99,KHAIGPRX997,KHAIGPRX995,KHAIGPRX991...           488
# 1   KHAIGPRX559,KHAIGPRX544,KHAIGPRX1078,KHAIGPRX1049             4
# 2   KHAIGPRX9,KHAIGPRX983,KHAIGPRX97,KHAIGPRX951,K...            89
# 3   KHAIGPRX999,KHAIGPRX998,KHAIGPRX989,KHAIGPRX97...           178
# 4   KHAIGPRX559,KHAIGPRX544,KHAIGPRX1078,KHAIGPRX1049             4
# 5   KHAIGPRX97,KHAIGPRX90,KHAIGPRX758,KHAIGPRX662,...             7
# 6   KHAIGPRX952_RS,KHAIGPRX94,KHAIGPRX932,KHAIGPRX...            33
# 7   KHAIGPRX882,KHAIGPRX852,KHAIGPRX821,KHAIGPRX77...            18
# 8   KHAIGPRX636,KHAIGPRX503,KHAIGPRX446,KHAIGPRX37...             6
# 9   KHAIGPRX9,KHAIGPRX99,KHAIGPRX997,KHAIGPRX992,K...           422
# 10  KHAIGPRX996,KHAIGPRX984,KHAIGPRX977,KHAIGPRX97...            45
# 11  KHAIGPRX937,KHAIGPRX910,KHAIGPRX760,KHAIGPRX64...            13
# 12                                        KHAIGPRX380             1
# 13  KHAIGPRX99,KHAIGPRX997,KHAIGPRX989,KHAIGPRX986...           422
# 14  KHAIGPRX935,KHAIGPRX855,KHAIGPRX81,KHAIGPRX818...            35
# 15  KHAIGPRX9,KHAIGPRX99,KHAIGPRX997,KHAIGPRX992,K...           343
# 16  KHAIGPRX949,KHAIGPRX937,KHAIGPRX933,KHAIGPRX93...           137
# 17  KHAIGPRX993,KHAIGPRX985,KHAIGPRX967,KHAIGPRX95...           135
# 18  KHAIGPRX937,KHAIGPRX910,KHAIGPRX760,KHAIGPRX64...            12
# 19  KHAIGPRX99,KHAIGPRX997,KHAIGPRX995,KHAIGPRX991...           488
# 20  KHAIGPRX559,KHAIGPRX544,KHAIGPRX1078,KHAIGPRX1049             4
# 21  KHAIGPRX999,KHAIGPRX998,KHAIGPRX989,KHAIGPRX97...           178
# 22  KHAIGPRX559,KHAIGPRX544,KHAIGPRX1078,KHAIGPRX1049             4
# 23  KHAIGPRX989,KHAIGPRX959,KHAIGPRX909,KHAIGPRX87...            52
# 24  KHAIGPRX9,KHAIGPRX983,KHAIGPRX97,KHAIGPRX951,K...            89
# 25  KHAIGPRX989,KHAIGPRX959,KHAIGPRX909,KHAIGPRX87...            52
# 26  KHAIGPRX97,KHAIGPRX90,KHAIGPRX758,KHAIGPRX662,...             7
# 27  KHAIGPRX636,KHAIGPRX503,KHAIGPRX446,KHAIGPRX37...             6
# 28  KHAIGPRX9,KHAIGPRX99,KHAIGPRX997,KHAIGPRX992,K...           343
# 29  KHAIGPRX949,KHAIGPRX937,KHAIGPRX933,KHAIGPRX93...           137
# 30  KHAIGPRX996,KHAIGPRX984,KHAIGPRX977,KHAIGPRX97...            45
# 31  KHAIGPRX993,KHAIGPRX985,KHAIGPRX967,KHAIGPRX95...           135
# 32  KHAIGPRX937,KHAIGPRX910,KHAIGPRX760,KHAIGPRX64...            12
# 33                                        KHAIGPRX380             1
# 34  KHAIGPRX99,KHAIGPRX990,KHAIGPRX98,KHAIGPRX981,...           366
# 35  KHAIGPRX971,KHAIGPRX955,KHAIGPRX942,KHAIGPRX89...           102
# 36  KHAIGPRX952_RS,KHAIGPRX94,KHAIGPRX932,KHAIGPRX...            33
# 37  KHAIGPRX972,KHAIGPRX941,KHAIGPRX940,KHAIGPRX92...            81
# 38  KHAIGPRX882,KHAIGPRX852,KHAIGPRX821,KHAIGPRX77...            18
# 39  KHAIGPRX972,KHAIGPRX95,KHAIGPRX941,KHAIGPRX928...            46
# 40  KHAIGPRX99,KHAIGPRX990,KHAIGPRX98,KHAIGPRX981,...           366
# 41  KHAIGPRX971,KHAIGPRX955,KHAIGPRX942,KHAIGPRX89...           102
# 42  KHAIGPRX972,KHAIGPRX94,KHAIGPRX941,KHAIGPRX940...            84
# 43  KHAIGPRX972,KHAIGPRX95,KHAIGPRX941,KHAIGPRX928...            48
# 44  KHAIGPRX99,KHAIGPRX997,KHAIGPRX989,KHAIGPRX986...           422
# 45  KHAIGPRX935,KHAIGPRX855,KHAIGPRX81,KHAIGPRX818...            35
# 46                                        KHAIGPRX370             1

# %%
grouped_new.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/haplotype_rsID_data.xlsx', index = False)

# %%
grouped = df.groupby(['rsID_mapped_sorted', 'Zygosity_mapped', 'Haplotype_updated']).agg({'Sample': lambda x: ', '.join(x.unique())}).reset_index()
grouped['Sample_count'] = grouped['Sample'].apply(lambda x: len(x.split(',')))
grouped.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/new_haplo_data_16_12_2023/1232_samples_Haplotype_updated.xlsx', index=False)
grouped
# Out:
#                 rsID_mapped_sorted                         Zygosity_mapped  \
# 0              rs1041983,rs1799930               Heterozygous,Heterozygous
# 1              rs1041983,rs1799930                 Heterozygous,Homozygous
# 2              rs1041983,rs1799930                 Homozygous,Heterozygous
# 3              rs1041983,rs1799930                   Homozygous,Homozygous
# 4    rs1041983,rs1799930,rs1799931    Homozygous,Heterozygous,Heterozygous
# 5   rs1041983,rs1799930,rs56393504  Heterozygous,Heterozygous,Heterozygous
# 6              rs1041983,rs1799931               Heterozygous,Heterozygous
# 7              rs1041983,rs1799931                 Homozygous,Heterozygous
# 8              rs1041983,rs1799931                   Homozygous,Homozygous
# 9             rs11045819,rs2306283               Heterozygous,Heterozygous
# 10            rs11045819,rs2306283                 Homozygous,Heterozygous
# 11             rs1142345,rs1800460               Heterozygous,Heterozygous
# 12      rs1208,rs1799929,rs1801280  Heterozygous,Heterozygous,Heterozygous
# 13      rs1208,rs1799929,rs1801280    Heterozygous,Heterozygous,Homozygous
# 14      rs1208,rs1799929,rs1801280    Heterozygous,Homozygous,Heterozygous
# 15      rs1208,rs1799929,rs1801280    Homozygous,Heterozygous,Heterozygous
# 16      rs1208,rs1799929,rs1801280      Homozygous,Homozygous,Heterozygous
# 17      rs1208,rs1799929,rs1801280        Homozygous,Homozygous,Homozygous
# 18                rs1208,rs1801280               Heterozygous,Heterozygous
# 19                rs1208,rs1801280                 Heterozygous,Homozygous
# 20                rs1208,rs1801280                 Homozygous,Heterozygous
# 21                rs1208,rs1801280                   Homozygous,Homozygous
# 22            rs12769205,rs4244285               Heterozygous,Heterozygous
# 23            rs12769205,rs4244285                 Heterozygous,Homozygous
# 24            rs12769205,rs4244285                 Homozygous,Heterozygous
# 25            rs12769205,rs4244285                   Homozygous,Homozygous
# 26             rs1799929,rs1801280               Heterozygous,Heterozygous
# 27             rs1799929,rs1801280                 Heterozygous,Homozygous
# 28             rs1799929,rs1801280                 Homozygous,Heterozygous
# 29             rs1799929,rs1801280                   Homozygous,Homozygous
# 30             rs2279343,rs3745274               Heterozygous,Heterozygous
# 31             rs2279343,rs3745274               Heterozygous,Heterozygous
# 32             rs2279343,rs3745274                 Heterozygous,Homozygous
# 33             rs2279343,rs3745274                 Heterozygous,Homozygous
# 34             rs2279343,rs3745274                 Homozygous,Heterozygous
# 35             rs2279343,rs3745274                 Homozygous,Heterozygous
# 36             rs2279343,rs3745274                   Homozygous,Homozygous
# 37             rs2279343,rs3745274                   Homozygous,Homozygous
# 38             rs2306283,rs4149056               Heterozygous,Heterozygous
# 39             rs2306283,rs4149056                 Homozygous,Heterozygous
# 40             rs2306283,rs4149056                   Homozygous,Homozygous
#
#    Haplotype_updated                                             Sample  \
# 0            NAT2*6A  KHAIGPRX99, KHAIGPRX997, KHAIGPRX995, KHAIGPRX...
# 1            NAT2*6A                           KHAIGPRX431, KHAIGPRX279
# 2            NAT2*6A  KHAIGPRX989, KHAIGPRX959, KHAIGPRX909, KHAIGPR...
# 3            NAT2*6A  KHAIGPRX999, KHAIGPRX998, KHAIGPRX972, KHAIGPR...
# 4            NAT2*6J  KHAIGPRX989, KHAIGPRX959, KHAIGPRX909, KHAIGPR...
# 5            NAT2*6O                                        KHAIGPRX370
# 6            NAT2*7B  KHAIGPRX9, KHAIGPRX983, KHAIGPRX951, KHAIGPRX9...
# 7            NAT2*7B  KHAIGPRX989, KHAIGPRX97, KHAIGPRX959, KHAIGPRX...
# 8            NAT2*7B  KHAIGPRX90, KHAIGPRX758, KHAIGPRX662, KHAIGPRX456
# 9         SLCO1B1*14  KHAIGPRX952_RS, KHAIGPRX94, KHAIGPRX932, KHAIG...
# 10        SLCO1B1*14  KHAIGPRX882, KHAIGPRX852, KHAIGPRX821, KHAIGPR...
# 11           TPMT*3A  KHAIGPRX636, KHAIGPRX503, KHAIGPRX446, KHAIGPR...
# 12           NAT2*5B  KHAIGPRX9, KHAIGPRX99, KHAIGPRX997, KHAIGPRX99...
# 13           NAT2*5B  KHAIGPRX937, KHAIGPRX910, KHAIGPRX286, KHAIGPR...
# 14           NAT2*5B             KHAIGPRX760, KHAIGPRX239, KHAIGPRX1005
# 15           NAT2*5B                                        KHAIGPRX288
# 16           NAT2*5B  KHAIGPRX647, KHAIGPRX570, KHAIGPRX524, KHAIGPR...
# 17           NAT2*5B                                    KHAIGPRX1006_RS
# 18           NAT2*5C  KHAIGPRX9, KHAIGPRX99, KHAIGPRX997, KHAIGPRX99...
# 19           NAT2*5C  KHAIGPRX937, KHAIGPRX910, KHAIGPRX380, KHAIGPR...
# 20           NAT2*5C  KHAIGPRX647, KHAIGPRX570, KHAIGPRX524, KHAIGPR...
# 21           NAT2*5C                                    KHAIGPRX1006_RS
# 22         CYP2C19*2  KHAIGPRX99, KHAIGPRX997, KHAIGPRX989, KHAIGPRX...
# 23         CYP2C19*2             KHAIGPRX715, KHAIGPRX568, KHAIGPRX1058
# 24         CYP2C19*2                                        KHAIGPRX175
# 25         CYP2C19*2  KHAIGPRX935, KHAIGPRX855, KHAIGPRX81, KHAIGPRX...
# 26           NAT2*5A  KHAIGPRX9, KHAIGPRX99, KHAIGPRX997, KHAIGPRX99...
# 27           NAT2*5A             KHAIGPRX760, KHAIGPRX239, KHAIGPRX1005
# 28           NAT2*5A  KHAIGPRX985, KHAIGPRX921, KHAIGPRX906, KHAIGPR...
# 29           NAT2*5A  KHAIGPRX993, KHAIGPRX967, KHAIGPRX956, KHAIGPR...
# 30         CYP2B6*26  KHAIGPRX99, KHAIGPRX990, KHAIGPRX98, KHAIGPRX9...
# 31          CYP2B6*6  KHAIGPRX99, KHAIGPRX990, KHAIGPRX98, KHAIGPRX9...
# 32         CYP2B6*26  KHAIGPRX897, KHAIGPRX894, KHAIGPRX815, KHAIGPR...
# 33          CYP2B6*6  KHAIGPRX897, KHAIGPRX894, KHAIGPRX815, KHAIGPR...
# 34         CYP2B6*26                           KHAIGPRX704, KHAIGPRX119
# 35          CYP2B6*6                           KHAIGPRX704, KHAIGPRX119
# 36         CYP2B6*26  KHAIGPRX971, KHAIGPRX955, KHAIGPRX942, KHAIGPR...
# 37          CYP2B6*6  KHAIGPRX971, KHAIGPRX955, KHAIGPRX942, KHAIGPR...
# 38        SLCO1B1*15  KHAIGPRX94, KHAIGPRX940, KHAIGPRX91, KHAIGPRX9...
# 39        SLCO1B1*15  KHAIGPRX972, KHAIGPRX941, KHAIGPRX928, KHAIGPR...
# 40        SLCO1B1*15  KHAIGPRX95, KHAIGPRX414, KHAIGPRX409, KHAIGPRX...
#
#     Sample_count
# 0            434
# 1              2
# 2             56
# 3            124
# 4             52
# 5              1
# 6             86
# 7             55
# 8              4
# 9             15
# 10            18
# 11             6
# 12           410
# 13             4
# 14             3
# 15             1
# 16             4
# 17             1
# 18           457
# 19             5
# 20             5
# 21             1
# 22           418
# 23             3
# 24             1
# 25            31
# 26           458
# 27             3
# 28            15
# 29           125
# 30           338
# 31           338
# 32            26
# 33            26
# 34             2
# 35             2
# 36            74
# 37            74
# 38            42
# 39            42
# 40             6

# %% [markdown]
# # condition3_ haplotype_new mapped genes positions along with mapped data...

# %%
import pandas as pd
variants = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/haplo_20_samples/KHAIGPRX1_final_DP.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
variants.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
variants
# Out:
#      CHROM        POS         rsID REF ALT QUAL FILTER  \
# 0     chr1   11786195    rs4846048   G   A    .   PASS
# 1     chr1   11786390    rs4845884   G   A    .   PASS
# 2     chr1   11787392    rs3737967   G   A    .   PASS
# 3     chr1   11787715    rs3820192   G   T    .   PASS
# 4     chr1   11788011    rs1537514   G   C    .   PASS
# ..     ...        ...          ...  ..  ..  ...    ...
# 108  chr21   45532180     rs914231   T   C    .   PASS
# 109  chr21   45534483  rs150745916   A   C    .   PASS
# 110   chrX  154531643    rs1050757   C   T    .   PASS
# 111   chrX  154532293    rs2071429   G   A    .   PASS
# 112   chrX  154532439    rs2230037   A   G    .   PASS
#
#                                                   INFO  \
# 0    ADP=28;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.2935,0....
# 1    ADP=28;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.06669,0...
# 2    ADP=25;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9257,0....
# 3    ADP=24;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8876,0....
# 4    ADP=29;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8824,0....
# ..                                                 ...
# 108  ADP=17;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.4856,0....
# 109  ADP=23;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.998,0.0...
# 110  ADP=28;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.5846,0....
# 111  ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.5852,0....
# 112  ADP=27;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.7841,0....
#
#                                                 FORMAT  \
# 0    GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1    GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2    GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3    GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4    GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# ..                                                 ...
# 108  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 109  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 110  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 111  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 112  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                 SAMPLE
# 0       0/1:51:28:28:14:14:50%:6.911E-6:55:44:10:4:8:6
# 1     1/1:158:28:28:0:28:100%:1.3074E-16:0:53:0:0:23:5
# 2      0/1:39:25:25:14:11:44%:1.1933E-4:54:47:14:0:9:2
# 3      0/1:27:24:24:16:8:33.33%:1.949E-3:47:50:8:8:3:5
# 4    0/1:46:29:29:16:13:44.83%:2.1506E-5:59:50:11:5...
# ..                                                 ...
# 108   0/1:43:17:17:6:11:64.71%:4.3258E-5:47:47:4:2:5:6
# 109  0/1:54:23:23:9:14:60.87%:3.4067E-6:42:50:7:2:13:1
# 110  1/1:158:28:28:0:28:100%:1.3074E-16:0:44:0:0:16:12
# 111   1/1:105:19:19:0:19:100%:2.8292E-11:0:47:0:0:16:3
# 112  1/1:152:27:27:0:27:100%:5.1363E-16:0:50:0:0:16:11
#
# [113 rows x 10 columns]

# %%
df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/haplo_20_samples/13genes_coordinates_haplotypes_07122023.xlsx', header = None)
df.columns = ['Gene', 'chromosome', 'Extended_Start_pos', 'Extended_End_pos']
df
# Out:
#        Gene chromosome Extended_Start_pos Extended_End_pos
# 0      GENE        CHR          Start_POS          END_POS
# 1    CYP2A6      chr19           40843541         40850447
# 2    CYP2B6      chr19           40991282         41018398
# 3   CYP2C19      chr10           94762681         94855547
# 4    CYP2C9      chr10           94938658         94990091
# 5    CYP2D6      chr22           42126499         42130810
# 6    CYP3A4       chr7           99756967         99784184
# 7    CYP3A5       chr7           99648194         99679996
# 8      NAT2       chr8           18391282         18401218
# 9    NUDT15      chr13           48037726         48047221
# 10  SLCO1B1      chr12           21131194         21239796
# 11     TPMT       chr6           18128311         18155077
# 12   UGT1A1       chr2          233760270        233773300
# 13     G6PD       chrX          154531391        154546846

# %%
# Step 1: Create a dictionary from the df DataFrame
chromosome_dict = {}
for _, row in df.iterrows():
    chromosome = row['chromosome']
    start_pos = row['Extended_Start_pos']
    end_pos = row['Extended_End_pos']
    gene = row['Gene']  # Assuming 'Gene' is the name of your gene column
    if chromosome not in chromosome_dict:
        chromosome_dict[chromosome] = []
    chromosome_dict[chromosome].append((start_pos, end_pos, gene))

# Step 2: Define a function to check coverage
def check_coverage(row):
    pos = row['POS']
    chromosome = row['CHROM']
    if chromosome in chromosome_dict:
        ranges = chromosome_dict[chromosome]
        for start, end, gene in ranges:
            if start <= pos <= end:
                return 'Covered', start, end, gene
    return 'Not_Covered', None, None, None  # Return None for start, end, and gene if not covered

# Step 3: Apply the function to create the new columns in data
variants['Covered/Not_Covered'], variants['Start_Pos_Covered'], variants['End_Pos_Covered'], variants['Gene'] = zip(*variants.apply(check_coverage, axis=1))

# Step 4: Create new columns for Covered rows
covered_rows = variants['Covered/Not_Covered'] == 'Covered'
variants.loc[covered_rows, 'Covered_Chromosome'] = variants.loc[covered_rows, 'CHROM']
variants.loc[covered_rows, 'Covered_Start_Pos'] = variants.loc[covered_rows, 'Start_Pos_Covered']
variants.loc[covered_rows, 'Covered_End_Pos'] = variants.loc[covered_rows, 'End_Pos_Covered']
variants.loc[covered_rows, 'Gene'] = variants.loc[covered_rows, 'Gene']

# Drop temporary columns
variants.drop(['Start_Pos_Covered', 'End_Pos_Covered'], axis=1, inplace=True)

# Display the DataFrame
variants = variants[variants['Covered/Not_Covered'] == 'Covered']
variants
# Out:
#      CHROM        POS         rsID REF ALT QUAL FILTER  \
# 45    chr6   18128428       rs7886   T   A    .   PASS
# 52    chr7   99662739    rs4646453   C   A    .   PASS
# 53    chr7   99763843    rs2242480   C   T    .   PASS
# 56    chr8   18400344    rs1801280   T   C    .   PASS
# 57    chr8   18400806       rs1208   G   A    .   PASS
# 58   chr10   94762804   rs17885098   C   T    .   PASS
# 59   chr10   94942093    rs9332120   T   C    .   PASS
# 60   chr12   21239628    rs4149087   T   G    .   PASS
# 61   chr12   21239652    rs4149088   A   G    .   PASS
# 62   chr13   48040905  rs747497670   G   C    .   PASS
# 98   chr19   40849944    rs2302990   A   G    .   PASS
# 99   chr19   40849991  rs376970015   T   C    .   PASS
# 100  chr19   41006887    rs4803419   C   T    .   PASS
# 110   chrX  154531643    rs1050757   C   T    .   PASS
# 111   chrX  154532293    rs2071429   G   A    .   PASS
# 112   chrX  154532439    rs2230037   A   G    .   PASS
#
#                                                   INFO  \
# 45   ADP=17;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.2372,0....
# 52   ADP=15;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8546,0....
# 53   ADP=26;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.5783,0....
# 56   ADP=25;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.7073,0....
# 57   ADP=23;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3229,0....
# 58   ADP=23;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9081,0....
# 59   ADP=44;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.8558,0....
# 60   ADP=19;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.5523,0....
# 61   ADP=17;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.5515,0....
# 62   ADP=18;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=NUDT...
# 98   ADP=84;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=CYP2...
# 99   ADP=73;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=CYP2...
# 100  ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.7109,0....
# 110  ADP=28;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.5846,0....
# 111  ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.5852,0....
# 112  ADP=27;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.7841,0....
#
#                                                 FORMAT  \
# 45   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 52   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 53   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 56   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 57   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 58   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 59   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 60   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 61   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 62   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 98   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 99   GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 100  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 110  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 111  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 112  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                 SAMPLE Covered/Not_Covered  \
# 45    0/1:24:17:17:10:7:41.18%:3.6151E-3:40:47:1:9:3:4             Covered
# 52        0/1:34:15:15:6:9:60%:3.4983E-4:55:43:5:1:8:1             Covered
# 53    1/1:146:26:26:0:26:100%:2.0165E-15:0:49:0:0:21:5             Covered
# 56     0/1:48:25:25:12:13:52%:1.4654E-5:49:61:9:3:10:3             Covered
# 57   0/1:49:23:23:10:13:56.52%:1.1242E-5:54:57:8:2:...             Covered
# 58    1/1:129:23:23:0:23:100%:1.2146E-13:0:54:0:0:17:6             Covered
# 59   1/1:254:44:44:0:44:100%:3.8097E-26:0:52:0:0:31:13             Covered
# 60    0/1:28:19:19:11:8:42.11%:1.5455E-3:43:44:8:3:6:2             Covered
# 61    0/1:20:17:17:11:6:35.29%:9.2021E-3:56:57:8:3:5:1             Covered
# 62   0/1:24:18:18:11:7:38.89%:3.8123E-3:56:41:11:0:7:0             Covered
# 98   0/1:58:84:84:66:18:21.43%:1.3771E-6:50:66:45:2...             Covered
# 99   0/1:55:73:73:56:17:23.29%:2.6617E-6:54:54:39:1...             Covered
# 100   1/1:105:19:19:0:19:100%:2.8292E-11:0:51:0:0:17:2             Covered
# 110  1/1:158:28:28:0:28:100%:1.3074E-16:0:44:0:0:16:12             Covered
# 111   1/1:105:19:19:0:19:100%:2.8292E-11:0:47:0:0:16:3             Covered
# 112  1/1:152:27:27:0:27:100%:5.1363E-16:0:50:0:0:16:11             Covered
#
#         Gene Covered_Chromosome  Covered_Start_Pos  Covered_End_Pos
# 45      TPMT               chr6         18128311.0       18155077.0
# 52    CYP3A5               chr7         99648194.0       99679996.0
# 53    CYP3A4               chr7         99756967.0       99784184.0
# 56      NAT2               chr8         18391282.0       18401218.0
# 57      NAT2               chr8         18391282.0       18401218.0
# 58   CYP2C19              chr10         94762681.0       94855547.0
# 59    CYP2C9              chr10         94938658.0       94990091.0
# 60   SLCO1B1              chr12         21131194.0       21239796.0
# 61   SLCO1B1              chr12         21131194.0       21239796.0
# 62    NUDT15              chr13         48037726.0       48047221.0
# 98    CYP2A6              chr19         40843541.0       40850447.0
# 99    CYP2A6              chr19         40843541.0       40850447.0
# 100   CYP2B6              chr19         40991282.0       41018398.0
# 110     G6PD               chrX        154531391.0      154546846.0
# 111     G6PD               chrX        154531391.0      154546846.0
# 112     G6PD               chrX        154531391.0      154546846.0

# %%
RSIDS_POSITION_DBSNP
