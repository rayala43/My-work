# %%
import numpy as np
import pandas as pd
import polars as pl
import sys
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px


pd.set_option('display.max_columns',None)
import psycopg2


#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Algorithms to use
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

#Metrics to evaluate the model
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve

import warnings
warnings.filterwarnings("ignore")

#importing PCA and TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %% [markdown]
# # VCF file Covered Positions Extraction From the Bed File

# %%
def read_bed_file(bed_file):
    bed_positions = set()
    with open(bed_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Skip header lines if present
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 3:
                chrom = fields[0]
                try:
                    start = int(fields[1])
                    end = int(fields[2])
                except ValueError:
                    continue  # Skip this line if start or end position is not an integer
                for pos in range(start, end + 1):
                    bed_positions.add((chrom, pos))
    return bed_positions

def normalize_chrom_name(chrom):
    return chrom.split('_')[0]

def filter_vcf_file(vcf_file, bed_positions):
    filtered_vcf_records = []
    with open(vcf_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Preserve header lines in the output
                filtered_vcf_records.append(line)
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 2:
                raw_chrom = fields[0]
                chrom = normalize_chrom_name(raw_chrom)
                try:
                    pos = int(fields[1])
                except ValueError:
                    continue  # Skip this line if 'POS' is not an integer
                if (chrom, pos) in bed_positions:
                    filtered_vcf_records.append(line)
    return filtered_vcf_records

def write_filtered_vcf(filtered_vcf_records, output_file):
    with open(output_file, 'w') as f:
        for record in filtered_vcf_records:
            f.write(record)

def main():
    bed_file = r'C:/Users/GenepoweRx_Madhu/Desktop/Covered_regions.bed'
    vcf_file = r'C:/Users/GenepoweRx_Madhu/Downloads/vcf_files_all/KHAIGHGPTTL187/KHAIGHGPTTL187_final.vcf'
    output_file = r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/KHAIGHGPTTL187_final.vcf'

    bed_positions = read_bed_file(bed_file)
    filtered_vcf_records = filter_vcf_file(vcf_file, bed_positions)
    write_filtered_vcf(filtered_vcf_records, output_file)

if __name__ == "__main__":
    main()

# %%
vcf = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/KHAIGHGPTTL187_final.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
vcf.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']

sample_cols = vcf['SAMPLE'].str.split(':', expand=True)
sample_cols.columns = ['GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RBQ', 'ABQ', 'RDF', 'RDR', 'ADF', 'ADR']

# Assign the values to the newly created columns
vcf = pd.concat([vcf, sample_cols], axis=1)
vcf = vcf[['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL','RDF', 'RDR', 'ADF', 'ADR']]
vcf
# Out:
#       CHROM       POS          rsID REF ALT QUAL FILTER  \
# 0      chr1     65529  rs1473003496   C   T    .   PASS
# 1      chr1     69270   rs201219564   A   G    .   PASS
# 2      chr1     69511     rs2691305   A   G    .   PASS
# 3      chr1     69897   rs200676709   T   C    .   PASS
# 4      chr1    924533   rs112703963   A   G    .   PASS
# ...     ...       ...           ...  ..  ..  ...    ...
# 34676  chrY  23179733             .   T   C    .   PASS
# 34677  chrY  23190581             .   T   C    .   PASS
# 34678  chrY  23227961             .   A   G    .   PASS
# 34679  chrY  24842348             .   A   G    .   PASS
# 34680  chrY  24853196             .   A   G    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=22;WT=0;HET=1;HOM=0;NC=0;ASP;RS=1473003496...  0/1   23   22   22
# 1      ADP=102;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  132  102  102
# 2      ADP=160;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  160  160
# 3      ADP=86;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1  165   86   86
# 4      ADP=33;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....  1/1  188   33   33
# ...                                                  ...  ...  ...  ...  ...
# 34676  ADP=89;WT=0;HET=1;HOM=0;NC=0;CSQ=C|synonymous_...  0/1   91   89   89
# 34677  ADP=67;WT=0;HET=1;HOM=0;NC=0;CSQ=C|synonymous_...  0/1   48   67   67
# 34678  ADP=75;WT=0;HET=1;HOM=0;NC=0;CSQ=G|synonymous_...  0/1   77   75   75
# 34679  ADP=65;WT=0;HET=1;HOM=0;NC=0;CSQ=G|synonymous_...  0/1   60   65   65
# 34680  ADP=54;WT=0;HET=1;HOM=0;NC=0;CSQ=G|synonymous_...  0/1   53   55   54
#
#        RD   AD    FREQ        PVAL RDF RDR  ADF ADR
# 0      15    7  31.82%   4.4505E-3  14   1    6   1
# 1      64   38  37.25%  5.1448E-14  41  23   28  10
# 2       0  160    100%  1.0505E-95   0   0  116  44
# 3      42   44  51.16%  3.1151E-17  27  15   34  10
# 4       0   33    100%  1.3852E-19   0   0   20  13
# ...    ..  ...     ...         ...  ..  ..  ...  ..
# 34676  62   27  30.34%  7.2581E-10  44  18   23   4
# 34677  52   15  22.39%   1.2648E-5  31  21   10   5
# 34678  52   23  30.67%   1.6219E-8  41  11   21   2
# 34679  47   18  27.69%   9.7371E-7  31  16   14   4
# 34680  38   16  29.63%   4.1444E-6  28  10   14   2
#
# [34681 rows x 20 columns]

# %%
vcf['HET'] = vcf['INFO'].str.extract(r'HET=(\d)')
vcf['HOM'] = vcf['INFO'].str.extract(r'HOM=(\d)')

# Create a new column 'Zygosity' based on conditions
vcf['Zygosity'] = ''

vcf.loc[vcf['HOM'] == '1', 'Zygosity'] = 'Homozygous'
vcf.loc[vcf['HET'] == '1', 'Zygosity'] = 'Heterozygous'
vcf['GT'] = vcf['GT'].astype(str)
vcf
# Out:
#       CHROM       POS          rsID REF ALT QUAL FILTER  \
# 0      chr1     69270   rs201219564   A   G    .   PASS
# 1      chr1     69511     rs2691305   A   G    .   PASS
# 2      chr1    451290             .   A   C    .   PASS
# 3      chr1    686266             .   A   C    .   PASS
# 4      chr1    924533   rs112703963   A   G    .   PASS
# ...     ...       ...           ...  ..  ..  ...    ...
# 36647  chrY   9528488  rs1179775265   T   G    .   PASS
# 36648  chrY  13360045     rs2032674   T   C    .   PASS
# 36649  chrY  14941891    rs17269816   C   T    .   PASS
# 36650  chrY  15174113    rs17307398   T   C    .   PASS
# 36651  chrY  20577481     rs9786153   C   T    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 1      ADP=114;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  114  114
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# 3      ADP=79;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   85   79   79
# 4      ADP=11;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....  1/1   58   11   11
# ...                                                  ...  ...  ...  ...  ...
# 36647  ADP=186;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  130  186  186
# 36648  ADP=54;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.8094,0....  1/1  255   54   54
# 36649  ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.91,0.09...  1/1  182   32   32
# 36650  ADP=29;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.266,0.7...  1/1  164   29   29
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
#
#         RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 1        0  114    100%   4.392E-68   0   0  98  16   0   1    Homozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# 3       54   25  31.65%   3.1101E-9  43  11  23   2   1   0  Heterozygous
# 4        0   11    100%   1.4176E-6   0   0  10   1   0   1    Homozygous
# ...    ...  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 36647  146   40  21.51%  8.6616E-14  77  69  17  23   1   0  Heterozygous
# 36648    0   54    100%  4.0229E-32   0   0  35  19   0   1    Homozygous
# 36649    0   32    100%  5.4567E-19   0   0  28   4   0   1    Homozygous
# 36650    0   29    100%  3.3259E-17   0   0  24   5   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
#
# [36652 rows x 23 columns]

# %%
vcf["Gene_Name"] = vcf["INFO"].str.extract('GENEINFO=(?P<GENEINFO>.+?);')
vcf['Gene Name'] = vcf['Gene_Name'].apply(lambda x: ','.join([segment.split(':')[0] for segment in x.split('|')]) if pd.notnull(x) else '')
vcf
# Out:
#       CHROM       POS          rsID REF ALT QUAL FILTER  \
# 0      chr1     69270   rs201219564   A   G    .   PASS
# 1      chr1     69511     rs2691305   A   G    .   PASS
# 2      chr1    451290             .   A   C    .   PASS
# 3      chr1    686266             .   A   C    .   PASS
# 4      chr1    924533   rs112703963   A   G    .   PASS
# ...     ...       ...           ...  ..  ..  ...    ...
# 36647  chrY   9528488  rs1179775265   T   G    .   PASS
# 36648  chrY  13360045     rs2032674   T   C    .   PASS
# 36649  chrY  14941891    rs17269816   C   T    .   PASS
# 36650  chrY  15174113    rs17307398   T   C    .   PASS
# 36651  chrY  20577481     rs9786153   C   T    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 1      ADP=114;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  114  114
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# 3      ADP=79;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   85   79   79
# 4      ADP=11;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....  1/1   58   11   11
# ...                                                  ...  ...  ...  ...  ...
# 36647  ADP=186;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  130  186  186
# 36648  ADP=54;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.8094,0....  1/1  255   54   54
# 36649  ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.91,0.09...  1/1  182   32   32
# 36650  ADP=29;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.266,0.7...  1/1  164   29   29
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
#
#         RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity  \
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 1        0  114    100%   4.392E-68   0   0  98  16   0   1    Homozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# 3       54   25  31.65%   3.1101E-9  43  11  23   2   1   0  Heterozygous
# 4        0   11    100%   1.4176E-6   0   0  10   1   0   1    Homozygous
# ...    ...  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 36647  146   40  21.51%  8.6616E-14  77  69  17  23   1   0  Heterozygous
# 36648    0   54    100%  4.0229E-32   0   0  35  19   0   1    Homozygous
# 36649    0   32    100%  5.4567E-19   0   0  28   4   0   1    Homozygous
# 36650    0   29    100%  3.3259E-17   0   0  24   5   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
#
#                                   Gene_Name            Gene Name
# 0                               OR4F5:79501                OR4F5
# 1                               OR4F5:79501                OR4F5
# 2                                       NaN
# 3                                       NaN
# 4      LOC107985728:107985728|SAMD11:148398  LOC107985728,SAMD11
# ...                                     ...                  ...
# 36647                      TSPY10:100289087               TSPY10
# 36648                              UTY:7404                  UTY
# 36649                                   NaN
# 36650                                   NaN
# 36651                           EIF1AY:9086               EIF1AY
#
# [36652 rows x 25 columns]

# %%
vcf['CSQ'] = vcf['INFO'].str.extract(r'CSQ=(.*)')
vcf['csq'] = vcf['CSQ'].str.split(',')
vcf = vcf.explode('csq')
vcf
# Out:
#       CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 1      chr1     69511    rs2691305   A   G    .   PASS
# 2      chr1    451290            .   A   C    .   PASS
# 2      chr1    451290            .   A   C    .   PASS
# ...     ...       ...          ...  ..  ..  ...    ...
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 1      ADP=114;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  114  114
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# ...                                                  ...  ...  ...  ...  ...
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
#
#         RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity  \
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 1        0  114    100%   4.392E-68   0   0  98  16   0   1    Homozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# ...    ...  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
#
#          Gene_Name Gene Name  \
# 0      OR4F5:79501     OR4F5
# 0      OR4F5:79501     OR4F5
# 1      OR4F5:79501     OR4F5
# 2              NaN
# 2              NaN
# ...            ...       ...
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
#
#                                                      CSQ  \
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# ...                                                  ...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
#
#                                                      csq
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 0      G|regulatory_region_variant|MODIFIER|||Regulat...
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# 2      C|intron_variant&non_coding_transcript_variant...
# ...                                                  ...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
#
# [328334 rows x 27 columns]

# %%
vcf['ClinVar_CLNDN'] = vcf['csq'].str.split('|').str[82]
vcf['CLIN_SIG'] = vcf['csq'].str.split('|').str[70]
vcf['ClinVar_CLNREVSTAT'] = vcf['csq'].str.split('|').str[81]
vcf['ClinVar'] = vcf['csq'].str.split('|').str[79]
vcf['HGVSC'] = vcf['csq'].str.split('|').str[10]
vcf['HGVSP'] = vcf['csq'].str.split('|').str[11]
vcf['PolyPhen'] = vcf['csq'].str.split('|').str[38]
vcf['BIOTYPE'] = vcf['csq'].str.split('|').str[7]
vcf['EXON'] = vcf['csq'].str.split('|').str[8]
vcf['INTRON'] = vcf['csq'].str.split('|').str[9]
vcf['Protein_position'] = vcf['csq'].str.split('|').str[14]
vcf['Amino_acids'] = vcf['csq'].str.split('|').str[15]
vcf['Codons'] = vcf['csq'].str.split('|').str[16]
vcf['STRAND'] = vcf['csq'].str.split('|').str[19]
vcf['PUBMED'] = vcf['csq'].str.split('|').str[73]
vcf['Consequence'] = vcf['csq'].str.split('|').str[1]
vcf['IMPACT'] = vcf['csq'].str.split('|').str[2]
vcf['SIFT'] = vcf['csq'].str.split('|').str[37]
vcf
# Out:
#       CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 1      chr1     69511    rs2691305   A   G    .   PASS
# 2      chr1    451290            .   A   C    .   PASS
# 2      chr1    451290            .   A   C    .   PASS
# ...     ...       ...          ...  ..  ..  ...    ...
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 1      ADP=114;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  114  114
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# ...                                                  ...  ...  ...  ...  ...
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
#
#         RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity  \
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 1        0  114    100%   4.392E-68   0   0  98  16   0   1    Homozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# ...    ...  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
#
#          Gene_Name Gene Name  \
# 0      OR4F5:79501     OR4F5
# 0      OR4F5:79501     OR4F5
# 1      OR4F5:79501     OR4F5
# 2              NaN
# 2              NaN
# ...            ...       ...
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
#
#                                                      CSQ  \
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# ...                                                  ...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
#
#                                                      csq ClinVar_CLNDN  \
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 0      G|regulatory_region_variant|MODIFIER|||Regulat...
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# 2      C|intron_variant&non_coding_transcript_variant...
# ...                                                  ...           ...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
#
#       CLIN_SIG ClinVar_CLNREVSTAT ClinVar                             HGVSC  \
# 0                                                ENST00000641515.2:c.243A>G
# 0
# 1                                                ENST00000641515.2:c.484A>G
# 2                                                ENST00000426406.4:c.389T>G
# 2                                          ENST00000455207.5:n.169+33750T>G
# ...        ...                ...     ...                               ...
# 36651
# 36651
# 36651
# 36651
# 36651
#
#                                HGVSP       PolyPhen          BIOTYPE EXON  \
# 0       ENSP00000493376.2:p.Ser81%3D                  protein_coding  3/3
# 0                                                    TF_binding_site
# 1      ENSP00000493376.2:p.Thr162Ala      benign(0)   protein_coding  3/3
# 2      ENSP00000409316.1:p.Leu130Arg  benign(0.336)   protein_coding  1/1
# 2                                                             lncRNA
# ...                              ...            ...              ...  ...
# 36651                                                         lncRNA
# 36651                                                         lncRNA
# 36651                                                         lncRNA
# 36651                                                         lncRNA
# 36651                                                         lncRNA
#
#       INTRON Protein_position Amino_acids   Codons STRAND  \
# 0                          81           S  tcA/tcG      1
# 0
# 1                         162         T/A  Aca/Gca      1
# 2                         130         L/R  cTc/cGc     -1
# 2        1/2                                           -1
# ...      ...              ...         ...      ...    ...
# 36651                                                  -1
# 36651                                                  -1
# 36651                                                  -1
# 36651                                                  -1
# 36651                                                  -1
#
#                                                   PUBMED  \
# 0
# 0
# 1
# 2
# 2
# ...                                                  ...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
#
#                                         Consequence    IMPACT  \
# 0                                synonymous_variant       LOW
# 0                         regulatory_region_variant  MODIFIER
# 1                                  missense_variant  MODERATE
# 2                                  missense_variant  MODERATE
# 2      intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                             ...       ...
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
#
#                                    SIFT
# 0
# 0
# 1                       tolerated(0.92)
# 2      deleterious_low_confidence(0.01)
# 2
# ...                                 ...
# 36651
# 36651
# 36651
# 36651
# 36651
#
# [328334 rows x 45 columns]

# %%
vcf['Protein Position and Amino Acid'] = vcf['Amino_acids'].str[0] + vcf['Protein_position'] + np.where(vcf['Amino_acids'].str[-1] == vcf['Amino_acids'].str[0], '', vcf['Amino_acids'].str[-1])
vcf
# Out:
#       CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 1      chr1     69511    rs2691305   A   G    .   PASS
# 2      chr1    451290            .   A   C    .   PASS
# 2      chr1    451290            .   A   C    .   PASS
# ...     ...       ...          ...  ..  ..  ...    ...
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 1      ADP=114;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  114  114
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# ...                                                  ...  ...  ...  ...  ...
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
#
#         RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity  \
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 1        0  114    100%   4.392E-68   0   0  98  16   0   1    Homozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# ...    ...  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
#
#          Gene_Name Gene Name  \
# 0      OR4F5:79501     OR4F5
# 0      OR4F5:79501     OR4F5
# 1      OR4F5:79501     OR4F5
# 2              NaN
# 2              NaN
# ...            ...       ...
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
#
#                                                      CSQ  \
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# ...                                                  ...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
#
#                                                      csq ClinVar_CLNDN  \
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 0      G|regulatory_region_variant|MODIFIER|||Regulat...
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# 2      C|intron_variant&non_coding_transcript_variant...
# ...                                                  ...           ...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
#
#       CLIN_SIG ClinVar_CLNREVSTAT ClinVar                             HGVSC  \
# 0                                                ENST00000641515.2:c.243A>G
# 0
# 1                                                ENST00000641515.2:c.484A>G
# 2                                                ENST00000426406.4:c.389T>G
# 2                                          ENST00000455207.5:n.169+33750T>G
# ...        ...                ...     ...                               ...
# 36651
# 36651
# 36651
# 36651
# 36651
#
#                                HGVSP       PolyPhen          BIOTYPE EXON  \
# 0       ENSP00000493376.2:p.Ser81%3D                  protein_coding  3/3
# 0                                                    TF_binding_site
# 1      ENSP00000493376.2:p.Thr162Ala      benign(0)   protein_coding  3/3
# 2      ENSP00000409316.1:p.Leu130Arg  benign(0.336)   protein_coding  1/1
# 2                                                             lncRNA
# ...                              ...            ...              ...  ...
# 36651                                                         lncRNA
# 36651                                                         lncRNA
# 36651                                                         lncRNA
# 36651                                                         lncRNA
# 36651                                                         lncRNA
#
#       INTRON Protein_position Amino_acids   Codons STRAND  \
# 0                          81           S  tcA/tcG      1
# 0
# 1                         162         T/A  Aca/Gca      1
# 2                         130         L/R  cTc/cGc     -1
# 2        1/2                                           -1
# ...      ...              ...         ...      ...    ...
# 36651                                                  -1
# 36651                                                  -1
# 36651                                                  -1
# 36651                                                  -1
# 36651                                                  -1
#
#                                                   PUBMED  \
# 0
# 0
# 1
# 2
# 2
# ...                                                  ...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
#
#                                         Consequence    IMPACT  \
# 0                                synonymous_variant       LOW
# 0                         regulatory_region_variant  MODIFIER
# 1                                  missense_variant  MODERATE
# 2                                  missense_variant  MODERATE
# 2      intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                             ...       ...
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
#
#                                    SIFT Protein Position and Amino Acid
# 0                                                                   S81
# 0                                                                   NaN
# 1                       tolerated(0.92)                           T162A
# 2      deleterious_low_confidence(0.01)                           L130R
# 2                                                                   NaN
# ...                                 ...                             ...
# 36651                                                               NaN
# 36651                                                               NaN
# 36651                                                               NaN
# 36651                                                               NaN
# 36651                                                               NaN
#
# [328334 rows x 46 columns]

# %%
vcf[['HGVSc', 'HGVSc (Transcript)']] = vcf['HGVSC'].str.split(':', 1, expand=True)
vcf[['HGVSp', 'HGVSp (Transcript)']] = vcf['HGVSP'].str.split(':', 1, expand=True)
vcf
# Out:
#       CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 1      chr1     69511    rs2691305   A   G    .   PASS
# 2      chr1    451290            .   A   C    .   PASS
# 2      chr1    451290            .   A   C    .   PASS
# ...     ...       ...          ...  ..  ..  ...    ...
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 1      ADP=114;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  114  114
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# ...                                                  ...  ...  ...  ...  ...
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
#
#         RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity  \
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 1        0  114    100%   4.392E-68   0   0  98  16   0   1    Homozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# ...    ...  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
#
#          Gene_Name Gene Name  \
# 0      OR4F5:79501     OR4F5
# 0      OR4F5:79501     OR4F5
# 1      OR4F5:79501     OR4F5
# 2              NaN
# 2              NaN
# ...            ...       ...
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
#
#                                                      CSQ  \
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# ...                                                  ...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
#
#                                                      csq ClinVar_CLNDN  \
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 0      G|regulatory_region_variant|MODIFIER|||Regulat...
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# 2      C|intron_variant&non_coding_transcript_variant...
# ...                                                  ...           ...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
#
#       CLIN_SIG ClinVar_CLNREVSTAT ClinVar                             HGVSC  \
# 0                                                ENST00000641515.2:c.243A>G
# 0
# 1                                                ENST00000641515.2:c.484A>G
# 2                                                ENST00000426406.4:c.389T>G
# 2                                          ENST00000455207.5:n.169+33750T>G
# ...        ...                ...     ...                               ...
# 36651
# 36651
# 36651
# 36651
# 36651
#
#                                HGVSP       PolyPhen          BIOTYPE EXON  \
# 0       ENSP00000493376.2:p.Ser81%3D                  protein_coding  3/3
# 0                                                    TF_binding_site
# 1      ENSP00000493376.2:p.Thr162Ala      benign(0)   protein_coding  3/3
# 2      ENSP00000409316.1:p.Leu130Arg  benign(0.336)   protein_coding  1/1
# 2                                                             lncRNA
# ...                              ...            ...              ...  ...
# 36651                                                         lncRNA
# 36651                                                         lncRNA
# 36651                                                         lncRNA
# 36651                                                         lncRNA
# 36651                                                         lncRNA
#
#       INTRON Protein_position Amino_acids   Codons STRAND  \
# 0                          81           S  tcA/tcG      1
# 0
# 1                         162         T/A  Aca/Gca      1
# 2                         130         L/R  cTc/cGc     -1
# 2        1/2                                           -1
# ...      ...              ...         ...      ...    ...
# 36651                                                  -1
# 36651                                                  -1
# 36651                                                  -1
# 36651                                                  -1
# 36651                                                  -1
#
#                                                   PUBMED  \
# 0
# 0
# 1
# 2
# 2
# ...                                                  ...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
#
#                                         Consequence    IMPACT  \
# 0                                synonymous_variant       LOW
# 0                         regulatory_region_variant  MODIFIER
# 1                                  missense_variant  MODERATE
# 2                                  missense_variant  MODERATE
# 2      intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                             ...       ...
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
#
#                                    SIFT Protein Position and Amino Acid  \
# 0                                                                   S81
# 0                                                                   NaN
# 1                       tolerated(0.92)                           T162A
# 2      deleterious_low_confidence(0.01)                           L130R
# 2                                                                   NaN
# ...                                 ...                             ...
# 36651                                                               NaN
# 36651                                                               NaN
# 36651                                                               NaN
# 36651                                                               NaN
# 36651                                                               NaN
#
#                    HGVSc HGVSc (Transcript)              HGVSp  \
# 0      ENST00000641515.2           c.243A>G  ENSP00000493376.2
# 0                                      None
# 1      ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 2      ENST00000426406.4           c.389T>G  ENSP00000409316.1
# 2      ENST00000455207.5     n.169+33750T>G
# ...                  ...                ...                ...
# 36651                                  None
# 36651                                  None
# 36651                                  None
# 36651                                  None
# 36651                                  None
#
#       HGVSp (Transcript)
# 0             p.Ser81%3D
# 0                   None
# 1            p.Thr162Ala
# 2            p.Leu130Arg
# 2                   None
# ...                  ...
# 36651               None
# 36651               None
# 36651               None
# 36651               None
# 36651               None
#
# [328334 rows x 50 columns]

# %%
vcf_final = vcf[['Gene Name', 'rsID','CHROM', 'POS', 'REF', 'ALT', 'Zygosity', 'Consequence', 'IMPACT',
          'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT',
          'ClinVar', 'HGVSc', 'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF',
       'ADR', 'SIFT', 'PolyPhen', 'BIOTYPE', 'EXON', 'INTRON',
          'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED']]
vcf_final
# Out:
#       Gene Name         rsID CHROM       POS REF ALT      Zygosity  \
# 0         OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 0         OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 1         OR4F5    rs2691305  chr1     69511   A   G    Homozygous
# 2                          .  chr1    451290   A   C  Heterozygous
# 2                          .  chr1    451290   A   C  Heterozygous
# ...         ...          ...   ...       ...  ..  ..           ...
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
#
#                                         Consequence    IMPACT ClinVar_CLNDN  \
# 0                                synonymous_variant       LOW
# 0                         regulatory_region_variant  MODIFIER
# 1                                  missense_variant  MODERATE
# 2                                  missense_variant  MODERATE
# 2      intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                             ...       ...           ...
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
#
#       CLIN_SIG ClinVar_CLNREVSTAT ClinVar              HGVSc  \
# 0                                          ENST00000641515.2
# 0
# 1                                          ENST00000641515.2
# 2                                          ENST00000426406.4
# 2                                          ENST00000455207.5
# ...        ...                ...     ...                ...
# 36651
# 36651
# 36651
# 36651
# 36651
#
#       HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  SDP  \
# 0               c.243A>G  ENSP00000493376.2         p.Ser81%3D  0/1  127  138
# 0                   None                                  None  0/1  127  138
# 1               c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255  114
# 2               c.389T>G  ENSP00000409316.1        p.Leu130Arg  0/1   56   64
# 2         n.169+33750T>G                                  None  0/1   56   64
# ...                  ...                ...                ...  ...  ...  ...
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
#
#         DP   RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0      138  100   38  27.54%  1.8855E-13  86  14  29   9
# 0      138  100   38  27.54%  1.8855E-13  86  14  29   9
# 1      114    0  114    100%   4.392E-68   0   0  98  16
# 2       64   47   17  26.56%    2.243E-6  33  14  15   2
# 2       64   47   17  26.56%    2.243E-6  33  14  15   2
# ...    ...  ...  ...     ...         ...  ..  ..  ..  ..
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
#
#                                    SIFT       PolyPhen          BIOTYPE EXON  \
# 0                                                        protein_coding  3/3
# 0                                                       TF_binding_site
# 1                       tolerated(0.92)      benign(0)   protein_coding  3/3
# 2      deleterious_low_confidence(0.01)  benign(0.336)   protein_coding  1/1
# 2                                                                lncRNA
# ...                                 ...            ...              ...  ...
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
#
#       INTRON Protein Position and Amino Acid   Codons STRAND  \
# 0                                        S81  tcA/tcG      1
# 0                                        NaN
# 1                                      T162A  Aca/Gca      1
# 2                                      L130R  cTc/cGc     -1
# 2        1/2                             NaN              -1
# ...      ...                             ...      ...    ...
# 36651                                    NaN              -1
# 36651                                    NaN              -1
# 36651                                    NaN              -1
# 36651                                    NaN              -1
# 36651                                    NaN              -1
#
#                                                   PUBMED
# 0
# 0
# 1
# 2
# 2
# ...                                                  ...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
#
# [328334 rows x 38 columns]

# %%
# Define the terms to remove
remove_terms = set(["not_specified", "not_provided"])

# Apply the filtering operation to 'Column1' only
vcf_final['ClinVar_CLNDN'] = vcf_final['ClinVar_CLNDN'].apply(lambda row: "&".join(
    [term for term in row.split("&") if term not in remove_terms]
    ) if isinstance(row, str) and not all(term in remove_terms for term in row.split("&")) else row)


vcf_final['CLIN_SIG'] = vcf_final['CLIN_SIG'].apply(lambda row: "&".join(
    [term for term in row.split("&") if term not in remove_terms]
    ) if isinstance(row, str) and not all(term in remove_terms for term in row.split("&")) else row)


vcf_final['ClinVar_CLNREVSTAT'] = vcf_final['ClinVar_CLNREVSTAT'].apply(lambda row: "&".join(
    [term for term in row.split("&") if term not in remove_terms]
    ) if isinstance(row, str) and not all(term in remove_terms for term in row.split("&")) else row)

# Print the modified DataFrame
vcf_final
# Out:
#       Gene Name         rsID CHROM       POS REF ALT      Zygosity  \
# 0         OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 0         OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 1         OR4F5    rs2691305  chr1     69511   A   G    Homozygous
# 2                          .  chr1    451290   A   C  Heterozygous
# 2                          .  chr1    451290   A   C  Heterozygous
# ...         ...          ...   ...       ...  ..  ..           ...
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
#
#                                         Consequence    IMPACT ClinVar_CLNDN  \
# 0                                synonymous_variant       LOW
# 0                         regulatory_region_variant  MODIFIER
# 1                                  missense_variant  MODERATE
# 2                                  missense_variant  MODERATE
# 2      intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                             ...       ...           ...
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
# 36651                         upstream_gene_variant  MODIFIER
#
#       CLIN_SIG ClinVar_CLNREVSTAT ClinVar              HGVSc  \
# 0                                          ENST00000641515.2
# 0
# 1                                          ENST00000641515.2
# 2                                          ENST00000426406.4
# 2                                          ENST00000455207.5
# ...        ...                ...     ...                ...
# 36651
# 36651
# 36651
# 36651
# 36651
#
#       HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  SDP  \
# 0               c.243A>G  ENSP00000493376.2         p.Ser81%3D  0/1  127  138
# 0                   None                                  None  0/1  127  138
# 1               c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255  114
# 2               c.389T>G  ENSP00000409316.1        p.Leu130Arg  0/1   56   64
# 2         n.169+33750T>G                                  None  0/1   56   64
# ...                  ...                ...                ...  ...  ...  ...
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
#
#         DP   RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0      138  100   38  27.54%  1.8855E-13  86  14  29   9
# 0      138  100   38  27.54%  1.8855E-13  86  14  29   9
# 1      114    0  114    100%   4.392E-68   0   0  98  16
# 2       64   47   17  26.56%    2.243E-6  33  14  15   2
# 2       64   47   17  26.56%    2.243E-6  33  14  15   2
# ...    ...  ...  ...     ...         ...  ..  ..  ..  ..
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
#
#                                    SIFT       PolyPhen          BIOTYPE EXON  \
# 0                                                        protein_coding  3/3
# 0                                                       TF_binding_site
# 1                       tolerated(0.92)      benign(0)   protein_coding  3/3
# 2      deleterious_low_confidence(0.01)  benign(0.336)   protein_coding  1/1
# 2                                                                lncRNA
# ...                                 ...            ...              ...  ...
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
#
#       INTRON Protein Position and Amino Acid   Codons STRAND  \
# 0                                        S81  tcA/tcG      1
# 0                                        NaN
# 1                                      T162A  Aca/Gca      1
# 2                                      L130R  cTc/cGc     -1
# 2        1/2                             NaN              -1
# ...      ...                             ...      ...    ...
# 36651                                    NaN              -1
# 36651                                    NaN              -1
# 36651                                    NaN              -1
# 36651                                    NaN              -1
# 36651                                    NaN              -1
#
#                                                   PUBMED
# 0
# 0
# 1
# 2
# 2
# ...                                                  ...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
# 36651  22271044&29391530&24262073&15896936&32996047&3...
#
# [328334 rows x 38 columns]

# %%
vcf_final = vcf_final.astype(str).applymap(lambda x: x.replace('&', ',').replace('_', ' '))
vcf_final
# Out:
#       Gene Name         rsID CHROM       POS REF ALT      Zygosity  \
# 0         OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 0         OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 1         OR4F5    rs2691305  chr1     69511   A   G    Homozygous
# 2                          .  chr1    451290   A   C  Heterozygous
# 2                          .  chr1    451290   A   C  Heterozygous
# ...         ...          ...   ...       ...  ..  ..           ...
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
#
#                                         Consequence    IMPACT ClinVar_CLNDN  \
# 0                                synonymous variant       LOW
# 0                         regulatory region variant  MODIFIER
# 1                                  missense variant  MODERATE
# 2                                  missense variant  MODERATE
# 2      intron variant,non coding transcript variant  MODIFIER
# ...                                             ...       ...           ...
# 36651                         upstream gene variant  MODIFIER
# 36651                         upstream gene variant  MODIFIER
# 36651                         upstream gene variant  MODIFIER
# 36651                         upstream gene variant  MODIFIER
# 36651                         upstream gene variant  MODIFIER
#
#       CLIN_SIG ClinVar_CLNREVSTAT ClinVar              HGVSc  \
# 0                                          ENST00000641515.2
# 0
# 1                                          ENST00000641515.2
# 2                                          ENST00000426406.4
# 2                                          ENST00000455207.5
# ...        ...                ...     ...                ...
# 36651
# 36651
# 36651
# 36651
# 36651
#
#       HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  SDP  \
# 0               c.243A>G  ENSP00000493376.2         p.Ser81%3D  0/1  127  138
# 0                   None                                  None  0/1  127  138
# 1               c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255  114
# 2               c.389T>G  ENSP00000409316.1        p.Leu130Arg  0/1   56   64
# 2         n.169+33750T>G                                  None  0/1   56   64
# ...                  ...                ...                ...  ...  ...  ...
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
#
#         DP   RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0      138  100   38  27.54%  1.8855E-13  86  14  29   9
# 0      138  100   38  27.54%  1.8855E-13  86  14  29   9
# 1      114    0  114    100%   4.392E-68   0   0  98  16
# 2       64   47   17  26.56%    2.243E-6  33  14  15   2
# 2       64   47   17  26.56%    2.243E-6  33  14  15   2
# ...    ...  ...  ...     ...         ...  ..  ..  ..  ..
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
#
#                                    SIFT       PolyPhen          BIOTYPE EXON  \
# 0                                                        protein coding  3/3
# 0                                                       TF binding site
# 1                       tolerated(0.92)      benign(0)   protein coding  3/3
# 2      deleterious low confidence(0.01)  benign(0.336)   protein coding  1/1
# 2                                                                lncRNA
# ...                                 ...            ...              ...  ...
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
#
#       INTRON Protein Position and Amino Acid   Codons STRAND  \
# 0                                        S81  tcA/tcG      1
# 0                                        nan
# 1                                      T162A  Aca/Gca      1
# 2                                      L130R  cTc/cGc     -1
# 2        1/2                             nan              -1
# ...      ...                             ...      ...    ...
# 36651                                    nan              -1
# 36651                                    nan              -1
# 36651                                    nan              -1
# 36651                                    nan              -1
# 36651                                    nan              -1
#
#                                                   PUBMED
# 0
# 0
# 1
# 2
# 2
# ...                                                  ...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
#
# [328334 rows x 38 columns]

# %%
vcf_final['POS'] = vcf_final['POS'].astype('int64')
vcf_final
# Out:
#       Gene Name         rsID CHROM       POS REF ALT      Zygosity  \
# 0         OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 0         OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 1         OR4F5    rs2691305  chr1     69511   A   G    Homozygous
# 2                          .  chr1    451290   A   C  Heterozygous
# 2                          .  chr1    451290   A   C  Heterozygous
# ...         ...          ...   ...       ...  ..  ..           ...
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
#
#                                         Consequence    IMPACT ClinVar_CLNDN  \
# 0                                synonymous variant       LOW
# 0                         regulatory region variant  MODIFIER
# 1                                  missense variant  MODERATE
# 2                                  missense variant  MODERATE
# 2      intron variant,non coding transcript variant  MODIFIER
# ...                                             ...       ...           ...
# 36651                         upstream gene variant  MODIFIER
# 36651                         upstream gene variant  MODIFIER
# 36651                         upstream gene variant  MODIFIER
# 36651                         upstream gene variant  MODIFIER
# 36651                         upstream gene variant  MODIFIER
#
#       CLIN_SIG ClinVar_CLNREVSTAT ClinVar              HGVSc  \
# 0                                          ENST00000641515.2
# 0
# 1                                          ENST00000641515.2
# 2                                          ENST00000426406.4
# 2                                          ENST00000455207.5
# ...        ...                ...     ...                ...
# 36651
# 36651
# 36651
# 36651
# 36651
#
#       HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  SDP  \
# 0               c.243A>G  ENSP00000493376.2         p.Ser81%3D  0/1  127  138
# 0                   None                                  None  0/1  127  138
# 1               c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255  114
# 2               c.389T>G  ENSP00000409316.1        p.Leu130Arg  0/1   56   64
# 2         n.169+33750T>G                                  None  0/1   56   64
# ...                  ...                ...                ...  ...  ...  ...
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
#
#         DP   RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0      138  100   38  27.54%  1.8855E-13  86  14  29   9
# 0      138  100   38  27.54%  1.8855E-13  86  14  29   9
# 1      114    0  114    100%   4.392E-68   0   0  98  16
# 2       64   47   17  26.56%    2.243E-6  33  14  15   2
# 2       64   47   17  26.56%    2.243E-6  33  14  15   2
# ...    ...  ...  ...     ...         ...  ..  ..  ..  ..
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
#
#                                    SIFT       PolyPhen          BIOTYPE EXON  \
# 0                                                        protein coding  3/3
# 0                                                       TF binding site
# 1                       tolerated(0.92)      benign(0)   protein coding  3/3
# 2      deleterious low confidence(0.01)  benign(0.336)   protein coding  1/1
# 2                                                                lncRNA
# ...                                 ...            ...              ...  ...
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
#
#       INTRON Protein Position and Amino Acid   Codons STRAND  \
# 0                                        S81  tcA/tcG      1
# 0                                        nan
# 1                                      T162A  Aca/Gca      1
# 2                                      L130R  cTc/cGc     -1
# 2        1/2                             nan              -1
# ...      ...                             ...      ...    ...
# 36651                                    nan              -1
# 36651                                    nan              -1
# 36651                                    nan              -1
# 36651                                    nan              -1
# 36651                                    nan              -1
#
#                                                   PUBMED
# 0
# 0
# 1
# 2
# 2
# ...                                                  ...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
#
# [328334 rows x 38 columns]

# %%
vcf_final['consequence'] = vcf_final['Consequence'].str.split(',').str[0]
vcf_final
# Out:
#       Gene Name         rsID CHROM       POS REF ALT      Zygosity  \
# 0         OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 0         OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 1         OR4F5    rs2691305  chr1     69511   A   G    Homozygous
# 2                          .  chr1    451290   A   C  Heterozygous
# 2                          .  chr1    451290   A   C  Heterozygous
# ...         ...          ...   ...       ...  ..  ..           ...
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 36651    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
#
#                                         Consequence    IMPACT ClinVar_CLNDN  \
# 0                                synonymous variant       LOW
# 0                         regulatory region variant  MODIFIER
# 1                                  missense variant  MODERATE
# 2                                  missense variant  MODERATE
# 2      intron variant,non coding transcript variant  MODIFIER
# ...                                             ...       ...           ...
# 36651                         upstream gene variant  MODIFIER
# 36651                         upstream gene variant  MODIFIER
# 36651                         upstream gene variant  MODIFIER
# 36651                         upstream gene variant  MODIFIER
# 36651                         upstream gene variant  MODIFIER
#
#       CLIN_SIG ClinVar_CLNREVSTAT ClinVar              HGVSc  \
# 0                                          ENST00000641515.2
# 0
# 1                                          ENST00000641515.2
# 2                                          ENST00000426406.4
# 2                                          ENST00000455207.5
# ...        ...                ...     ...                ...
# 36651
# 36651
# 36651
# 36651
# 36651
#
#       HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  SDP  \
# 0               c.243A>G  ENSP00000493376.2         p.Ser81%3D  0/1  127  138
# 0                   None                                  None  0/1  127  138
# 1               c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255  114
# 2               c.389T>G  ENSP00000409316.1        p.Leu130Arg  0/1   56   64
# 2         n.169+33750T>G                                  None  0/1   56   64
# ...                  ...                ...                ...  ...  ...  ...
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
# 36651               None                                  None  1/1  123   22
#
#         DP   RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0      138  100   38  27.54%  1.8855E-13  86  14  29   9
# 0      138  100   38  27.54%  1.8855E-13  86  14  29   9
# 1      114    0  114    100%   4.392E-68   0   0  98  16
# 2       64   47   17  26.56%    2.243E-6  33  14  15   2
# 2       64   47   17  26.56%    2.243E-6  33  14  15   2
# ...    ...  ...  ...     ...         ...  ..  ..  ..  ..
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
# 36651   22    0   22    100%  4.7526E-13   0   0  14   8
#
#                                    SIFT       PolyPhen          BIOTYPE EXON  \
# 0                                                        protein coding  3/3
# 0                                                       TF binding site
# 1                       tolerated(0.92)      benign(0)   protein coding  3/3
# 2      deleterious low confidence(0.01)  benign(0.336)   protein coding  1/1
# 2                                                                lncRNA
# ...                                 ...            ...              ...  ...
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
# 36651                                                            lncRNA
#
#       INTRON Protein Position and Amino Acid   Codons STRAND  \
# 0                                        S81  tcA/tcG      1
# 0                                        nan
# 1                                      T162A  Aca/Gca      1
# 2                                      L130R  cTc/cGc     -1
# 2        1/2                             nan              -1
# ...      ...                             ...      ...    ...
# 36651                                    nan              -1
# 36651                                    nan              -1
# 36651                                    nan              -1
# 36651                                    nan              -1
# 36651                                    nan              -1
#
#                                                   PUBMED  \
# 0
# 0
# 1
# 2
# 2
# ...                                                  ...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
# 36651  22271044,29391530,24262073,15896936,32996047,3...
#
#                      consequence
# 0             synonymous variant
# 0      regulatory region variant
# 1               missense variant
# 2               missense variant
# 2                 intron variant
# ...                          ...
# 36651      upstream gene variant
# 36651      upstream gene variant
# 36651      upstream gene variant
# 36651      upstream gene variant
# 36651      upstream gene variant
#
# [328334 rows x 39 columns]

# %%
df_1 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Madhu_folder_04_07_2023/kidney_health_final.vcf/consequence.xlsx')
df_1
# Out:
#                             consequence Consequence_score
# 0                   transcript ablation             10/10
# 1               splice acceptor variant              8/10
# 2                  splice donor variant              8/10
# 3                           stop gained             10/10
# 4                    frameshift variant             10/10
# 5                             stop lost              9/10
# 6                            start lost              9/10
# 7              transcript amplification              8/10
# 8                     inframe insertion              6/10
# 9                      inframe deletion              6/10
# 10                     missense variant              7/10
# 11             protein altering variant              5/10
# 12                splice region variant              4/10
# 13        splice donor 5th base variant              4/10
# 14          splice donor region variant              4/10
# 15  splice polypyrimidine tract variant              4/10
# 16    incomplete terminal codon variant              3/10
# 17               start retained variant              3/10
# 18                stop retained variant              3/10
# 19                   synonymous variant              3/10
# 20              coding sequence variant              3/10
# 21                 mature miRNA variant              3/10
# 22                  5 prime UTR variant              3/10
# 23                  3 prime UTR variant              3/10
# 24   non coding transcript exon variant              2/10
# 25                       intron variant              2/10
# 26               NMD transcript variant              2/10
# 27        non coding transcript variant              2/10
# 28                upstream gene variant              2/10
# 29              downstream gene variant              2/10
# 30                        TFBS ablation              2/10
# 31                   TFBS amplification              2/10
# 32              TF binding site variant              2/10
# 33           regulatory region ablation              2/10
# 34      regulatory region amplification              2/10
# 35                   feature elongation              2/10
# 36            regulatory region variant              2/10
# 37                   feature truncation              1/10
# 38                   intergenic variant              1/10

# %%
merged_1 = pd.merge(vcf_final, df_1, on='consequence', how='left', sort=False)
merged_1
# Out:
#        Gene Name         rsID CHROM       POS REF ALT      Zygosity  \
# 0          OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 1          OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 2          OR4F5    rs2691305  chr1     69511   A   G    Homozygous
# 3                           .  chr1    451290   A   C  Heterozygous
# 4                           .  chr1    451290   A   C  Heterozygous
# ...          ...          ...   ...       ...  ..  ..           ...
# 328329    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328330    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328331    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328332    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328333    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
#
#                                          Consequence    IMPACT ClinVar_CLNDN  \
# 0                                 synonymous variant       LOW
# 1                          regulatory region variant  MODIFIER
# 2                                   missense variant  MODERATE
# 3                                   missense variant  MODERATE
# 4       intron variant,non coding transcript variant  MODIFIER
# ...                                              ...       ...           ...
# 328329                         upstream gene variant  MODIFIER
# 328330                         upstream gene variant  MODIFIER
# 328331                         upstream gene variant  MODIFIER
# 328332                         upstream gene variant  MODIFIER
# 328333                         upstream gene variant  MODIFIER
#
#        CLIN_SIG ClinVar_CLNREVSTAT ClinVar              HGVSc  \
# 0                                           ENST00000641515.2
# 1
# 2                                           ENST00000641515.2
# 3                                           ENST00000426406.4
# 4                                           ENST00000455207.5
# ...         ...                ...     ...                ...
# 328329
# 328330
# 328331
# 328332
# 328333
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  \
# 0                c.243A>G  ENSP00000493376.2         p.Ser81%3D  0/1  127
# 1                    None                                  None  0/1  127
# 2                c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255
# 3                c.389T>G  ENSP00000409316.1        p.Leu130Arg  0/1   56
# 4          n.169+33750T>G                                  None  0/1   56
# ...                   ...                ...                ...  ...  ...
# 328329               None                                  None  1/1  123
# 328330               None                                  None  1/1  123
# 328331               None                                  None  1/1  123
# 328332               None                                  None  1/1  123
# 328333               None                                  None  1/1  123
#
#         SDP   DP   RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0       138  138  100   38  27.54%  1.8855E-13  86  14  29   9
# 1       138  138  100   38  27.54%  1.8855E-13  86  14  29   9
# 2       114  114    0  114    100%   4.392E-68   0   0  98  16
# 3        64   64   47   17  26.56%    2.243E-6  33  14  15   2
# 4        64   64   47   17  26.56%    2.243E-6  33  14  15   2
# ...     ...  ...  ...  ...     ...         ...  ..  ..  ..  ..
# 328329   22   22    0   22    100%  4.7526E-13   0   0  14   8
# 328330   22   22    0   22    100%  4.7526E-13   0   0  14   8
# 328331   22   22    0   22    100%  4.7526E-13   0   0  14   8
# 328332   22   22    0   22    100%  4.7526E-13   0   0  14   8
# 328333   22   22    0   22    100%  4.7526E-13   0   0  14   8
#
#                                     SIFT       PolyPhen          BIOTYPE EXON  \
# 0                                                         protein coding  3/3
# 1                                                        TF binding site
# 2                        tolerated(0.92)      benign(0)   protein coding  3/3
# 3       deleterious low confidence(0.01)  benign(0.336)   protein coding  1/1
# 4                                                                 lncRNA
# ...                                  ...            ...              ...  ...
# 328329                                                            lncRNA
# 328330                                                            lncRNA
# 328331                                                            lncRNA
# 328332                                                            lncRNA
# 328333                                                            lncRNA
#
#        INTRON Protein Position and Amino Acid   Codons STRAND  \
# 0                                         S81  tcA/tcG      1
# 1                                         nan
# 2                                       T162A  Aca/Gca      1
# 3                                       L130R  cTc/cGc     -1
# 4         1/2                             nan              -1
# ...       ...                             ...      ...    ...
# 328329                                    nan              -1
# 328330                                    nan              -1
# 328331                                    nan              -1
# 328332                                    nan              -1
# 328333                                    nan              -1
#
#                                                    PUBMED  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 328329  22271044,29391530,24262073,15896936,32996047,3...
# 328330  22271044,29391530,24262073,15896936,32996047,3...
# 328331  22271044,29391530,24262073,15896936,32996047,3...
# 328332  22271044,29391530,24262073,15896936,32996047,3...
# 328333  22271044,29391530,24262073,15896936,32996047,3...
#
#                       consequence Consequence_score
# 0              synonymous variant              3/10
# 1       regulatory region variant              2/10
# 2                missense variant              7/10
# 3                missense variant              7/10
# 4                  intron variant              2/10
# ...                           ...               ...
# 328329      upstream gene variant              2/10
# 328330      upstream gene variant              2/10
# 328331      upstream gene variant              2/10
# 328332      upstream gene variant              2/10
# 328333      upstream gene variant              2/10
#
# [328334 rows x 40 columns]

# %%
df_2 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Madhu_folder_04_07_2023/kidney_health_final.vcf/IMPACT.xlsx')
df_2
# Out:
#      IMPACT  IMPACT_score
# 0      HIGH          10.0
# 1  MODERATE           5.0
# 2       LOW           2.5
# 3  MODIFIER           1.5

# %%
merged_2 = pd.merge(merged_1, df_2, on = 'IMPACT', how='left', sort=False)
merged_2
# Out:
#        Gene Name         rsID CHROM       POS REF ALT      Zygosity  \
# 0          OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 1          OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 2          OR4F5    rs2691305  chr1     69511   A   G    Homozygous
# 3                           .  chr1    451290   A   C  Heterozygous
# 4                           .  chr1    451290   A   C  Heterozygous
# ...          ...          ...   ...       ...  ..  ..           ...
# 328329    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328330    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328331    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328332    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328333    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
#
#                                          Consequence    IMPACT ClinVar_CLNDN  \
# 0                                 synonymous variant       LOW
# 1                          regulatory region variant  MODIFIER
# 2                                   missense variant  MODERATE
# 3                                   missense variant  MODERATE
# 4       intron variant,non coding transcript variant  MODIFIER
# ...                                              ...       ...           ...
# 328329                         upstream gene variant  MODIFIER
# 328330                         upstream gene variant  MODIFIER
# 328331                         upstream gene variant  MODIFIER
# 328332                         upstream gene variant  MODIFIER
# 328333                         upstream gene variant  MODIFIER
#
#        CLIN_SIG ClinVar_CLNREVSTAT ClinVar              HGVSc  \
# 0                                           ENST00000641515.2
# 1
# 2                                           ENST00000641515.2
# 3                                           ENST00000426406.4
# 4                                           ENST00000455207.5
# ...         ...                ...     ...                ...
# 328329
# 328330
# 328331
# 328332
# 328333
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  \
# 0                c.243A>G  ENSP00000493376.2         p.Ser81%3D  0/1  127
# 1                    None                                  None  0/1  127
# 2                c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255
# 3                c.389T>G  ENSP00000409316.1        p.Leu130Arg  0/1   56
# 4          n.169+33750T>G                                  None  0/1   56
# ...                   ...                ...                ...  ...  ...
# 328329               None                                  None  1/1  123
# 328330               None                                  None  1/1  123
# 328331               None                                  None  1/1  123
# 328332               None                                  None  1/1  123
# 328333               None                                  None  1/1  123
#
#         SDP   DP   RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0       138  138  100   38  27.54%  1.8855E-13  86  14  29   9
# 1       138  138  100   38  27.54%  1.8855E-13  86  14  29   9
# 2       114  114    0  114    100%   4.392E-68   0   0  98  16
# 3        64   64   47   17  26.56%    2.243E-6  33  14  15   2
# 4        64   64   47   17  26.56%    2.243E-6  33  14  15   2
# ...     ...  ...  ...  ...     ...         ...  ..  ..  ..  ..
# 328329   22   22    0   22    100%  4.7526E-13   0   0  14   8
# 328330   22   22    0   22    100%  4.7526E-13   0   0  14   8
# 328331   22   22    0   22    100%  4.7526E-13   0   0  14   8
# 328332   22   22    0   22    100%  4.7526E-13   0   0  14   8
# 328333   22   22    0   22    100%  4.7526E-13   0   0  14   8
#
#                                     SIFT       PolyPhen          BIOTYPE EXON  \
# 0                                                         protein coding  3/3
# 1                                                        TF binding site
# 2                        tolerated(0.92)      benign(0)   protein coding  3/3
# 3       deleterious low confidence(0.01)  benign(0.336)   protein coding  1/1
# 4                                                                 lncRNA
# ...                                  ...            ...              ...  ...
# 328329                                                            lncRNA
# 328330                                                            lncRNA
# 328331                                                            lncRNA
# 328332                                                            lncRNA
# 328333                                                            lncRNA
#
#        INTRON Protein Position and Amino Acid   Codons STRAND  \
# 0                                         S81  tcA/tcG      1
# 1                                         nan
# 2                                       T162A  Aca/Gca      1
# 3                                       L130R  cTc/cGc     -1
# 4         1/2                             nan              -1
# ...       ...                             ...      ...    ...
# 328329                                    nan              -1
# 328330                                    nan              -1
# 328331                                    nan              -1
# 328332                                    nan              -1
# 328333                                    nan              -1
#
#                                                    PUBMED  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 328329  22271044,29391530,24262073,15896936,32996047,3...
# 328330  22271044,29391530,24262073,15896936,32996047,3...
# 328331  22271044,29391530,24262073,15896936,32996047,3...
# 328332  22271044,29391530,24262073,15896936,32996047,3...
# 328333  22271044,29391530,24262073,15896936,32996047,3...
#
#                       consequence Consequence_score  IMPACT_score
# 0              synonymous variant              3/10           2.5
# 1       regulatory region variant              2/10           1.5
# 2                missense variant              7/10           5.0
# 3                missense variant              7/10           5.0
# 4                  intron variant              2/10           1.5
# ...                           ...               ...           ...
# 328329      upstream gene variant              2/10           1.5
# 328330      upstream gene variant              2/10           1.5
# 328331      upstream gene variant              2/10           1.5
# 328332      upstream gene variant              2/10           1.5
# 328333      upstream gene variant              2/10           1.5
#
# [328334 rows x 41 columns]

# %%
merged_2 = merged_2[['Gene Name', 'rsID', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
       'Consequence','Consequence_score', 'IMPACT', 'IMPACT_score', 'ClinVar_CLNDN', 'CLIN_SIG',
       'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc', 'HGVSc (Transcript)', 'HGVSp',
       'HGVSp (Transcript)', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ',
       'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT', 'PolyPhen', 'BIOTYPE',
       'EXON', 'INTRON', 'Protein Position and Amino Acid', 'Codons', 'STRAND',
       'PUBMED']]
merged_2
# Out:
#        Gene Name         rsID CHROM       POS REF ALT      Zygosity  \
# 0          OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 1          OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 2          OR4F5    rs2691305  chr1     69511   A   G    Homozygous
# 3                           .  chr1    451290   A   C  Heterozygous
# 4                           .  chr1    451290   A   C  Heterozygous
# ...          ...          ...   ...       ...  ..  ..           ...
# 328329    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328330    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328331    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328332    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328333    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
#
#                                          Consequence Consequence_score  \
# 0                                 synonymous variant              3/10
# 1                          regulatory region variant              2/10
# 2                                   missense variant              7/10
# 3                                   missense variant              7/10
# 4       intron variant,non coding transcript variant              2/10
# ...                                              ...               ...
# 328329                         upstream gene variant              2/10
# 328330                         upstream gene variant              2/10
# 328331                         upstream gene variant              2/10
# 328332                         upstream gene variant              2/10
# 328333                         upstream gene variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT  \
# 0            LOW           2.5
# 1       MODIFIER           1.5
# 2       MODERATE           5.0
# 3       MODERATE           5.0
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...                ...
# 328329  MODIFIER           1.5
# 328330  MODIFIER           1.5
# 328331  MODIFIER           1.5
# 328332  MODIFIER           1.5
# 328333  MODIFIER           1.5
#
#        ClinVar              HGVSc HGVSc (Transcript)              HGVSp  \
# 0               ENST00000641515.2           c.243A>G  ENSP00000493376.2
# 1                                               None
# 2               ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 3               ENST00000426406.4           c.389T>G  ENSP00000409316.1
# 4               ENST00000455207.5     n.169+33750T>G
# ...        ...                ...                ...                ...
# 328329                                          None
# 328330                                          None
# 328331                                          None
# 328332                                          None
# 328333                                          None
#
#        HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD    FREQ        PVAL  \
# 0              p.Ser81%3D  0/1  127  138  138  100   38  27.54%  1.8855E-13
# 1                    None  0/1  127  138  138  100   38  27.54%  1.8855E-13
# 2             p.Thr162Ala  1/1  255  114  114    0  114    100%   4.392E-68
# 3             p.Leu130Arg  0/1   56   64   64   47   17  26.56%    2.243E-6
# 4                    None  0/1   56   64   64   47   17  26.56%    2.243E-6
# ...                   ...  ...  ...  ...  ...  ...  ...     ...         ...
# 328329               None  1/1  123   22   22    0   22    100%  4.7526E-13
# 328330               None  1/1  123   22   22    0   22    100%  4.7526E-13
# 328331               None  1/1  123   22   22    0   22    100%  4.7526E-13
# 328332               None  1/1  123   22   22    0   22    100%  4.7526E-13
# 328333               None  1/1  123   22   22    0   22    100%  4.7526E-13
#
#        RDF RDR ADF ADR                              SIFT       PolyPhen  \
# 0       86  14  29   9
# 1       86  14  29   9
# 2        0   0  98  16                   tolerated(0.92)      benign(0)
# 3       33  14  15   2  deleterious low confidence(0.01)  benign(0.336)
# 4       33  14  15   2
# ...     ..  ..  ..  ..                               ...            ...
# 328329   0   0  14   8
# 328330   0   0  14   8
# 328331   0   0  14   8
# 328332   0   0  14   8
# 328333   0   0  14   8
#
#                 BIOTYPE EXON INTRON Protein Position and Amino Acid   Codons  \
# 0        protein coding  3/3                                    S81  tcA/tcG
# 1       TF binding site                                         nan
# 2        protein coding  3/3                                  T162A  Aca/Gca
# 3        protein coding  1/1                                  L130R  cTc/cGc
# 4                lncRNA         1/2                             nan
# ...                 ...  ...    ...                             ...      ...
# 328329           lncRNA                                         nan
# 328330           lncRNA                                         nan
# 328331           lncRNA                                         nan
# 328332           lncRNA                                         nan
# 328333           lncRNA                                         nan
#
#        STRAND                                             PUBMED
# 0           1
# 1
# 2           1
# 3          -1
# 4          -1
# ...       ...                                                ...
# 328329     -1  22271044,29391530,24262073,15896936,32996047,3...
# 328330     -1  22271044,29391530,24262073,15896936,32996047,3...
# 328331     -1  22271044,29391530,24262073,15896936,32996047,3...
# 328332     -1  22271044,29391530,24262073,15896936,32996047,3...
# 328333     -1  22271044,29391530,24262073,15896936,32996047,3...
#
# [328334 rows x 40 columns]

# %%
df_gene = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/cardiac genes.xlsx')
df_gene
# Out:
#    Gene Name
# 0       LDLR
# 1   LDLR-AS1
# 2       NOS3
# 3     PRKAG2
# 4       LRP6
# ..       ...
# 75      TRDN
# 76   LDLRAP1
# 77     PCSK9
# 78      APOB
# 79     STAP1
#
# [80 rows x 1 columns]

# %%
merged_2['Gene_Match'] = 'No'

# Iterate through each gene in df1
for genes in merged_2['Gene Name']:
    if isinstance(genes, str):  # Check if the gene value is a non-null string
        gene_list = genes.split(',')  # Split the genes by comma to create a list
        match = any(gene in df_gene['Gene Name'].values for gene in gene_list)  # Check if any gene in the list exists in df2
        if match:
            merged_2.loc[merged_2['Gene Name'] == genes, 'Gene_Match'] = 'Yes'
            
merged_2
# Out:
#        Gene Name         rsID CHROM       POS REF ALT      Zygosity  \
# 0          OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 1          OR4F5  rs201219564  chr1     69270   A   G  Heterozygous
# 2          OR4F5    rs2691305  chr1     69511   A   G    Homozygous
# 3                           .  chr1    451290   A   C  Heterozygous
# 4                           .  chr1    451290   A   C  Heterozygous
# ...          ...          ...   ...       ...  ..  ..           ...
# 328329    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328330    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328331    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328332    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 328333    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
#
#                                          Consequence Consequence_score  \
# 0                                 synonymous variant              3/10
# 1                          regulatory region variant              2/10
# 2                                   missense variant              7/10
# 3                                   missense variant              7/10
# 4       intron variant,non coding transcript variant              2/10
# ...                                              ...               ...
# 328329                         upstream gene variant              2/10
# 328330                         upstream gene variant              2/10
# 328331                         upstream gene variant              2/10
# 328332                         upstream gene variant              2/10
# 328333                         upstream gene variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT  \
# 0            LOW           2.5
# 1       MODIFIER           1.5
# 2       MODERATE           5.0
# 3       MODERATE           5.0
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...                ...
# 328329  MODIFIER           1.5
# 328330  MODIFIER           1.5
# 328331  MODIFIER           1.5
# 328332  MODIFIER           1.5
# 328333  MODIFIER           1.5
#
#        ClinVar              HGVSc HGVSc (Transcript)              HGVSp  \
# 0               ENST00000641515.2           c.243A>G  ENSP00000493376.2
# 1                                               None
# 2               ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 3               ENST00000426406.4           c.389T>G  ENSP00000409316.1
# 4               ENST00000455207.5     n.169+33750T>G
# ...        ...                ...                ...                ...
# 328329                                          None
# 328330                                          None
# 328331                                          None
# 328332                                          None
# 328333                                          None
#
#        HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD    FREQ        PVAL  \
# 0              p.Ser81%3D  0/1  127  138  138  100   38  27.54%  1.8855E-13
# 1                    None  0/1  127  138  138  100   38  27.54%  1.8855E-13
# 2             p.Thr162Ala  1/1  255  114  114    0  114    100%   4.392E-68
# 3             p.Leu130Arg  0/1   56   64   64   47   17  26.56%    2.243E-6
# 4                    None  0/1   56   64   64   47   17  26.56%    2.243E-6
# ...                   ...  ...  ...  ...  ...  ...  ...     ...         ...
# 328329               None  1/1  123   22   22    0   22    100%  4.7526E-13
# 328330               None  1/1  123   22   22    0   22    100%  4.7526E-13
# 328331               None  1/1  123   22   22    0   22    100%  4.7526E-13
# 328332               None  1/1  123   22   22    0   22    100%  4.7526E-13
# 328333               None  1/1  123   22   22    0   22    100%  4.7526E-13
#
#        RDF RDR ADF ADR                              SIFT       PolyPhen  \
# 0       86  14  29   9
# 1       86  14  29   9
# 2        0   0  98  16                   tolerated(0.92)      benign(0)
# 3       33  14  15   2  deleterious low confidence(0.01)  benign(0.336)
# 4       33  14  15   2
# ...     ..  ..  ..  ..                               ...            ...
# 328329   0   0  14   8
# 328330   0   0  14   8
# 328331   0   0  14   8
# 328332   0   0  14   8
# 328333   0   0  14   8
#
#                 BIOTYPE EXON INTRON Protein Position and Amino Acid   Codons  \
# 0        protein coding  3/3                                    S81  tcA/tcG
# 1       TF binding site                                         nan
# 2        protein coding  3/3                                  T162A  Aca/Gca
# 3        protein coding  1/1                                  L130R  cTc/cGc
# 4                lncRNA         1/2                             nan
# ...                 ...  ...    ...                             ...      ...
# 328329           lncRNA                                         nan
# 328330           lncRNA                                         nan
# 328331           lncRNA                                         nan
# 328332           lncRNA                                         nan
# 328333           lncRNA                                         nan
#
#        STRAND                                             PUBMED Gene_Match
# 0           1                                                            No
# 1                                                                        No
# 2           1                                                            No
# 3          -1                                                            No
# 4          -1                                                            No
# ...       ...                                                ...        ...
# 328329     -1  22271044,29391530,24262073,15896936,32996047,3...         No
# 328330     -1  22271044,29391530,24262073,15896936,32996047,3...         No
# 328331     -1  22271044,29391530,24262073,15896936,32996047,3...         No
# 328332     -1  22271044,29391530,24262073,15896936,32996047,3...         No
# 328333     -1  22271044,29391530,24262073,15896936,32996047,3...         No
#
# [328334 rows x 41 columns]

# %%
merged_2.Gene_Match.value_counts()
# Out:
# No     322967
# Yes      5367
# Name: Gene_Match, dtype: int64

# %%
merged_2 = merged_2[['Gene Name', 'Gene_Match', 'rsID', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
       'Consequence', 'Consequence_score', 'IMPACT', 'IMPACT_score',
       'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc',
       'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP',
       'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT',
       'PolyPhen', 'BIOTYPE', 'EXON', 'INTRON',
       'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED']]
merged_2
# Out:
#        Gene Name Gene_Match         rsID CHROM       POS REF ALT  \
# 0          OR4F5         No  rs201219564  chr1     69270   A   G
# 1          OR4F5         No  rs201219564  chr1     69270   A   G
# 2          OR4F5         No    rs2691305  chr1     69511   A   G
# 3                        No            .  chr1    451290   A   C
# 4                        No            .  chr1    451290   A   C
# ...          ...        ...          ...   ...       ...  ..  ..
# 328329    EIF1AY         No    rs9786153  chrY  20577481   C   T
# 328330    EIF1AY         No    rs9786153  chrY  20577481   C   T
# 328331    EIF1AY         No    rs9786153  chrY  20577481   C   T
# 328332    EIF1AY         No    rs9786153  chrY  20577481   C   T
# 328333    EIF1AY         No    rs9786153  chrY  20577481   C   T
#
#             Zygosity                                   Consequence  \
# 0       Heterozygous                            synonymous variant
# 1       Heterozygous                     regulatory region variant
# 2         Homozygous                              missense variant
# 3       Heterozygous                              missense variant
# 4       Heterozygous  intron variant,non coding transcript variant
# ...              ...                                           ...
# 328329    Homozygous                         upstream gene variant
# 328330    Homozygous                         upstream gene variant
# 328331    Homozygous                         upstream gene variant
# 328332    Homozygous                         upstream gene variant
# 328333    Homozygous                         upstream gene variant
#
#        Consequence_score    IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG  \
# 0                   3/10       LOW           2.5
# 1                   2/10  MODIFIER           1.5
# 2                   7/10  MODERATE           5.0
# 3                   7/10  MODERATE           5.0
# 4                   2/10  MODIFIER           1.5
# ...                  ...       ...           ...           ...      ...
# 328329              2/10  MODIFIER           1.5
# 328330              2/10  MODIFIER           1.5
# 328331              2/10  MODIFIER           1.5
# 328332              2/10  MODIFIER           1.5
# 328333              2/10  MODIFIER           1.5
#
#        ClinVar_CLNREVSTAT ClinVar              HGVSc HGVSc (Transcript)  \
# 0                                  ENST00000641515.2           c.243A>G
# 1                                                                  None
# 2                                  ENST00000641515.2           c.484A>G
# 3                                  ENST00000426406.4           c.389T>G
# 4                                  ENST00000455207.5     n.169+33750T>G
# ...                   ...     ...                ...                ...
# 328329                                                             None
# 328330                                                             None
# 328331                                                             None
# 328332                                                             None
# 328333                                                             None
#
#                     HGVSp HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD  \
# 0       ENSP00000493376.2         p.Ser81%3D  0/1  127  138  138  100   38
# 1                                       None  0/1  127  138  138  100   38
# 2       ENSP00000493376.2        p.Thr162Ala  1/1  255  114  114    0  114
# 3       ENSP00000409316.1        p.Leu130Arg  0/1   56   64   64   47   17
# 4                                       None  0/1   56   64   64   47   17
# ...                   ...                ...  ...  ...  ...  ...  ...  ...
# 328329                                  None  1/1  123   22   22    0   22
# 328330                                  None  1/1  123   22   22    0   22
# 328331                                  None  1/1  123   22   22    0   22
# 328332                                  None  1/1  123   22   22    0   22
# 328333                                  None  1/1  123   22   22    0   22
#
#           FREQ        PVAL RDF RDR ADF ADR                              SIFT  \
# 0       27.54%  1.8855E-13  86  14  29   9
# 1       27.54%  1.8855E-13  86  14  29   9
# 2         100%   4.392E-68   0   0  98  16                   tolerated(0.92)
# 3       26.56%    2.243E-6  33  14  15   2  deleterious low confidence(0.01)
# 4       26.56%    2.243E-6  33  14  15   2
# ...        ...         ...  ..  ..  ..  ..                               ...
# 328329    100%  4.7526E-13   0   0  14   8
# 328330    100%  4.7526E-13   0   0  14   8
# 328331    100%  4.7526E-13   0   0  14   8
# 328332    100%  4.7526E-13   0   0  14   8
# 328333    100%  4.7526E-13   0   0  14   8
#
#              PolyPhen          BIOTYPE EXON INTRON  \
# 0                       protein coding  3/3
# 1                      TF binding site
# 2           benign(0)   protein coding  3/3
# 3       benign(0.336)   protein coding  1/1
# 4                               lncRNA         1/2
# ...               ...              ...  ...    ...
# 328329                          lncRNA
# 328330                          lncRNA
# 328331                          lncRNA
# 328332                          lncRNA
# 328333                          lncRNA
#
#        Protein Position and Amino Acid   Codons STRAND  \
# 0                                  S81  tcA/tcG      1
# 1                                  nan
# 2                                T162A  Aca/Gca      1
# 3                                L130R  cTc/cGc     -1
# 4                                  nan              -1
# ...                                ...      ...    ...
# 328329                             nan              -1
# 328330                             nan              -1
# 328331                             nan              -1
# 328332                             nan              -1
# 328333                             nan              -1
#
#                                                    PUBMED
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 328329  22271044,29391530,24262073,15896936,32996047,3...
# 328330  22271044,29391530,24262073,15896936,32996047,3...
# 328331  22271044,29391530,24262073,15896936,32996047,3...
# 328332  22271044,29391530,24262073,15896936,32996047,3...
# 328333  22271044,29391530,24262073,15896936,32996047,3...
#
# [328334 rows x 41 columns]

# %%
df_3 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Condition_pos/Cardiac_pos.xlsx')
df_3
# Out:
#             POS Literature
# 0     104858586        Yes
# 1     104826974        Yes
# 2     104824472        Yes
# 3     104858554        Yes
# 4     104794495        Yes
# ...         ...        ...
# 1861   31592980        Yes
# 1862   31595223        Yes
# 1863   31593004        Yes
# 1864   31598691        Yes
# 1865   31595256        Yes
#
# [1866 rows x 2 columns]

# %%
merged_3 = pd.merge(merged_2, df_3, on = 'POS', how = 'left', sort=False)
merged_3['Literature'] = merged_3['Literature'].fillna('No')
merged_3
# Out:
#        Gene Name Gene_Match         rsID CHROM       POS REF ALT  \
# 0          OR4F5         No  rs201219564  chr1     69270   A   G
# 1          OR4F5         No  rs201219564  chr1     69270   A   G
# 2          OR4F5         No    rs2691305  chr1     69511   A   G
# 3                        No            .  chr1    451290   A   C
# 4                        No            .  chr1    451290   A   C
# ...          ...        ...          ...   ...       ...  ..  ..
# 328329    EIF1AY         No    rs9786153  chrY  20577481   C   T
# 328330    EIF1AY         No    rs9786153  chrY  20577481   C   T
# 328331    EIF1AY         No    rs9786153  chrY  20577481   C   T
# 328332    EIF1AY         No    rs9786153  chrY  20577481   C   T
# 328333    EIF1AY         No    rs9786153  chrY  20577481   C   T
#
#             Zygosity                                   Consequence  \
# 0       Heterozygous                            synonymous variant
# 1       Heterozygous                     regulatory region variant
# 2         Homozygous                              missense variant
# 3       Heterozygous                              missense variant
# 4       Heterozygous  intron variant,non coding transcript variant
# ...              ...                                           ...
# 328329    Homozygous                         upstream gene variant
# 328330    Homozygous                         upstream gene variant
# 328331    Homozygous                         upstream gene variant
# 328332    Homozygous                         upstream gene variant
# 328333    Homozygous                         upstream gene variant
#
#        Consequence_score    IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG  \
# 0                   3/10       LOW           2.5
# 1                   2/10  MODIFIER           1.5
# 2                   7/10  MODERATE           5.0
# 3                   7/10  MODERATE           5.0
# 4                   2/10  MODIFIER           1.5
# ...                  ...       ...           ...           ...      ...
# 328329              2/10  MODIFIER           1.5
# 328330              2/10  MODIFIER           1.5
# 328331              2/10  MODIFIER           1.5
# 328332              2/10  MODIFIER           1.5
# 328333              2/10  MODIFIER           1.5
#
#        ClinVar_CLNREVSTAT ClinVar              HGVSc HGVSc (Transcript)  \
# 0                                  ENST00000641515.2           c.243A>G
# 1                                                                  None
# 2                                  ENST00000641515.2           c.484A>G
# 3                                  ENST00000426406.4           c.389T>G
# 4                                  ENST00000455207.5     n.169+33750T>G
# ...                   ...     ...                ...                ...
# 328329                                                             None
# 328330                                                             None
# 328331                                                             None
# 328332                                                             None
# 328333                                                             None
#
#                     HGVSp HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD  \
# 0       ENSP00000493376.2         p.Ser81%3D  0/1  127  138  138  100   38
# 1                                       None  0/1  127  138  138  100   38
# 2       ENSP00000493376.2        p.Thr162Ala  1/1  255  114  114    0  114
# 3       ENSP00000409316.1        p.Leu130Arg  0/1   56   64   64   47   17
# 4                                       None  0/1   56   64   64   47   17
# ...                   ...                ...  ...  ...  ...  ...  ...  ...
# 328329                                  None  1/1  123   22   22    0   22
# 328330                                  None  1/1  123   22   22    0   22
# 328331                                  None  1/1  123   22   22    0   22
# 328332                                  None  1/1  123   22   22    0   22
# 328333                                  None  1/1  123   22   22    0   22
#
#           FREQ        PVAL RDF RDR ADF ADR                              SIFT  \
# 0       27.54%  1.8855E-13  86  14  29   9
# 1       27.54%  1.8855E-13  86  14  29   9
# 2         100%   4.392E-68   0   0  98  16                   tolerated(0.92)
# 3       26.56%    2.243E-6  33  14  15   2  deleterious low confidence(0.01)
# 4       26.56%    2.243E-6  33  14  15   2
# ...        ...         ...  ..  ..  ..  ..                               ...
# 328329    100%  4.7526E-13   0   0  14   8
# 328330    100%  4.7526E-13   0   0  14   8
# 328331    100%  4.7526E-13   0   0  14   8
# 328332    100%  4.7526E-13   0   0  14   8
# 328333    100%  4.7526E-13   0   0  14   8
#
#              PolyPhen          BIOTYPE EXON INTRON  \
# 0                       protein coding  3/3
# 1                      TF binding site
# 2           benign(0)   protein coding  3/3
# 3       benign(0.336)   protein coding  1/1
# 4                               lncRNA         1/2
# ...               ...              ...  ...    ...
# 328329                          lncRNA
# 328330                          lncRNA
# 328331                          lncRNA
# 328332                          lncRNA
# 328333                          lncRNA
#
#        Protein Position and Amino Acid   Codons STRAND  \
# 0                                  S81  tcA/tcG      1
# 1                                  nan
# 2                                T162A  Aca/Gca      1
# 3                                L130R  cTc/cGc     -1
# 4                                  nan              -1
# ...                                ...      ...    ...
# 328329                             nan              -1
# 328330                             nan              -1
# 328331                             nan              -1
# 328332                             nan              -1
# 328333                             nan              -1
#
#                                                    PUBMED Literature
# 0                                                                 No
# 1                                                                 No
# 2                                                                 No
# 3                                                                 No
# 4                                                                 No
# ...                                                   ...        ...
# 328329  22271044,29391530,24262073,15896936,32996047,3...         No
# 328330  22271044,29391530,24262073,15896936,32996047,3...         No
# 328331  22271044,29391530,24262073,15896936,32996047,3...         No
# 328332  22271044,29391530,24262073,15896936,32996047,3...         No
# 328333  22271044,29391530,24262073,15896936,32996047,3...         No
#
# [328334 rows x 42 columns]

# %%
merged_3.Literature.value_counts()
# Out:
# No     328255
# Yes        79
# Name: Literature, dtype: int64

# %%
merged_3[merged_3['Literature'] == 'Yes']
# Out:
#        Gene Name Gene_Match       rsID CHROM        POS REF ALT      Zygosity  \
# 15189      CASQ2        Yes  rs7521023  chr1  115700759   G   A  Heterozygous
# 15190      CASQ2        Yes  rs7521023  chr1  115700759   G   A  Heterozygous
# 15191      CASQ2        Yes  rs7521023  chr1  115700759   G   A  Heterozygous
# 23277      TNNT2        Yes  rs3730238  chr1  201361301   T   C  Heterozygous
# 23278      TNNT2        Yes  rs3730238  chr1  201361301   T   C  Heterozygous
# ...          ...        ...        ...   ...        ...  ..  ..           ...
# 297400     KCNH2        Yes  rs1805123  chr7  150948446   T   G    Homozygous
# 297401     KCNH2        Yes  rs1805123  chr7  150948446   T   G    Homozygous
# 297402     KCNH2        Yes  rs1805123  chr7  150948446   T   G    Homozygous
# 297403     KCNH2        Yes  rs1805123  chr7  150948446   T   G    Homozygous
# 297404     KCNH2        Yes  rs1805123  chr7  150948446   T   G    Homozygous
#
#                                               Consequence Consequence_score  \
# 15189                                 3 prime UTR variant              3/10
# 15190                             downstream gene variant              2/10
# 15191                             downstream gene variant              2/10
# 23277                                    missense variant              7/10
# 23278                                    missense variant              7/10
# ...                                                   ...               ...
# 297400                            downstream gene variant              2/10
# 297401                            downstream gene variant              2/10
# 297402                            downstream gene variant              2/10
# 297403                            downstream gene variant              2/10
# 297404  splice region variant,non coding transcript ex...              4/10
#
#           IMPACT  IMPACT_score  \
# 15189   MODIFIER           1.5
# 15190   MODIFIER           1.5
# 15191   MODIFIER           1.5
# 23277   MODERATE           5.0
# 23278   MODERATE           5.0
# ...          ...           ...
# 297400  MODIFIER           1.5
# 297401  MODIFIER           1.5
# 297402  MODIFIER           1.5
# 297403  MODIFIER           1.5
# 297404       LOW           2.5
#
#                                             ClinVar_CLNDN  \
# 15189   Caudal regression sequence,Catecholaminergic p...
# 15190   Caudal regression sequence,Catecholaminergic p...
# 15191   Caudal regression sequence,Catecholaminergic p...
# 23277   Dilated Cardiomyopathy, Dominant,Cardiovascula...
# 23278   Dilated Cardiomyopathy, Dominant,Cardiovascula...
# ...                                                   ...
# 297400  Cardiac arrhythmia,Cardiovascular phenotype,At...
# 297401  Cardiac arrhythmia,Cardiovascular phenotype,At...
# 297402  Cardiac arrhythmia,Cardiovascular phenotype,At...
# 297403  Cardiac arrhythmia,Cardiovascular phenotype,At...
# 297404  Cardiac arrhythmia,Cardiovascular phenotype,At...
#
#                     CLIN_SIG  \
# 15189   benign,likely benign
# 15190   benign,likely benign
# 15191   benign,likely benign
# 23277   benign,likely benign
# 23278   benign,likely benign
# ...                      ...
# 297400                benign
# 297401                benign
# 297402                benign
# 297403                benign
# 297404                benign
#
#                                        ClinVar_CLNREVSTAT ClinVar  \
# 15189                 criteria provided, single submitter  292122
# 15190                 criteria provided, single submitter  292122
# 15191                 criteria provided, single submitter  292122
# 23277   criteria provided, multiple submitters, no con...   43669
# 23278   criteria provided, multiple submitters, no con...   43669
# ...                                                   ...     ...
# 297400  criteria provided, multiple submitters, no con...   67427
# 297401  criteria provided, multiple submitters, no con...   67427
# 297402  criteria provided, multiple submitters, no con...   67427
# 297403  criteria provided, multiple submitters, no con...   67427
# 297404  criteria provided, multiple submitters, no con...   67427
#
#                      HGVSc HGVSc (Transcript)              HGVSp  \
# 15189    ENST00000261448.6          c.*482C>T
# 15190                                    None
# 15191                                    None
# 23277   ENST00000236918.11           c.788A>G  ENSP00000236918.8
# 23278    ENST00000360372.8           c.659A>G  ENSP00000353535.5
# ...                    ...                ...                ...
# 297400                                   None
# 297401                                   None
# 297402                                   None
# 297403                                   None
# 297404   ENST00000684241.1          n.3523A>C
#
#        HGVSp (Transcript)   GT  GQ SDP  DP  RD  AD    FREQ        PVAL RDF  \
# 15189                None  0/1  52  26  26  12  14  53.85%   5.4595E-6  10
# 15190                None  0/1  52  26  26  12  14  53.85%   5.4595E-6  10
# 15191                None  0/1  52  26  26  12  14  53.85%   5.4595E-6  10
# 23277         p.Lys263Arg  0/1  68  32  32  14  18  56.25%   1.3089E-7  14
# 23278         p.Lys220Arg  0/1  68  32  32  14  18  56.25%   1.3089E-7  14
# ...                   ...  ...  ..  ..  ..  ..  ..     ...         ...  ..
# 297400               None  1/1  93  18  18   0  17  94.44%  4.2852E-10   0
# 297401               None  1/1  93  18  18   0  17  94.44%  4.2852E-10   0
# 297402               None  1/1  93  18  18   0  17  94.44%  4.2852E-10   0
# 297403               None  1/1  93  18  18   0  17  94.44%  4.2852E-10   0
# 297404               None  1/1  93  18  18   0  17  94.44%  4.2852E-10   0
#
#        RDR ADF ADR                              SIFT       PolyPhen  \
# 15189    2  11   3
# 15190    2  11   3
# 15191    2  11   3
# 23277    0  12   6  deleterious low confidence(0.04)  benign(0.007)
# 23278    0  12   6                 deleterious(0.02)  benign(0.388)
# ...     ..  ..  ..                               ...            ...
# 297400   0  12   5
# 297401   0  12   5
# 297402   0  12   5
# 297403   0  12   5
# 297404   0  12   5
#
#                 BIOTYPE   EXON INTRON Protein Position and Amino Acid  \
# 15189    protein coding  11/11                                    nan
# 15190    protein coding                                           nan
# 15191    protein coding                                           nan
# 23277    protein coding  14/16                                  K263R
# 23278    protein coding  12/14                                  K220R
# ...                 ...    ...    ...                             ...
# 297400  retained intron                                           nan
# 297401  retained intron                                           nan
# 297402  retained intron                                           nan
# 297403  retained intron                                           nan
# 297404  retained intron   9/13                                    nan
#
#          Codons STRAND                                             PUBMED  \
# 15189               -1                27899944,24444446,31053292,32765588
# 15190                1                27899944,24444446,31053292,32765588
# 15191                1                27899944,24444446,31053292,32765588
# 23277   aAg/aGg     -1  25741868,24033266,18414213,23861362,15542288,2...
# 23278   aAg/aGg     -1  25741868,24033266,18414213,23861362,15542288,2...
# ...         ...    ...                                                ...
# 297400              -1  25741868,21056700,24033266,20850564,23820649,2...
# 297401              -1  25741868,21056700,24033266,20850564,23820649,2...
# 297402              -1  25741868,21056700,24033266,20850564,23820649,2...
# 297403              -1  25741868,21056700,24033266,20850564,23820649,2...
# 297404              -1  25741868,21056700,24033266,20850564,23820649,2...
#
#        Literature
# 15189         Yes
# 15190         Yes
# 15191         Yes
# 23277         Yes
# 23278         Yes
# ...           ...
# 297400        Yes
# 297401        Yes
# 297402        Yes
# 297403        Yes
# 297404        Yes
#
# [79 rows x 42 columns]

# %%
merged_3 = merged_3[['Gene Name', 'Gene_Match', 'rsID', 'CHROM', 'POS', 'Literature', 'REF', 'ALT', 'Zygosity',
       'Consequence','Consequence_score', 'IMPACT', 'IMPACT_score', 'ClinVar_CLNDN', 'CLIN_SIG',
       'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc', 'HGVSc (Transcript)', 'HGVSp',
       'HGVSp (Transcript)', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ',
       'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT', 'PolyPhen', 'BIOTYPE',
       'EXON', 'INTRON', 'Protein Position and Amino Acid', 'Codons', 'STRAND',
       'PUBMED']]
merged_3
# Out:
#        Gene Name Gene_Match         rsID CHROM       POS Literature REF ALT  \
# 0          OR4F5         No  rs201219564  chr1     69270         No   A   G
# 1          OR4F5         No  rs201219564  chr1     69270         No   A   G
# 2          OR4F5         No    rs2691305  chr1     69511         No   A   G
# 3                        No            .  chr1    451290         No   A   C
# 4                        No            .  chr1    451290         No   A   C
# ...          ...        ...          ...   ...       ...        ...  ..  ..
# 328329    EIF1AY         No    rs9786153  chrY  20577481         No   C   T
# 328330    EIF1AY         No    rs9786153  chrY  20577481         No   C   T
# 328331    EIF1AY         No    rs9786153  chrY  20577481         No   C   T
# 328332    EIF1AY         No    rs9786153  chrY  20577481         No   C   T
# 328333    EIF1AY         No    rs9786153  chrY  20577481         No   C   T
#
#             Zygosity                                   Consequence  \
# 0       Heterozygous                            synonymous variant
# 1       Heterozygous                     regulatory region variant
# 2         Homozygous                              missense variant
# 3       Heterozygous                              missense variant
# 4       Heterozygous  intron variant,non coding transcript variant
# ...              ...                                           ...
# 328329    Homozygous                         upstream gene variant
# 328330    Homozygous                         upstream gene variant
# 328331    Homozygous                         upstream gene variant
# 328332    Homozygous                         upstream gene variant
# 328333    Homozygous                         upstream gene variant
#
#        Consequence_score    IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG  \
# 0                   3/10       LOW           2.5
# 1                   2/10  MODIFIER           1.5
# 2                   7/10  MODERATE           5.0
# 3                   7/10  MODERATE           5.0
# 4                   2/10  MODIFIER           1.5
# ...                  ...       ...           ...           ...      ...
# 328329              2/10  MODIFIER           1.5
# 328330              2/10  MODIFIER           1.5
# 328331              2/10  MODIFIER           1.5
# 328332              2/10  MODIFIER           1.5
# 328333              2/10  MODIFIER           1.5
#
#        ClinVar_CLNREVSTAT ClinVar              HGVSc HGVSc (Transcript)  \
# 0                                  ENST00000641515.2           c.243A>G
# 1                                                                  None
# 2                                  ENST00000641515.2           c.484A>G
# 3                                  ENST00000426406.4           c.389T>G
# 4                                  ENST00000455207.5     n.169+33750T>G
# ...                   ...     ...                ...                ...
# 328329                                                             None
# 328330                                                             None
# 328331                                                             None
# 328332                                                             None
# 328333                                                             None
#
#                     HGVSp HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD  \
# 0       ENSP00000493376.2         p.Ser81%3D  0/1  127  138  138  100   38
# 1                                       None  0/1  127  138  138  100   38
# 2       ENSP00000493376.2        p.Thr162Ala  1/1  255  114  114    0  114
# 3       ENSP00000409316.1        p.Leu130Arg  0/1   56   64   64   47   17
# 4                                       None  0/1   56   64   64   47   17
# ...                   ...                ...  ...  ...  ...  ...  ...  ...
# 328329                                  None  1/1  123   22   22    0   22
# 328330                                  None  1/1  123   22   22    0   22
# 328331                                  None  1/1  123   22   22    0   22
# 328332                                  None  1/1  123   22   22    0   22
# 328333                                  None  1/1  123   22   22    0   22
#
#           FREQ        PVAL RDF RDR ADF ADR                              SIFT  \
# 0       27.54%  1.8855E-13  86  14  29   9
# 1       27.54%  1.8855E-13  86  14  29   9
# 2         100%   4.392E-68   0   0  98  16                   tolerated(0.92)
# 3       26.56%    2.243E-6  33  14  15   2  deleterious low confidence(0.01)
# 4       26.56%    2.243E-6  33  14  15   2
# ...        ...         ...  ..  ..  ..  ..                               ...
# 328329    100%  4.7526E-13   0   0  14   8
# 328330    100%  4.7526E-13   0   0  14   8
# 328331    100%  4.7526E-13   0   0  14   8
# 328332    100%  4.7526E-13   0   0  14   8
# 328333    100%  4.7526E-13   0   0  14   8
#
#              PolyPhen          BIOTYPE EXON INTRON  \
# 0                       protein coding  3/3
# 1                      TF binding site
# 2           benign(0)   protein coding  3/3
# 3       benign(0.336)   protein coding  1/1
# 4                               lncRNA         1/2
# ...               ...              ...  ...    ...
# 328329                          lncRNA
# 328330                          lncRNA
# 328331                          lncRNA
# 328332                          lncRNA
# 328333                          lncRNA
#
#        Protein Position and Amino Acid   Codons STRAND  \
# 0                                  S81  tcA/tcG      1
# 1                                  nan
# 2                                T162A  Aca/Gca      1
# 3                                L130R  cTc/cGc     -1
# 4                                  nan              -1
# ...                                ...      ...    ...
# 328329                             nan              -1
# 328330                             nan              -1
# 328331                             nan              -1
# 328332                             nan              -1
# 328333                             nan              -1
#
#                                                    PUBMED
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 328329  22271044,29391530,24262073,15896936,32996047,3...
# 328330  22271044,29391530,24262073,15896936,32996047,3...
# 328331  22271044,29391530,24262073,15896936,32996047,3...
# 328332  22271044,29391530,24262073,15896936,32996047,3...
# 328333  22271044,29391530,24262073,15896936,32996047,3...
#
# [328334 rows x 42 columns]

# %%
merged_3.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Processed_vcf_files/KHCDPRGPTTL6_depth_vcf_processed.xlsx', index=False)
