# %%
import numpy as np
import pandas as pd
import polars as pl
import sys
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px


pd.set_option('display.max_columns',None)
import psycopg2


#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Algorithms to use
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

#Metrics to evaluate the model
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve

import warnings
warnings.filterwarnings("ignore")

#importing PCA and TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
father = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Desktop/Trio_analysis/new_trio_files/Covered_father_new.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
father.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
father['DP_father'] = father['SAMPLE'].str.split(':').str[3].fillna('0').replace('', 0).astype(int)
father['RD_father'] = father['SAMPLE'].str.split(':').str[4].fillna('0').replace('', 0).astype(int)
father['AD_father'] = father['SAMPLE'].str.split(':').str[5].fillna('0').replace('', 0).astype(int)
father['VAF_father'] = father['AD_father'] / (father['RD_father'] + father['AD_father']).replace('', 0).astype('float')
father['CSQ'] = father['INFO'].str.extract(r'CSQ=(.*)')
father['gnomADe_AF'] = father['CSQ'].str.split('|').str[48].replace('', 0).astype('float')
father['gnomADe_SAS_AF'] = father['CSQ'].str.split('|').str[56].replace('', 0).astype('float')
father["Gene_Name"] = father["INFO"].str.extract('GENEINFO=(?P<GENEINFO>.+?);')

father['HET'] = father['INFO'].str.extract(r'HET=(\d)')
father['HOM'] = father['INFO'].str.extract(r'HOM=(\d)')
# Create a new column 'Zygosity' based on conditions
father['Zygosity_father'] = ''
father.loc[father['HOM'] == '1', 'Zygosity_father'] = 'Homozygous'
father.loc[father['HET'] == '1', 'Zygosity_father'] = 'Heterozygous'

father['Gene_Name'] = father['Gene_Name'].apply(lambda x: ','.join(set([segment.split(':')[0] for segment in x.split('|')])) if pd.notnull(x) else '')
father = father[['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'Gene_Name', 'Zygosity_father', 'DP_father', 'RD_father', 'AD_father', 'VAF_father', 'gnomADe_AF', 'gnomADe_SAS_AF']]
father
# Out:
#       CHROM        POS         rsID REF ALT            Gene_Name  \
# 0      chr1      69270  rs201219564   A   G                OR4F5
# 1      chr1      69511    rs2691305   A   G                OR4F5
# 2      chr1      69897  rs200676709   T   C                OR4F5
# 3      chr1     924533  rs112703963   A   G  SAMD11,LOC107985728
# 4      chr1     942451    rs6672356   T   C               SAMD11
# ...     ...        ...          ...  ..  ..                  ...
# 31681  chrX  155383098            .   T   C
# 31682  chrX  156010159  rs200413398   A   G                 IL9R
# 31683  chrX  156010162  rs150178903   A   G                 IL9R
# 31684  chrY    3019783    rs9786184   A   C            LINC00278
# 31685  chrY   21904151     rs162865   G   A               RBMY1E
#
#       Zygosity_father  DP_father  RD_father  AD_father  VAF_father  \
# 0        Heterozygous        140         88         52    0.371429
# 1          Homozygous        147          1        146    0.993197
# 2        Heterozygous        137         99         38    0.277372
# 3          Homozygous         93          0         93    1.000000
# 4          Homozygous         80          0         80    1.000000
# ...               ...        ...        ...        ...         ...
# 31681    Heterozygous         87         59         28    0.321839
# 31682    Heterozygous         32         11         21    0.656250
# 31683    Heterozygous         33         13         20    0.606061
# 31684      Homozygous         39          0         39    1.000000
# 31685    Heterozygous         78         58         20    0.256410
#
#        gnomADe_AF  gnomADe_SAS_AF
# 0          0.8380          0.9005
# 1          0.9497          0.9854
# 2          0.7209          0.8049
# 3          0.0000          0.0000
# 4          0.9999          0.9997
# ...           ...             ...
# 31681      0.0000          0.0000
# 31682      0.1634          0.2709
# 31683      0.1568          0.2628
# 31684      0.0000          0.0000
# 31685      0.0000          0.0000
#
# [31686 rows x 13 columns]

# %%
mother = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Desktop/Trio_analysis/new_trio_files/Covered_mother_new.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
mother.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
mother['DP_mother'] = mother['SAMPLE'].str.split(':').str[3].fillna('0').replace('', 0).astype(int)
mother['RD_mother'] = mother['SAMPLE'].str.split(':').str[4].fillna('0').replace('', 0).astype(int)
mother['AD_mother'] = mother['SAMPLE'].str.split(':').str[5].fillna('0').replace('', 0).astype(int)
mother['VAF_mother'] = mother['AD_mother'] / (mother['RD_mother'] + mother['AD_mother']).replace('', 0).astype('float')

mother['HET'] = mother['INFO'].str.extract(r'HET=(\d)')
mother['HOM'] = mother['INFO'].str.extract(r'HOM=(\d)')
# Create a new column 'Zygosity' based on conditions
mother['Zygosity_mother'] = ''
mother.loc[mother['HOM'] == '1', 'Zygosity_mother'] = 'Homozygous'
mother.loc[mother['HET'] == '1', 'Zygosity_mother'] = 'Heterozygous'

mother['CSQ'] = mother['INFO'].str.extract(r'CSQ=(.*)')
mother['gnomADe_AF'] = mother['CSQ'].str.split('|').str[48].replace('', 0).astype('float')
mother['gnomADe_SAS_AF'] = mother['CSQ'].str.split('|').str[56].replace('', 0).astype('float')
mother = mother[['CHROM', 'POS', 'REF', 'ALT', 'Zygosity_mother', 'DP_mother', 'RD_mother', 'AD_mother', 'VAF_mother']]
mother
# Out:
#       CHROM        POS REF ALT Zygosity_mother  DP_mother  RD_mother  \
# 0      chr1      69270   A   G    Heterozygous         44         16
# 1      chr1      69511   A   G      Homozygous        133          0
# 2      chr1      69761   A   T    Heterozygous         66         48
# 3      chr1      69897   T   C    Heterozygous         46         29
# 4      chr1     924533   A   G      Homozygous         40          1
# ...     ...        ...  ..  ..             ...        ...        ...
# 29803  chrX  154653251   C   G    Heterozygous         41         26
# 29804  chrX  154653499   C   T    Heterozygous         72         49
# 29805  chrX  154766321   G   T      Homozygous         44          0
# 29806  chrX  154792236   C   T    Heterozygous         47         17
# 29807  chrX  155997799   C   T    Heterozygous         18          7
#
#        AD_mother  VAF_mother
# 0             28    0.636364
# 1            133    1.000000
# 2             18    0.272727
# 3             17    0.369565
# 4             39    0.975000
# ...          ...         ...
# 29803         15    0.365854
# 29804         23    0.319444
# 29805         43    1.000000
# 29806         30    0.638298
# 29807         11    0.611111
#
# [29808 rows x 9 columns]

# %%
son = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Desktop/Trio_analysis/new_trio_files/Covered_son_new.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
son.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
son['DP_son'] = son['SAMPLE'].str.split(':').str[3].fillna('0').replace('', 0).astype(int)
son['RD_son'] = son['SAMPLE'].str.split(':').str[4].fillna('0').replace('', 0).astype(int)
son['AD_son'] = son['SAMPLE'].str.split(':').str[5].fillna('0').replace('', 0).astype(int)
son['VAF_son'] = son['AD_son'] / (son['RD_son'] + son['AD_son']).replace('', 0).astype('float')

son['HET'] = son['INFO'].str.extract(r'HET=(\d)')
son['HOM'] = son['INFO'].str.extract(r'HOM=(\d)')
# Create a new column 'Zygosity' based on conditions
son['Zygosity_son'] = ''
son.loc[son['HOM'] == '1', 'Zygosity_son'] = 'Homozygous'
son.loc[son['HET'] == '1', 'Zygosity_son'] = 'Heterozygous'

son['CSQ'] = son['INFO'].str.extract(r'CSQ=(.*)')
son['gnomADe_AF'] = son['CSQ'].str.split('|').str[48].replace('', 0).astype('float')
son['gnomADe_SAS_AF'] = son['CSQ'].str.split('|').str[56].replace('', 0).astype('float')
son = son[['CHROM', 'POS', 'REF', 'ALT', 'Zygosity_son', 'DP_son', 'RD_son', 'AD_son', 'VAF_son']]
son
# Out:
#       CHROM        POS REF ALT  Zygosity_son  DP_son  RD_son  AD_son   VAF_son
# 0      chr1      69270   A   G  Heterozygous     104      30      74  0.711538
# 1      chr1      69511   A   G    Homozygous     205       0     205  1.000000
# 2      chr1      69897   T   C  Heterozygous      93      28      65  0.698925
# 3      chr1     924533   A   G    Homozygous      81       0      80  1.000000
# 4      chr1     942451   T   C    Homozygous      98       0      98  1.000000
# ...     ...        ...  ..  ..           ...     ...     ...     ...       ...
# 32709  chrX  155277884   G   T    Homozygous      28       0      28  1.000000
# 32710  chrX  156003433   T   C  Heterozygous       9       3       6  0.666667
# 32711  chrY    3019783   A   C    Homozygous      42       0      42  1.000000
# 32712  chrY   12914512   C   A    Homozygous      18       0      18  1.000000
# 32713  chrY   21904151   G   A  Heterozygous      52      41      11  0.211538
#
# [32714 rows x 9 columns]

# %%
intersection = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/latest_trio/intersected_variants.xlsx')
intersection = intersection[['CHROM', 'POS', 'REF', 'ALT']]
intersection
# Out:
#       CHROM        POS REF ALT
# 0      chr1      69270   A   G
# 1      chr1      69511   A   G
# 2      chr1      69897   T   C
# 3      chr1     924533   A   G
# 4      chr1     942451   T   C
# ...     ...        ...  ..  ..
# 15198  chrX  154485448   T   C
# 15199  chrX  154563953   C   T
# 15200  chrX  154652556   C   A
# 15201  chrX  154653499   C   T
# 15202  chrX  154766321   G   T
#
# [15203 rows x 4 columns]

# %%
intersection_father = pd.merge(intersection, father, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'left', sort = False)
intersection_father
# Out:
#       CHROM        POS REF ALT                   rsID            Gene_Name  \
# 0      chr1      69270   A   G            rs201219564                OR4F5
# 1      chr1      69511   A   G              rs2691305                OR4F5
# 2      chr1      69897   T   C            rs200676709                OR4F5
# 3      chr1     924533   A   G            rs112703963  SAMD11,LOC107985728
# 4      chr1     942451   T   C              rs6672356               SAMD11
# ...     ...        ...  ..  ..                    ...                  ...
# 15198  chrX  154485448   T   C              rs7057286                UBL4A
# 15199  chrX  154563953   C   T  rs201709278;rs5945206                IKBKG
# 15200  chrX  154652556   C   A              rs4326559   CTAG2,LOC105373387
# 15201  chrX  154653499   C   T             rs17855367   CTAG2,LOC105373387
# 15202  chrX  154766321   G   T              rs2728532                 DKC1
#
#       Zygosity_father  DP_father  RD_father  AD_father  VAF_father  \
# 0        Heterozygous        140         88         52    0.371429
# 1          Homozygous        147          1        146    0.993197
# 2        Heterozygous        137         99         38    0.277372
# 3          Homozygous         93          0         93    1.000000
# 4          Homozygous         80          0         80    1.000000
# ...               ...        ...        ...        ...         ...
# 15198      Homozygous         49          0         49    1.000000
# 15199    Heterozygous         59         15         44    0.745763
# 15200      Homozygous         40          1         39    0.975000
# 15201    Heterozygous         59         28         31    0.525424
# 15202      Homozygous         36          0         36    1.000000
#
#        gnomADe_AF  gnomADe_SAS_AF
# 0          0.8380          0.9005
# 1          0.9497          0.9854
# 2          0.7209          0.8049
# 3          0.0000          0.0000
# 4          0.9999          0.9997
# ...           ...             ...
# 15198      0.0000          0.0000
# 15199      0.0000          0.0000
# 15200      0.0000          0.0000
# 15201      0.0000          0.0000
# 15202      0.9979          1.0000
#
# [15203 rows x 13 columns]

# %%
intersection_mother = pd.merge(intersection_father, mother, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'left', sort = False)
intersection_mother
# Out:
#       CHROM        POS REF ALT                   rsID            Gene_Name  \
# 0      chr1      69270   A   G            rs201219564                OR4F5
# 1      chr1      69511   A   G              rs2691305                OR4F5
# 2      chr1      69897   T   C            rs200676709                OR4F5
# 3      chr1     924533   A   G            rs112703963  SAMD11,LOC107985728
# 4      chr1     942451   T   C              rs6672356               SAMD11
# ...     ...        ...  ..  ..                    ...                  ...
# 15198  chrX  154485448   T   C              rs7057286                UBL4A
# 15199  chrX  154563953   C   T  rs201709278;rs5945206                IKBKG
# 15200  chrX  154652556   C   A              rs4326559   CTAG2,LOC105373387
# 15201  chrX  154653499   C   T             rs17855367   CTAG2,LOC105373387
# 15202  chrX  154766321   G   T              rs2728532                 DKC1
#
#       Zygosity_father  DP_father  RD_father  AD_father  VAF_father  \
# 0        Heterozygous        140         88         52    0.371429
# 1          Homozygous        147          1        146    0.993197
# 2        Heterozygous        137         99         38    0.277372
# 3          Homozygous         93          0         93    1.000000
# 4          Homozygous         80          0         80    1.000000
# ...               ...        ...        ...        ...         ...
# 15198      Homozygous         49          0         49    1.000000
# 15199    Heterozygous         59         15         44    0.745763
# 15200      Homozygous         40          1         39    0.975000
# 15201    Heterozygous         59         28         31    0.525424
# 15202      Homozygous         36          0         36    1.000000
#
#        gnomADe_AF  gnomADe_SAS_AF Zygosity_mother  DP_mother  RD_mother  \
# 0          0.8380          0.9005    Heterozygous         44         16
# 1          0.9497          0.9854      Homozygous        133          0
# 2          0.7209          0.8049    Heterozygous         46         29
# 3          0.0000          0.0000      Homozygous         40          1
# 4          0.9999          0.9997      Homozygous         38          0
# ...           ...             ...             ...        ...        ...
# 15198      0.0000          0.0000      Homozygous         75          0
# 15199      0.0000          0.0000      Homozygous         35          0
# 15200      0.0000          0.0000    Heterozygous         39         23
# 15201      0.0000          0.0000    Heterozygous         72         49
# 15202      0.9979          1.0000      Homozygous         44          0
#
#        AD_mother  VAF_mother
# 0             28    0.636364
# 1            133    1.000000
# 2             17    0.369565
# 3             39    0.975000
# 4             38    1.000000
# ...          ...         ...
# 15198         75    1.000000
# 15199         35    1.000000
# 15200         16    0.410256
# 15201         23    0.319444
# 15202         43    1.000000
#
# [15203 rows x 18 columns]

# %%
intersection_all = pd.merge(intersection_mother, son, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'left', sort = False)
intersection_all
# Out:
#       CHROM        POS REF ALT                   rsID            Gene_Name  \
# 0      chr1      69270   A   G            rs201219564                OR4F5
# 1      chr1      69511   A   G              rs2691305                OR4F5
# 2      chr1      69897   T   C            rs200676709                OR4F5
# 3      chr1     924533   A   G            rs112703963  SAMD11,LOC107985728
# 4      chr1     942451   T   C              rs6672356               SAMD11
# ...     ...        ...  ..  ..                    ...                  ...
# 15198  chrX  154485448   T   C              rs7057286                UBL4A
# 15199  chrX  154563953   C   T  rs201709278;rs5945206                IKBKG
# 15200  chrX  154652556   C   A              rs4326559   CTAG2,LOC105373387
# 15201  chrX  154653499   C   T             rs17855367   CTAG2,LOC105373387
# 15202  chrX  154766321   G   T              rs2728532                 DKC1
#
#       Zygosity_father  DP_father  RD_father  AD_father  VAF_father  \
# 0        Heterozygous        140         88         52    0.371429
# 1          Homozygous        147          1        146    0.993197
# 2        Heterozygous        137         99         38    0.277372
# 3          Homozygous         93          0         93    1.000000
# 4          Homozygous         80          0         80    1.000000
# ...               ...        ...        ...        ...         ...
# 15198      Homozygous         49          0         49    1.000000
# 15199    Heterozygous         59         15         44    0.745763
# 15200      Homozygous         40          1         39    0.975000
# 15201    Heterozygous         59         28         31    0.525424
# 15202      Homozygous         36          0         36    1.000000
#
#        gnomADe_AF  gnomADe_SAS_AF Zygosity_mother  DP_mother  RD_mother  \
# 0          0.8380          0.9005    Heterozygous         44         16
# 1          0.9497          0.9854      Homozygous        133          0
# 2          0.7209          0.8049    Heterozygous         46         29
# 3          0.0000          0.0000      Homozygous         40          1
# 4          0.9999          0.9997      Homozygous         38          0
# ...           ...             ...             ...        ...        ...
# 15198      0.0000          0.0000      Homozygous         75          0
# 15199      0.0000          0.0000      Homozygous         35          0
# 15200      0.0000          0.0000    Heterozygous         39         23
# 15201      0.0000          0.0000    Heterozygous         72         49
# 15202      0.9979          1.0000      Homozygous         44          0
#
#        AD_mother  VAF_mother  Zygosity_son  DP_son  RD_son  AD_son   VAF_son
# 0             28    0.636364  Heterozygous     104      30      74  0.711538
# 1            133    1.000000    Homozygous     205       0     205  1.000000
# 2             17    0.369565  Heterozygous      93      28      65  0.698925
# 3             39    0.975000    Homozygous      81       0      80  1.000000
# 4             38    1.000000    Homozygous      98       0      98  1.000000
# ...          ...         ...           ...     ...     ...     ...       ...
# 15198         75    1.000000    Homozygous      67       0      67  1.000000
# 15199         35    1.000000    Homozygous      33       0      33  1.000000
# 15200         16    0.410256    Homozygous      43       0      43  1.000000
# 15201         23    0.319444  Heterozygous      86      41      45  0.523256
# 15202         43    1.000000    Homozygous      57       0      57  1.000000
#
# [15203 rows x 23 columns]

# %%
intersection_all.to_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Trio_analysis/new_trio_files/Intersection_FMS_DP_VAF_Zygosity.xlsx', index=False)

# %%
father = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/latest_trio/Father_data_columns.xlsx')
father['CSQ'] = father['INFO'].str.extract(r'CSQ=(.*)')
father['gnomADe_AF'] = father['CSQ'].str.split('|').str[48].replace('', 0).astype('float')
father['gnomADe_SAS_AF'] = father['CSQ'].str.split('|').str[56].replace('', 0).astype('float')
father.head()
# Out:
#   CHROM     POS         rsID REF ALT QUAL FILTER  \
# 0  chr1   69270  rs201219564   A   G    .   PASS
# 1  chr1   69511    rs2691305   A   G    .   PASS
# 2  chr1   69897  rs200676709   T   C    .   PASS
# 3  chr1  924533  rs112703963   A   G    .   PASS
# 4  chr1  942451    rs6672356   T   C    .   PASS
#
#                                                 INFO   GT   GQ  SDP  RD   AD  \
# 0  ADP=140;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  181  140  88   52
# 1  ADP=147;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  147   1  146
# 2  ADP=137;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0...  0/1  127  137  99   38
# 3  ADP=93;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....  1/1  255   93   0   93
# 4  ADP=80;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,1;COMMO...  1/1  255   80   0   80
#
#      FREQ          PVAL  RBQ  ABQ  RDF  RDR  ADF  ADR   DP  gnomADg_AF  \
# 0  37.14%  6.374300e-19   59   49   77   11   43    9  140      0.6291
# 1  99.32%  1.000100e-85   37   55    1    0  115   31  147      0.8460
# 2  27.74%  1.838500e-13   56   50   63   36   27   11  137      0.4864
# 3    100%  1.745100e-55    0   54    0    0   70   23   93      0.8215
# 4    100%  1.086400e-47    0   51    0    0   54   26   80      0.9998
#
#    gnomADg_SAS_AF                                                CSQ  \
# 0          0.8855  G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1          0.9772  G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2          0.6220  C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 3          0.9098  G|upstream_gene_variant|MODIFIER|SAMD11|ENSG00...
# 4          0.9996  C|downstream_gene_variant|MODIFIER|NOC2L|ENSG0...
#
#    gnomADe_AF  gnomADe_SAS_AF
# 0      0.8380          0.9005
# 1      0.9497          0.9854
# 2      0.7209          0.8049
# 3      0.0000          0.0000
# 4      0.9999          0.9997

# %%
mother = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/latest_trio/Mother_data_columns.xlsx')
mother['CSQ'] = mother['INFO'].str.extract(r'CSQ=(.*)')
mother['gnomADe_AF'] = mother['CSQ'].str.split('|').str[48].replace('', 0).astype('float')
mother['gnomADe_SAS_AF'] = mother['CSQ'].str.split('|').str[56].replace('', 0).astype('float')
mother.head()
# Out:
#   CHROM     POS         rsID REF ALT QUAL FILTER  \
# 0  chr1   69270  rs201219564   A   G    .   PASS
# 1  chr1   69511    rs2691305   A   G    .   PASS
# 2  chr1   69761  rs200505207   A   T    .   PASS
# 3  chr1   69897  rs200676709   T   C    .   PASS
# 4  chr1  924533  rs112703963   A   G    .   PASS
#
#                                                 INFO   GT   GQ  SDP  RD   AD  \
# 0  ADP=44;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEIN...  0/1  112   44  16   28
# 1  ADP=133;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  133   0  133
# 2  ADP=66;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9633,0....  0/1   60   66  48   18
# 3  ADP=46;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1   59   46  29   17
# 4  ADP=40;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....  1/1  214   40   1   39
#
#      FREQ          PVAL  RBQ  ABQ  RDF  RDR  ADF  ADR   DP  gnomADg_AF  \
# 0  63.64%  5.699700e-12   66   47   15    1   22    6   44     0.62910
# 1    100%  1.725600e-79    0   55    0    0  108   25  133     0.84600
# 2  27.27%  9.974000e-07   57   61   35   13   14    4   66     0.06088
# 3  36.96%  1.241300e-06   62   59   22    7   15    2   46     0.48640
# 4   97.5%  3.813700e-22   62   56    1    0   30    9   40     0.82150
#
#    gnomADg_SAS_AF                                                CSQ  \
# 0         0.88550  G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1         0.97720  G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2         0.04502  T|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 3         0.62200  C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 4         0.90980  G|upstream_gene_variant|MODIFIER|SAMD11|ENSG00...
#
#    gnomADe_AF  gnomADe_SAS_AF
# 0     0.83800         0.90050
# 1     0.94970         0.98540
# 2     0.09168         0.07638
# 3     0.72090         0.80490
# 4     0.00000         0.00000

# %%
son = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/latest_trio/Son_data_columns.xlsx')
son['CSQ'] = son['INFO'].str.extract(r'CSQ=(.*)')
son['gnomADe_AF'] = son['CSQ'].str.split('|').str[48].replace('', 0).astype('float')
son['gnomADe_SAS_AF'] = son['CSQ'].str.split('|').str[56].replace('', 0).astype('float')
son.head()
# Out:
#   CHROM     POS         rsID REF ALT QUAL FILTER  \
# 0  chr1   69270  rs201219564   A   G    .   PASS
# 1  chr1   69511    rs2691305   A   G    .   PASS
# 2  chr1   69897  rs200676709   T   C    .   PASS
# 3  chr1  924533  rs112703963   A   G    .   PASS
# 4  chr1  942451    rs6672356   T   C    .   PASS
#
#                                                 INFO   GT   GQ  SDP  RD   AD  \
# 0  ADP=104;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  255  104  30   74
# 1  ADP=205;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  205   0  205
# 2  ADP=93;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1  255   93  28   65
# 3  ADP=81;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....  1/1  255   81   0   80
# 4  ADP=98;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,1;COMMO...  1/1  255   98   0   98
#
#      FREQ           PVAL  RBQ  ABQ  RDF  RDR  ADF  ADR   DP  gnomADg_AF  \
# 0  71.15%   3.209300e-32   58   49   21    9   59   15  104      0.6291
# 1    100%  9.603300e-123    0   54    0    0  145   60  205      0.8460
# 2  69.89%   4.005100e-28   53   51   15   13   49   16   93      0.4864
# 3  98.77%   1.086400e-47    0   52    0    0   48   32   81      0.8215
# 4    100%   1.749300e-58    0   48    0    0   66   32   98      0.9998
#
#    gnomADg_SAS_AF                                                CSQ  \
# 0          0.8855  G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1          0.9772  G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2          0.6220  C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 3          0.9098  G|upstream_gene_variant|MODIFIER|SAMD11|ENSG00...
# 4          0.9996  C|downstream_gene_variant|MODIFIER|NOC2L|ENSG0...
#
#    gnomADe_AF  gnomADe_SAS_AF
# 0      0.8380          0.9005
# 1      0.9497          0.9854
# 2      0.7209          0.8049
# 3      0.0000          0.0000
# 4      0.9999          0.9997

# %%
intersection = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/latest_trio/intersected_variants.xlsx')
intersection.head()
# Out:
#   CHROM     POS REF ALT         rsID
# 0  chr1   69270   A   G  rs201219564
# 1  chr1   69511   A   G    rs2691305
# 2  chr1   69897   T   C  rs200676709
# 3  chr1  924533   A   G  rs112703963
# 4  chr1  942451   T   C    rs6672356

# %%
father_dummy = father.copy()
father_dummy = father_dummy[['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'INFO']]
father_dummy
# Out:
#       CHROM        POS         rsID REF ALT  \
# 0      chr1      69270  rs201219564   A   G
# 1      chr1      69511    rs2691305   A   G
# 2      chr1      69897  rs200676709   T   C
# 3      chr1     924533  rs112703963   A   G
# 4      chr1     942451    rs6672356   T   C
# ...     ...        ...          ...  ..  ..
# 31681  chrX  155383098            .   T   C
# 31682  chrX  156010159  rs200413398   A   G
# 31683  chrX  156010162  rs150178903   A   G
# 31684  chrY    3019783    rs9786184   A   C
# 31685  chrY   21904151     rs162865   G   A
#
#                                                     INFO
# 0      ADP=140;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...
# 1      ADP=147;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...
# 2      ADP=137;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0...
# 3      ADP=93;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....
# 4      ADP=80;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,1;COMMO...
# ...                                                  ...
# 31681  ADP=87;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...
# 31682  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.858,0.1...
# 31683  ADP=33;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8956,0....
# 31684  ADP=39;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1744,0....
# 31685  ADP=78;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=RBMY...
#
# [31686 rows x 6 columns]

# %%
father_dummy["Gene_Name"] = father_dummy["INFO"].str.extract('GENEINFO=(?P<GENEINFO>.+?);')
father_dummy['Gene_Name'] = father_dummy['Gene_Name'].apply(lambda x: ','.join(set([segment.split(':')[0] for segment in x.split('|')])) if pd.notnull(x) else '')
father_dummy = father_dummy[['CHROM', 'POS', 'REF', 'ALT', 'Gene_Name']]
father_dummy
# Out:
#       CHROM        POS REF ALT            Gene_Name
# 0      chr1      69270   A   G                OR4F5
# 1      chr1      69511   A   G                OR4F5
# 2      chr1      69897   T   C                OR4F5
# 3      chr1     924533   A   G  LOC107985728,SAMD11
# 4      chr1     942451   T   C               SAMD11
# ...     ...        ...  ..  ..                  ...
# 31681  chrX  155383098   T   C
# 31682  chrX  156010159   A   G                 IL9R
# 31683  chrX  156010162   A   G                 IL9R
# 31684  chrY    3019783   A   C            LINC00278
# 31685  chrY   21904151   G   A               RBMY1E
#
# [31686 rows x 5 columns]

# %%
intersection_data = pd.merge(intersection, father_dummy, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'left', sort = False)
intersection_data
# Out:
#       CHROM        POS REF ALT                   rsID            Gene_Name
# 0      chr1      69270   A   G            rs201219564                OR4F5
# 1      chr1      69511   A   G              rs2691305                OR4F5
# 2      chr1      69897   T   C            rs200676709                OR4F5
# 3      chr1     924533   A   G            rs112703963  LOC107985728,SAMD11
# 4      chr1     942451   T   C              rs6672356               SAMD11
# ...     ...        ...  ..  ..                    ...                  ...
# 15198  chrX  154485448   T   C              rs7057286                UBL4A
# 15199  chrX  154563953   C   T  rs201709278;rs5945206                IKBKG
# 15200  chrX  154652556   C   A              rs4326559   LOC105373387,CTAG2
# 15201  chrX  154653499   C   T             rs17855367   LOC105373387,CTAG2
# 15202  chrX  154766321   G   T              rs2728532                 DKC1
#
# [15203 rows x 6 columns]

# %%
father_mapped = pd.merge(intersection_data, son, on = ['CHROM', 'POS', 'REF', 'ALT'], how = 'left', sort=False)
father_mapped = father_mapped[['CHROM', 'POS', 'REF', 'ALT', 'rsID_x', 'Gene_Name', 'DP', 'gnomADg_AF', 'gnomADg_SAS_AF', 'gnomADe_AF', 'gnomADe_SAS_AF']]
father_mapped.rename(columns={'rsID_x': 'rsID'}, inplace=True)
father_mapped.to_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/latest_trio/Son_intersection_mapped_new.xlsx', index=False)
father_mapped
# Out:
#       CHROM        POS REF ALT                   rsID            Gene_Name  \
# 0      chr1      69270   A   G            rs201219564                OR4F5
# 1      chr1      69511   A   G              rs2691305                OR4F5
# 2      chr1      69897   T   C            rs200676709                OR4F5
# 3      chr1     924533   A   G            rs112703963  LOC107985728,SAMD11
# 4      chr1     942451   T   C              rs6672356               SAMD11
# ...     ...        ...  ..  ..                    ...                  ...
# 15198  chrX  154485448   T   C              rs7057286                UBL4A
# 15199  chrX  154563953   C   T  rs201709278;rs5945206                IKBKG
# 15200  chrX  154652556   C   A              rs4326559   LOC105373387,CTAG2
# 15201  chrX  154653499   C   T             rs17855367   LOC105373387,CTAG2
# 15202  chrX  154766321   G   T              rs2728532                 DKC1
#
#         DP  gnomADg_AF  gnomADg_SAS_AF  gnomADe_AF  gnomADe_SAS_AF
# 0      104      0.6291          0.8855      0.8380          0.9005
# 1      205      0.8460          0.9772      0.9497          0.9854
# 2       93      0.4864          0.6220      0.7209          0.8049
# 3       81      0.8215          0.9098      0.0000          0.0000
# 4       98      0.9998          0.9996      0.9999          0.9997
# ...    ...         ...             ...         ...             ...
# 15198   67      0.6669          0.5396      0.0000          0.0000
# 15199   33      0.0000          0.0000      0.0000          0.0000
# 15200   43      0.4733          0.4243      0.0000          0.0000
# 15201   86      0.4428          0.3835      0.0000          0.0000
# 15202   57      0.9924          1.0000      0.9979          1.0000
#
# [15203 rows x 11 columns]

# %%
genes = father_mapped.copy()

# %%
genes['Gene_Name'] = genes['Gene_Name'].str.split(',')
genes = genes.explode('Gene_Name')

# Drop rows with null values
genes.dropna(subset=['Gene_Name'], inplace=True)

# Extract unique gene names
unique_genes = pd.DataFrame(genes['Gene_Name'].unique())
unique_genes
# Out:
#                  0
# 0            OR4F5
# 1           SAMD11
# 2     LOC107985728
# 3            NOC2L
# 4           KLHL17
# ...            ...
# 8269         UBL4A
# 8270         IKBKG
# 8271  LOC105373387
# 8272         CTAG2
# 8273          DKC1
#
# [8274 rows x 1 columns]

# %%
unique_genes.to_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/latest_trio/unique_genes_new.xlsx', index=False)

# %%
def read_bed_file(bed_file):
    bed_positions = set()
    with open(bed_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Skip header lines if present
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 3:
                chrom = fields[0]
                try:
                    start = int(fields[1])
                    end = int(fields[2])
                except ValueError:
                    continue  # Skip this line if start or end position is not an integer
                for pos in range(start, end + 1):
                    bed_positions.add((chrom, pos))
    return bed_positions

def normalize_chrom_name(chrom):
    return chrom.split('_')[0]

def filter_vcf_file(vcf_file, bed_positions):
    filtered_vcf_records = []
    with open(vcf_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Preserve header lines in the output
                filtered_vcf_records.append(line)
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 2:
                raw_chrom = fields[0]
                chrom = normalize_chrom_name(raw_chrom)
                try:
                    pos = int(fields[1])
                except ValueError:
                    continue  # Skip this line if 'POS' is not an integer
                if (chrom, pos) in bed_positions:
                    filtered_vcf_records.append(line)
    return filtered_vcf_records

def write_filtered_vcf(filtered_vcf_records, output_file):
    with open(output_file, 'w') as f:
        for record in filtered_vcf_records:
            f.write(record)

def main():
    bed_file = r'C:/Users/GenepoweRx_Madhu/Downloads/BED_files/KAPA_HyperExome_hg38_primary_targets_extended.bed'
    vcf_file = r'C:/Users/GenepoweRx_Madhu/Downloads/vcf_files_all/KHAIGPRX6_final_son.vcf'
    output_file = r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/KHAIGPRX6_final_son_covered.vcf'

    bed_positions = read_bed_file(bed_file)
    filtered_vcf_records = filter_vcf_file(vcf_file, bed_positions)
    write_filtered_vcf(filtered_vcf_records, output_file)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/BED_files/KAPA_HyperExome_hg38_primary_targets_extended.bed', sep = '\t', header = None, error_bad_lines=False)
df.columns = ['chromosome', 'Start_pos', 'End_pos']
df
# Out:
#        chromosome  Start_pos   End_pos
# 0            chr1      65544     65593
# 1            chr1      69016     70028
# 2            chr1     450719    451698
# 3            chr1     685695    686674
# 4            chr1     924411    924968
# ...           ...        ...       ...
# 242132       chrY   25038788  25038934
# 242133       chrY   25041748  25041906
# 242134       chrY   25043925  25044043
# 242135       chrY   25622422  25624085
# 242136       chrY   25624434  25624547
#
# [242137 rows x 3 columns]

# %%
# Value to check
value = 57209963

# Filter rows where the value lies between start and end positions
filtered_df = df[(df['Start_pos'] <= value) & (df['End_pos'] >= value)]

# Display the filtered DataFrame
filtered_df
# Out:
#        chromosome  Start_pos   End_pos
# 163897      chr14   57209932  57210081

# %%
vcf = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/vcf_files_all/KHAIGPRX5_final_father.vcf', comment='#', sep='\t', header=None, low_memory=False, encoding='latin-1')
vcf.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
vcf
# Out:
#       CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0      chr1     12284            .   A   C    .   PASS
# 1      chr1     14590     rs707679   G   A    .   PASS
# 2      chr1     14599     rs707680   T   A    .   PASS
# 3      chr1     14604  rs541940975   A   G    .   PASS
# 4      chr1     14610  rs878986575   T   C    .   PASS
# ...     ...       ...          ...  ..  ..  ...    ...
# 82471  chrY  57209963            .   G   A    .   PASS
# 82472  chrY  57210759            .   C   G    .   PASS
# 82473  chrY  57211544            .   C   T    .   PASS
# 82474  chrY  57211636            .   G   A    .   PASS
# 82475  chrY  57211706            .   G   C    .   PASS
#
#                                                     INFO  \
# 0      ADP=16;WT=0;HET=1;HOM=0;NC=0;CSQ=C|intron_vari...
# 1      ADP=12;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...
# 2      ADP=15;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8524,0....
# 3      ADP=17;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8524,.,...
# 4      ADP=18;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...
# ...                                                  ...
# 82471  ADP=27;WT=0;HET=1;HOM=0;NC=0;CSQ=A|non_coding_...
# 82472  ADP=52;WT=0;HET=1;HOM=0;NC=0;CSQ=G|non_coding_...
# 82473  ADP=58;WT=0;HET=1;HOM=0;NC=0;CSQ=T|splice_poly...
# 82474  ADP=63;WT=0;HET=1;HOM=0;NC=0;CSQ=A|intron_vari...
# 82475  ADP=52;WT=0;HET=1;HOM=0;NC=0;CSQ=C|intron_vari...
#
#                                                   FORMAT  \
# 0      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# ...                                                  ...
# 82471  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 82472  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 82473  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 82474  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 82475  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                   SAMPLE
# 0           0/1:29:16:16:8:8:50%:1.2236E-3:49:58:7:1:5:3
# 1            0/1:21:12:12:6:6:50%:6.865E-3:43:37:6:0:6:0
# 2           0/1:34:15:15:6:9:60%:3.4983E-4:43:34:6:0:9:0
# 3      0/1:38:17:17:7:10:58.82%:1.4831E-4:51:35:7:0:10:0
# 4      0/1:42:18:18:7:11:61.11%:5.2969E-5:59:37:7:0:11:0
# ...                                                  ...
# 82471  0/1:26:27:27:19:8:29.63%:2.1337E-3:59:64:15:4:7:1
# 82472  0/1:39:52:52:40:12:23.08%:1.1939E-4:67:61:36:4...
# 82473  0/1:64:58:58:39:19:32.76%:3.2669E-7:59:59:33:6...
# 82474  0/1:110:63:63:33:30:47.62%:9.545E-12:53:55:27:...
# 82475  0/1:39:52:52:40:12:23.08%:1.1939E-4:51:55:32:8...
#
# [82476 rows x 10 columns]

# %%
vcf_1 = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/KHAIGPRX5_final_father_covered.vcf', comment='#', sep='\t', header=None, low_memory=False, encoding='latin-1')
vcf_1.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
vcf_1
# Out:
#       CHROM        POS         rsID REF ALT QUAL FILTER  \
# 0      chr1      69270  rs201219564   A   G    .   PASS
# 1      chr1      69511    rs2691305   A   G    .   PASS
# 2      chr1      69897  rs200676709   T   C    .   PASS
# 3      chr1     924533  rs112703963   A   G    .   PASS
# 4      chr1     942451    rs6672356   T   C    .   PASS
# ...     ...        ...          ...  ..  ..  ...    ...
# 31721  chrX  155383098            .   T   C    .   PASS
# 31722  chrX  156010159  rs200413398   A   G    .   PASS
# 31723  chrX  156010162  rs150178903   A   G    .   PASS
# 31724  chrY    3019783    rs9786184   A   C    .   PASS
# 31725  chrY   21904151     rs162865   G   A    .   PASS
#
#                                                     INFO  \
# 0      ADP=140;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...
# 1      ADP=147;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...
# 2      ADP=137;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0...
# 3      ADP=93;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....
# 4      ADP=80;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,1;COMMO...
# ...                                                  ...
# 31721  ADP=87;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...
# 31722  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.858,0.1...
# 31723  ADP=33;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8956,0....
# 31724  ADP=39;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1744,0....
# 31725  ADP=78;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=RBMY...
#
#                                                   FORMAT  \
# 0      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# ...                                                  ...
# 31721  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31722  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31723  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31724  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31725  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                   SAMPLE
# 0      0/1:181:140:140:88:52:37.14%:6.3743E-19:59:49:...
# 1      1/1:255:147:147:1:146:99.32%:1.0001E-85:37:55:...
# 2      0/1:127:137:137:99:38:27.74%:1.8385E-13:56:50:...
# 3      1/1:255:93:93:0:93:100%:1.7451E-55:0:54:0:0:70:23
# 4      1/1:255:80:80:0:80:100%:1.0864E-47:0:51:0:0:54:26
# ...                                                  ...
# 31721  0/1:95:87:87:59:28:32.18%:2.7793E-10:52:61:46:...
# 31722  0/1:85:33:32:11:21:65.62%:3.1387E-9:56:52:8:3:...
# 31723  0/1:78:34:33:13:20:60.61%:1.4096E-8:53:54:9:4:...
# 31724   1/1:224:39:39:0:39:100%:3.6742E-23:0:63:0:0:33:6
# 31725  0/1:66:78:78:58:20:25.64%:2.3595E-7:58:49:42:1...
#
# [31726 rows x 10 columns]

# %%
merged_vcf = pd.merge(vcf, vcf_1, on=['CHROM', 'POS', 'REF', 'ALT'], how='inner', indicator=True)
merged_vcf
# Out:
#       CHROM        POS       rsID_x REF ALT QUAL_x FILTER_x  \
# 0      chr1      69270  rs201219564   A   G      .     PASS
# 1      chr1      69511    rs2691305   A   G      .     PASS
# 2      chr1      69897  rs200676709   T   C      .     PASS
# 3      chr1     924533  rs112703963   A   G      .     PASS
# 4      chr1     942451    rs6672356   T   C      .     PASS
# ...     ...        ...          ...  ..  ..    ...      ...
# 31721  chrX  155383098            .   T   C      .     PASS
# 31722  chrX  156010159  rs200413398   A   G      .     PASS
# 31723  chrX  156010162  rs150178903   A   G      .     PASS
# 31724  chrY    3019783    rs9786184   A   C      .     PASS
# 31725  chrY   21904151     rs162865   G   A      .     PASS
#
#                                                   INFO_x  \
# 0      ADP=140;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...
# 1      ADP=147;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...
# 2      ADP=137;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0...
# 3      ADP=93;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....
# 4      ADP=80;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,1;COMMO...
# ...                                                  ...
# 31721  ADP=87;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...
# 31722  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.858,0.1...
# 31723  ADP=33;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8956,0....
# 31724  ADP=39;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1744,0....
# 31725  ADP=78;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=RBMY...
#
#                                                 FORMAT_x  \
# 0      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# ...                                                  ...
# 31721  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31722  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31723  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31724  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31725  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                 SAMPLE_x       rsID_y QUAL_y  \
# 0      0/1:181:140:140:88:52:37.14%:6.3743E-19:59:49:...  rs201219564      .
# 1      1/1:255:147:147:1:146:99.32%:1.0001E-85:37:55:...    rs2691305      .
# 2      0/1:127:137:137:99:38:27.74%:1.8385E-13:56:50:...  rs200676709      .
# 3      1/1:255:93:93:0:93:100%:1.7451E-55:0:54:0:0:70:23  rs112703963      .
# 4      1/1:255:80:80:0:80:100%:1.0864E-47:0:51:0:0:54:26    rs6672356      .
# ...                                                  ...          ...    ...
# 31721  0/1:95:87:87:59:28:32.18%:2.7793E-10:52:61:46:...            .      .
# 31722  0/1:85:33:32:11:21:65.62%:3.1387E-9:56:52:8:3:...  rs200413398      .
# 31723  0/1:78:34:33:13:20:60.61%:1.4096E-8:53:54:9:4:...  rs150178903      .
# 31724   1/1:224:39:39:0:39:100%:3.6742E-23:0:63:0:0:33:6    rs9786184      .
# 31725  0/1:66:78:78:58:20:25.64%:2.3595E-7:58:49:42:1...     rs162865      .
#
#       FILTER_y                                             INFO_y  \
# 0         PASS  ADP=140;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...
# 1         PASS  ADP=147;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...
# 2         PASS  ADP=137;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0...
# 3         PASS  ADP=93;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....
# 4         PASS  ADP=80;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,1;COMMO...
# ...        ...                                                ...
# 31721     PASS  ADP=87;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...
# 31722     PASS  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.858,0.1...
# 31723     PASS  ADP=33;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8956,0....
# 31724     PASS  ADP=39;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1744,0....
# 31725     PASS  ADP=78;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=RBMY...
#
#                                                 FORMAT_y  \
# 0      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# ...                                                  ...
# 31721  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31722  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31723  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31724  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31725  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                 SAMPLE_y _merge
# 0      0/1:181:140:140:88:52:37.14%:6.3743E-19:59:49:...   both
# 1      1/1:255:147:147:1:146:99.32%:1.0001E-85:37:55:...   both
# 2      0/1:127:137:137:99:38:27.74%:1.8385E-13:56:50:...   both
# 3      1/1:255:93:93:0:93:100%:1.7451E-55:0:54:0:0:70:23   both
# 4      1/1:255:80:80:0:80:100%:1.0864E-47:0:51:0:0:54:26   both
# ...                                                  ...    ...
# 31721  0/1:95:87:87:59:28:32.18%:2.7793E-10:52:61:46:...   both
# 31722  0/1:85:33:32:11:21:65.62%:3.1387E-9:56:52:8:3:...   both
# 31723  0/1:78:34:33:13:20:60.61%:1.4096E-8:53:54:9:4:...   both
# 31724   1/1:224:39:39:0:39:100%:3.6742E-23:0:63:0:0:33:6   both
# 31725  0/1:66:78:78:58:20:25.64%:2.3595E-7:58:49:42:1...   both
#
# [31726 rows x 17 columns]

# %%
# Merge the two DataFrames based on the specified columns ('CHROM', 'POS', 'REF', 'ALT')
merged_vcf = pd.merge(vcf, vcf_1, on=['CHROM', 'POS', 'REF', 'ALT'], how='outer', indicator=True)

# Get the non-common rows from the merged DataFrame
non_common_rows = merged_vcf[merged_vcf['_merge'] != 'both']

# Drop the '_merge' column, which was used for indicating commonality
non_common_rows.drop(columns='_merge', inplace=True)
non_common_rows
# Out:
#       CHROM       POS       rsID_x REF ALT QUAL_x FILTER_x  \
# 0      chr1     12284            .   A   C      .     PASS
# 1      chr1     14590     rs707679   G   A      .     PASS
# 2      chr1     14599     rs707680   T   A      .     PASS
# 3      chr1     14604  rs541940975   A   G      .     PASS
# 4      chr1     14610  rs878986575   T   C      .     PASS
# ...     ...       ...          ...  ..  ..    ...      ...
# 82471  chrY  57209963            .   G   A      .     PASS
# 82472  chrY  57210759            .   C   G      .     PASS
# 82473  chrY  57211544            .   C   T      .     PASS
# 82474  chrY  57211636            .   G   A      .     PASS
# 82475  chrY  57211706            .   G   C      .     PASS
#
#                                                   INFO_x  \
# 0      ADP=16;WT=0;HET=1;HOM=0;NC=0;CSQ=C|intron_vari...
# 1      ADP=12;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...
# 2      ADP=15;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8524,0....
# 3      ADP=17;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8524,.,...
# 4      ADP=18;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...
# ...                                                  ...
# 82471  ADP=27;WT=0;HET=1;HOM=0;NC=0;CSQ=A|non_coding_...
# 82472  ADP=52;WT=0;HET=1;HOM=0;NC=0;CSQ=G|non_coding_...
# 82473  ADP=58;WT=0;HET=1;HOM=0;NC=0;CSQ=T|splice_poly...
# 82474  ADP=63;WT=0;HET=1;HOM=0;NC=0;CSQ=A|intron_vari...
# 82475  ADP=52;WT=0;HET=1;HOM=0;NC=0;CSQ=C|intron_vari...
#
#                                                 FORMAT_x  \
# 0      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# ...                                                  ...
# 82471  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 82472  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 82473  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 82474  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 82475  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                 SAMPLE_x rsID_y QUAL_y  \
# 0           0/1:29:16:16:8:8:50%:1.2236E-3:49:58:7:1:5:3    NaN    NaN
# 1            0/1:21:12:12:6:6:50%:6.865E-3:43:37:6:0:6:0    NaN    NaN
# 2           0/1:34:15:15:6:9:60%:3.4983E-4:43:34:6:0:9:0    NaN    NaN
# 3      0/1:38:17:17:7:10:58.82%:1.4831E-4:51:35:7:0:10:0    NaN    NaN
# 4      0/1:42:18:18:7:11:61.11%:5.2969E-5:59:37:7:0:11:0    NaN    NaN
# ...                                                  ...    ...    ...
# 82471  0/1:26:27:27:19:8:29.63%:2.1337E-3:59:64:15:4:7:1    NaN    NaN
# 82472  0/1:39:52:52:40:12:23.08%:1.1939E-4:67:61:36:4...    NaN    NaN
# 82473  0/1:64:58:58:39:19:32.76%:3.2669E-7:59:59:33:6...    NaN    NaN
# 82474  0/1:110:63:63:33:30:47.62%:9.545E-12:53:55:27:...    NaN    NaN
# 82475  0/1:39:52:52:40:12:23.08%:1.1939E-4:51:55:32:8...    NaN    NaN
#
#       FILTER_y INFO_y FORMAT_y SAMPLE_y
# 0          NaN    NaN      NaN      NaN
# 1          NaN    NaN      NaN      NaN
# 2          NaN    NaN      NaN      NaN
# 3          NaN    NaN      NaN      NaN
# 4          NaN    NaN      NaN      NaN
# ...        ...    ...      ...      ...
# 82471      NaN    NaN      NaN      NaN
# 82472      NaN    NaN      NaN      NaN
# 82473      NaN    NaN      NaN      NaN
# 82474      NaN    NaN      NaN      NaN
# 82475      NaN    NaN      NaN      NaN
#
# [50750 rows x 16 columns]

# %%
50750 + 31726
# Out:
# 82476

# %%
vcf_3= pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/vcf_files_all/matching_positions_father.vcf.vcf', comment='#', sep='\t', header=None, low_memory=False, encoding='latin-1')
vcf_3.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
vcf_3
# Out:
#       CHROM        POS         rsID REF ALT QUAL FILTER  \
# 0      chr1      69270  rs201219564   A   G    .   PASS
# 1      chr1      69511    rs2691305   A   G    .   PASS
# 2      chr1      69897  rs200676709   T   C    .   PASS
# 3      chr1     924533  rs112703963   A   G    .   PASS
# 4      chr1     942451    rs6672356   T   C    .   PASS
# ...     ...        ...          ...  ..  ..  ...    ...
# 31681  chrX  155383098            .   T   C    .   PASS
# 31682  chrX  156010159  rs200413398   A   G    .   PASS
# 31683  chrX  156010162  rs150178903   A   G    .   PASS
# 31684  chrY    3019783    rs9786184   A   C    .   PASS
# 31685  chrY   21904151     rs162865   G   A    .   PASS
#
#                                                     INFO  \
# 0      ADP=140;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...
# 1      ADP=147;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...
# 2      ADP=137;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0...
# 3      ADP=93;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....
# 4      ADP=80;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,1;COMMO...
# ...                                                  ...
# 31681  ADP=87;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...
# 31682  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.858,0.1...
# 31683  ADP=33;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8956,0....
# 31684  ADP=39;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1744,0....
# 31685  ADP=78;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=RBMY...
#
#                                                   FORMAT  \
# 0      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# ...                                                  ...
# 31681  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31682  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31683  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31684  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31685  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                   SAMPLE
# 0      0/1:181:140:140:88:52:37.14%:6.3743E-19:59:49:...
# 1      1/1:255:147:147:1:146:99.32%:1.0001E-85:37:55:...
# 2      0/1:127:137:137:99:38:27.74%:1.8385E-13:56:50:...
# 3      1/1:255:93:93:0:93:100%:1.7451E-55:0:54:0:0:70:23
# 4      1/1:255:80:80:0:80:100%:1.0864E-47:0:51:0:0:54:26
# ...                                                  ...
# 31681  0/1:95:87:87:59:28:32.18%:2.7793E-10:52:61:46:...
# 31682  0/1:85:33:32:11:21:65.62%:3.1387E-9:56:52:8:3:...
# 31683  0/1:78:34:33:13:20:60.61%:1.4096E-8:53:54:9:4:...
# 31684   1/1:224:39:39:0:39:100%:3.6742E-23:0:63:0:0:33:6
# 31685  0/1:66:78:78:58:20:25.64%:2.3595E-7:58:49:42:1...
#
# [31686 rows x 10 columns]

# %%
31726 - 31686
# Out:
# 40

# %%
# Merge the two DataFrames based on the specified columns ('CHROM', 'POS', 'REF', 'ALT')
merged_vcf = pd.merge(vcf_3, vcf_1, on=['CHROM', 'POS', 'REF', 'ALT'], how='outer', indicator=True)

# Get the non-common rows from the merged DataFrame
non_common_rows = merged_vcf[merged_vcf['_merge'] != 'both']

# Drop the '_merge' column, which was used for indicating commonality
non_common_rows.drop(columns='_merge', inplace=True)
non_common_rows
# Out:
#                          CHROM      POS rsID_x REF ALT QUAL_x FILTER_x INFO_x  \
# 31686  chr16_KI270728v1_random   661635    NaN   G   C    NaN      NaN    NaN
# 31687  chr16_KI270728v1_random   661744    NaN   A   C    NaN      NaN    NaN
# 31688  chr16_KI270728v1_random   661775    NaN   T   C    NaN      NaN    NaN
# 31689  chr16_KI270728v1_random  1436517    NaN   G   C    NaN      NaN    NaN
# 31690  chr16_KI270728v1_random  1436793    NaN   G   T    NaN      NaN    NaN
# 31691  chr16_KI270728v1_random  1447573    NaN   A   C    NaN      NaN    NaN
# 31692  chr16_KI270728v1_random  1447646    NaN   C   T    NaN      NaN    NaN
# 31693  chr16_KI270728v1_random  1448375    NaN   G   T    NaN      NaN    NaN
# 31694      chr4_GL000257v2_alt   505927    NaN   C   T    NaN      NaN    NaN
# 31695      chr7_KI270803v1_alt   290188    NaN   A   C    NaN      NaN    NaN
# 31696      chr7_KI270803v1_alt   510876    NaN   G   C    NaN      NaN    NaN
# 31697      chr7_KI270803v1_alt   510972    NaN   C   T    NaN      NaN    NaN
# 31698      chr7_KI270803v1_alt   887410    NaN   G   A    NaN      NaN    NaN
# 31699      chr8_KI270821v1_alt   240886    NaN   A   G    NaN      NaN    NaN
# 31700     chr12_GL877876v1_alt   196140    NaN   G   T    NaN      NaN    NaN
# 31701     chr16_KI270853v1_alt   565193    NaN   C   A    NaN      NaN    NaN
# 31702     chr16_KI270853v1_alt   565195    NaN   C   T    NaN      NaN    NaN
# 31703     chr16_KI270853v1_alt  1978064    NaN   G   A    NaN      NaN    NaN
# 31704     chr16_KI270853v1_alt  2025467    NaN   C   T    NaN      NaN    NaN
# 31705     chr16_GL383556v1_alt    47491    NaN   G   A    NaN      NaN    NaN
# 31706     chr17_KI270861v1_alt   138279    NaN   A   C    NaN      NaN    NaN
# 31707     chr17_KI270857v1_alt  1781279    NaN   G   A    NaN      NaN    NaN
# 31708     chr17_KI270857v1_alt  1781290    NaN   C   G    NaN      NaN    NaN
# 31709     chr17_KI270857v1_alt  2387450    NaN   T   C    NaN      NaN    NaN
# 31710      chr2_KI270894v1_alt    41636    NaN   C   T    NaN      NaN    NaN
# 31711      chr5_KI270897v1_alt   748320    NaN   C   A    NaN      NaN    NaN
# 31712      chr5_KI270897v1_alt   748361    NaN   G   T    NaN      NaN    NaN
# 31713      chr5_KI270897v1_alt   748445    NaN   G   A    NaN      NaN    NaN
# 31714      chr5_KI270897v1_alt   748452    NaN   C   T    NaN      NaN    NaN
# 31715     chr12_KI270904v1_alt   196129    NaN   G   T    NaN      NaN    NaN
# 31716     chr12_KI270904v1_alt   196142    NaN   G   T    NaN      NaN    NaN
# 31717     chr12_KI270904v1_alt   196150    NaN   C   T    NaN      NaN    NaN
# 31718     chr19_GL949748v2_alt  1007679    NaN   A   G    NaN      NaN    NaN
# 31719     chr19_GL949748v2_alt  1007690    NaN   T   G    NaN      NaN    NaN
# 31720     chr19_GL949748v2_alt  1043030    NaN   G   T    NaN      NaN    NaN
# 31721     chr19_GL949749v2_alt   990312    NaN   G   A    NaN      NaN    NaN
# 31722     chr19_GL949750v2_alt   964861    NaN   G   A    NaN      NaN    NaN
# 31723     chr19_GL949751v2_alt   966712    NaN   G   A    NaN      NaN    NaN
# 31724     chr19_GL949753v2_alt   694950    NaN   G   A    NaN      NaN    NaN
# 31725     chr19_KI270938v1_alt   519384    NaN   C   T    NaN      NaN    NaN
#
#       FORMAT_x SAMPLE_x rsID_y QUAL_y FILTER_y  \
# 31686      NaN      NaN      .      .     PASS
# 31687      NaN      NaN      .      .     PASS
# 31688      NaN      NaN      .      .     PASS
# 31689      NaN      NaN      .      .     PASS
# 31690      NaN      NaN      .      .     PASS
# 31691      NaN      NaN      .      .     PASS
# 31692      NaN      NaN      .      .     PASS
# 31693      NaN      NaN      .      .     PASS
# 31694      NaN      NaN      .      .     PASS
# 31695      NaN      NaN      .      .     PASS
# 31696      NaN      NaN      .      .     PASS
# 31697      NaN      NaN      .      .     PASS
# 31698      NaN      NaN      .      .     PASS
# 31699      NaN      NaN      .      .     PASS
# 31700      NaN      NaN      .      .     PASS
# 31701      NaN      NaN      .      .     PASS
# 31702      NaN      NaN      .      .     PASS
# 31703      NaN      NaN      .      .     PASS
# 31704      NaN      NaN      .      .     PASS
# 31705      NaN      NaN      .      .     PASS
# 31706      NaN      NaN      .      .     PASS
# 31707      NaN      NaN      .      .     PASS
# 31708      NaN      NaN      .      .     PASS
# 31709      NaN      NaN      .      .     PASS
# 31710      NaN      NaN      .      .     PASS
# 31711      NaN      NaN      .      .     PASS
# 31712      NaN      NaN      .      .     PASS
# 31713      NaN      NaN      .      .     PASS
# 31714      NaN      NaN      .      .     PASS
# 31715      NaN      NaN      .      .     PASS
# 31716      NaN      NaN      .      .     PASS
# 31717      NaN      NaN      .      .     PASS
# 31718      NaN      NaN      .      .     PASS
# 31719      NaN      NaN      .      .     PASS
# 31720      NaN      NaN      .      .     PASS
# 31721      NaN      NaN      .      .     PASS
# 31722      NaN      NaN      .      .     PASS
# 31723      NaN      NaN      .      .     PASS
# 31724      NaN      NaN      .      .     PASS
# 31725      NaN      NaN      .      .     PASS
#
#                                                   INFO_y  \
# 31686  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|intergenic_...
# 31687  ADP=17;WT=0;HET=1;HOM=0;NC=0;CSQ=C|intergenic_...
# 31688  ADP=13;WT=0;HET=1;HOM=0;NC=0;CSQ=C|intergenic_...
# 31689  ADP=29;WT=0;HET=1;HOM=0;NC=0;CSQ=C|intergenic_...
# 31690  ADP=27;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
# 31691  ADP=46;WT=0;HET=1;HOM=0;NC=0;CSQ=C|intergenic_...
# 31692  ADP=70;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
# 31693  ADP=27;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
# 31694  ADP=35;WT=0;HET=0;HOM=1;NC=0;CSQ=T|intergenic_...
# 31695  ADP=9;WT=0;HET=0;HOM=1;NC=0;CSQ=C|intergenic_v...
# 31696  ADP=16;WT=0;HET=1;HOM=0;NC=0;CSQ=C|intergenic_...
# 31697  ADP=67;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
# 31698  ADP=51;WT=0;HET=1;HOM=0;NC=0;CSQ=A|intergenic_...
# 31699  ADP=30;WT=0;HET=0;HOM=1;NC=0;CSQ=G|intergenic_...
# 31700  ADP=24;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
# 31701  ADP=35;WT=0;HET=1;HOM=0;NC=0;CSQ=A|intergenic_...
# 31702  ADP=35;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
# 31703  ADP=46;WT=0;HET=1;HOM=0;NC=0;CSQ=A|intergenic_...
# 31704  ADP=31;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
# 31705  ADP=31;WT=0;HET=1;HOM=0;NC=0;CSQ=A|intergenic_...
# 31706  ADP=12;WT=0;HET=0;HOM=1;NC=0;CSQ=C|intergenic_...
# 31707  ADP=47;WT=0;HET=1;HOM=0;NC=0;CSQ=A|intergenic_...
# 31708  ADP=47;WT=0;HET=0;HOM=1;NC=0;CSQ=G|intergenic_...
# 31709  ADP=30;WT=0;HET=1;HOM=0;NC=0;CSQ=C|intergenic_...
# 31710  ADP=113;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic...
# 31711  ADP=19;WT=0;HET=1;HOM=0;NC=0;CSQ=A|intergenic_...
# 31712  ADP=27;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
# 31713  ADP=31;WT=0;HET=1;HOM=0;NC=0;CSQ=A|intergenic_...
# 31714  ADP=34;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
# 31715  ADP=21;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
# 31716  ADP=21;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
# 31717  ADP=24;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
# 31718  ADP=12;WT=0;HET=0;HOM=1;NC=0;CSQ=G|intergenic_...
# 31719  ADP=13;WT=0;HET=0;HOM=1;NC=0;CSQ=G|intergenic_...
# 31720  ADP=12;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
# 31721  ADP=14;WT=0;HET=1;HOM=0;NC=0;CSQ=A|intergenic_...
# 31722  ADP=9;WT=0;HET=1;HOM=0;NC=0;CSQ=A|intergenic_v...
# 31723  ADP=10;WT=0;HET=0;HOM=1;NC=0;CSQ=A|intergenic_...
# 31724  ADP=13;WT=0;HET=1;HOM=0;NC=0;CSQ=A|intergenic_...
# 31725  ADP=19;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intergenic_...
#
#                                                 FORMAT_y  \
# 31686  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31687  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31688  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31689  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31690  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31691  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31692  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31693  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31694  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31695  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31696  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31697  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31698  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31699  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31700  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31701  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31702  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31703  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31704  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31705  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31706  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31707  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31708  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31709  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31710  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31711  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31712  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31713  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31714  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31715  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31716  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31717  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31718  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31719  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31720  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31721  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31722  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31723  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31724  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31725  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                 SAMPLE_y
# 31686    0/1:29:15:15:7:8:53.33%:1.0995E-3:58:57:7:0:8:0
# 31687   0/1:24:17:17:10:7:41.18%:3.6151E-3:55:51:7:3:3:4
# 31688    0/1:21:13:13:7:6:46.15%:7.4534E-3:46:55:5:2:3:3
# 31689  0/1:55:29:29:14:15:51.72%:2.6068E-6:46:34:14:0...
# 31690  0/1:67:27:27:10:17:62.96%:1.7891E-7:43:39:3:7:...
# 31691  0/1:80:46:46:24:22:47.83%:8.5409E-9:57:52:23:1...
# 31692  0/1:103:70:70:40:29:41.43%:4.3774E-11:63:60:37...
# 31693  0/1:22:27:27:20:7:25.93%:5.0143E-3:46:54:6:14:4:3
# 31694   1/1:200:35:35:0:35:100%:8.9137E-21:0:62:0:0:30:5
# 31695         1/1:46:9:9:0:9:100%:2.0568E-5:0:50:0:0:7:2
# 31696   0/1:39:16:16:6:10:62.5%:1.2413E-4:49:46:6:0:10:0
# 31697  0/1:113:67:67:36:31:46.27%:4.8717E-12:53:51:33...
# 31698  0/1:102:51:51:23:27:52.94%:5.635E-11:54:55:18:...
# 31699   1/1:170:30:30:0:30:100%:8.4556E-18:0:48:0:0:21:9
# 31700  0/1:39:24:24:13:11:45.83%:1.1047E-4:64:53:12:1...
# 31701  0/1:71:35:35:16:19:54.29%:6.3952E-8:53:46:10:6...
# 31702  0/1:76:35:35:15:20:57.14%:2.0063E-8:55:42:10:5...
# 31703  0/1:32:46:46:36:10:21.74%:5.6532E-4:55:51:26:1...
# 31704  0/1:30:31:31:22:9:29.03%:9.9376E-4:58:52:18:4:6:3
# 31705  0/1:59:31:31:15:16:51.61%:1.0995E-6:66:66:14:1...
# 31706       1/1:37:12:12:3:9:75%:1.6826E-4:49:43:3:0:3:6
# 31707  0/1:80:47:47:25:22:46.81%:9.3895E-9:51:53:20:5...
# 31708  1/1:255:47:47:0:47:100%:6.1512E-28:0:51:0:0:37:10
# 31709   0/1:55:30:30:15:15:50%:2.9161E-6:50:58:14:1:11:4
# 31710  0/1:99:113:113:83:30:26.55%:1.0094E-10:56:52:6...
# 31711   0/1:20:19:19:13:6:31.58%:9.828E-3:53:49:11:2:5:1
# 31712  0/1:42:27:27:15:12:44.44%:5.0681E-5:57:58:12:3...
# 31713  0/1:59:31:31:15:16:51.61%:1.0995E-6:64:61:13:2...
# 31714  0/1:49:34:34:20:14:41.18%:1.1295E-5:56:66:14:6...
# 31715   0/1:27:21:21:13:8:38.1%:1.7241E-3:59:47:12:1:5:3
# 31716   0/1:27:21:21:13:8:38.1%:1.7241E-3:56:47:11:2:3:5
# 31717   0/1:27:24:24:16:8:33.33%:1.949E-3:53:47:13:3:3:5
# 31718       1/1:64:12:12:0:12:100%:3.698E-7:0:42:0:0:9:3
# 31719     1/1:70:13:13:0:13:100%:9.6148E-8:0:48:0:0:10:3
# 31720    0/1:26:12:12:5:7:58.33%:2.2883E-3:51:57:2:3:4:3
# 31721    0/1:30:14:14:6:8:57.14%:9.6618E-4:64:56:5:1:6:2
# 31722      0/1:23:9:9:3:6:66.67%:4.5249E-3:49:61:2:1:5:1
# 31723      1/1:52:10:10:0:10:100%:5.4125E-6:0:61:0:0:8:2
# 31724    0/1:36:13:13:4:9:69.23%:2.2883E-4:64:39:4:0:6:3
# 31725  0/1:53:19:19:6:13:68.42%:5.0106E-6:55:61:3:3:10:3

# %% [markdown]
# # Covered Analysis

# %%
father = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Desktop/Trio_analysis/new_trio_files/Covered_father_new.vcf', comment='#', sep='\t', header=None, low_memory=False, encoding='latin-1')
father.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
father
# Out:
#       CHROM        POS         rsID REF ALT QUAL FILTER  \
# 0      chr1      69270  rs201219564   A   G    .   PASS
# 1      chr1      69511    rs2691305   A   G    .   PASS
# 2      chr1      69897  rs200676709   T   C    .   PASS
# 3      chr1     924533  rs112703963   A   G    .   PASS
# 4      chr1     942451    rs6672356   T   C    .   PASS
# ...     ...        ...          ...  ..  ..  ...    ...
# 31681  chrX  155383098            .   T   C    .   PASS
# 31682  chrX  156010159  rs200413398   A   G    .   PASS
# 31683  chrX  156010162  rs150178903   A   G    .   PASS
# 31684  chrY    3019783    rs9786184   A   C    .   PASS
# 31685  chrY   21904151     rs162865   G   A    .   PASS
#
#                                                     INFO  \
# 0      ADP=140;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...
# 1      ADP=147;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...
# 2      ADP=137;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0...
# 3      ADP=93;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....
# 4      ADP=80;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,1;COMMO...
# ...                                                  ...
# 31681  ADP=87;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...
# 31682  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.858,0.1...
# 31683  ADP=33;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8956,0....
# 31684  ADP=39;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1744,0....
# 31685  ADP=78;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=RBMY...
#
#                                                   FORMAT  \
# 0      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# ...                                                  ...
# 31681  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31682  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31683  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31684  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 31685  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                   SAMPLE
# 0      0/1:181:140:140:88:52:37.14%:6.3743E-19:59:49:...
# 1      1/1:255:147:147:1:146:99.32%:1.0001E-85:37:55:...
# 2      0/1:127:137:137:99:38:27.74%:1.8385E-13:56:50:...
# 3      1/1:255:93:93:0:93:100%:1.7451E-55:0:54:0:0:70:23
# 4      1/1:255:80:80:0:80:100%:1.0864E-47:0:51:0:0:54:26
# ...                                                  ...
# 31681  0/1:95:87:87:59:28:32.18%:2.7793E-10:52:61:46:...
# 31682  0/1:85:33:32:11:21:65.62%:3.1387E-9:56:52:8:3:...
# 31683  0/1:78:34:33:13:20:60.61%:1.4096E-8:53:54:9:4:...
# 31684   1/1:224:39:39:0:39:100%:3.6742E-23:0:63:0:0:33:6
# 31685  0/1:66:78:78:58:20:25.64%:2.3595E-7:58:49:42:1...
#
# [31686 rows x 10 columns]

# %%
mother = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Desktop/Trio_analysis/new_trio_files/Covered_mother_new.vcf', comment='#', sep='\t', header=None, low_memory=False, encoding='latin-1')
mother.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
mother
# Out:
#       CHROM        POS         rsID REF ALT QUAL FILTER  \
# 0      chr1      69270  rs201219564   A   G    .   PASS
# 1      chr1      69511    rs2691305   A   G    .   PASS
# 2      chr1      69761  rs200505207   A   T    .   PASS
# 3      chr1      69897  rs200676709   T   C    .   PASS
# 4      chr1     924533  rs112703963   A   G    .   PASS
# ...     ...        ...          ...  ..  ..  ...    ...
# 29803  chrX  154653251   rs17328091   C   G    .   PASS
# 29804  chrX  154653499   rs17855367   C   T    .   PASS
# 29805  chrX  154766321    rs2728532   G   T    .   PASS
# 29806  chrX  154792236  rs782318569   C   T    .   PASS
# 29807  chrX  155997799    rs6642401   C   T    .   PASS
#
#                                                     INFO  \
# 0      ADP=44;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEIN...
# 1      ADP=133;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...
# 2      ADP=66;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9633,0....
# 3      ADP=46;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....
# 4      ADP=40;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....
# ...                                                  ...
# 29803  ADP=41;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.4906,0....
# 29804  ADP=72;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.5428,.,...
# 29805  ADP=44;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.007417,...
# 29806  ADP=47;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9995,0....
# 29807  ADP=18;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9483,0....
#
#                                                   FORMAT  \
# 0      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# ...                                                  ...
# 29803  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 29804  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 29805  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 29806  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 29807  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                   SAMPLE
# 0      0/1:112:44:44:16:28:63.64%:5.6997E-12:66:47:15...
# 1      1/1:255:133:133:0:133:100%:1.7256E-79:0:55:0:0...
# 2      0/1:60:66:66:48:18:27.27%:9.974E-7:57:61:35:13...
# 3      0/1:59:46:46:29:17:36.96%:1.2413E-6:62:59:22:7...
# 4      1/1:214:40:40:1:39:97.5%:3.8137E-22:62:56:1:0:...
# ...                                                  ...
# 29803  0/1:51:41:41:26:15:36.59%:6.364E-6:44:52:26:0:...
# 29804  0/1:78:72:72:49:23:31.94%:1.4681E-8:61:46:37:1...
# 29805  1/1:248:44:44:0:43:97.73%:1.5066E-25:0:55:0:0:...
# 29806  0/1:120:47:47:17:30:63.83%:8.4848E-13:47:48:13...
# 29807   0/1:42:18:18:7:11:61.11%:5.2969E-5:52:56:5:2:7:4
#
# [29808 rows x 10 columns]

# %%
son = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Desktop/Trio_analysis/new_trio_files/Covered_son_new.vcf', comment='#', sep='\t', header=None, low_memory=False, encoding='latin-1')
son.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
son
# Out:
#       CHROM        POS         rsID REF ALT QUAL FILTER  \
# 0      chr1      69270  rs201219564   A   G    .   PASS
# 1      chr1      69511    rs2691305   A   G    .   PASS
# 2      chr1      69897  rs200676709   T   C    .   PASS
# 3      chr1     924533  rs112703963   A   G    .   PASS
# 4      chr1     942451    rs6672356   T   C    .   PASS
# ...     ...        ...          ...  ..  ..  ...    ...
# 32709  chrX  155277884     rs559165   G   T    .   PASS
# 32710  chrX  156003433    rs2037999   T   C    .   PASS
# 32711  chrY    3019783    rs9786184   A   C    .   PASS
# 32712  chrY   12914512    rs2032624   C   A    .   PASS
# 32713  chrY   21904151     rs162865   G   A    .   PASS
#
#                                                     INFO  \
# 0      ADP=104;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...
# 1      ADP=205;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...
# 2      ADP=93;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....
# 3      ADP=81;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....
# 4      ADP=98;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,1;COMMO...
# ...                                                  ...
# 32709  ADP=28;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6458,0....
# 32710  ADP=9;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.4079,0.5...
# 32711  ADP=42;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1744,0....
# 32712  ADP=18;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.7575,0....
# 32713  ADP=52;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=RBMY...
#
#                                                   FORMAT  \
# 0      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# ...                                                  ...
# 32709  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 32710  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 32711  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 32712  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 32713  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                   SAMPLE
# 0      0/1:255:104:104:30:74:71.15%:3.2093E-32:58:49:...
# 1      1/1:255:205:205:0:205:100%:9.6033E-123:0:54:0:...
# 2      0/1:255:93:93:28:65:69.89%:4.0051E-28:53:51:15...
# 3      1/1:255:81:81:0:80:98.77%:1.0864E-47:0:52:0:0:...
# 4      1/1:255:98:98:0:98:100%:1.7493E-58:0:48:0:0:66:32
# ...                                                  ...
# 32709   1/1:158:28:28:0:28:100%:1.3074E-16:0:54:0:0:25:3
# 32710      0/1:23:9:9:3:6:66.67%:4.5249E-3:61:67:3:0:6:0
# 32711  1/1:242:42:42:0:42:100%:5.9562E-25:0:54:0:0:31:11
# 32712    1/1:99:18:18:0:18:100%:1.1019E-10:0:56:0:0:15:3
# 32713  0/1:35:52:52:41:11:21.15%:2.7081E-4:53:43:28:1...
#
# [32714 rows x 10 columns]

# %%
mother_son = pd.merge(mother, son, on = ['CHROM', 'POS', 'rsID', 'REF', 'ALT'], how = 'inner', sort=False)
mother_son = mother_son[['CHROM', 'POS', 'rsID', 'REF', 'ALT']]
mother_son
# Out:
#       CHROM        POS                   rsID REF ALT
# 0      chr1      69270            rs201219564   A   G
# 1      chr1      69511              rs2691305   A   G
# 2      chr1      69897            rs200676709   T   C
# 3      chr1     924533            rs112703963   A   G
# 4      chr1     942451              rs6672356   T   C
# ...     ...        ...                    ...  ..  ..
# 22170  chrX  154556836                      .   C   T
# 22171  chrX  154563953  rs201709278;rs5945206   C   T
# 22172  chrX  154652556              rs4326559   C   A
# 22173  chrX  154653499             rs17855367   C   T
# 22174  chrX  154766321              rs2728532   G   T
#
# [22175 rows x 5 columns]

# %%
father_son.to_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Trio_analysis/new_trio_files/Mother_Son_common_variants.xlsx', index = False)

# %%
# Merge the two DataFrames on the common column with an indicator
merged = son.merge(mother_son, on=['CHROM', 'POS', 'rsID', 'REF', 'ALT'], how='left', indicator=True)

# Filter rows where the indicator column is set to 'left_only'
non_common_rows_df1 = merged[merged['_merge'] == 'left_only']

# Drop the indicator column if you don't need it
non_common_rows_df1 = non_common_rows_df1.drop(columns=['_merge'])
non_common_rows_df1 = non_common_rows_df1[['CHROM', 'POS', 'rsID', 'REF', 'ALT']]
non_common_rows_df1
# Out:
#       CHROM        POS         rsID REF ALT
# 10     chr1     953778   rs13303056   G   C
# 11     chr1     953779   rs13302945   A   C
# 29     chr1    1020239  rs201073369   G   C
# 30     chr1    1022260    rs6657048   C   T
# 33     chr1    1047342  rs142416636   A   G
# ...     ...        ...          ...  ..  ..
# 32709  chrX  155277884     rs559165   G   T
# 32710  chrX  156003433    rs2037999   T   C
# 32711  chrY    3019783    rs9786184   A   C
# 32712  chrY   12914512    rs2032624   C   A
# 32713  chrY   21904151     rs162865   G   A
#
# [10539 rows x 5 columns]

# %%
non_common_rows_df1.to_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Trio_analysis/new_trio_files/Son_only_variants_(M&S_analysis).xlsx', index=False)

# %%
df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/MODY_new_05_10_2023/All_5samples.xlsx')
df['CHROM'] = 'chr' + df['Chr:Pos'].str.split(':').str[0]
df['POS'] = df['Chr:Pos'].str.split(':').str[1].astype(int)
df['REF'] = df['Ref/Alt'].str.split('/').str[0]
df['ALT'] = df['Ref/Alt'].str.split('/').str[1]
columns_to_check = ['CHROM', 'POS', 'REF', 'ALT']
# Use drop_duplicates to remove duplicated rows based on the specified columns
df = df.drop_duplicates(subset=columns_to_check)
df
# Out:
#             Chr:Pos Ref/Alt  Gene Name     Gene Inheritance Entrez Gene ID  \
# 0           1:69511     A/G      OR4F5  Default (Recessive)          79501
# 1          1:817514     T/C     FAM87B  Default (Recessive)         400728
# 2          1:826893     G/A  LINC00115  Default (Recessive)          79854
# 3          1:827209     G/C  LINC00115  Default (Recessive)          79854
# 4          1:827212     C/G  LINC00115  Default (Recessive)          79854
# ...             ...     ...        ...                  ...            ...
# 481215  X:154641461     NaN        NaN                  NaN            NaN
# 481219  X:154773313     A/T       DKC1            Recessive           1736
# 481223  X:154785208     -/C       MPP1  Default (Recessive)           4354
# 481224  X:154785208     A/C       MPP1  Default (Recessive)           4354
# 481239   Y:11153779     NaN        NaN                  NaN            NaN
#
#        Transcript Name Transcript Strand                        HGVS cDot  \
# 0       NM_001005484.2                 +          NM_001005484.2:c.484A>G
# 1          NR_103536.1                 +             NR_103536.1:n.144T>C
# 2          NR_024321.1                 -             NR_024321.1:n.630C>T
# 3          NR_024321.1                 -             NR_024321.1:n.314C>G
# 4          NR_024321.1                 -             NR_024321.1:n.311G>C
# ...                ...               ...                              ...
# 481215             NaN               NaN                              NaN
# 481219     NM_001363.5                 +         NM_001363.5:c.1155+64A>T
# 481223     NM_002436.4                 -  NM_002436.4:c.678-51_678-50insG
# 481224     NM_002436.4                 -          NM_002436.4:c.678-51T>G
# 481239             NaN               NaN                              NaN
#
#                          HGVS pDot        Sequence Ontology  \
# 0       NP_001005484.2:p.Thr162Ala         missense_variant
# 1                              NaN  non_coding_exon_variant
# 2                              NaN  non_coding_exon_variant
# 3                              NaN  non_coding_exon_variant
# 4                              NaN  non_coding_exon_variant
# ...                            ...                      ...
# 481215                         NaN                      NaN
# 481219                         NaN           intron_variant
# 481223                         NaN           intron_variant
# 481224                         NaN           intron_variant
# 481239                         NaN                      NaN
#
#                   Other Transcript Effects ACMG Classification Criteria  \
# 0                   Single Transcript Gene                      BA1,BP4
# 1                   Single Transcript Gene                  BA1,BS2,BP7
# 2                   Single Transcript Gene                  BA1,BS2,BP7
# 3                   Single Transcript Gene                  BA1,BS2,BP7
# 4                   Single Transcript Gene                  BA1,BS2,BP7
# ...                                    ...                          ...
# 481215                                 NaN                          NaN
# 481219  Other Transcripts Have Same Effect                      PM2,BP7
# 481223  Other Transcripts Have Same Effect                  BA1,BS2,BP7
# 481224  Other Transcripts Have Same Effect                  BA1,BS2,BP7
# 481239                                 NaN                          NaN
#
#                  ACMG Classification Criteria Description   Classification  \
# 0       OR4F5:Allele frequency is above 0.01 recessive...           Benign
# 1       FAM87B:Allele frequency is above 0.01 recessiv...           Benign
# 2       LINC00115:Allele frequency is above 0.01 reces...           Benign
# 3       LINC00115:Allele frequency is above 0.01 reces...           Benign
# 4       LINC00115:Allele frequency is above 0.01 reces...           Benign
# ...                                                   ...              ...
# 481215                                                NaN              NaN
# 481219  DKC1:Variant is missing from all sub populatio...  VUS/Conflicting
# 481223  MPP1:Allele frequency is above 0.01 recessive ...           Benign
# 481224  MPP1:Allele frequency is above 0.01 recessive ...           Benign
# 481239                                                NaN              NaN
#
#        Auto Classification Previous Classification Count  \
# 0                   Benign                           NaN
# 1                   Benign                           NaN
# 2                   Benign                           NaN
# 3                   Benign                           NaN
# 4                   Benign                           NaN
# ...                    ...                           ...
# 481215                 NaN                           NaN
# 481219     VUS/Conflicting                           NaN
# 481223              Benign                           NaN
# 481224              Benign                           NaN
# 481239                 NaN                           NaN
#
#        Previous Classification Last Classification Date  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 481215                     NaN                      NaN
# 481219                     NaN                      NaN
# 481223                     NaN                      NaN
# 481224                     NaN                      NaN
# 481239                     NaN                      NaN
#
#        Max Sub Population Freq Group Name    Max MAF Max Allele Number  \
# 0             Annotated gnomAD East Asian   0.999461             16698
# 1                       Annotated 1kG All   0.753195              5008
# 2             Annotated gnomAD East Asian   0.896992             10106
# 3             Annotated gnomAD East Asian   0.894115              7952
# 4             Annotated gnomAD East Asian   0.894327              7826
# ...                                   ...        ...               ...
# 481215                                NaN        NaN               NaN
# 481219                                NaN        NaN               NaN
# 481223                  Annotated 1kG All  0.0492715              3775
# 481224                  Annotated 1kG All   0.132715              3775
# 481239                                NaN        NaN               NaN
#
#        Max Allele Count CHROM        POS  REF  ALT
# 0                 16689  chr1      69511    A    G
# 1                  3772  chr1     817514    T    C
# 2                  9065  chr1     826893    G    A
# 3                  7110  chr1     827209    G    C
# 4                  6999  chr1     827212    C    G
# ...                 ...   ...        ...  ...  ...
# 481215              NaN  chrX  154641461  NaN  NaN
# 481219              NaN  chrX  154773313    A    T
# 481223              186  chrX  154785208    -    C
# 481224              501  chrX  154785208    A    C
# 481239              NaN  chrY   11153779  NaN  NaN
#
# [194203 rows x 26 columns]

# %%
mother_son['POS'] = mother_son['POS'].astype(int)

merged = pd.merge(mother_son, df, on=['CHROM', 'POS', 'REF', 'ALT'], how='left', sort=False)
merged = merged.drop_duplicates(subset=['CHROM', 'POS', 'REF', 'ALT'])

# To fill NaN values in the 'Classification' column with 'NA', you need to assign the result back to the column.
merged['Classification'] = merged['Classification'].fillna('NA')
merged= merged.fillna('-')
# List of your specified priorities
priorities = ['Pathogenic', 'Likely Pathogenic', 'VUS/Weak Pathogenic', 'VUS/Conflicting', 'VUS', 'VUS/Weak Benign', 'Likely Benign', 'Benign']

# Function to select the highest ranked value from Original_Column
def select_highest_ranked(row):
    values = row['Classification'].split(',')
    for rank in priorities:
        if rank in values:
            return rank
    return None  # Return None if no rank found

# Apply the function to create the final selected rank column
merged['Classification'] = merged.apply(select_highest_ranked, axis=1)
merged
# Out:
#       CHROM        POS                   rsID REF ALT      Chr:Pos Ref/Alt  \
# 0      chr1      69270            rs201219564   A   G            -       -
# 1      chr1      69511              rs2691305   A   G      1:69511     A/G
# 2      chr1      69897            rs200676709   T   C            -       -
# 3      chr1     924533            rs112703963   A   G            -       -
# 4      chr1     942451              rs6672356   T   C            -       -
# ...     ...        ...                    ...  ..  ..          ...     ...
# 22170  chrX  154556836                      .   C   T            -       -
# 22171  chrX  154563953  rs201709278;rs5945206   C   T            -       -
# 22172  chrX  154652556              rs4326559   C   A  X:154652556     C/A
# 22173  chrX  154653499             rs17855367   C   T            -       -
# 22174  chrX  154766321              rs2728532   G   T  X:154766321     G/T
#
#       Gene Name     Gene Inheritance Entrez Gene ID Transcript Name  \
# 0             -                    -              -               -
# 1         OR4F5  Default (Recessive)          79501  NM_001005484.2
# 2             -                    -              -               -
# 3             -                    -              -               -
# 4             -                    -              -               -
# ...         ...                  ...            ...             ...
# 22170         -                    -              -               -
# 22171         -                    -              -               -
# 22172     CTAG2  Default (Recessive)          30848     NM_172377.5
# 22173         -                    -              -               -
# 22174      DKC1            Recessive           1736     NM_001363.5
#
#       Transcript Strand                HGVS cDot                   HGVS pDot  \
# 0                     -                        -                           -
# 1                     +  NM_001005484.2:c.484A>G  NP_001005484.2:p.Thr162Ala
# 2                     -                        -                           -
# 3                     -                        -                           -
# 4                     -                        -                           -
# ...                 ...                      ...                         ...
# 22170                 -                        -                           -
# 22171                 -                        -                           -
# 22172                 -     NM_172377.5:c.345G>T       NP_758965.2:p.Pro115=
# 22173                 -                        -                           -
# 22174                 +     NM_001363.5:c.369G>T       NP_001354.1:p.Thr123=
#
#         Sequence Ontology            Other Transcript Effects  \
# 0                       -                                   -
# 1        missense_variant              Single Transcript Gene
# 2                       -                                   -
# 3                       -                                   -
# 4                       -                                   -
# ...                   ...                                 ...
# 22170                   -                                   -
# 22171                   -                                   -
# 22172  synonymous_variant  Other Transcripts Have Same Effect
# 22173                   -                                   -
# 22174  synonymous_variant  Other Transcripts Have Same Effect
#
#       ACMG Classification Criteria  \
# 0                                -
# 1                          BA1,BP4
# 2                                -
# 3                                -
# 4                                -
# ...                            ...
# 22170                            -
# 22171                            -
# 22172          BA1,BS2,BP4,BP7,BP6
# 22173                            -
# 22174          BA1,BS2,BP4,BP7,BP6
#
#                 ACMG Classification Criteria Description Classification  \
# 0                                                      -           None
# 1      OR4F5:Allele frequency is above 0.01 recessive...         Benign
# 2                                                      -           None
# 3                                                      -           None
# 4                                                      -           None
# ...                                                  ...            ...
# 22170                                                  -           None
# 22171                                                  -           None
# 22172  CTAG2:Allele frequency is above 0.01 recessive...         Benign
# 22173                                                  -           None
# 22174  DKC1:Allele frequency is above 0.01 recessive ...         Benign
#
#       Auto Classification Previous Classification Count  \
# 0                       -                             -
# 1                  Benign                             -
# 2                       -                             -
# 3                       -                             -
# 4                       -                             -
# ...                   ...                           ...
# 22170                   -                             -
# 22171                   -                             -
# 22172              Benign                             -
# 22173                   -                             -
# 22174              Benign                             -
#
#       Previous Classification Last Classification Date  \
# 0                           -                        -
# 1                           -                        -
# 2                           -                        -
# 3                           -                        -
# 4                           -                        -
# ...                       ...                      ...
# 22170                       -                        -
# 22171                       -                        -
# 22172                       -                        -
# 22173                       -                        -
# 22174                       -                        -
#
#       Max Sub Population Freq Group Name   Max MAF Max Allele Number  \
# 0                                      -         -                 -
# 1            Annotated gnomAD East Asian  0.999461             16698
# 2                                      -         -                 -
# 3                                      -         -                 -
# 4                                      -         -                 -
# ...                                  ...       ...               ...
# 22170                                  -         -                 -
# 22171                                  -         -                 -
# 22172        Annotated gnomAD East Asian  0.799206             12844
# 22173                                  -         -                 -
# 22174  Annotated gnomAD Ashkenazi Jewish         1              7293
#
#       Max Allele Count
# 0                    -
# 1                16689
# 2                    -
# 3                    -
# 4                    -
# ...                ...
# 22170                -
# 22171                -
# 22172            10265
# 22173                -
# 22174             7293
#
# [22175 rows x 27 columns]

# %%
merged.to_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Trio_analysis/new_trio_files/Mother_Son_ACMG.xlsx', index = False)

# %%
value_counts_with_null_bcftools = merged['Classification'].value_counts(dropna=False)
#result_df = pd.DataFrame({'Counts': value_counts_with_null_bcftools})
result_df = pd.DataFrame({'Variant_classification': value_counts_with_null_bcftools.index, 'Counts': value_counts_with_null_bcftools.values})
result_df
# Out:
#   Variant_classification  Counts
# 0                 Benign   16252
# 1                   None    5432
# 2          Likely Benign     212
# 3        VUS/Conflicting     184
# 4    VUS/Weak Pathogenic      86
# 5        VUS/Weak Benign       6
# 6                    VUS       2
# 7      Likely Pathogenic       1

# %%
result_df.Counts.sum()
# Out:
# 22175

# %%
result_df.to_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Trio_analysis/new_trio_files/Mother_Son_Classification_counts.xlsx', index = False)

# %%
import pandas as pd
import os

file_directory = r'C:/Users/GenepoweRx_Madhu/Downloads/TRIO/'

# Define a function to read and process an Excel file
def read_excel_file(file_path):
    # Construct the full file path
    full_file_path = os.path.join(file_directory, file_path)

    # Read the Excel file into a Pandas DataFrame, specifying header and usecols
    excel_df = pd.read_excel(full_file_path, header=1, usecols=[0, 1])
    return excel_df

# List of Excel file names (without full paths)
excel_files = ['Germline_KHAFAMGPCSP1.xlsx', 'Germline_KHAFAMGPCSP2.xlsx']  # Replace with your Excel file names

# Initialize the result DataFrame with the data from the first Excel file
result_df = read_excel_file(excel_files[0])

# Define the columns to join on
join_columns = ['Chr:Pos', 'Ref/Alt']

# Iterate through the rest of the Excel files and merge with the result based on the join columns
for file_name in excel_files[1:]:
    excel_df = read_excel_file(file_name)
    result_df = pd.merge(result_df, excel_df, on=join_columns, how='inner')

# Specify the full file path for the output Excel file
output_excel_path = os.path.join(file_directory, 'intersected_data.xlsx')

# Save the result to an Excel file
result_df.to_excel(output_excel_path, index=False)
