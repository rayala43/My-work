# %%
import numpy as np
import pandas as pd
import polars as pl
import sys
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px


pd.set_option('display.max_columns',None)
import psycopg2


#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Algorithms to use
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

#Metrics to evaluate the model
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve

import warnings
warnings.filterwarnings("ignore")

#importing PCA and TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
def read_bed_file(bed_file):
    bed_positions = set()
    with open(bed_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Skip header lines if present
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 3:
                chrom = fields[0]
                try:
                    start = int(fields[1])
                    end = int(fields[2])
                except ValueError:
                    continue  # Skip this line if start or end position is not an integer
                for pos in range(start, end + 1):
                    bed_positions.add((chrom, pos))
    return bed_positions

def normalize_chrom_name(chrom):
    return chrom.split('_')[0]

def filter_vcf_file(vcf_file, bed_positions):
    filtered_vcf_records = []
    with open(vcf_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Preserve header lines in the output
                filtered_vcf_records.append(line)
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 2:
                raw_chrom = fields[0]
                chrom = normalize_chrom_name(raw_chrom)
                try:
                    pos = int(fields[1])
                except ValueError:
                    continue  # Skip this line if 'POS' is not an integer
                if (chrom, pos) in bed_positions:
                    filtered_vcf_records.append(line)
    return filtered_vcf_records

def write_filtered_vcf(filtered_vcf_records, output_file):
    with open(output_file, 'w') as f:
        for record in filtered_vcf_records:
            f.write(record)

def main():
    bed_file = r'C:/Users/GenepoweRx_Madhu/Desktop/Covered_regions.bed'
    vcf_file = r'C:/Users/GenepoweRx_Madhu/Downloads/KHCDPRGPTTL6_annotated_indel.vcf'
    output_file = r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/KHCDPRGPTTL6_annotated_indel.vcf'

    bed_positions = read_bed_file(bed_file)
    filtered_vcf_records = filter_vcf_file(vcf_file, bed_positions)
    write_filtered_vcf(filtered_vcf_records, output_file)

if __name__ == "__main__":
    main()

# %%
vcf = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Desktop/output_filtered_recently.vcf', comment='#', sep="\t", header=None, low_memory=False)
vcf.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
vcf
# Out:
#       CHROM       POS          rsID REF ALT QUAL FILTER  \
# 0      chr1     69270   rs201219564   A   G    .   PASS
# 1      chr1     69511     rs2691305   A   G    .   PASS
# 2      chr1    451290             .   A   C    .   PASS
# 3      chr1    686266             .   A   C    .   PASS
# 4      chr1    924533   rs112703963   A   G    .   PASS
# ...     ...       ...           ...  ..  ..  ...    ...
# 36647  chrY   9528488  rs1179775265   T   G    .   PASS
# 36648  chrY  13360045     rs2032674   T   C    .   PASS
# 36649  chrY  14941891    rs17269816   C   T    .   PASS
# 36650  chrY  15174113    rs17307398   T   C    .   PASS
# 36651  chrY  20577481     rs9786153   C   T    .   PASS
#
#                                                     INFO  \
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...
# 1      ADP=114;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...
# 3      ADP=79;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...
# 4      ADP=11;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....
# ...                                                  ...
# 36647  ADP=186;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...
# 36648  ADP=54;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.8094,0....
# 36649  ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.91,0.09...
# 36650  ADP=29;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.266,0.7...
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....
#
#                                                   FORMAT  \
# 0      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4      GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# ...                                                  ...
# 36647  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 36648  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 36649  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 36650  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 36651  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                   SAMPLE
# 0      0/1:127:138:138:100:38:27.54%:1.8855E-13:60:45...
# 1      1/1:255:114:114:0:114:100%:4.392E-68:0:59:0:0:...
# 2      0/1:56:64:64:47:17:26.56%:2.243E-6:55:58:33:14...
# 3      0/1:85:79:79:54:25:31.65%:3.1101E-9:55:54:43:1...
# 4         1/1:58:11:11:0:11:100%:1.4176E-6:0:63:0:0:10:1
# ...                                                  ...
# 36647  0/1:130:186:186:146:40:21.51%:8.6616E-14:52:49...
# 36648  1/1:255:54:54:0:54:100%:4.0229E-32:0:55:0:0:35:19
# 36649   1/1:182:32:32:0:32:100%:5.4567E-19:0:62:0:0:28:4
# 36650   1/1:164:29:29:0:29:100%:3.3259E-17:0:58:0:0:24:5
# 36651   1/1:123:22:22:0:22:100%:4.7526E-13:0:56:0:0:14:8
#
# [36652 rows x 10 columns]

# %%
sample_cols = vcf['SAMPLE'].str.split(':', expand=True)
sample_cols.columns = ['GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RBQ', 'ABQ', 'RDF', 'RDR', 'ADF', 'ADR']

# Assign the values to the newly created columns
vcf = pd.concat([vcf, sample_cols], axis=1)
vcf = vcf[['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL','RDF', 'RDR', 'ADF', 'ADR']]
vcf
# Out:
#       CHROM       POS          rsID REF ALT QUAL FILTER  \
# 0      chr1     69270   rs201219564   A   G    .   PASS
# 1      chr1     69511     rs2691305   A   G    .   PASS
# 2      chr1    451290             .   A   C    .   PASS
# 3      chr1    686266             .   A   C    .   PASS
# 4      chr1    924533   rs112703963   A   G    .   PASS
# ...     ...       ...           ...  ..  ..  ...    ...
# 36647  chrY   9528488  rs1179775265   T   G    .   PASS
# 36648  chrY  13360045     rs2032674   T   C    .   PASS
# 36649  chrY  14941891    rs17269816   C   T    .   PASS
# 36650  chrY  15174113    rs17307398   T   C    .   PASS
# 36651  chrY  20577481     rs9786153   C   T    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 1      ADP=114;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  114  114
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# 3      ADP=79;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   85   79   79
# 4      ADP=11;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....  1/1   58   11   11
# ...                                                  ...  ...  ...  ...  ...
# 36647  ADP=186;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  130  186  186
# 36648  ADP=54;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.8094,0....  1/1  255   54   54
# 36649  ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.91,0.09...  1/1  182   32   32
# 36650  ADP=29;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.266,0.7...  1/1  164   29   29
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
#
#         RD   AD    FREQ        PVAL RDF RDR ADF ADR
# 0      100   38  27.54%  1.8855E-13  86  14  29   9
# 1        0  114    100%   4.392E-68   0   0  98  16
# 2       47   17  26.56%    2.243E-6  33  14  15   2
# 3       54   25  31.65%   3.1101E-9  43  11  23   2
# 4        0   11    100%   1.4176E-6   0   0  10   1
# ...    ...  ...     ...         ...  ..  ..  ..  ..
# 36647  146   40  21.51%  8.6616E-14  77  69  17  23
# 36648    0   54    100%  4.0229E-32   0   0  35  19
# 36649    0   32    100%  5.4567E-19   0   0  28   4
# 36650    0   29    100%  3.3259E-17   0   0  24   5
# 36651    0   22    100%  4.7526E-13   0   0  14   8
#
# [36652 rows x 20 columns]

# %%
vcf['HET'] = vcf['INFO'].str.extract(r'HET=(\d)')
vcf['HOM'] = vcf['INFO'].str.extract(r'HOM=(\d)')

# Create a new column 'Zygosity' based on conditions
vcf['Zygosity'] = ''

vcf.loc[vcf['HOM'] == '1', 'Zygosity'] = 'Homozygous'
vcf.loc[vcf['HET'] == '1', 'Zygosity'] = 'Heterozygous'
vcf['GT'] = vcf['GT'].astype(str)

vcf
# Out:
#       CHROM       POS          rsID REF ALT QUAL FILTER  \
# 0      chr1     69270   rs201219564   A   G    .   PASS
# 1      chr1     69511     rs2691305   A   G    .   PASS
# 2      chr1    451290             .   A   C    .   PASS
# 3      chr1    686266             .   A   C    .   PASS
# 4      chr1    924533   rs112703963   A   G    .   PASS
# ...     ...       ...           ...  ..  ..  ...    ...
# 36647  chrY   9528488  rs1179775265   T   G    .   PASS
# 36648  chrY  13360045     rs2032674   T   C    .   PASS
# 36649  chrY  14941891    rs17269816   C   T    .   PASS
# 36650  chrY  15174113    rs17307398   T   C    .   PASS
# 36651  chrY  20577481     rs9786153   C   T    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 1      ADP=114;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  114  114
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# 3      ADP=79;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   85   79   79
# 4      ADP=11;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....  1/1   58   11   11
# ...                                                  ...  ...  ...  ...  ...
# 36647  ADP=186;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  130  186  186
# 36648  ADP=54;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.8094,0....  1/1  255   54   54
# 36649  ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.91,0.09...  1/1  182   32   32
# 36650  ADP=29;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.266,0.7...  1/1  164   29   29
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
#
#         RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 1        0  114    100%   4.392E-68   0   0  98  16   0   1    Homozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# 3       54   25  31.65%   3.1101E-9  43  11  23   2   1   0  Heterozygous
# 4        0   11    100%   1.4176E-6   0   0  10   1   0   1    Homozygous
# ...    ...  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 36647  146   40  21.51%  8.6616E-14  77  69  17  23   1   0  Heterozygous
# 36648    0   54    100%  4.0229E-32   0   0  35  19   0   1    Homozygous
# 36649    0   32    100%  5.4567E-19   0   0  28   4   0   1    Homozygous
# 36650    0   29    100%  3.3259E-17   0   0  24   5   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
#
# [36652 rows x 23 columns]

# %%
vcf["Gene_Name"] = vcf["INFO"].str.extract('GENEINFO=(?P<GENEINFO>.+?);')
vcf['Gene Name'] = vcf['Gene_Name'].apply(lambda x: ','.join([segment.split(':')[0] for segment in x.split('|')]) if pd.notnull(x) else '')
vcf
# Out:
#       CHROM       POS          rsID REF ALT QUAL FILTER  \
# 0      chr1     69270   rs201219564   A   G    .   PASS
# 1      chr1     69511     rs2691305   A   G    .   PASS
# 2      chr1    451290             .   A   C    .   PASS
# 3      chr1    686266             .   A   C    .   PASS
# 4      chr1    924533   rs112703963   A   G    .   PASS
# ...     ...       ...           ...  ..  ..  ...    ...
# 36647  chrY   9528488  rs1179775265   T   G    .   PASS
# 36648  chrY  13360045     rs2032674   T   C    .   PASS
# 36649  chrY  14941891    rs17269816   C   T    .   PASS
# 36650  chrY  15174113    rs17307398   T   C    .   PASS
# 36651  chrY  20577481     rs9786153   C   T    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 1      ADP=114;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  114  114
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# 3      ADP=79;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   85   79   79
# 4      ADP=11;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.2502,0....  1/1   58   11   11
# ...                                                  ...  ...  ...  ...  ...
# 36647  ADP=186;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  130  186  186
# 36648  ADP=54;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.8094,0....  1/1  255   54   54
# 36649  ADP=32;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.91,0.09...  1/1  182   32   32
# 36650  ADP=29;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.266,0.7...  1/1  164   29   29
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
#
#         RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity  \
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 1        0  114    100%   4.392E-68   0   0  98  16   0   1    Homozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# 3       54   25  31.65%   3.1101E-9  43  11  23   2   1   0  Heterozygous
# 4        0   11    100%   1.4176E-6   0   0  10   1   0   1    Homozygous
# ...    ...  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 36647  146   40  21.51%  8.6616E-14  77  69  17  23   1   0  Heterozygous
# 36648    0   54    100%  4.0229E-32   0   0  35  19   0   1    Homozygous
# 36649    0   32    100%  5.4567E-19   0   0  28   4   0   1    Homozygous
# 36650    0   29    100%  3.3259E-17   0   0  24   5   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
#
#                                   Gene_Name            Gene Name
# 0                               OR4F5:79501                OR4F5
# 1                               OR4F5:79501                OR4F5
# 2                                       NaN
# 3                                       NaN
# 4      LOC107985728:107985728|SAMD11:148398  LOC107985728,SAMD11
# ...                                     ...                  ...
# 36647                      TSPY10:100289087               TSPY10
# 36648                              UTY:7404                  UTY
# 36649                                   NaN
# 36650                                   NaN
# 36651                           EIF1AY:9086               EIF1AY
#
# [36652 rows x 25 columns]

# %%
vcf['CSQ'] = vcf['INFO'].str.extract(r'CSQ=(.*)')

vcf['csq'] = vcf['CSQ'].str.split(',')
vcf = vcf.explode('csq')
vcf
# Out:
#       CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 1      chr1     69511    rs2691305   A   G    .   PASS
# 2      chr1    451290            .   A   C    .   PASS
# 2      chr1    451290            .   A   C    .   PASS
# ...     ...       ...          ...  ..  ..  ...    ...
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
# 36651  chrY  20577481    rs9786153   C   T    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 0      ADP=138;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  127  138  138
# 1      ADP=114;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  114  114
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# 2      ADP=64;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   56   64   64
# ...                                                  ...  ...  ...  ...  ...
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
# 36651  ADP=22;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1727,0....  1/1  123   22   22
#
#         RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity  \
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 0      100   38  27.54%  1.8855E-13  86  14  29   9   1   0  Heterozygous
# 1        0  114    100%   4.392E-68   0   0  98  16   0   1    Homozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# 2       47   17  26.56%    2.243E-6  33  14  15   2   1   0  Heterozygous
# ...    ...  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
# 36651    0   22    100%  4.7526E-13   0   0  14   8   0   1    Homozygous
#
#          Gene_Name Gene Name  \
# 0      OR4F5:79501     OR4F5
# 0      OR4F5:79501     OR4F5
# 1      OR4F5:79501     OR4F5
# 2              NaN
# 2              NaN
# ...            ...       ...
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
# 36651  EIF1AY:9086    EIF1AY
#
#                                                      CSQ  \
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# ...                                                  ...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
# 36651  T|intron_variant|MODIFIER|EIF1AY|ENSG000001986...
#
#                                                      csq
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 0      G|regulatory_region_variant|MODIFIER|||Regulat...
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2      C|missense_variant|MODERATE|OR4F29|ENSG0000028...
# 2      C|intron_variant&non_coding_transcript_variant...
# ...                                                  ...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
# 36651  T|upstream_gene_variant|MODIFIER|TTTY10|ENSG00...
#
# [328334 rows x 27 columns]

# %%
vcf.CHROM.value_counts()
# Out:
# chr1                       29303
# chr19                      25115
# chr17                      23572
# chr11                      22962
# chr2                       22900
# chr16                      20186
# chr3                       17731
# chr7                       17335
# chr12                      16069
# chr9                       13364
# chr5                       12909
# chr6                       12758
# chr8                       12545
# chr15                      12444
# chr10                      12436
# chr14                      11737
# chr4                       10735
# chr22                       9572
# chr20                       7483
# chr18                       4874
# chr13                       4688
# chrX                        3826
# chr21                       3676
# chrY                          65
# chr16_KI270728v1_random       11
# chr19_GL949746v1_alt           6
# chr19_KI270938v1_alt           6
# chr16_KI270853v1_alt           4
# chr12_KI270904v1_alt           4
# chr12_GL877876v1_alt           3
# chr6_GL000254v2_alt            2
# chr4_GL000257v2_alt            2
# chr9_KI270719v1_random         2
# chr6_GL000251v2_alt            1
# chr9_KI270823v1_alt            1
# chr17_KI270857v1_alt           1
# chr6_GL000252v2_alt            1
# chr17_KI270861v1_alt           1
# chr19_GL949752v1_alt           1
# chr19_GL949753v2_alt           1
# chr16_GL383556v1_alt           1
# chr11_KI270903v1_alt           1
# Name: CHROM, dtype: int64

# %%
#vcf['SYMBOL / Gene Name'] = vcf['csq'].str.split('|').str[3]
vcf['ClinVar_CLNDN'] = vcf['csq'].str.split('|').str[82]
vcf['CLIN_SIG'] = vcf['csq'].str.split('|').str[70]
vcf['ClinVar_CLNREVSTAT'] = vcf['csq'].str.split('|').str[81]
vcf['ClinVar'] = vcf['csq'].str.split('|').str[79]
vcf['HGVSC'] = vcf['csq'].str.split('|').str[10]
vcf['HGVSP'] = vcf['csq'].str.split('|').str[11]
vcf['PolyPhen'] = vcf['csq'].str.split('|').str[38]
vcf['BIOTYPE'] = vcf['csq'].str.split('|').str[7]
vcf['EXON'] = vcf['csq'].str.split('|').str[8]
vcf['INTRON'] = vcf['csq'].str.split('|').str[9]
vcf['Protein_position'] = vcf['csq'].str.split('|').str[14]
vcf['Amino_acids'] = vcf['csq'].str.split('|').str[15]
vcf['Codons'] = vcf['csq'].str.split('|').str[16]
vcf['STRAND'] = vcf['csq'].str.split('|').str[19]
vcf['PUBMED'] = vcf['csq'].str.split('|').str[73]
vcf['Consequence'] = vcf['csq'].str.split('|').str[1]
vcf['IMPACT'] = vcf['csq'].str.split('|').str[2]
vcf['SIFT'] = vcf['csq'].str.split('|').str[37]
vcf
# Out:
#       CHROM       POS          ID REF ALT QUAL FILTER  \
# 0      chr1     13684  rs71260404   C   T    .   PASS
# 0      chr1     13684  rs71260404   C   T    .   PASS
# 0      chr1     13684  rs71260404   C   T    .   PASS
# 0      chr1     13684  rs71260404   C   T    .   PASS
# 0      chr1     13684  rs71260404   C   T    .   PASS
# ...     ...       ...         ...  ..  ..  ...    ...
# 83759  chrY  57211949           .   T   C    .   PASS
# 83759  chrY  57211949           .   T   C    .   PASS
# 83759  chrY  57211949           .   T   C    .   PASS
# 83759  chrY  57211949           .   T   C    .   PASS
# 83759  chrY  57211949           .   T   C    .   PASS
#
#                                                     INFO   GT  GQ  SDP  DP  \
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# ...                                                  ...  ...  ..  ...  ..
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
#
#        RD  AD    FREQ      PVAL  RDF  RDR  ADF  ADR HET HOM      Zygosity  \
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# ...    ..  ..     ...       ...  ...  ...  ...  ...  ..  ..           ...
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
#
#                Gene_Name Gene Name  \
# 0      DDX11L1:100287102   DDX11L1
# 0      DDX11L1:100287102   DDX11L1
# 0      DDX11L1:100287102   DDX11L1
# 0      DDX11L1:100287102   DDX11L1
# 0      DDX11L1:100287102   DDX11L1
# ...                  ...       ...
# 83759                NaN
# 83759                NaN
# 83759                NaN
# 83759                NaN
# 83759                NaN
#
#                                                      CSQ  \
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# ...                                                  ...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
#
#                                                      csq ClinVar_CLNDN  \
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|non_coding_transcript_exon_variant|MODIFIER|...
# 0      T|downstream_gene_variant|MODIFIER|WASH7P|ENSG...
# 0      T|downstream_gene_variant|MODIFIER|MIR6859-1|E...
# 0      T|regulatory_region_variant|MODIFIER|||Regulat...
# ...                                                  ...           ...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|downstream_gene_variant|MODIFIER|WASH6P|ENSG...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|downstream_gene_variant|MODIFIER|DDX11L16|EN...
#
#       CLIN_SIG ClinVar_CLNREVSTAT ClinVar                        HGVSC HGVSP  \
# 0
# 0                                           ENST00000456328.2:n.932C>T
# 0
# 0
# 0
# ...        ...                ...     ...                          ...   ...
# 83759                                      ENST00000484415.6:n.2746T>C
# 83759                                      ENST00000492963.6:n.2950T>C
# 83759
# 83759                                      ENST00000496301.6:n.1404T>C
# 83759
#
#       PolyPhen                             BIOTYPE EXON INTRON  \
# 0               transcribed_unprocessed_pseudogene
# 0                                           lncRNA  3/3
# 0                           unprocessed_pseudogene
# 0                                            miRNA
# 0                                         enhancer
# ...        ...                                 ...  ...    ...
# 83759                              retained_intron  5/5
# 83759                              retained_intron  6/6
# 83759                              retained_intron
# 83759                              retained_intron  2/2
# 83759                       unprocessed_pseudogene
#
#       Protein_position Amino_acids Codons STRAND PUBMED  \
# 0                                              1
# 0                                              1
# 0                                             -1
# 0                                             -1
# 0
# ...                ...         ...    ...    ...    ...
# 83759                                          1
# 83759                                          1
# 83759                                          1
# 83759                                          1
# 83759                                         -1
#
#                               Consequence    IMPACT SIFT
# 0                 downstream_gene_variant  MODIFIER
# 0      non_coding_transcript_exon_variant  MODIFIER
# 0                 downstream_gene_variant  MODIFIER
# 0                 downstream_gene_variant  MODIFIER
# 0               regulatory_region_variant  MODIFIER
# ...                                   ...       ...  ...
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759             downstream_gene_variant  MODIFIER
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759             downstream_gene_variant  MODIFIER
#
# [661656 rows x 45 columns]

# %%
vcf['Protein Position and Amino Acid'] = vcf['Amino_acids'].str[0] + vcf['Protein_position'] + np.where(vcf['Amino_acids'].str[-1] == vcf['Amino_acids'].str[0], '', vcf['Amino_acids'].str[-1])
vcf
# Out:
#       CHROM       POS          ID REF ALT QUAL FILTER  \
# 0      chr1     13684  rs71260404   C   T    .   PASS
# 0      chr1     13684  rs71260404   C   T    .   PASS
# 0      chr1     13684  rs71260404   C   T    .   PASS
# 0      chr1     13684  rs71260404   C   T    .   PASS
# 0      chr1     13684  rs71260404   C   T    .   PASS
# ...     ...       ...         ...  ..  ..  ...    ...
# 83759  chrY  57211949           .   T   C    .   PASS
# 83759  chrY  57211949           .   T   C    .   PASS
# 83759  chrY  57211949           .   T   C    .   PASS
# 83759  chrY  57211949           .   T   C    .   PASS
# 83759  chrY  57211949           .   T   C    .   PASS
#
#                                                     INFO   GT  GQ  SDP  DP  \
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# ...                                                  ...  ...  ..  ...  ..
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
#
#        RD  AD    FREQ      PVAL  RDF  RDR  ADF  ADR HET HOM      Zygosity  \
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# ...    ..  ..     ...       ...  ...  ...  ...  ...  ..  ..           ...
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
#
#                Gene_Name Gene Name  \
# 0      DDX11L1:100287102   DDX11L1
# 0      DDX11L1:100287102   DDX11L1
# 0      DDX11L1:100287102   DDX11L1
# 0      DDX11L1:100287102   DDX11L1
# 0      DDX11L1:100287102   DDX11L1
# ...                  ...       ...
# 83759                NaN
# 83759                NaN
# 83759                NaN
# 83759                NaN
# 83759                NaN
#
#                                                      CSQ  \
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# ...                                                  ...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
#
#                                                      csq ClinVar_CLNDN  \
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|non_coding_transcript_exon_variant|MODIFIER|...
# 0      T|downstream_gene_variant|MODIFIER|WASH7P|ENSG...
# 0      T|downstream_gene_variant|MODIFIER|MIR6859-1|E...
# 0      T|regulatory_region_variant|MODIFIER|||Regulat...
# ...                                                  ...           ...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|downstream_gene_variant|MODIFIER|WASH6P|ENSG...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|downstream_gene_variant|MODIFIER|DDX11L16|EN...
#
#       CLIN_SIG ClinVar_CLNREVSTAT ClinVar                        HGVSC HGVSP  \
# 0
# 0                                           ENST00000456328.2:n.932C>T
# 0
# 0
# 0
# ...        ...                ...     ...                          ...   ...
# 83759                                      ENST00000484415.6:n.2746T>C
# 83759                                      ENST00000492963.6:n.2950T>C
# 83759
# 83759                                      ENST00000496301.6:n.1404T>C
# 83759
#
#       PolyPhen                             BIOTYPE EXON INTRON  \
# 0               transcribed_unprocessed_pseudogene
# 0                                           lncRNA  3/3
# 0                           unprocessed_pseudogene
# 0                                            miRNA
# 0                                         enhancer
# ...        ...                                 ...  ...    ...
# 83759                              retained_intron  5/5
# 83759                              retained_intron  6/6
# 83759                              retained_intron
# 83759                              retained_intron  2/2
# 83759                       unprocessed_pseudogene
#
#       Protein_position Amino_acids Codons STRAND PUBMED  \
# 0                                              1
# 0                                              1
# 0                                             -1
# 0                                             -1
# 0
# ...                ...         ...    ...    ...    ...
# 83759                                          1
# 83759                                          1
# 83759                                          1
# 83759                                          1
# 83759                                         -1
#
#                               Consequence    IMPACT SIFT  \
# 0                 downstream_gene_variant  MODIFIER
# 0      non_coding_transcript_exon_variant  MODIFIER
# 0                 downstream_gene_variant  MODIFIER
# 0                 downstream_gene_variant  MODIFIER
# 0               regulatory_region_variant  MODIFIER
# ...                                   ...       ...  ...
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759             downstream_gene_variant  MODIFIER
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759             downstream_gene_variant  MODIFIER
#
#       Protein Position and Amino Acid
# 0                                 NaN
# 0                                 NaN
# 0                                 NaN
# 0                                 NaN
# 0                                 NaN
# ...                               ...
# 83759                             NaN
# 83759                             NaN
# 83759                             NaN
# 83759                             NaN
# 83759                             NaN
#
# [661656 rows x 46 columns]

# %%
vcf.INFO.iloc[0]
# Out:
# 'ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX11L1:100287102;GNO;RS=71260404;RSPOS=13684;RV;SAO=0;SLO;SSR=0;TOPMED=0.72495380988786952,0.27504619011213047;VC=SNV;VP=0x050100000005000102000100;WGT=1;dbSNPBuildID=130;CSQ=T|downstream_gene_variant|MODIFIER|DDX11L1|ENSG00000223972|Transcript|ENST00000450305|transcribed_unprocessed_pseudogene||||||||||rs71260404|14|1||SNV|HGNC|HGNC:37102|YES|||||||||||||||||||||||||||||||||0.1495|0.02914|0.2292|0.1784|0.2692|0.1122|0.1975|0.18|0.2406|0.149|0.1845|0.2692|gnomADg_ASJ|||||||||||||,T|non_coding_transcript_exon_variant|MODIFIER|DDX11L2|ENSG00000290825|Transcript|ENST00000456328|lncRNA|3/3||ENST00000456328.2:n.932C>T||932|||||rs71260404||1||SNV|EntrezGene||YES|||1||||||||||||||||||||||||||||||0.1495|0.02914|0.2292|0.1784|0.2692|0.1122|0.1975|0.18|0.2406|0.149|0.1845|0.2692|gnomADg_ASJ|||||||||||||,T|downstream_gene_variant|MODIFIER|WASH7P|ENSG00000227232|Transcript|ENST00000488147|unprocessed_pseudogene||||||||||rs71260404|720|-1||SNV|HGNC|HGNC:38034|YES|||||||||||||||||||||||||||||||||0.1495|0.02914|0.2292|0.1784|0.2692|0.1122|0.1975|0.18|0.2406|0.149|0.1845|0.2692|gnomADg_ASJ|||||||||||||,T|downstream_gene_variant|MODIFIER|MIR6859-1|ENSG00000278267|Transcript|ENST00000619216|miRNA||||||||||rs71260404|3685|-1||SNV|HGNC|HGNC:50039|YES|||||||||||||||||||||||||||||||||0.1495|0.02914|0.2292|0.1784|0.2692|0.1122|0.1975|0.18|0.2406|0.149|0.1845|0.2692|gnomADg_ASJ|||||||||||||,T|regulatory_region_variant|MODIFIER|||RegulatoryFeature|ENSR00001164745|enhancer||||||||||rs71260404||||SNV||||||||||||||||||||||||||||||||||||0.1495|0.02914|0.2292|0.1784|0.2692|0.1122|0.1975|0.18|0.2406|0.149|0.1845|0.2692|gnomADg_ASJ|||||||||||||'

# %%
vcf[['HGVSc', 'HGVSc (Transcript)']] = vcf['HGVSC'].str.split(':', 1, expand=True)
vcf[['HGVSp', 'HGVSp (Transcript)']] = vcf['HGVSP'].str.split(':', 1, expand=True)
vcf
# Out:
#       CHROM       POS          ID REF ALT QUAL FILTER  \
# 0      chr1     13684  rs71260404   C   T    .   PASS
# 0      chr1     13684  rs71260404   C   T    .   PASS
# 0      chr1     13684  rs71260404   C   T    .   PASS
# 0      chr1     13684  rs71260404   C   T    .   PASS
# 0      chr1     13684  rs71260404   C   T    .   PASS
# ...     ...       ...         ...  ..  ..  ...    ...
# 83759  chrY  57211949           .   T   C    .   PASS
# 83759  chrY  57211949           .   T   C    .   PASS
# 83759  chrY  57211949           .   T   C    .   PASS
# 83759  chrY  57211949           .   T   C    .   PASS
# 83759  chrY  57211949           .   T   C    .   PASS
#
#                                                     INFO   GT  GQ  SDP  DP  \
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# 0      ADP=30;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX1...  0/1  22   30  30
# ...                                                  ...  ...  ..  ...  ..
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
# 83759  ADP=15;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  29   15  15
#
#        RD  AD    FREQ      PVAL  RDF  RDR  ADF  ADR HET HOM      Zygosity  \
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# 0      23   7  23.33%  0.005271    5   18    4    3   1   0  Heterozygous
# ...    ..  ..     ...       ...  ...  ...  ...  ...  ..  ..           ...
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
# 83759   7   8  53.33%  0.001099    4    3    2    6   1   0  Heterozygous
#
#                Gene_Name Gene Name  \
# 0      DDX11L1:100287102   DDX11L1
# 0      DDX11L1:100287102   DDX11L1
# 0      DDX11L1:100287102   DDX11L1
# 0      DDX11L1:100287102   DDX11L1
# 0      DDX11L1:100287102   DDX11L1
# ...                  ...       ...
# 83759                NaN
# 83759                NaN
# 83759                NaN
# 83759                NaN
# 83759                NaN
#
#                                                      CSQ  \
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# ...                                                  ...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
#
#                                                      csq ClinVar_CLNDN  \
# 0      T|downstream_gene_variant|MODIFIER|DDX11L1|ENS...
# 0      T|non_coding_transcript_exon_variant|MODIFIER|...
# 0      T|downstream_gene_variant|MODIFIER|WASH7P|ENSG...
# 0      T|downstream_gene_variant|MODIFIER|MIR6859-1|E...
# 0      T|regulatory_region_variant|MODIFIER|||Regulat...
# ...                                                  ...           ...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|downstream_gene_variant|MODIFIER|WASH6P|ENSG...
# 83759  C|non_coding_transcript_exon_variant|MODIFIER|...
# 83759  C|downstream_gene_variant|MODIFIER|DDX11L16|EN...
#
#       CLIN_SIG ClinVar_CLNREVSTAT ClinVar                        HGVSC HGVSP  \
# 0
# 0                                           ENST00000456328.2:n.932C>T
# 0
# 0
# 0
# ...        ...                ...     ...                          ...   ...
# 83759                                      ENST00000484415.6:n.2746T>C
# 83759                                      ENST00000492963.6:n.2950T>C
# 83759
# 83759                                      ENST00000496301.6:n.1404T>C
# 83759
#
#       PolyPhen                             BIOTYPE EXON INTRON  \
# 0               transcribed_unprocessed_pseudogene
# 0                                           lncRNA  3/3
# 0                           unprocessed_pseudogene
# 0                                            miRNA
# 0                                         enhancer
# ...        ...                                 ...  ...    ...
# 83759                              retained_intron  5/5
# 83759                              retained_intron  6/6
# 83759                              retained_intron
# 83759                              retained_intron  2/2
# 83759                       unprocessed_pseudogene
#
#       Protein_position Amino_acids Codons STRAND PUBMED  \
# 0                                              1
# 0                                              1
# 0                                             -1
# 0                                             -1
# 0
# ...                ...         ...    ...    ...    ...
# 83759                                          1
# 83759                                          1
# 83759                                          1
# 83759                                          1
# 83759                                         -1
#
#                               Consequence    IMPACT SIFT  \
# 0                 downstream_gene_variant  MODIFIER
# 0      non_coding_transcript_exon_variant  MODIFIER
# 0                 downstream_gene_variant  MODIFIER
# 0                 downstream_gene_variant  MODIFIER
# 0               regulatory_region_variant  MODIFIER
# ...                                   ...       ...  ...
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759             downstream_gene_variant  MODIFIER
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759             downstream_gene_variant  MODIFIER
#
#       Protein Position and Amino Acid              HGVSc HGVSc (Transcript)  \
# 0                                 NaN                                  None
# 0                                 NaN  ENST00000456328.2           n.932C>T
# 0                                 NaN                                  None
# 0                                 NaN                                  None
# 0                                 NaN                                  None
# ...                               ...                ...                ...
# 83759                             NaN  ENST00000484415.6          n.2746T>C
# 83759                             NaN  ENST00000492963.6          n.2950T>C
# 83759                             NaN                                  None
# 83759                             NaN  ENST00000496301.6          n.1404T>C
# 83759                             NaN                                  None
#
#       HGVSp HGVSp (Transcript)
# 0                         None
# 0                         None
# 0                         None
# 0                         None
# 0                         None
# ...     ...                ...
# 83759                     None
# 83759                     None
# 83759                     None
# 83759                     None
# 83759                     None
#
# [661656 rows x 50 columns]

# %%
vcf_final = vcf[['Gene Name', 'ID','CHROM', 'POS', 'REF', 'ALT', 'Zygosity', 'Consequence', 'IMPACT',
          'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT',
          'ClinVar', 'HGVSc', 'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF',
       'ADR', 'SIFT', 'PolyPhen', 'BIOTYPE', 'EXON', 'INTRON',
          'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED']]
vcf_final
# Out:
#       Gene Name          ID CHROM       POS REF ALT      Zygosity  \
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# ...         ...         ...   ...       ...  ..  ..           ...
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
#
#                               Consequence    IMPACT ClinVar_CLNDN CLIN_SIG  \
# 0                 downstream_gene_variant  MODIFIER
# 0      non_coding_transcript_exon_variant  MODIFIER
# 0                 downstream_gene_variant  MODIFIER
# 0                 downstream_gene_variant  MODIFIER
# 0               regulatory_region_variant  MODIFIER
# ...                                   ...       ...           ...      ...
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759             downstream_gene_variant  MODIFIER
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759             downstream_gene_variant  MODIFIER
#
#       ClinVar_CLNREVSTAT ClinVar              HGVSc HGVSc (Transcript) HGVSp  \
# 0                                                                 None
# 0                                 ENST00000456328.2           n.932C>T
# 0                                                                 None
# 0                                                                 None
# 0                                                                 None
# ...                  ...     ...                ...                ...   ...
# 83759                             ENST00000484415.6          n.2746T>C
# 83759                             ENST00000492963.6          n.2950T>C
# 83759                                                             None
# 83759                             ENST00000496301.6          n.1404T>C
# 83759                                                             None
#
#       HGVSp (Transcript)   GT  GQ  SDP  DP  RD  AD    FREQ      PVAL  RDF  \
# 0                   None  0/1  22   30  30  23   7  23.33%  0.005271    5
# 0                   None  0/1  22   30  30  23   7  23.33%  0.005271    5
# 0                   None  0/1  22   30  30  23   7  23.33%  0.005271    5
# 0                   None  0/1  22   30  30  23   7  23.33%  0.005271    5
# 0                   None  0/1  22   30  30  23   7  23.33%  0.005271    5
# ...                  ...  ...  ..  ...  ..  ..  ..     ...       ...  ...
# 83759               None  0/1  29   15  15   7   8  53.33%  0.001099    4
# 83759               None  0/1  29   15  15   7   8  53.33%  0.001099    4
# 83759               None  0/1  29   15  15   7   8  53.33%  0.001099    4
# 83759               None  0/1  29   15  15   7   8  53.33%  0.001099    4
# 83759               None  0/1  29   15  15   7   8  53.33%  0.001099    4
#
#        RDR  ADF  ADR SIFT PolyPhen                             BIOTYPE EXON  \
# 0       18    4    3                transcribed_unprocessed_pseudogene
# 0       18    4    3                                            lncRNA  3/3
# 0       18    4    3                            unprocessed_pseudogene
# 0       18    4    3                                             miRNA
# 0       18    4    3                                          enhancer
# ...    ...  ...  ...  ...      ...                                 ...  ...
# 83759    3    2    6                                   retained_intron  5/5
# 83759    3    2    6                                   retained_intron  6/6
# 83759    3    2    6                                   retained_intron
# 83759    3    2    6                                   retained_intron  2/2
# 83759    3    2    6                            unprocessed_pseudogene
#
#       INTRON Protein Position and Amino Acid Codons STRAND PUBMED
# 0                                        NaN             1
# 0                                        NaN             1
# 0                                        NaN            -1
# 0                                        NaN            -1
# 0                                        NaN
# ...      ...                             ...    ...    ...    ...
# 83759                                    NaN             1
# 83759                                    NaN             1
# 83759                                    NaN             1
# 83759                                    NaN             1
# 83759                                    NaN            -1
#
# [661656 rows x 38 columns]

# %%
vcf_final.ClinVar_CLNDN.value_counts()
# Out:
#                                                                                                                                                                                                                                                                476553
# not_provided                                                                                                                                                                                                                                                    76180
# not_specified&not_provided                                                                                                                                                                                                                                       2856
# not_specified                                                                                                                                                                                                                                                    2582
# not_provided&not_specified                                                                                                                                                                                                                                       1532
#                                                                                                                                                                                                                                                                 ...
# Achromatopsia&Cone_dystrophy_4&not_specified&not_provided                                                                                                                                                                                                           1
# Bile_acid_malabsorption&_primary&_1                                                                                                                                                                                                                                 1
# Achromatopsia&not_specified&not_provided&Cone_dystrophy_4                                                                                                                                                                                                           1
# Cardiovascular_phenotype&not_specified&not_provided&Cardiomyopathy&Hypertrophic_cardiomyopathy_1&MYH7-related_skeletal_myopathy&Dilated_cardiomyopathy_1S&Myosin_storage_myopathy&Hypertrophic_cardiomyopathy&Left_ventricular_noncompaction_cardiomyopathy         1
# Amyotrophic_lateral_sclerosis_type_4&Spinocerebellar_ataxia&_autosomal_recessive&_with_axonal_neuropathy_2&not_provided&not_specified                                                                                                                               1
# Name: ClinVar_CLNDN, Length: 5572, dtype: int64

# %%
# Define the terms to remove
remove_terms = set(["not_specified", "not_provided"])

# Apply the filtering operation to 'Column1' only
vcf_final['ClinVar_CLNDN'] = vcf_final['ClinVar_CLNDN'].apply(lambda row: "&".join(
    [term for term in row.split("&") if term not in remove_terms]
    ) if isinstance(row, str) and not all(term in remove_terms for term in row.split("&")) else row)


vcf_final['CLIN_SIG'] = vcf_final['CLIN_SIG'].apply(lambda row: "&".join(
    [term for term in row.split("&") if term not in remove_terms]
    ) if isinstance(row, str) and not all(term in remove_terms for term in row.split("&")) else row)


vcf_final['ClinVar_CLNREVSTAT'] = vcf_final['ClinVar_CLNREVSTAT'].apply(lambda row: "&".join(
    [term for term in row.split("&") if term not in remove_terms]
    ) if isinstance(row, str) and not all(term in remove_terms for term in row.split("&")) else row)

# Print the modified DataFrame
vcf_final
# Out:
#       Gene Name          ID CHROM       POS REF ALT      Zygosity  \
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# ...         ...         ...   ...       ...  ..  ..           ...
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
#
#                               Consequence    IMPACT ClinVar_CLNDN CLIN_SIG  \
# 0                 downstream_gene_variant  MODIFIER
# 0      non_coding_transcript_exon_variant  MODIFIER
# 0                 downstream_gene_variant  MODIFIER
# 0                 downstream_gene_variant  MODIFIER
# 0               regulatory_region_variant  MODIFIER
# ...                                   ...       ...           ...      ...
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759             downstream_gene_variant  MODIFIER
# 83759  non_coding_transcript_exon_variant  MODIFIER
# 83759             downstream_gene_variant  MODIFIER
#
#       ClinVar_CLNREVSTAT ClinVar              HGVSc HGVSc (Transcript) HGVSp  \
# 0                                                                 None
# 0                                 ENST00000456328.2           n.932C>T
# 0                                                                 None
# 0                                                                 None
# 0                                                                 None
# ...                  ...     ...                ...                ...   ...
# 83759                             ENST00000484415.6          n.2746T>C
# 83759                             ENST00000492963.6          n.2950T>C
# 83759                                                             None
# 83759                             ENST00000496301.6          n.1404T>C
# 83759                                                             None
#
#       HGVSp (Transcript)   GT  GQ  SDP  DP  RD  AD    FREQ      PVAL  RDF  \
# 0                   None  0/1  22   30  30  23   7  23.33%  0.005271    5
# 0                   None  0/1  22   30  30  23   7  23.33%  0.005271    5
# 0                   None  0/1  22   30  30  23   7  23.33%  0.005271    5
# 0                   None  0/1  22   30  30  23   7  23.33%  0.005271    5
# 0                   None  0/1  22   30  30  23   7  23.33%  0.005271    5
# ...                  ...  ...  ..  ...  ..  ..  ..     ...       ...  ...
# 83759               None  0/1  29   15  15   7   8  53.33%  0.001099    4
# 83759               None  0/1  29   15  15   7   8  53.33%  0.001099    4
# 83759               None  0/1  29   15  15   7   8  53.33%  0.001099    4
# 83759               None  0/1  29   15  15   7   8  53.33%  0.001099    4
# 83759               None  0/1  29   15  15   7   8  53.33%  0.001099    4
#
#        RDR  ADF  ADR SIFT PolyPhen                             BIOTYPE EXON  \
# 0       18    4    3                transcribed_unprocessed_pseudogene
# 0       18    4    3                                            lncRNA  3/3
# 0       18    4    3                            unprocessed_pseudogene
# 0       18    4    3                                             miRNA
# 0       18    4    3                                          enhancer
# ...    ...  ...  ...  ...      ...                                 ...  ...
# 83759    3    2    6                                   retained_intron  5/5
# 83759    3    2    6                                   retained_intron  6/6
# 83759    3    2    6                                   retained_intron
# 83759    3    2    6                                   retained_intron  2/2
# 83759    3    2    6                            unprocessed_pseudogene
#
#       INTRON Protein Position and Amino Acid Codons STRAND PUBMED
# 0                                        NaN             1
# 0                                        NaN             1
# 0                                        NaN            -1
# 0                                        NaN            -1
# 0                                        NaN
# ...      ...                             ...    ...    ...    ...
# 83759                                    NaN             1
# 83759                                    NaN             1
# 83759                                    NaN             1
# 83759                                    NaN             1
# 83759                                    NaN            -1
#
# [661656 rows x 38 columns]

# %%
vcf_final = vcf_final.astype(str).applymap(lambda x: x.replace('&', ',').replace('_', ' '))
vcf_final
# Out:
#       Gene Name          ID CHROM       POS REF ALT      Zygosity  \
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# ...         ...         ...   ...       ...  ..  ..           ...
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
#
#                               Consequence    IMPACT ClinVar_CLNDN CLIN_SIG  \
# 0                 downstream gene variant  MODIFIER
# 0      non coding transcript exon variant  MODIFIER
# 0                 downstream gene variant  MODIFIER
# 0                 downstream gene variant  MODIFIER
# 0               regulatory region variant  MODIFIER
# ...                                   ...       ...           ...      ...
# 83759  non coding transcript exon variant  MODIFIER
# 83759  non coding transcript exon variant  MODIFIER
# 83759             downstream gene variant  MODIFIER
# 83759  non coding transcript exon variant  MODIFIER
# 83759             downstream gene variant  MODIFIER
#
#       ClinVar_CLNREVSTAT ClinVar              HGVSc HGVSc (Transcript) HGVSp  \
# 0                                                                 None
# 0                                 ENST00000456328.2           n.932C>T
# 0                                                                 None
# 0                                                                 None
# 0                                                                 None
# ...                  ...     ...                ...                ...   ...
# 83759                             ENST00000484415.6          n.2746T>C
# 83759                             ENST00000492963.6          n.2950T>C
# 83759                                                             None
# 83759                             ENST00000496301.6          n.1404T>C
# 83759                                                             None
#
#       HGVSp (Transcript)   GT  GQ SDP  DP  RD AD    FREQ       PVAL RDF RDR  \
# 0                   None  0/1  22  30  30  23  7  23.33%  0.0052713   5  18
# 0                   None  0/1  22  30  30  23  7  23.33%  0.0052713   5  18
# 0                   None  0/1  22  30  30  23  7  23.33%  0.0052713   5  18
# 0                   None  0/1  22  30  30  23  7  23.33%  0.0052713   5  18
# 0                   None  0/1  22  30  30  23  7  23.33%  0.0052713   5  18
# ...                  ...  ...  ..  ..  ..  .. ..     ...        ...  ..  ..
# 83759               None  0/1  29  15  15   7  8  53.33%  0.0010995   4   3
# 83759               None  0/1  29  15  15   7  8  53.33%  0.0010995   4   3
# 83759               None  0/1  29  15  15   7  8  53.33%  0.0010995   4   3
# 83759               None  0/1  29  15  15   7  8  53.33%  0.0010995   4   3
# 83759               None  0/1  29  15  15   7  8  53.33%  0.0010995   4   3
#
#       ADF ADR SIFT PolyPhen                             BIOTYPE EXON INTRON  \
# 0       4   3                transcribed unprocessed pseudogene
# 0       4   3                                            lncRNA  3/3
# 0       4   3                            unprocessed pseudogene
# 0       4   3                                             miRNA
# 0       4   3                                          enhancer
# ...    ..  ..  ...      ...                                 ...  ...    ...
# 83759   2   6                                   retained intron  5/5
# 83759   2   6                                   retained intron  6/6
# 83759   2   6                                   retained intron
# 83759   2   6                                   retained intron  2/2
# 83759   2   6                            unprocessed pseudogene
#
#       Protein Position and Amino Acid Codons STRAND PUBMED
# 0                                 nan             1
# 0                                 nan             1
# 0                                 nan            -1
# 0                                 nan            -1
# 0                                 nan
# ...                               ...    ...    ...    ...
# 83759                             nan             1
# 83759                             nan             1
# 83759                             nan             1
# 83759                             nan             1
# 83759                             nan            -1
#
# [661656 rows x 38 columns]

# %%
vcf_final['POS'] = vcf_final['POS'].astype('int64')
vcf_final
# Out:
#       Gene Name          ID CHROM       POS REF ALT      Zygosity  \
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# 0       DDX11L1  rs71260404  chr1     13684   C   T  Heterozygous
# ...         ...         ...   ...       ...  ..  ..           ...
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
# 83759                     .  chrY  57211949   T   C  Heterozygous
#
#                               Consequence    IMPACT ClinVar_CLNDN CLIN_SIG  \
# 0                 downstream gene variant  MODIFIER
# 0      non coding transcript exon variant  MODIFIER
# 0                 downstream gene variant  MODIFIER
# 0                 downstream gene variant  MODIFIER
# 0               regulatory region variant  MODIFIER
# ...                                   ...       ...           ...      ...
# 83759  non coding transcript exon variant  MODIFIER
# 83759  non coding transcript exon variant  MODIFIER
# 83759             downstream gene variant  MODIFIER
# 83759  non coding transcript exon variant  MODIFIER
# 83759             downstream gene variant  MODIFIER
#
#       ClinVar_CLNREVSTAT ClinVar              HGVSc HGVSc (Transcript) HGVSp  \
# 0                                                                 None
# 0                                 ENST00000456328.2           n.932C>T
# 0                                                                 None
# 0                                                                 None
# 0                                                                 None
# ...                  ...     ...                ...                ...   ...
# 83759                             ENST00000484415.6          n.2746T>C
# 83759                             ENST00000492963.6          n.2950T>C
# 83759                                                             None
# 83759                             ENST00000496301.6          n.1404T>C
# 83759                                                             None
#
#       HGVSp (Transcript)   GT  GQ SDP  DP  RD AD    FREQ       PVAL RDF RDR  \
# 0                   None  0/1  22  30  30  23  7  23.33%  0.0052713   5  18
# 0                   None  0/1  22  30  30  23  7  23.33%  0.0052713   5  18
# 0                   None  0/1  22  30  30  23  7  23.33%  0.0052713   5  18
# 0                   None  0/1  22  30  30  23  7  23.33%  0.0052713   5  18
# 0                   None  0/1  22  30  30  23  7  23.33%  0.0052713   5  18
# ...                  ...  ...  ..  ..  ..  .. ..     ...        ...  ..  ..
# 83759               None  0/1  29  15  15   7  8  53.33%  0.0010995   4   3
# 83759               None  0/1  29  15  15   7  8  53.33%  0.0010995   4   3
# 83759               None  0/1  29  15  15   7  8  53.33%  0.0010995   4   3
# 83759               None  0/1  29  15  15   7  8  53.33%  0.0010995   4   3
# 83759               None  0/1  29  15  15   7  8  53.33%  0.0010995   4   3
#
#       ADF ADR SIFT PolyPhen                             BIOTYPE EXON INTRON  \
# 0       4   3                transcribed unprocessed pseudogene
# 0       4   3                                            lncRNA  3/3
# 0       4   3                            unprocessed pseudogene
# 0       4   3                                             miRNA
# 0       4   3                                          enhancer
# ...    ..  ..  ...      ...                                 ...  ...    ...
# 83759   2   6                                   retained intron  5/5
# 83759   2   6                                   retained intron  6/6
# 83759   2   6                                   retained intron
# 83759   2   6                                   retained intron  2/2
# 83759   2   6                            unprocessed pseudogene
#
#       Protein Position and Amino Acid Codons STRAND PUBMED
# 0                                 nan             1
# 0                                 nan             1
# 0                                 nan            -1
# 0                                 nan            -1
# 0                                 nan
# ...                               ...    ...    ...    ...
# 83759                             nan             1
# 83759                             nan             1
# 83759                             nan             1
# 83759                             nan             1
# 83759                             nan            -1
#
# [661656 rows x 38 columns]

# %%
vcf_final.isnull().sum()
# Out:
# Gene Name                          0
# ID                                 0
# CHROM                              0
# POS                                0
# REF                                0
# ALT                                0
# Zygosity                           0
# Consequence                        0
# IMPACT                             0
# ClinVar_CLNDN                      0
# CLIN_SIG                           0
# ClinVar_CLNREVSTAT                 0
# ClinVar                            0
# HGVSc                              0
# HGVSc (Transcript)                 0
# HGVSp                              0
# HGVSp (Transcript)                 0
# GT                                 0
# GQ                                 0
# SDP                                0
# DP                                 0
# RD                                 0
# AD                                 0
# FREQ                               0
# PVAL                               0
# RDF                                0
# RDR                                0
# ADF                                0
# ADR                                0
# SIFT                               0
# PolyPhen                           0
# BIOTYPE                            0
# EXON                               0
# INTRON                             0
# Protein Position and Amino Acid    0
# Codons                             0
# STRAND                             0
# PUBMED                             0
# dtype: int64

# %%
vcf_final.CLIN_SIG.value_counts()
# Out:
#                                                                             477203
# benign                                                                      168597
# benign,likely benign                                                          4708
# likely benign                                                                 2996
# benign,benign/likely benign                                                   1331
#                                                                              ...
# benign,benign/likely benign,conflicting interpretations of pathogenicity         3
# uncertain significance,risk factor                                               2
# association,likely benign                                                        2
# likely benign,drug response,other                                                2
# conflicting interpretations of pathogenicity,risk factor,benign                  2
# Name: CLIN_SIG, Length: 109, dtype: int64

# %%
df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/vcf_files_all/KHGLBS535/POS.xlsx')
df
# Out:
#            POS
# 0        69270
# 1        69511
# 2        69735
# 3        69897
# 4       451229
# ...        ...
# 38110  2789135
# 38111  3019783
# 38112  6885470
# 38113  9466925
# 38114  9467257
#
# [38115 rows x 1 columns]

# %%
merged_vcf = pd.merge(vcf_final, df, on = 'POS', how = 'inner')
merged_vcf
# Out:
#        Gene Name            ID CHROM      POS REF ALT      Zygosity  \
# 0          OR4F5   rs201219564  chr1    69270   A   G  Heterozygous
# 1          OR4F5   rs201219564  chr1    69270   A   G  Heterozygous
# 2          OR4F5     rs2691305  chr1    69511   A   G    Homozygous
# 3          OR4F5  rs1245478362  chr1    69735   A   G  Heterozygous
# 4          OR4F5   rs200676709  chr1    69897   T   C  Heterozygous
# ...          ...           ...   ...      ...  ..  ..           ...
# 333893     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333894     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333895     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333896     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333897     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
#
#                       Consequence    IMPACT ClinVar_CLNDN CLIN_SIG  \
# 0              synonymous variant       LOW
# 1       regulatory region variant  MODIFIER
# 2                missense variant  MODERATE
# 3              synonymous variant       LOW
# 4              synonymous variant       LOW
# ...                           ...       ...           ...      ...
# 333893      upstream gene variant  MODIFIER
# 333894           missense variant  MODERATE
# 333895           missense variant  MODERATE
# 333896      upstream gene variant  MODIFIER
# 333897      upstream gene variant  MODIFIER
#
#        ClinVar_CLNREVSTAT ClinVar              HGVSc HGVSc (Transcript)  \
# 0                                  ENST00000641515.2           c.243A>G
# 1                                                                  None
# 2                                  ENST00000641515.2           c.484A>G
# 3                                  ENST00000641515.2           c.708A>G
# 4                                  ENST00000641515.2           c.870T>C
# ...                   ...     ...                ...                ...
# 333893                                                             None
# 333894                             ENST00000423647.6           c.257G>A
# 333895                             ENST00000451548.6           c.257G>A
# 333896                                                             None
# 333897                                                             None
#
#                     HGVSp HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD  \
# 0       ENSP00000493376.2         p.Ser81%3D  0/1  120  101  101   66   35
# 1                                       None  0/1  120  101  101   66   35
# 2       ENSP00000493376.2        p.Thr162Ala  1/1  255  143  143    0  143
# 3       ENSP00000493376.2        p.Leu236%3D  0/1  163  180  180  131   49
# 4       ENSP00000493376.2        p.Ser290%3D  0/1   75   96   96   73   23
# ...                   ...                ...  ...  ...  ...  ...  ...  ...
# 333893                                  None  0/1  255  383  383  273  110
# 333894  ENSP00000389324.3         p.Arg86Gln  0/1  255  383  383  273  110
# 333895  ENSP00000403304.1         p.Arg86Gln  0/1  255  383  383  273  110
# 333896                                  None  0/1  255  383  383  273  110
# 333897                                  None  0/1  255  383  383  273  110
#
#           FREQ                   PVAL  RDF  RDR  ADF ADR             SIFT  \
# 0       34.65%             8.1311e-13   48   18   24  11
# 1       34.65%             8.1311e-13   48   18   24  11
# 2         100%             1.7063e-85    0    0  100  43  tolerated(0.92)
# 3       27.22%             4.0111e-17   84   47   39  10
# 4       23.96%             2.6678e-08   30   43   13  10
# ...        ...                    ...  ...  ...  ...  ..              ...
# 333893  28.72%  7.984299999999999e-38  136  137   83  27
# 333894  28.72%  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333895  28.72%  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333896  28.72%  7.984299999999999e-38  136  137   83  27
# 333897  28.72%  7.984299999999999e-38  136  137   83  27
#
#              PolyPhen                             BIOTYPE EXON INTRON  \
# 0                                          protein coding  3/3
# 1                                         TF binding site
# 2           benign(0)                      protein coding  3/3
# 3                                          protein coding  3/3
# 4                                          protein coding  3/3
# ...               ...                                 ...  ...    ...
# 333893                 transcribed unprocessed pseudogene
# 333894  benign(0.375)                      protein coding  1/6
# 333895  benign(0.101)                      protein coding  1/6
# 333896                                             lncRNA
# 333897                                             lncRNA
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED
# 0                                  S81  tcA/tcG      1
# 1                                  nan
# 2                                T162A  Aca/Gca      1
# 3                                 L236  ctA/ctG      1
# 4                                 S290  tcT/tcC      1
# ...                                ...      ...    ...    ...
# 333893                             nan              -1
# 333894                            R86Q  cGg/cAg      1
# 333895                            R86Q  cGg/cAg      1
# 333896                             nan              -1
# 333897                             nan              -1
#
# [333898 rows x 38 columns]

# %%
336150-335796
# Out:
# 354

# %%
#merged_vcf.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Processed_vcf_files/KHHSPTGPCSP6_processed_vcf.xlsx', index=False)

# %%
#df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Processed_vcf_files/KHHSPTGPCSP6_processed_vcf.xlsx')
#df.head()

# %%
merged_vcf.Consequence.value_counts()
# Out:
# downstream gene variant                                     58852
# intron variant                                              46047
# upstream gene variant                                       43542
# synonymous variant                                          35881
# missense variant                                            28788
#                                                             ...
# stop gained,splice region variant                               4
# coding sequence variant                                         4
# start lost,splice region variant,NMD transcript variant         3
# stop gained,splice region variant,NMD transcript variant        3
# stop lost,splice region variant,NMD transcript variant          1
# Name: Consequence, Length: 63, dtype: int64

# %%
merged_vcf['consequence'] = merged_vcf['Consequence'].str.split(',').str[0]
merged_vcf
# Out:
#        Gene Name            ID CHROM      POS REF ALT      Zygosity  \
# 0          OR4F5   rs201219564  chr1    69270   A   G  Heterozygous
# 1          OR4F5   rs201219564  chr1    69270   A   G  Heterozygous
# 2          OR4F5     rs2691305  chr1    69511   A   G    Homozygous
# 3          OR4F5  rs1245478362  chr1    69735   A   G  Heterozygous
# 4          OR4F5   rs200676709  chr1    69897   T   C  Heterozygous
# ...          ...           ...   ...      ...  ..  ..           ...
# 333893     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333894     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333895     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333896     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333897     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
#
#                       Consequence    IMPACT ClinVar_CLNDN CLIN_SIG  \
# 0              synonymous variant       LOW
# 1       regulatory region variant  MODIFIER
# 2                missense variant  MODERATE
# 3              synonymous variant       LOW
# 4              synonymous variant       LOW
# ...                           ...       ...           ...      ...
# 333893      upstream gene variant  MODIFIER
# 333894           missense variant  MODERATE
# 333895           missense variant  MODERATE
# 333896      upstream gene variant  MODIFIER
# 333897      upstream gene variant  MODIFIER
#
#        ClinVar_CLNREVSTAT ClinVar              HGVSc HGVSc (Transcript)  \
# 0                                  ENST00000641515.2           c.243A>G
# 1                                                                  None
# 2                                  ENST00000641515.2           c.484A>G
# 3                                  ENST00000641515.2           c.708A>G
# 4                                  ENST00000641515.2           c.870T>C
# ...                   ...     ...                ...                ...
# 333893                                                             None
# 333894                             ENST00000423647.6           c.257G>A
# 333895                             ENST00000451548.6           c.257G>A
# 333896                                                             None
# 333897                                                             None
#
#                     HGVSp HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD  \
# 0       ENSP00000493376.2         p.Ser81%3D  0/1  120  101  101   66   35
# 1                                       None  0/1  120  101  101   66   35
# 2       ENSP00000493376.2        p.Thr162Ala  1/1  255  143  143    0  143
# 3       ENSP00000493376.2        p.Leu236%3D  0/1  163  180  180  131   49
# 4       ENSP00000493376.2        p.Ser290%3D  0/1   75   96   96   73   23
# ...                   ...                ...  ...  ...  ...  ...  ...  ...
# 333893                                  None  0/1  255  383  383  273  110
# 333894  ENSP00000389324.3         p.Arg86Gln  0/1  255  383  383  273  110
# 333895  ENSP00000403304.1         p.Arg86Gln  0/1  255  383  383  273  110
# 333896                                  None  0/1  255  383  383  273  110
# 333897                                  None  0/1  255  383  383  273  110
#
#           FREQ                   PVAL  RDF  RDR  ADF ADR             SIFT  \
# 0       34.65%             8.1311e-13   48   18   24  11
# 1       34.65%             8.1311e-13   48   18   24  11
# 2         100%             1.7063e-85    0    0  100  43  tolerated(0.92)
# 3       27.22%             4.0111e-17   84   47   39  10
# 4       23.96%             2.6678e-08   30   43   13  10
# ...        ...                    ...  ...  ...  ...  ..              ...
# 333893  28.72%  7.984299999999999e-38  136  137   83  27
# 333894  28.72%  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333895  28.72%  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333896  28.72%  7.984299999999999e-38  136  137   83  27
# 333897  28.72%  7.984299999999999e-38  136  137   83  27
#
#              PolyPhen                             BIOTYPE EXON INTRON  \
# 0                                          protein coding  3/3
# 1                                         TF binding site
# 2           benign(0)                      protein coding  3/3
# 3                                          protein coding  3/3
# 4                                          protein coding  3/3
# ...               ...                                 ...  ...    ...
# 333893                 transcribed unprocessed pseudogene
# 333894  benign(0.375)                      protein coding  1/6
# 333895  benign(0.101)                      protein coding  1/6
# 333896                                             lncRNA
# 333897                                             lncRNA
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED  \
# 0                                  S81  tcA/tcG      1
# 1                                  nan
# 2                                T162A  Aca/Gca      1
# 3                                 L236  ctA/ctG      1
# 4                                 S290  tcT/tcC      1
# ...                                ...      ...    ...    ...
# 333893                             nan              -1
# 333894                            R86Q  cGg/cAg      1
# 333895                            R86Q  cGg/cAg      1
# 333896                             nan              -1
# 333897                             nan              -1
#
#                       consequence
# 0              synonymous variant
# 1       regulatory region variant
# 2                missense variant
# 3              synonymous variant
# 4              synonymous variant
# ...                           ...
# 333893      upstream gene variant
# 333894           missense variant
# 333895           missense variant
# 333896      upstream gene variant
# 333897      upstream gene variant
#
# [333898 rows x 39 columns]

# %%
merged_vcf[merged_vcf['ID'] == 'rs6672356']
# Out:
#    Gene Name         ID CHROM     POS REF ALT    Zygosity  \
# 46    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 47    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 48    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 49    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 50    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 51    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 52    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 53    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 54    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 55    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 56    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 57    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 58    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 59    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 60    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 61    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 62    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 63    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 64    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
#
#                            Consequence    IMPACT ClinVar_CLNDN CLIN_SIG  \
# 46             downstream gene variant  MODIFIER  not provided   benign
# 47                    missense variant  MODERATE  not provided   benign
# 48                    missense variant  MODERATE  not provided   benign
# 49                    missense variant  MODERATE  not provided   benign
# 50  non coding transcript exon variant  MODIFIER  not provided   benign
# 51  non coding transcript exon variant  MODIFIER  not provided   benign
# 52  non coding transcript exon variant  MODIFIER  not provided   benign
# 53             downstream gene variant  MODIFIER  not provided   benign
# 54             downstream gene variant  MODIFIER  not provided   benign
# 55             downstream gene variant  MODIFIER  not provided   benign
# 56             downstream gene variant  MODIFIER  not provided   benign
# 57                    missense variant  MODERATE  not provided   benign
# 58                    missense variant  MODERATE  not provided   benign
# 59                    missense variant  MODERATE  not provided   benign
# 60                    missense variant  MODERATE  not provided   benign
# 61                    missense variant  MODERATE  not provided   benign
# 62                    missense variant  MODERATE  not provided   benign
# 63                    missense variant  MODERATE  not provided   benign
# 64           regulatory region variant  MODIFIER  not provided   benign
#
#                      ClinVar_CLNREVSTAT  ClinVar              HGVSc  \
# 46  criteria provided, single submitter  1166513
# 47  criteria provided, single submitter  1166513  ENST00000341065.8
# 48  criteria provided, single submitter  1166513  ENST00000342066.8
# 49  criteria provided, single submitter  1166513  ENST00000455979.1
# 50  criteria provided, single submitter  1166513  ENST00000464948.1
# 51  criteria provided, single submitter  1166513  ENST00000466827.1
# 52  criteria provided, single submitter  1166513  ENST00000474461.1
# 53  criteria provided, single submitter  1166513
# 54  criteria provided, single submitter  1166513
# 55  criteria provided, single submitter  1166513
# 56  criteria provided, single submitter  1166513
# 57  criteria provided, single submitter  1166513  ENST00000616016.5
# 58  criteria provided, single submitter  1166513  ENST00000616125.5
# 59  criteria provided, single submitter  1166513  ENST00000617307.5
# 60  criteria provided, single submitter  1166513  ENST00000618181.5
# 61  criteria provided, single submitter  1166513  ENST00000618323.5
# 62  criteria provided, single submitter  1166513  ENST00000618779.5
# 63  criteria provided, single submitter  1166513  ENST00000622503.5
# 64  criteria provided, single submitter  1166513
#
#    HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ SDP  DP  \
# 46               None                                  None  1/1  255  79  79
# 47           c.751T>C  ENSP00000349216.4        p.Trp251Arg  1/1  255  79  79
# 48          c.1027T>C  ENSP00000342313.3        p.Trp343Arg  1/1  255  79  79
# 49           c.508T>C  ENSP00000412228.1        p.Trp170Arg  1/1  255  79  79
# 50           n.286T>C                                  None  1/1  255  79  79
# 51           n.191T>C                                  None  1/1  255  79  79
# 52           n.389T>C                                  None  1/1  255  79  79
# 53               None                                  None  1/1  255  79  79
# 54               None                                  None  1/1  255  79  79
# 55               None                                  None  1/1  255  79  79
# 56               None                                  None  1/1  255  79  79
# 57          c.1516T>C  ENSP00000478421.2        p.Trp506Arg  1/1  255  79  79
# 58           c.703T>C  ENSP00000484643.1        p.Trp235Arg  1/1  255  79  79
# 59          c.1030T>C  ENSP00000482090.2        p.Trp344Arg  1/1  255  79  79
# 60           c.652T>C  ENSP00000480870.1        p.Trp218Arg  1/1  255  79  79
# 61          c.1519T>C  ENSP00000480678.2        p.Trp507Arg  1/1  255  79  79
# 62           c.841T>C  ENSP00000484256.1        p.Trp281Arg  1/1  255  79  79
# 63          c.1030T>C  ENSP00000482138.1        p.Trp344Arg  1/1  255  79  79
# 64               None                                  None  1/1  255  79  79
#
#    RD  AD  FREQ        PVAL RDF RDR ADF ADR                         SIFT  \
# 46  0  79  100%  4.3185e-47   0   0  38  41
# 47  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 48  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 49  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 50  0  79  100%  4.3185e-47   0   0  38  41
# 51  0  79  100%  4.3185e-47   0   0  38  41
# 52  0  79  100%  4.3185e-47   0   0  38  41
# 53  0  79  100%  4.3185e-47   0   0  38  41
# 54  0  79  100%  4.3185e-47   0   0  38  41
# 55  0  79  100%  4.3185e-47   0   0  38  41
# 56  0  79  100%  4.3185e-47   0   0  38  41
# 57  0  79  100%  4.3185e-47   0   0  38  41  tolerated low confidence(1)
# 58  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 59  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 60  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 61  0  79  100%  4.3185e-47   0   0  38  41  tolerated low confidence(1)
# 62  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 63  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 64  0  79  100%  4.3185e-47   0   0  38  41
#
#          PolyPhen                         BIOTYPE   EXON INTRON  \
# 46                                 protein coding
# 47      benign(0)                  protein coding   8/12
# 48      benign(0)                  protein coding  10/14
# 49      benign(0)                  protein coding    4/7
# 50                                retained intron    1/2
# 51                                retained intron    2/2
# 52                                retained intron    3/4
# 53                                retained intron
# 54                 protein coding CDS not defined
# 55                                retained intron
# 56                 protein coding CDS not defined
# 57      benign(0)                  protein coding  10/14
# 58  benign(0.001)                  protein coding   7/11
# 59      benign(0)                  protein coding   9/13
# 60      benign(0)                  protein coding   6/10
# 61      benign(0)                  protein coding  10/14
# 62      benign(0)                  protein coding   8/12
# 63      benign(0)                  protein coding   9/13
# 64                                       promoter
#
#    Protein Position and Amino Acid   Codons STRAND PUBMED  \
# 46                             nan              -1
# 47                           W251R  Tgg/Cgg      1
# 48                           W343R  Tgg/Cgg      1
# 49                           W170R  Tgg/Cgg      1
# 50                             nan               1
# 51                             nan               1
# 52                             nan               1
# 53                             nan              -1
# 54                             nan               1
# 55                             nan              -1
# 56                             nan              -1
# 57                           W506R  Tgg/Cgg      1
# 58                           W235R  Tgg/Cgg      1
# 59                           W344R  Tgg/Cgg      1
# 60                           W218R  Tgg/Cgg      1
# 61                           W507R  Tgg/Cgg      1
# 62                           W281R  Tgg/Cgg      1
# 63                           W344R  Tgg/Cgg      1
# 64                             nan
#
#                            consequence
# 46             downstream gene variant
# 47                    missense variant
# 48                    missense variant
# 49                    missense variant
# 50  non coding transcript exon variant
# 51  non coding transcript exon variant
# 52  non coding transcript exon variant
# 53             downstream gene variant
# 54             downstream gene variant
# 55             downstream gene variant
# 56             downstream gene variant
# 57                    missense variant
# 58                    missense variant
# 59                    missense variant
# 60                    missense variant
# 61                    missense variant
# 62                    missense variant
# 63                    missense variant
# 64           regulatory region variant

# %%
df_1 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Madhu_folder_04_07_2023/kidney_health_final.vcf/consequence.xlsx')
df_1
# Out:
#                             consequence Consequence_score
# 0                   transcript ablation             10/10
# 1               splice acceptor variant              8/10
# 2                  splice donor variant              8/10
# 3                           stop gained             10/10
# 4                    frameshift variant             10/10
# 5                             stop lost              9/10
# 6                            start lost              9/10
# 7              transcript amplification              8/10
# 8                     inframe insertion              6/10
# 9                      inframe deletion              6/10
# 10                     missense variant              7/10
# 11             protein altering variant              5/10
# 12                splice region variant              4/10
# 13        splice donor 5th base variant              4/10
# 14          splice donor region variant              4/10
# 15  splice polypyrimidine tract variant              4/10
# 16    incomplete terminal codon variant              3/10
# 17               start retained variant              3/10
# 18                stop retained variant              3/10
# 19                   synonymous variant              3/10
# 20              coding sequence variant              3/10
# 21                 mature miRNA variant              3/10
# 22                  5 prime UTR variant              3/10
# 23                  3 prime UTR variant              3/10
# 24   non coding transcript exon variant              2/10
# 25                       intron variant              2/10
# 26               NMD transcript variant              2/10
# 27        non coding transcript variant              2/10
# 28                upstream gene variant              2/10
# 29              downstream gene variant              2/10
# 30                        TFBS ablation              2/10
# 31                   TFBS amplification              2/10
# 32              TF binding site variant              2/10
# 33           regulatory region ablation              2/10
# 34      regulatory region amplification              2/10
# 35                   feature elongation              2/10
# 36            regulatory region variant              2/10
# 37                   feature truncation              1/10
# 38                   intergenic variant              1/10

# %%
merged_1 = pd.merge(merged_vcf, df_1, on='consequence', how='left', sort=False)
merged_1
# Out:
#        Gene Name            ID CHROM      POS REF ALT      Zygosity  \
# 0          OR4F5   rs201219564  chr1    69270   A   G  Heterozygous
# 1          OR4F5   rs201219564  chr1    69270   A   G  Heterozygous
# 2          OR4F5     rs2691305  chr1    69511   A   G    Homozygous
# 3          OR4F5  rs1245478362  chr1    69735   A   G  Heterozygous
# 4          OR4F5   rs200676709  chr1    69897   T   C  Heterozygous
# ...          ...           ...   ...      ...  ..  ..           ...
# 333893     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333894     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333895     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333896     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333897     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
#
#                       Consequence    IMPACT ClinVar_CLNDN CLIN_SIG  \
# 0              synonymous variant       LOW
# 1       regulatory region variant  MODIFIER
# 2                missense variant  MODERATE
# 3              synonymous variant       LOW
# 4              synonymous variant       LOW
# ...                           ...       ...           ...      ...
# 333893      upstream gene variant  MODIFIER
# 333894           missense variant  MODERATE
# 333895           missense variant  MODERATE
# 333896      upstream gene variant  MODIFIER
# 333897      upstream gene variant  MODIFIER
#
#        ClinVar_CLNREVSTAT ClinVar              HGVSc HGVSc (Transcript)  \
# 0                                  ENST00000641515.2           c.243A>G
# 1                                                                  None
# 2                                  ENST00000641515.2           c.484A>G
# 3                                  ENST00000641515.2           c.708A>G
# 4                                  ENST00000641515.2           c.870T>C
# ...                   ...     ...                ...                ...
# 333893                                                             None
# 333894                             ENST00000423647.6           c.257G>A
# 333895                             ENST00000451548.6           c.257G>A
# 333896                                                             None
# 333897                                                             None
#
#                     HGVSp HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD  \
# 0       ENSP00000493376.2         p.Ser81%3D  0/1  120  101  101   66   35
# 1                                       None  0/1  120  101  101   66   35
# 2       ENSP00000493376.2        p.Thr162Ala  1/1  255  143  143    0  143
# 3       ENSP00000493376.2        p.Leu236%3D  0/1  163  180  180  131   49
# 4       ENSP00000493376.2        p.Ser290%3D  0/1   75   96   96   73   23
# ...                   ...                ...  ...  ...  ...  ...  ...  ...
# 333893                                  None  0/1  255  383  383  273  110
# 333894  ENSP00000389324.3         p.Arg86Gln  0/1  255  383  383  273  110
# 333895  ENSP00000403304.1         p.Arg86Gln  0/1  255  383  383  273  110
# 333896                                  None  0/1  255  383  383  273  110
# 333897                                  None  0/1  255  383  383  273  110
#
#           FREQ                   PVAL  RDF  RDR  ADF ADR             SIFT  \
# 0       34.65%             8.1311e-13   48   18   24  11
# 1       34.65%             8.1311e-13   48   18   24  11
# 2         100%             1.7063e-85    0    0  100  43  tolerated(0.92)
# 3       27.22%             4.0111e-17   84   47   39  10
# 4       23.96%             2.6678e-08   30   43   13  10
# ...        ...                    ...  ...  ...  ...  ..              ...
# 333893  28.72%  7.984299999999999e-38  136  137   83  27
# 333894  28.72%  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333895  28.72%  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333896  28.72%  7.984299999999999e-38  136  137   83  27
# 333897  28.72%  7.984299999999999e-38  136  137   83  27
#
#              PolyPhen                             BIOTYPE EXON INTRON  \
# 0                                          protein coding  3/3
# 1                                         TF binding site
# 2           benign(0)                      protein coding  3/3
# 3                                          protein coding  3/3
# 4                                          protein coding  3/3
# ...               ...                                 ...  ...    ...
# 333893                 transcribed unprocessed pseudogene
# 333894  benign(0.375)                      protein coding  1/6
# 333895  benign(0.101)                      protein coding  1/6
# 333896                                             lncRNA
# 333897                                             lncRNA
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED  \
# 0                                  S81  tcA/tcG      1
# 1                                  nan
# 2                                T162A  Aca/Gca      1
# 3                                 L236  ctA/ctG      1
# 4                                 S290  tcT/tcC      1
# ...                                ...      ...    ...    ...
# 333893                             nan              -1
# 333894                            R86Q  cGg/cAg      1
# 333895                            R86Q  cGg/cAg      1
# 333896                             nan              -1
# 333897                             nan              -1
#
#                       consequence Consequence_score
# 0              synonymous variant              3/10
# 1       regulatory region variant              2/10
# 2                missense variant              7/10
# 3              synonymous variant              3/10
# 4              synonymous variant              3/10
# ...                           ...               ...
# 333893      upstream gene variant              2/10
# 333894           missense variant              7/10
# 333895           missense variant              7/10
# 333896      upstream gene variant              2/10
# 333897      upstream gene variant              2/10
#
# [333898 rows x 40 columns]

# %%
merged_1[merged_1['ID'] == 'rs6672356']
# Out:
#    Gene Name         ID CHROM     POS REF ALT    Zygosity  \
# 46    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 47    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 48    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 49    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 50    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 51    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 52    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 53    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 54    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 55    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 56    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 57    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 58    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 59    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 60    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 61    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 62    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 63    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 64    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
#
#                            Consequence    IMPACT ClinVar_CLNDN CLIN_SIG  \
# 46             downstream gene variant  MODIFIER  not provided   benign
# 47                    missense variant  MODERATE  not provided   benign
# 48                    missense variant  MODERATE  not provided   benign
# 49                    missense variant  MODERATE  not provided   benign
# 50  non coding transcript exon variant  MODIFIER  not provided   benign
# 51  non coding transcript exon variant  MODIFIER  not provided   benign
# 52  non coding transcript exon variant  MODIFIER  not provided   benign
# 53             downstream gene variant  MODIFIER  not provided   benign
# 54             downstream gene variant  MODIFIER  not provided   benign
# 55             downstream gene variant  MODIFIER  not provided   benign
# 56             downstream gene variant  MODIFIER  not provided   benign
# 57                    missense variant  MODERATE  not provided   benign
# 58                    missense variant  MODERATE  not provided   benign
# 59                    missense variant  MODERATE  not provided   benign
# 60                    missense variant  MODERATE  not provided   benign
# 61                    missense variant  MODERATE  not provided   benign
# 62                    missense variant  MODERATE  not provided   benign
# 63                    missense variant  MODERATE  not provided   benign
# 64           regulatory region variant  MODIFIER  not provided   benign
#
#                      ClinVar_CLNREVSTAT  ClinVar              HGVSc  \
# 46  criteria provided, single submitter  1166513
# 47  criteria provided, single submitter  1166513  ENST00000341065.8
# 48  criteria provided, single submitter  1166513  ENST00000342066.8
# 49  criteria provided, single submitter  1166513  ENST00000455979.1
# 50  criteria provided, single submitter  1166513  ENST00000464948.1
# 51  criteria provided, single submitter  1166513  ENST00000466827.1
# 52  criteria provided, single submitter  1166513  ENST00000474461.1
# 53  criteria provided, single submitter  1166513
# 54  criteria provided, single submitter  1166513
# 55  criteria provided, single submitter  1166513
# 56  criteria provided, single submitter  1166513
# 57  criteria provided, single submitter  1166513  ENST00000616016.5
# 58  criteria provided, single submitter  1166513  ENST00000616125.5
# 59  criteria provided, single submitter  1166513  ENST00000617307.5
# 60  criteria provided, single submitter  1166513  ENST00000618181.5
# 61  criteria provided, single submitter  1166513  ENST00000618323.5
# 62  criteria provided, single submitter  1166513  ENST00000618779.5
# 63  criteria provided, single submitter  1166513  ENST00000622503.5
# 64  criteria provided, single submitter  1166513
#
#    HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ SDP  DP  \
# 46               None                                  None  1/1  255  79  79
# 47           c.751T>C  ENSP00000349216.4        p.Trp251Arg  1/1  255  79  79
# 48          c.1027T>C  ENSP00000342313.3        p.Trp343Arg  1/1  255  79  79
# 49           c.508T>C  ENSP00000412228.1        p.Trp170Arg  1/1  255  79  79
# 50           n.286T>C                                  None  1/1  255  79  79
# 51           n.191T>C                                  None  1/1  255  79  79
# 52           n.389T>C                                  None  1/1  255  79  79
# 53               None                                  None  1/1  255  79  79
# 54               None                                  None  1/1  255  79  79
# 55               None                                  None  1/1  255  79  79
# 56               None                                  None  1/1  255  79  79
# 57          c.1516T>C  ENSP00000478421.2        p.Trp506Arg  1/1  255  79  79
# 58           c.703T>C  ENSP00000484643.1        p.Trp235Arg  1/1  255  79  79
# 59          c.1030T>C  ENSP00000482090.2        p.Trp344Arg  1/1  255  79  79
# 60           c.652T>C  ENSP00000480870.1        p.Trp218Arg  1/1  255  79  79
# 61          c.1519T>C  ENSP00000480678.2        p.Trp507Arg  1/1  255  79  79
# 62           c.841T>C  ENSP00000484256.1        p.Trp281Arg  1/1  255  79  79
# 63          c.1030T>C  ENSP00000482138.1        p.Trp344Arg  1/1  255  79  79
# 64               None                                  None  1/1  255  79  79
#
#    RD  AD  FREQ        PVAL RDF RDR ADF ADR                         SIFT  \
# 46  0  79  100%  4.3185e-47   0   0  38  41
# 47  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 48  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 49  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 50  0  79  100%  4.3185e-47   0   0  38  41
# 51  0  79  100%  4.3185e-47   0   0  38  41
# 52  0  79  100%  4.3185e-47   0   0  38  41
# 53  0  79  100%  4.3185e-47   0   0  38  41
# 54  0  79  100%  4.3185e-47   0   0  38  41
# 55  0  79  100%  4.3185e-47   0   0  38  41
# 56  0  79  100%  4.3185e-47   0   0  38  41
# 57  0  79  100%  4.3185e-47   0   0  38  41  tolerated low confidence(1)
# 58  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 59  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 60  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 61  0  79  100%  4.3185e-47   0   0  38  41  tolerated low confidence(1)
# 62  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 63  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 64  0  79  100%  4.3185e-47   0   0  38  41
#
#          PolyPhen                         BIOTYPE   EXON INTRON  \
# 46                                 protein coding
# 47      benign(0)                  protein coding   8/12
# 48      benign(0)                  protein coding  10/14
# 49      benign(0)                  protein coding    4/7
# 50                                retained intron    1/2
# 51                                retained intron    2/2
# 52                                retained intron    3/4
# 53                                retained intron
# 54                 protein coding CDS not defined
# 55                                retained intron
# 56                 protein coding CDS not defined
# 57      benign(0)                  protein coding  10/14
# 58  benign(0.001)                  protein coding   7/11
# 59      benign(0)                  protein coding   9/13
# 60      benign(0)                  protein coding   6/10
# 61      benign(0)                  protein coding  10/14
# 62      benign(0)                  protein coding   8/12
# 63      benign(0)                  protein coding   9/13
# 64                                       promoter
#
#    Protein Position and Amino Acid   Codons STRAND PUBMED  \
# 46                             nan              -1
# 47                           W251R  Tgg/Cgg      1
# 48                           W343R  Tgg/Cgg      1
# 49                           W170R  Tgg/Cgg      1
# 50                             nan               1
# 51                             nan               1
# 52                             nan               1
# 53                             nan              -1
# 54                             nan               1
# 55                             nan              -1
# 56                             nan              -1
# 57                           W506R  Tgg/Cgg      1
# 58                           W235R  Tgg/Cgg      1
# 59                           W344R  Tgg/Cgg      1
# 60                           W218R  Tgg/Cgg      1
# 61                           W507R  Tgg/Cgg      1
# 62                           W281R  Tgg/Cgg      1
# 63                           W344R  Tgg/Cgg      1
# 64                             nan
#
#                            consequence Consequence_score
# 46             downstream gene variant              2/10
# 47                    missense variant              7/10
# 48                    missense variant              7/10
# 49                    missense variant              7/10
# 50  non coding transcript exon variant              2/10
# 51  non coding transcript exon variant              2/10
# 52  non coding transcript exon variant              2/10
# 53             downstream gene variant              2/10
# 54             downstream gene variant              2/10
# 55             downstream gene variant              2/10
# 56             downstream gene variant              2/10
# 57                    missense variant              7/10
# 58                    missense variant              7/10
# 59                    missense variant              7/10
# 60                    missense variant              7/10
# 61                    missense variant              7/10
# 62                    missense variant              7/10
# 63                    missense variant              7/10
# 64           regulatory region variant              2/10

# %%
df_2 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Madhu_folder_04_07_2023/kidney_health_final.vcf/IMPACT.xlsx')
df_2
# Out:
#      IMPACT  IMPACT_score
# 0      HIGH          10.0
# 1  MODERATE           5.0
# 2       LOW           2.5
# 3  MODIFIER           1.5

# %%
merged_2 = pd.merge(merged_1, df_2, on = 'IMPACT', how='left', sort=False)
merged_2
# Out:
#        Gene Name            ID CHROM      POS REF ALT      Zygosity  \
# 0          OR4F5   rs201219564  chr1    69270   A   G  Heterozygous
# 1          OR4F5   rs201219564  chr1    69270   A   G  Heterozygous
# 2          OR4F5     rs2691305  chr1    69511   A   G    Homozygous
# 3          OR4F5  rs1245478362  chr1    69735   A   G  Heterozygous
# 4          OR4F5   rs200676709  chr1    69897   T   C  Heterozygous
# ...          ...           ...   ...      ...  ..  ..           ...
# 333893     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333894     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333895     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333896     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333897     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
#
#                       Consequence    IMPACT ClinVar_CLNDN CLIN_SIG  \
# 0              synonymous variant       LOW
# 1       regulatory region variant  MODIFIER
# 2                missense variant  MODERATE
# 3              synonymous variant       LOW
# 4              synonymous variant       LOW
# ...                           ...       ...           ...      ...
# 333893      upstream gene variant  MODIFIER
# 333894           missense variant  MODERATE
# 333895           missense variant  MODERATE
# 333896      upstream gene variant  MODIFIER
# 333897      upstream gene variant  MODIFIER
#
#        ClinVar_CLNREVSTAT ClinVar              HGVSc HGVSc (Transcript)  \
# 0                                  ENST00000641515.2           c.243A>G
# 1                                                                  None
# 2                                  ENST00000641515.2           c.484A>G
# 3                                  ENST00000641515.2           c.708A>G
# 4                                  ENST00000641515.2           c.870T>C
# ...                   ...     ...                ...                ...
# 333893                                                             None
# 333894                             ENST00000423647.6           c.257G>A
# 333895                             ENST00000451548.6           c.257G>A
# 333896                                                             None
# 333897                                                             None
#
#                     HGVSp HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD  \
# 0       ENSP00000493376.2         p.Ser81%3D  0/1  120  101  101   66   35
# 1                                       None  0/1  120  101  101   66   35
# 2       ENSP00000493376.2        p.Thr162Ala  1/1  255  143  143    0  143
# 3       ENSP00000493376.2        p.Leu236%3D  0/1  163  180  180  131   49
# 4       ENSP00000493376.2        p.Ser290%3D  0/1   75   96   96   73   23
# ...                   ...                ...  ...  ...  ...  ...  ...  ...
# 333893                                  None  0/1  255  383  383  273  110
# 333894  ENSP00000389324.3         p.Arg86Gln  0/1  255  383  383  273  110
# 333895  ENSP00000403304.1         p.Arg86Gln  0/1  255  383  383  273  110
# 333896                                  None  0/1  255  383  383  273  110
# 333897                                  None  0/1  255  383  383  273  110
#
#           FREQ                   PVAL  RDF  RDR  ADF ADR             SIFT  \
# 0       34.65%             8.1311e-13   48   18   24  11
# 1       34.65%             8.1311e-13   48   18   24  11
# 2         100%             1.7063e-85    0    0  100  43  tolerated(0.92)
# 3       27.22%             4.0111e-17   84   47   39  10
# 4       23.96%             2.6678e-08   30   43   13  10
# ...        ...                    ...  ...  ...  ...  ..              ...
# 333893  28.72%  7.984299999999999e-38  136  137   83  27
# 333894  28.72%  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333895  28.72%  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333896  28.72%  7.984299999999999e-38  136  137   83  27
# 333897  28.72%  7.984299999999999e-38  136  137   83  27
#
#              PolyPhen                             BIOTYPE EXON INTRON  \
# 0                                          protein coding  3/3
# 1                                         TF binding site
# 2           benign(0)                      protein coding  3/3
# 3                                          protein coding  3/3
# 4                                          protein coding  3/3
# ...               ...                                 ...  ...    ...
# 333893                 transcribed unprocessed pseudogene
# 333894  benign(0.375)                      protein coding  1/6
# 333895  benign(0.101)                      protein coding  1/6
# 333896                                             lncRNA
# 333897                                             lncRNA
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED  \
# 0                                  S81  tcA/tcG      1
# 1                                  nan
# 2                                T162A  Aca/Gca      1
# 3                                 L236  ctA/ctG      1
# 4                                 S290  tcT/tcC      1
# ...                                ...      ...    ...    ...
# 333893                             nan              -1
# 333894                            R86Q  cGg/cAg      1
# 333895                            R86Q  cGg/cAg      1
# 333896                             nan              -1
# 333897                             nan              -1
#
#                       consequence Consequence_score  IMPACT_score
# 0              synonymous variant              3/10           2.5
# 1       regulatory region variant              2/10           1.5
# 2                missense variant              7/10           5.0
# 3              synonymous variant              3/10           2.5
# 4              synonymous variant              3/10           2.5
# ...                           ...               ...           ...
# 333893      upstream gene variant              2/10           1.5
# 333894           missense variant              7/10           5.0
# 333895           missense variant              7/10           5.0
# 333896      upstream gene variant              2/10           1.5
# 333897      upstream gene variant              2/10           1.5
#
# [333898 rows x 41 columns]

# %%
merged_2[merged_2['ID'] == 'rs6672356']
# Out:
#    Gene Name         ID CHROM     POS REF ALT    Zygosity  \
# 46    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 47    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 48    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 49    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 50    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 51    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 52    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 53    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 54    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 55    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 56    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 57    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 58    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 59    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 60    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 61    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 62    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 63    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
# 64    SAMD11  rs6672356  chr1  942451   T   C  Homozygous
#
#                            Consequence    IMPACT ClinVar_CLNDN CLIN_SIG  \
# 46             downstream gene variant  MODIFIER  not provided   benign
# 47                    missense variant  MODERATE  not provided   benign
# 48                    missense variant  MODERATE  not provided   benign
# 49                    missense variant  MODERATE  not provided   benign
# 50  non coding transcript exon variant  MODIFIER  not provided   benign
# 51  non coding transcript exon variant  MODIFIER  not provided   benign
# 52  non coding transcript exon variant  MODIFIER  not provided   benign
# 53             downstream gene variant  MODIFIER  not provided   benign
# 54             downstream gene variant  MODIFIER  not provided   benign
# 55             downstream gene variant  MODIFIER  not provided   benign
# 56             downstream gene variant  MODIFIER  not provided   benign
# 57                    missense variant  MODERATE  not provided   benign
# 58                    missense variant  MODERATE  not provided   benign
# 59                    missense variant  MODERATE  not provided   benign
# 60                    missense variant  MODERATE  not provided   benign
# 61                    missense variant  MODERATE  not provided   benign
# 62                    missense variant  MODERATE  not provided   benign
# 63                    missense variant  MODERATE  not provided   benign
# 64           regulatory region variant  MODIFIER  not provided   benign
#
#                      ClinVar_CLNREVSTAT  ClinVar              HGVSc  \
# 46  criteria provided, single submitter  1166513
# 47  criteria provided, single submitter  1166513  ENST00000341065.8
# 48  criteria provided, single submitter  1166513  ENST00000342066.8
# 49  criteria provided, single submitter  1166513  ENST00000455979.1
# 50  criteria provided, single submitter  1166513  ENST00000464948.1
# 51  criteria provided, single submitter  1166513  ENST00000466827.1
# 52  criteria provided, single submitter  1166513  ENST00000474461.1
# 53  criteria provided, single submitter  1166513
# 54  criteria provided, single submitter  1166513
# 55  criteria provided, single submitter  1166513
# 56  criteria provided, single submitter  1166513
# 57  criteria provided, single submitter  1166513  ENST00000616016.5
# 58  criteria provided, single submitter  1166513  ENST00000616125.5
# 59  criteria provided, single submitter  1166513  ENST00000617307.5
# 60  criteria provided, single submitter  1166513  ENST00000618181.5
# 61  criteria provided, single submitter  1166513  ENST00000618323.5
# 62  criteria provided, single submitter  1166513  ENST00000618779.5
# 63  criteria provided, single submitter  1166513  ENST00000622503.5
# 64  criteria provided, single submitter  1166513
#
#    HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ SDP  DP  \
# 46               None                                  None  1/1  255  79  79
# 47           c.751T>C  ENSP00000349216.4        p.Trp251Arg  1/1  255  79  79
# 48          c.1027T>C  ENSP00000342313.3        p.Trp343Arg  1/1  255  79  79
# 49           c.508T>C  ENSP00000412228.1        p.Trp170Arg  1/1  255  79  79
# 50           n.286T>C                                  None  1/1  255  79  79
# 51           n.191T>C                                  None  1/1  255  79  79
# 52           n.389T>C                                  None  1/1  255  79  79
# 53               None                                  None  1/1  255  79  79
# 54               None                                  None  1/1  255  79  79
# 55               None                                  None  1/1  255  79  79
# 56               None                                  None  1/1  255  79  79
# 57          c.1516T>C  ENSP00000478421.2        p.Trp506Arg  1/1  255  79  79
# 58           c.703T>C  ENSP00000484643.1        p.Trp235Arg  1/1  255  79  79
# 59          c.1030T>C  ENSP00000482090.2        p.Trp344Arg  1/1  255  79  79
# 60           c.652T>C  ENSP00000480870.1        p.Trp218Arg  1/1  255  79  79
# 61          c.1519T>C  ENSP00000480678.2        p.Trp507Arg  1/1  255  79  79
# 62           c.841T>C  ENSP00000484256.1        p.Trp281Arg  1/1  255  79  79
# 63          c.1030T>C  ENSP00000482138.1        p.Trp344Arg  1/1  255  79  79
# 64               None                                  None  1/1  255  79  79
#
#    RD  AD  FREQ        PVAL RDF RDR ADF ADR                         SIFT  \
# 46  0  79  100%  4.3185e-47   0   0  38  41
# 47  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 48  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 49  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 50  0  79  100%  4.3185e-47   0   0  38  41
# 51  0  79  100%  4.3185e-47   0   0  38  41
# 52  0  79  100%  4.3185e-47   0   0  38  41
# 53  0  79  100%  4.3185e-47   0   0  38  41
# 54  0  79  100%  4.3185e-47   0   0  38  41
# 55  0  79  100%  4.3185e-47   0   0  38  41
# 56  0  79  100%  4.3185e-47   0   0  38  41
# 57  0  79  100%  4.3185e-47   0   0  38  41  tolerated low confidence(1)
# 58  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 59  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 60  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 61  0  79  100%  4.3185e-47   0   0  38  41  tolerated low confidence(1)
# 62  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 63  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 64  0  79  100%  4.3185e-47   0   0  38  41
#
#          PolyPhen                         BIOTYPE   EXON INTRON  \
# 46                                 protein coding
# 47      benign(0)                  protein coding   8/12
# 48      benign(0)                  protein coding  10/14
# 49      benign(0)                  protein coding    4/7
# 50                                retained intron    1/2
# 51                                retained intron    2/2
# 52                                retained intron    3/4
# 53                                retained intron
# 54                 protein coding CDS not defined
# 55                                retained intron
# 56                 protein coding CDS not defined
# 57      benign(0)                  protein coding  10/14
# 58  benign(0.001)                  protein coding   7/11
# 59      benign(0)                  protein coding   9/13
# 60      benign(0)                  protein coding   6/10
# 61      benign(0)                  protein coding  10/14
# 62      benign(0)                  protein coding   8/12
# 63      benign(0)                  protein coding   9/13
# 64                                       promoter
#
#    Protein Position and Amino Acid   Codons STRAND PUBMED  \
# 46                             nan              -1
# 47                           W251R  Tgg/Cgg      1
# 48                           W343R  Tgg/Cgg      1
# 49                           W170R  Tgg/Cgg      1
# 50                             nan               1
# 51                             nan               1
# 52                             nan               1
# 53                             nan              -1
# 54                             nan               1
# 55                             nan              -1
# 56                             nan              -1
# 57                           W506R  Tgg/Cgg      1
# 58                           W235R  Tgg/Cgg      1
# 59                           W344R  Tgg/Cgg      1
# 60                           W218R  Tgg/Cgg      1
# 61                           W507R  Tgg/Cgg      1
# 62                           W281R  Tgg/Cgg      1
# 63                           W344R  Tgg/Cgg      1
# 64                             nan
#
#                            consequence Consequence_score  IMPACT_score
# 46             downstream gene variant              2/10           1.5
# 47                    missense variant              7/10           5.0
# 48                    missense variant              7/10           5.0
# 49                    missense variant              7/10           5.0
# 50  non coding transcript exon variant              2/10           1.5
# 51  non coding transcript exon variant              2/10           1.5
# 52  non coding transcript exon variant              2/10           1.5
# 53             downstream gene variant              2/10           1.5
# 54             downstream gene variant              2/10           1.5
# 55             downstream gene variant              2/10           1.5
# 56             downstream gene variant              2/10           1.5
# 57                    missense variant              7/10           5.0
# 58                    missense variant              7/10           5.0
# 59                    missense variant              7/10           5.0
# 60                    missense variant              7/10           5.0
# 61                    missense variant              7/10           5.0
# 62                    missense variant              7/10           5.0
# 63                    missense variant              7/10           5.0
# 64           regulatory region variant              2/10           1.5

# %%
merged_2 = merged_2[['Gene Name', 'ID', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
       'Consequence','Consequence_score', 'IMPACT', 'IMPACT_score', 'ClinVar_CLNDN', 'CLIN_SIG',
       'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc', 'HGVSc (Transcript)', 'HGVSp',
       'HGVSp (Transcript)', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ',
       'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT', 'PolyPhen', 'BIOTYPE',
       'EXON', 'INTRON', 'Protein Position and Amino Acid', 'Codons', 'STRAND',
       'PUBMED']]
merged_2
# Out:
#        Gene Name            ID CHROM      POS REF ALT      Zygosity  \
# 0          OR4F5   rs201219564  chr1    69270   A   G  Heterozygous
# 1          OR4F5   rs201219564  chr1    69270   A   G  Heterozygous
# 2          OR4F5     rs2691305  chr1    69511   A   G    Homozygous
# 3          OR4F5  rs1245478362  chr1    69735   A   G  Heterozygous
# 4          OR4F5   rs200676709  chr1    69897   T   C  Heterozygous
# ...          ...           ...   ...      ...  ..  ..           ...
# 333893     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333894     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333895     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333896     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333897     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
#
#                       Consequence Consequence_score    IMPACT  IMPACT_score  \
# 0              synonymous variant              3/10       LOW           2.5
# 1       regulatory region variant              2/10  MODIFIER           1.5
# 2                missense variant              7/10  MODERATE           5.0
# 3              synonymous variant              3/10       LOW           2.5
# 4              synonymous variant              3/10       LOW           2.5
# ...                           ...               ...       ...           ...
# 333893      upstream gene variant              2/10  MODIFIER           1.5
# 333894           missense variant              7/10  MODERATE           5.0
# 333895           missense variant              7/10  MODERATE           5.0
# 333896      upstream gene variant              2/10  MODIFIER           1.5
# 333897      upstream gene variant              2/10  MODIFIER           1.5
#
#        ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar              HGVSc  \
# 0                                                         ENST00000641515.2
# 1
# 2                                                         ENST00000641515.2
# 3                                                         ENST00000641515.2
# 4                                                         ENST00000641515.2
# ...              ...      ...                ...     ...                ...
# 333893
# 333894                                                    ENST00000423647.6
# 333895                                                    ENST00000451548.6
# 333896
# 333897
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  \
# 0                c.243A>G  ENSP00000493376.2         p.Ser81%3D  0/1  120
# 1                    None                                  None  0/1  120
# 2                c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255
# 3                c.708A>G  ENSP00000493376.2        p.Leu236%3D  0/1  163
# 4                c.870T>C  ENSP00000493376.2        p.Ser290%3D  0/1   75
# ...                   ...                ...                ...  ...  ...
# 333893               None                                  None  0/1  255
# 333894           c.257G>A  ENSP00000389324.3         p.Arg86Gln  0/1  255
# 333895           c.257G>A  ENSP00000403304.1         p.Arg86Gln  0/1  255
# 333896               None                                  None  0/1  255
# 333897               None                                  None  0/1  255
#
#         SDP   DP   RD   AD    FREQ                   PVAL  RDF  RDR  ADF ADR  \
# 0       101  101   66   35  34.65%             8.1311e-13   48   18   24  11
# 1       101  101   66   35  34.65%             8.1311e-13   48   18   24  11
# 2       143  143    0  143    100%             1.7063e-85    0    0  100  43
# 3       180  180  131   49  27.22%             4.0111e-17   84   47   39  10
# 4        96   96   73   23  23.96%             2.6678e-08   30   43   13  10
# ...     ...  ...  ...  ...     ...                    ...  ...  ...  ...  ..
# 333893  383  383  273  110  28.72%  7.984299999999999e-38  136  137   83  27
# 333894  383  383  273  110  28.72%  7.984299999999999e-38  136  137   83  27
# 333895  383  383  273  110  28.72%  7.984299999999999e-38  136  137   83  27
# 333896  383  383  273  110  28.72%  7.984299999999999e-38  136  137   83  27
# 333897  383  383  273  110  28.72%  7.984299999999999e-38  136  137   83  27
#
#                    SIFT       PolyPhen                             BIOTYPE  \
# 0                                                           protein coding
# 1                                                          TF binding site
# 2       tolerated(0.92)      benign(0)                      protein coding
# 3                                                           protein coding
# 4                                                           protein coding
# ...                 ...            ...                                 ...
# 333893                                  transcribed unprocessed pseudogene
# 333894     tolerated(1)  benign(0.375)                      protein coding
# 333895     tolerated(1)  benign(0.101)                      protein coding
# 333896                                                              lncRNA
# 333897                                                              lncRNA
#
#        EXON INTRON Protein Position and Amino Acid   Codons STRAND PUBMED
# 0       3/3                                    S81  tcA/tcG      1
# 1                                              nan
# 2       3/3                                  T162A  Aca/Gca      1
# 3       3/3                                   L236  ctA/ctG      1
# 4       3/3                                   S290  tcT/tcC      1
# ...     ...    ...                             ...      ...    ...    ...
# 333893                                         nan              -1
# 333894  1/6                                   R86Q  cGg/cAg      1
# 333895  1/6                                   R86Q  cGg/cAg      1
# 333896                                         nan              -1
# 333897                                         nan              -1
#
# [333898 rows x 40 columns]

# %%
df_gene = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Vitiligo_genes.xlsx')
df_gene
# Out:
#    Gene Name
# 0     HLADR4
# 1     HLADR7
# 2     HLADQ7
# 3     HLADR1
# 4     HLAB13
# 5    HLADQW3
# 6     HLACW6
# 7     HLAA30
# 8       AIS1
# 9      FOXD3
# 10     NALP1
# 11    CXCL10
# 12     HLAA2
# 13    PTPN22
# 14       LPP

# %%
#merged_2 = pd.merge(merged_2, df_gene, on = 'Gene Name', how='left', sort=False)
#merged_2['Gene_Match_Condition'] = merged_2['Gene_Match_Condition'].fillna('No')
#merged_2

# %%
merged_2['Gene_Match'] = 'No'

# Iterate through each gene in df1
for genes in merged_2['Gene Name']:
    if isinstance(genes, str):  # Check if the gene value is a non-null string
        gene_list = genes.split(',')  # Split the genes by comma to create a list
        match = any(gene in df_gene['Gene Name'].values for gene in gene_list)  # Check if any gene in the list exists in df2
        if match:
            merged_2.loc[merged_2['Gene Name'] == genes, 'Gene_Match'] = 'Yes'
            
merged_2
# Out:
#        Gene Name            ID CHROM      POS REF ALT      Zygosity  \
# 0          OR4F5   rs201219564  chr1    69270   A   G  Heterozygous
# 1          OR4F5   rs201219564  chr1    69270   A   G  Heterozygous
# 2          OR4F5     rs2691305  chr1    69511   A   G    Homozygous
# 3          OR4F5  rs1245478362  chr1    69735   A   G  Heterozygous
# 4          OR4F5   rs200676709  chr1    69897   T   C  Heterozygous
# ...          ...           ...   ...      ...  ..  ..           ...
# 333893     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333894     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333895     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333896     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
# 333897     TSPY1   rs777840135  chrY  9467257   G   A  Heterozygous
#
#                       Consequence Consequence_score    IMPACT  IMPACT_score  \
# 0              synonymous variant              3/10       LOW           2.5
# 1       regulatory region variant              2/10  MODIFIER           1.5
# 2                missense variant              7/10  MODERATE           5.0
# 3              synonymous variant              3/10       LOW           2.5
# 4              synonymous variant              3/10       LOW           2.5
# ...                           ...               ...       ...           ...
# 333893      upstream gene variant              2/10  MODIFIER           1.5
# 333894           missense variant              7/10  MODERATE           5.0
# 333895           missense variant              7/10  MODERATE           5.0
# 333896      upstream gene variant              2/10  MODIFIER           1.5
# 333897      upstream gene variant              2/10  MODIFIER           1.5
#
#        ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar              HGVSc  \
# 0                                                         ENST00000641515.2
# 1
# 2                                                         ENST00000641515.2
# 3                                                         ENST00000641515.2
# 4                                                         ENST00000641515.2
# ...              ...      ...                ...     ...                ...
# 333893
# 333894                                                    ENST00000423647.6
# 333895                                                    ENST00000451548.6
# 333896
# 333897
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  \
# 0                c.243A>G  ENSP00000493376.2         p.Ser81%3D  0/1  120
# 1                    None                                  None  0/1  120
# 2                c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255
# 3                c.708A>G  ENSP00000493376.2        p.Leu236%3D  0/1  163
# 4                c.870T>C  ENSP00000493376.2        p.Ser290%3D  0/1   75
# ...                   ...                ...                ...  ...  ...
# 333893               None                                  None  0/1  255
# 333894           c.257G>A  ENSP00000389324.3         p.Arg86Gln  0/1  255
# 333895           c.257G>A  ENSP00000403304.1         p.Arg86Gln  0/1  255
# 333896               None                                  None  0/1  255
# 333897               None                                  None  0/1  255
#
#         SDP   DP   RD   AD    FREQ                   PVAL  RDF  RDR  ADF ADR  \
# 0       101  101   66   35  34.65%             8.1311e-13   48   18   24  11
# 1       101  101   66   35  34.65%             8.1311e-13   48   18   24  11
# 2       143  143    0  143    100%             1.7063e-85    0    0  100  43
# 3       180  180  131   49  27.22%             4.0111e-17   84   47   39  10
# 4        96   96   73   23  23.96%             2.6678e-08   30   43   13  10
# ...     ...  ...  ...  ...     ...                    ...  ...  ...  ...  ..
# 333893  383  383  273  110  28.72%  7.984299999999999e-38  136  137   83  27
# 333894  383  383  273  110  28.72%  7.984299999999999e-38  136  137   83  27
# 333895  383  383  273  110  28.72%  7.984299999999999e-38  136  137   83  27
# 333896  383  383  273  110  28.72%  7.984299999999999e-38  136  137   83  27
# 333897  383  383  273  110  28.72%  7.984299999999999e-38  136  137   83  27
#
#                    SIFT       PolyPhen                             BIOTYPE  \
# 0                                                           protein coding
# 1                                                          TF binding site
# 2       tolerated(0.92)      benign(0)                      protein coding
# 3                                                           protein coding
# 4                                                           protein coding
# ...                 ...            ...                                 ...
# 333893                                  transcribed unprocessed pseudogene
# 333894     tolerated(1)  benign(0.375)                      protein coding
# 333895     tolerated(1)  benign(0.101)                      protein coding
# 333896                                                              lncRNA
# 333897                                                              lncRNA
#
#        EXON INTRON Protein Position and Amino Acid   Codons STRAND PUBMED  \
# 0       3/3                                    S81  tcA/tcG      1
# 1                                              nan
# 2       3/3                                  T162A  Aca/Gca      1
# 3       3/3                                   L236  ctA/ctG      1
# 4       3/3                                   S290  tcT/tcC      1
# ...     ...    ...                             ...      ...    ...    ...
# 333893                                         nan              -1
# 333894  1/6                                   R86Q  cGg/cAg      1
# 333895  1/6                                   R86Q  cGg/cAg      1
# 333896                                         nan              -1
# 333897                                         nan              -1
#
#        Gene_Match
# 0              No
# 1              No
# 2              No
# 3              No
# 4              No
# ...           ...
# 333893         No
# 333894         No
# 333895         No
# 333896         No
# 333897         No
#
# [333898 rows x 41 columns]

# %%
merged_2.Gene_Match.value_counts()
# Out:
# No     333870
# Yes        28
# Name: Gene_Match, dtype: int64

# %%
merged_2.columns
# Out:
# Index(['Gene Name', 'ID', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
#        'Consequence', 'Consequence_score', 'IMPACT', 'IMPACT_score',
#        'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc',
#        'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP',
#        'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT',
#        'PolyPhen', 'BIOTYPE', 'EXON', 'INTRON',
#        'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED',
#        'Gene_Match'],
#       dtype='object')

# %%
merged_2 = merged_2[['Gene Name', 'Gene_Match', 'ID', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
       'Consequence', 'Consequence_score', 'IMPACT', 'IMPACT_score',
       'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc',
       'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP',
       'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT',
       'PolyPhen', 'BIOTYPE', 'EXON', 'INTRON',
       'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED']]
merged_2
# Out:
#        Gene Name Gene_Match            ID CHROM      POS REF ALT  \
# 0          OR4F5         No   rs201219564  chr1    69270   A   G
# 1          OR4F5         No   rs201219564  chr1    69270   A   G
# 2          OR4F5         No     rs2691305  chr1    69511   A   G
# 3          OR4F5         No  rs1245478362  chr1    69735   A   G
# 4          OR4F5         No   rs200676709  chr1    69897   T   C
# ...          ...        ...           ...   ...      ...  ..  ..
# 333893     TSPY1         No   rs777840135  chrY  9467257   G   A
# 333894     TSPY1         No   rs777840135  chrY  9467257   G   A
# 333895     TSPY1         No   rs777840135  chrY  9467257   G   A
# 333896     TSPY1         No   rs777840135  chrY  9467257   G   A
# 333897     TSPY1         No   rs777840135  chrY  9467257   G   A
#
#             Zygosity                Consequence Consequence_score    IMPACT  \
# 0       Heterozygous         synonymous variant              3/10       LOW
# 1       Heterozygous  regulatory region variant              2/10  MODIFIER
# 2         Homozygous           missense variant              7/10  MODERATE
# 3       Heterozygous         synonymous variant              3/10       LOW
# 4       Heterozygous         synonymous variant              3/10       LOW
# ...              ...                        ...               ...       ...
# 333893  Heterozygous      upstream gene variant              2/10  MODIFIER
# 333894  Heterozygous           missense variant              7/10  MODERATE
# 333895  Heterozygous           missense variant              7/10  MODERATE
# 333896  Heterozygous      upstream gene variant              2/10  MODIFIER
# 333897  Heterozygous      upstream gene variant              2/10  MODIFIER
#
#         IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar  \
# 0                2.5
# 1                1.5
# 2                5.0
# 3                2.5
# 4                2.5
# ...              ...           ...      ...                ...     ...
# 333893           1.5
# 333894           5.0
# 333895           5.0
# 333896           1.5
# 333897           1.5
#
#                     HGVSc HGVSc (Transcript)              HGVSp  \
# 0       ENST00000641515.2           c.243A>G  ENSP00000493376.2
# 1                                       None
# 2       ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 3       ENST00000641515.2           c.708A>G  ENSP00000493376.2
# 4       ENST00000641515.2           c.870T>C  ENSP00000493376.2
# ...                   ...                ...                ...
# 333893                                  None
# 333894  ENST00000423647.6           c.257G>A  ENSP00000389324.3
# 333895  ENST00000451548.6           c.257G>A  ENSP00000403304.1
# 333896                                  None
# 333897                                  None
#
#        HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD    FREQ  \
# 0              p.Ser81%3D  0/1  120  101  101   66   35  34.65%
# 1                    None  0/1  120  101  101   66   35  34.65%
# 2             p.Thr162Ala  1/1  255  143  143    0  143    100%
# 3             p.Leu236%3D  0/1  163  180  180  131   49  27.22%
# 4             p.Ser290%3D  0/1   75   96   96   73   23  23.96%
# ...                   ...  ...  ...  ...  ...  ...  ...     ...
# 333893               None  0/1  255  383  383  273  110  28.72%
# 333894         p.Arg86Gln  0/1  255  383  383  273  110  28.72%
# 333895         p.Arg86Gln  0/1  255  383  383  273  110  28.72%
# 333896               None  0/1  255  383  383  273  110  28.72%
# 333897               None  0/1  255  383  383  273  110  28.72%
#
#                          PVAL  RDF  RDR  ADF ADR             SIFT  \
# 0                  8.1311e-13   48   18   24  11
# 1                  8.1311e-13   48   18   24  11
# 2                  1.7063e-85    0    0  100  43  tolerated(0.92)
# 3                  4.0111e-17   84   47   39  10
# 4                  2.6678e-08   30   43   13  10
# ...                       ...  ...  ...  ...  ..              ...
# 333893  7.984299999999999e-38  136  137   83  27
# 333894  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333895  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333896  7.984299999999999e-38  136  137   83  27
# 333897  7.984299999999999e-38  136  137   83  27
#
#              PolyPhen                             BIOTYPE EXON INTRON  \
# 0                                          protein coding  3/3
# 1                                         TF binding site
# 2           benign(0)                      protein coding  3/3
# 3                                          protein coding  3/3
# 4                                          protein coding  3/3
# ...               ...                                 ...  ...    ...
# 333893                 transcribed unprocessed pseudogene
# 333894  benign(0.375)                      protein coding  1/6
# 333895  benign(0.101)                      protein coding  1/6
# 333896                                             lncRNA
# 333897                                             lncRNA
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED
# 0                                  S81  tcA/tcG      1
# 1                                  nan
# 2                                T162A  Aca/Gca      1
# 3                                 L236  ctA/ctG      1
# 4                                 S290  tcT/tcC      1
# ...                                ...      ...    ...    ...
# 333893                             nan              -1
# 333894                            R86Q  cGg/cAg      1
# 333895                            R86Q  cGg/cAg      1
# 333896                             nan              -1
# 333897                             nan              -1
#
# [333898 rows x 41 columns]

# %%
330219 - 329950
# Out:
# 269

# %%
df_3 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Condition_pos/Vitiligo_pos.xlsx')
df_3
# Out:
#          POS Literature
# 0  113834946        Yes
# 1  188371466        Yes
# 2  188394766        Yes
# 3  188396801        Yes
# 4  188406566        Yes

# %%
merged_3 = pd.merge(merged_2, df_3, on = 'POS', how = 'left', sort=False)
merged_3
# Out:
#        Gene Name Gene_Match            ID CHROM      POS REF ALT  \
# 0          OR4F5         No   rs201219564  chr1    69270   A   G
# 1          OR4F5         No   rs201219564  chr1    69270   A   G
# 2          OR4F5         No     rs2691305  chr1    69511   A   G
# 3          OR4F5         No  rs1245478362  chr1    69735   A   G
# 4          OR4F5         No   rs200676709  chr1    69897   T   C
# ...          ...        ...           ...   ...      ...  ..  ..
# 333893     TSPY1         No   rs777840135  chrY  9467257   G   A
# 333894     TSPY1         No   rs777840135  chrY  9467257   G   A
# 333895     TSPY1         No   rs777840135  chrY  9467257   G   A
# 333896     TSPY1         No   rs777840135  chrY  9467257   G   A
# 333897     TSPY1         No   rs777840135  chrY  9467257   G   A
#
#             Zygosity                Consequence Consequence_score    IMPACT  \
# 0       Heterozygous         synonymous variant              3/10       LOW
# 1       Heterozygous  regulatory region variant              2/10  MODIFIER
# 2         Homozygous           missense variant              7/10  MODERATE
# 3       Heterozygous         synonymous variant              3/10       LOW
# 4       Heterozygous         synonymous variant              3/10       LOW
# ...              ...                        ...               ...       ...
# 333893  Heterozygous      upstream gene variant              2/10  MODIFIER
# 333894  Heterozygous           missense variant              7/10  MODERATE
# 333895  Heterozygous           missense variant              7/10  MODERATE
# 333896  Heterozygous      upstream gene variant              2/10  MODIFIER
# 333897  Heterozygous      upstream gene variant              2/10  MODIFIER
#
#         IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar  \
# 0                2.5
# 1                1.5
# 2                5.0
# 3                2.5
# 4                2.5
# ...              ...           ...      ...                ...     ...
# 333893           1.5
# 333894           5.0
# 333895           5.0
# 333896           1.5
# 333897           1.5
#
#                     HGVSc HGVSc (Transcript)              HGVSp  \
# 0       ENST00000641515.2           c.243A>G  ENSP00000493376.2
# 1                                       None
# 2       ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 3       ENST00000641515.2           c.708A>G  ENSP00000493376.2
# 4       ENST00000641515.2           c.870T>C  ENSP00000493376.2
# ...                   ...                ...                ...
# 333893                                  None
# 333894  ENST00000423647.6           c.257G>A  ENSP00000389324.3
# 333895  ENST00000451548.6           c.257G>A  ENSP00000403304.1
# 333896                                  None
# 333897                                  None
#
#        HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD    FREQ  \
# 0              p.Ser81%3D  0/1  120  101  101   66   35  34.65%
# 1                    None  0/1  120  101  101   66   35  34.65%
# 2             p.Thr162Ala  1/1  255  143  143    0  143    100%
# 3             p.Leu236%3D  0/1  163  180  180  131   49  27.22%
# 4             p.Ser290%3D  0/1   75   96   96   73   23  23.96%
# ...                   ...  ...  ...  ...  ...  ...  ...     ...
# 333893               None  0/1  255  383  383  273  110  28.72%
# 333894         p.Arg86Gln  0/1  255  383  383  273  110  28.72%
# 333895         p.Arg86Gln  0/1  255  383  383  273  110  28.72%
# 333896               None  0/1  255  383  383  273  110  28.72%
# 333897               None  0/1  255  383  383  273  110  28.72%
#
#                          PVAL  RDF  RDR  ADF ADR             SIFT  \
# 0                  8.1311e-13   48   18   24  11
# 1                  8.1311e-13   48   18   24  11
# 2                  1.7063e-85    0    0  100  43  tolerated(0.92)
# 3                  4.0111e-17   84   47   39  10
# 4                  2.6678e-08   30   43   13  10
# ...                       ...  ...  ...  ...  ..              ...
# 333893  7.984299999999999e-38  136  137   83  27
# 333894  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333895  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333896  7.984299999999999e-38  136  137   83  27
# 333897  7.984299999999999e-38  136  137   83  27
#
#              PolyPhen                             BIOTYPE EXON INTRON  \
# 0                                          protein coding  3/3
# 1                                         TF binding site
# 2           benign(0)                      protein coding  3/3
# 3                                          protein coding  3/3
# 4                                          protein coding  3/3
# ...               ...                                 ...  ...    ...
# 333893                 transcribed unprocessed pseudogene
# 333894  benign(0.375)                      protein coding  1/6
# 333895  benign(0.101)                      protein coding  1/6
# 333896                                             lncRNA
# 333897                                             lncRNA
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED Literature
# 0                                  S81  tcA/tcG      1               NaN
# 1                                  nan                               NaN
# 2                                T162A  Aca/Gca      1               NaN
# 3                                 L236  ctA/ctG      1               NaN
# 4                                 S290  tcT/tcC      1               NaN
# ...                                ...      ...    ...    ...        ...
# 333893                             nan              -1               NaN
# 333894                            R86Q  cGg/cAg      1               NaN
# 333895                            R86Q  cGg/cAg      1               NaN
# 333896                             nan              -1               NaN
# 333897                             nan              -1               NaN
#
# [333898 rows x 42 columns]

# %%
merged_3['Literature'] = merged_3['Literature'].fillna('No')
merged_3
# Out:
#        Gene Name Gene_Match            ID CHROM      POS REF ALT  \
# 0          OR4F5         No   rs201219564  chr1    69270   A   G
# 1          OR4F5         No   rs201219564  chr1    69270   A   G
# 2          OR4F5         No     rs2691305  chr1    69511   A   G
# 3          OR4F5         No  rs1245478362  chr1    69735   A   G
# 4          OR4F5         No   rs200676709  chr1    69897   T   C
# ...          ...        ...           ...   ...      ...  ..  ..
# 333893     TSPY1         No   rs777840135  chrY  9467257   G   A
# 333894     TSPY1         No   rs777840135  chrY  9467257   G   A
# 333895     TSPY1         No   rs777840135  chrY  9467257   G   A
# 333896     TSPY1         No   rs777840135  chrY  9467257   G   A
# 333897     TSPY1         No   rs777840135  chrY  9467257   G   A
#
#             Zygosity                Consequence Consequence_score    IMPACT  \
# 0       Heterozygous         synonymous variant              3/10       LOW
# 1       Heterozygous  regulatory region variant              2/10  MODIFIER
# 2         Homozygous           missense variant              7/10  MODERATE
# 3       Heterozygous         synonymous variant              3/10       LOW
# 4       Heterozygous         synonymous variant              3/10       LOW
# ...              ...                        ...               ...       ...
# 333893  Heterozygous      upstream gene variant              2/10  MODIFIER
# 333894  Heterozygous           missense variant              7/10  MODERATE
# 333895  Heterozygous           missense variant              7/10  MODERATE
# 333896  Heterozygous      upstream gene variant              2/10  MODIFIER
# 333897  Heterozygous      upstream gene variant              2/10  MODIFIER
#
#         IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar  \
# 0                2.5
# 1                1.5
# 2                5.0
# 3                2.5
# 4                2.5
# ...              ...           ...      ...                ...     ...
# 333893           1.5
# 333894           5.0
# 333895           5.0
# 333896           1.5
# 333897           1.5
#
#                     HGVSc HGVSc (Transcript)              HGVSp  \
# 0       ENST00000641515.2           c.243A>G  ENSP00000493376.2
# 1                                       None
# 2       ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 3       ENST00000641515.2           c.708A>G  ENSP00000493376.2
# 4       ENST00000641515.2           c.870T>C  ENSP00000493376.2
# ...                   ...                ...                ...
# 333893                                  None
# 333894  ENST00000423647.6           c.257G>A  ENSP00000389324.3
# 333895  ENST00000451548.6           c.257G>A  ENSP00000403304.1
# 333896                                  None
# 333897                                  None
#
#        HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD    FREQ  \
# 0              p.Ser81%3D  0/1  120  101  101   66   35  34.65%
# 1                    None  0/1  120  101  101   66   35  34.65%
# 2             p.Thr162Ala  1/1  255  143  143    0  143    100%
# 3             p.Leu236%3D  0/1  163  180  180  131   49  27.22%
# 4             p.Ser290%3D  0/1   75   96   96   73   23  23.96%
# ...                   ...  ...  ...  ...  ...  ...  ...     ...
# 333893               None  0/1  255  383  383  273  110  28.72%
# 333894         p.Arg86Gln  0/1  255  383  383  273  110  28.72%
# 333895         p.Arg86Gln  0/1  255  383  383  273  110  28.72%
# 333896               None  0/1  255  383  383  273  110  28.72%
# 333897               None  0/1  255  383  383  273  110  28.72%
#
#                          PVAL  RDF  RDR  ADF ADR             SIFT  \
# 0                  8.1311e-13   48   18   24  11
# 1                  8.1311e-13   48   18   24  11
# 2                  1.7063e-85    0    0  100  43  tolerated(0.92)
# 3                  4.0111e-17   84   47   39  10
# 4                  2.6678e-08   30   43   13  10
# ...                       ...  ...  ...  ...  ..              ...
# 333893  7.984299999999999e-38  136  137   83  27
# 333894  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333895  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333896  7.984299999999999e-38  136  137   83  27
# 333897  7.984299999999999e-38  136  137   83  27
#
#              PolyPhen                             BIOTYPE EXON INTRON  \
# 0                                          protein coding  3/3
# 1                                         TF binding site
# 2           benign(0)                      protein coding  3/3
# 3                                          protein coding  3/3
# 4                                          protein coding  3/3
# ...               ...                                 ...  ...    ...
# 333893                 transcribed unprocessed pseudogene
# 333894  benign(0.375)                      protein coding  1/6
# 333895  benign(0.101)                      protein coding  1/6
# 333896                                             lncRNA
# 333897                                             lncRNA
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED Literature
# 0                                  S81  tcA/tcG      1                No
# 1                                  nan                                No
# 2                                T162A  Aca/Gca      1                No
# 3                                 L236  ctA/ctG      1                No
# 4                                 S290  tcT/tcC      1                No
# ...                                ...      ...    ...    ...        ...
# 333893                             nan              -1                No
# 333894                            R86Q  cGg/cAg      1                No
# 333895                            R86Q  cGg/cAg      1                No
# 333896                             nan              -1                No
# 333897                             nan              -1                No
#
# [333898 rows x 42 columns]

# %%
merged_3.Literature.value_counts()
# Out:
# No     333889
# Yes         9
# Name: Literature, dtype: int64

# %%
merged_3[merged_3['Literature'] == 'Yes']
# Out:
#               Gene Name Gene_Match         ID CHROM        POS REF ALT  \
# 16704  PTPN22,AP4B1-AS1        Yes  rs2476601  chr1  113834946   A   G
# 16705  PTPN22,AP4B1-AS1        Yes  rs2476601  chr1  113834946   A   G
# 16706  PTPN22,AP4B1-AS1        Yes  rs2476601  chr1  113834946   A   G
# 16707  PTPN22,AP4B1-AS1        Yes  rs2476601  chr1  113834946   A   G
# 16708  PTPN22,AP4B1-AS1        Yes  rs2476601  chr1  113834946   A   G
# 16709  PTPN22,AP4B1-AS1        Yes  rs2476601  chr1  113834946   A   G
# 16710  PTPN22,AP4B1-AS1        Yes  rs2476601  chr1  113834946   A   G
# 16711  PTPN22,AP4B1-AS1        Yes  rs2476601  chr1  113834946   A   G
# 16712  PTPN22,AP4B1-AS1        Yes  rs2476601  chr1  113834946   A   G
#
#          Zygosity                                   Consequence  \
# 16704  Homozygous                              missense variant
# 16705  Homozygous                              missense variant
# 16706  Homozygous                                intron variant
# 16707  Homozygous            non coding transcript exon variant
# 16708  Homozygous                              missense variant
# 16709  Homozygous                              missense variant
# 16710  Homozygous    3 prime UTR variant,NMD transcript variant
# 16711  Homozygous                              missense variant
# 16712  Homozygous  intron variant,non coding transcript variant
#
#       Consequence_score    IMPACT  IMPACT_score ClinVar_CLNDN  \
# 16704              7/10  MODERATE           5.0
# 16705              7/10  MODERATE           5.0
# 16706              2/10  MODIFIER           1.5
# 16707              2/10  MODIFIER           1.5
# 16708              7/10  MODERATE           5.0
# 16709              7/10  MODERATE           5.0
# 16710              3/10  MODIFIER           1.5
# 16711              7/10  MODERATE           5.0
# 16712              2/10  MODIFIER           1.5
#
#                  CLIN_SIG ClinVar_CLNREVSTAT ClinVar               HGVSc  \
# 16704  benign,risk factor                             ENST00000359785.10
# 16705  benign,risk factor                              ENST00000420377.6
# 16706  benign,risk factor                              ENST00000460620.5
# 16707  benign,risk factor                              ENST00000484147.5
# 16708  benign,risk factor                              ENST00000525799.1
# 16709  benign,risk factor                              ENST00000528414.5
# 16710  benign,risk factor                              ENST00000532224.5
# 16711  benign,risk factor                              ENST00000538253.5
# 16712  benign,risk factor                              ENST00000664434.1
#
#       HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT  GQ SDP  \
# 16704          c.1858T>C  ENSP00000352833.5        p.Trp620Arg  1/1  70  13
# 16705          c.1858T>C  ENSP00000388229.2        p.Trp620Arg  1/1  70  13
# 16706     c.469-15292T>C                                  None  1/1  70  13
# 16707          n.1899T>C                                  None  1/1  70  13
# 16708          c.1477T>C  ENSP00000432674.1        p.Trp493Arg  1/1  70  13
# 16709          c.1693T>C  ENSP00000435176.1        p.Trp565Arg  1/1  70  13
# 16710         c.*1136T>C                                  None  1/1  70  13
# 16711          c.1786T>C  ENSP00000439372.2        p.Trp596Arg  1/1  70  13
# 16712      n.470+3133A>G                                  None  1/1  70  13
#
#        DP RD  AD  FREQ        PVAL RDF RDR ADF ADR          SIFT   PolyPhen  \
# 16704  13  0  13  100%  9.6148e-08   0   0   9   4  tolerated(1)  benign(0)
# 16705  13  0  13  100%  9.6148e-08   0   0   9   4  tolerated(1)  benign(0)
# 16706  13  0  13  100%  9.6148e-08   0   0   9   4
# 16707  13  0  13  100%  9.6148e-08   0   0   9   4
# 16708  13  0  13  100%  9.6148e-08   0   0   9   4  tolerated(1)  benign(0)
# 16709  13  0  13  100%  9.6148e-08   0   0   9   4  tolerated(1)  benign(0)
# 16710  13  0  13  100%  9.6148e-08   0   0   9   4
# 16711  13  0  13  100%  9.6148e-08   0   0   9   4  tolerated(1)  benign(0)
# 16712  13  0  13  100%  9.6148e-08   0   0   9   4
#
#                        BIOTYPE   EXON INTRON Protein Position and Amino Acid  \
# 16704           protein coding  14/21                                  W620R
# 16705           protein coding  14/20                                  W620R
# 16706           protein coding           6/7                             nan
# 16707          retained intron  14/16                                    nan
# 16708           protein coding   9/15                                  W493R
# 16709           protein coding  12/19                                  W565R
# 16710  nonsense mediated decay  10/17                                    nan
# 16711           protein coding  13/20                                  W596R
# 16712                   lncRNA           4/5                             nan
#
#         Codons STRAND                                             PUBMED  \
# 16704  Tgg/Cgg     -1  18248681,30409984,20941391,27417569,20444268,2...
# 16705  Tgg/Cgg     -1  18248681,30409984,20941391,27417569,20444268,2...
# 16706              -1  18248681,30409984,20941391,27417569,20444268,2...
# 16707              -1  18248681,30409984,20941391,27417569,20444268,2...
# 16708  Tgg/Cgg     -1  18248681,30409984,20941391,27417569,20444268,2...
# 16709  Tgg/Cgg     -1  18248681,30409984,20941391,27417569,20444268,2...
# 16710              -1  18248681,30409984,20941391,27417569,20444268,2...
# 16711  Tgg/Cgg     -1  18248681,30409984,20941391,27417569,20444268,2...
# 16712               1  18248681,30409984,20941391,27417569,20444268,2...
#
#       Literature
# 16704        Yes
# 16705        Yes
# 16706        Yes
# 16707        Yes
# 16708        Yes
# 16709        Yes
# 16710        Yes
# 16711        Yes
# 16712        Yes

# %%
merged_3.columns
# Out:
# Index(['Gene Name', 'Gene_Match', 'ID', 'CHROM', 'POS', 'REF', 'ALT',
#        'Zygosity', 'Consequence', 'Consequence_score', 'IMPACT',
#        'IMPACT_score', 'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT',
#        'ClinVar', 'HGVSc', 'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)',
#        'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR',
#        'ADF', 'ADR', 'SIFT', 'PolyPhen', 'BIOTYPE', 'EXON', 'INTRON',
#        'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED',
#        'Literature'],
#       dtype='object')

# %%
merged_3 = merged_3[['Gene Name', 'Gene_Match', 'ID', 'CHROM', 'POS', 'Literature', 'REF', 'ALT', 'Zygosity',
       'Consequence','Consequence_score', 'IMPACT', 'IMPACT_score', 'ClinVar_CLNDN', 'CLIN_SIG',
       'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc', 'HGVSc (Transcript)', 'HGVSp',
       'HGVSp (Transcript)', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ',
       'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT', 'PolyPhen', 'BIOTYPE',
       'EXON', 'INTRON', 'Protein Position and Amino Acid', 'Codons', 'STRAND',
       'PUBMED']]
merged_3
# Out:
#        Gene Name Gene_Match            ID CHROM      POS Literature REF ALT  \
# 0          OR4F5         No   rs201219564  chr1    69270         No   A   G
# 1          OR4F5         No   rs201219564  chr1    69270         No   A   G
# 2          OR4F5         No     rs2691305  chr1    69511         No   A   G
# 3          OR4F5         No  rs1245478362  chr1    69735         No   A   G
# 4          OR4F5         No   rs200676709  chr1    69897         No   T   C
# ...          ...        ...           ...   ...      ...        ...  ..  ..
# 333893     TSPY1         No   rs777840135  chrY  9467257         No   G   A
# 333894     TSPY1         No   rs777840135  chrY  9467257         No   G   A
# 333895     TSPY1         No   rs777840135  chrY  9467257         No   G   A
# 333896     TSPY1         No   rs777840135  chrY  9467257         No   G   A
# 333897     TSPY1         No   rs777840135  chrY  9467257         No   G   A
#
#             Zygosity                Consequence Consequence_score    IMPACT  \
# 0       Heterozygous         synonymous variant              3/10       LOW
# 1       Heterozygous  regulatory region variant              2/10  MODIFIER
# 2         Homozygous           missense variant              7/10  MODERATE
# 3       Heterozygous         synonymous variant              3/10       LOW
# 4       Heterozygous         synonymous variant              3/10       LOW
# ...              ...                        ...               ...       ...
# 333893  Heterozygous      upstream gene variant              2/10  MODIFIER
# 333894  Heterozygous           missense variant              7/10  MODERATE
# 333895  Heterozygous           missense variant              7/10  MODERATE
# 333896  Heterozygous      upstream gene variant              2/10  MODIFIER
# 333897  Heterozygous      upstream gene variant              2/10  MODIFIER
#
#         IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar  \
# 0                2.5
# 1                1.5
# 2                5.0
# 3                2.5
# 4                2.5
# ...              ...           ...      ...                ...     ...
# 333893           1.5
# 333894           5.0
# 333895           5.0
# 333896           1.5
# 333897           1.5
#
#                     HGVSc HGVSc (Transcript)              HGVSp  \
# 0       ENST00000641515.2           c.243A>G  ENSP00000493376.2
# 1                                       None
# 2       ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 3       ENST00000641515.2           c.708A>G  ENSP00000493376.2
# 4       ENST00000641515.2           c.870T>C  ENSP00000493376.2
# ...                   ...                ...                ...
# 333893                                  None
# 333894  ENST00000423647.6           c.257G>A  ENSP00000389324.3
# 333895  ENST00000451548.6           c.257G>A  ENSP00000403304.1
# 333896                                  None
# 333897                                  None
#
#        HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD    FREQ  \
# 0              p.Ser81%3D  0/1  120  101  101   66   35  34.65%
# 1                    None  0/1  120  101  101   66   35  34.65%
# 2             p.Thr162Ala  1/1  255  143  143    0  143    100%
# 3             p.Leu236%3D  0/1  163  180  180  131   49  27.22%
# 4             p.Ser290%3D  0/1   75   96   96   73   23  23.96%
# ...                   ...  ...  ...  ...  ...  ...  ...     ...
# 333893               None  0/1  255  383  383  273  110  28.72%
# 333894         p.Arg86Gln  0/1  255  383  383  273  110  28.72%
# 333895         p.Arg86Gln  0/1  255  383  383  273  110  28.72%
# 333896               None  0/1  255  383  383  273  110  28.72%
# 333897               None  0/1  255  383  383  273  110  28.72%
#
#                          PVAL  RDF  RDR  ADF ADR             SIFT  \
# 0                  8.1311e-13   48   18   24  11
# 1                  8.1311e-13   48   18   24  11
# 2                  1.7063e-85    0    0  100  43  tolerated(0.92)
# 3                  4.0111e-17   84   47   39  10
# 4                  2.6678e-08   30   43   13  10
# ...                       ...  ...  ...  ...  ..              ...
# 333893  7.984299999999999e-38  136  137   83  27
# 333894  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333895  7.984299999999999e-38  136  137   83  27     tolerated(1)
# 333896  7.984299999999999e-38  136  137   83  27
# 333897  7.984299999999999e-38  136  137   83  27
#
#              PolyPhen                             BIOTYPE EXON INTRON  \
# 0                                          protein coding  3/3
# 1                                         TF binding site
# 2           benign(0)                      protein coding  3/3
# 3                                          protein coding  3/3
# 4                                          protein coding  3/3
# ...               ...                                 ...  ...    ...
# 333893                 transcribed unprocessed pseudogene
# 333894  benign(0.375)                      protein coding  1/6
# 333895  benign(0.101)                      protein coding  1/6
# 333896                                             lncRNA
# 333897                                             lncRNA
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED
# 0                                  S81  tcA/tcG      1
# 1                                  nan
# 2                                T162A  Aca/Gca      1
# 3                                 L236  ctA/ctG      1
# 4                                 S290  tcT/tcC      1
# ...                                ...      ...    ...    ...
# 333893                             nan              -1
# 333894                            R86Q  cGg/cAg      1
# 333895                            R86Q  cGg/cAg      1
# 333896                             nan              -1
# 333897                             nan              -1
#
# [333898 rows x 42 columns]

# %%
merged_3[merged_3['ID'] == 'rs6672356']
# Out:
#    Gene Name Gene_Match         ID CHROM     POS Literature REF ALT  \
# 46    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 47    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 48    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 49    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 50    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 51    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 52    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 53    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 54    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 55    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 56    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 57    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 58    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 59    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 60    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 61    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 62    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 63    SAMD11         No  rs6672356  chr1  942451         No   T   C
# 64    SAMD11         No  rs6672356  chr1  942451         No   T   C
#
#       Zygosity                         Consequence Consequence_score  \
# 46  Homozygous             downstream gene variant              2/10
# 47  Homozygous                    missense variant              7/10
# 48  Homozygous                    missense variant              7/10
# 49  Homozygous                    missense variant              7/10
# 50  Homozygous  non coding transcript exon variant              2/10
# 51  Homozygous  non coding transcript exon variant              2/10
# 52  Homozygous  non coding transcript exon variant              2/10
# 53  Homozygous             downstream gene variant              2/10
# 54  Homozygous             downstream gene variant              2/10
# 55  Homozygous             downstream gene variant              2/10
# 56  Homozygous             downstream gene variant              2/10
# 57  Homozygous                    missense variant              7/10
# 58  Homozygous                    missense variant              7/10
# 59  Homozygous                    missense variant              7/10
# 60  Homozygous                    missense variant              7/10
# 61  Homozygous                    missense variant              7/10
# 62  Homozygous                    missense variant              7/10
# 63  Homozygous                    missense variant              7/10
# 64  Homozygous           regulatory region variant              2/10
#
#       IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG  \
# 46  MODIFIER           1.5  not provided   benign
# 47  MODERATE           5.0  not provided   benign
# 48  MODERATE           5.0  not provided   benign
# 49  MODERATE           5.0  not provided   benign
# 50  MODIFIER           1.5  not provided   benign
# 51  MODIFIER           1.5  not provided   benign
# 52  MODIFIER           1.5  not provided   benign
# 53  MODIFIER           1.5  not provided   benign
# 54  MODIFIER           1.5  not provided   benign
# 55  MODIFIER           1.5  not provided   benign
# 56  MODIFIER           1.5  not provided   benign
# 57  MODERATE           5.0  not provided   benign
# 58  MODERATE           5.0  not provided   benign
# 59  MODERATE           5.0  not provided   benign
# 60  MODERATE           5.0  not provided   benign
# 61  MODERATE           5.0  not provided   benign
# 62  MODERATE           5.0  not provided   benign
# 63  MODERATE           5.0  not provided   benign
# 64  MODIFIER           1.5  not provided   benign
#
#                      ClinVar_CLNREVSTAT  ClinVar              HGVSc  \
# 46  criteria provided, single submitter  1166513
# 47  criteria provided, single submitter  1166513  ENST00000341065.8
# 48  criteria provided, single submitter  1166513  ENST00000342066.8
# 49  criteria provided, single submitter  1166513  ENST00000455979.1
# 50  criteria provided, single submitter  1166513  ENST00000464948.1
# 51  criteria provided, single submitter  1166513  ENST00000466827.1
# 52  criteria provided, single submitter  1166513  ENST00000474461.1
# 53  criteria provided, single submitter  1166513
# 54  criteria provided, single submitter  1166513
# 55  criteria provided, single submitter  1166513
# 56  criteria provided, single submitter  1166513
# 57  criteria provided, single submitter  1166513  ENST00000616016.5
# 58  criteria provided, single submitter  1166513  ENST00000616125.5
# 59  criteria provided, single submitter  1166513  ENST00000617307.5
# 60  criteria provided, single submitter  1166513  ENST00000618181.5
# 61  criteria provided, single submitter  1166513  ENST00000618323.5
# 62  criteria provided, single submitter  1166513  ENST00000618779.5
# 63  criteria provided, single submitter  1166513  ENST00000622503.5
# 64  criteria provided, single submitter  1166513
#
#    HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ SDP  DP  \
# 46               None                                  None  1/1  255  79  79
# 47           c.751T>C  ENSP00000349216.4        p.Trp251Arg  1/1  255  79  79
# 48          c.1027T>C  ENSP00000342313.3        p.Trp343Arg  1/1  255  79  79
# 49           c.508T>C  ENSP00000412228.1        p.Trp170Arg  1/1  255  79  79
# 50           n.286T>C                                  None  1/1  255  79  79
# 51           n.191T>C                                  None  1/1  255  79  79
# 52           n.389T>C                                  None  1/1  255  79  79
# 53               None                                  None  1/1  255  79  79
# 54               None                                  None  1/1  255  79  79
# 55               None                                  None  1/1  255  79  79
# 56               None                                  None  1/1  255  79  79
# 57          c.1516T>C  ENSP00000478421.2        p.Trp506Arg  1/1  255  79  79
# 58           c.703T>C  ENSP00000484643.1        p.Trp235Arg  1/1  255  79  79
# 59          c.1030T>C  ENSP00000482090.2        p.Trp344Arg  1/1  255  79  79
# 60           c.652T>C  ENSP00000480870.1        p.Trp218Arg  1/1  255  79  79
# 61          c.1519T>C  ENSP00000480678.2        p.Trp507Arg  1/1  255  79  79
# 62           c.841T>C  ENSP00000484256.1        p.Trp281Arg  1/1  255  79  79
# 63          c.1030T>C  ENSP00000482138.1        p.Trp344Arg  1/1  255  79  79
# 64               None                                  None  1/1  255  79  79
#
#    RD  AD  FREQ        PVAL RDF RDR ADF ADR                         SIFT  \
# 46  0  79  100%  4.3185e-47   0   0  38  41
# 47  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 48  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 49  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 50  0  79  100%  4.3185e-47   0   0  38  41
# 51  0  79  100%  4.3185e-47   0   0  38  41
# 52  0  79  100%  4.3185e-47   0   0  38  41
# 53  0  79  100%  4.3185e-47   0   0  38  41
# 54  0  79  100%  4.3185e-47   0   0  38  41
# 55  0  79  100%  4.3185e-47   0   0  38  41
# 56  0  79  100%  4.3185e-47   0   0  38  41
# 57  0  79  100%  4.3185e-47   0   0  38  41  tolerated low confidence(1)
# 58  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 59  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 60  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 61  0  79  100%  4.3185e-47   0   0  38  41  tolerated low confidence(1)
# 62  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 63  0  79  100%  4.3185e-47   0   0  38  41                 tolerated(1)
# 64  0  79  100%  4.3185e-47   0   0  38  41
#
#          PolyPhen                         BIOTYPE   EXON INTRON  \
# 46                                 protein coding
# 47      benign(0)                  protein coding   8/12
# 48      benign(0)                  protein coding  10/14
# 49      benign(0)                  protein coding    4/7
# 50                                retained intron    1/2
# 51                                retained intron    2/2
# 52                                retained intron    3/4
# 53                                retained intron
# 54                 protein coding CDS not defined
# 55                                retained intron
# 56                 protein coding CDS not defined
# 57      benign(0)                  protein coding  10/14
# 58  benign(0.001)                  protein coding   7/11
# 59      benign(0)                  protein coding   9/13
# 60      benign(0)                  protein coding   6/10
# 61      benign(0)                  protein coding  10/14
# 62      benign(0)                  protein coding   8/12
# 63      benign(0)                  protein coding   9/13
# 64                                       promoter
#
#    Protein Position and Amino Acid   Codons STRAND PUBMED
# 46                             nan              -1
# 47                           W251R  Tgg/Cgg      1
# 48                           W343R  Tgg/Cgg      1
# 49                           W170R  Tgg/Cgg      1
# 50                             nan               1
# 51                             nan               1
# 52                             nan               1
# 53                             nan              -1
# 54                             nan               1
# 55                             nan              -1
# 56                             nan              -1
# 57                           W506R  Tgg/Cgg      1
# 58                           W235R  Tgg/Cgg      1
# 59                           W344R  Tgg/Cgg      1
# 60                           W218R  Tgg/Cgg      1
# 61                           W507R  Tgg/Cgg      1
# 62                           W281R  Tgg/Cgg      1
# 63                           W344R  Tgg/Cgg      1
# 64                             nan

# %%
merged_3.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Processed_vcf_files/KHGLBS535_depth_vcf_processed.xlsx', index=False)

# %% [markdown]
# # InDel Analysis

# %%
indel = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/cdpr_and_csps_all_files/KHCDPRGPTTL5/KHCDPRGPTTL5_indel_clinical_significance.xlsx')
indel = indel.rename({'gene_name' : 'Gene Name'}, axis=1)
indel
# Out:
#              allele      zygocity Gene Name         rsid  \
# 0    ['AAGAGAG', A]  Heterozygous     TRPS1   rs10546472
# 1    ['AAGAGAG', A]  Heterozygous     TRPS1   rs10546472
# 2      ['ACCTT', A]  Heterozygous  ADAMTS17   rs10549565
# 3       ['ATCC', A]  Heterozygous     KIF1A   rs10594016
# 4       ['ATCC', A]  Heterozygous     KIF1A   rs10594016
# ..              ...           ...       ...          ...
# 578    ['AACTT', A]  Heterozygous     PLCB1   rs78940282
# 579       ['AT', A]  Heterozygous     ATCAY  rs796133913
# 580       ['AT', A]  Heterozygous     ATCAY  rs796133913
# 581       ['GT', G]  Heterozygous     CD2AP  rs797004904
# 582       ['TA', T]  Heterozygous     BRCA1    rs8176144
#
#                          consequence  \
# 0                5_prime_UTR_variant
# 1                5_prime_UTR_variant
# 2                3_prime_UTR_variant
# 3    inframe_insertion', 'SO:0001627
# 4     inframe_deletion', 'SO:0001627
# ..                               ...
# 578              3_prime_UTR_variant
# 579              3_prime_UTR_variant
# 580              3_prime_UTR_variant
# 581              3_prime_UTR_variant
# 582                   intron_variant
#
#                             clinical_significance  \
# 0                          Uncertain_significance
# 1                          Uncertain_significance
# 2                                          Benign
# 3    Conflicting_interpretations_of_pathogenicity
# 4                                          Benign
# ..                                            ...
# 578                                 Likely_benign
# 579                                        Benign
# 580                        Uncertain_significance
# 581                                        Benign
# 582                                        Benign
#
#                                    associated_diseases  \
# 0                       Trichorhinophalangeal_syndrome
# 1                       Trichorhinophalangeal_syndrome
# 2    Weill-Marchesani_4_syndrome', '_recessive|not_...
# 3    Hereditary_spastic_paraplegia_30|not_specified...
# 4                           not_specified|not_provided
# ..                                                 ...
# 578  Early_Infantile_Epileptic_Encephalopathy', '_A...
# 579                      Cayman_type_cerebellar_ataxia
# 580                      Cayman_type_cerebellar_ataxia
# 581                 Focal_segmental_glomerulosclerosis
# 582  Hereditary_breast_ovarian_cancer_syndrome|Brea...
#
#                                          review_status    origin variant_type  \
# 0               criteria_provided', '_single_submitter  germline        indel
# 1               criteria_provided', '_single_submitter  germline        indel
# 2    criteria_provided', '_multiple_submitters', '_...  germline        indel
# 3    criteria_provided', '_conflicting_interpretations  germline        indel
# 4    criteria_provided', '_multiple_submitters', '_...  germline        indel
# ..                                                 ...       ...          ...
# 578             criteria_provided', '_single_submitter  germline        indel
# 579             criteria_provided', '_single_submitter  germline        indel
# 580             criteria_provided', '_single_submitter  germline        indel
# 581             criteria_provided', '_single_submitter  germline        indel
# 582                           reviewed_by_expert_panel  germline        indel
#
#     variant_subtype Phargkb_ann_exists is_mutation Variant_is_precious
# 0         Insertion           MayBe No          No                  No
# 1          Deletion           MayBe No          No                  No
# 2          Deletion           MayBe No          No                  No
# 3         Insertion           MayBe No          No                 Yes
# 4          Deletion           MayBe No          No                 Yes
# ..              ...                ...         ...                 ...
# 578        Deletion           MayBe No          No                  No
# 579        Deletion           MayBe No          No                  No
# 580        Deletion           MayBe No          No                  No
# 581        Deletion           MayBe No          No                  No
# 582        Deletion           MayBe No          No                 Yes
#
# [583 rows x 14 columns]

# %%
df_gene = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/cardiac genes.xlsx')
df_gene
# Out:
#    Gene Name
# 0       LDLR
# 1   LDLR-AS1
# 2       NOS3
# 3     PRKAG2
# 4       LRP6
# ..       ...
# 75      TRDN
# 76   LDLRAP1
# 77     PCSK9
# 78      APOB
# 79     STAP1
#
# [80 rows x 1 columns]

# %%
indel['Gene_Match'] = 'No'

# Iterate through each gene in df1
for genes in indel['Gene Name']:
    if isinstance(genes, str):  # Check if the gene value is a non-null string
        gene_list = genes.split(',')  # Split the genes by comma to create a list
        match = any(gene in df_gene['Gene Name'].values for gene in gene_list)  # Check if any gene in the list exists in df2
        if match:
            indel.loc[indel['Gene Name'] == genes, 'Gene_Match'] = 'Yes'
            
indel
# Out:
#              allele      zygocity Gene Name         rsid  \
# 0    ['AAGAGAG', A]  Heterozygous     TRPS1   rs10546472
# 1    ['AAGAGAG', A]  Heterozygous     TRPS1   rs10546472
# 2      ['ACCTT', A]  Heterozygous  ADAMTS17   rs10549565
# 3       ['ATCC', A]  Heterozygous     KIF1A   rs10594016
# 4       ['ATCC', A]  Heterozygous     KIF1A   rs10594016
# ..              ...           ...       ...          ...
# 578    ['AACTT', A]  Heterozygous     PLCB1   rs78940282
# 579       ['AT', A]  Heterozygous     ATCAY  rs796133913
# 580       ['AT', A]  Heterozygous     ATCAY  rs796133913
# 581       ['GT', G]  Heterozygous     CD2AP  rs797004904
# 582       ['TA', T]  Heterozygous     BRCA1    rs8176144
#
#                          consequence  \
# 0                5_prime_UTR_variant
# 1                5_prime_UTR_variant
# 2                3_prime_UTR_variant
# 3    inframe_insertion', 'SO:0001627
# 4     inframe_deletion', 'SO:0001627
# ..                               ...
# 578              3_prime_UTR_variant
# 579              3_prime_UTR_variant
# 580              3_prime_UTR_variant
# 581              3_prime_UTR_variant
# 582                   intron_variant
#
#                             clinical_significance  \
# 0                          Uncertain_significance
# 1                          Uncertain_significance
# 2                                          Benign
# 3    Conflicting_interpretations_of_pathogenicity
# 4                                          Benign
# ..                                            ...
# 578                                 Likely_benign
# 579                                        Benign
# 580                        Uncertain_significance
# 581                                        Benign
# 582                                        Benign
#
#                                    associated_diseases  \
# 0                       Trichorhinophalangeal_syndrome
# 1                       Trichorhinophalangeal_syndrome
# 2    Weill-Marchesani_4_syndrome', '_recessive|not_...
# 3    Hereditary_spastic_paraplegia_30|not_specified...
# 4                           not_specified|not_provided
# ..                                                 ...
# 578  Early_Infantile_Epileptic_Encephalopathy', '_A...
# 579                      Cayman_type_cerebellar_ataxia
# 580                      Cayman_type_cerebellar_ataxia
# 581                 Focal_segmental_glomerulosclerosis
# 582  Hereditary_breast_ovarian_cancer_syndrome|Brea...
#
#                                          review_status    origin variant_type  \
# 0               criteria_provided', '_single_submitter  germline        indel
# 1               criteria_provided', '_single_submitter  germline        indel
# 2    criteria_provided', '_multiple_submitters', '_...  germline        indel
# 3    criteria_provided', '_conflicting_interpretations  germline        indel
# 4    criteria_provided', '_multiple_submitters', '_...  germline        indel
# ..                                                 ...       ...          ...
# 578             criteria_provided', '_single_submitter  germline        indel
# 579             criteria_provided', '_single_submitter  germline        indel
# 580             criteria_provided', '_single_submitter  germline        indel
# 581             criteria_provided', '_single_submitter  germline        indel
# 582                           reviewed_by_expert_panel  germline        indel
#
#     variant_subtype Phargkb_ann_exists is_mutation Variant_is_precious  \
# 0         Insertion           MayBe No          No                  No
# 1          Deletion           MayBe No          No                  No
# 2          Deletion           MayBe No          No                  No
# 3         Insertion           MayBe No          No                 Yes
# 4          Deletion           MayBe No          No                 Yes
# ..              ...                ...         ...                 ...
# 578        Deletion           MayBe No          No                  No
# 579        Deletion           MayBe No          No                  No
# 580        Deletion           MayBe No          No                  No
# 581        Deletion           MayBe No          No                  No
# 582        Deletion           MayBe No          No                 Yes
#
#     Gene_Match
# 0           No
# 1           No
# 2           No
# 3           No
# 4           No
# ..         ...
# 578         No
# 579         No
# 580         No
# 581         No
# 582         No
#
# [583 rows x 15 columns]

# %%
indel.Gene_Match.value_counts()
# Out:
# No     556
# Yes     27
# Name: Gene_Match, dtype: int64

# %% [markdown]
# ## InDel Analysis

# %%
data = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/KHCDPRGPTTL6_annotated_indel.vcf', comment='#', sep= '\t', header=None, low_memory=False)
data.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
data
# Out:
#      CHROM        POS                      rsID     REF ALT QUAL FILTER  \
# 0     chr1    1043223                rs35881187     CCT   C    .   PASS
# 1     chr1    1299382               rs143128930      AG   A    .   PASS
# 2     chr1    1353987               rs140777846     CTG   C    .   PASS
# 3     chr1    1398672     rs368050244;rs3831366  CTAGAG   C    .   PASS
# 4     chr1    1629572               rs112177324      TG   T    .   PASS
# ...    ...        ...                       ...     ...  ..  ...    ...
# 2606  chrX  153913005      rs5904376;rs77485258       G  GC    .   PASS
# 2607  chrX  155228363               rs781912204       A  AT    .   PASS
# 2608  chrX  155492733  rs1169019545;rs376271737       T  TG    .   PASS
# 2609  chrY   12786501               rs760255651      CT   C    .   PASS
# 2610  chrY   21311242               rs202147921       A  AT    .   PASS
#
#                                                    INFO  \
# 0     ADP=29;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.5208,0....
# 1     ADP=65;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8806,0....
# 2     ADP=76;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.1793,0....
# 3     ADP=60;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.925...
# 4     ADP=21;WT=0;HET=1;HOM=0;NC=0;ASP;G5;GENEINFO=M...
# ...                                                 ...
# 2606  ADP=63;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.0002649...
# 2607  ADP=25;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=VBP1...
# 2608  ADP=17;WT=0;HET=0;HOM=1;NC=0;ASP;GENEINFO=TMLH...
# 2609  ADP=21;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=USP9...
# 2610  ADP=18;WT=0;HET=0;HOM=1;NC=0;ASP;RS=202147921;...
#
#                                                  FORMAT  \
# 0     GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1     GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2     GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3     GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4     GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# ...                                                 ...
# 2606  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2607  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2608  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2609  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2610  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                  SAMPLE
# 0     1/1:150:29:29:1:28:96.55%:9.9776E-16:32:21:1:0...
# 1     0/1:109:65:65:35:30:46.15%:1.1519E-11:55:57:27...
# 2     0/1:151:76:76:36:40:52.63%:7.6319E-16:58:56:28...
# 3     0/1:131:60:60:26:34:56.67%:7.4725E-14:57:50:21...
# 4     0/1:50:22:21:9:13:59.09%:9.5813E-6:57:56:9:0:11:2
# ...                                                 ...
# 2606  1/1:255:63:63:2:61:96.83%:3.4466E-34:74:55:2:0...
# 2607     0/1:64:25:25:5:15:60%:3.8543E-7:64:55:5:0:14:1
# 2608  1/1:81:17:17:1:16:94.12%:7.7134E-9:35:55:0:1:11:5
# 2609  0/1:50:21:21:4:12:57.14%:8.0605E-6:42:49:3:1:10:2
# 2610  1/1:71:18:18:2:15:83.33%:7.3277E-8:74:65:2:0:13:2
#
# [2611 rows x 10 columns]

# %%
sample_cols = data['SAMPLE'].str.split(':', expand=True)
sample_cols.columns = ['GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RBQ', 'ABQ', 'RDF', 'RDR', 'ADF', 'ADR']

# Assign the values to the newly created columns
data = pd.concat([data, sample_cols], axis=1)
data = data[['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL','RDF', 'RDR', 'ADF', 'ADR']]
data
# Out:
#      CHROM        POS                      rsID     REF ALT QUAL FILTER  \
# 0     chr1    1043223                rs35881187     CCT   C    .   PASS
# 1     chr1    1299382               rs143128930      AG   A    .   PASS
# 2     chr1    1353987               rs140777846     CTG   C    .   PASS
# 3     chr1    1398672     rs368050244;rs3831366  CTAGAG   C    .   PASS
# 4     chr1    1629572               rs112177324      TG   T    .   PASS
# ...    ...        ...                       ...     ...  ..  ...    ...
# 2606  chrX  153913005      rs5904376;rs77485258       G  GC    .   PASS
# 2607  chrX  155228363               rs781912204       A  AT    .   PASS
# 2608  chrX  155492733  rs1169019545;rs376271737       T  TG    .   PASS
# 2609  chrY   12786501               rs760255651      CT   C    .   PASS
# 2610  chrY   21311242               rs202147921       A  AT    .   PASS
#
#                                                    INFO   GT   GQ SDP  DP  RD  \
# 0     ADP=29;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.5208,0....  1/1  150  29  29   1
# 1     ADP=65;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8806,0....  0/1  109  65  65  35
# 2     ADP=76;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.1793,0....  0/1  151  76  76  36
# 3     ADP=60;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.925...  0/1  131  60  60  26
# 4     ADP=21;WT=0;HET=1;HOM=0;NC=0;ASP;G5;GENEINFO=M...  0/1   50  22  21   9
# ...                                                 ...  ...  ...  ..  ..  ..
# 2606  ADP=63;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.0002649...  1/1  255  63  63   2
# 2607  ADP=25;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=VBP1...  0/1   64  25  25   5
# 2608  ADP=17;WT=0;HET=0;HOM=1;NC=0;ASP;GENEINFO=TMLH...  1/1   81  17  17   1
# 2609  ADP=21;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=USP9...  0/1   50  21  21   4
# 2610  ADP=18;WT=0;HET=0;HOM=1;NC=0;ASP;RS=202147921;...  1/1   71  18  18   2
#
#       AD    FREQ        PVAL RDF RDR ADF ADR
# 0     28  96.55%  9.9776E-16   1   0  25   3
# 1     30  46.15%  1.1519E-11  27   8  26   4
# 2     40  52.63%  7.6319E-16  28   8  34   6
# 3     34  56.67%  7.4725E-14  21   5  26   8
# 4     13  59.09%   9.5813E-6   9   0  11   2
# ...   ..     ...         ...  ..  ..  ..  ..
# 2606  61  96.83%  3.4466E-34   2   0  50  11
# 2607  15     60%   3.8543E-7   5   0  14   1
# 2608  16  94.12%   7.7134E-9   0   1  11   5
# 2609  12  57.14%   8.0605E-6   3   1  10   2
# 2610  15  83.33%   7.3277E-8   2   0  13   2
#
# [2611 rows x 20 columns]

# %%
data.INFO.iloc[0]
# Out:
# 'ADP=29;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.5208,0.4792;COMMON=1;G5;GENEINFO=AGRN:375790;GNO;INT;KGPhase1;KGPhase3;PM;PMC;RS=35881187;RSPOS=1043224;RV;SAO=0;SLO;SSR=0;TOPMED=0.55968081039755351,0.44031918960244648;VC=DIV;VLD;VP=0x05012808000515013e000200;WGT=1;dbSNPBuildID=126'

# %%
# Create empty columns
columns = ['ADP', 'WT', 'HET', 'HOM', 'NC', 'CDA', 'OTH', 'S3D', 'WTD', 'dbSNPBuildID', 'SLO',
           'NSF', 'R3', 'R5', 'NSN', 'NSM', 'G5A', 'COMMON', 'RS', 'RV', 'TPA', 'CFL', 'GNO',
           'VLD', 'ASP', 'ASS', 'Ref', 'U3', 'U5', 'TOPMED', 'WGT', 'MTP', 'LSD', 'NOC',
           'DSS', 'SYN', 'KGPhase3', 'CAF', 'VC', 'MUT', 'KGPhase1', 'NOV', 'VP', 'SAO',
           'GENEINFO', 'INT', 'G5', 'OM', 'PMC', 'SSR', 'RSPOS', 'HD', 'PM', 'ClinVar',
           'ClinVar_CLNSIG']

for col in columns:
    data[col] = ''

# Populate columns based on 'info' values
for i, row in data.iterrows():
    info = row['INFO']
    items = info.split(';')
    for item in items:
        key_value = item.split('=')
        key = key_value[0]
        if key in columns:
            if len(key_value) > 1:
                value = key_value[1]
                data.at[i, key] = f"{key}={value}"
            else:
                data.at[i, key] = key
        else:
            data.at[i, key] = 'null'


            
data["Gene_Name"] = data["INFO"].str.extract('GENEINFO=(?P<GENEINFO>.+?);')
data['Gene Name'] = data['Gene_Name'].apply(lambda x: ','.join([segment.split(':')[0] for segment in x.split('|')]) if pd.notnull(x) else '')

# Print the resulting DataFrame
data
# Out:
#      CHROM        POS                      rsID     REF ALT QUAL FILTER  \
# 0     chr1    1043223                rs35881187     CCT   C    .   PASS
# 1     chr1    1299382               rs143128930      AG   A    .   PASS
# 2     chr1    1353987               rs140777846     CTG   C    .   PASS
# 3     chr1    1398672     rs368050244;rs3831366  CTAGAG   C    .   PASS
# 4     chr1    1629572               rs112177324    null   T    .   PASS
# ...    ...        ...                       ...     ...  ..  ...    ...
# 2606  chrX  153913005      rs5904376;rs77485258       G  GC    .   PASS
# 2607  chrX  155228363               rs781912204       A  AT    .   PASS
# 2608  chrX  155492733  rs1169019545;rs376271737       T  TG    .   PASS
# 2609  chrY   12786501               rs760255651      CT   C    .   PASS
# 2610  chrY   21311242               rs202147921       A  AT    .   PASS
#
#                                                    INFO   GT   GQ SDP  DP  RD  \
# 0     ADP=29;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.5208,0....  1/1  150  29  29   1
# 1     ADP=65;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8806,0....  0/1  109  65  65  35
# 2     ADP=76;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.1793,0....  0/1  151  76  76  36
# 3     ADP=60;WT=0;HET=1;HOM=0;NC=0;ASP;ASS;CAF=0.925...  0/1  131  60  60  26
# 4     ADP=21;WT=0;HET=1;HOM=0;NC=0;ASP;G5;GENEINFO=M...  0/1   50  22  21   9
# ...                                                 ...  ...  ...  ..  ..  ..
# 2606  ADP=63;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.0002649...  1/1  255  63  63   2
# 2607  ADP=25;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=VBP1...  0/1   64  25  25   5
# 2608  ADP=17;WT=0;HET=0;HOM=1;NC=0;ASP;GENEINFO=TMLH...  1/1   81  17  17   1
# 2609  ADP=21;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=USP9...  0/1   50  21  21   4
# 2610  ADP=18;WT=0;HET=0;HOM=1;NC=0;ASP;RS=202147921;...  1/1   71  18  18   2
#
#       AD    FREQ        PVAL RDF RDR ADF ADR     ADP    WT    HET    HOM  \
# 0     28  96.55%  9.9776E-16   1   0  25   3  ADP=29  WT=0  HET=0  HOM=1
# 1     30  46.15%  1.1519E-11  27   8  26   4  ADP=65  WT=0  HET=1  HOM=0
# 2     40  52.63%  7.6319E-16  28   8  34   6  ADP=76  WT=0  HET=1  HOM=0
# 3     34  56.67%  7.4725E-14  21   5  26   8  ADP=60  WT=0  HET=1  HOM=0
# 4     13  59.09%   9.5813E-6   9   0  11   2  ADP=21  WT=0  HET=1  HOM=0
# ...   ..     ...         ...  ..  ..  ..  ..     ...   ...    ...    ...
# 2606  61  96.83%  3.4466E-34   2   0  50  11  ADP=63  WT=0  HET=0  HOM=1
# 2607  15     60%   3.8543E-7   5   0  14   1  ADP=25  WT=0  HET=1  HOM=0
# 2608  16  94.12%   7.7134E-9   0   1  11   5  ADP=17  WT=0  HET=0  HOM=1
# 2609  12  57.14%   8.0605E-6   3   1  10   2  ADP=21  WT=0  HET=1  HOM=0
# 2610  15  83.33%   7.3277E-8   2   0  13   2  ADP=18  WT=0  HET=0  HOM=1
#
#         NC CDA OTH S3D WTD          dbSNPBuildID  SLO  NSF R3  R5 NSN NSM  \
# 0     NC=0                      dbSNPBuildID=126  SLO
# 1     NC=0                      dbSNPBuildID=134               R5
# 2     NC=0                      dbSNPBuildID=134  SLO
# 3     NC=0                  dbSNPBuildID=107,138  SLO          R5
# 4     NC=0                      dbSNPBuildID=132  SLO  NSF
# ...    ...  ..  ..  ..  ..                   ...  ...  ... ..  ..  ..  ..
# 2606  NC=0                  dbSNPBuildID=131,126  SLO
# 2607  NC=0                      dbSNPBuildID=144
# 2608  NC=0                  dbSNPBuildID=151,138
# 2609  NC=0                      dbSNPBuildID=144
# 2610  NC=0                      dbSNPBuildID=137
#
#       G5A      COMMON                       RS  RV TPA CFL  GNO  VLD  ASP  \
# 0            COMMON=1              RS=35881187  RV          GNO  VLD  ASP
# 1            COMMON=1             RS=143128930                   VLD  ASP
# 2     G5A    COMMON=1             RS=140777846              GNO  VLD  ASP
# 3          COMMON=1,1     RS=3831366,368050244              GNO  VLD  ASP
# 4                                 RS=112177324              GNO  VLD  ASP
# ...   ...         ...                      ...  ..  ..  ..  ...  ...  ...
# 2606       COMMON=0,0      RS=77485258,5904376              GNO       ASP
# 2607                              RS=781912204                        ASP
# 2608                   RS=1169019545,376271737                        ASP
# 2609                              RS=760255651                        ASP
# 2610                              RS=202147921                        ASP
#
#       ASS Ref U3 U5                                             TOPMED  \
# 0                       TOPMED=0.55968081039755351,0.44031918960244648
# 1                       TOPMED=0.91126720183486238,0.08873279816513761
# 2                       TOPMED=0.13763857033639143,0.86236142966360856
# 3     ASS               TOPMED=0.94513729612640163,0.05486270387359836
# 4                       TOPMED=0.75031058868501529,0.24968941131498470
# ...   ...  .. .. ..                                                ...
# 2606                    TOPMED=0.01672400611620795,0.98327599388379204
# 2607                 TOPMED=0.43169438073394495,0.56314506880733944...
# 2608                    TOPMED=0.35031218144750254,0.64968781855249745
# 2609
# 2610
#
#           WGT MTP LSD NOC DSS SYN  KGPhase3  \
# 0       WGT=1                      KGPhase3
# 1       WGT=1                      KGPhase3
# 2       WGT=1                      KGPhase3
# 3     WGT=1,1                      KGPhase3
# 4       WGT=1                      KGPhase3
# ...       ...  ..  ..  ..  ..  ..       ...
# 2606  WGT=1,1                      KGPhase3
# 2607    WGT=1
# 2608  WGT=1,1
# 2609    WGT=1
# 2610    WGT=1
#
#                                         CAF          VC MUT  KGPhase1  NOV  \
# 0                         CAF=0.5208,0.4792      VC=DIV      KGPhase1
# 1                         CAF=0.8806,0.1194      VC=DIV      KGPhase1
# 2                         CAF=0.1793,0.8207      VC=DIV
# 3         CAF=0.9259,0.07408,0.9259,0.07408  VC=DIV,DIV      KGPhase1
# 4                                                VC=DIV      KGPhase1
# ...                                     ...         ...  ..       ...  ...
# 2606  CAF=0.0002649,0.9997,0.0002649,0.9997  VC=DIV,DIV      KGPhase1
# 2607                                             VC=DIV                NOV
# 2608                                         VC=DIV,DIV
# 2609                                             VC=DIV
# 2610                                             VC=DIV
#
#                                                      VP      SAO  \
# 0                         VP=0x05012808000515013e000200    SAO=0
# 1                         VP=0x0500000a000515003e000200    SAO=0
# 2                         VP=0x050100080005170126000200    SAO=0
# 3     VP=0x05012822000515013e000200,0x0500000a000500...  SAO=0,0
# 4                         VP=0x05010008120515013e000200    SAO=0
# ...                                                 ...      ...
# 2606  VP=0x05000008000501003e000200,0x05010008000500...  SAO=0,0
# 2607                      VP=0x050000080005000002000204    SAO=0
# 2608  VP=0x050000080005000002000200,0x05000008000500...  SAO=0,0
# 2609                      VP=0x050000080005000002000200    SAO=0
# 2610                      VP=0x050000000005000002000200    SAO=0
#
#                                                GENEINFO  INT  G5 OM  PMC  \
# 0                                  GENEINFO=AGRN:375790  INT  G5     PMC
# 1                                 GENEINFO=ACAP3:116983  INT  G5
# 2                                  GENEINFO=MXRA8:54587  INT  G5
# 3     GENEINFO=LOC148413:148413|CCNL2:81669,LOC14841...  INT  G5     PMC
# 4                                  GENEINFO=MIB2:142678  INT  G5
# ...                                                 ...  ...  .. ..  ...
# 2606                   GENEINFO=ARHGAP4:393,ARHGAP4:393  INT  G5
# 2607                                 GENEINFO=VBP1:7411  INT
# 2608  GENEINFO=TMLHE:55217|TMLHE-AS1:100507404,TMLHE...  INT
# 2609                                GENEINFO=USP9Y:8287  INT
# 2610
#
#           SSR                      RSPOS HD  PM ClinVar ClinVar_CLNSIG  \
# 0       SSR=0              RSPOS=1043224     PM
# 1       SSR=0              RSPOS=1299383
# 2       SSR=0              RSPOS=1353988
# 3     SSR=0,0      RSPOS=1398673,1398677     PM
# 4       SSR=0              RSPOS=1629573
# ...       ...                        ... ..  ..     ...            ...
# 2606  SSR=0,0  RSPOS=153913005,153913008
# 2607    SSR=0            RSPOS=155228363
# 2608  SSR=0,0  RSPOS=155492733,155492734
# 2609    SSR=0             RSPOS=12786503
# 2610    SSR=0             RSPOS=21311242
#
#                                               Gene_Name  \
# 0                                           AGRN:375790
# 1                                          ACAP3:116983
# 2                                           MXRA8:54587
# 3     LOC148413:148413|CCNL2:81669,LOC148413:148413|...
# 4                                           MIB2:142678
# ...                                                 ...
# 2606                            ARHGAP4:393,ARHGAP4:393
# 2607                                          VBP1:7411
# 2608  TMLHE:55217|TMLHE-AS1:100507404,TMLHE:55217|TM...
# 2609                                         USP9Y:8287
# 2610                                                NaN
#
#                       Gene Name
# 0                          AGRN
# 1                         ACAP3
# 2                         MXRA8
# 3         LOC148413,CCNL2,CCNL2
# 4                          MIB2
# ...                         ...
# 2606                    ARHGAP4
# 2607                       VBP1
# 2608  TMLHE,TMLHE-AS1,TMLHE-AS1
# 2609                      USP9Y
# 2610
#
# [2611 rows x 77 columns]

# %%
data.columns
# Out:
# Index(['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'GT',
#        'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF',
#        'ADR', 'ADP', 'WT', 'HET', 'HOM', 'NC', 'CDA', 'OTH', 'S3D', 'WTD',
#        'dbSNPBuildID', 'SLO', 'NSF', 'R3', 'R5', 'NSN', 'NSM', 'G5A', 'COMMON',
#        'RS', 'RV', 'TPA', 'CFL', 'GNO', 'VLD', 'ASP', 'ASS', 'Ref', 'U3', 'U5',
#        'TOPMED', 'WGT', 'MTP', 'LSD', 'NOC', 'DSS', 'SYN', 'KGPhase3', 'CAF',
#        'VC', 'MUT', 'KGPhase1', 'NOV', 'VP', 'SAO', 'GENEINFO', 'INT', 'G5',
#        'OM', 'PMC', 'SSR', 'RSPOS', 'HD', 'PM', 'ClinVar', 'ClinVar_CLNSIG',
#        'Gene_Name', 'Gene Name'],
#       dtype='object')

# %%
data = data[['CHROM', 'POS', 'Gene Name', 'rsID', 'REF', 'ALT', 'GT',
       'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF',
       'ADR', 'ADP', 'WT', 'HET', 'HOM', 'NC', 'CDA', 'OTH', 'S3D', 'WTD',
       'dbSNPBuildID', 'SLO', 'NSF', 'R3', 'R5', 'NSN', 'NSM', 'G5A', 'COMMON',
       'RS', 'RV', 'TPA', 'CFL', 'GNO', 'VLD', 'ASP', 'ASS', 'Ref', 'U3', 'U5',
       'TOPMED', 'WGT', 'MTP', 'LSD', 'NOC', 'DSS', 'SYN', 'KGPhase3', 'CAF',
       'VC', 'MUT', 'KGPhase1', 'NOV', 'VP', 'SAO', 'INT', 'G5',
       'OM', 'PMC', 'SSR', 'RSPOS', 'HD', 'PM', 'ClinVar', 'ClinVar_CLNSIG']]
data
# Out:
#      CHROM        POS                  Gene Name                      rsID  \
# 0     chr1    1043223                       AGRN                rs35881187
# 1     chr1    1299382                      ACAP3               rs143128930
# 2     chr1    1353987                      MXRA8               rs140777846
# 3     chr1    1398672      LOC148413,CCNL2,CCNL2     rs368050244;rs3831366
# 4     chr1    1629572                       MIB2               rs112177324
# ...    ...        ...                        ...                       ...
# 2606  chrX  153913005                    ARHGAP4      rs5904376;rs77485258
# 2607  chrX  155228363                       VBP1               rs781912204
# 2608  chrX  155492733  TMLHE,TMLHE-AS1,TMLHE-AS1  rs1169019545;rs376271737
# 2609  chrY   12786501                      USP9Y               rs760255651
# 2610  chrY   21311242                                          rs202147921
#
#          REF ALT   GT   GQ SDP  DP  RD  AD    FREQ        PVAL RDF RDR ADF  \
# 0        CCT   C  1/1  150  29  29   1  28  96.55%  9.9776E-16   1   0  25
# 1         AG   A  0/1  109  65  65  35  30  46.15%  1.1519E-11  27   8  26
# 2        CTG   C  0/1  151  76  76  36  40  52.63%  7.6319E-16  28   8  34
# 3     CTAGAG   C  0/1  131  60  60  26  34  56.67%  7.4725E-14  21   5  26
# 4       null   T  0/1   50  22  21   9  13  59.09%   9.5813E-6   9   0  11
# ...      ...  ..  ...  ...  ..  ..  ..  ..     ...         ...  ..  ..  ..
# 2606       G  GC  1/1  255  63  63   2  61  96.83%  3.4466E-34   2   0  50
# 2607       A  AT  0/1   64  25  25   5  15     60%   3.8543E-7   5   0  14
# 2608       T  TG  1/1   81  17  17   1  16  94.12%   7.7134E-9   0   1  11
# 2609      CT   C  0/1   50  21  21   4  12  57.14%   8.0605E-6   3   1  10
# 2610       A  AT  1/1   71  18  18   2  15  83.33%   7.3277E-8   2   0  13
#
#      ADR     ADP    WT    HET    HOM    NC CDA OTH S3D WTD  \
# 0      3  ADP=29  WT=0  HET=0  HOM=1  NC=0
# 1      4  ADP=65  WT=0  HET=1  HOM=0  NC=0
# 2      6  ADP=76  WT=0  HET=1  HOM=0  NC=0
# 3      8  ADP=60  WT=0  HET=1  HOM=0  NC=0
# 4      2  ADP=21  WT=0  HET=1  HOM=0  NC=0
# ...   ..     ...   ...    ...    ...   ...  ..  ..  ..  ..
# 2606  11  ADP=63  WT=0  HET=0  HOM=1  NC=0
# 2607   1  ADP=25  WT=0  HET=1  HOM=0  NC=0
# 2608   5  ADP=17  WT=0  HET=0  HOM=1  NC=0
# 2609   2  ADP=21  WT=0  HET=1  HOM=0  NC=0
# 2610   2  ADP=18  WT=0  HET=0  HOM=1  NC=0
#
#               dbSNPBuildID  SLO  NSF R3  R5 NSN NSM  G5A      COMMON  \
# 0         dbSNPBuildID=126  SLO                             COMMON=1
# 1         dbSNPBuildID=134               R5                 COMMON=1
# 2         dbSNPBuildID=134  SLO                      G5A    COMMON=1
# 3     dbSNPBuildID=107,138  SLO          R5               COMMON=1,1
# 4         dbSNPBuildID=132  SLO  NSF
# ...                    ...  ...  ... ..  ..  ..  ..  ...         ...
# 2606  dbSNPBuildID=131,126  SLO                           COMMON=0,0
# 2607      dbSNPBuildID=144
# 2608  dbSNPBuildID=151,138
# 2609      dbSNPBuildID=144
# 2610      dbSNPBuildID=137
#
#                            RS  RV TPA CFL  GNO  VLD  ASP  ASS Ref U3 U5  \
# 0                 RS=35881187  RV          GNO  VLD  ASP
# 1                RS=143128930                   VLD  ASP
# 2                RS=140777846              GNO  VLD  ASP
# 3        RS=3831366,368050244              GNO  VLD  ASP  ASS
# 4                RS=112177324              GNO  VLD  ASP
# ...                       ...  ..  ..  ..  ...  ...  ...  ...  .. .. ..
# 2606      RS=77485258,5904376              GNO       ASP
# 2607             RS=781912204                        ASP
# 2608  RS=1169019545,376271737                        ASP
# 2609             RS=760255651                        ASP
# 2610             RS=202147921                        ASP
#
#                                                  TOPMED      WGT MTP LSD NOC  \
# 0        TOPMED=0.55968081039755351,0.44031918960244648    WGT=1
# 1        TOPMED=0.91126720183486238,0.08873279816513761    WGT=1
# 2        TOPMED=0.13763857033639143,0.86236142966360856    WGT=1
# 3        TOPMED=0.94513729612640163,0.05486270387359836  WGT=1,1
# 4        TOPMED=0.75031058868501529,0.24968941131498470    WGT=1
# ...                                                 ...      ...  ..  ..  ..
# 2606     TOPMED=0.01672400611620795,0.98327599388379204  WGT=1,1
# 2607  TOPMED=0.43169438073394495,0.56314506880733944...    WGT=1
# 2608     TOPMED=0.35031218144750254,0.64968781855249745  WGT=1,1
# 2609                                                       WGT=1
# 2610                                                       WGT=1
#
#      DSS SYN  KGPhase3                                    CAF          VC MUT  \
# 0             KGPhase3                      CAF=0.5208,0.4792      VC=DIV
# 1             KGPhase3                      CAF=0.8806,0.1194      VC=DIV
# 2             KGPhase3                      CAF=0.1793,0.8207      VC=DIV
# 3             KGPhase3      CAF=0.9259,0.07408,0.9259,0.07408  VC=DIV,DIV
# 4             KGPhase3                                             VC=DIV
# ...   ..  ..       ...                                    ...         ...  ..
# 2606          KGPhase3  CAF=0.0002649,0.9997,0.0002649,0.9997  VC=DIV,DIV
# 2607                                                               VC=DIV
# 2608                                                           VC=DIV,DIV
# 2609                                                               VC=DIV
# 2610                                                               VC=DIV
#
#       KGPhase1  NOV                                                 VP  \
# 0     KGPhase1                           VP=0x05012808000515013e000200
# 1     KGPhase1                           VP=0x0500000a000515003e000200
# 2                                        VP=0x050100080005170126000200
# 3     KGPhase1       VP=0x05012822000515013e000200,0x0500000a000500...
# 4     KGPhase1                           VP=0x05010008120515013e000200
# ...        ...  ...                                                ...
# 2606  KGPhase1       VP=0x05000008000501003e000200,0x05010008000500...
# 2607            NOV                      VP=0x050000080005000002000204
# 2608                 VP=0x050000080005000002000200,0x05000008000500...
# 2609                                     VP=0x050000080005000002000200
# 2610                                     VP=0x050000000005000002000200
#
#           SAO  INT  G5 OM  PMC      SSR                      RSPOS HD  PM  \
# 0       SAO=0  INT  G5     PMC    SSR=0              RSPOS=1043224     PM
# 1       SAO=0  INT  G5            SSR=0              RSPOS=1299383
# 2       SAO=0  INT  G5            SSR=0              RSPOS=1353988
# 3     SAO=0,0  INT  G5     PMC  SSR=0,0      RSPOS=1398673,1398677     PM
# 4       SAO=0  INT  G5            SSR=0              RSPOS=1629573
# ...       ...  ...  .. ..  ...      ...                        ... ..  ..
# 2606  SAO=0,0  INT  G5          SSR=0,0  RSPOS=153913005,153913008
# 2607    SAO=0  INT                SSR=0            RSPOS=155228363
# 2608  SAO=0,0  INT              SSR=0,0  RSPOS=155492733,155492734
# 2609    SAO=0  INT                SSR=0             RSPOS=12786503
# 2610    SAO=0                     SSR=0             RSPOS=21311242
#
#      ClinVar ClinVar_CLNSIG
# 0
# 1
# 2
# 3
# 4
# ...      ...            ...
# 2606
# 2607
# 2608
# 2609
# 2610
#
# [2611 rows x 72 columns]

# %%
data.ClinVar_CLNSIG.value_counts()
# Out:
#     2611
# Name: ClinVar_CLNSIG, dtype: int64

# %%
data['Allele'] = '[' + data['REF'] + ', ' + data['ALT'] + ']'
data
# Out:
#      CHROM        POS                  Gene Name                      rsID  \
# 0     chr1    1043223                       AGRN                rs35881187
# 1     chr1    1299382                      ACAP3               rs143128930
# 2     chr1    1353987                      MXRA8               rs140777846
# 3     chr1    1398672      LOC148413,CCNL2,CCNL2     rs368050244;rs3831366
# 4     chr1    1629572                       MIB2               rs112177324
# ...    ...        ...                        ...                       ...
# 2606  chrX  153913005                    ARHGAP4      rs5904376;rs77485258
# 2607  chrX  155228363                       VBP1               rs781912204
# 2608  chrX  155492733  TMLHE,TMLHE-AS1,TMLHE-AS1  rs1169019545;rs376271737
# 2609  chrY   12786501                      USP9Y               rs760255651
# 2610  chrY   21311242                                          rs202147921
#
#          REF ALT   GT   GQ SDP  DP  RD  AD    FREQ        PVAL RDF RDR ADF  \
# 0        CCT   C  1/1  150  29  29   1  28  96.55%  9.9776E-16   1   0  25
# 1         AG   A  0/1  109  65  65  35  30  46.15%  1.1519E-11  27   8  26
# 2        CTG   C  0/1  151  76  76  36  40  52.63%  7.6319E-16  28   8  34
# 3     CTAGAG   C  0/1  131  60  60  26  34  56.67%  7.4725E-14  21   5  26
# 4       null   T  0/1   50  22  21   9  13  59.09%   9.5813E-6   9   0  11
# ...      ...  ..  ...  ...  ..  ..  ..  ..     ...         ...  ..  ..  ..
# 2606       G  GC  1/1  255  63  63   2  61  96.83%  3.4466E-34   2   0  50
# 2607       A  AT  0/1   64  25  25   5  15     60%   3.8543E-7   5   0  14
# 2608       T  TG  1/1   81  17  17   1  16  94.12%   7.7134E-9   0   1  11
# 2609      CT   C  0/1   50  21  21   4  12  57.14%   8.0605E-6   3   1  10
# 2610       A  AT  1/1   71  18  18   2  15  83.33%   7.3277E-8   2   0  13
#
#      ADR     ADP    WT    HET    HOM    NC CDA OTH S3D WTD  \
# 0      3  ADP=29  WT=0  HET=0  HOM=1  NC=0
# 1      4  ADP=65  WT=0  HET=1  HOM=0  NC=0
# 2      6  ADP=76  WT=0  HET=1  HOM=0  NC=0
# 3      8  ADP=60  WT=0  HET=1  HOM=0  NC=0
# 4      2  ADP=21  WT=0  HET=1  HOM=0  NC=0
# ...   ..     ...   ...    ...    ...   ...  ..  ..  ..  ..
# 2606  11  ADP=63  WT=0  HET=0  HOM=1  NC=0
# 2607   1  ADP=25  WT=0  HET=1  HOM=0  NC=0
# 2608   5  ADP=17  WT=0  HET=0  HOM=1  NC=0
# 2609   2  ADP=21  WT=0  HET=1  HOM=0  NC=0
# 2610   2  ADP=18  WT=0  HET=0  HOM=1  NC=0
#
#               dbSNPBuildID  SLO  NSF R3  R5 NSN NSM  G5A      COMMON  \
# 0         dbSNPBuildID=126  SLO                             COMMON=1
# 1         dbSNPBuildID=134               R5                 COMMON=1
# 2         dbSNPBuildID=134  SLO                      G5A    COMMON=1
# 3     dbSNPBuildID=107,138  SLO          R5               COMMON=1,1
# 4         dbSNPBuildID=132  SLO  NSF
# ...                    ...  ...  ... ..  ..  ..  ..  ...         ...
# 2606  dbSNPBuildID=131,126  SLO                           COMMON=0,0
# 2607      dbSNPBuildID=144
# 2608  dbSNPBuildID=151,138
# 2609      dbSNPBuildID=144
# 2610      dbSNPBuildID=137
#
#                            RS  RV TPA CFL  GNO  VLD  ASP  ASS Ref U3 U5  \
# 0                 RS=35881187  RV          GNO  VLD  ASP
# 1                RS=143128930                   VLD  ASP
# 2                RS=140777846              GNO  VLD  ASP
# 3        RS=3831366,368050244              GNO  VLD  ASP  ASS
# 4                RS=112177324              GNO  VLD  ASP
# ...                       ...  ..  ..  ..  ...  ...  ...  ...  .. .. ..
# 2606      RS=77485258,5904376              GNO       ASP
# 2607             RS=781912204                        ASP
# 2608  RS=1169019545,376271737                        ASP
# 2609             RS=760255651                        ASP
# 2610             RS=202147921                        ASP
#
#                                                  TOPMED      WGT MTP LSD NOC  \
# 0        TOPMED=0.55968081039755351,0.44031918960244648    WGT=1
# 1        TOPMED=0.91126720183486238,0.08873279816513761    WGT=1
# 2        TOPMED=0.13763857033639143,0.86236142966360856    WGT=1
# 3        TOPMED=0.94513729612640163,0.05486270387359836  WGT=1,1
# 4        TOPMED=0.75031058868501529,0.24968941131498470    WGT=1
# ...                                                 ...      ...  ..  ..  ..
# 2606     TOPMED=0.01672400611620795,0.98327599388379204  WGT=1,1
# 2607  TOPMED=0.43169438073394495,0.56314506880733944...    WGT=1
# 2608     TOPMED=0.35031218144750254,0.64968781855249745  WGT=1,1
# 2609                                                       WGT=1
# 2610                                                       WGT=1
#
#      DSS SYN  KGPhase3                                    CAF          VC MUT  \
# 0             KGPhase3                      CAF=0.5208,0.4792      VC=DIV
# 1             KGPhase3                      CAF=0.8806,0.1194      VC=DIV
# 2             KGPhase3                      CAF=0.1793,0.8207      VC=DIV
# 3             KGPhase3      CAF=0.9259,0.07408,0.9259,0.07408  VC=DIV,DIV
# 4             KGPhase3                                             VC=DIV
# ...   ..  ..       ...                                    ...         ...  ..
# 2606          KGPhase3  CAF=0.0002649,0.9997,0.0002649,0.9997  VC=DIV,DIV
# 2607                                                               VC=DIV
# 2608                                                           VC=DIV,DIV
# 2609                                                               VC=DIV
# 2610                                                               VC=DIV
#
#       KGPhase1  NOV                                                 VP  \
# 0     KGPhase1                           VP=0x05012808000515013e000200
# 1     KGPhase1                           VP=0x0500000a000515003e000200
# 2                                        VP=0x050100080005170126000200
# 3     KGPhase1       VP=0x05012822000515013e000200,0x0500000a000500...
# 4     KGPhase1                           VP=0x05010008120515013e000200
# ...        ...  ...                                                ...
# 2606  KGPhase1       VP=0x05000008000501003e000200,0x05010008000500...
# 2607            NOV                      VP=0x050000080005000002000204
# 2608                 VP=0x050000080005000002000200,0x05000008000500...
# 2609                                     VP=0x050000080005000002000200
# 2610                                     VP=0x050000000005000002000200
#
#           SAO  INT  G5 OM  PMC      SSR                      RSPOS HD  PM  \
# 0       SAO=0  INT  G5     PMC    SSR=0              RSPOS=1043224     PM
# 1       SAO=0  INT  G5            SSR=0              RSPOS=1299383
# 2       SAO=0  INT  G5            SSR=0              RSPOS=1353988
# 3     SAO=0,0  INT  G5     PMC  SSR=0,0      RSPOS=1398673,1398677     PM
# 4       SAO=0  INT  G5            SSR=0              RSPOS=1629573
# ...       ...  ...  .. ..  ...      ...                        ... ..  ..
# 2606  SAO=0,0  INT  G5          SSR=0,0  RSPOS=153913005,153913008
# 2607    SAO=0  INT                SSR=0            RSPOS=155228363
# 2608  SAO=0,0  INT              SSR=0,0  RSPOS=155492733,155492734
# 2609    SAO=0  INT                SSR=0             RSPOS=12786503
# 2610    SAO=0                     SSR=0             RSPOS=21311242
#
#      ClinVar ClinVar_CLNSIG       Allele
# 0                               [CCT, C]
# 1                                [AG, A]
# 2                               [CTG, C]
# 3                            [CTAGAG, C]
# 4                              [null, T]
# ...      ...            ...          ...
# 2606                             [G, GC]
# 2607                             [A, AT]
# 2608                             [T, TG]
# 2609                             [CT, C]
# 2610                             [A, AT]
#
# [2611 rows x 73 columns]

# %%
data.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/InDel_columns_Extracted.xlsx', index=False)

# %%
df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/KHCDPRGPTTL6_InDel.xlsx')
df = df.rename({'zygocity':'zygosity'}, axis = 1)
df['Allele'] = df['allele'].str.replace('\'', '')
df
# Out:
#                allele      zygosity Gene Name Gene_Match         rsid  \
# 0        ['ACCTT', A]    Homozygous  ADAMTS17         No   rs10549565
# 1         ['CACA', C]  Heterozygous    GIGYF2         No   rs10555297
# 2          ['GCA', G]  Heterozygous     TRPV3         No   rs10573788
# 3          ['CAT', C]    Homozygous    PTGES3         No   rs10579382
# 4          ['CAA', C]  Heterozygous      JAK3         No   rs10580414
# ..                ...           ...       ...        ...          ...
# 664  ['AAAGGAAGT', A]  Heterozygous       ATR         No  rs797045404
# 665         ['TA', T]  Heterozygous     WDR62         No  rs797046108
# 666        ['CTT', C]  Heterozygous    ANTXR2         No   rs80314910
# 667      ['CCTTT', C]  Heterozygous     CNGB1         No  rs866017919
# 668         ['C', CA]  Heterozygous    CHMP2B         No  rs886058906
#
#                                      consequence Consequence_score  \
# 0                            3_prime_UTR_variant              3/10
# 1    non-coding_transcript_variant', 'SO:0001822              2/10
# 2              5_prime_UTR_variant', 'SO:0001624              3/10
# 3         initiatior_codon_variant', 'SO:0001589               NaN
# 4                                            NaN               NaN
# ..                                           ...               ...
# 664                               intron_variant              2/10
# 665                               intron_variant              2/10
# 666            5_prime_UTR_variant', 'SO:0001627              3/10
# 667                          3_prime_UTR_variant              3/10
# 668                          3_prime_UTR_variant              3/10
#
#                             clinical_significance  \
# 0                                          Benign
# 1                                          Benign
# 2                                          Benign
# 3                                          Benign
# 4                                          Benign
# ..                                            ...
# 664                        Uncertain_significance
# 665  Conflicting_interpretations_of_pathogenicity
# 666                                        Benign
# 667                                 Likely_benign
# 668                        Uncertain_significance
#
#                                    associated_diseases  \
# 0    Weill-Marchesani_4_syndrome', '_recessive|not_...
# 1    Parkinson_disease_11', '_autosomal_dominant', ...
# 2                      Olmsted_syndrome_1|not_provided
# 3                                         not_provided
# 4             Severe_combined_immunodeficiency_disease
# ..                                                 ...
# 664                         not_specified|not_provided
# 665  not_specified|Primary_Microcephaly_2_With_or_W...
# 666         Hyaline_fibromatosis_syndrome|not_provided
# 667                 Retinitis_Pigmentosa', '_Recessive
# 668                            Frontotemporal_dementia
#
#                                          review_status    origin variant_type  \
# 0    criteria_provided', '_multiple_submitters', '_...  germline        indel
# 1               criteria_provided', '_single_submitter  germline        indel
# 2    criteria_provided', '_multiple_submitters', '_...  germline        indel
# 3                       no_assertion_criteria_provided  germline        indel
# 4               criteria_provided', '_single_submitter  germline        indel
# ..                                                 ...       ...          ...
# 664  criteria_provided', '_multiple_submitters', '_...  germline        indel
# 665  criteria_provided', '_conflicting_interpretations  germline        indel
# 666  criteria_provided', '_multiple_submitters', '_...  germline        indel
# 667             criteria_provided', '_single_submitter  germline        indel
# 668             criteria_provided', '_single_submitter  germline        indel
#
#     variant_subtype Phargkb_ann_exists is_mutation Variant_is_precious  \
# 0          Deletion           MayBe No          No                  No
# 1          Deletion           MayBe No          No                 Yes
# 2          Deletion           MayBe No          No                  No
# 3          Deletion           MayBe No          No                  No
# 4          Deletion           MayBe No          No                  No
# ..              ...                ...         ...                 ...
# 664        Deletion           MayBe No          No                 Yes
# 665        Deletion           MayBe No          No                 Yes
# 666        Deletion           MayBe No          No                 Yes
# 667        Deletion           MayBe No          No                  No
# 668       Insertion           MayBe No          No                 Yes
#
#              Allele
# 0        [ACCTT, A]
# 1         [CACA, C]
# 2          [GCA, G]
# 3          [CAT, C]
# 4          [CAA, C]
# ..              ...
# 664  [AAAGGAAGT, A]
# 665         [TA, T]
# 666        [CTT, C]
# 667      [CCTTT, C]
# 668         [C, CA]
#
# [669 rows x 17 columns]
