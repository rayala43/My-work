# %%
import numpy as np
import pandas as pd
import polars as pl
import sys
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px


pd.set_option('display.max_columns',None)
import psycopg2


#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Algorithms to use
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

#Metrics to evaluate the model
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve

import warnings
warnings.filterwarnings("ignore")

#importing PCA and TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
def read_bed_file(bed_file):
    bed_positions = set()
    with open(bed_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Skip header lines if present
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 3:
                chrom = fields[0]
                try:
                    start = int(fields[1])
                    end = int(fields[2])
                except ValueError:
                    continue  # Skip this line if start or end position is not an integer
                for pos in range(start, end + 1):
                    bed_positions.add((chrom, pos))
    return bed_positions

def normalize_chrom_name(chrom):
    return chrom.split('_')[0]

def filter_vcf_file(vcf_file, bed_positions):
    filtered_vcf_records = []
    with open(vcf_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Preserve header lines in the output
                filtered_vcf_records.append(line)
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 2:
                raw_chrom = fields[0]
                chrom = normalize_chrom_name(raw_chrom)
                try:
                    pos = int(fields[1])
                except ValueError:
                    continue  # Skip this line if 'POS' is not an integer
                if (chrom, pos) in bed_positions:
                    filtered_vcf_records.append(line)
    return filtered_vcf_records

def write_filtered_vcf(filtered_vcf_records, output_file):
    with open(output_file, 'w') as f:
        for record in filtered_vcf_records:
            f.write(record)

def main():
    bed_file = r'C:/Users/GenepoweRx_Madhu/Downloads/BED_files/kalyani_mam_covered.bed'
    vcf_file = r'C:/Users/GenepoweRx_Madhu/Downloads/vcf_files_all/KHGLBS448_final.vcf'
    output_file = r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/KHGLBS448_final.vcf'

    bed_positions = read_bed_file(bed_file)
    filtered_vcf_records = filter_vcf_file(vcf_file, bed_positions)
    write_filtered_vcf(filtered_vcf_records, output_file)

if __name__ == "__main__":
    main()

# %%
vcf = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/KHGLBS448_final.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
vcf.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']

sample_cols = vcf['SAMPLE'].str.split(':', expand=True)
sample_cols.columns = ['GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RBQ', 'ABQ', 'RDF', 'RDR', 'ADF', 'ADR']

# Assign the values to the newly created columns
vcf = pd.concat([vcf, sample_cols], axis=1)
vcf = vcf[['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL','RDF', 'RDR', 'ADF', 'ADR']]
vcf
# Out:
#       CHROM        POS         rsID REF ALT QUAL FILTER  \
# 0      chr1      69270  rs201219564   A   G    .   PASS
# 1      chr1      69511    rs2691305   A   G    .   PASS
# 2      chr1      69897  rs200676709   T   C    .   PASS
# 3      chr1     685694            .   T   C    .   PASS
# 4      chr1     686266            .   A   C    .   PASS
# ...     ...        ...          ...  ..  ..  ...    ...
# 33484  chrX  155997799    rs6642401   C   T    .   PASS
# 33485  chrX  156003433    rs2037999   T   C    .   PASS
# 33486  chrY    2789135    rs2534636   C   T    .   PASS
# 33487  chrY    9467257  rs777840135   G   A    .   PASS
# 33488  chrY   21311315   rs17250535   T   A    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=143;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  137  143  143
# 1      ADP=168;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  168  168
# 2      ADP=98;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1  109   98   98
# 3      ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# 4      ADP=89;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   58   89   89
# ...                                                  ...  ...  ...  ...  ...
# 33484  ADP=27;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9483,0....  0/1   47   27   27
# 33485  ADP=9;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.4079,0.5...  1/1   29    9    9
# 33486  ADP=54;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9278,0....  1/1  255   55   54
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33488  ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9319,0....  1/1  105   19   19
#
#         RD   AD    FREQ         PVAL  RDF RDR  ADF ADR
# 0      102   41  28.67%   1.5868E-14   99   3   33   8
# 1        0  168    100%  1.6424E-100    0   0  145  23
# 2       66   32  32.65%   1.1206E-11   52  14   25   7
# 3       12    6  33.33%    9.5308E-3   12   0    6   0
# 4       71   18  20.22%    1.4677E-6   58  13   14   4
# ...    ...  ...     ...          ...  ...  ..  ...  ..
# 33484   14   13  48.15%      1.81E-5   12   2   12   1
# 33485    2    7  77.78%    1.1312E-3    2   0    6   1
# 33486    0   54    100%   4.0229E-32    0   0   47   7
# 33487  174   67   27.8%    3.236E-23  132  42   58   9
# 33488    0   19    100%   2.8292E-11    0   0   17   2
#
# [33489 rows x 20 columns]

# %%
vcf['HET'] = vcf['INFO'].str.extract(r'HET=(\d)')
vcf['HOM'] = vcf['INFO'].str.extract(r'HOM=(\d)')

# Create a new column 'Zygosity' based on conditions
vcf['Zygosity'] = ''

vcf.loc[vcf['HOM'] == '1', 'Zygosity'] = 'Homozygous'
vcf.loc[vcf['HET'] == '1', 'Zygosity'] = 'Heterozygous'
vcf['GT'] = vcf['GT'].astype(str)
vcf
# Out:
#       CHROM        POS         rsID REF ALT QUAL FILTER  \
# 0      chr1      69270  rs201219564   A   G    .   PASS
# 1      chr1      69511    rs2691305   A   G    .   PASS
# 2      chr1      69897  rs200676709   T   C    .   PASS
# 3      chr1     685694            .   T   C    .   PASS
# 4      chr1     686266            .   A   C    .   PASS
# ...     ...        ...          ...  ..  ..  ...    ...
# 33484  chrX  155997799    rs6642401   C   T    .   PASS
# 33485  chrX  156003433    rs2037999   T   C    .   PASS
# 33486  chrY    2789135    rs2534636   C   T    .   PASS
# 33487  chrY    9467257  rs777840135   G   A    .   PASS
# 33488  chrY   21311315   rs17250535   T   A    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=143;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  137  143  143
# 1      ADP=168;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  168  168
# 2      ADP=98;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1  109   98   98
# 3      ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# 4      ADP=89;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   58   89   89
# ...                                                  ...  ...  ...  ...  ...
# 33484  ADP=27;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9483,0....  0/1   47   27   27
# 33485  ADP=9;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.4079,0.5...  1/1   29    9    9
# 33486  ADP=54;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9278,0....  1/1  255   55   54
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33488  ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9319,0....  1/1  105   19   19
#
#         RD   AD    FREQ         PVAL  RDF RDR  ADF ADR HET HOM      Zygosity
# 0      102   41  28.67%   1.5868E-14   99   3   33   8   1   0  Heterozygous
# 1        0  168    100%  1.6424E-100    0   0  145  23   0   1    Homozygous
# 2       66   32  32.65%   1.1206E-11   52  14   25   7   1   0  Heterozygous
# 3       12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# 4       71   18  20.22%    1.4677E-6   58  13   14   4   1   0  Heterozygous
# ...    ...  ...     ...          ...  ...  ..  ...  ..  ..  ..           ...
# 33484   14   13  48.15%      1.81E-5   12   2   12   1   1   0  Heterozygous
# 33485    2    7  77.78%    1.1312E-3    2   0    6   1   0   1    Homozygous
# 33486    0   54    100%   4.0229E-32    0   0   47   7   0   1    Homozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33488    0   19    100%   2.8292E-11    0   0   17   2   0   1    Homozygous
#
# [33489 rows x 23 columns]

# %%
vcf["Gene Name"] = vcf["INFO"].str.extract('GENEINFO=(?P<GENEINFO>.+?);')
vcf['Gene Name'] = vcf['Gene Name'].apply(lambda x: ','.join(set([segment.split(':')[0] for segment in x.split('|')])) if pd.notnull(x) else '')
vcf
# Out:
#       CHROM        POS         rsID REF ALT QUAL FILTER  \
# 0      chr1      69270  rs201219564   A   G    .   PASS
# 1      chr1      69511    rs2691305   A   G    .   PASS
# 2      chr1      69897  rs200676709   T   C    .   PASS
# 3      chr1     685694            .   T   C    .   PASS
# 4      chr1     686266            .   A   C    .   PASS
# ...     ...        ...          ...  ..  ..  ...    ...
# 33484  chrX  155997799    rs6642401   C   T    .   PASS
# 33485  chrX  156003433    rs2037999   T   C    .   PASS
# 33486  chrY    2789135    rs2534636   C   T    .   PASS
# 33487  chrY    9467257  rs777840135   G   A    .   PASS
# 33488  chrY   21311315   rs17250535   T   A    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=143;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  137  143  143
# 1      ADP=168;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  168  168
# 2      ADP=98;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1  109   98   98
# 3      ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# 4      ADP=89;WT=0;HET=1;HOM=0;NC=0;CSQ=C|missense_va...  0/1   58   89   89
# ...                                                  ...  ...  ...  ...  ...
# 33484  ADP=27;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.9483,0....  0/1   47   27   27
# 33485  ADP=9;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.4079,0.5...  1/1   29    9    9
# 33486  ADP=54;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9278,0....  1/1  255   55   54
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33488  ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9319,0....  1/1  105   19   19
#
#         RD   AD    FREQ         PVAL  RDF RDR  ADF ADR HET HOM      Zygosity  \
# 0      102   41  28.67%   1.5868E-14   99   3   33   8   1   0  Heterozygous
# 1        0  168    100%  1.6424E-100    0   0  145  23   0   1    Homozygous
# 2       66   32  32.65%   1.1206E-11   52  14   25   7   1   0  Heterozygous
# 3       12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# 4       71   18  20.22%    1.4677E-6   58  13   14   4   1   0  Heterozygous
# ...    ...  ...     ...          ...  ...  ..  ...  ..  ..  ..           ...
# 33484   14   13  48.15%      1.81E-5   12   2   12   1   1   0  Heterozygous
# 33485    2    7  77.78%    1.1312E-3    2   0    6   1   0   1    Homozygous
# 33486    0   54    100%   4.0229E-32    0   0   47   7   0   1    Homozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33488    0   19    100%   2.8292E-11    0   0   17   2   0   1    Homozygous
#
#       Gene Name
# 0         OR4F5
# 1         OR4F5
# 2         OR4F5
# 3
# 4
# ...         ...
# 33484      IL9R
# 33485      IL9R
# 33486       SRY
# 33487     TSPY1
# 33488
#
# [33489 rows x 24 columns]

# %%
vcf['CSQ'] = vcf['INFO'].str.extract(r'CSQ=(.*)')
vcf['csq'] = vcf['CSQ'].str.split(',')
vcf = vcf.explode('csq')
vcf
# Out:
#       CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 1      chr1     69511    rs2691305   A   G    .   PASS
# 2      chr1     69897  rs200676709   T   C    .   PASS
# 3      chr1    685694            .   T   C    .   PASS
# 3      chr1    685694            .   T   C    .   PASS
# ...     ...       ...          ...  ..  ..  ...    ...
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33488  chrY  21311315   rs17250535   T   A    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=143;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  137  143  143
# 1      ADP=168;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  168  168
# 2      ADP=98;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1  109   98   98
# 3      ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# 3      ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# ...                                                  ...  ...  ...  ...  ...
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33488  ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9319,0....  1/1  105   19   19
#
#         RD   AD    FREQ         PVAL  RDF RDR  ADF ADR HET HOM      Zygosity  \
# 0      102   41  28.67%   1.5868E-14   99   3   33   8   1   0  Heterozygous
# 1        0  168    100%  1.6424E-100    0   0  145  23   0   1    Homozygous
# 2       66   32  32.65%   1.1206E-11   52  14   25   7   1   0  Heterozygous
# 3       12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# 3       12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# ...    ...  ...     ...          ...  ...  ..  ...  ..  ..  ..           ...
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33488    0   19    100%   2.8292E-11    0   0   17   2   0   1    Homozygous
#
#       Gene Name                                                CSQ  \
# 0         OR4F5  G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1         OR4F5  G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2         OR4F5  C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 3                C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 3                C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# ...         ...                                                ...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33488            A|non_coding_transcript_exon_variant|MODIFIER|...
#
#                                                      csq
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2      C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 3      C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 3      C|intron_variant&non_coding_transcript_variant...
# ...                                                  ...
# 33487  A|missense_variant|MODERATE|TSPY1|ENSG00000258...
# 33487  A|missense_variant|MODERATE|TSPY1|ENSG00000258...
# 33487  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33487  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33488  A|non_coding_transcript_exon_variant|MODIFIER|...
#
# [275979 rows x 26 columns]

# %%
########################################################### Required columns extraction from the CSQ column ####################
vcf['Allele'] = vcf['csq'].str.split('|').str[0]
vcf['Consequence'] = vcf['csq'].str.split('|').str[1]
vcf['IMPACT'] = vcf['csq'].str.split('|').str[2]
vcf['SYMBOL'] = vcf['csq'].str.split('|').str[3]
vcf['Gene'] = vcf['csq'].str.split('|').str[4]
vcf['Feature_type'] = vcf['csq'].str.split('|').str[5]
vcf['Feature'] = vcf['csq'].str.split('|').str[6]
vcf['BIOTYPE'] = vcf['csq'].str.split('|').str[7]
vcf['EXON'] = vcf['csq'].str.split('|').str[8]
vcf['INTRON'] = vcf['csq'].str.split('|').str[9]
vcf['HGVSc'] = vcf['csq'].str.split('|').str[10]
vcf['HGVSp'] = vcf['csq'].str.split('|').str[11]
vcf['cDNA_position'] = vcf['csq'].str.split('|').str[12]
vcf['CDS_position'] = vcf['csq'].str.split('|').str[13]
vcf['Protein_position'] = vcf['csq'].str.split('|').str[14]
vcf['Amino_acids'] = vcf['csq'].str.split('|').str[15]
vcf['Codons'] = vcf['csq'].str.split('|').str[16]
vcf['Existing_variation'] = vcf['csq'].str.split('|').str[17]
vcf['DISTANCE'] = vcf['csq'].str.split('|').str[18]
vcf['STRAND'] = vcf['csq'].str.split('|').str[19]
vcf['FLAGS'] = vcf['csq'].str.split('|').str[20]
vcf['SYMBOL_SOURCE'] = vcf['csq'].str.split('|').str[21]
vcf['HGNC_ID'] = vcf['csq'].str.split('|').str[22]
vcf['SOURCE'] = vcf['csq'].str.split('|').str[23]
vcf['ClinVar'] = vcf['csq'].str.split('|').str[24]
vcf['ClinVar_CLNSIG'] = vcf['csq'].str.split('|').str[25]
vcf['ClinVar_CLNREVSTAT'] = vcf['csq'].str.split('|').str[26]
vcf['ClinVar_CLNDN'] = vcf['csq'].str.split('|').str[27]
vcf
# Out:
#       CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 1      chr1     69511    rs2691305   A   G    .   PASS
# 2      chr1     69897  rs200676709   T   C    .   PASS
# 3      chr1    685694            .   T   C    .   PASS
# 3      chr1    685694            .   T   C    .   PASS
# ...     ...       ...          ...  ..  ..  ...    ...
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33488  chrY  21311315   rs17250535   T   A    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=143;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  137  143  143
# 1      ADP=168;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  168  168
# 2      ADP=98;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1  109   98   98
# 3      ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# 3      ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# ...                                                  ...  ...  ...  ...  ...
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33488  ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9319,0....  1/1  105   19   19
#
#         RD   AD    FREQ         PVAL  RDF RDR  ADF ADR HET HOM      Zygosity  \
# 0      102   41  28.67%   1.5868E-14   99   3   33   8   1   0  Heterozygous
# 1        0  168    100%  1.6424E-100    0   0  145  23   0   1    Homozygous
# 2       66   32  32.65%   1.1206E-11   52  14   25   7   1   0  Heterozygous
# 3       12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# 3       12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# ...    ...  ...     ...          ...  ...  ..  ...  ..  ..  ..           ...
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33488    0   19    100%   2.8292E-11    0   0   17   2   0   1    Homozygous
#
#       Gene Name                                                CSQ  \
# 0         OR4F5  G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1         OR4F5  G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2         OR4F5  C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 3                C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 3                C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# ...         ...                                                ...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33488            A|non_coding_transcript_exon_variant|MODIFIER|...
#
#                                                      csq Allele  \
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...      G
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...      G
# 2      C|synonymous_variant|LOW|OR4F5|ENSG00000186092...      C
# 3      C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...      C
# 3      C|intron_variant&non_coding_transcript_variant...      C
# ...                                                  ...    ...
# 33487  A|missense_variant|MODERATE|TSPY1|ENSG00000258...      A
# 33487  A|missense_variant|MODERATE|TSPY1|ENSG00000258...      A
# 33487  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...      A
# 33487  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...      A
# 33488  A|non_coding_transcript_exon_variant|MODIFIER|...      A
#
#                                         Consequence    IMPACT    SYMBOL  \
# 0                                synonymous_variant       LOW     OR4F5
# 1                                  missense_variant  MODERATE     OR4F5
# 2                                synonymous_variant       LOW     OR4F5
# 3                           downstream_gene_variant  MODIFIER    OR4F16
# 3      intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                             ...       ...       ...
# 33487                              missense_variant  MODERATE     TSPY1
# 33487                              missense_variant  MODERATE     TSPY1
# 33487                         upstream_gene_variant  MODIFIER  FAM197Y5
# 33487                         upstream_gene_variant  MODIFIER  FAM197Y5
# 33488            non_coding_transcript_exon_variant  MODIFIER
#
#                   Gene Feature_type          Feature                 BIOTYPE  \
# 0      ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 1      ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 2      ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 3      ENSG00000284662   Transcript  ENST00000332831          protein_coding
# 3      ENSG00000230021   Transcript  ENST00000419394    processed_transcript
# ...                ...          ...              ...                     ...
# 33487  ENSG00000258992   Transcript  ENST00000423647          protein_coding
# 33487  ENSG00000258992   Transcript  ENST00000451548          protein_coding
# 33487  ENSG00000225516   Transcript  ENST00000615605    processed_transcript
# 33487  ENSG00000225516   Transcript  ENST00000619815    processed_transcript
# 33488  ENSG00000226918   Transcript  ENST00000437359  unprocessed_pseudogene
#
#       EXON INTRON HGVSc HGVSp cDNA_position CDS_position Protein_position  \
# 0      3/3                              303          243               81
# 1      3/3                              544          484              162
# 2      3/3                              930          870              290
# 3
# 3             3/3
# ...    ...    ...   ...   ...           ...          ...              ...
# 33487  1/6                              303          257               86
# 33487  1/6                              303          257               86
# 33487
# 33487
# 33488  1/9                               48
#
#       Amino_acids   Codons Existing_variation DISTANCE STRAND FLAGS  \
# 0               S  tcA/tcG                                  1
# 1             T/A  Aca/Gca                                  1
# 2               S  tcT/tcC                                  1
# 3                                                   22     -1
# 3                                                          -1
# ...           ...      ...                ...      ...    ...   ...
# 33487         R/Q  cGg/cAg                                  1
# 33487         R/Q  cGg/cAg                                  1
# 33487                                             2900     -1
# 33487                                             2912     -1
# 33488                                                       1
#
#       SYMBOL_SOURCE     HGNC_ID SOURCE ClinVar ClinVar_CLNSIG  \
# 0              HGNC  HGNC:14825
# 1              HGNC  HGNC:14825
# 2              HGNC  HGNC:14825
# 3              HGNC  HGNC:15079
# 3
# ...             ...         ...    ...     ...            ...
# 33487          HGNC  HGNC:12381
# 33487          HGNC  HGNC:12381
# 33487          HGNC  HGNC:37467
# 33487          HGNC  HGNC:37467
# 33488
#
#       ClinVar_CLNREVSTAT ClinVar_CLNDN
# 0
# 1
# 2
# 3
# 3
# ...                  ...           ...
# 33487
# 33487
# 33487
# 33487
# 33488
#
# [275979 rows x 54 columns]

# %%
vcf['consequence'] = vcf['Consequence'].apply(lambda x: x.split('&')[0] if isinstance(x, str) else x)
vcf
# Out:
#       CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 1      chr1     69511    rs2691305   A   G    .   PASS
# 2      chr1     69897  rs200676709   T   C    .   PASS
# 3      chr1    685694            .   T   C    .   PASS
# 3      chr1    685694            .   T   C    .   PASS
# ...     ...       ...          ...  ..  ..  ...    ...
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33488  chrY  21311315   rs17250535   T   A    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=143;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  137  143  143
# 1      ADP=168;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  168  168
# 2      ADP=98;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1  109   98   98
# 3      ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# 3      ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# ...                                                  ...  ...  ...  ...  ...
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33488  ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9319,0....  1/1  105   19   19
#
#         RD   AD    FREQ         PVAL  RDF RDR  ADF ADR HET HOM      Zygosity  \
# 0      102   41  28.67%   1.5868E-14   99   3   33   8   1   0  Heterozygous
# 1        0  168    100%  1.6424E-100    0   0  145  23   0   1    Homozygous
# 2       66   32  32.65%   1.1206E-11   52  14   25   7   1   0  Heterozygous
# 3       12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# 3       12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# ...    ...  ...     ...          ...  ...  ..  ...  ..  ..  ..           ...
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33488    0   19    100%   2.8292E-11    0   0   17   2   0   1    Homozygous
#
#       Gene Name                                                CSQ  \
# 0         OR4F5  G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1         OR4F5  G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2         OR4F5  C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 3                C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 3                C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# ...         ...                                                ...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33488            A|non_coding_transcript_exon_variant|MODIFIER|...
#
#                                                      csq Allele  \
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...      G
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...      G
# 2      C|synonymous_variant|LOW|OR4F5|ENSG00000186092...      C
# 3      C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...      C
# 3      C|intron_variant&non_coding_transcript_variant...      C
# ...                                                  ...    ...
# 33487  A|missense_variant|MODERATE|TSPY1|ENSG00000258...      A
# 33487  A|missense_variant|MODERATE|TSPY1|ENSG00000258...      A
# 33487  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...      A
# 33487  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...      A
# 33488  A|non_coding_transcript_exon_variant|MODIFIER|...      A
#
#                                         Consequence    IMPACT    SYMBOL  \
# 0                                synonymous_variant       LOW     OR4F5
# 1                                  missense_variant  MODERATE     OR4F5
# 2                                synonymous_variant       LOW     OR4F5
# 3                           downstream_gene_variant  MODIFIER    OR4F16
# 3      intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                             ...       ...       ...
# 33487                              missense_variant  MODERATE     TSPY1
# 33487                              missense_variant  MODERATE     TSPY1
# 33487                         upstream_gene_variant  MODIFIER  FAM197Y5
# 33487                         upstream_gene_variant  MODIFIER  FAM197Y5
# 33488            non_coding_transcript_exon_variant  MODIFIER
#
#                   Gene Feature_type          Feature                 BIOTYPE  \
# 0      ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 1      ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 2      ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 3      ENSG00000284662   Transcript  ENST00000332831          protein_coding
# 3      ENSG00000230021   Transcript  ENST00000419394    processed_transcript
# ...                ...          ...              ...                     ...
# 33487  ENSG00000258992   Transcript  ENST00000423647          protein_coding
# 33487  ENSG00000258992   Transcript  ENST00000451548          protein_coding
# 33487  ENSG00000225516   Transcript  ENST00000615605    processed_transcript
# 33487  ENSG00000225516   Transcript  ENST00000619815    processed_transcript
# 33488  ENSG00000226918   Transcript  ENST00000437359  unprocessed_pseudogene
#
#       EXON INTRON HGVSc HGVSp cDNA_position CDS_position Protein_position  \
# 0      3/3                              303          243               81
# 1      3/3                              544          484              162
# 2      3/3                              930          870              290
# 3
# 3             3/3
# ...    ...    ...   ...   ...           ...          ...              ...
# 33487  1/6                              303          257               86
# 33487  1/6                              303          257               86
# 33487
# 33487
# 33488  1/9                               48
#
#       Amino_acids   Codons Existing_variation DISTANCE STRAND FLAGS  \
# 0               S  tcA/tcG                                  1
# 1             T/A  Aca/Gca                                  1
# 2               S  tcT/tcC                                  1
# 3                                                   22     -1
# 3                                                          -1
# ...           ...      ...                ...      ...    ...   ...
# 33487         R/Q  cGg/cAg                                  1
# 33487         R/Q  cGg/cAg                                  1
# 33487                                             2900     -1
# 33487                                             2912     -1
# 33488                                                       1
#
#       SYMBOL_SOURCE     HGNC_ID SOURCE ClinVar ClinVar_CLNSIG  \
# 0              HGNC  HGNC:14825
# 1              HGNC  HGNC:14825
# 2              HGNC  HGNC:14825
# 3              HGNC  HGNC:15079
# 3
# ...             ...         ...    ...     ...            ...
# 33487          HGNC  HGNC:12381
# 33487          HGNC  HGNC:12381
# 33487          HGNC  HGNC:37467
# 33487          HGNC  HGNC:37467
# 33488
#
#       ClinVar_CLNREVSTAT ClinVar_CLNDN                         consequence
# 0                                                       synonymous_variant
# 1                                                         missense_variant
# 2                                                       synonymous_variant
# 3                                                  downstream_gene_variant
# 3                                                           intron_variant
# ...                  ...           ...                                 ...
# 33487                                                     missense_variant
# 33487                                                     missense_variant
# 33487                                                upstream_gene_variant
# 33487                                                upstream_gene_variant
# 33488                                   non_coding_transcript_exon_variant
#
# [275979 rows x 55 columns]

# %%
vcf['consequence'] = vcf['consequence'].str.split(',').str[0]
vcf['consequence'] = vcf['consequence'].str.replace('_', ' ')
vcf
# Out:
#       CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0      chr1     69270  rs201219564   A   G    .   PASS
# 1      chr1     69511    rs2691305   A   G    .   PASS
# 2      chr1     69897  rs200676709   T   C    .   PASS
# 3      chr1    685694            .   T   C    .   PASS
# 3      chr1    685694            .   T   C    .   PASS
# ...     ...       ...          ...  ..  ..  ...    ...
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33487  chrY   9467257  rs777840135   G   A    .   PASS
# 33488  chrY  21311315   rs17250535   T   A    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=143;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  137  143  143
# 1      ADP=168;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  168  168
# 2      ADP=98;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1  109   98   98
# 3      ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# 3      ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# ...                                                  ...  ...  ...  ...  ...
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33487  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 33488  ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9319,0....  1/1  105   19   19
#
#         RD   AD    FREQ         PVAL  RDF RDR  ADF ADR HET HOM      Zygosity  \
# 0      102   41  28.67%   1.5868E-14   99   3   33   8   1   0  Heterozygous
# 1        0  168    100%  1.6424E-100    0   0  145  23   0   1    Homozygous
# 2       66   32  32.65%   1.1206E-11   52  14   25   7   1   0  Heterozygous
# 3       12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# 3       12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# ...    ...  ...     ...          ...  ...  ..  ...  ..  ..  ..           ...
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33487  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 33488    0   19    100%   2.8292E-11    0   0   17   2   0   1    Homozygous
#
#       Gene Name                                                CSQ  \
# 0         OR4F5  G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1         OR4F5  G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2         OR4F5  C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 3                C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 3                C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# ...         ...                                                ...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33487     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 33488            A|non_coding_transcript_exon_variant|MODIFIER|...
#
#                                                      csq Allele  \
# 0      G|synonymous_variant|LOW|OR4F5|ENSG00000186092...      G
# 1      G|missense_variant|MODERATE|OR4F5|ENSG00000186...      G
# 2      C|synonymous_variant|LOW|OR4F5|ENSG00000186092...      C
# 3      C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...      C
# 3      C|intron_variant&non_coding_transcript_variant...      C
# ...                                                  ...    ...
# 33487  A|missense_variant|MODERATE|TSPY1|ENSG00000258...      A
# 33487  A|missense_variant|MODERATE|TSPY1|ENSG00000258...      A
# 33487  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...      A
# 33487  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...      A
# 33488  A|non_coding_transcript_exon_variant|MODIFIER|...      A
#
#                                         Consequence    IMPACT    SYMBOL  \
# 0                                synonymous_variant       LOW     OR4F5
# 1                                  missense_variant  MODERATE     OR4F5
# 2                                synonymous_variant       LOW     OR4F5
# 3                           downstream_gene_variant  MODIFIER    OR4F16
# 3      intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                             ...       ...       ...
# 33487                              missense_variant  MODERATE     TSPY1
# 33487                              missense_variant  MODERATE     TSPY1
# 33487                         upstream_gene_variant  MODIFIER  FAM197Y5
# 33487                         upstream_gene_variant  MODIFIER  FAM197Y5
# 33488            non_coding_transcript_exon_variant  MODIFIER
#
#                   Gene Feature_type          Feature                 BIOTYPE  \
# 0      ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 1      ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 2      ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 3      ENSG00000284662   Transcript  ENST00000332831          protein_coding
# 3      ENSG00000230021   Transcript  ENST00000419394    processed_transcript
# ...                ...          ...              ...                     ...
# 33487  ENSG00000258992   Transcript  ENST00000423647          protein_coding
# 33487  ENSG00000258992   Transcript  ENST00000451548          protein_coding
# 33487  ENSG00000225516   Transcript  ENST00000615605    processed_transcript
# 33487  ENSG00000225516   Transcript  ENST00000619815    processed_transcript
# 33488  ENSG00000226918   Transcript  ENST00000437359  unprocessed_pseudogene
#
#       EXON INTRON HGVSc HGVSp cDNA_position CDS_position Protein_position  \
# 0      3/3                              303          243               81
# 1      3/3                              544          484              162
# 2      3/3                              930          870              290
# 3
# 3             3/3
# ...    ...    ...   ...   ...           ...          ...              ...
# 33487  1/6                              303          257               86
# 33487  1/6                              303          257               86
# 33487
# 33487
# 33488  1/9                               48
#
#       Amino_acids   Codons Existing_variation DISTANCE STRAND FLAGS  \
# 0               S  tcA/tcG                                  1
# 1             T/A  Aca/Gca                                  1
# 2               S  tcT/tcC                                  1
# 3                                                   22     -1
# 3                                                          -1
# ...           ...      ...                ...      ...    ...   ...
# 33487         R/Q  cGg/cAg                                  1
# 33487         R/Q  cGg/cAg                                  1
# 33487                                             2900     -1
# 33487                                             2912     -1
# 33488                                                       1
#
#       SYMBOL_SOURCE     HGNC_ID SOURCE ClinVar ClinVar_CLNSIG  \
# 0              HGNC  HGNC:14825
# 1              HGNC  HGNC:14825
# 2              HGNC  HGNC:14825
# 3              HGNC  HGNC:15079
# 3
# ...             ...         ...    ...     ...            ...
# 33487          HGNC  HGNC:12381
# 33487          HGNC  HGNC:12381
# 33487          HGNC  HGNC:37467
# 33487          HGNC  HGNC:37467
# 33488
#
#       ClinVar_CLNREVSTAT ClinVar_CLNDN                         consequence
# 0                                                       synonymous variant
# 1                                                         missense variant
# 2                                                       synonymous variant
# 3                                                  downstream gene variant
# 3                                                           intron variant
# ...                  ...           ...                                 ...
# 33487                                                     missense variant
# 33487                                                     missense variant
# 33487                                                upstream gene variant
# 33487                                                upstream gene variant
# 33488                                   non coding transcript exon variant
#
# [275979 rows x 55 columns]

# %%
df_1 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Madhu_folder_04_07_2023/kidney_health_final.vcf/consequence.xlsx')
df_1
# Out:
#                             consequence Consequence_score
# 0                   transcript ablation             10/10
# 1               splice acceptor variant              8/10
# 2                  splice donor variant              8/10
# 3                           stop gained             10/10
# 4                    frameshift variant             10/10
# 5                             stop lost              9/10
# 6                            start lost              9/10
# 7              transcript amplification              8/10
# 8                     inframe insertion              6/10
# 9                      inframe deletion              6/10
# 10                     missense variant              7/10
# 11             protein altering variant              5/10
# 12                splice region variant              4/10
# 13        splice donor 5th base variant              4/10
# 14          splice donor region variant              4/10
# 15  splice polypyrimidine tract variant              4/10
# 16    incomplete terminal codon variant              3/10
# 17               start retained variant              3/10
# 18                stop retained variant              3/10
# 19                   synonymous variant              3/10
# 20              coding sequence variant              3/10
# 21                 mature miRNA variant              3/10
# 22                  5 prime UTR variant              3/10
# 23                  3 prime UTR variant              3/10
# 24   non coding transcript exon variant              2/10
# 25                       intron variant              2/10
# 26               NMD transcript variant              2/10
# 27        non coding transcript variant              2/10
# 28                upstream gene variant              2/10
# 29              downstream gene variant              2/10
# 30                        TFBS ablation              2/10
# 31                   TFBS amplification              2/10
# 32              TF binding site variant              2/10
# 33           regulatory region ablation              2/10
# 34      regulatory region amplification              2/10
# 35                   feature elongation              2/10
# 36            regulatory region variant              2/10
# 37                   feature truncation              1/10
# 38                   intergenic variant              1/10

# %%
merged_1 = pd.merge(vcf, df_1, on='consequence', how='left', sort=False)
merged_1
# Out:
#        CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0       chr1     69270  rs201219564   A   G    .   PASS
# 1       chr1     69511    rs2691305   A   G    .   PASS
# 2       chr1     69897  rs200676709   T   C    .   PASS
# 3       chr1    685694            .   T   C    .   PASS
# 4       chr1    685694            .   T   C    .   PASS
# ...      ...       ...          ...  ..  ..  ...    ...
# 275974  chrY   9467257  rs777840135   G   A    .   PASS
# 275975  chrY   9467257  rs777840135   G   A    .   PASS
# 275976  chrY   9467257  rs777840135   G   A    .   PASS
# 275977  chrY   9467257  rs777840135   G   A    .   PASS
# 275978  chrY  21311315   rs17250535   T   A    .   PASS
#
#                                                      INFO   GT   GQ  SDP   DP  \
# 0       ADP=143;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  137  143  143
# 1       ADP=168;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  168  168
# 2       ADP=98;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1  109   98   98
# 3       ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# 4       ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# ...                                                   ...  ...  ...  ...  ...
# 275974  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 275975  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 275976  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 275977  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 275978  ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9319,0....  1/1  105   19   19
#
#          RD   AD    FREQ         PVAL  RDF RDR  ADF ADR HET HOM      Zygosity  \
# 0       102   41  28.67%   1.5868E-14   99   3   33   8   1   0  Heterozygous
# 1         0  168    100%  1.6424E-100    0   0  145  23   0   1    Homozygous
# 2        66   32  32.65%   1.1206E-11   52  14   25   7   1   0  Heterozygous
# 3        12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# 4        12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# ...     ...  ...     ...          ...  ...  ..  ...  ..  ..  ..           ...
# 275974  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 275975  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 275976  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 275977  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 275978    0   19    100%   2.8292E-11    0   0   17   2   0   1    Homozygous
#
#        Gene Name                                                CSQ  \
# 0          OR4F5  G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1          OR4F5  G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2          OR4F5  C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 3                 C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 4                 C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# ...          ...                                                ...
# 275974     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 275975     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 275976     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 275977     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 275978            A|non_coding_transcript_exon_variant|MODIFIER|...
#
#                                                       csq Allele  \
# 0       G|synonymous_variant|LOW|OR4F5|ENSG00000186092...      G
# 1       G|missense_variant|MODERATE|OR4F5|ENSG00000186...      G
# 2       C|synonymous_variant|LOW|OR4F5|ENSG00000186092...      C
# 3       C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...      C
# 4       C|intron_variant&non_coding_transcript_variant...      C
# ...                                                   ...    ...
# 275974  A|missense_variant|MODERATE|TSPY1|ENSG00000258...      A
# 275975  A|missense_variant|MODERATE|TSPY1|ENSG00000258...      A
# 275976  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...      A
# 275977  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...      A
# 275978  A|non_coding_transcript_exon_variant|MODIFIER|...      A
#
#                                          Consequence    IMPACT    SYMBOL  \
# 0                                 synonymous_variant       LOW     OR4F5
# 1                                   missense_variant  MODERATE     OR4F5
# 2                                 synonymous_variant       LOW     OR4F5
# 3                            downstream_gene_variant  MODIFIER    OR4F16
# 4       intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                              ...       ...       ...
# 275974                              missense_variant  MODERATE     TSPY1
# 275975                              missense_variant  MODERATE     TSPY1
# 275976                         upstream_gene_variant  MODIFIER  FAM197Y5
# 275977                         upstream_gene_variant  MODIFIER  FAM197Y5
# 275978            non_coding_transcript_exon_variant  MODIFIER
#
#                    Gene Feature_type          Feature                 BIOTYPE  \
# 0       ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 1       ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 2       ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 3       ENSG00000284662   Transcript  ENST00000332831          protein_coding
# 4       ENSG00000230021   Transcript  ENST00000419394    processed_transcript
# ...                 ...          ...              ...                     ...
# 275974  ENSG00000258992   Transcript  ENST00000423647          protein_coding
# 275975  ENSG00000258992   Transcript  ENST00000451548          protein_coding
# 275976  ENSG00000225516   Transcript  ENST00000615605    processed_transcript
# 275977  ENSG00000225516   Transcript  ENST00000619815    processed_transcript
# 275978  ENSG00000226918   Transcript  ENST00000437359  unprocessed_pseudogene
#
#        EXON INTRON HGVSc HGVSp cDNA_position CDS_position Protein_position  \
# 0       3/3                              303          243               81
# 1       3/3                              544          484              162
# 2       3/3                              930          870              290
# 3
# 4              3/3
# ...     ...    ...   ...   ...           ...          ...              ...
# 275974  1/6                              303          257               86
# 275975  1/6                              303          257               86
# 275976
# 275977
# 275978  1/9                               48
#
#        Amino_acids   Codons Existing_variation DISTANCE STRAND FLAGS  \
# 0                S  tcA/tcG                                  1
# 1              T/A  Aca/Gca                                  1
# 2                S  tcT/tcC                                  1
# 3                                                    22     -1
# 4                                                           -1
# ...            ...      ...                ...      ...    ...   ...
# 275974         R/Q  cGg/cAg                                  1
# 275975         R/Q  cGg/cAg                                  1
# 275976                                             2900     -1
# 275977                                             2912     -1
# 275978                                                       1
#
#        SYMBOL_SOURCE     HGNC_ID SOURCE ClinVar ClinVar_CLNSIG  \
# 0               HGNC  HGNC:14825
# 1               HGNC  HGNC:14825
# 2               HGNC  HGNC:14825
# 3               HGNC  HGNC:15079
# 4
# ...              ...         ...    ...     ...            ...
# 275974          HGNC  HGNC:12381
# 275975          HGNC  HGNC:12381
# 275976          HGNC  HGNC:37467
# 275977          HGNC  HGNC:37467
# 275978
#
#        ClinVar_CLNREVSTAT ClinVar_CLNDN                         consequence  \
# 0                                                        synonymous variant
# 1                                                          missense variant
# 2                                                        synonymous variant
# 3                                                   downstream gene variant
# 4                                                            intron variant
# ...                   ...           ...                                 ...
# 275974                                                     missense variant
# 275975                                                     missense variant
# 275976                                                upstream gene variant
# 275977                                                upstream gene variant
# 275978                                   non coding transcript exon variant
#
#        Consequence_score
# 0                   3/10
# 1                   7/10
# 2                   3/10
# 3                   2/10
# 4                   2/10
# ...                  ...
# 275974              7/10
# 275975              7/10
# 275976              2/10
# 275977              2/10
# 275978              2/10
#
# [275979 rows x 56 columns]

# %%
df_2 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Madhu_folder_04_07_2023/kidney_health_final.vcf/IMPACT.xlsx')
df_2
# Out:
#      IMPACT  IMPACT_score
# 0      HIGH          10.0
# 1  MODERATE           5.0
# 2       LOW           2.5
# 3  MODIFIER           1.5

# %%
merged_2 = pd.merge(merged_1, df_2, on = 'IMPACT', how='left', sort=False)
merged_2
# Out:
#        CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0       chr1     69270  rs201219564   A   G    .   PASS
# 1       chr1     69511    rs2691305   A   G    .   PASS
# 2       chr1     69897  rs200676709   T   C    .   PASS
# 3       chr1    685694            .   T   C    .   PASS
# 4       chr1    685694            .   T   C    .   PASS
# ...      ...       ...          ...  ..  ..  ...    ...
# 275974  chrY   9467257  rs777840135   G   A    .   PASS
# 275975  chrY   9467257  rs777840135   G   A    .   PASS
# 275976  chrY   9467257  rs777840135   G   A    .   PASS
# 275977  chrY   9467257  rs777840135   G   A    .   PASS
# 275978  chrY  21311315   rs17250535   T   A    .   PASS
#
#                                                      INFO   GT   GQ  SDP   DP  \
# 0       ADP=143;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  137  143  143
# 1       ADP=168;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  168  168
# 2       ADP=98;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1  109   98   98
# 3       ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# 4       ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# ...                                                   ...  ...  ...  ...  ...
# 275974  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 275975  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 275976  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 275977  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 275978  ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9319,0....  1/1  105   19   19
#
#          RD   AD    FREQ         PVAL  RDF RDR  ADF ADR HET HOM      Zygosity  \
# 0       102   41  28.67%   1.5868E-14   99   3   33   8   1   0  Heterozygous
# 1         0  168    100%  1.6424E-100    0   0  145  23   0   1    Homozygous
# 2        66   32  32.65%   1.1206E-11   52  14   25   7   1   0  Heterozygous
# 3        12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# 4        12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# ...     ...  ...     ...          ...  ...  ..  ...  ..  ..  ..           ...
# 275974  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 275975  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 275976  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 275977  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 275978    0   19    100%   2.8292E-11    0   0   17   2   0   1    Homozygous
#
#        Gene Name                                                CSQ  \
# 0          OR4F5  G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1          OR4F5  G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2          OR4F5  C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 3                 C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 4                 C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# ...          ...                                                ...
# 275974     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 275975     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 275976     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 275977     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 275978            A|non_coding_transcript_exon_variant|MODIFIER|...
#
#                                                       csq Allele  \
# 0       G|synonymous_variant|LOW|OR4F5|ENSG00000186092...      G
# 1       G|missense_variant|MODERATE|OR4F5|ENSG00000186...      G
# 2       C|synonymous_variant|LOW|OR4F5|ENSG00000186092...      C
# 3       C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...      C
# 4       C|intron_variant&non_coding_transcript_variant...      C
# ...                                                   ...    ...
# 275974  A|missense_variant|MODERATE|TSPY1|ENSG00000258...      A
# 275975  A|missense_variant|MODERATE|TSPY1|ENSG00000258...      A
# 275976  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...      A
# 275977  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...      A
# 275978  A|non_coding_transcript_exon_variant|MODIFIER|...      A
#
#                                          Consequence    IMPACT    SYMBOL  \
# 0                                 synonymous_variant       LOW     OR4F5
# 1                                   missense_variant  MODERATE     OR4F5
# 2                                 synonymous_variant       LOW     OR4F5
# 3                            downstream_gene_variant  MODIFIER    OR4F16
# 4       intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                              ...       ...       ...
# 275974                              missense_variant  MODERATE     TSPY1
# 275975                              missense_variant  MODERATE     TSPY1
# 275976                         upstream_gene_variant  MODIFIER  FAM197Y5
# 275977                         upstream_gene_variant  MODIFIER  FAM197Y5
# 275978            non_coding_transcript_exon_variant  MODIFIER
#
#                    Gene Feature_type          Feature                 BIOTYPE  \
# 0       ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 1       ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 2       ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 3       ENSG00000284662   Transcript  ENST00000332831          protein_coding
# 4       ENSG00000230021   Transcript  ENST00000419394    processed_transcript
# ...                 ...          ...              ...                     ...
# 275974  ENSG00000258992   Transcript  ENST00000423647          protein_coding
# 275975  ENSG00000258992   Transcript  ENST00000451548          protein_coding
# 275976  ENSG00000225516   Transcript  ENST00000615605    processed_transcript
# 275977  ENSG00000225516   Transcript  ENST00000619815    processed_transcript
# 275978  ENSG00000226918   Transcript  ENST00000437359  unprocessed_pseudogene
#
#        EXON INTRON HGVSc HGVSp cDNA_position CDS_position Protein_position  \
# 0       3/3                              303          243               81
# 1       3/3                              544          484              162
# 2       3/3                              930          870              290
# 3
# 4              3/3
# ...     ...    ...   ...   ...           ...          ...              ...
# 275974  1/6                              303          257               86
# 275975  1/6                              303          257               86
# 275976
# 275977
# 275978  1/9                               48
#
#        Amino_acids   Codons Existing_variation DISTANCE STRAND FLAGS  \
# 0                S  tcA/tcG                                  1
# 1              T/A  Aca/Gca                                  1
# 2                S  tcT/tcC                                  1
# 3                                                    22     -1
# 4                                                           -1
# ...            ...      ...                ...      ...    ...   ...
# 275974         R/Q  cGg/cAg                                  1
# 275975         R/Q  cGg/cAg                                  1
# 275976                                             2900     -1
# 275977                                             2912     -1
# 275978                                                       1
#
#        SYMBOL_SOURCE     HGNC_ID SOURCE ClinVar ClinVar_CLNSIG  \
# 0               HGNC  HGNC:14825
# 1               HGNC  HGNC:14825
# 2               HGNC  HGNC:14825
# 3               HGNC  HGNC:15079
# 4
# ...              ...         ...    ...     ...            ...
# 275974          HGNC  HGNC:12381
# 275975          HGNC  HGNC:12381
# 275976          HGNC  HGNC:37467
# 275977          HGNC  HGNC:37467
# 275978
#
#        ClinVar_CLNREVSTAT ClinVar_CLNDN                         consequence  \
# 0                                                        synonymous variant
# 1                                                          missense variant
# 2                                                        synonymous variant
# 3                                                   downstream gene variant
# 4                                                            intron variant
# ...                   ...           ...                                 ...
# 275974                                                     missense variant
# 275975                                                     missense variant
# 275976                                                upstream gene variant
# 275977                                                upstream gene variant
# 275978                                   non coding transcript exon variant
#
#        Consequence_score  IMPACT_score
# 0                   3/10           2.5
# 1                   7/10           5.0
# 2                   3/10           2.5
# 3                   2/10           1.5
# 4                   2/10           1.5
# ...                  ...           ...
# 275974              7/10           5.0
# 275975              7/10           5.0
# 275976              2/10           1.5
# 275977              2/10           1.5
# 275978              2/10           1.5
#
# [275979 rows x 57 columns]

# %%
df_gene = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Hereditary_Cancer_New_genes.xlsx')
df_gene
# Out:
#    Gene Name
# 0        ATM
# 1      BARD1
# 2      BRCA1
# 3      BRCA2
# 4      BRIP1
# 5       CDH1
# 6     CDKN2A
# 7      CHEK2
# 8       MSH2
# 9       MSH6
# 10      PMS2
# 11     EPCAM
# 12      PTEN
# 13    RAD51C
# 14    RAD51D
# 15       NF1
# 16     PALB2
# 17     STK11
# 18      TP53
# 19       MRI
# 20      RRSO
# 21       RRM
# 22     FANCC
# 23     MRE11
# 24     MUTYH
# 25       NBN
# 26     RAD50
# 27     RECQL
# 28     RINT1
# 29      SLX4
# 30   SMARCA4
# 31     XRCC2
# 32    HOXB13

# %%
merged_2['Gene_Match'] = 'No'

# Iterate through each gene in df1
for genes in merged_2['Gene Name']:
    if isinstance(genes, str):  # Check if the gene value is a non-null string
        gene_list = genes.split(',')  # Split the genes by comma to create a list
        match = any(gene in df_gene['Gene Name'].values for gene in gene_list)  # Check if any gene in the list exists in df2
        if match:
            merged_2.loc[merged_2['Gene Name'] == genes, 'Gene_Match'] = 'Yes'
            
merged_2
# Out:
#        CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0       chr1     69270  rs201219564   A   G    .   PASS
# 1       chr1     69511    rs2691305   A   G    .   PASS
# 2       chr1     69897  rs200676709   T   C    .   PASS
# 3       chr1    685694            .   T   C    .   PASS
# 4       chr1    685694            .   T   C    .   PASS
# ...      ...       ...          ...  ..  ..  ...    ...
# 275974  chrY   9467257  rs777840135   G   A    .   PASS
# 275975  chrY   9467257  rs777840135   G   A    .   PASS
# 275976  chrY   9467257  rs777840135   G   A    .   PASS
# 275977  chrY   9467257  rs777840135   G   A    .   PASS
# 275978  chrY  21311315   rs17250535   T   A    .   PASS
#
#                                                      INFO   GT   GQ  SDP   DP  \
# 0       ADP=143;WT=0;HET=1;HOM=0;NC=0;ASP;G5;G5A;GENEI...  0/1  137  143  143
# 1       ADP=168;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  168  168
# 2       ADP=98;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1  109   98   98
# 3       ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# 4       ADP=18;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   20   18   18
# ...                                                   ...  ...  ...  ...  ...
# 275974  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 275975  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 275976  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 275977  ADP=241;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=TSP...  0/1  224  241  241
# 275978  ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.9319,0....  1/1  105   19   19
#
#          RD   AD    FREQ         PVAL  RDF RDR  ADF ADR HET HOM      Zygosity  \
# 0       102   41  28.67%   1.5868E-14   99   3   33   8   1   0  Heterozygous
# 1         0  168    100%  1.6424E-100    0   0  145  23   0   1    Homozygous
# 2        66   32  32.65%   1.1206E-11   52  14   25   7   1   0  Heterozygous
# 3        12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# 4        12    6  33.33%    9.5308E-3   12   0    6   0   1   0  Heterozygous
# ...     ...  ...     ...          ...  ...  ..  ...  ..  ..  ..           ...
# 275974  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 275975  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 275976  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 275977  174   67   27.8%    3.236E-23  132  42   58   9   1   0  Heterozygous
# 275978    0   19    100%   2.8292E-11    0   0   17   2   0   1    Homozygous
#
#        Gene Name                                                CSQ  \
# 0          OR4F5  G|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 1          OR4F5  G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 2          OR4F5  C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 3                 C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 4                 C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# ...          ...                                                ...
# 275974     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 275975     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 275976     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 275977     TSPY1  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...
# 275978            A|non_coding_transcript_exon_variant|MODIFIER|...
#
#                                                       csq Allele  \
# 0       G|synonymous_variant|LOW|OR4F5|ENSG00000186092...      G
# 1       G|missense_variant|MODERATE|OR4F5|ENSG00000186...      G
# 2       C|synonymous_variant|LOW|OR4F5|ENSG00000186092...      C
# 3       C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...      C
# 4       C|intron_variant&non_coding_transcript_variant...      C
# ...                                                   ...    ...
# 275974  A|missense_variant|MODERATE|TSPY1|ENSG00000258...      A
# 275975  A|missense_variant|MODERATE|TSPY1|ENSG00000258...      A
# 275976  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...      A
# 275977  A|upstream_gene_variant|MODIFIER|FAM197Y5|ENSG...      A
# 275978  A|non_coding_transcript_exon_variant|MODIFIER|...      A
#
#                                          Consequence    IMPACT    SYMBOL  \
# 0                                 synonymous_variant       LOW     OR4F5
# 1                                   missense_variant  MODERATE     OR4F5
# 2                                 synonymous_variant       LOW     OR4F5
# 3                            downstream_gene_variant  MODIFIER    OR4F16
# 4       intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                              ...       ...       ...
# 275974                              missense_variant  MODERATE     TSPY1
# 275975                              missense_variant  MODERATE     TSPY1
# 275976                         upstream_gene_variant  MODIFIER  FAM197Y5
# 275977                         upstream_gene_variant  MODIFIER  FAM197Y5
# 275978            non_coding_transcript_exon_variant  MODIFIER
#
#                    Gene Feature_type          Feature                 BIOTYPE  \
# 0       ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 1       ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 2       ENSG00000186092   Transcript  ENST00000641515          protein_coding
# 3       ENSG00000284662   Transcript  ENST00000332831          protein_coding
# 4       ENSG00000230021   Transcript  ENST00000419394    processed_transcript
# ...                 ...          ...              ...                     ...
# 275974  ENSG00000258992   Transcript  ENST00000423647          protein_coding
# 275975  ENSG00000258992   Transcript  ENST00000451548          protein_coding
# 275976  ENSG00000225516   Transcript  ENST00000615605    processed_transcript
# 275977  ENSG00000225516   Transcript  ENST00000619815    processed_transcript
# 275978  ENSG00000226918   Transcript  ENST00000437359  unprocessed_pseudogene
#
#        EXON INTRON HGVSc HGVSp cDNA_position CDS_position Protein_position  \
# 0       3/3                              303          243               81
# 1       3/3                              544          484              162
# 2       3/3                              930          870              290
# 3
# 4              3/3
# ...     ...    ...   ...   ...           ...          ...              ...
# 275974  1/6                              303          257               86
# 275975  1/6                              303          257               86
# 275976
# 275977
# 275978  1/9                               48
#
#        Amino_acids   Codons Existing_variation DISTANCE STRAND FLAGS  \
# 0                S  tcA/tcG                                  1
# 1              T/A  Aca/Gca                                  1
# 2                S  tcT/tcC                                  1
# 3                                                    22     -1
# 4                                                           -1
# ...            ...      ...                ...      ...    ...   ...
# 275974         R/Q  cGg/cAg                                  1
# 275975         R/Q  cGg/cAg                                  1
# 275976                                             2900     -1
# 275977                                             2912     -1
# 275978                                                       1
#
#        SYMBOL_SOURCE     HGNC_ID SOURCE ClinVar ClinVar_CLNSIG  \
# 0               HGNC  HGNC:14825
# 1               HGNC  HGNC:14825
# 2               HGNC  HGNC:14825
# 3               HGNC  HGNC:15079
# 4
# ...              ...         ...    ...     ...            ...
# 275974          HGNC  HGNC:12381
# 275975          HGNC  HGNC:12381
# 275976          HGNC  HGNC:37467
# 275977          HGNC  HGNC:37467
# 275978
#
#        ClinVar_CLNREVSTAT ClinVar_CLNDN                         consequence  \
# 0                                                        synonymous variant
# 1                                                          missense variant
# 2                                                        synonymous variant
# 3                                                   downstream gene variant
# 4                                                            intron variant
# ...                   ...           ...                                 ...
# 275974                                                     missense variant
# 275975                                                     missense variant
# 275976                                                upstream gene variant
# 275977                                                upstream gene variant
# 275978                                   non coding transcript exon variant
#
#        Consequence_score  IMPACT_score Gene_Match
# 0                   3/10           2.5         No
# 1                   7/10           5.0         No
# 2                   3/10           2.5         No
# 3                   2/10           1.5         No
# 4                   2/10           1.5         No
# ...                  ...           ...        ...
# 275974              7/10           5.0         No
# 275975              7/10           5.0         No
# 275976              2/10           1.5         No
# 275977              2/10           1.5         No
# 275978              2/10           1.5         No
#
# [275979 rows x 58 columns]

# %%
merged_2[merged_2['Gene_Match'] == 'Yes']
# Out:
#        CHROM       POS       rsID REF ALT QUAL FILTER  \
# 10581   chr1  45331833  rs3219489   C   G    .   PASS
# 10582   chr1  45331833  rs3219489   C   G    .   PASS
# 10583   chr1  45331833  rs3219489   C   G    .   PASS
# 10584   chr1  45331833  rs3219489   C   G    .   PASS
# 10585   chr1  45331833  rs3219489   C   G    .   PASS
# ...      ...       ...        ...  ..  ..  ...    ...
# 266041  chr9  95099836  rs4647558   C   T    .   PASS
# 266042  chr9  95100419  rs4647554   A   G    .   PASS
# 266043  chr9  95100419  rs4647554   A   G    .   PASS
# 266044  chr9  95100419  rs4647554   A   G    .   PASS
# 266045  chr9  95100419  rs4647554   A   G    .   PASS
#
#                                                      INFO   GT  GQ SDP  DP  \
# 10581   ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6865,0....  0/1  63  32  32
# 10582   ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6865,0....  0/1  63  32  32
# 10583   ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6865,0....  0/1  63  32  32
# 10584   ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6865,0....  0/1  63  32  32
# 10585   ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.6865,0....  0/1  63  32  32
# ...                                                   ...  ...  ..  ..  ..
# 266041  ADP=59;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.5865,0....  0/1  98  59  59
# 266042  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.4972,0....  0/1  45  32  32
# 266043  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.4972,0....  0/1  45  32  32
# 266044  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.4972,0....  0/1  45  32  32
# 266045  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.4972,0....  0/1  45  32  32
#
#         RD  AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity  \
# 10581   15  17  53.12%   4.1013E-7  13   2  15   2   1   0  Heterozygous
# 10582   15  17  53.12%   4.1013E-7  13   2  15   2   1   0  Heterozygous
# 10583   15  17  53.12%   4.1013E-7  13   2  15   2   1   0  Heterozygous
# 10584   15  17  53.12%   4.1013E-7  13   2  15   2   1   0  Heterozygous
# 10585   15  17  53.12%   4.1013E-7  13   2  15   2   1   0  Heterozygous
# ...     ..  ..     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 266041  32  27  45.76%  1.5211E-10  24   8  23   4   1   0  Heterozygous
# 266042  19  13  40.62%   2.6443E-5  15   4  11   2   1   0  Heterozygous
# 266043  19  13  40.62%   2.6443E-5  15   4  11   2   1   0  Heterozygous
# 266044  19  13  40.62%   2.6443E-5  15   4  11   2   1   0  Heterozygous
# 266045  19  13  40.62%   2.6443E-5  15   4  11   2   1   0  Heterozygous
#
#            Gene Name                                                CSQ  \
# 10581          MUTYH  G|downstream_gene_variant|MODIFIER|HPDL|ENSG00...
# 10582          MUTYH  G|downstream_gene_variant|MODIFIER|HPDL|ENSG00...
# 10583          MUTYH  G|downstream_gene_variant|MODIFIER|HPDL|ENSG00...
# 10584          MUTYH  G|downstream_gene_variant|MODIFIER|HPDL|ENSG00...
# 10585          MUTYH  G|downstream_gene_variant|MODIFIER|HPDL|ENSG00...
# ...              ...                                                ...
# 266041  FANCC,C9orf3  T|3_prime_UTR_variant|MODIFIER|FANCC|ENSG00000...
# 266042  FANCC,C9orf3  G|3_prime_UTR_variant|MODIFIER|FANCC|ENSG00000...
# 266043  FANCC,C9orf3  G|3_prime_UTR_variant|MODIFIER|FANCC|ENSG00000...
# 266044  FANCC,C9orf3  G|3_prime_UTR_variant|MODIFIER|FANCC|ENSG00000...
# 266045  FANCC,C9orf3  G|3_prime_UTR_variant|MODIFIER|FANCC|ENSG00000...
#
#                                                       csq Allele  \
# 10581   G|downstream_gene_variant|MODIFIER|HPDL|ENSG00...      G
# 10582   G|missense_variant|MODERATE|MUTYH|ENSG00000132...      G
# 10583   G|missense_variant|MODERATE|MUTYH|ENSG00000132...      G
# 10584   G|missense_variant|MODERATE|MUTYH|ENSG00000132...      G
# 10585   G|missense_variant|MODERATE|MUTYH|ENSG00000132...      G
# ...                                                   ...    ...
# 266041  T|non_coding_transcript_exon_variant|MODIFIER|...      T
# 266042  G|3_prime_UTR_variant|MODIFIER|FANCC|ENSG00000...      G
# 266043  G|3_prime_UTR_variant|MODIFIER|FANCC|ENSG00000...      G
# 266044  G|downstream_gene_variant|MODIFIER|FANCC|ENSG0...      G
# 266045  G|non_coding_transcript_exon_variant|MODIFIER|...      G
#
#                                Consequence    IMPACT SYMBOL             Gene  \
# 10581              downstream_gene_variant  MODIFIER   HPDL  ENSG00000186603
# 10582                     missense_variant  MODERATE  MUTYH  ENSG00000132781
# 10583                     missense_variant  MODERATE  MUTYH  ENSG00000132781
# 10584                     missense_variant  MODERATE  MUTYH  ENSG00000132781
# 10585                     missense_variant  MODERATE  MUTYH  ENSG00000132781
# ...                                    ...       ...    ...              ...
# 266041  non_coding_transcript_exon_variant  MODIFIER  FANCC  ENSG00000158169
# 266042                 3_prime_UTR_variant  MODIFIER  FANCC  ENSG00000158169
# 266043                 3_prime_UTR_variant  MODIFIER  FANCC  ENSG00000158169
# 266044             downstream_gene_variant  MODIFIER  FANCC  ENSG00000158169
# 266045  non_coding_transcript_exon_variant  MODIFIER  FANCC  ENSG00000158169
#
#        Feature_type          Feature                  BIOTYPE   EXON INTRON  \
# 10581    Transcript  ENST00000334815           protein_coding
# 10582    Transcript  ENST00000354383           protein_coding  12/16
# 10583    Transcript  ENST00000355498           protein_coding  12/16
# 10584    Transcript  ENST00000372098           protein_coding  12/16
# 10585    Transcript  ENST00000372104           protein_coding  13/17
# ...             ...              ...                      ...    ...    ...
# 266041   Transcript  ENST00000696260          retained_intron    3/3
# 266042   Transcript  ENST00000289081           protein_coding  15/15
# 266043   Transcript  ENST00000375305           protein_coding  15/15
# 266044   Transcript  ENST00000649334  nonsense_mediated_decay
# 266045   Transcript  ENST00000696260          retained_intron    3/3
#
#        HGVSc HGVSp cDNA_position CDS_position Protein_position Amino_acids  \
# 10581
# 10582                       1044          933              311         Q/H
# 10583                       1076          930              310         Q/H
# 10584                       1139         1005              335         Q/H
# 10585                       1123          930              310         Q/H
# ...      ...   ...           ...          ...              ...         ...
# 266041                      4363
# 266042                      3227
# 266043                      3169
# 266044
# 266045                      3780
#
#          Codons Existing_variation DISTANCE STRAND FLAGS SYMBOL_SOURCE  \
# 10581                                  3123      1                HGNC
# 10582   caG/caC                                 -1                HGNC
# 10583   caG/caC                                 -1                HGNC
# 10584   caG/caC                                 -1                HGNC
# 10585   caG/caC                                 -1                HGNC
# ...         ...                ...      ...    ...   ...           ...
# 266041                                          -1                HGNC
# 266042                                          -1                HGNC
# 266043                                          -1                HGNC
# 266044                                 1291     -1                HGNC
# 266045                                          -1                HGNC
#
#            HGNC_ID SOURCE ClinVar ClinVar_CLNSIG  \
# 10581   HGNC:28242          41767         Benign
# 10582    HGNC:7527          41767         Benign
# 10583    HGNC:7527          41767         Benign
# 10584    HGNC:7527          41767         Benign
# 10585    HGNC:7527          41767         Benign
# ...            ...    ...     ...            ...
# 266041   HGNC:3584         367581         Benign
# 266042   HGNC:3584         367589         Benign
# 266043   HGNC:3584         367589         Benign
# 266044   HGNC:3584         367589         Benign
# 266045   HGNC:3584         367589         Benign
#
#                                        ClinVar_CLNREVSTAT  \
# 10581   criteria_provided&_multiple_submitters&_no_con...
# 10582   criteria_provided&_multiple_submitters&_no_con...
# 10583   criteria_provided&_multiple_submitters&_no_con...
# 10584   criteria_provided&_multiple_submitters&_no_con...
# 10585   criteria_provided&_multiple_submitters&_no_con...
# ...                                                   ...
# 266041                criteria_provided&_single_submitter
# 266042                criteria_provided&_single_submitter
# 266043                criteria_provided&_single_submitter
# 266044                criteria_provided&_single_submitter
# 266045                criteria_provided&_single_submitter
#
#                                             ClinVar_CLNDN  \
# 10581   Carcinoma_of_colon&MUTYH-related_attenuated_fa...
# 10582   Carcinoma_of_colon&MUTYH-related_attenuated_fa...
# 10583   Carcinoma_of_colon&MUTYH-related_attenuated_fa...
# 10584   Carcinoma_of_colon&MUTYH-related_attenuated_fa...
# 10585   Carcinoma_of_colon&MUTYH-related_attenuated_fa...
# ...                                                   ...
# 266041             Fanconi_anemia_complementation_group_C
# 266042             Fanconi_anemia_complementation_group_C
# 266043             Fanconi_anemia_complementation_group_C
# 266044             Fanconi_anemia_complementation_group_C
# 266045             Fanconi_anemia_complementation_group_C
#
#                                consequence Consequence_score  IMPACT_score  \
# 10581              downstream gene variant              2/10           1.5
# 10582                     missense variant              7/10           5.0
# 10583                     missense variant              7/10           5.0
# 10584                     missense variant              7/10           5.0
# 10585                     missense variant              7/10           5.0
# ...                                    ...               ...           ...
# 266041  non coding transcript exon variant              2/10           1.5
# 266042                 3 prime UTR variant              3/10           1.5
# 266043                 3 prime UTR variant              3/10           1.5
# 266044             downstream gene variant              2/10           1.5
# 266045  non coding transcript exon variant              2/10           1.5
#
#        Gene_Match
# 10581         Yes
# 10582         Yes
# 10583         Yes
# 10584         Yes
# 10585         Yes
# ...           ...
# 266041        Yes
# 266042        Yes
# 266043        Yes
# 266044        Yes
# 266045        Yes
#
# [1726 rows x 58 columns]

# %%
merged_2.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Processed_vcf_files/KHGLBS448_final_depth_vcf_processed.xlsx', index=False)
