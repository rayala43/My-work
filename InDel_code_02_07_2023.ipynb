# %%
import numpy as np
import pandas as pd
import polars as pl
import sys
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px


pd.set_option('display.max_columns',None)
import psycopg2


#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Algorithms to use
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

#Metrics to evaluate the model
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve

import warnings
warnings.filterwarnings("ignore")

#importing PCA and TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
def read_bed_file(bed_file):
    bed_positions = set()
    with open(bed_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Skip header lines if present
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 3:
                chrom = fields[0]
                try:
                    start = int(fields[1])
                    end = int(fields[2])
                except ValueError:
                    continue  # Skip this line if start or end position is not an integer
                for pos in range(start, end + 1):
                    bed_positions.add((chrom, pos))
    return bed_positions

def normalize_chrom_name(chrom):
    return chrom.split('_')[0]

def filter_vcf_file(vcf_file, bed_positions):
    filtered_vcf_records = []
    with open(vcf_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Preserve header lines in the output
                filtered_vcf_records.append(line)
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 2:
                raw_chrom = fields[0]
                chrom = normalize_chrom_name(raw_chrom)
                try:
                    pos = int(fields[1])
                except ValueError:
                    continue  # Skip this line if 'POS' is not an integer
                if (chrom, pos) in bed_positions:
                    filtered_vcf_records.append(line)
    return filtered_vcf_records

def write_filtered_vcf(filtered_vcf_records, output_file):
    with open(output_file, 'w') as f:
        for record in filtered_vcf_records:
            f.write(record)

def main():
    bed_file = r'C:/Users/GenepoweRx_Madhu/Downloads/BED_files/kalyani_mam_covered.bed'
    vcf_file = r'C:/Users/GenepoweRx_Madhu/Downloads/vcf_files_all/KHGLBS567/KHGLBS567_annotated_indel.vcf'
    output_file = r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/KHGLBS567_annotated_indel.vcf'

    bed_positions = read_bed_file(bed_file)
    filtered_vcf_records = filter_vcf_file(vcf_file, bed_positions)
    write_filtered_vcf(filtered_vcf_records, output_file)

if __name__ == "__main__":
    main()

# %%
data = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/KHGLBS567_annotated_indel.vcf', comment='#', sep= '\t', header=None, low_memory=False)
data.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']
data
# Out:
#      CHROM        POS                      rsID     REF ALT QUAL FILTER  \
# 0     chr1    1043223                rs35881187     CCT   C    .   PASS
# 1     chr1    1331945               rs200330269       G  GC    .   PASS
# 2     chr1    1353987               rs140777846     CTG   C    .   PASS
# 3     chr1    1355779               rs201260508      GA   G    .   PASS
# 4     chr1    1387763                rs35654872     CCT   C    .   PASS
# ...    ...        ...                       ...     ...  ..  ...    ...
# 2926  chrX  154585478              rs1372477485  ATTCTG   A    .   PASS
# 2927  chrX  155228363               rs781912204       A  AT    .   PASS
# 2928  chrX  155492733  rs1169019545;rs376271737       T  TG    .   PASS
# 2929  chrY   12786501               rs760255651      CT   C    .   PASS
# 2930  chrY   21311242               rs202147921       A  AT    .   PASS
#
#                                                    INFO  \
# 0     ADP=24;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.5208,0....
# 1     ADP=50;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8105,0....
# 2     ADP=58;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1793,0....
# 3     ADP=18;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,1;COMMO...
# 4     ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6565,0....
# ...                                                 ...
# 2926  ADP=18;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=CTAG...
# 2927  ADP=23;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=VBP1...
# 2928  ADP=23;WT=0;HET=0;HOM=1;NC=0;ASP;GENEINFO=TMLH...
# 2929  ADP=20;WT=0;HET=0;HOM=1;NC=0;ASP;GENEINFO=USP9...
# 2930  ADP=29;WT=0;HET=1;HOM=0;NC=0;ASP;RS=202147921;...
#
#                                                  FORMAT  \
# 0     GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 1     GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2     GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 3     GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 4     GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# ...                                                 ...
# 2926  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2927  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2928  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2929  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
# 2930  GT:GQ:SDP:DP:RD:AD:FREQ:PVAL:RBQ:ABQ:RDF:RDR:A...
#
#                                                  SAMPLE
# 0       1/1:135:24:24:0:24:100%:3.101E-14:0:19:0:0:20:4
# 1      0/1:58:50:50:32:17:34%:1.4216E-6:42:35:9:23:1:16
# 2     1/1:255:58:58:2:56:96.55%:2.8822E-31:63:49:2:0...
# 3      1/1:60:18:18:4:14:77.78%:8.0605E-7:32:40:0:4:9:5
# 4      1/1:105:19:19:0:19:100%:2.8292E-11:0:19:0:0:17:2
# ...                                                 ...
# 2926   0/1:42:18:18:7:11:61.11%:5.2969E-5:42:58:2:5:7:4
# 2927  0/1:66:23:23:4:15:65.22%:2.5053E-7:46:47:4:0:13:2
# 2928  1/1:115:23:23:1:22:95.65%:2.9149E-12:35:46:0:1...
# 2929     1/1:71:20:20:2:15:75%:7.3277E-8:55:44:2:0:13:2
# 2930  0/1:90:29:29:7:21:72.41%:8.7917E-10:55:52:6:1:...
#
# [2931 rows x 10 columns]

# %%
sample_cols = data['SAMPLE'].str.split(':', expand=True)
sample_cols.columns = ['GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RBQ', 'ABQ', 'RDF', 'RDR', 'ADF', 'ADR']

# Assign the values to the newly created columns
data = pd.concat([data, sample_cols], axis=1)
data = data[['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL','RDF', 'RDR', 'ADF', 'ADR']]
data
# Out:
#      CHROM        POS                      rsID     REF ALT QUAL FILTER  \
# 0     chr1    1043223                rs35881187     CCT   C    .   PASS
# 1     chr1    1331945               rs200330269       G  GC    .   PASS
# 2     chr1    1353987               rs140777846     CTG   C    .   PASS
# 3     chr1    1355779               rs201260508      GA   G    .   PASS
# 4     chr1    1387763                rs35654872     CCT   C    .   PASS
# ...    ...        ...                       ...     ...  ..  ...    ...
# 2926  chrX  154585478              rs1372477485  ATTCTG   A    .   PASS
# 2927  chrX  155228363               rs781912204       A  AT    .   PASS
# 2928  chrX  155492733  rs1169019545;rs376271737       T  TG    .   PASS
# 2929  chrY   12786501               rs760255651      CT   C    .   PASS
# 2930  chrY   21311242               rs202147921       A  AT    .   PASS
#
#                                                    INFO   GT   GQ SDP  DP  RD  \
# 0     ADP=24;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.5208,0....  1/1  135  24  24   0
# 1     ADP=50;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8105,0....  0/1   58  50  50  32
# 2     ADP=58;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1793,0....  1/1  255  58  58   2
# 3     ADP=18;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,1;COMMO...  1/1   60  18  18   4
# 4     ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6565,0....  1/1  105  19  19   0
# ...                                                 ...  ...  ...  ..  ..  ..
# 2926  ADP=18;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=CTAG...  0/1   42  18  18   7
# 2927  ADP=23;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=VBP1...  0/1   66  23  23   4
# 2928  ADP=23;WT=0;HET=0;HOM=1;NC=0;ASP;GENEINFO=TMLH...  1/1  115  23  23   1
# 2929  ADP=20;WT=0;HET=0;HOM=1;NC=0;ASP;GENEINFO=USP9...  1/1   71  20  20   2
# 2930  ADP=29;WT=0;HET=1;HOM=0;NC=0;ASP;RS=202147921;...  0/1   90  29  29   7
#
#       AD    FREQ        PVAL RDF RDR ADF ADR
# 0     24    100%   3.101E-14   0   0  20   4
# 1     17     34%   1.4216E-6   9  23   1  16
# 2     56  96.55%  2.8822E-31   2   0  51   5
# 3     14  77.78%   8.0605E-7   0   4   9   5
# 4     19    100%  2.8292E-11   0   0  17   2
# ...   ..     ...         ...  ..  ..  ..  ..
# 2926  11  61.11%   5.2969E-5   2   5   7   4
# 2927  15  65.22%   2.5053E-7   4   0  13   2
# 2928  22  95.65%  2.9149E-12   0   1   8  14
# 2929  15     75%   7.3277E-8   2   0  13   2
# 2930  21  72.41%  8.7917E-10   6   1  13   8
#
# [2931 rows x 20 columns]

# %%
# Create empty columns
columns = ['ADP', 'WT', 'HET', 'HOM', 'NC', 'CDA', 'OTH', 'S3D', 'WTD', 'dbSNPBuildID', 'SLO',
           'NSF', 'R3', 'R5', 'NSN', 'NSM', 'G5A', 'COMMON', 'RS', 'RV', 'TPA', 'CFL', 'GNO',
           'VLD', 'ASP', 'ASS', 'Ref', 'U3', 'U5', 'TOPMED', 'WGT', 'MTP', 'LSD', 'NOC',
           'DSS', 'SYN', 'KGPhase3', 'CAF', 'VC', 'MUT', 'KGPhase1', 'NOV', 'VP', 'SAO',
           'GENEINFO', 'INT', 'G5', 'OM', 'PMC', 'SSR', 'RSPOS', 'HD', 'PM', 'ClinVar',
           'ClinVar_CLNSIG']

for col in columns:
    data[col] = ''

# Populate columns based on 'INFO' values
for i, row in data.iterrows():
    info = row['INFO']
    items = info.split(';')
    for item in items:
        key_value = item.split('=')
        key = key_value[0]
        if key in columns:
            if len(key_value) > 1:
                value = key_value[1]
                data.at[i, key] = f"{key}={value}"
            else:
                data.at[i, key] = key
        else:
            data.at[i, key] = 'null'


            
data["Gene_Name"] = data["INFO"].str.extract('GENEINFO=(?P<GENEINFO>.+?);')
#data['Gene Name'] = data['Gene_Name'].apply(lambda x: ','.join([segment.split(':')[0] for segment in x.split('|')]) if pd.notnull(x) else '')
data['Gene Name'] = data['Gene_Name'].apply(lambda x: ','.join(set([segment.split(':')[0] for segment in x.split('|')])) if pd.notnull(x) else '')

# Print the resulting DataFrame
data
# Out:
#      CHROM        POS                      rsID     REF ALT QUAL FILTER  \
# 0     chr1    1043223                rs35881187     CCT   C    .   PASS
# 1     chr1    1331945               rs200330269       G  GC    .   PASS
# 2     chr1    1353987               rs140777846     CTG   C    .   PASS
# 3     chr1    1355779               rs201260508      GA   G    .   PASS
# 4     chr1    1387763                rs35654872     CCT   C    .   PASS
# ...    ...        ...                       ...     ...  ..  ...    ...
# 2926  chrX  154585478              rs1372477485  ATTCTG   A    .   PASS
# 2927  chrX  155228363               rs781912204       A  AT    .   PASS
# 2928  chrX  155492733  rs1169019545;rs376271737       T  TG    .   PASS
# 2929  chrY   12786501               rs760255651      CT   C    .   PASS
# 2930  chrY   21311242               rs202147921       A  AT    .   PASS
#
#                                                    INFO   GT   GQ SDP  DP  RD  \
# 0     ADP=24;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.5208,0....  1/1  135  24  24   0
# 1     ADP=50;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8105,0....  0/1   58  50  50  32
# 2     ADP=58;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.1793,0....  1/1  255  58  58   2
# 3     ADP=18;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,1;COMMO...  1/1   60  18  18   4
# 4     ADP=19;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.6565,0....  1/1  105  19  19   0
# ...                                                 ...  ...  ...  ..  ..  ..
# 2926  ADP=18;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=CTAG...  0/1   42  18  18   7
# 2927  ADP=23;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=VBP1...  0/1   66  23  23   4
# 2928  ADP=23;WT=0;HET=0;HOM=1;NC=0;ASP;GENEINFO=TMLH...  1/1  115  23  23   1
# 2929  ADP=20;WT=0;HET=0;HOM=1;NC=0;ASP;GENEINFO=USP9...  1/1   71  20  20   2
# 2930  ADP=29;WT=0;HET=1;HOM=0;NC=0;ASP;RS=202147921;...  0/1   90  29  29   7
#
#       AD    FREQ        PVAL RDF RDR ADF ADR     ADP    WT    HET    HOM  \
# 0     24    100%   3.101E-14   0   0  20   4  ADP=24  WT=0  HET=0  HOM=1
# 1     17     34%   1.4216E-6   9  23   1  16  ADP=50  WT=0  HET=1  HOM=0
# 2     56  96.55%  2.8822E-31   2   0  51   5  ADP=58  WT=0  HET=0  HOM=1
# 3     14  77.78%   8.0605E-7   0   4   9   5  ADP=18  WT=0  HET=0  HOM=1
# 4     19    100%  2.8292E-11   0   0  17   2  ADP=19  WT=0  HET=0  HOM=1
# ...   ..     ...         ...  ..  ..  ..  ..     ...   ...    ...    ...
# 2926  11  61.11%   5.2969E-5   2   5   7   4  ADP=18  WT=0  HET=1  HOM=0
# 2927  15  65.22%   2.5053E-7   4   0  13   2  ADP=23  WT=0  HET=1  HOM=0
# 2928  22  95.65%  2.9149E-12   0   1   8  14  ADP=23  WT=0  HET=0  HOM=1
# 2929  15     75%   7.3277E-8   2   0  13   2  ADP=20  WT=0  HET=0  HOM=1
# 2930  21  72.41%  8.7917E-10   6   1  13   8  ADP=29  WT=0  HET=1  HOM=0
#
#         NC CDA OTH S3D WTD          dbSNPBuildID  SLO NSF R3 R5 NSN NSM  G5A  \
# 0     NC=0                      dbSNPBuildID=126  SLO
# 1     NC=0                      dbSNPBuildID=137
# 2     NC=0                      dbSNPBuildID=134  SLO                    G5A
# 3     NC=0                      dbSNPBuildID=137
# 4     NC=0                      dbSNPBuildID=126  SLO
# ...    ...  ..  ..  ..  ..                   ...  ...  .. .. ..  ..  ..  ...
# 2926  NC=0                      dbSNPBuildID=151
# 2927  NC=0                      dbSNPBuildID=144
# 2928  NC=0                  dbSNPBuildID=151,138
# 2929  NC=0                      dbSNPBuildID=144
# 2930  NC=0                      dbSNPBuildID=137
#
#         COMMON                       RS  RV TPA CFL  GNO  VLD  ASP ASS Ref U3  \
# 0     COMMON=1              RS=35881187  RV          GNO  VLD  ASP
# 1     COMMON=1             RS=200330269                   VLD  ASP
# 2     COMMON=1             RS=140777846              GNO  VLD  ASP
# 3     COMMON=0             RS=201260508                        ASP
# 4     COMMON=1              RS=35654872  RV          GNO  VLD  ASP
# ...        ...                      ...  ..  ..  ..  ...  ...  ...  ..  .. ..
# 2926                      RS=1372477485                        ASP
# 2927                       RS=781912204                        ASP
# 2928            RS=1169019545,376271737                        ASP
# 2929                       RS=760255651                        ASP
# 2930                       RS=202147921                        ASP
#
#      U5                                             TOPMED      WGT MTP LSD  \
# 0           TOPMED=0.55968081039755351,0.44031918960244648    WGT=1
# 1        TOPMED=0.82975758154943934,0.17023445463812436...    WGT=1
# 2           TOPMED=0.13763857033639143,0.86236142966360856    WGT=1
# 3           TOPMED=0.22555109582059123,0.77444890417940876    WGT=1
# 4           TOPMED=0.43493565239551478,0.56506434760448521    WGT=1
# ...  ..                                                ...      ...  ..  ..
# 2926                                                          WGT=1
# 2927     TOPMED=0.43169438073394495,0.56314506880733944...    WGT=1
# 2928        TOPMED=0.35031218144750254,0.64968781855249745  WGT=1,1
# 2929                                                          WGT=1
# 2930                                                          WGT=1
#
#      NOC DSS SYN  KGPhase3                  CAF          VC MUT  KGPhase1  \
# 0                 KGPhase3    CAF=0.5208,0.4792      VC=DIV      KGPhase1
# 1                 KGPhase3  CAF=0.8105,0.1895,.      VC=DIV      KGPhase1
# 2                 KGPhase3    CAF=0.1793,0.8207      VC=DIV
# 3                 KGPhase3              CAF=0,1      VC=DIV      KGPhase1
# 4                 KGPhase3    CAF=0.6565,0.3435      VC=DIV      KGPhase1
# ...   ..  ..  ..       ...                  ...         ...  ..       ...
# 2926                                                 VC=DIV
# 2927                                                 VC=DIV
# 2928                                             VC=DIV,DIV
# 2929                                                 VC=DIV
# 2930                                                 VC=DIV
#
#       NOV                                                 VP      SAO  \
# 0                              VP=0x05012808000515013e000200    SAO=0
# 1                              VP=0x05000008000515003e000200    SAO=0
# 2                              VP=0x050100080005170126000200    SAO=0
# 3                              VP=0x05000008000500003e000200    SAO=0
# 4                              VP=0x05010008000515013e000200    SAO=0
# ...   ...                                                ...      ...
# 2926                           VP=0x050000080005000002000200    SAO=0
# 2927  NOV                      VP=0x050000080005000002000204    SAO=0
# 2928       VP=0x050000080005000002000200,0x05000008000500...  SAO=0,0
# 2929                           VP=0x050000080005000002000200    SAO=0
# 2930                           VP=0x050000000005000002000200    SAO=0
#
#                                                GENEINFO  INT  G5 OM  PMC  \
# 0                                  GENEINFO=AGRN:375790  INT  G5     PMC
# 1                                 GENEINFO=TAS1R3:83756  INT  G5
# 2                                  GENEINFO=MXRA8:54587  INT  G5
# 3                                  GENEINFO=MXRA8:54587  INT
# 4                                  GENEINFO=CCNL2:81669  INT  G5
# ...                                                 ...  ...  .. ..  ...
# 2926                             GENEINFO=CTAG1A:246100  INT
# 2927                                 GENEINFO=VBP1:7411  INT
# 2928  GENEINFO=TMLHE:55217|TMLHE-AS1:100507404,TMLHE...  INT
# 2929                                GENEINFO=USP9Y:8287  INT
# 2930
#
#           SSR                      RSPOS HD  PM ClinVar ClinVar_CLNSIG  \
# 0       SSR=0              RSPOS=1043224     PM
# 1       SSR=0              RSPOS=1331945
# 2       SSR=0              RSPOS=1353988
# 3       SSR=0              RSPOS=1355780
# 4       SSR=0              RSPOS=1387764
# ...       ...                        ... ..  ..     ...            ...
# 2926    SSR=0            RSPOS=154585479
# 2927    SSR=0            RSPOS=155228363
# 2928  SSR=0,0  RSPOS=155492733,155492734
# 2929    SSR=0             RSPOS=12786503
# 2930    SSR=0             RSPOS=21311242
#
#                                               Gene_Name        Gene Name
# 0                                           AGRN:375790             AGRN
# 1                                          TAS1R3:83756           TAS1R3
# 2                                           MXRA8:54587            MXRA8
# 3                                           MXRA8:54587            MXRA8
# 4                                           CCNL2:81669            CCNL2
# ...                                                 ...              ...
# 2926                                      CTAG1A:246100           CTAG1A
# 2927                                          VBP1:7411             VBP1
# 2928  TMLHE:55217|TMLHE-AS1:100507404,TMLHE:55217|TM...  TMLHE-AS1,TMLHE
# 2929                                         USP9Y:8287            USP9Y
# 2930                                                NaN
#
# [2931 rows x 77 columns]

# %%
data = data[['CHROM', 'POS', 'Gene Name', 'rsID', 'REF', 'ALT', 'GT',
       'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF',
       'ADR', 'ADP', 'WT', 'HET', 'HOM', 'NC', 'CDA', 'OTH', 'S3D', 'WTD',
       'dbSNPBuildID', 'SLO', 'NSF', 'R3', 'R5', 'NSN', 'NSM', 'G5A', 'COMMON',
       'RS', 'RV', 'TPA', 'CFL', 'GNO', 'VLD', 'ASP', 'ASS', 'Ref', 'U3', 'U5',
       'TOPMED', 'WGT', 'MTP', 'LSD', 'NOC', 'DSS', 'SYN', 'KGPhase3', 'CAF',
       'VC', 'MUT', 'KGPhase1', 'NOV', 'VP', 'SAO', 'INT', 'G5',
       'OM', 'PMC', 'SSR', 'RSPOS', 'HD', 'PM']]
data
# Out:
#      CHROM        POS        Gene Name                      rsID     REF ALT  \
# 0     chr1    1043223             AGRN                rs35881187     CCT   C
# 1     chr1    1331945           TAS1R3               rs200330269       G  GC
# 2     chr1    1353987            MXRA8               rs140777846     CTG   C
# 3     chr1    1355779            MXRA8               rs201260508      GA   G
# 4     chr1    1387763            CCNL2                rs35654872     CCT   C
# ...    ...        ...              ...                       ...     ...  ..
# 2926  chrX  154585478           CTAG1A              rs1372477485  ATTCTG   A
# 2927  chrX  155228363             VBP1               rs781912204       A  AT
# 2928  chrX  155492733  TMLHE-AS1,TMLHE  rs1169019545;rs376271737       T  TG
# 2929  chrY   12786501            USP9Y               rs760255651      CT   C
# 2930  chrY   21311242                                rs202147921       A  AT
#
#        GT   GQ SDP  DP  RD  AD    FREQ        PVAL RDF RDR ADF ADR     ADP  \
# 0     1/1  135  24  24   0  24    100%   3.101E-14   0   0  20   4  ADP=24
# 1     0/1   58  50  50  32  17     34%   1.4216E-6   9  23   1  16  ADP=50
# 2     1/1  255  58  58   2  56  96.55%  2.8822E-31   2   0  51   5  ADP=58
# 3     1/1   60  18  18   4  14  77.78%   8.0605E-7   0   4   9   5  ADP=18
# 4     1/1  105  19  19   0  19    100%  2.8292E-11   0   0  17   2  ADP=19
# ...   ...  ...  ..  ..  ..  ..     ...         ...  ..  ..  ..  ..     ...
# 2926  0/1   42  18  18   7  11  61.11%   5.2969E-5   2   5   7   4  ADP=18
# 2927  0/1   66  23  23   4  15  65.22%   2.5053E-7   4   0  13   2  ADP=23
# 2928  1/1  115  23  23   1  22  95.65%  2.9149E-12   0   1   8  14  ADP=23
# 2929  1/1   71  20  20   2  15     75%   7.3277E-8   2   0  13   2  ADP=20
# 2930  0/1   90  29  29   7  21  72.41%  8.7917E-10   6   1  13   8  ADP=29
#
#         WT    HET    HOM    NC CDA OTH S3D WTD          dbSNPBuildID  SLO NSF  \
# 0     WT=0  HET=0  HOM=1  NC=0                      dbSNPBuildID=126  SLO
# 1     WT=0  HET=1  HOM=0  NC=0                      dbSNPBuildID=137
# 2     WT=0  HET=0  HOM=1  NC=0                      dbSNPBuildID=134  SLO
# 3     WT=0  HET=0  HOM=1  NC=0                      dbSNPBuildID=137
# 4     WT=0  HET=0  HOM=1  NC=0                      dbSNPBuildID=126  SLO
# ...    ...    ...    ...   ...  ..  ..  ..  ..                   ...  ...  ..
# 2926  WT=0  HET=1  HOM=0  NC=0                      dbSNPBuildID=151
# 2927  WT=0  HET=1  HOM=0  NC=0                      dbSNPBuildID=144
# 2928  WT=0  HET=0  HOM=1  NC=0                  dbSNPBuildID=151,138
# 2929  WT=0  HET=0  HOM=1  NC=0                      dbSNPBuildID=144
# 2930  WT=0  HET=1  HOM=0  NC=0                      dbSNPBuildID=137
#
#      R3 R5 NSN NSM  G5A    COMMON                       RS  RV TPA CFL  GNO  \
# 0                        COMMON=1              RS=35881187  RV          GNO
# 1                        COMMON=1             RS=200330269
# 2                   G5A  COMMON=1             RS=140777846              GNO
# 3                        COMMON=0             RS=201260508
# 4                        COMMON=1              RS=35654872  RV          GNO
# ...  .. ..  ..  ..  ...       ...                      ...  ..  ..  ..  ...
# 2926                                         RS=1372477485
# 2927                                          RS=781912204
# 2928                               RS=1169019545,376271737
# 2929                                          RS=760255651
# 2930                                          RS=202147921
#
#       VLD  ASP ASS Ref U3 U5  \
# 0     VLD  ASP
# 1     VLD  ASP
# 2     VLD  ASP
# 3          ASP
# 4     VLD  ASP
# ...   ...  ...  ..  .. .. ..
# 2926       ASP
# 2927       ASP
# 2928       ASP
# 2929       ASP
# 2930       ASP
#
#                                                  TOPMED      WGT MTP LSD NOC  \
# 0        TOPMED=0.55968081039755351,0.44031918960244648    WGT=1
# 1     TOPMED=0.82975758154943934,0.17023445463812436...    WGT=1
# 2        TOPMED=0.13763857033639143,0.86236142966360856    WGT=1
# 3        TOPMED=0.22555109582059123,0.77444890417940876    WGT=1
# 4        TOPMED=0.43493565239551478,0.56506434760448521    WGT=1
# ...                                                 ...      ...  ..  ..  ..
# 2926                                                       WGT=1
# 2927  TOPMED=0.43169438073394495,0.56314506880733944...    WGT=1
# 2928     TOPMED=0.35031218144750254,0.64968781855249745  WGT=1,1
# 2929                                                       WGT=1
# 2930                                                       WGT=1
#
#      DSS SYN  KGPhase3                  CAF          VC MUT  KGPhase1  NOV  \
# 0             KGPhase3    CAF=0.5208,0.4792      VC=DIV      KGPhase1
# 1             KGPhase3  CAF=0.8105,0.1895,.      VC=DIV      KGPhase1
# 2             KGPhase3    CAF=0.1793,0.8207      VC=DIV
# 3             KGPhase3              CAF=0,1      VC=DIV      KGPhase1
# 4             KGPhase3    CAF=0.6565,0.3435      VC=DIV      KGPhase1
# ...   ..  ..       ...                  ...         ...  ..       ...  ...
# 2926                                             VC=DIV
# 2927                                             VC=DIV                NOV
# 2928                                         VC=DIV,DIV
# 2929                                             VC=DIV
# 2930                                             VC=DIV
#
#                                                      VP      SAO  INT  G5 OM  \
# 0                         VP=0x05012808000515013e000200    SAO=0  INT  G5
# 1                         VP=0x05000008000515003e000200    SAO=0  INT  G5
# 2                         VP=0x050100080005170126000200    SAO=0  INT  G5
# 3                         VP=0x05000008000500003e000200    SAO=0  INT
# 4                         VP=0x05010008000515013e000200    SAO=0  INT  G5
# ...                                                 ...      ...  ...  .. ..
# 2926                      VP=0x050000080005000002000200    SAO=0  INT
# 2927                      VP=0x050000080005000002000204    SAO=0  INT
# 2928  VP=0x050000080005000002000200,0x05000008000500...  SAO=0,0  INT
# 2929                      VP=0x050000080005000002000200    SAO=0  INT
# 2930                      VP=0x050000000005000002000200    SAO=0
#
#       PMC      SSR                      RSPOS HD  PM
# 0     PMC    SSR=0              RSPOS=1043224     PM
# 1            SSR=0              RSPOS=1331945
# 2            SSR=0              RSPOS=1353988
# 3            SSR=0              RSPOS=1355780
# 4            SSR=0              RSPOS=1387764
# ...   ...      ...                        ... ..  ..
# 2926         SSR=0            RSPOS=154585479
# 2927         SSR=0            RSPOS=155228363
# 2928       SSR=0,0  RSPOS=155492733,155492734
# 2929         SSR=0             RSPOS=12786503
# 2930         SSR=0             RSPOS=21311242
#
# [2931 rows x 70 columns]

# %%
data['rsid'] = data['rsID'].str.split(';')
data = data.explode('rsid')
data
# Out:
#      CHROM        POS        Gene Name                      rsID  REF ALT  \
# 0     chr1    1043223             AGRN                rs35881187  CCT   C
# 1     chr1    1331945           TAS1R3               rs200330269    G  GC
# 2     chr1    1353987            MXRA8               rs140777846  CTG   C
# 3     chr1    1355779            MXRA8               rs201260508   GA   G
# 4     chr1    1387763            CCNL2                rs35654872  CCT   C
# ...    ...        ...              ...                       ...  ...  ..
# 2927  chrX  155228363             VBP1               rs781912204    A  AT
# 2928  chrX  155492733  TMLHE-AS1,TMLHE  rs1169019545;rs376271737    T  TG
# 2928  chrX  155492733  TMLHE-AS1,TMLHE  rs1169019545;rs376271737    T  TG
# 2929  chrY   12786501            USP9Y               rs760255651   CT   C
# 2930  chrY   21311242                                rs202147921    A  AT
#
#        GT   GQ SDP  DP  RD  AD    FREQ        PVAL RDF RDR ADF ADR     ADP  \
# 0     1/1  135  24  24   0  24    100%   3.101E-14   0   0  20   4  ADP=24
# 1     0/1   58  50  50  32  17     34%   1.4216E-6   9  23   1  16  ADP=50
# 2     1/1  255  58  58   2  56  96.55%  2.8822E-31   2   0  51   5  ADP=58
# 3     1/1   60  18  18   4  14  77.78%   8.0605E-7   0   4   9   5  ADP=18
# 4     1/1  105  19  19   0  19    100%  2.8292E-11   0   0  17   2  ADP=19
# ...   ...  ...  ..  ..  ..  ..     ...         ...  ..  ..  ..  ..     ...
# 2927  0/1   66  23  23   4  15  65.22%   2.5053E-7   4   0  13   2  ADP=23
# 2928  1/1  115  23  23   1  22  95.65%  2.9149E-12   0   1   8  14  ADP=23
# 2928  1/1  115  23  23   1  22  95.65%  2.9149E-12   0   1   8  14  ADP=23
# 2929  1/1   71  20  20   2  15     75%   7.3277E-8   2   0  13   2  ADP=20
# 2930  0/1   90  29  29   7  21  72.41%  8.7917E-10   6   1  13   8  ADP=29
#
#         WT    HET    HOM    NC CDA OTH S3D WTD          dbSNPBuildID  SLO NSF  \
# 0     WT=0  HET=0  HOM=1  NC=0                      dbSNPBuildID=126  SLO
# 1     WT=0  HET=1  HOM=0  NC=0                      dbSNPBuildID=137
# 2     WT=0  HET=0  HOM=1  NC=0                      dbSNPBuildID=134  SLO
# 3     WT=0  HET=0  HOM=1  NC=0                      dbSNPBuildID=137
# 4     WT=0  HET=0  HOM=1  NC=0                      dbSNPBuildID=126  SLO
# ...    ...    ...    ...   ...  ..  ..  ..  ..                   ...  ...  ..
# 2927  WT=0  HET=1  HOM=0  NC=0                      dbSNPBuildID=144
# 2928  WT=0  HET=0  HOM=1  NC=0                  dbSNPBuildID=151,138
# 2928  WT=0  HET=0  HOM=1  NC=0                  dbSNPBuildID=151,138
# 2929  WT=0  HET=0  HOM=1  NC=0                      dbSNPBuildID=144
# 2930  WT=0  HET=1  HOM=0  NC=0                      dbSNPBuildID=137
#
#      R3 R5 NSN NSM  G5A    COMMON                       RS  RV TPA CFL  GNO  \
# 0                        COMMON=1              RS=35881187  RV          GNO
# 1                        COMMON=1             RS=200330269
# 2                   G5A  COMMON=1             RS=140777846              GNO
# 3                        COMMON=0             RS=201260508
# 4                        COMMON=1              RS=35654872  RV          GNO
# ...  .. ..  ..  ..  ...       ...                      ...  ..  ..  ..  ...
# 2927                                          RS=781912204
# 2928                               RS=1169019545,376271737
# 2928                               RS=1169019545,376271737
# 2929                                          RS=760255651
# 2930                                          RS=202147921
#
#       VLD  ASP ASS Ref U3 U5  \
# 0     VLD  ASP
# 1     VLD  ASP
# 2     VLD  ASP
# 3          ASP
# 4     VLD  ASP
# ...   ...  ...  ..  .. .. ..
# 2927       ASP
# 2928       ASP
# 2928       ASP
# 2929       ASP
# 2930       ASP
#
#                                                  TOPMED      WGT MTP LSD NOC  \
# 0        TOPMED=0.55968081039755351,0.44031918960244648    WGT=1
# 1     TOPMED=0.82975758154943934,0.17023445463812436...    WGT=1
# 2        TOPMED=0.13763857033639143,0.86236142966360856    WGT=1
# 3        TOPMED=0.22555109582059123,0.77444890417940876    WGT=1
# 4        TOPMED=0.43493565239551478,0.56506434760448521    WGT=1
# ...                                                 ...      ...  ..  ..  ..
# 2927  TOPMED=0.43169438073394495,0.56314506880733944...    WGT=1
# 2928     TOPMED=0.35031218144750254,0.64968781855249745  WGT=1,1
# 2928     TOPMED=0.35031218144750254,0.64968781855249745  WGT=1,1
# 2929                                                       WGT=1
# 2930                                                       WGT=1
#
#      DSS SYN  KGPhase3                  CAF          VC MUT  KGPhase1  NOV  \
# 0             KGPhase3    CAF=0.5208,0.4792      VC=DIV      KGPhase1
# 1             KGPhase3  CAF=0.8105,0.1895,.      VC=DIV      KGPhase1
# 2             KGPhase3    CAF=0.1793,0.8207      VC=DIV
# 3             KGPhase3              CAF=0,1      VC=DIV      KGPhase1
# 4             KGPhase3    CAF=0.6565,0.3435      VC=DIV      KGPhase1
# ...   ..  ..       ...                  ...         ...  ..       ...  ...
# 2927                                             VC=DIV                NOV
# 2928                                         VC=DIV,DIV
# 2928                                         VC=DIV,DIV
# 2929                                             VC=DIV
# 2930                                             VC=DIV
#
#                                                      VP      SAO  INT  G5 OM  \
# 0                         VP=0x05012808000515013e000200    SAO=0  INT  G5
# 1                         VP=0x05000008000515003e000200    SAO=0  INT  G5
# 2                         VP=0x050100080005170126000200    SAO=0  INT  G5
# 3                         VP=0x05000008000500003e000200    SAO=0  INT
# 4                         VP=0x05010008000515013e000200    SAO=0  INT  G5
# ...                                                 ...      ...  ...  .. ..
# 2927                      VP=0x050000080005000002000204    SAO=0  INT
# 2928  VP=0x050000080005000002000200,0x05000008000500...  SAO=0,0  INT
# 2928  VP=0x050000080005000002000200,0x05000008000500...  SAO=0,0  INT
# 2929                      VP=0x050000080005000002000200    SAO=0  INT
# 2930                      VP=0x050000000005000002000200    SAO=0
#
#       PMC      SSR                      RSPOS HD  PM          rsid
# 0     PMC    SSR=0              RSPOS=1043224     PM    rs35881187
# 1            SSR=0              RSPOS=1331945          rs200330269
# 2            SSR=0              RSPOS=1353988          rs140777846
# 3            SSR=0              RSPOS=1355780          rs201260508
# 4            SSR=0              RSPOS=1387764           rs35654872
# ...   ...      ...                        ... ..  ..           ...
# 2927         SSR=0            RSPOS=155228363          rs781912204
# 2928       SSR=0,0  RSPOS=155492733,155492734         rs1169019545
# 2928       SSR=0,0  RSPOS=155492733,155492734          rs376271737
# 2929         SSR=0             RSPOS=12786503          rs760255651
# 2930         SSR=0             RSPOS=21311242          rs202147921
#
# [4948 rows x 71 columns]

# %%
df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/KHHSPTGPCSP15_and_16/KHHSPTGPCSP16/KHHSPTGPCSP16_indel_clinical_significance.xlsx')
df = df.rename(columns={'gene_name': 'Gene name', 'zygocity':'zygosity'})
df
# Out:
#           allele      zygosity Gene name          rsid  \
# 0      ['TA', T]  Heterozygous     WDR41    rs10536220
# 1      ['TA', T]  Heterozygous     WDR41    rs10536220
# 2      ['G', GA]  Heterozygous   TRAPPC2  rs1057515794
# 3     ['CAT', C]  Heterozygous    PTGES3    rs10579382
# 4     ['CCT', C]    Homozygous       EDA    rs10579679
# ..           ...           ...       ...           ...
# 765    ['AT', A]  Heterozygous     ATCAY   rs796133913
# 766  ['ACCT', A]    Homozygous      RYR1   rs796750554
# 767    ['GT', G]    Homozygous     CD2AP   rs797004904
# 768    ['TA', T]    Homozygous     BRCA1     rs8176144
# 769    ['G', GT]  Heterozygous      MYLK   rs879035240
#
#                                 consequence  \
# 0                       3_prime_UTR_variant
# 1                       3_prime_UTR_variant
# 2                       3_prime_UTR_variant
# 3    initiatior_codon_variant', 'SO:0001589
# 4                            intron_variant
# ..                                      ...
# 765                     3_prime_UTR_variant
# 766                          intron_variant
# 767                     3_prime_UTR_variant
# 768                          intron_variant
# 769                     3_prime_UTR_variant
#
#                             clinical_significance  \
# 0                          Uncertain_significance
# 1                                          Benign
# 2    Conflicting_interpretations_of_pathogenicity
# 3                                          Benign
# 4                                          Benign
# ..                                            ...
# 765                        Uncertain_significance
# 766                                        Benign
# 767                                        Benign
# 768                                        Benign
# 769                        Uncertain_significance
#
#                                    associated_diseases  \
# 0                                Striatal_Degeneration
# 1                                Striatal_Degeneration
# 2    Spondyloepiphyseal_dysplasia_congenita|not_pro...
# 3                                         not_provided
# 4    Hypohidrotic_X-linked_ectodermal_dysplasia|not...
# ..                                                 ...
# 765                      Cayman_type_cerebellar_ataxia
# 766  Congenital_multicore_myopathy_with_external_op...
# 767                 Focal_segmental_glomerulosclerosis
# 768  Hereditary_breast_ovarian_cancer_syndrome|Brea...
# 769  Familial_thoracic_aortic_aneurysm_and_aortic_d...
#
#                                          review_status    origin variant_type  \
# 0               criteria_provided', '_single_submitter  germline        indel
# 1               criteria_provided', '_single_submitter  germline        indel
# 2    criteria_provided', '_conflicting_interpretations  germline        indel
# 3                       no_assertion_criteria_provided  germline        indel
# 4    criteria_provided', '_multiple_submitters', '_...  germline        indel
# ..                                                 ...       ...          ...
# 765             criteria_provided', '_single_submitter  germline        indel
# 766  criteria_provided', '_multiple_submitters', '_...  germline        indel
# 767             criteria_provided', '_single_submitter  germline        indel
# 768                           reviewed_by_expert_panel  germline        indel
# 769             criteria_provided', '_single_submitter  germline        indel
#
#     variant_subtype Phargkb_ann_exists is_mutation Variant_is_precious
# 0          Deletion           MayBe No          No                 Yes
# 1          Deletion           MayBe No          No                 Yes
# 2         Insertion           MayBe No          No                 Yes
# 3          Deletion           MayBe No          No                  No
# 4          Deletion           MayBe No          No                 Yes
# ..              ...                ...         ...                 ...
# 765        Deletion           MayBe No          No                  No
# 766        Deletion           MayBe No          No                 Yes
# 767        Deletion           MayBe No          No                  No
# 768        Deletion           MayBe No          No                 Yes
# 769       Insertion           MayBe No          No                 Yes
#
# [770 rows x 14 columns]

# %%
merged = pd.merge(data, df, on = 'rsid', how = 'outer', sort=False)
merged
# Out:
#      CHROM        POS              Gene Name                    rsID  REF  \
# 0     chr1  1043223.0                   AGRN              rs35881187  CCT
# 1     chr1  1299382.0                  ACAP3             rs143128930   AG
# 2     chr1  1312198.0  INTS11,MIR6727,CPSF3L  rs70949570;rs752605219    T
# 3     chr1  1312198.0  INTS11,MIR6727,CPSF3L  rs70949570;rs752605219    T
# 4     chr1  1353987.0                  MXRA8             rs140777846  CTG
# ...    ...        ...                    ...                     ...  ...
# 4913   NaN        NaN                    NaN                     NaN  NaN
# 4914   NaN        NaN                    NaN                     NaN  NaN
# 4915   NaN        NaN                    NaN                     NaN  NaN
# 4916   NaN        NaN                    NaN                     NaN  NaN
# 4917   NaN        NaN                    NaN                     NaN  NaN
#
#          ALT   GT   GQ  SDP   DP   RD   AD    FREQ        PVAL  RDF  RDR  ADF  \
# 0          C  0/1   93   30   30    8   22  73.33%  4.1351E-10    8    0   21
# 1          A  0/1   66   23   23    7   16  69.57%   2.4726E-7    5    2   11
# 2     TGGGGG  0/1   29   19   19    2    7  36.84%   1.1312E-3    0    2    7
# 3     TGGGGG  0/1   29   19   19    2    7  36.84%   1.1312E-3    0    2    7
# 4          C  0/1   93   59   59   33   26  44.07%  4.2407E-10   20   13   16
# ...      ...  ...  ...  ...  ...  ...  ...     ...         ...  ...  ...  ...
# 4913     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4914     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4915     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4916     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4917     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
#
#       ADR     ADP    WT    HET    HOM    NC  CDA  OTH  S3D  WTD  \
# 0       1  ADP=30  WT=0  HET=1  HOM=0  NC=0
# 1       5  ADP=23  WT=0  HET=1  HOM=0  NC=0
# 2       0  ADP=19  WT=0  HET=1  HOM=0  NC=0
# 3       0  ADP=19  WT=0  HET=1  HOM=0  NC=0
# 4      10  ADP=59  WT=0  HET=1  HOM=0  NC=0
# ...   ...     ...   ...    ...    ...   ...  ...  ...  ...  ...
# 4913  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4914  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4915  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4916  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4917  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
#
#               dbSNPBuildID  SLO  NSF   R3   R5  NSN  NSM  G5A    COMMON  \
# 0         dbSNPBuildID=126  SLO                                COMMON=1
# 1         dbSNPBuildID=134                  R5                 COMMON=1
# 2     dbSNPBuildID=144,130  SLO        R3
# 3     dbSNPBuildID=144,130  SLO        R3
# 4         dbSNPBuildID=134  SLO                           G5A  COMMON=1
# ...                    ...  ...  ...  ...  ...  ...  ...  ...       ...
# 4913                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4914                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4915                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4916                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4917                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
#
#                          RS   RV  TPA  CFL  GNO  VLD  ASP  ASS  Ref   U3   U5  \
# 0               RS=35881187   RV            GNO  VLD  ASP
# 1              RS=143128930                      VLD  ASP
# 2     RS=752605219,70949570                 GNO  VLD  ASP
# 3     RS=752605219,70949570                 GNO  VLD  ASP
# 4              RS=140777846                 GNO  VLD  ASP
# ...                     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4913                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4914                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4915                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4916                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4917                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                                  TOPMED      WGT  MTP  LSD  \
# 0        TOPMED=0.55968081039755351,0.44031918960244648    WGT=1
# 1        TOPMED=0.91126720183486238,0.08873279816513761    WGT=1
# 2     TOPMED=0.42793546126401630,0.00001592762487257...  WGT=1,1
# 3     TOPMED=0.42793546126401630,0.00001592762487257...  WGT=1,1
# 4        TOPMED=0.13763857033639143,0.86236142966360856    WGT=1
# ...                                                 ...      ...  ...  ...
# 4913                                                NaN      NaN  NaN  NaN
# 4914                                                NaN      NaN  NaN  NaN
# 4915                                                NaN      NaN  NaN  NaN
# 4916                                                NaN      NaN  NaN  NaN
# 4917                                                NaN      NaN  NaN  NaN
#
#       NOC  DSS  SYN  KGPhase3                CAF          VC  MUT  KGPhase1  \
# 0                    KGPhase3  CAF=0.5208,0.4792      VC=DIV       KGPhase1
# 1                    KGPhase3  CAF=0.8806,0.1194      VC=DIV       KGPhase1
# 2                                                 VC=DIV,DIV
# 3                                                 VC=DIV,DIV
# 4                    KGPhase3  CAF=0.1793,0.8207      VC=DIV
# ...   ...  ...  ...       ...                ...         ...  ...       ...
# 4913  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4914  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4915  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4916  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4917  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
#
#       NOV                                                 VP      SAO  INT  \
# 0                              VP=0x05012808000515013e000200    SAO=0  INT
# 1                              VP=0x0500000a000515003e000200    SAO=0  INT
# 2     NOV  VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 3     NOV  VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 4                              VP=0x050100080005170126000200    SAO=0  INT
# ...   ...                                                ...      ...  ...
# 4913  NaN                                                NaN      NaN  NaN
# 4914  NaN                                                NaN      NaN  NaN
# 4915  NaN                                                NaN      NaN  NaN
# 4916  NaN                                                NaN      NaN  NaN
# 4917  NaN                                                NaN      NaN  NaN
#
#        G5   OM  PMC      SSR                  RSPOS   HD   PM         rsid  \
# 0      G5       PMC    SSR=0          RSPOS=1043224        PM   rs35881187
# 1      G5              SSR=0          RSPOS=1299383            rs143128930
# 2                    SSR=0,0  RSPOS=1312198,1312208             rs70949570
# 3                    SSR=0,0  RSPOS=1312198,1312208            rs752605219
# 4      G5              SSR=0          RSPOS=1353988            rs140777846
# ...   ...  ...  ...      ...                    ...  ...  ...          ...
# 4913  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs70976124
# 4914  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs71027384
# 4915  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs72459173
# 4916  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs74733861
# 4917  NaN  NaN  NaN      NaN                    NaN  NaN  NaN  rs796097780
#
#                         allele      zygosity Gene name          consequence  \
# 0                   ['CCT', C]  Heterozygous      AGRN       intron_variant
# 1                          NaN           NaN       NaN                  NaN
# 2                          NaN           NaN       NaN                  NaN
# 3                          NaN           NaN       NaN                  NaN
# 4                          NaN           NaN       NaN                  NaN
# ...                        ...           ...       ...                  ...
# 4913                 ['GC', G]    Homozygous      HEXB       intron_variant
# 4914                 ['A', AT]  Heterozygous    SERAC1       intron_variant
# 4915  ['GAAATCTCAGGACTAGA', G]  Heterozygous     ADAM9       intron_variant
# 4916            ['AAGTCTC', A]    Homozygous      PSAP       intron_variant
# 4917                 ['AT', A]  Heterozygous    LHFPL5  3_prime_UTR_variant
#
#      clinical_significance                                associated_diseases  \
# 0                   Benign  Congenital_myasthenic_syndrome_8|not_specified...
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# ...                    ...                                                ...
# 4913                Benign                      Sandhoff_disease|not_provided
# 4914                Benign  3-methylglutaconic_aciduria_with_deafness', '_...
# 4915                Benign                                       not_provided
# 4916                Benign                                       not_provided
# 4917         Likely_benign            Nonsyndromic_Hearing_Loss', '_Recessive
#
#                                           review_status    origin  \
# 0     criteria_provided', '_multiple_submitters', '_...  germline
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# ...                                                 ...       ...
# 4913  criteria_provided', '_multiple_submitters', '_...  germline
# 4914  criteria_provided', '_multiple_submitters', '_...  germline
# 4915             criteria_provided', '_single_submitter  germline
# 4916             criteria_provided', '_single_submitter  germline
# 4917             criteria_provided', '_single_submitter  germline
#
#      variant_type variant_subtype Phargkb_ann_exists is_mutation  \
# 0           indel        Deletion           MayBe No          No
# 1             NaN             NaN                NaN         NaN
# 2             NaN             NaN                NaN         NaN
# 3             NaN             NaN                NaN         NaN
# 4             NaN             NaN                NaN         NaN
# ...           ...             ...                ...         ...
# 4913        indel        Deletion           MayBe No          No
# 4914        indel       Insertion           MayBe No          No
# 4915        indel        Deletion           MayBe No          No
# 4916        indel        Deletion           MayBe No          No
# 4917        indel        Deletion           MayBe No          No
#
#      Variant_is_precious
# 0                    Yes
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 4913                  No
# 4914                  No
# 4915                  No
# 4916                  No
# 4917                  No
#
# [4918 rows x 84 columns]

# %%
merged['Gene Name'] = merged['Gene Name'].fillna(merged['Gene name'])
merged
# Out:
#      CHROM        POS              Gene Name                    rsID  REF  \
# 0     chr1  1043223.0                   AGRN              rs35881187  CCT
# 1     chr1  1299382.0                  ACAP3             rs143128930   AG
# 2     chr1  1312198.0  INTS11,MIR6727,CPSF3L  rs70949570;rs752605219    T
# 3     chr1  1312198.0  INTS11,MIR6727,CPSF3L  rs70949570;rs752605219    T
# 4     chr1  1353987.0                  MXRA8             rs140777846  CTG
# ...    ...        ...                    ...                     ...  ...
# 4913   NaN        NaN                   HEXB                     NaN  NaN
# 4914   NaN        NaN                 SERAC1                     NaN  NaN
# 4915   NaN        NaN                  ADAM9                     NaN  NaN
# 4916   NaN        NaN                   PSAP                     NaN  NaN
# 4917   NaN        NaN                 LHFPL5                     NaN  NaN
#
#          ALT   GT   GQ  SDP   DP   RD   AD    FREQ        PVAL  RDF  RDR  ADF  \
# 0          C  0/1   93   30   30    8   22  73.33%  4.1351E-10    8    0   21
# 1          A  0/1   66   23   23    7   16  69.57%   2.4726E-7    5    2   11
# 2     TGGGGG  0/1   29   19   19    2    7  36.84%   1.1312E-3    0    2    7
# 3     TGGGGG  0/1   29   19   19    2    7  36.84%   1.1312E-3    0    2    7
# 4          C  0/1   93   59   59   33   26  44.07%  4.2407E-10   20   13   16
# ...      ...  ...  ...  ...  ...  ...  ...     ...         ...  ...  ...  ...
# 4913     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4914     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4915     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4916     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4917     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
#
#       ADR     ADP    WT    HET    HOM    NC  CDA  OTH  S3D  WTD  \
# 0       1  ADP=30  WT=0  HET=1  HOM=0  NC=0
# 1       5  ADP=23  WT=0  HET=1  HOM=0  NC=0
# 2       0  ADP=19  WT=0  HET=1  HOM=0  NC=0
# 3       0  ADP=19  WT=0  HET=1  HOM=0  NC=0
# 4      10  ADP=59  WT=0  HET=1  HOM=0  NC=0
# ...   ...     ...   ...    ...    ...   ...  ...  ...  ...  ...
# 4913  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4914  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4915  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4916  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4917  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
#
#               dbSNPBuildID  SLO  NSF   R3   R5  NSN  NSM  G5A    COMMON  \
# 0         dbSNPBuildID=126  SLO                                COMMON=1
# 1         dbSNPBuildID=134                  R5                 COMMON=1
# 2     dbSNPBuildID=144,130  SLO        R3
# 3     dbSNPBuildID=144,130  SLO        R3
# 4         dbSNPBuildID=134  SLO                           G5A  COMMON=1
# ...                    ...  ...  ...  ...  ...  ...  ...  ...       ...
# 4913                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4914                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4915                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4916                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4917                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
#
#                          RS   RV  TPA  CFL  GNO  VLD  ASP  ASS  Ref   U3   U5  \
# 0               RS=35881187   RV            GNO  VLD  ASP
# 1              RS=143128930                      VLD  ASP
# 2     RS=752605219,70949570                 GNO  VLD  ASP
# 3     RS=752605219,70949570                 GNO  VLD  ASP
# 4              RS=140777846                 GNO  VLD  ASP
# ...                     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4913                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4914                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4915                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4916                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4917                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                                  TOPMED      WGT  MTP  LSD  \
# 0        TOPMED=0.55968081039755351,0.44031918960244648    WGT=1
# 1        TOPMED=0.91126720183486238,0.08873279816513761    WGT=1
# 2     TOPMED=0.42793546126401630,0.00001592762487257...  WGT=1,1
# 3     TOPMED=0.42793546126401630,0.00001592762487257...  WGT=1,1
# 4        TOPMED=0.13763857033639143,0.86236142966360856    WGT=1
# ...                                                 ...      ...  ...  ...
# 4913                                                NaN      NaN  NaN  NaN
# 4914                                                NaN      NaN  NaN  NaN
# 4915                                                NaN      NaN  NaN  NaN
# 4916                                                NaN      NaN  NaN  NaN
# 4917                                                NaN      NaN  NaN  NaN
#
#       NOC  DSS  SYN  KGPhase3                CAF          VC  MUT  KGPhase1  \
# 0                    KGPhase3  CAF=0.5208,0.4792      VC=DIV       KGPhase1
# 1                    KGPhase3  CAF=0.8806,0.1194      VC=DIV       KGPhase1
# 2                                                 VC=DIV,DIV
# 3                                                 VC=DIV,DIV
# 4                    KGPhase3  CAF=0.1793,0.8207      VC=DIV
# ...   ...  ...  ...       ...                ...         ...  ...       ...
# 4913  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4914  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4915  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4916  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4917  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
#
#       NOV                                                 VP      SAO  INT  \
# 0                              VP=0x05012808000515013e000200    SAO=0  INT
# 1                              VP=0x0500000a000515003e000200    SAO=0  INT
# 2     NOV  VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 3     NOV  VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 4                              VP=0x050100080005170126000200    SAO=0  INT
# ...   ...                                                ...      ...  ...
# 4913  NaN                                                NaN      NaN  NaN
# 4914  NaN                                                NaN      NaN  NaN
# 4915  NaN                                                NaN      NaN  NaN
# 4916  NaN                                                NaN      NaN  NaN
# 4917  NaN                                                NaN      NaN  NaN
#
#        G5   OM  PMC      SSR                  RSPOS   HD   PM         rsid  \
# 0      G5       PMC    SSR=0          RSPOS=1043224        PM   rs35881187
# 1      G5              SSR=0          RSPOS=1299383            rs143128930
# 2                    SSR=0,0  RSPOS=1312198,1312208             rs70949570
# 3                    SSR=0,0  RSPOS=1312198,1312208            rs752605219
# 4      G5              SSR=0          RSPOS=1353988            rs140777846
# ...   ...  ...  ...      ...                    ...  ...  ...          ...
# 4913  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs70976124
# 4914  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs71027384
# 4915  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs72459173
# 4916  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs74733861
# 4917  NaN  NaN  NaN      NaN                    NaN  NaN  NaN  rs796097780
#
#                         allele      zygosity Gene name          consequence  \
# 0                   ['CCT', C]  Heterozygous      AGRN       intron_variant
# 1                          NaN           NaN       NaN                  NaN
# 2                          NaN           NaN       NaN                  NaN
# 3                          NaN           NaN       NaN                  NaN
# 4                          NaN           NaN       NaN                  NaN
# ...                        ...           ...       ...                  ...
# 4913                 ['GC', G]    Homozygous      HEXB       intron_variant
# 4914                 ['A', AT]  Heterozygous    SERAC1       intron_variant
# 4915  ['GAAATCTCAGGACTAGA', G]  Heterozygous     ADAM9       intron_variant
# 4916            ['AAGTCTC', A]    Homozygous      PSAP       intron_variant
# 4917                 ['AT', A]  Heterozygous    LHFPL5  3_prime_UTR_variant
#
#      clinical_significance                                associated_diseases  \
# 0                   Benign  Congenital_myasthenic_syndrome_8|not_specified...
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# ...                    ...                                                ...
# 4913                Benign                      Sandhoff_disease|not_provided
# 4914                Benign  3-methylglutaconic_aciduria_with_deafness', '_...
# 4915                Benign                                       not_provided
# 4916                Benign                                       not_provided
# 4917         Likely_benign            Nonsyndromic_Hearing_Loss', '_Recessive
#
#                                           review_status    origin  \
# 0     criteria_provided', '_multiple_submitters', '_...  germline
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# ...                                                 ...       ...
# 4913  criteria_provided', '_multiple_submitters', '_...  germline
# 4914  criteria_provided', '_multiple_submitters', '_...  germline
# 4915             criteria_provided', '_single_submitter  germline
# 4916             criteria_provided', '_single_submitter  germline
# 4917             criteria_provided', '_single_submitter  germline
#
#      variant_type variant_subtype Phargkb_ann_exists is_mutation  \
# 0           indel        Deletion           MayBe No          No
# 1             NaN             NaN                NaN         NaN
# 2             NaN             NaN                NaN         NaN
# 3             NaN             NaN                NaN         NaN
# 4             NaN             NaN                NaN         NaN
# ...           ...             ...                ...         ...
# 4913        indel        Deletion           MayBe No          No
# 4914        indel       Insertion           MayBe No          No
# 4915        indel        Deletion           MayBe No          No
# 4916        indel        Deletion           MayBe No          No
# 4917        indel        Deletion           MayBe No          No
#
#      Variant_is_precious
# 0                    Yes
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 4913                  No
# 4914                  No
# 4915                  No
# 4916                  No
# 4917                  No
#
# [4918 rows x 84 columns]

# %%
cond_genes = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Hereditary_cancer_genes.xlsx')
cond_genes
# Out:
#    Gene Name
# 0        ATM
# 1      BRCA1
# 2      BRCA2
# 3      BRIP1
# 4      CHEK2
# 5      BARD1
# 6       CDH1
# 7     CDKN2A
# 8      EPCAM
# 9      FANCC
# 10    HOXB13
# 11     MRE11
# 12      MSH2
# 13      MSH6
# 14     MUTYH
# 15       NBN
# 16       NF1
# 17     PALB2
# 18      PMS2
# 19     RAD50
# 20    RAD51D
# 21    RAD51C
# 22     RECQL
# 23      SLX4
# 24     STK11
# 25   SMARCA4
# 26      PTEN
# 27     XRCC2
# 28      TP53

# %% [markdown]
# # Multiple Genes

# %%
merged['Gene Match'] = 'No'
merged['Matched_Gene'] = ''
    
# Iterate through each gene in vcf['Gene']
for index, genes in merged['Gene Name'].iteritems():
    if isinstance(genes, str):
        gene_list = genes.split(',')
        for gene in gene_list:
            if gene in cond_genes['Gene Name'].values:
                merged.at[index, 'Gene Match'] = 'Yes'
                merged.at[index, 'Matched_Gene'] = gene
                break
merged
# Out:
#      CHROM        POS Gene Name         rsID  REF  ALT   GT   GQ  SDP   DP  \
# 0     chr1  1299382.0     ACAP3  rs143128930   AG    A  0/1   97   50   50
# 1     chr1  1331945.0    TAS1R3  rs200330269    G   GC  0/1   48   41   41
# 2     chr1  1353987.0     MXRA8  rs140777846  CTG    C  0/1  219   70   70
# 3     chr1  1355779.0     MXRA8  rs201260508   GA    G  0/1   88   29   29
# 4     chr1  1657358.0    CDK11B  rs377230281    T   TA  0/1   78  112  112
# ...    ...        ...       ...          ...  ...  ...  ...  ...  ...  ...
# 4953   NaN        NaN     KAT6B          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4954   NaN        NaN     KAT6B          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4955   NaN        NaN    GNPTAB          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4956   NaN        NaN    EEF1A2          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4957   NaN        NaN      SOS1          NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        RD   AD    FREQ        PVAL  RDF  RDR  ADF  ADR      ADP    WT    HET  \
# 0      24   26     52%  1.7375E-10   18    6   17    9   ADP=50  WT=0  HET=1
# 1      26   14  34.15%   1.5388E-5   12   14    2   12   ADP=41  WT=0  HET=1
# 2      19   51  72.86%  1.2075E-22   12    7   34   17   ADP=70  WT=0  HET=1
# 3       8   21  72.41%   1.2841E-9    7    1    8   13   ADP=29  WT=0  HET=1
# 4      88   24  21.43%   1.4999E-8   65   23    4   20  ADP=112  WT=0  HET=1
# ...   ...  ...     ...         ...  ...  ...  ...  ...      ...   ...    ...
# 4953  NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN      NaN   NaN    NaN
# 4954  NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN      NaN   NaN    NaN
# 4955  NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN      NaN   NaN    NaN
# 4956  NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN      NaN   NaN    NaN
# 4957  NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN      NaN   NaN    NaN
#
#         HOM    NC  CDA  OTH  S3D  WTD      dbSNPBuildID  SLO  NSF   R3   R5  \
# 0     HOM=0  NC=0                      dbSNPBuildID=134                  R5
# 1     HOM=0  NC=0                      dbSNPBuildID=137
# 2     HOM=0  NC=0                      dbSNPBuildID=134  SLO
# 3     HOM=0  NC=0                      dbSNPBuildID=137
# 4     HOM=0  NC=0                      dbSNPBuildID=138
# ...     ...   ...  ...  ...  ...  ...               ...  ...  ...  ...  ...
# 4953    NaN   NaN  NaN  NaN  NaN  NaN               NaN  NaN  NaN  NaN  NaN
# 4954    NaN   NaN  NaN  NaN  NaN  NaN               NaN  NaN  NaN  NaN  NaN
# 4955    NaN   NaN  NaN  NaN  NaN  NaN               NaN  NaN  NaN  NaN  NaN
# 4956    NaN   NaN  NaN  NaN  NaN  NaN               NaN  NaN  NaN  NaN  NaN
# 4957    NaN   NaN  NaN  NaN  NaN  NaN               NaN  NaN  NaN  NaN  NaN
#
#       NSN  NSM  G5A    COMMON            RS   RV  TPA  CFL  GNO  VLD  ASP  \
# 0                    COMMON=1  RS=143128930                      VLD  ASP
# 1                    COMMON=1  RS=200330269                      VLD  ASP
# 2               G5A  COMMON=1  RS=140777846                 GNO  VLD  ASP
# 3                    COMMON=0  RS=201260508                           ASP
# 4                              RS=377230281                           ASP
# ...   ...  ...  ...       ...           ...  ...  ...  ...  ...  ...  ...
# 4953  NaN  NaN  NaN       NaN           NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4954  NaN  NaN  NaN       NaN           NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4955  NaN  NaN  NaN       NaN           NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4956  NaN  NaN  NaN       NaN           NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4957  NaN  NaN  NaN       NaN           NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#       ASS  Ref   U3   U5                                             TOPMED  \
# 0                            TOPMED=0.91126720183486238,0.08873279816513761
# 1                         TOPMED=0.82975758154943934,0.17023445463812436...
# 2                            TOPMED=0.13763857033639143,0.86236142966360856
# 3                            TOPMED=0.22555109582059123,0.77444890417940876
# 4                            TOPMED=0.98587219673802242,0.01412780326197757
# ...   ...  ...  ...  ...                                                ...
# 4953  NaN  NaN  NaN  NaN                                                NaN
# 4954  NaN  NaN  NaN  NaN                                                NaN
# 4955  NaN  NaN  NaN  NaN                                                NaN
# 4956  NaN  NaN  NaN  NaN                                                NaN
# 4957  NaN  NaN  NaN  NaN                                                NaN
#
#         WGT  MTP  LSD  NOC  DSS  SYN  KGPhase3                  CAF      VC  \
# 0     WGT=1                           KGPhase3    CAF=0.8806,0.1194  VC=DIV
# 1     WGT=1                           KGPhase3  CAF=0.8105,0.1895,.  VC=DIV
# 2     WGT=1                           KGPhase3    CAF=0.1793,0.8207  VC=DIV
# 3     WGT=1                           KGPhase3              CAF=0,1  VC=DIV
# 4     WGT=1                                                          VC=DIV
# ...     ...  ...  ...  ...  ...  ...       ...                  ...     ...
# 4953    NaN  NaN  NaN  NaN  NaN  NaN       NaN                  NaN     NaN
# 4954    NaN  NaN  NaN  NaN  NaN  NaN       NaN                  NaN     NaN
# 4955    NaN  NaN  NaN  NaN  NaN  NaN       NaN                  NaN     NaN
# 4956    NaN  NaN  NaN  NaN  NaN  NaN       NaN                  NaN     NaN
# 4957    NaN  NaN  NaN  NaN  NaN  NaN       NaN                  NaN     NaN
#
#       MUT  KGPhase1  NOV                             VP    SAO  INT   G5   OM  \
# 0          KGPhase1       VP=0x0500000a000515003e000200  SAO=0  INT   G5
# 1          KGPhase1       VP=0x05000008000515003e000200  SAO=0  INT   G5
# 2                         VP=0x050100080005170126000200  SAO=0  INT   G5
# 3          KGPhase1       VP=0x05000008000500003e000200  SAO=0  INT
# 4                         VP=0x050000080005000002000200  SAO=0  INT
# ...   ...       ...  ...                            ...    ...  ...  ...  ...
# 4953  NaN       NaN  NaN                            NaN    NaN  NaN  NaN  NaN
# 4954  NaN       NaN  NaN                            NaN    NaN  NaN  NaN  NaN
# 4955  NaN       NaN  NaN                            NaN    NaN  NaN  NaN  NaN
# 4956  NaN       NaN  NaN                            NaN    NaN  NaN  NaN  NaN
# 4957  NaN       NaN  NaN                            NaN    NaN  NaN  NaN  NaN
#
#       PMC    SSR          RSPOS   HD   PM ClinVar ClinVar_CLNSIG         rsid  \
# 0          SSR=0  RSPOS=1299383                                   rs143128930
# 1          SSR=0  RSPOS=1331945                                   rs200330269
# 2          SSR=0  RSPOS=1353988                                   rs140777846
# 3          SSR=0  RSPOS=1355780                                   rs201260508
# 4          SSR=0  RSPOS=1657358                                   rs377230281
# ...   ...    ...            ...  ...  ...     ...            ...          ...
# 4953  NaN    NaN            NaN  NaN  NaN     NaN            NaN   rs71929101
# 4954  NaN    NaN            NaN  NaN  NaN     NaN            NaN   rs71929101
# 4955  NaN    NaN            NaN  NaN  NaN     NaN            NaN   rs76300806
# 4956  NaN    NaN            NaN  NaN  NaN     NaN            NaN   rs77467883
# 4957  NaN    NaN            NaN  NaN  NaN     NaN            NaN  rs869215095
#
#            allele      zygocity Gene name          consequence  \
# 0             NaN           NaN       NaN                  NaN
# 1             NaN           NaN       NaN                  NaN
# 2             NaN           NaN       NaN                  NaN
# 3             NaN           NaN       NaN                  NaN
# 4             NaN           NaN       NaN                  NaN
# ...           ...           ...       ...                  ...
# 4953  ['GGAA', G]  Heterozygous     KAT6B     inframe_deletion
# 4954  ['GGAA', G]  Heterozygous     KAT6B     inframe_deletion
# 4955  ['AGCC', A]  Heterozygous    GNPTAB  5_prime_UTR_variant
# 4956    ['AG', A]    Homozygous    EEF1A2       intron_variant
# 4957    ['G', GT]    Homozygous      SOS1       intron_variant
#
#      clinical_significance                                associated_diseases  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# ...                    ...                                                ...
# 4953  Benign/Likely_benign  Genitopatellar_syndrome|not_specified|not_prov...
# 4954                Benign               Genitopatellar_syndrome|not_provided
# 4955                Benign  Mucolipidosis_type_II|Pseudo-Hurler_polydystro...
# 4956                Benign                                       not_provided
# 4957                Benign                         not_specified|not_provided
#
#                                           review_status    origin  \
# 0                                                   NaN       NaN
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# ...                                                 ...       ...
# 4953  criteria_provided', '_multiple_submitters', '_...  germline
# 4954             criteria_provided', '_single_submitter  germline
# 4955  criteria_provided', '_multiple_submitters', '_...  germline
# 4956             criteria_provided', '_single_submitter  germline
# 4957  criteria_provided', '_multiple_submitters', '_...  germline
#
#      variant_type variant_subtype Phargkb_ann_exists is_mutation  \
# 0             NaN             NaN                NaN         NaN
# 1             NaN             NaN                NaN         NaN
# 2             NaN             NaN                NaN         NaN
# 3             NaN             NaN                NaN         NaN
# 4             NaN             NaN                NaN         NaN
# ...           ...             ...                ...         ...
# 4953        indel        Deletion           MayBe No          No
# 4954        indel        Deletion           MayBe No          No
# 4955        indel        Deletion           MayBe No          No
# 4956        indel        Deletion           MayBe No          No
# 4957        indel       Insertion           MayBe No          No
#
#      Variant_is_precious Gene Match Matched_Gene
# 0                    NaN         No
# 1                    NaN         No
# 2                    NaN         No
# 3                    NaN         No
# 4                    NaN         No
# ...                  ...        ...          ...
# 4953                 Yes         No
# 4954                 Yes         No
# 4955                 Yes         No
# 4956                  No         No
# 4957                 Yes         No
#
# [4958 rows x 88 columns]

# %%
merged.Matched_Gene.value_counts()
# Out:
#            4876
# POLG         19
# NPC1          9
# APTX          5
# SNCA          4
# ASS1          3
# LRRK2         3
# ERCC4         3
# NR4A2         3
# RNF168        2
# SETX          2
# XPA           2
# VLDLR         2
# TTPA          2
# CA8           2
# CSTB          2
# CYP27A1       2
# VPS13C        2
# TRPM7         2
# IVD           2
# PCSK9         2
# PDHB          1
# TNK2          1
# PINK1         1
# KCNN2         1
# PEX7          1
# VPS35         1
# ATP7B         1
# ATM           1
# PHYH          1
# Name: Matched_Gene, dtype: int64

# %% [markdown]
# # single Gene

# %%
merged['Gene_Match'] = 'No'

# Iterate through each gene in df1
for genes in merged['Gene Name']:
    if isinstance(genes, str):  # Check if the gene value is a non-null string
        gene_list = genes.split(',')  # Split the genes by comma to create a list
        match = any(gene in cond_genes['Gene Name'].values for gene in gene_list)  # Check if any gene in the list exists in df2
        if match:
            merged.loc[merged['Gene Name'] == genes, 'Gene_Match'] = 'Yes'
            
merged
# Out:
#      CHROM        POS              Gene Name                    rsID  REF  \
# 0     chr1  1043223.0                   AGRN              rs35881187  CCT
# 1     chr1  1299382.0                  ACAP3             rs143128930   AG
# 2     chr1  1312198.0  INTS11,MIR6727,CPSF3L  rs70949570;rs752605219    T
# 3     chr1  1312198.0  INTS11,MIR6727,CPSF3L  rs70949570;rs752605219    T
# 4     chr1  1353987.0                  MXRA8             rs140777846  CTG
# ...    ...        ...                    ...                     ...  ...
# 4913   NaN        NaN                   HEXB                     NaN  NaN
# 4914   NaN        NaN                 SERAC1                     NaN  NaN
# 4915   NaN        NaN                  ADAM9                     NaN  NaN
# 4916   NaN        NaN                   PSAP                     NaN  NaN
# 4917   NaN        NaN                 LHFPL5                     NaN  NaN
#
#          ALT   GT   GQ  SDP   DP   RD   AD    FREQ        PVAL  RDF  RDR  ADF  \
# 0          C  0/1   93   30   30    8   22  73.33%  4.1351E-10    8    0   21
# 1          A  0/1   66   23   23    7   16  69.57%   2.4726E-7    5    2   11
# 2     TGGGGG  0/1   29   19   19    2    7  36.84%   1.1312E-3    0    2    7
# 3     TGGGGG  0/1   29   19   19    2    7  36.84%   1.1312E-3    0    2    7
# 4          C  0/1   93   59   59   33   26  44.07%  4.2407E-10   20   13   16
# ...      ...  ...  ...  ...  ...  ...  ...     ...         ...  ...  ...  ...
# 4913     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4914     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4915     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4916     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4917     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
#
#       ADR     ADP    WT    HET    HOM    NC  CDA  OTH  S3D  WTD  \
# 0       1  ADP=30  WT=0  HET=1  HOM=0  NC=0
# 1       5  ADP=23  WT=0  HET=1  HOM=0  NC=0
# 2       0  ADP=19  WT=0  HET=1  HOM=0  NC=0
# 3       0  ADP=19  WT=0  HET=1  HOM=0  NC=0
# 4      10  ADP=59  WT=0  HET=1  HOM=0  NC=0
# ...   ...     ...   ...    ...    ...   ...  ...  ...  ...  ...
# 4913  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4914  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4915  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4916  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4917  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
#
#               dbSNPBuildID  SLO  NSF   R3   R5  NSN  NSM  G5A    COMMON  \
# 0         dbSNPBuildID=126  SLO                                COMMON=1
# 1         dbSNPBuildID=134                  R5                 COMMON=1
# 2     dbSNPBuildID=144,130  SLO        R3
# 3     dbSNPBuildID=144,130  SLO        R3
# 4         dbSNPBuildID=134  SLO                           G5A  COMMON=1
# ...                    ...  ...  ...  ...  ...  ...  ...  ...       ...
# 4913                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4914                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4915                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4916                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4917                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
#
#                          RS   RV  TPA  CFL  GNO  VLD  ASP  ASS  Ref   U3   U5  \
# 0               RS=35881187   RV            GNO  VLD  ASP
# 1              RS=143128930                      VLD  ASP
# 2     RS=752605219,70949570                 GNO  VLD  ASP
# 3     RS=752605219,70949570                 GNO  VLD  ASP
# 4              RS=140777846                 GNO  VLD  ASP
# ...                     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4913                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4914                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4915                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4916                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4917                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                                  TOPMED      WGT  MTP  LSD  \
# 0        TOPMED=0.55968081039755351,0.44031918960244648    WGT=1
# 1        TOPMED=0.91126720183486238,0.08873279816513761    WGT=1
# 2     TOPMED=0.42793546126401630,0.00001592762487257...  WGT=1,1
# 3     TOPMED=0.42793546126401630,0.00001592762487257...  WGT=1,1
# 4        TOPMED=0.13763857033639143,0.86236142966360856    WGT=1
# ...                                                 ...      ...  ...  ...
# 4913                                                NaN      NaN  NaN  NaN
# 4914                                                NaN      NaN  NaN  NaN
# 4915                                                NaN      NaN  NaN  NaN
# 4916                                                NaN      NaN  NaN  NaN
# 4917                                                NaN      NaN  NaN  NaN
#
#       NOC  DSS  SYN  KGPhase3                CAF          VC  MUT  KGPhase1  \
# 0                    KGPhase3  CAF=0.5208,0.4792      VC=DIV       KGPhase1
# 1                    KGPhase3  CAF=0.8806,0.1194      VC=DIV       KGPhase1
# 2                                                 VC=DIV,DIV
# 3                                                 VC=DIV,DIV
# 4                    KGPhase3  CAF=0.1793,0.8207      VC=DIV
# ...   ...  ...  ...       ...                ...         ...  ...       ...
# 4913  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4914  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4915  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4916  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4917  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
#
#       NOV                                                 VP      SAO  INT  \
# 0                              VP=0x05012808000515013e000200    SAO=0  INT
# 1                              VP=0x0500000a000515003e000200    SAO=0  INT
# 2     NOV  VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 3     NOV  VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 4                              VP=0x050100080005170126000200    SAO=0  INT
# ...   ...                                                ...      ...  ...
# 4913  NaN                                                NaN      NaN  NaN
# 4914  NaN                                                NaN      NaN  NaN
# 4915  NaN                                                NaN      NaN  NaN
# 4916  NaN                                                NaN      NaN  NaN
# 4917  NaN                                                NaN      NaN  NaN
#
#        G5   OM  PMC      SSR                  RSPOS   HD   PM         rsid  \
# 0      G5       PMC    SSR=0          RSPOS=1043224        PM   rs35881187
# 1      G5              SSR=0          RSPOS=1299383            rs143128930
# 2                    SSR=0,0  RSPOS=1312198,1312208             rs70949570
# 3                    SSR=0,0  RSPOS=1312198,1312208            rs752605219
# 4      G5              SSR=0          RSPOS=1353988            rs140777846
# ...   ...  ...  ...      ...                    ...  ...  ...          ...
# 4913  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs70976124
# 4914  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs71027384
# 4915  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs72459173
# 4916  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs74733861
# 4917  NaN  NaN  NaN      NaN                    NaN  NaN  NaN  rs796097780
#
#                         allele      zygosity Gene name          consequence  \
# 0                   ['CCT', C]  Heterozygous      AGRN       intron_variant
# 1                          NaN           NaN       NaN                  NaN
# 2                          NaN           NaN       NaN                  NaN
# 3                          NaN           NaN       NaN                  NaN
# 4                          NaN           NaN       NaN                  NaN
# ...                        ...           ...       ...                  ...
# 4913                 ['GC', G]    Homozygous      HEXB       intron_variant
# 4914                 ['A', AT]  Heterozygous    SERAC1       intron_variant
# 4915  ['GAAATCTCAGGACTAGA', G]  Heterozygous     ADAM9       intron_variant
# 4916            ['AAGTCTC', A]    Homozygous      PSAP       intron_variant
# 4917                 ['AT', A]  Heterozygous    LHFPL5  3_prime_UTR_variant
#
#      clinical_significance                                associated_diseases  \
# 0                   Benign  Congenital_myasthenic_syndrome_8|not_specified...
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# ...                    ...                                                ...
# 4913                Benign                      Sandhoff_disease|not_provided
# 4914                Benign  3-methylglutaconic_aciduria_with_deafness', '_...
# 4915                Benign                                       not_provided
# 4916                Benign                                       not_provided
# 4917         Likely_benign            Nonsyndromic_Hearing_Loss', '_Recessive
#
#                                           review_status    origin  \
# 0     criteria_provided', '_multiple_submitters', '_...  germline
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# ...                                                 ...       ...
# 4913  criteria_provided', '_multiple_submitters', '_...  germline
# 4914  criteria_provided', '_multiple_submitters', '_...  germline
# 4915             criteria_provided', '_single_submitter  germline
# 4916             criteria_provided', '_single_submitter  germline
# 4917             criteria_provided', '_single_submitter  germline
#
#      variant_type variant_subtype Phargkb_ann_exists is_mutation  \
# 0           indel        Deletion           MayBe No          No
# 1             NaN             NaN                NaN         NaN
# 2             NaN             NaN                NaN         NaN
# 3             NaN             NaN                NaN         NaN
# 4             NaN             NaN                NaN         NaN
# ...           ...             ...                ...         ...
# 4913        indel        Deletion           MayBe No          No
# 4914        indel       Insertion           MayBe No          No
# 4915        indel        Deletion           MayBe No          No
# 4916        indel        Deletion           MayBe No          No
# 4917        indel        Deletion           MayBe No          No
#
#      Variant_is_precious Gene_Match
# 0                    Yes         No
# 1                    NaN         No
# 2                    NaN         No
# 3                    NaN         No
# 4                    NaN         No
# ...                  ...        ...
# 4913                  No         No
# 4914                  No         No
# 4915                  No         No
# 4916                  No         No
# 4917                  No         No
#
# [4918 rows x 85 columns]

# %%
cond_genes = cond_genes.rename({'Gene Name':'Matched_Gene', 'Gene_Match':'Gene Match'}, axis=1)
cond_genes
# Out:
#    Matched_Gene
# 0         BRCA1
# 1         BRCA2
# 2         PALB2
# 3        CDKN2A
# 4           ATM
# 5          TP53
# 6         STK11
# 7          MLH1
# 8          MSH2
# 9          MSH6
# 10         PMS2
# 11        EPCAM

# %%
merged = merged.drop(columns=['Gene Match'], axis=1)
merged_2 = pd.merge(merged, cond_genes, on= 'Matched_Gene', how = 'left', sort = False)
merged_2['Gene Match'] = merged_2['Gene Match'].fillna('No')
merged_2
# Out:
#      CHROM        POS Gene Name         rsID  REF  ALT   GT   GQ  SDP   DP  \
# 0     chr1  1299382.0     ACAP3  rs143128930   AG    A  0/1   97   50   50
# 1     chr1  1331945.0    TAS1R3  rs200330269    G   GC  0/1   48   41   41
# 2     chr1  1353987.0     MXRA8  rs140777846  CTG    C  0/1  219   70   70
# 3     chr1  1355779.0     MXRA8  rs201260508   GA    G  0/1   88   29   29
# 4     chr1  1657358.0    CDK11B  rs377230281    T   TA  0/1   78  112  112
# ...    ...        ...       ...          ...  ...  ...  ...  ...  ...  ...
# 4953   NaN        NaN     KAT6B          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4954   NaN        NaN     KAT6B          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4955   NaN        NaN    GNPTAB          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4956   NaN        NaN    EEF1A2          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4957   NaN        NaN      SOS1          NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        RD   AD    FREQ        PVAL  RDF  RDR  ADF  ADR      ADP    WT    HET  \
# 0      24   26     52%  1.7375E-10   18    6   17    9   ADP=50  WT=0  HET=1
# 1      26   14  34.15%   1.5388E-5   12   14    2   12   ADP=41  WT=0  HET=1
# 2      19   51  72.86%  1.2075E-22   12    7   34   17   ADP=70  WT=0  HET=1
# 3       8   21  72.41%   1.2841E-9    7    1    8   13   ADP=29  WT=0  HET=1
# 4      88   24  21.43%   1.4999E-8   65   23    4   20  ADP=112  WT=0  HET=1
# ...   ...  ...     ...         ...  ...  ...  ...  ...      ...   ...    ...
# 4953  NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN      NaN   NaN    NaN
# 4954  NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN      NaN   NaN    NaN
# 4955  NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN      NaN   NaN    NaN
# 4956  NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN      NaN   NaN    NaN
# 4957  NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN      NaN   NaN    NaN
#
#         HOM    NC  CDA  OTH  S3D  WTD      dbSNPBuildID  SLO  NSF   R3   R5  \
# 0     HOM=0  NC=0                      dbSNPBuildID=134                  R5
# 1     HOM=0  NC=0                      dbSNPBuildID=137
# 2     HOM=0  NC=0                      dbSNPBuildID=134  SLO
# 3     HOM=0  NC=0                      dbSNPBuildID=137
# 4     HOM=0  NC=0                      dbSNPBuildID=138
# ...     ...   ...  ...  ...  ...  ...               ...  ...  ...  ...  ...
# 4953    NaN   NaN  NaN  NaN  NaN  NaN               NaN  NaN  NaN  NaN  NaN
# 4954    NaN   NaN  NaN  NaN  NaN  NaN               NaN  NaN  NaN  NaN  NaN
# 4955    NaN   NaN  NaN  NaN  NaN  NaN               NaN  NaN  NaN  NaN  NaN
# 4956    NaN   NaN  NaN  NaN  NaN  NaN               NaN  NaN  NaN  NaN  NaN
# 4957    NaN   NaN  NaN  NaN  NaN  NaN               NaN  NaN  NaN  NaN  NaN
#
#       NSN  NSM  G5A    COMMON            RS   RV  TPA  CFL  GNO  VLD  ASP  \
# 0                    COMMON=1  RS=143128930                      VLD  ASP
# 1                    COMMON=1  RS=200330269                      VLD  ASP
# 2               G5A  COMMON=1  RS=140777846                 GNO  VLD  ASP
# 3                    COMMON=0  RS=201260508                           ASP
# 4                              RS=377230281                           ASP
# ...   ...  ...  ...       ...           ...  ...  ...  ...  ...  ...  ...
# 4953  NaN  NaN  NaN       NaN           NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4954  NaN  NaN  NaN       NaN           NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4955  NaN  NaN  NaN       NaN           NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4956  NaN  NaN  NaN       NaN           NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4957  NaN  NaN  NaN       NaN           NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#       ASS  Ref   U3   U5                                             TOPMED  \
# 0                            TOPMED=0.91126720183486238,0.08873279816513761
# 1                         TOPMED=0.82975758154943934,0.17023445463812436...
# 2                            TOPMED=0.13763857033639143,0.86236142966360856
# 3                            TOPMED=0.22555109582059123,0.77444890417940876
# 4                            TOPMED=0.98587219673802242,0.01412780326197757
# ...   ...  ...  ...  ...                                                ...
# 4953  NaN  NaN  NaN  NaN                                                NaN
# 4954  NaN  NaN  NaN  NaN                                                NaN
# 4955  NaN  NaN  NaN  NaN                                                NaN
# 4956  NaN  NaN  NaN  NaN                                                NaN
# 4957  NaN  NaN  NaN  NaN                                                NaN
#
#         WGT  MTP  LSD  NOC  DSS  SYN  KGPhase3                  CAF      VC  \
# 0     WGT=1                           KGPhase3    CAF=0.8806,0.1194  VC=DIV
# 1     WGT=1                           KGPhase3  CAF=0.8105,0.1895,.  VC=DIV
# 2     WGT=1                           KGPhase3    CAF=0.1793,0.8207  VC=DIV
# 3     WGT=1                           KGPhase3              CAF=0,1  VC=DIV
# 4     WGT=1                                                          VC=DIV
# ...     ...  ...  ...  ...  ...  ...       ...                  ...     ...
# 4953    NaN  NaN  NaN  NaN  NaN  NaN       NaN                  NaN     NaN
# 4954    NaN  NaN  NaN  NaN  NaN  NaN       NaN                  NaN     NaN
# 4955    NaN  NaN  NaN  NaN  NaN  NaN       NaN                  NaN     NaN
# 4956    NaN  NaN  NaN  NaN  NaN  NaN       NaN                  NaN     NaN
# 4957    NaN  NaN  NaN  NaN  NaN  NaN       NaN                  NaN     NaN
#
#       MUT  KGPhase1  NOV                             VP    SAO  INT   G5   OM  \
# 0          KGPhase1       VP=0x0500000a000515003e000200  SAO=0  INT   G5
# 1          KGPhase1       VP=0x05000008000515003e000200  SAO=0  INT   G5
# 2                         VP=0x050100080005170126000200  SAO=0  INT   G5
# 3          KGPhase1       VP=0x05000008000500003e000200  SAO=0  INT
# 4                         VP=0x050000080005000002000200  SAO=0  INT
# ...   ...       ...  ...                            ...    ...  ...  ...  ...
# 4953  NaN       NaN  NaN                            NaN    NaN  NaN  NaN  NaN
# 4954  NaN       NaN  NaN                            NaN    NaN  NaN  NaN  NaN
# 4955  NaN       NaN  NaN                            NaN    NaN  NaN  NaN  NaN
# 4956  NaN       NaN  NaN                            NaN    NaN  NaN  NaN  NaN
# 4957  NaN       NaN  NaN                            NaN    NaN  NaN  NaN  NaN
#
#       PMC    SSR          RSPOS   HD   PM ClinVar ClinVar_CLNSIG         rsid  \
# 0          SSR=0  RSPOS=1299383                                   rs143128930
# 1          SSR=0  RSPOS=1331945                                   rs200330269
# 2          SSR=0  RSPOS=1353988                                   rs140777846
# 3          SSR=0  RSPOS=1355780                                   rs201260508
# 4          SSR=0  RSPOS=1657358                                   rs377230281
# ...   ...    ...            ...  ...  ...     ...            ...          ...
# 4953  NaN    NaN            NaN  NaN  NaN     NaN            NaN   rs71929101
# 4954  NaN    NaN            NaN  NaN  NaN     NaN            NaN   rs71929101
# 4955  NaN    NaN            NaN  NaN  NaN     NaN            NaN   rs76300806
# 4956  NaN    NaN            NaN  NaN  NaN     NaN            NaN   rs77467883
# 4957  NaN    NaN            NaN  NaN  NaN     NaN            NaN  rs869215095
#
#            allele      zygocity Gene name          consequence  \
# 0             NaN           NaN       NaN                  NaN
# 1             NaN           NaN       NaN                  NaN
# 2             NaN           NaN       NaN                  NaN
# 3             NaN           NaN       NaN                  NaN
# 4             NaN           NaN       NaN                  NaN
# ...           ...           ...       ...                  ...
# 4953  ['GGAA', G]  Heterozygous     KAT6B     inframe_deletion
# 4954  ['GGAA', G]  Heterozygous     KAT6B     inframe_deletion
# 4955  ['AGCC', A]  Heterozygous    GNPTAB  5_prime_UTR_variant
# 4956    ['AG', A]    Homozygous    EEF1A2       intron_variant
# 4957    ['G', GT]    Homozygous      SOS1       intron_variant
#
#      clinical_significance                                associated_diseases  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# ...                    ...                                                ...
# 4953  Benign/Likely_benign  Genitopatellar_syndrome|not_specified|not_prov...
# 4954                Benign               Genitopatellar_syndrome|not_provided
# 4955                Benign  Mucolipidosis_type_II|Pseudo-Hurler_polydystro...
# 4956                Benign                                       not_provided
# 4957                Benign                         not_specified|not_provided
#
#                                           review_status    origin  \
# 0                                                   NaN       NaN
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# ...                                                 ...       ...
# 4953  criteria_provided', '_multiple_submitters', '_...  germline
# 4954             criteria_provided', '_single_submitter  germline
# 4955  criteria_provided', '_multiple_submitters', '_...  germline
# 4956             criteria_provided', '_single_submitter  germline
# 4957  criteria_provided', '_multiple_submitters', '_...  germline
#
#      variant_type variant_subtype Phargkb_ann_exists is_mutation  \
# 0             NaN             NaN                NaN         NaN
# 1             NaN             NaN                NaN         NaN
# 2             NaN             NaN                NaN         NaN
# 3             NaN             NaN                NaN         NaN
# 4             NaN             NaN                NaN         NaN
# ...           ...             ...                ...         ...
# 4953        indel        Deletion           MayBe No          No
# 4954        indel        Deletion           MayBe No          No
# 4955        indel        Deletion           MayBe No          No
# 4956        indel        Deletion           MayBe No          No
# 4957        indel       Insertion           MayBe No          No
#
#      Variant_is_precious Matched_Gene Gene Match
# 0                    NaN                      No
# 1                    NaN                      No
# 2                    NaN                      No
# 3                    NaN                      No
# 4                    NaN                      No
# ...                  ...          ...        ...
# 4953                 Yes                      No
# 4954                 Yes                      No
# 4955                 Yes                      No
# 4956                  No                      No
# 4957                 Yes                      No
#
# [4958 rows x 88 columns]

# %%
merged['Consequence'] = merged['consequence'].astype(str).apply(lambda x: x.replace('&', ',').replace('_', ' ').replace("'", '').replace("-", ' '))
merged['Consequence'] = merged['Consequence'].str.split(',').str[0]
merged
# Out:
#      CHROM        POS              Gene Name                    rsID  REF  \
# 0     chr1  1043223.0                   AGRN              rs35881187  CCT
# 1     chr1  1299382.0                  ACAP3             rs143128930   AG
# 2     chr1  1312198.0  INTS11,MIR6727,CPSF3L  rs70949570;rs752605219    T
# 3     chr1  1312198.0  INTS11,MIR6727,CPSF3L  rs70949570;rs752605219    T
# 4     chr1  1353987.0                  MXRA8             rs140777846  CTG
# ...    ...        ...                    ...                     ...  ...
# 4913   NaN        NaN                   HEXB                     NaN  NaN
# 4914   NaN        NaN                 SERAC1                     NaN  NaN
# 4915   NaN        NaN                  ADAM9                     NaN  NaN
# 4916   NaN        NaN                   PSAP                     NaN  NaN
# 4917   NaN        NaN                 LHFPL5                     NaN  NaN
#
#          ALT   GT   GQ  SDP   DP   RD   AD    FREQ        PVAL  RDF  RDR  ADF  \
# 0          C  0/1   93   30   30    8   22  73.33%  4.1351E-10    8    0   21
# 1          A  0/1   66   23   23    7   16  69.57%   2.4726E-7    5    2   11
# 2     TGGGGG  0/1   29   19   19    2    7  36.84%   1.1312E-3    0    2    7
# 3     TGGGGG  0/1   29   19   19    2    7  36.84%   1.1312E-3    0    2    7
# 4          C  0/1   93   59   59   33   26  44.07%  4.2407E-10   20   13   16
# ...      ...  ...  ...  ...  ...  ...  ...     ...         ...  ...  ...  ...
# 4913     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4914     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4915     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4916     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4917     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
#
#       ADR     ADP    WT    HET    HOM    NC  CDA  OTH  S3D  WTD  \
# 0       1  ADP=30  WT=0  HET=1  HOM=0  NC=0
# 1       5  ADP=23  WT=0  HET=1  HOM=0  NC=0
# 2       0  ADP=19  WT=0  HET=1  HOM=0  NC=0
# 3       0  ADP=19  WT=0  HET=1  HOM=0  NC=0
# 4      10  ADP=59  WT=0  HET=1  HOM=0  NC=0
# ...   ...     ...   ...    ...    ...   ...  ...  ...  ...  ...
# 4913  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4914  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4915  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4916  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4917  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
#
#               dbSNPBuildID  SLO  NSF   R3   R5  NSN  NSM  G5A    COMMON  \
# 0         dbSNPBuildID=126  SLO                                COMMON=1
# 1         dbSNPBuildID=134                  R5                 COMMON=1
# 2     dbSNPBuildID=144,130  SLO        R3
# 3     dbSNPBuildID=144,130  SLO        R3
# 4         dbSNPBuildID=134  SLO                           G5A  COMMON=1
# ...                    ...  ...  ...  ...  ...  ...  ...  ...       ...
# 4913                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4914                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4915                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4916                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4917                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
#
#                          RS   RV  TPA  CFL  GNO  VLD  ASP  ASS  Ref   U3   U5  \
# 0               RS=35881187   RV            GNO  VLD  ASP
# 1              RS=143128930                      VLD  ASP
# 2     RS=752605219,70949570                 GNO  VLD  ASP
# 3     RS=752605219,70949570                 GNO  VLD  ASP
# 4              RS=140777846                 GNO  VLD  ASP
# ...                     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4913                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4914                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4915                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4916                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4917                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                                  TOPMED      WGT  MTP  LSD  \
# 0        TOPMED=0.55968081039755351,0.44031918960244648    WGT=1
# 1        TOPMED=0.91126720183486238,0.08873279816513761    WGT=1
# 2     TOPMED=0.42793546126401630,0.00001592762487257...  WGT=1,1
# 3     TOPMED=0.42793546126401630,0.00001592762487257...  WGT=1,1
# 4        TOPMED=0.13763857033639143,0.86236142966360856    WGT=1
# ...                                                 ...      ...  ...  ...
# 4913                                                NaN      NaN  NaN  NaN
# 4914                                                NaN      NaN  NaN  NaN
# 4915                                                NaN      NaN  NaN  NaN
# 4916                                                NaN      NaN  NaN  NaN
# 4917                                                NaN      NaN  NaN  NaN
#
#       NOC  DSS  SYN  KGPhase3                CAF          VC  MUT  KGPhase1  \
# 0                    KGPhase3  CAF=0.5208,0.4792      VC=DIV       KGPhase1
# 1                    KGPhase3  CAF=0.8806,0.1194      VC=DIV       KGPhase1
# 2                                                 VC=DIV,DIV
# 3                                                 VC=DIV,DIV
# 4                    KGPhase3  CAF=0.1793,0.8207      VC=DIV
# ...   ...  ...  ...       ...                ...         ...  ...       ...
# 4913  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4914  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4915  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4916  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4917  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
#
#       NOV                                                 VP      SAO  INT  \
# 0                              VP=0x05012808000515013e000200    SAO=0  INT
# 1                              VP=0x0500000a000515003e000200    SAO=0  INT
# 2     NOV  VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 3     NOV  VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 4                              VP=0x050100080005170126000200    SAO=0  INT
# ...   ...                                                ...      ...  ...
# 4913  NaN                                                NaN      NaN  NaN
# 4914  NaN                                                NaN      NaN  NaN
# 4915  NaN                                                NaN      NaN  NaN
# 4916  NaN                                                NaN      NaN  NaN
# 4917  NaN                                                NaN      NaN  NaN
#
#        G5   OM  PMC      SSR                  RSPOS   HD   PM         rsid  \
# 0      G5       PMC    SSR=0          RSPOS=1043224        PM   rs35881187
# 1      G5              SSR=0          RSPOS=1299383            rs143128930
# 2                    SSR=0,0  RSPOS=1312198,1312208             rs70949570
# 3                    SSR=0,0  RSPOS=1312198,1312208            rs752605219
# 4      G5              SSR=0          RSPOS=1353988            rs140777846
# ...   ...  ...  ...      ...                    ...  ...  ...          ...
# 4913  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs70976124
# 4914  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs71027384
# 4915  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs72459173
# 4916  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs74733861
# 4917  NaN  NaN  NaN      NaN                    NaN  NaN  NaN  rs796097780
#
#                         allele      zygosity Gene name          consequence  \
# 0                   ['CCT', C]  Heterozygous      AGRN       intron_variant
# 1                          NaN           NaN       NaN                  NaN
# 2                          NaN           NaN       NaN                  NaN
# 3                          NaN           NaN       NaN                  NaN
# 4                          NaN           NaN       NaN                  NaN
# ...                        ...           ...       ...                  ...
# 4913                 ['GC', G]    Homozygous      HEXB       intron_variant
# 4914                 ['A', AT]  Heterozygous    SERAC1       intron_variant
# 4915  ['GAAATCTCAGGACTAGA', G]  Heterozygous     ADAM9       intron_variant
# 4916            ['AAGTCTC', A]    Homozygous      PSAP       intron_variant
# 4917                 ['AT', A]  Heterozygous    LHFPL5  3_prime_UTR_variant
#
#      clinical_significance                                associated_diseases  \
# 0                   Benign  Congenital_myasthenic_syndrome_8|not_specified...
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# ...                    ...                                                ...
# 4913                Benign                      Sandhoff_disease|not_provided
# 4914                Benign  3-methylglutaconic_aciduria_with_deafness', '_...
# 4915                Benign                                       not_provided
# 4916                Benign                                       not_provided
# 4917         Likely_benign            Nonsyndromic_Hearing_Loss', '_Recessive
#
#                                           review_status    origin  \
# 0     criteria_provided', '_multiple_submitters', '_...  germline
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# ...                                                 ...       ...
# 4913  criteria_provided', '_multiple_submitters', '_...  germline
# 4914  criteria_provided', '_multiple_submitters', '_...  germline
# 4915             criteria_provided', '_single_submitter  germline
# 4916             criteria_provided', '_single_submitter  germline
# 4917             criteria_provided', '_single_submitter  germline
#
#      variant_type variant_subtype Phargkb_ann_exists is_mutation  \
# 0           indel        Deletion           MayBe No          No
# 1             NaN             NaN                NaN         NaN
# 2             NaN             NaN                NaN         NaN
# 3             NaN             NaN                NaN         NaN
# 4             NaN             NaN                NaN         NaN
# ...           ...             ...                ...         ...
# 4913        indel        Deletion           MayBe No          No
# 4914        indel       Insertion           MayBe No          No
# 4915        indel        Deletion           MayBe No          No
# 4916        indel        Deletion           MayBe No          No
# 4917        indel        Deletion           MayBe No          No
#
#      Variant_is_precious Gene_Match          Consequence
# 0                    Yes         No       intron variant
# 1                    NaN         No                  nan
# 2                    NaN         No                  nan
# 3                    NaN         No                  nan
# 4                    NaN         No                  nan
# ...                  ...        ...                  ...
# 4913                  No         No       intron variant
# 4914                  No         No       intron variant
# 4915                  No         No       intron variant
# 4916                  No         No       intron variant
# 4917                  No         No  3 prime UTR variant
#
# [4918 rows x 86 columns]

# %%
df_1 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Madhu_folder_04_07_2023/kidney_health_final.vcf/consequence.xlsx')
df_1 = df_1.rename({'consequence':'Consequence'}, axis =1)
df_1
# Out:
#                             Consequence Consequence_score
# 0                   transcript ablation             10/10
# 1               splice acceptor variant              8/10
# 2                  splice donor variant              8/10
# 3                           stop gained             10/10
# 4                    frameshift variant             10/10
# 5                             stop lost              9/10
# 6                            start lost              9/10
# 7              transcript amplification              8/10
# 8                     inframe insertion              6/10
# 9                      inframe deletion              6/10
# 10                     missense variant              7/10
# 11             protein altering variant              5/10
# 12                splice region variant              4/10
# 13        splice donor 5th base variant              4/10
# 14          splice donor region variant              4/10
# 15  splice polypyrimidine tract variant              4/10
# 16    incomplete terminal codon variant              3/10
# 17               start retained variant              3/10
# 18                stop retained variant              3/10
# 19                   synonymous variant              3/10
# 20              coding sequence variant              3/10
# 21                 mature miRNA variant              3/10
# 22                  5 prime UTR variant              3/10
# 23                  3 prime UTR variant              3/10
# 24   non coding transcript exon variant              2/10
# 25                       intron variant              2/10
# 26               NMD transcript variant              2/10
# 27        non coding transcript variant              2/10
# 28                upstream gene variant              2/10
# 29              downstream gene variant              2/10
# 30                        TFBS ablation              2/10
# 31                   TFBS amplification              2/10
# 32              TF binding site variant              2/10
# 33           regulatory region ablation              2/10
# 34      regulatory region amplification              2/10
# 35                   feature elongation              2/10
# 36            regulatory region variant              2/10
# 37                   feature truncation              1/10
# 38                   intergenic variant              1/10

# %%
merged_1 = pd.merge(merged, df_1, on='Consequence', how='left', sort=False)
merged_1
# Out:
#      CHROM        POS              Gene Name                    rsID  REF  \
# 0     chr1  1043223.0                   AGRN              rs35881187  CCT
# 1     chr1  1299382.0                  ACAP3             rs143128930   AG
# 2     chr1  1312198.0  INTS11,MIR6727,CPSF3L  rs70949570;rs752605219    T
# 3     chr1  1312198.0  INTS11,MIR6727,CPSF3L  rs70949570;rs752605219    T
# 4     chr1  1353987.0                  MXRA8             rs140777846  CTG
# ...    ...        ...                    ...                     ...  ...
# 4913   NaN        NaN                   HEXB                     NaN  NaN
# 4914   NaN        NaN                 SERAC1                     NaN  NaN
# 4915   NaN        NaN                  ADAM9                     NaN  NaN
# 4916   NaN        NaN                   PSAP                     NaN  NaN
# 4917   NaN        NaN                 LHFPL5                     NaN  NaN
#
#          ALT   GT   GQ  SDP   DP   RD   AD    FREQ        PVAL  RDF  RDR  ADF  \
# 0          C  0/1   93   30   30    8   22  73.33%  4.1351E-10    8    0   21
# 1          A  0/1   66   23   23    7   16  69.57%   2.4726E-7    5    2   11
# 2     TGGGGG  0/1   29   19   19    2    7  36.84%   1.1312E-3    0    2    7
# 3     TGGGGG  0/1   29   19   19    2    7  36.84%   1.1312E-3    0    2    7
# 4          C  0/1   93   59   59   33   26  44.07%  4.2407E-10   20   13   16
# ...      ...  ...  ...  ...  ...  ...  ...     ...         ...  ...  ...  ...
# 4913     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4914     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4915     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4916     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
# 4917     NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN         NaN  NaN  NaN  NaN
#
#       ADR     ADP    WT    HET    HOM    NC  CDA  OTH  S3D  WTD  \
# 0       1  ADP=30  WT=0  HET=1  HOM=0  NC=0
# 1       5  ADP=23  WT=0  HET=1  HOM=0  NC=0
# 2       0  ADP=19  WT=0  HET=1  HOM=0  NC=0
# 3       0  ADP=19  WT=0  HET=1  HOM=0  NC=0
# 4      10  ADP=59  WT=0  HET=1  HOM=0  NC=0
# ...   ...     ...   ...    ...    ...   ...  ...  ...  ...  ...
# 4913  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4914  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4915  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4916  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 4917  NaN     NaN   NaN    NaN    NaN   NaN  NaN  NaN  NaN  NaN
#
#               dbSNPBuildID  SLO  NSF   R3   R5  NSN  NSM  G5A    COMMON  \
# 0         dbSNPBuildID=126  SLO                                COMMON=1
# 1         dbSNPBuildID=134                  R5                 COMMON=1
# 2     dbSNPBuildID=144,130  SLO        R3
# 3     dbSNPBuildID=144,130  SLO        R3
# 4         dbSNPBuildID=134  SLO                           G5A  COMMON=1
# ...                    ...  ...  ...  ...  ...  ...  ...  ...       ...
# 4913                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4914                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4915                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4916                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 4917                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
#
#                          RS   RV  TPA  CFL  GNO  VLD  ASP  ASS  Ref   U3   U5  \
# 0               RS=35881187   RV            GNO  VLD  ASP
# 1              RS=143128930                      VLD  ASP
# 2     RS=752605219,70949570                 GNO  VLD  ASP
# 3     RS=752605219,70949570                 GNO  VLD  ASP
# 4              RS=140777846                 GNO  VLD  ASP
# ...                     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4913                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4914                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4915                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4916                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4917                    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                                  TOPMED      WGT  MTP  LSD  \
# 0        TOPMED=0.55968081039755351,0.44031918960244648    WGT=1
# 1        TOPMED=0.91126720183486238,0.08873279816513761    WGT=1
# 2     TOPMED=0.42793546126401630,0.00001592762487257...  WGT=1,1
# 3     TOPMED=0.42793546126401630,0.00001592762487257...  WGT=1,1
# 4        TOPMED=0.13763857033639143,0.86236142966360856    WGT=1
# ...                                                 ...      ...  ...  ...
# 4913                                                NaN      NaN  NaN  NaN
# 4914                                                NaN      NaN  NaN  NaN
# 4915                                                NaN      NaN  NaN  NaN
# 4916                                                NaN      NaN  NaN  NaN
# 4917                                                NaN      NaN  NaN  NaN
#
#       NOC  DSS  SYN  KGPhase3                CAF          VC  MUT  KGPhase1  \
# 0                    KGPhase3  CAF=0.5208,0.4792      VC=DIV       KGPhase1
# 1                    KGPhase3  CAF=0.8806,0.1194      VC=DIV       KGPhase1
# 2                                                 VC=DIV,DIV
# 3                                                 VC=DIV,DIV
# 4                    KGPhase3  CAF=0.1793,0.8207      VC=DIV
# ...   ...  ...  ...       ...                ...         ...  ...       ...
# 4913  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4914  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4915  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4916  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
# 4917  NaN  NaN  NaN       NaN                NaN         NaN  NaN       NaN
#
#       NOV                                                 VP      SAO  INT  \
# 0                              VP=0x05012808000515013e000200    SAO=0  INT
# 1                              VP=0x0500000a000515003e000200    SAO=0  INT
# 2     NOV  VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 3     NOV  VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 4                              VP=0x050100080005170126000200    SAO=0  INT
# ...   ...                                                ...      ...  ...
# 4913  NaN                                                NaN      NaN  NaN
# 4914  NaN                                                NaN      NaN  NaN
# 4915  NaN                                                NaN      NaN  NaN
# 4916  NaN                                                NaN      NaN  NaN
# 4917  NaN                                                NaN      NaN  NaN
#
#        G5   OM  PMC      SSR                  RSPOS   HD   PM         rsid  \
# 0      G5       PMC    SSR=0          RSPOS=1043224        PM   rs35881187
# 1      G5              SSR=0          RSPOS=1299383            rs143128930
# 2                    SSR=0,0  RSPOS=1312198,1312208             rs70949570
# 3                    SSR=0,0  RSPOS=1312198,1312208            rs752605219
# 4      G5              SSR=0          RSPOS=1353988            rs140777846
# ...   ...  ...  ...      ...                    ...  ...  ...          ...
# 4913  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs70976124
# 4914  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs71027384
# 4915  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs72459173
# 4916  NaN  NaN  NaN      NaN                    NaN  NaN  NaN   rs74733861
# 4917  NaN  NaN  NaN      NaN                    NaN  NaN  NaN  rs796097780
#
#                         allele      zygosity Gene name          consequence  \
# 0                   ['CCT', C]  Heterozygous      AGRN       intron_variant
# 1                          NaN           NaN       NaN                  NaN
# 2                          NaN           NaN       NaN                  NaN
# 3                          NaN           NaN       NaN                  NaN
# 4                          NaN           NaN       NaN                  NaN
# ...                        ...           ...       ...                  ...
# 4913                 ['GC', G]    Homozygous      HEXB       intron_variant
# 4914                 ['A', AT]  Heterozygous    SERAC1       intron_variant
# 4915  ['GAAATCTCAGGACTAGA', G]  Heterozygous     ADAM9       intron_variant
# 4916            ['AAGTCTC', A]    Homozygous      PSAP       intron_variant
# 4917                 ['AT', A]  Heterozygous    LHFPL5  3_prime_UTR_variant
#
#      clinical_significance                                associated_diseases  \
# 0                   Benign  Congenital_myasthenic_syndrome_8|not_specified...
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# ...                    ...                                                ...
# 4913                Benign                      Sandhoff_disease|not_provided
# 4914                Benign  3-methylglutaconic_aciduria_with_deafness', '_...
# 4915                Benign                                       not_provided
# 4916                Benign                                       not_provided
# 4917         Likely_benign            Nonsyndromic_Hearing_Loss', '_Recessive
#
#                                           review_status    origin  \
# 0     criteria_provided', '_multiple_submitters', '_...  germline
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# ...                                                 ...       ...
# 4913  criteria_provided', '_multiple_submitters', '_...  germline
# 4914  criteria_provided', '_multiple_submitters', '_...  germline
# 4915             criteria_provided', '_single_submitter  germline
# 4916             criteria_provided', '_single_submitter  germline
# 4917             criteria_provided', '_single_submitter  germline
#
#      variant_type variant_subtype Phargkb_ann_exists is_mutation  \
# 0           indel        Deletion           MayBe No          No
# 1             NaN             NaN                NaN         NaN
# 2             NaN             NaN                NaN         NaN
# 3             NaN             NaN                NaN         NaN
# 4             NaN             NaN                NaN         NaN
# ...           ...             ...                ...         ...
# 4913        indel        Deletion           MayBe No          No
# 4914        indel       Insertion           MayBe No          No
# 4915        indel        Deletion           MayBe No          No
# 4916        indel        Deletion           MayBe No          No
# 4917        indel        Deletion           MayBe No          No
#
#      Variant_is_precious Gene_Match          Consequence Consequence_score
# 0                    Yes         No       intron variant              2/10
# 1                    NaN         No                  nan               NaN
# 2                    NaN         No                  nan               NaN
# 3                    NaN         No                  nan               NaN
# 4                    NaN         No                  nan               NaN
# ...                  ...        ...                  ...               ...
# 4913                  No         No       intron variant              2/10
# 4914                  No         No       intron variant              2/10
# 4915                  No         No       intron variant              2/10
# 4916                  No         No       intron variant              2/10
# 4917                  No         No  3 prime UTR variant              3/10
#
# [4918 rows x 87 columns]

# %%
merged_1.columns
# Out:
# Index(['CHROM', 'POS', 'Gene Name', 'rsID', 'REF', 'ALT', 'GT', 'GQ', 'SDP',
#        'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'ADP',
#        'WT', 'HET', 'HOM', 'NC', 'CDA', 'OTH', 'S3D', 'WTD', 'dbSNPBuildID',
#        'SLO', 'NSF', 'R3', 'R5', 'NSN', 'NSM', 'G5A', 'COMMON', 'RS', 'RV',
#        'TPA', 'CFL', 'GNO', 'VLD', 'ASP', 'ASS', 'Ref', 'U3', 'U5', 'TOPMED',
#        'WGT', 'MTP', 'LSD', 'NOC', 'DSS', 'SYN', 'KGPhase3', 'CAF', 'VC',
#        'MUT', 'KGPhase1', 'NOV', 'VP', 'SAO', 'INT', 'G5', 'OM', 'PMC', 'SSR',
#        'RSPOS', 'HD', 'PM', 'rsid', 'allele', 'zygosity', 'Gene name',
#        'consequence', 'clinical_significance', 'associated_diseases',
#        'review_status', 'origin', 'variant_type', 'variant_subtype',
#        'Phargkb_ann_exists', 'is_mutation', 'Variant_is_precious',
#        'Gene_Match', 'Consequence', 'Consequence_score'],
#       dtype='object')

# %%
merged_1 = merged_1[['CHROM', 'POS', 'Gene Name', 'Gene_Match', 'rsID', 'REF', 'ALT', 'GT', 'GQ', 'SDP',
       'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'ADP',
       'WT', 'HET', 'HOM', 'NC', 'CDA', 'OTH', 'S3D', 'WTD', 'dbSNPBuildID',
       'SLO', 'NSF', 'R3', 'R5', 'NSN', 'NSM', 'G5A', 'COMMON', 'RS', 'RV',
       'TPA', 'CFL', 'GNO', 'VLD', 'ASP', 'ASS', 'Ref', 'U3', 'U5', 'TOPMED',
       'WGT', 'MTP', 'LSD', 'NOC', 'DSS', 'SYN', 'KGPhase3', 'CAF', 'VC',
       'MUT', 'KGPhase1', 'NOV', 'VP', 'SAO', 'INT', 'G5', 'OM', 'PMC', 'SSR',
       'RSPOS', 'HD', 'PM', 'allele',
       'zygosity', 'consequence', 'Consequence_score', 'clinical_significance',
       'associated_diseases', 'review_status', 'origin', 'variant_type',
       'variant_subtype', 'Phargkb_ann_exists', 'is_mutation',
       'Variant_is_precious']]
merged_1
# Out:
#      CHROM        POS              Gene Name Gene_Match  \
# 0     chr1  1043223.0                   AGRN         No
# 1     chr1  1299382.0                  ACAP3         No
# 2     chr1  1312198.0  INTS11,MIR6727,CPSF3L         No
# 3     chr1  1312198.0  INTS11,MIR6727,CPSF3L         No
# 4     chr1  1353987.0                  MXRA8         No
# ...    ...        ...                    ...        ...
# 4913   NaN        NaN                   HEXB         No
# 4914   NaN        NaN                 SERAC1         No
# 4915   NaN        NaN                  ADAM9         No
# 4916   NaN        NaN                   PSAP         No
# 4917   NaN        NaN                 LHFPL5         No
#
#                         rsID  REF     ALT   GT   GQ  SDP   DP   RD   AD  \
# 0                 rs35881187  CCT       C  0/1   93   30   30    8   22
# 1                rs143128930   AG       A  0/1   66   23   23    7   16
# 2     rs70949570;rs752605219    T  TGGGGG  0/1   29   19   19    2    7
# 3     rs70949570;rs752605219    T  TGGGGG  0/1   29   19   19    2    7
# 4                rs140777846  CTG       C  0/1   93   59   59   33   26
# ...                      ...  ...     ...  ...  ...  ...  ...  ...  ...
# 4913                     NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4914                     NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4915                     NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4916                     NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4917                     NaN  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#         FREQ        PVAL  RDF  RDR  ADF  ADR     ADP    WT    HET    HOM  \
# 0     73.33%  4.1351E-10    8    0   21    1  ADP=30  WT=0  HET=1  HOM=0
# 1     69.57%   2.4726E-7    5    2   11    5  ADP=23  WT=0  HET=1  HOM=0
# 2     36.84%   1.1312E-3    0    2    7    0  ADP=19  WT=0  HET=1  HOM=0
# 3     36.84%   1.1312E-3    0    2    7    0  ADP=19  WT=0  HET=1  HOM=0
# 4     44.07%  4.2407E-10   20   13   16   10  ADP=59  WT=0  HET=1  HOM=0
# ...      ...         ...  ...  ...  ...  ...     ...   ...    ...    ...
# 4913     NaN         NaN  NaN  NaN  NaN  NaN     NaN   NaN    NaN    NaN
# 4914     NaN         NaN  NaN  NaN  NaN  NaN     NaN   NaN    NaN    NaN
# 4915     NaN         NaN  NaN  NaN  NaN  NaN     NaN   NaN    NaN    NaN
# 4916     NaN         NaN  NaN  NaN  NaN  NaN     NaN   NaN    NaN    NaN
# 4917     NaN         NaN  NaN  NaN  NaN  NaN     NaN   NaN    NaN    NaN
#
#         NC  CDA  OTH  S3D  WTD          dbSNPBuildID  SLO  NSF   R3   R5  NSN  \
# 0     NC=0                          dbSNPBuildID=126  SLO
# 1     NC=0                          dbSNPBuildID=134                  R5
# 2     NC=0                      dbSNPBuildID=144,130  SLO        R3
# 3     NC=0                      dbSNPBuildID=144,130  SLO        R3
# 4     NC=0                          dbSNPBuildID=134  SLO
# ...    ...  ...  ...  ...  ...                   ...  ...  ...  ...  ...  ...
# 4913   NaN  NaN  NaN  NaN  NaN                   NaN  NaN  NaN  NaN  NaN  NaN
# 4914   NaN  NaN  NaN  NaN  NaN                   NaN  NaN  NaN  NaN  NaN  NaN
# 4915   NaN  NaN  NaN  NaN  NaN                   NaN  NaN  NaN  NaN  NaN  NaN
# 4916   NaN  NaN  NaN  NaN  NaN                   NaN  NaN  NaN  NaN  NaN  NaN
# 4917   NaN  NaN  NaN  NaN  NaN                   NaN  NaN  NaN  NaN  NaN  NaN
#
#       NSM  G5A    COMMON                     RS   RV  TPA  CFL  GNO  VLD  ASP  \
# 0               COMMON=1            RS=35881187   RV            GNO  VLD  ASP
# 1               COMMON=1           RS=143128930                      VLD  ASP
# 2                         RS=752605219,70949570                 GNO  VLD  ASP
# 3                         RS=752605219,70949570                 GNO  VLD  ASP
# 4          G5A  COMMON=1           RS=140777846                 GNO  VLD  ASP
# ...   ...  ...       ...                    ...  ...  ...  ...  ...  ...  ...
# 4913  NaN  NaN       NaN                    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4914  NaN  NaN       NaN                    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4915  NaN  NaN       NaN                    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4916  NaN  NaN       NaN                    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4917  NaN  NaN       NaN                    NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#       ASS  Ref   U3   U5                                             TOPMED  \
# 0                            TOPMED=0.55968081039755351,0.44031918960244648
# 1                            TOPMED=0.91126720183486238,0.08873279816513761
# 2                         TOPMED=0.42793546126401630,0.00001592762487257...
# 3                         TOPMED=0.42793546126401630,0.00001592762487257...
# 4                            TOPMED=0.13763857033639143,0.86236142966360856
# ...   ...  ...  ...  ...                                                ...
# 4913  NaN  NaN  NaN  NaN                                                NaN
# 4914  NaN  NaN  NaN  NaN                                                NaN
# 4915  NaN  NaN  NaN  NaN                                                NaN
# 4916  NaN  NaN  NaN  NaN                                                NaN
# 4917  NaN  NaN  NaN  NaN                                                NaN
#
#           WGT  MTP  LSD  NOC  DSS  SYN  KGPhase3                CAF  \
# 0       WGT=1                           KGPhase3  CAF=0.5208,0.4792
# 1       WGT=1                           KGPhase3  CAF=0.8806,0.1194
# 2     WGT=1,1
# 3     WGT=1,1
# 4       WGT=1                           KGPhase3  CAF=0.1793,0.8207
# ...       ...  ...  ...  ...  ...  ...       ...                ...
# 4913      NaN  NaN  NaN  NaN  NaN  NaN       NaN                NaN
# 4914      NaN  NaN  NaN  NaN  NaN  NaN       NaN                NaN
# 4915      NaN  NaN  NaN  NaN  NaN  NaN       NaN                NaN
# 4916      NaN  NaN  NaN  NaN  NaN  NaN       NaN                NaN
# 4917      NaN  NaN  NaN  NaN  NaN  NaN       NaN                NaN
#
#               VC  MUT  KGPhase1  NOV  \
# 0         VC=DIV       KGPhase1
# 1         VC=DIV       KGPhase1
# 2     VC=DIV,DIV                 NOV
# 3     VC=DIV,DIV                 NOV
# 4         VC=DIV
# ...          ...  ...       ...  ...
# 4913         NaN  NaN       NaN  NaN
# 4914         NaN  NaN       NaN  NaN
# 4915         NaN  NaN       NaN  NaN
# 4916         NaN  NaN       NaN  NaN
# 4917         NaN  NaN       NaN  NaN
#
#                                                      VP      SAO  INT   G5  \
# 0                         VP=0x05012808000515013e000200    SAO=0  INT   G5
# 1                         VP=0x0500000a000515003e000200    SAO=0  INT   G5
# 2     VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 3     VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 4                         VP=0x050100080005170126000200    SAO=0  INT   G5
# ...                                                 ...      ...  ...  ...
# 4913                                                NaN      NaN  NaN  NaN
# 4914                                                NaN      NaN  NaN  NaN
# 4915                                                NaN      NaN  NaN  NaN
# 4916                                                NaN      NaN  NaN  NaN
# 4917                                                NaN      NaN  NaN  NaN
#
#        OM  PMC      SSR                  RSPOS   HD   PM  \
# 0          PMC    SSR=0          RSPOS=1043224        PM
# 1                 SSR=0          RSPOS=1299383
# 2               SSR=0,0  RSPOS=1312198,1312208
# 3               SSR=0,0  RSPOS=1312198,1312208
# 4                 SSR=0          RSPOS=1353988
# ...   ...  ...      ...                    ...  ...  ...
# 4913  NaN  NaN      NaN                    NaN  NaN  NaN
# 4914  NaN  NaN      NaN                    NaN  NaN  NaN
# 4915  NaN  NaN      NaN                    NaN  NaN  NaN
# 4916  NaN  NaN      NaN                    NaN  NaN  NaN
# 4917  NaN  NaN      NaN                    NaN  NaN  NaN
#
#                         allele      zygosity          consequence  \
# 0                   ['CCT', C]  Heterozygous       intron_variant
# 1                          NaN           NaN                  NaN
# 2                          NaN           NaN                  NaN
# 3                          NaN           NaN                  NaN
# 4                          NaN           NaN                  NaN
# ...                        ...           ...                  ...
# 4913                 ['GC', G]    Homozygous       intron_variant
# 4914                 ['A', AT]  Heterozygous       intron_variant
# 4915  ['GAAATCTCAGGACTAGA', G]  Heterozygous       intron_variant
# 4916            ['AAGTCTC', A]    Homozygous       intron_variant
# 4917                 ['AT', A]  Heterozygous  3_prime_UTR_variant
#
#      Consequence_score clinical_significance  \
# 0                 2/10                Benign
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
# ...                ...                   ...
# 4913              2/10                Benign
# 4914              2/10                Benign
# 4915              2/10                Benign
# 4916              2/10                Benign
# 4917              3/10         Likely_benign
#
#                                     associated_diseases  \
# 0     Congenital_myasthenic_syndrome_8|not_specified...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4913                      Sandhoff_disease|not_provided
# 4914  3-methylglutaconic_aciduria_with_deafness', '_...
# 4915                                       not_provided
# 4916                                       not_provided
# 4917            Nonsyndromic_Hearing_Loss', '_Recessive
#
#                                           review_status    origin  \
# 0     criteria_provided', '_multiple_submitters', '_...  germline
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# ...                                                 ...       ...
# 4913  criteria_provided', '_multiple_submitters', '_...  germline
# 4914  criteria_provided', '_multiple_submitters', '_...  germline
# 4915             criteria_provided', '_single_submitter  germline
# 4916             criteria_provided', '_single_submitter  germline
# 4917             criteria_provided', '_single_submitter  germline
#
#      variant_type variant_subtype Phargkb_ann_exists is_mutation  \
# 0           indel        Deletion           MayBe No          No
# 1             NaN             NaN                NaN         NaN
# 2             NaN             NaN                NaN         NaN
# 3             NaN             NaN                NaN         NaN
# 4             NaN             NaN                NaN         NaN
# ...           ...             ...                ...         ...
# 4913        indel        Deletion           MayBe No          No
# 4914        indel       Insertion           MayBe No          No
# 4915        indel        Deletion           MayBe No          No
# 4916        indel        Deletion           MayBe No          No
# 4917        indel        Deletion           MayBe No          No
#
#      Variant_is_precious
# 0                    Yes
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 4913                  No
# 4914                  No
# 4915                  No
# 4916                  No
# 4917                  No
#
# [4918 rows x 84 columns]

# %%
merged_1 = merged_1.fillna('NA')
merged_1
# Out:
#      CHROM        POS              Gene Name Gene_Match  \
# 0     chr1  1043223.0                   AGRN         No
# 1     chr1  1299382.0                  ACAP3         No
# 2     chr1  1312198.0  INTS11,MIR6727,CPSF3L         No
# 3     chr1  1312198.0  INTS11,MIR6727,CPSF3L         No
# 4     chr1  1353987.0                  MXRA8         No
# ...    ...        ...                    ...        ...
# 4913    NA         NA                   HEXB         No
# 4914    NA         NA                 SERAC1         No
# 4915    NA         NA                  ADAM9         No
# 4916    NA         NA                   PSAP         No
# 4917    NA         NA                 LHFPL5         No
#
#                         rsID  REF     ALT   GT  GQ SDP  DP  RD  AD    FREQ  \
# 0                 rs35881187  CCT       C  0/1  93  30  30   8  22  73.33%
# 1                rs143128930   AG       A  0/1  66  23  23   7  16  69.57%
# 2     rs70949570;rs752605219    T  TGGGGG  0/1  29  19  19   2   7  36.84%
# 3     rs70949570;rs752605219    T  TGGGGG  0/1  29  19  19   2   7  36.84%
# 4                rs140777846  CTG       C  0/1  93  59  59  33  26  44.07%
# ...                      ...  ...     ...  ...  ..  ..  ..  ..  ..     ...
# 4913                      NA   NA      NA   NA  NA  NA  NA  NA  NA      NA
# 4914                      NA   NA      NA   NA  NA  NA  NA  NA  NA      NA
# 4915                      NA   NA      NA   NA  NA  NA  NA  NA  NA      NA
# 4916                      NA   NA      NA   NA  NA  NA  NA  NA  NA      NA
# 4917                      NA   NA      NA   NA  NA  NA  NA  NA  NA      NA
#
#             PVAL RDF RDR ADF ADR     ADP    WT    HET    HOM    NC CDA OTH  \
# 0     4.1351E-10   8   0  21   1  ADP=30  WT=0  HET=1  HOM=0  NC=0
# 1      2.4726E-7   5   2  11   5  ADP=23  WT=0  HET=1  HOM=0  NC=0
# 2      1.1312E-3   0   2   7   0  ADP=19  WT=0  HET=1  HOM=0  NC=0
# 3      1.1312E-3   0   2   7   0  ADP=19  WT=0  HET=1  HOM=0  NC=0
# 4     4.2407E-10  20  13  16  10  ADP=59  WT=0  HET=1  HOM=0  NC=0
# ...          ...  ..  ..  ..  ..     ...   ...    ...    ...   ...  ..  ..
# 4913          NA  NA  NA  NA  NA      NA    NA     NA     NA    NA  NA  NA
# 4914          NA  NA  NA  NA  NA      NA    NA     NA     NA    NA  NA  NA
# 4915          NA  NA  NA  NA  NA      NA    NA     NA     NA    NA  NA  NA
# 4916          NA  NA  NA  NA  NA      NA    NA     NA     NA    NA  NA  NA
# 4917          NA  NA  NA  NA  NA      NA    NA     NA     NA    NA  NA  NA
#
#      S3D WTD          dbSNPBuildID  SLO NSF  R3  R5 NSN NSM  G5A    COMMON  \
# 0                 dbSNPBuildID=126  SLO                           COMMON=1
# 1                 dbSNPBuildID=134               R5               COMMON=1
# 2             dbSNPBuildID=144,130  SLO      R3
# 3             dbSNPBuildID=144,130  SLO      R3
# 4                 dbSNPBuildID=134  SLO                      G5A  COMMON=1
# ...   ..  ..                   ...  ...  ..  ..  ..  ..  ..  ...       ...
# 4913  NA  NA                    NA   NA  NA  NA  NA  NA  NA   NA        NA
# 4914  NA  NA                    NA   NA  NA  NA  NA  NA  NA   NA        NA
# 4915  NA  NA                    NA   NA  NA  NA  NA  NA  NA   NA        NA
# 4916  NA  NA                    NA   NA  NA  NA  NA  NA  NA   NA        NA
# 4917  NA  NA                    NA   NA  NA  NA  NA  NA  NA   NA        NA
#
#                          RS  RV TPA CFL  GNO  VLD  ASP ASS Ref  U3  U5  \
# 0               RS=35881187  RV          GNO  VLD  ASP
# 1              RS=143128930                   VLD  ASP
# 2     RS=752605219,70949570              GNO  VLD  ASP
# 3     RS=752605219,70949570              GNO  VLD  ASP
# 4              RS=140777846              GNO  VLD  ASP
# ...                     ...  ..  ..  ..  ...  ...  ...  ..  ..  ..  ..
# 4913                     NA  NA  NA  NA   NA   NA   NA  NA  NA  NA  NA
# 4914                     NA  NA  NA  NA   NA   NA   NA  NA  NA  NA  NA
# 4915                     NA  NA  NA  NA   NA   NA   NA  NA  NA  NA  NA
# 4916                     NA  NA  NA  NA   NA   NA   NA  NA  NA  NA  NA
# 4917                     NA  NA  NA  NA   NA   NA   NA  NA  NA  NA  NA
#
#                                                  TOPMED      WGT MTP LSD NOC  \
# 0        TOPMED=0.55968081039755351,0.44031918960244648    WGT=1
# 1        TOPMED=0.91126720183486238,0.08873279816513761    WGT=1
# 2     TOPMED=0.42793546126401630,0.00001592762487257...  WGT=1,1
# 3     TOPMED=0.42793546126401630,0.00001592762487257...  WGT=1,1
# 4        TOPMED=0.13763857033639143,0.86236142966360856    WGT=1
# ...                                                 ...      ...  ..  ..  ..
# 4913                                                 NA       NA  NA  NA  NA
# 4914                                                 NA       NA  NA  NA  NA
# 4915                                                 NA       NA  NA  NA  NA
# 4916                                                 NA       NA  NA  NA  NA
# 4917                                                 NA       NA  NA  NA  NA
#
#      DSS SYN  KGPhase3                CAF          VC MUT  KGPhase1  NOV  \
# 0             KGPhase3  CAF=0.5208,0.4792      VC=DIV      KGPhase1
# 1             KGPhase3  CAF=0.8806,0.1194      VC=DIV      KGPhase1
# 2                                          VC=DIV,DIV                NOV
# 3                                          VC=DIV,DIV                NOV
# 4             KGPhase3  CAF=0.1793,0.8207      VC=DIV
# ...   ..  ..       ...                ...         ...  ..       ...  ...
# 4913  NA  NA        NA                 NA          NA  NA        NA   NA
# 4914  NA  NA        NA                 NA          NA  NA        NA   NA
# 4915  NA  NA        NA                 NA          NA  NA        NA   NA
# 4916  NA  NA        NA                 NA          NA  NA        NA   NA
# 4917  NA  NA        NA                 NA          NA  NA        NA   NA
#
#                                                      VP      SAO  INT  G5  OM  \
# 0                         VP=0x05012808000515013e000200    SAO=0  INT  G5
# 1                         VP=0x0500000a000515003e000200    SAO=0  INT  G5
# 2     VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 3     VP=0x0500000c0005040002000204,0x0501000c000500...  SAO=0,0  INT
# 4                         VP=0x050100080005170126000200    SAO=0  INT  G5
# ...                                                 ...      ...  ...  ..  ..
# 4913                                                 NA       NA   NA  NA  NA
# 4914                                                 NA       NA   NA  NA  NA
# 4915                                                 NA       NA   NA  NA  NA
# 4916                                                 NA       NA   NA  NA  NA
# 4917                                                 NA       NA   NA  NA  NA
#
#       PMC      SSR                  RSPOS  HD  PM                    allele  \
# 0     PMC    SSR=0          RSPOS=1043224      PM                ['CCT', C]
# 1            SSR=0          RSPOS=1299383                                NA
# 2          SSR=0,0  RSPOS=1312198,1312208                                NA
# 3          SSR=0,0  RSPOS=1312198,1312208                                NA
# 4            SSR=0          RSPOS=1353988                                NA
# ...   ...      ...                    ...  ..  ..                       ...
# 4913   NA       NA                     NA  NA  NA                 ['GC', G]
# 4914   NA       NA                     NA  NA  NA                 ['A', AT]
# 4915   NA       NA                     NA  NA  NA  ['GAAATCTCAGGACTAGA', G]
# 4916   NA       NA                     NA  NA  NA            ['AAGTCTC', A]
# 4917   NA       NA                     NA  NA  NA                 ['AT', A]
#
#           zygosity          consequence Consequence_score  \
# 0     Heterozygous       intron_variant              2/10
# 1               NA                   NA                NA
# 2               NA                   NA                NA
# 3               NA                   NA                NA
# 4               NA                   NA                NA
# ...            ...                  ...               ...
# 4913    Homozygous       intron_variant              2/10
# 4914  Heterozygous       intron_variant              2/10
# 4915  Heterozygous       intron_variant              2/10
# 4916    Homozygous       intron_variant              2/10
# 4917  Heterozygous  3_prime_UTR_variant              3/10
#
#      clinical_significance                                associated_diseases  \
# 0                   Benign  Congenital_myasthenic_syndrome_8|not_specified...
# 1                       NA                                                 NA
# 2                       NA                                                 NA
# 3                       NA                                                 NA
# 4                       NA                                                 NA
# ...                    ...                                                ...
# 4913                Benign                      Sandhoff_disease|not_provided
# 4914                Benign  3-methylglutaconic_aciduria_with_deafness', '_...
# 4915                Benign                                       not_provided
# 4916                Benign                                       not_provided
# 4917         Likely_benign            Nonsyndromic_Hearing_Loss', '_Recessive
#
#                                           review_status    origin  \
# 0     criteria_provided', '_multiple_submitters', '_...  germline
# 1                                                    NA        NA
# 2                                                    NA        NA
# 3                                                    NA        NA
# 4                                                    NA        NA
# ...                                                 ...       ...
# 4913  criteria_provided', '_multiple_submitters', '_...  germline
# 4914  criteria_provided', '_multiple_submitters', '_...  germline
# 4915             criteria_provided', '_single_submitter  germline
# 4916             criteria_provided', '_single_submitter  germline
# 4917             criteria_provided', '_single_submitter  germline
#
#      variant_type variant_subtype Phargkb_ann_exists is_mutation  \
# 0           indel        Deletion           MayBe No          No
# 1              NA              NA                 NA          NA
# 2              NA              NA                 NA          NA
# 3              NA              NA                 NA          NA
# 4              NA              NA                 NA          NA
# ...           ...             ...                ...         ...
# 4913        indel        Deletion           MayBe No          No
# 4914        indel       Insertion           MayBe No          No
# 4915        indel        Deletion           MayBe No          No
# 4916        indel        Deletion           MayBe No          No
# 4917        indel        Deletion           MayBe No          No
#
#      Variant_is_precious
# 0                    Yes
# 1                     NA
# 2                     NA
# 3                     NA
# 4                     NA
# ...                  ...
# 4913                  No
# 4914                  No
# 4915                  No
# 4916                  No
# 4917                  No
#
# [4918 rows x 84 columns]

# %%
merged_1.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/InDel_files/KHHSPTGPCSP16_InDel_final.xlsx', index=False)

# %% [markdown]
# # Multiple Genes wise analysis

# %%
merged_2['Gene Match'] = 'No'
merged_2['Matched_Gene'] = ''
    
# Iterate through each gene in vcf['Gene']
for index, genes in merged_2['Gene Name'].iteritems():
    if isinstance(genes, str):
        gene_list = genes.split(',')
        for gene in gene_list:
            if gene in df_gene['Gene Name'].values:
                merged_2.at[index, 'Gene Match'] = 'Yes'
                merged_2.at[index, 'Matched_Gene'] = gene
                break
    
merged_2
