# %%
import numpy as np
import pandas as pd
import polars as pl
import sys
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px


pd.set_option('display.max_columns',None)
import psycopg2


#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Algorithms to use
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

#Metrics to evaluate the model
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve

import warnings
warnings.filterwarnings("ignore")

#importing PCA and TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
def read_bed_file(bed_file):
    bed_positions = set()
    with open(bed_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Skip header lines if present
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 3:
                chrom = fields[0]
                try:
                    start = int(fields[1])
                    end = int(fields[2])
                except ValueError:
                    continue  # Skip this line if start or end position is not an integer
                for pos in range(start, end + 1):
                    bed_positions.add((chrom, pos))
    return bed_positions

def normalize_chrom_name(chrom):
    return chrom.split('_')[0]

def filter_vcf_file(vcf_file, bed_positions):
    filtered_vcf_records = []
    with open(vcf_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Preserve header lines in the output
                filtered_vcf_records.append(line)
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 2:
                raw_chrom = fields[0]
                chrom = normalize_chrom_name(raw_chrom)
                try:
                    pos = int(fields[1])
                except ValueError:
                    continue  # Skip this line if 'POS' is not an integer
                if (chrom, pos) in bed_positions:
                    filtered_vcf_records.append(line)
    return filtered_vcf_records

def write_filtered_vcf(filtered_vcf_records, output_file):
    with open(output_file, 'w') as f:
        for record in filtered_vcf_records:
            f.write(record)

def main():
    bed_file = r'C:/Users/GenepoweRx_Madhu/Desktop/Covered_regions.bed'
    vcf_file = r'C:/Users/GenepoweRx_Madhu/Downloads/KHAIGHGPTTL207_annotated_indel.vcf'
    output_file = r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/KHAIGHGPTTL207_annotated_indel.vcf'

    bed_positions = read_bed_file(bed_file)
    filtered_vcf_records = filter_vcf_file(vcf_file, bed_positions)
    write_filtered_vcf(filtered_vcf_records, output_file)

if __name__ == "__main__":
    main()

# %%
vcf = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/KHAIGHGPTTL207_annotated_indel.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
vcf.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']

sample_cols = vcf['SAMPLE'].str.split(':', expand=True)
sample_cols.columns = ['GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RBQ', 'ABQ', 'RDF', 'RDR', 'ADF', 'ADR']

# Assign the values to the newly created columns
vcf = pd.concat([vcf, sample_cols], axis=1)
vcf = vcf[['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL','RDF', 'RDR', 'ADF', 'ADR']]
vcf
# Out:
#      CHROM        POS                               rsID  REF ALT QUAL FILTER  \
# 0     chr1    1299382                        rs143128930   AG   A    .   PASS
# 1     chr1    1331945                        rs200330269    G  GC    .   PASS
# 2     chr1    1353987                        rs140777846  CTG   C    .   PASS
# 3     chr1    1355779                        rs201260508   GA   G    .   PASS
# 4     chr1    1657358                        rs377230281    T  TA    .   PASS
# ...    ...        ...                                ...  ...  ..  ...    ...
# 2759  chrX  153462077            rs138590468;rs369801831   TA   T    .   PASS
# 2760  chrX  153692201                        rs199498083    C  CA    .   PASS
# 2761  chrX  153909413  rs11405331;rs34046683;rs869136125    T  TG    .   PASS
# 2762  chrX  153913005               rs5904376;rs77485258    G  GC    .   PASS
# 2763  chrX  155228363                        rs781912204    A  AT    .   PASS
#
#                                                    INFO   GT   GQ  SDP   DP  \
# 0     ADP=50;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8806,0....  0/1   97   50   50
# 1     ADP=41;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8105,0....  0/1   48   41   41
# 2     ADP=70;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.1793,0....  0/1  219   70   70
# 3     ADP=29;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0,1;COMMO...  0/1   88   29   29
# 4     ADP=112;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=CDK...  0/1   78  112  112
# ...                                                 ...  ...  ...  ...  ...
# 2759  ADP=40;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.5624,0....  0/1   56   40   40
# 2760  ADP=79;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8972,0....  0/1  113   79   79
# 2761  ADP=30;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,.,1,0,1...  1/1  170   30   30
# 2762  ADP=108;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.000264...  1/1  255  108  108
# 2763  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=VBP1...  0/1   56   32   32
#
#       RD   AD    FREQ        PVAL RDF RDR ADF ADR
# 0     24   26     52%  1.7375E-10  18   6  17   9
# 1     26   14  34.15%   1.5388E-5  12  14   2  12
# 2     19   51  72.86%  1.2075E-22  12   7  34  17
# 3      8   21  72.41%   1.2841E-9   7   1   8  13
# 4     88   24  21.43%   1.4999E-8  65  23   4  20
# ...   ..  ...     ...         ...  ..  ..  ..  ..
# 2759  24   16     40%   2.3315E-6  20   4  13   3
# 2760  47   32  40.51%  4.4277E-12  30  17  23   9
# 2761   0   30    100%  8.4556E-18   0   0  16  14
# 2762   7  101  93.52%  7.6722E-54   4   3  76  25
# 2763  13   15  46.88%   2.3037E-6  12   1  12   3
#
# [2764 rows x 20 columns]

# %%
vcf['HET'] = vcf['INFO'].str.extract(r'HET=(\d)')
vcf['HOM'] = vcf['INFO'].str.extract(r'HOM=(\d)')

# Create a new column 'Zygosity' based on conditions
vcf['Zygosity'] = ''

vcf.loc[vcf['HOM'] == '1', 'Zygosity'] = 'Homozygous'
vcf.loc[vcf['HET'] == '1', 'Zygosity'] = 'Heterozygous'
vcf['GT'] = vcf['GT'].astype(str)
vcf
# Out:
#      CHROM        POS                               rsID  REF ALT QUAL FILTER  \
# 0     chr1    1299382                        rs143128930   AG   A    .   PASS
# 1     chr1    1331945                        rs200330269    G  GC    .   PASS
# 2     chr1    1353987                        rs140777846  CTG   C    .   PASS
# 3     chr1    1355779                        rs201260508   GA   G    .   PASS
# 4     chr1    1657358                        rs377230281    T  TA    .   PASS
# ...    ...        ...                                ...  ...  ..  ...    ...
# 2759  chrX  153462077            rs138590468;rs369801831   TA   T    .   PASS
# 2760  chrX  153692201                        rs199498083    C  CA    .   PASS
# 2761  chrX  153909413  rs11405331;rs34046683;rs869136125    T  TG    .   PASS
# 2762  chrX  153913005               rs5904376;rs77485258    G  GC    .   PASS
# 2763  chrX  155228363                        rs781912204    A  AT    .   PASS
#
#                                                    INFO   GT   GQ  SDP   DP  \
# 0     ADP=50;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8806,0....  0/1   97   50   50
# 1     ADP=41;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8105,0....  0/1   48   41   41
# 2     ADP=70;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.1793,0....  0/1  219   70   70
# 3     ADP=29;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0,1;COMMO...  0/1   88   29   29
# 4     ADP=112;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=CDK...  0/1   78  112  112
# ...                                                 ...  ...  ...  ...  ...
# 2759  ADP=40;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.5624,0....  0/1   56   40   40
# 2760  ADP=79;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8972,0....  0/1  113   79   79
# 2761  ADP=30;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,.,1,0,1...  1/1  170   30   30
# 2762  ADP=108;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.000264...  1/1  255  108  108
# 2763  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=VBP1...  0/1   56   32   32
#
#       RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity
# 0     24   26     52%  1.7375E-10  18   6  17   9   1   0  Heterozygous
# 1     26   14  34.15%   1.5388E-5  12  14   2  12   1   0  Heterozygous
# 2     19   51  72.86%  1.2075E-22  12   7  34  17   1   0  Heterozygous
# 3      8   21  72.41%   1.2841E-9   7   1   8  13   1   0  Heterozygous
# 4     88   24  21.43%   1.4999E-8  65  23   4  20   1   0  Heterozygous
# ...   ..  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 2759  24   16     40%   2.3315E-6  20   4  13   3   1   0  Heterozygous
# 2760  47   32  40.51%  4.4277E-12  30  17  23   9   1   0  Heterozygous
# 2761   0   30    100%  8.4556E-18   0   0  16  14   0   1    Homozygous
# 2762   7  101  93.52%  7.6722E-54   4   3  76  25   0   1    Homozygous
# 2763  13   15  46.88%   2.3037E-6  12   1  12   3   1   0  Heterozygous
#
# [2764 rows x 23 columns]

# %%
vcf["Gene_Name"] = vcf["INFO"].str.extract('GENEINFO=(?P<GENEINFO>.+?);')
vcf['Gene Name'] = vcf['Gene_Name'].apply(lambda x: ','.join([segment.split(':')[0] for segment in x.split('|')]) if pd.notnull(x) else '')
vcf
# Out:
#      CHROM        POS                               rsID  REF ALT QUAL FILTER  \
# 0     chr1    1299382                        rs143128930   AG   A    .   PASS
# 1     chr1    1331945                        rs200330269    G  GC    .   PASS
# 2     chr1    1353987                        rs140777846  CTG   C    .   PASS
# 3     chr1    1355779                        rs201260508   GA   G    .   PASS
# 4     chr1    1657358                        rs377230281    T  TA    .   PASS
# ...    ...        ...                                ...  ...  ..  ...    ...
# 2759  chrX  153462077            rs138590468;rs369801831   TA   T    .   PASS
# 2760  chrX  153692201                        rs199498083    C  CA    .   PASS
# 2761  chrX  153909413  rs11405331;rs34046683;rs869136125    T  TG    .   PASS
# 2762  chrX  153913005               rs5904376;rs77485258    G  GC    .   PASS
# 2763  chrX  155228363                        rs781912204    A  AT    .   PASS
#
#                                                    INFO   GT   GQ  SDP   DP  \
# 0     ADP=50;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8806,0....  0/1   97   50   50
# 1     ADP=41;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8105,0....  0/1   48   41   41
# 2     ADP=70;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.1793,0....  0/1  219   70   70
# 3     ADP=29;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0,1;COMMO...  0/1   88   29   29
# 4     ADP=112;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=CDK...  0/1   78  112  112
# ...                                                 ...  ...  ...  ...  ...
# 2759  ADP=40;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.5624,0....  0/1   56   40   40
# 2760  ADP=79;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8972,0....  0/1  113   79   79
# 2761  ADP=30;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,.,1,0,1...  1/1  170   30   30
# 2762  ADP=108;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.000264...  1/1  255  108  108
# 2763  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=VBP1...  0/1   56   32   32
#
#       RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity  \
# 0     24   26     52%  1.7375E-10  18   6  17   9   1   0  Heterozygous
# 1     26   14  34.15%   1.5388E-5  12  14   2  12   1   0  Heterozygous
# 2     19   51  72.86%  1.2075E-22  12   7  34  17   1   0  Heterozygous
# 3      8   21  72.41%   1.2841E-9   7   1   8  13   1   0  Heterozygous
# 4     88   24  21.43%   1.4999E-8  65  23   4  20   1   0  Heterozygous
# ...   ..  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 2759  24   16     40%   2.3315E-6  20   4  13   3   1   0  Heterozygous
# 2760  47   32  40.51%  4.4277E-12  30  17  23   9   1   0  Heterozygous
# 2761   0   30    100%  8.4556E-18   0   0  16  14   0   1    Homozygous
# 2762   7  101  93.52%  7.6722E-54   4   3  76  25   0   1    Homozygous
# 2763  13   15  46.88%   2.3037E-6  12   1  12   3   1   0  Heterozygous
#
#                                 Gene_Name Gene Name
# 0                            ACAP3:116983     ACAP3
# 1                            TAS1R3:83756    TAS1R3
# 2                             MXRA8:54587     MXRA8
# 3                             MXRA8:54587     MXRA8
# 4                              CDK11B:984    CDK11B
# ...                                   ...       ...
# 2759              HAUS7:55559,HAUS7:55559     HAUS7
# 2760                          SLC6A8:6535    SLC6A8
# 2761  ARHGAP4:393,ARHGAP4:393,ARHGAP4:393   ARHGAP4
# 2762              ARHGAP4:393,ARHGAP4:393   ARHGAP4
# 2763                            VBP1:7411      VBP1
#
# [2764 rows x 25 columns]

# %%
vcf['CSQ'] = vcf['INFO'].str.extract(r'CSQ=(.*)')
vcf['csq'] = vcf['CSQ'].str.split(',')
vcf = vcf.explode('csq')
vcf
# Out:
#      CHROM        POS                               rsID  REF ALT QUAL FILTER  \
# 0     chr1    1299382                        rs143128930   AG   A    .   PASS
# 1     chr1    1331945                        rs200330269    G  GC    .   PASS
# 2     chr1    1353987                        rs140777846  CTG   C    .   PASS
# 3     chr1    1355779                        rs201260508   GA   G    .   PASS
# 4     chr1    1657358                        rs377230281    T  TA    .   PASS
# ...    ...        ...                                ...  ...  ..  ...    ...
# 2759  chrX  153462077            rs138590468;rs369801831   TA   T    .   PASS
# 2760  chrX  153692201                        rs199498083    C  CA    .   PASS
# 2761  chrX  153909413  rs11405331;rs34046683;rs869136125    T  TG    .   PASS
# 2762  chrX  153913005               rs5904376;rs77485258    G  GC    .   PASS
# 2763  chrX  155228363                        rs781912204    A  AT    .   PASS
#
#                                                    INFO   GT   GQ  SDP   DP  \
# 0     ADP=50;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8806,0....  0/1   97   50   50
# 1     ADP=41;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8105,0....  0/1   48   41   41
# 2     ADP=70;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.1793,0....  0/1  219   70   70
# 3     ADP=29;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0,1;COMMO...  0/1   88   29   29
# 4     ADP=112;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=CDK...  0/1   78  112  112
# ...                                                 ...  ...  ...  ...  ...
# 2759  ADP=40;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.5624,0....  0/1   56   40   40
# 2760  ADP=79;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8972,0....  0/1  113   79   79
# 2761  ADP=30;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,.,1,0,1...  1/1  170   30   30
# 2762  ADP=108;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.000264...  1/1  255  108  108
# 2763  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=VBP1...  0/1   56   32   32
#
#       RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity  \
# 0     24   26     52%  1.7375E-10  18   6  17   9   1   0  Heterozygous
# 1     26   14  34.15%   1.5388E-5  12  14   2  12   1   0  Heterozygous
# 2     19   51  72.86%  1.2075E-22  12   7  34  17   1   0  Heterozygous
# 3      8   21  72.41%   1.2841E-9   7   1   8  13   1   0  Heterozygous
# 4     88   24  21.43%   1.4999E-8  65  23   4  20   1   0  Heterozygous
# ...   ..  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 2759  24   16     40%   2.3315E-6  20   4  13   3   1   0  Heterozygous
# 2760  47   32  40.51%  4.4277E-12  30  17  23   9   1   0  Heterozygous
# 2761   0   30    100%  8.4556E-18   0   0  16  14   0   1    Homozygous
# 2762   7  101  93.52%  7.6722E-54   4   3  76  25   0   1    Homozygous
# 2763  13   15  46.88%   2.3037E-6  12   1  12   3   1   0  Heterozygous
#
#                                 Gene_Name Gene Name  CSQ  csq
# 0                            ACAP3:116983     ACAP3  NaN  NaN
# 1                            TAS1R3:83756    TAS1R3  NaN  NaN
# 2                             MXRA8:54587     MXRA8  NaN  NaN
# 3                             MXRA8:54587     MXRA8  NaN  NaN
# 4                              CDK11B:984    CDK11B  NaN  NaN
# ...                                   ...       ...  ...  ...
# 2759              HAUS7:55559,HAUS7:55559     HAUS7  NaN  NaN
# 2760                          SLC6A8:6535    SLC6A8  NaN  NaN
# 2761  ARHGAP4:393,ARHGAP4:393,ARHGAP4:393   ARHGAP4  NaN  NaN
# 2762              ARHGAP4:393,ARHGAP4:393   ARHGAP4  NaN  NaN
# 2763                            VBP1:7411      VBP1  NaN  NaN
#
# [2764 rows x 27 columns]

# %%
vcf['ClinVar_CLNDN'] = vcf['csq'].str.split('|').str[82]
vcf['CLIN_SIG'] = vcf['csq'].str.split('|').str[70]
vcf['ClinVar_CLNREVSTAT'] = vcf['csq'].str.split('|').str[81]
vcf['ClinVar'] = vcf['csq'].str.split('|').str[79]
vcf['HGVSC'] = vcf['csq'].str.split('|').str[10]
vcf['HGVSP'] = vcf['csq'].str.split('|').str[11]
vcf['PolyPhen'] = vcf['csq'].str.split('|').str[38]
vcf['BIOTYPE'] = vcf['csq'].str.split('|').str[7]
vcf['EXON'] = vcf['csq'].str.split('|').str[8]
vcf['INTRON'] = vcf['csq'].str.split('|').str[9]
vcf['Protein_position'] = vcf['csq'].str.split('|').str[14]
vcf['Amino_acids'] = vcf['csq'].str.split('|').str[15]
vcf['Codons'] = vcf['csq'].str.split('|').str[16]
vcf['STRAND'] = vcf['csq'].str.split('|').str[19]
vcf['PUBMED'] = vcf['csq'].str.split('|').str[73]
vcf['Consequence'] = vcf['csq'].str.split('|').str[1]
vcf['IMPACT'] = vcf['csq'].str.split('|').str[2]
vcf['SIFT'] = vcf['csq'].str.split('|').str[37]

vcf['AF'] = vcf['csq'].str.split('|').str[42]
vcf['AFR_AF'] = vcf['csq'].str.split('|').str[43]
vcf['AMR_AF'] = vcf['csq'].str.split('|').str[44]
vcf['EAS_AF'] = vcf['csq'].str.split('|').str[45]
vcf['EUR_AF'] = vcf['csq'].str.split('|').str[46]
vcf['SAS_AF'] = vcf['csq'].str.split('|').str[47]
vcf['gnomADe_AF'] = vcf['csq'].str.split('|').str[48]
vcf['gnomADe_AFR_AF'] = vcf['csq'].str.split('|').str[49]
vcf['gnomADe_AMR_AF'] = vcf['csq'].str.split('|').str[50]
vcf['gnomADe_ASJ_AF'] = vcf['csq'].str.split('|').str[51]
vcf['gnomADe_EAS_AF'] = vcf['csq'].str.split('|').str[52]
vcf['gnomADe_FIN_AF'] = vcf['csq'].str.split('|').str[53]
vcf['gnomADe_NFE_AF'] = vcf['csq'].str.split('|').str[54]
vcf['gnomADe_OTH_AF'] = vcf['csq'].str.split('|').str[55]
vcf['gnomADe_SAS_AF'] = vcf['csq'].str.split('|').str[56]
vcf['gnomADg_AF'] = vcf['csq'].str.split('|').str[57]
vcf['gnomADg_AFR_AF'] = vcf['csq'].str.split('|').str[58]
vcf['gnomADg_AMI_AF'] = vcf['csq'].str.split('|').str[59]
vcf['gnomADg_AMR_AF'] = vcf['csq'].str.split('|').str[60]
vcf['gnomADg_ASJ_AF'] = vcf['csq'].str.split('|').str[61]
vcf['gnomADg_EAS_AF'] = vcf['csq'].str.split('|').str[62]
vcf['gnomADg_FIN_AF'] = vcf['csq'].str.split('|').str[63]
vcf['gnomADg_MID_AF'] = vcf['csq'].str.split('|').str[64]
vcf['gnomADg_NFE_AF'] = vcf['csq'].str.split('|').str[65]
vcf['gnomADg_OTH_AF'] = vcf['csq'].str.split('|').str[66]
vcf['gnomADg_SAS_AF'] = vcf['csq'].str.split('|').str[67]
vcf['MAX_AF'] = vcf['csq'].str.split('|').str[68]
vcf['MAX_AF_POPS'] = vcf['csq'].str.split('|').str[69]
vcf
# Out:
#      CHROM        POS                               rsID  REF ALT QUAL FILTER  \
# 0     chr1    1299382                        rs143128930   AG   A    .   PASS
# 1     chr1    1331945                        rs200330269    G  GC    .   PASS
# 2     chr1    1353987                        rs140777846  CTG   C    .   PASS
# 3     chr1    1355779                        rs201260508   GA   G    .   PASS
# 4     chr1    1657358                        rs377230281    T  TA    .   PASS
# ...    ...        ...                                ...  ...  ..  ...    ...
# 2759  chrX  153462077            rs138590468;rs369801831   TA   T    .   PASS
# 2760  chrX  153692201                        rs199498083    C  CA    .   PASS
# 2761  chrX  153909413  rs11405331;rs34046683;rs869136125    T  TG    .   PASS
# 2762  chrX  153913005               rs5904376;rs77485258    G  GC    .   PASS
# 2763  chrX  155228363                        rs781912204    A  AT    .   PASS
#
#                                                    INFO   GT   GQ  SDP   DP  \
# 0     ADP=50;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8806,0....  0/1   97   50   50
# 1     ADP=41;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8105,0....  0/1   48   41   41
# 2     ADP=70;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.1793,0....  0/1  219   70   70
# 3     ADP=29;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0,1;COMMO...  0/1   88   29   29
# 4     ADP=112;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=CDK...  0/1   78  112  112
# ...                                                 ...  ...  ...  ...  ...
# 2759  ADP=40;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.5624,0....  0/1   56   40   40
# 2760  ADP=79;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8972,0....  0/1  113   79   79
# 2761  ADP=30;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0,.,1,0,1...  1/1  170   30   30
# 2762  ADP=108;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.000264...  1/1  255  108  108
# 2763  ADP=32;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=VBP1...  0/1   56   32   32
#
#       RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity  \
# 0     24   26     52%  1.7375E-10  18   6  17   9   1   0  Heterozygous
# 1     26   14  34.15%   1.5388E-5  12  14   2  12   1   0  Heterozygous
# 2     19   51  72.86%  1.2075E-22  12   7  34  17   1   0  Heterozygous
# 3      8   21  72.41%   1.2841E-9   7   1   8  13   1   0  Heterozygous
# 4     88   24  21.43%   1.4999E-8  65  23   4  20   1   0  Heterozygous
# ...   ..  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 2759  24   16     40%   2.3315E-6  20   4  13   3   1   0  Heterozygous
# 2760  47   32  40.51%  4.4277E-12  30  17  23   9   1   0  Heterozygous
# 2761   0   30    100%  8.4556E-18   0   0  16  14   0   1    Homozygous
# 2762   7  101  93.52%  7.6722E-54   4   3  76  25   0   1    Homozygous
# 2763  13   15  46.88%   2.3037E-6  12   1  12   3   1   0  Heterozygous
#
#                                 Gene_Name Gene Name  CSQ  csq ClinVar_CLNDN  \
# 0                            ACAP3:116983     ACAP3  NaN  NaN           NaN
# 1                            TAS1R3:83756    TAS1R3  NaN  NaN           NaN
# 2                             MXRA8:54587     MXRA8  NaN  NaN           NaN
# 3                             MXRA8:54587     MXRA8  NaN  NaN           NaN
# 4                              CDK11B:984    CDK11B  NaN  NaN           NaN
# ...                                   ...       ...  ...  ...           ...
# 2759              HAUS7:55559,HAUS7:55559     HAUS7  NaN  NaN           NaN
# 2760                          SLC6A8:6535    SLC6A8  NaN  NaN           NaN
# 2761  ARHGAP4:393,ARHGAP4:393,ARHGAP4:393   ARHGAP4  NaN  NaN           NaN
# 2762              ARHGAP4:393,ARHGAP4:393   ARHGAP4  NaN  NaN           NaN
# 2763                            VBP1:7411      VBP1  NaN  NaN           NaN
#
#      CLIN_SIG ClinVar_CLNREVSTAT ClinVar HGVSC HGVSP PolyPhen BIOTYPE EXON  \
# 0         NaN                NaN     NaN   NaN   NaN      NaN     NaN  NaN
# 1         NaN                NaN     NaN   NaN   NaN      NaN     NaN  NaN
# 2         NaN                NaN     NaN   NaN   NaN      NaN     NaN  NaN
# 3         NaN                NaN     NaN   NaN   NaN      NaN     NaN  NaN
# 4         NaN                NaN     NaN   NaN   NaN      NaN     NaN  NaN
# ...       ...                ...     ...   ...   ...      ...     ...  ...
# 2759      NaN                NaN     NaN   NaN   NaN      NaN     NaN  NaN
# 2760      NaN                NaN     NaN   NaN   NaN      NaN     NaN  NaN
# 2761      NaN                NaN     NaN   NaN   NaN      NaN     NaN  NaN
# 2762      NaN                NaN     NaN   NaN   NaN      NaN     NaN  NaN
# 2763      NaN                NaN     NaN   NaN   NaN      NaN     NaN  NaN
#
#      INTRON Protein_position Amino_acids Codons STRAND PUBMED Consequence  \
# 0       NaN              NaN         NaN    NaN    NaN    NaN         NaN
# 1       NaN              NaN         NaN    NaN    NaN    NaN         NaN
# 2       NaN              NaN         NaN    NaN    NaN    NaN         NaN
# 3       NaN              NaN         NaN    NaN    NaN    NaN         NaN
# 4       NaN              NaN         NaN    NaN    NaN    NaN         NaN
# ...     ...              ...         ...    ...    ...    ...         ...
# 2759    NaN              NaN         NaN    NaN    NaN    NaN         NaN
# 2760    NaN              NaN         NaN    NaN    NaN    NaN         NaN
# 2761    NaN              NaN         NaN    NaN    NaN    NaN         NaN
# 2762    NaN              NaN         NaN    NaN    NaN    NaN         NaN
# 2763    NaN              NaN         NaN    NaN    NaN    NaN         NaN
#
#      IMPACT SIFT   AF AFR_AF AMR_AF EAS_AF EUR_AF SAS_AF gnomADe_AF  \
# 0       NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN        NaN
# 1       NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN        NaN
# 2       NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN        NaN
# 3       NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN        NaN
# 4       NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN        NaN
# ...     ...  ...  ...    ...    ...    ...    ...    ...        ...
# 2759    NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN        NaN
# 2760    NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN        NaN
# 2761    NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN        NaN
# 2762    NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN        NaN
# 2763    NaN  NaN  NaN    NaN    NaN    NaN    NaN    NaN        NaN
#
#      gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               NaN            NaN            NaN            NaN
# 4               NaN            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 2759            NaN            NaN            NaN            NaN
# 2760            NaN            NaN            NaN            NaN
# 2761            NaN            NaN            NaN            NaN
# 2762            NaN            NaN            NaN            NaN
# 2763            NaN            NaN            NaN            NaN
#
#      gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF  \
# 0               NaN            NaN            NaN            NaN        NaN
# 1               NaN            NaN            NaN            NaN        NaN
# 2               NaN            NaN            NaN            NaN        NaN
# 3               NaN            NaN            NaN            NaN        NaN
# 4               NaN            NaN            NaN            NaN        NaN
# ...             ...            ...            ...            ...        ...
# 2759            NaN            NaN            NaN            NaN        NaN
# 2760            NaN            NaN            NaN            NaN        NaN
# 2761            NaN            NaN            NaN            NaN        NaN
# 2762            NaN            NaN            NaN            NaN        NaN
# 2763            NaN            NaN            NaN            NaN        NaN
#
#      gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               NaN            NaN            NaN            NaN
# 4               NaN            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 2759            NaN            NaN            NaN            NaN
# 2760            NaN            NaN            NaN            NaN
# 2761            NaN            NaN            NaN            NaN
# 2762            NaN            NaN            NaN            NaN
# 2763            NaN            NaN            NaN            NaN
#
#      gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               NaN            NaN            NaN            NaN
# 4               NaN            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 2759            NaN            NaN            NaN            NaN
# 2760            NaN            NaN            NaN            NaN
# 2761            NaN            NaN            NaN            NaN
# 2762            NaN            NaN            NaN            NaN
# 2763            NaN            NaN            NaN            NaN
#
#      gnomADg_OTH_AF gnomADg_SAS_AF MAX_AF MAX_AF_POPS
# 0               NaN            NaN    NaN         NaN
# 1               NaN            NaN    NaN         NaN
# 2               NaN            NaN    NaN         NaN
# 3               NaN            NaN    NaN         NaN
# 4               NaN            NaN    NaN         NaN
# ...             ...            ...    ...         ...
# 2759            NaN            NaN    NaN         NaN
# 2760            NaN            NaN    NaN         NaN
# 2761            NaN            NaN    NaN         NaN
# 2762            NaN            NaN    NaN         NaN
# 2763            NaN            NaN    NaN         NaN
#
# [2764 rows x 73 columns]

# %%
x = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Cerebellarataxia_Lit_final_Positions_hg38_hg37.xlsx')
x['chrom'] = x['Chrom-pos-Ref-Alt_38'].str.split(',')
x = x.explode('chrom')

x['CHROM'] = x['chrom'].str.split('-').str[0]

# Function to add 'chr' prefix conditionally
def add_chr_prefix(chrom):
    if pd.notnull(chrom) and chrom.strip() != '':
        return 'chr' + str(chrom)
    else:
        return chrom

# Applying the function to the 'chromosome' column
x['CHROM'] = x['CHROM'].apply(add_chr_prefix)
x['CHROM'] = x['CHROM'].str.strip()
x['CHROM'] = x['CHROM'].str.replace(r'\s+', '')
x['POS'] = x['chrom'].str.split('-').str[1]

x.dropna(subset=['CHROM'], inplace=True)
# Drop rows with empty cells after removing leading and trailing whitespaces
x['CHROM'] = x['CHROM'].str.strip()
x['POS'] = x['POS'].str.strip()
# Dropping rows with empty cells and NaN values in both 'chromosome' and 'position' columns
x.dropna(subset=['CHROM', 'POS'], inplace=True)
df_3 = x[['CHROM', 'POS']]
df_3['Literature'] = 'Yes'
df_3.drop_duplicates(subset='POS', inplace=True)
df_3['POS'] = df_3['POS'].astype('int64')
df_3 = df_3.reset_index()
df_3 = df_3[['CHROM', 'POS', 'Literature']]
df_3
# Out:
#      CHROM        POS Literature
# 0     chrX   38352177        Yes
# 1     chrX   38352183        Yes
# 2     chrX   38352181        Yes
# 3     chrX   38352256        Yes
# 4     chrX   38352332        Yes
# ...    ...        ...        ...
# 1882  chr7  107915692        Yes
# 1883  chr7  107916864        Yes
# 1884  chr7  107915532        Yes
# 1885  chr7  107917349        Yes
# 1886  chr7  107917418        Yes
#
# [1887 rows x 3 columns]

# %%
df_3.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Cerebellarataxia.xlsx', index=False)

# %%
df_3 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/parkin_Cerebellarataxia_lit_pos.xlsx')
df_3
# Out:
#      CHROM        POS        Literature
# 0     chr1    7962863         Parkinson
# 1     chr1    7984930         Parkinson
# 2     chr1    7984981         Parkinson
# 3     chr1    7984954         Parkinson
# 4     chr1    7970951         Parkinson
# ...    ...        ...               ...
# 3146  chr7  107915692  Cerebellarataxia
# 3147  chr7  107916864  Cerebellarataxia
# 3148  chr7  107915532  Cerebellarataxia
# 3149  chr7  107917349  Cerebellarataxia
# 3150  chr7  107917418  Cerebellarataxia
#
# [3151 rows x 3 columns]

# %%
df_gene = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Park_cere_genes.xlsx')
df_gene
# Out:
#    Gene Name        Gene_Match
# 0       MYO6         Parkinson
# 1       GBA1         Parkinson
# 2       PRKN         Parkinson
# 3      MRE11         Parkinson
# 4      LRRK2         Parkinson
# ..       ...               ...
# 79      CLN1  Cerebellarataxia
# 80      CLN2  Cerebellarataxia
# 81      CLN3  Cerebellarataxia
# 82      PHYH  Cerebellarataxia
# 83      PEX7  Cerebellarataxia
#
# [84 rows x 2 columns]

# %%
vcf['Protein Position and Amino Acid'] = vcf['Amino_acids'].str[0] + vcf['Protein_position'] + np.where(vcf['Amino_acids'].str[-1] == vcf['Amino_acids'].str[0], '', vcf['Amino_acids'].str[-1])
vcf
# Out:
#       CHROM        POS         rsID REF ALT QUAL FILTER  \
# 0      chr1      69511    rs2691305   A   G    .   PASS
# 1      chr1      69897  rs200676709   T   C    .   PASS
# 2      chr1     685694            .   T   C    .   PASS
# 2      chr1     685694            .   T   C    .   PASS
# 2      chr1     685694            .   T   C    .   PASS
# ...     ...        ...          ...  ..  ..  ...    ...
# 38700  chrX  156003433    rs2037999   T   C    .   PASS
# 38701  chrX  156009937  rs147385831   G   A    .   PASS
# 38701  chrX  156009937  rs147385831   G   A    .   PASS
# 38701  chrX  156009937  rs147385831   G   A    .   PASS
# 38701  chrX  156009937  rs147385831   G   A    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=120;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  120  120
# 1      ADP=98;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1   82   98   98
# 2      ADP=28;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   34   28   28
# 2      ADP=28;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   34   28   28
# 2      ADP=28;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   34   28   28
# ...                                                  ...  ...  ...  ...  ...
# 38700  ADP=11;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.4079,0....  1/1   58   11   11
# 38701  ADP=20;WT=0;HET=1;HOM=0;NC=0;ASP;CFL;GENEINFO=...  0/1   27   20   20
# 38701  ADP=20;WT=0;HET=1;HOM=0;NC=0;ASP;CFL;GENEINFO=...  0/1   27   20   20
# 38701  ADP=20;WT=0;HET=1;HOM=0;NC=0;ASP;CFL;GENEINFO=...  0/1   27   20   20
# 38701  ADP=20;WT=0;HET=1;HOM=0;NC=0;ASP;CFL;GENEINFO=...  0/1   27   20   20
#
#        RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity  \
# 0       0  120    100%  1.1001E-71   0   0  86  34   0   1    Homozygous
# 1      73   25  25.51%   5.1517E-9  41  32  11  14   1   0  Heterozygous
# 2      18   10  35.71%   3.6855E-4  17   1   9   1   1   0  Heterozygous
# 2      18   10  35.71%   3.6855E-4  17   1   9   1   1   0  Heterozygous
# 2      18   10  35.71%   3.6855E-4  17   1   9   1   1   0  Heterozygous
# ...    ..  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 38700   0   11    100%   1.4176E-6   0   0   7   4   0   1    Homozygous
# 38701  12    8     40%    1.638E-3  12   0   8   0   1   0  Heterozygous
# 38701  12    8     40%    1.638E-3  12   0   8   0   1   0  Heterozygous
# 38701  12    8     40%    1.638E-3  12   0   8   0   1   0  Heterozygous
# 38701  12    8     40%    1.638E-3  12   0   8   0   1   0  Heterozygous
#
#          Gene_Name Gene Name  \
# 0      OR4F5:79501     OR4F5
# 1      OR4F5:79501     OR4F5
# 2              NaN
# 2              NaN
# 2              NaN
# ...            ...       ...
# 38700    IL9R:3581      IL9R
# 38701    IL9R:3581      IL9R
# 38701    IL9R:3581      IL9R
# 38701    IL9R:3581      IL9R
# 38701    IL9R:3581      IL9R
#
#                                                      CSQ  \
# 0      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 1      C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 2      C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 2      C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 2      C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# ...                                                  ...
# 38700  C|splice_polypyrimidine_tract_variant&intron_v...
# 38701  A|missense_variant|MODERATE|IL9R|ENSG000001243...
# 38701  A|missense_variant|MODERATE|IL9R|ENSG000001243...
# 38701  A|missense_variant|MODERATE|IL9R|ENSG000001243...
# 38701  A|missense_variant|MODERATE|IL9R|ENSG000001243...
#
#                                                      csq ClinVar_CLNDN  \
# 0      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 1      C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 2      C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 2      C|intron_variant&non_coding_transcript_variant...
# 2      C|intron_variant&non_coding_transcript_variant...
# ...                                                  ...           ...
# 38700  C|regulatory_region_variant|MODIFIER|||Regulat...
# 38701  A|missense_variant|MODERATE|IL9R|ENSG000001243...  not_provided
# 38701  A|3_prime_UTR_variant|MODIFIER|IL9R|ENSG000001...  not_provided
# 38701  A|downstream_gene_variant|MODIFIER|WASIR1|ENSG...  not_provided
# 38701  A|downstream_gene_variant|MODIFIER|IL9R|ENSG00...  not_provided
#
#       CLIN_SIG                   ClinVar_CLNREVSTAT ClinVar  \
# 0
# 1
# 2
# 2
# 2
# ...        ...                                  ...     ...
# 38700
# 38701   benign  criteria_provided&_single_submitter  771064
# 38701   benign  criteria_provided&_single_submitter  771064
# 38701   benign  criteria_provided&_single_submitter  771064
# 38701   benign  criteria_provided&_single_submitter  771064
#
#                                   HGVSC                          HGVSP  \
# 0            ENST00000641515.2:c.484A>G  ENSP00000493376.2:p.Thr162Ala
# 1            ENST00000641515.2:c.870T>C  ENSP00000493376.2:p.Ser290%3D
# 2
# 2      ENST00000419394.2:n.480+17991A>G
# 2      ENST00000440200.5:n.169+34338A>G
# ...                                 ...                            ...
# 38700
# 38701      ENST00000244174.11:c.1094G>A  ENSP00000244174.5:p.Arg365His
# 38701        ENST00000369423.7:c.*85G>A
# 38701
# 38701
#
#         PolyPhen                         BIOTYPE EXON INTRON Protein_position  \
# 0      benign(0)                  protein_coding  3/3                     162
# 1                                 protein_coding  3/3                     290
# 2                                 protein_coding
# 2                           processed_transcript         3/3
# 2                           processed_transcript         1/2
# ...          ...                             ...  ...    ...              ...
# 38700                                   enhancer
# 38701  benign(0)                  protein_coding  9/9                     365
# 38701                             protein_coding  9/9
# 38701                                     lncRNA
# 38701             protein_coding_CDS_not_defined
#
#       Amino_acids   Codons STRAND PUBMED  \
# 0             T/A  Aca/Gca      1
# 1               S  tcT/tcC      1
# 2                              -1
# 2                              -1
# 2                              -1
# ...           ...      ...    ...    ...
# 38700
# 38701         R/H  cGt/cAt      1
# 38701                           1
# 38701                          -1
# 38701                           1
#
#                                         Consequence    IMPACT  \
# 0                                  missense_variant  MODERATE
# 1                                synonymous_variant       LOW
# 2                           downstream_gene_variant  MODIFIER
# 2      intron_variant&non_coding_transcript_variant  MODIFIER
# 2      intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                             ...       ...
# 38700                     regulatory_region_variant  MODIFIER
# 38701                              missense_variant  MODERATE
# 38701                           3_prime_UTR_variant  MODIFIER
# 38701                       downstream_gene_variant  MODIFIER
# 38701                       downstream_gene_variant  MODIFIER
#
#                   SIFT      AF AFR_AF  AMR_AF EAS_AF  EUR_AF  SAS_AF  \
# 0      tolerated(0.92)
# 1                       0.6881  0.407  0.6254  0.876  0.7942  0.8098
# 2
# 2
# 2
# ...                ...     ...    ...     ...    ...     ...     ...
# 38700
# 38701  tolerated(0.56)
# 38701
# 38701
# 38701
#
#       gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF  \
# 0         0.9497         0.6075         0.9514         0.9767         0.9994
# 1         0.7209          0.307         0.6749         0.8131         0.7793
# 2
# 2
# 2
# ...          ...            ...            ...            ...            ...
# 38700      0.441         0.8217         0.3483         0.4304          0.702
# 38701    0.01405        0.02867       0.007828        0.01496        0.01587
# 38701    0.01405        0.02867       0.007828        0.01496        0.01587
# 38701    0.01405        0.02867       0.007828        0.01496        0.01587
# 38701    0.01405        0.02867       0.007828        0.01496        0.01587
#
#       gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF  \
# 0             0.9916         0.9726         0.9506         0.9854      0.846
# 1             0.8652         0.8438         0.7932         0.8049     0.4864
# 2
# 2
# 2
# ...              ...            ...            ...            ...        ...
# 38700         0.5274         0.3271         0.4035         0.5578     0.5073
# 38701       0.005438       0.008185        0.02348         0.0411    0.02864
# 38701       0.005438       0.008185        0.02348         0.0411    0.02864
# 38701       0.005438       0.008185        0.02348         0.0411    0.02864
# 38701       0.005438       0.008185        0.02348         0.0411    0.02864
#
#       gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF  \
# 0             0.5948          0.998         0.8951         0.9784
# 1             0.2916         0.6511         0.4782         0.6714
# 2
# 2
# 2
# ...              ...            ...            ...            ...
# 38700          0.809          0.356         0.3772         0.4374
# 38701        0.03691        0.04154        0.01196        0.03051
# 38701        0.03691        0.04154        0.01196        0.03051
# 38701        0.03691        0.04154        0.01196        0.03051
# 38701        0.03691        0.04154        0.01196        0.03051
#
#       gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0             0.9998         0.9907            0.9         0.9674
# 1             0.6047         0.6987         0.6441         0.6751
# 2
# 2
# 2
# ...              ...            ...            ...            ...
# 38700         0.7099         0.5742         0.4209         0.3323
# 38701        0.02488         0.0722        0.03478        0.02331
# 38701        0.02488         0.0722        0.03478        0.02331
# 38701        0.02488         0.0722        0.03478        0.02331
# 38701        0.02488         0.0722        0.03478        0.02331
#
#       gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0             0.8624         0.9772  0.9998  gnomADg_EAS
# 1             0.4659          0.622   0.876          EAS
# 2
# 2
# 2
# ...              ...            ...     ...          ...
# 38700         0.4516         0.5465  0.8217  gnomADe_AFR
# 38701        0.02312        0.04483  0.0722  gnomADg_FIN
# 38701        0.02312        0.04483  0.0722  gnomADg_FIN
# 38701        0.02312        0.04483  0.0722  gnomADg_FIN
# 38701        0.02312        0.04483  0.0722  gnomADg_FIN
#
#       Protein Position and Amino Acid
# 0                               T162A
# 1                                S290
# 2                                 NaN
# 2                                 NaN
# 2                                 NaN
# ...                               ...
# 38700                             NaN
# 38701                           R365H
# 38701                             NaN
# 38701                             NaN
# 38701                             NaN
#
# [340657 rows x 74 columns]

# %%
vcf[['HGVSc', 'HGVSc (Transcript)']] = vcf['HGVSC'].str.split(':', 1, expand=True)
vcf[['HGVSp', 'HGVSp (Transcript)']] = vcf['HGVSP'].str.split(':', 1, expand=True)
vcf
# Out:
#       CHROM        POS         rsID REF ALT QUAL FILTER  \
# 0      chr1      69511    rs2691305   A   G    .   PASS
# 1      chr1      69897  rs200676709   T   C    .   PASS
# 2      chr1     685694            .   T   C    .   PASS
# 2      chr1     685694            .   T   C    .   PASS
# 2      chr1     685694            .   T   C    .   PASS
# ...     ...        ...          ...  ..  ..  ...    ...
# 38700  chrX  156003433    rs2037999   T   C    .   PASS
# 38701  chrX  156009937  rs147385831   G   A    .   PASS
# 38701  chrX  156009937  rs147385831   G   A    .   PASS
# 38701  chrX  156009937  rs147385831   G   A    .   PASS
# 38701  chrX  156009937  rs147385831   G   A    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 0      ADP=120;WT=0;HET=0;HOM=1;NC=0;ASP;G5;GENEINFO=...  1/1  255  120  120
# 1      ADP=98;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.3119,0....  0/1   82   98   98
# 2      ADP=28;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   34   28   28
# 2      ADP=28;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   34   28   28
# 2      ADP=28;WT=0;HET=1;HOM=0;NC=0;CSQ=C|downstream_...  0/1   34   28   28
# ...                                                  ...  ...  ...  ...  ...
# 38700  ADP=11;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.4079,0....  1/1   58   11   11
# 38701  ADP=20;WT=0;HET=1;HOM=0;NC=0;ASP;CFL;GENEINFO=...  0/1   27   20   20
# 38701  ADP=20;WT=0;HET=1;HOM=0;NC=0;ASP;CFL;GENEINFO=...  0/1   27   20   20
# 38701  ADP=20;WT=0;HET=1;HOM=0;NC=0;ASP;CFL;GENEINFO=...  0/1   27   20   20
# 38701  ADP=20;WT=0;HET=1;HOM=0;NC=0;ASP;CFL;GENEINFO=...  0/1   27   20   20
#
#        RD   AD    FREQ        PVAL RDF RDR ADF ADR HET HOM      Zygosity  \
# 0       0  120    100%  1.1001E-71   0   0  86  34   0   1    Homozygous
# 1      73   25  25.51%   5.1517E-9  41  32  11  14   1   0  Heterozygous
# 2      18   10  35.71%   3.6855E-4  17   1   9   1   1   0  Heterozygous
# 2      18   10  35.71%   3.6855E-4  17   1   9   1   1   0  Heterozygous
# 2      18   10  35.71%   3.6855E-4  17   1   9   1   1   0  Heterozygous
# ...    ..  ...     ...         ...  ..  ..  ..  ..  ..  ..           ...
# 38700   0   11    100%   1.4176E-6   0   0   7   4   0   1    Homozygous
# 38701  12    8     40%    1.638E-3  12   0   8   0   1   0  Heterozygous
# 38701  12    8     40%    1.638E-3  12   0   8   0   1   0  Heterozygous
# 38701  12    8     40%    1.638E-3  12   0   8   0   1   0  Heterozygous
# 38701  12    8     40%    1.638E-3  12   0   8   0   1   0  Heterozygous
#
#          Gene_Name Gene Name  \
# 0      OR4F5:79501     OR4F5
# 1      OR4F5:79501     OR4F5
# 2              NaN
# 2              NaN
# 2              NaN
# ...            ...       ...
# 38700    IL9R:3581      IL9R
# 38701    IL9R:3581      IL9R
# 38701    IL9R:3581      IL9R
# 38701    IL9R:3581      IL9R
# 38701    IL9R:3581      IL9R
#
#                                                      CSQ  \
# 0      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 1      C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 2      C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 2      C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 2      C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# ...                                                  ...
# 38700  C|splice_polypyrimidine_tract_variant&intron_v...
# 38701  A|missense_variant|MODERATE|IL9R|ENSG000001243...
# 38701  A|missense_variant|MODERATE|IL9R|ENSG000001243...
# 38701  A|missense_variant|MODERATE|IL9R|ENSG000001243...
# 38701  A|missense_variant|MODERATE|IL9R|ENSG000001243...
#
#                                                      csq ClinVar_CLNDN  \
# 0      G|missense_variant|MODERATE|OR4F5|ENSG00000186...
# 1      C|synonymous_variant|LOW|OR4F5|ENSG00000186092...
# 2      C|downstream_gene_variant|MODIFIER|OR4F16|ENSG...
# 2      C|intron_variant&non_coding_transcript_variant...
# 2      C|intron_variant&non_coding_transcript_variant...
# ...                                                  ...           ...
# 38700  C|regulatory_region_variant|MODIFIER|||Regulat...
# 38701  A|missense_variant|MODERATE|IL9R|ENSG000001243...  not_provided
# 38701  A|3_prime_UTR_variant|MODIFIER|IL9R|ENSG000001...  not_provided
# 38701  A|downstream_gene_variant|MODIFIER|WASIR1|ENSG...  not_provided
# 38701  A|downstream_gene_variant|MODIFIER|IL9R|ENSG00...  not_provided
#
#       CLIN_SIG                   ClinVar_CLNREVSTAT ClinVar  \
# 0
# 1
# 2
# 2
# 2
# ...        ...                                  ...     ...
# 38700
# 38701   benign  criteria_provided&_single_submitter  771064
# 38701   benign  criteria_provided&_single_submitter  771064
# 38701   benign  criteria_provided&_single_submitter  771064
# 38701   benign  criteria_provided&_single_submitter  771064
#
#                                   HGVSC                          HGVSP  \
# 0            ENST00000641515.2:c.484A>G  ENSP00000493376.2:p.Thr162Ala
# 1            ENST00000641515.2:c.870T>C  ENSP00000493376.2:p.Ser290%3D
# 2
# 2      ENST00000419394.2:n.480+17991A>G
# 2      ENST00000440200.5:n.169+34338A>G
# ...                                 ...                            ...
# 38700
# 38701      ENST00000244174.11:c.1094G>A  ENSP00000244174.5:p.Arg365His
# 38701        ENST00000369423.7:c.*85G>A
# 38701
# 38701
#
#         PolyPhen                         BIOTYPE EXON INTRON Protein_position  \
# 0      benign(0)                  protein_coding  3/3                     162
# 1                                 protein_coding  3/3                     290
# 2                                 protein_coding
# 2                           processed_transcript         3/3
# 2                           processed_transcript         1/2
# ...          ...                             ...  ...    ...              ...
# 38700                                   enhancer
# 38701  benign(0)                  protein_coding  9/9                     365
# 38701                             protein_coding  9/9
# 38701                                     lncRNA
# 38701             protein_coding_CDS_not_defined
#
#       Amino_acids   Codons STRAND PUBMED  \
# 0             T/A  Aca/Gca      1
# 1               S  tcT/tcC      1
# 2                              -1
# 2                              -1
# 2                              -1
# ...           ...      ...    ...    ...
# 38700
# 38701         R/H  cGt/cAt      1
# 38701                           1
# 38701                          -1
# 38701                           1
#
#                                         Consequence    IMPACT  \
# 0                                  missense_variant  MODERATE
# 1                                synonymous_variant       LOW
# 2                           downstream_gene_variant  MODIFIER
# 2      intron_variant&non_coding_transcript_variant  MODIFIER
# 2      intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                             ...       ...
# 38700                     regulatory_region_variant  MODIFIER
# 38701                              missense_variant  MODERATE
# 38701                           3_prime_UTR_variant  MODIFIER
# 38701                       downstream_gene_variant  MODIFIER
# 38701                       downstream_gene_variant  MODIFIER
#
#                   SIFT      AF AFR_AF  AMR_AF EAS_AF  EUR_AF  SAS_AF  \
# 0      tolerated(0.92)
# 1                       0.6881  0.407  0.6254  0.876  0.7942  0.8098
# 2
# 2
# 2
# ...                ...     ...    ...     ...    ...     ...     ...
# 38700
# 38701  tolerated(0.56)
# 38701
# 38701
# 38701
#
#       gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF  \
# 0         0.9497         0.6075         0.9514         0.9767         0.9994
# 1         0.7209          0.307         0.6749         0.8131         0.7793
# 2
# 2
# 2
# ...          ...            ...            ...            ...            ...
# 38700      0.441         0.8217         0.3483         0.4304          0.702
# 38701    0.01405        0.02867       0.007828        0.01496        0.01587
# 38701    0.01405        0.02867       0.007828        0.01496        0.01587
# 38701    0.01405        0.02867       0.007828        0.01496        0.01587
# 38701    0.01405        0.02867       0.007828        0.01496        0.01587
#
#       gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF  \
# 0             0.9916         0.9726         0.9506         0.9854      0.846
# 1             0.8652         0.8438         0.7932         0.8049     0.4864
# 2
# 2
# 2
# ...              ...            ...            ...            ...        ...
# 38700         0.5274         0.3271         0.4035         0.5578     0.5073
# 38701       0.005438       0.008185        0.02348         0.0411    0.02864
# 38701       0.005438       0.008185        0.02348         0.0411    0.02864
# 38701       0.005438       0.008185        0.02348         0.0411    0.02864
# 38701       0.005438       0.008185        0.02348         0.0411    0.02864
#
#       gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF  \
# 0             0.5948          0.998         0.8951         0.9784
# 1             0.2916         0.6511         0.4782         0.6714
# 2
# 2
# 2
# ...              ...            ...            ...            ...
# 38700          0.809          0.356         0.3772         0.4374
# 38701        0.03691        0.04154        0.01196        0.03051
# 38701        0.03691        0.04154        0.01196        0.03051
# 38701        0.03691        0.04154        0.01196        0.03051
# 38701        0.03691        0.04154        0.01196        0.03051
#
#       gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0             0.9998         0.9907            0.9         0.9674
# 1             0.6047         0.6987         0.6441         0.6751
# 2
# 2
# 2
# ...              ...            ...            ...            ...
# 38700         0.7099         0.5742         0.4209         0.3323
# 38701        0.02488         0.0722        0.03478        0.02331
# 38701        0.02488         0.0722        0.03478        0.02331
# 38701        0.02488         0.0722        0.03478        0.02331
# 38701        0.02488         0.0722        0.03478        0.02331
#
#       gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0             0.8624         0.9772  0.9998  gnomADg_EAS
# 1             0.4659          0.622   0.876          EAS
# 2
# 2
# 2
# ...              ...            ...     ...          ...
# 38700         0.4516         0.5465  0.8217  gnomADe_AFR
# 38701        0.02312        0.04483  0.0722  gnomADg_FIN
# 38701        0.02312        0.04483  0.0722  gnomADg_FIN
# 38701        0.02312        0.04483  0.0722  gnomADg_FIN
# 38701        0.02312        0.04483  0.0722  gnomADg_FIN
#
#       Protein Position and Amino Acid               HGVSc HGVSc (Transcript)  \
# 0                               T162A   ENST00000641515.2           c.484A>G
# 1                                S290   ENST00000641515.2           c.870T>C
# 2                                 NaN                                   None
# 2                                 NaN   ENST00000419394.2     n.480+17991A>G
# 2                                 NaN   ENST00000440200.5     n.169+34338A>G
# ...                               ...                 ...                ...
# 38700                             NaN                                   None
# 38701                           R365H  ENST00000244174.11          c.1094G>A
# 38701                             NaN   ENST00000369423.7           c.*85G>A
# 38701                             NaN                                   None
# 38701                             NaN                                   None
#
#                    HGVSp HGVSp (Transcript)
# 0      ENSP00000493376.2        p.Thr162Ala
# 1      ENSP00000493376.2        p.Ser290%3D
# 2                                      None
# 2                                      None
# 2                                      None
# ...                  ...                ...
# 38700                                  None
# 38701  ENSP00000244174.5        p.Arg365His
# 38701                                  None
# 38701                                  None
# 38701                                  None
#
# [340657 rows x 78 columns]

# %%
vcf_final = vcf[['Gene Name', 'rsID','CHROM', 'POS', 'REF', 'ALT', 'Zygosity', 'Consequence', 'IMPACT',
          'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT',
          'ClinVar', 'HGVSc', 'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF',
       'ADR', 'SIFT', 'PolyPhen', 'AF', 'AFR_AF', 'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF',
       'gnomADe_AF', 'gnomADe_AFR_AF', 'gnomADe_AMR_AF', 'gnomADe_ASJ_AF',
       'gnomADe_EAS_AF', 'gnomADe_FIN_AF', 'gnomADe_NFE_AF', 'gnomADe_OTH_AF',
       'gnomADe_SAS_AF', 'gnomADg_AF', 'gnomADg_AFR_AF', 'gnomADg_AMI_AF',
       'gnomADg_AMR_AF', 'gnomADg_ASJ_AF', 'gnomADg_EAS_AF', 'gnomADg_FIN_AF',
       'gnomADg_MID_AF', 'gnomADg_NFE_AF', 'gnomADg_OTH_AF', 'gnomADg_SAS_AF',
       'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE', 'EXON', 'INTRON',
          'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED']]
vcf_final
# Out:
#       Gene Name         rsID CHROM        POS REF ALT      Zygosity  \
# 0         OR4F5    rs2691305  chr1      69511   A   G    Homozygous
# 1         OR4F5  rs200676709  chr1      69897   T   C  Heterozygous
# 2                          .  chr1     685694   T   C  Heterozygous
# 2                          .  chr1     685694   T   C  Heterozygous
# 2                          .  chr1     685694   T   C  Heterozygous
# ...         ...          ...   ...        ...  ..  ..           ...
# 38700      IL9R    rs2037999  chrX  156003433   T   C    Homozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
#
#                                         Consequence    IMPACT ClinVar_CLNDN  \
# 0                                  missense_variant  MODERATE
# 1                                synonymous_variant       LOW
# 2                           downstream_gene_variant  MODIFIER
# 2      intron_variant&non_coding_transcript_variant  MODIFIER
# 2      intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                             ...       ...           ...
# 38700                     regulatory_region_variant  MODIFIER
# 38701                              missense_variant  MODERATE  not_provided
# 38701                           3_prime_UTR_variant  MODIFIER  not_provided
# 38701                       downstream_gene_variant  MODIFIER  not_provided
# 38701                       downstream_gene_variant  MODIFIER  not_provided
#
#       CLIN_SIG                   ClinVar_CLNREVSTAT ClinVar  \
# 0
# 1
# 2
# 2
# 2
# ...        ...                                  ...     ...
# 38700
# 38701   benign  criteria_provided&_single_submitter  771064
# 38701   benign  criteria_provided&_single_submitter  771064
# 38701   benign  criteria_provided&_single_submitter  771064
# 38701   benign  criteria_provided&_single_submitter  771064
#
#                     HGVSc HGVSc (Transcript)              HGVSp  \
# 0       ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 1       ENST00000641515.2           c.870T>C  ENSP00000493376.2
# 2                                       None
# 2       ENST00000419394.2     n.480+17991A>G
# 2       ENST00000440200.5     n.169+34338A>G
# ...                   ...                ...                ...
# 38700                                   None
# 38701  ENST00000244174.11          c.1094G>A  ENSP00000244174.5
# 38701   ENST00000369423.7           c.*85G>A
# 38701                                   None
# 38701                                   None
#
#       HGVSp (Transcript)   GT   GQ  SDP   DP  RD   AD    FREQ        PVAL RDF  \
# 0            p.Thr162Ala  1/1  255  120  120   0  120    100%  1.1001E-71   0
# 1            p.Ser290%3D  0/1   82   98   98  73   25  25.51%   5.1517E-9  41
# 2                   None  0/1   34   28   28  18   10  35.71%   3.6855E-4  17
# 2                   None  0/1   34   28   28  18   10  35.71%   3.6855E-4  17
# 2                   None  0/1   34   28   28  18   10  35.71%   3.6855E-4  17
# ...                  ...  ...  ...  ...  ...  ..  ...     ...         ...  ..
# 38700               None  1/1   58   11   11   0   11    100%   1.4176E-6   0
# 38701        p.Arg365His  0/1   27   20   20  12    8     40%    1.638E-3  12
# 38701               None  0/1   27   20   20  12    8     40%    1.638E-3  12
# 38701               None  0/1   27   20   20  12    8     40%    1.638E-3  12
# 38701               None  0/1   27   20   20  12    8     40%    1.638E-3  12
#
#       RDR ADF ADR             SIFT   PolyPhen      AF AFR_AF  AMR_AF EAS_AF  \
# 0       0  86  34  tolerated(0.92)  benign(0)
# 1      32  11  14                              0.6881  0.407  0.6254  0.876
# 2       1   9   1
# 2       1   9   1
# 2       1   9   1
# ...    ..  ..  ..              ...        ...     ...    ...     ...    ...
# 38700   0   7   4
# 38701   0   8   0  tolerated(0.56)  benign(0)
# 38701   0   8   0
# 38701   0   8   0
# 38701   0   8   0
#
#        EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF  \
# 0                         0.9497         0.6075         0.9514         0.9767
# 1      0.7942  0.8098     0.7209          0.307         0.6749         0.8131
# 2
# 2
# 2
# ...       ...     ...        ...            ...            ...            ...
# 38700                      0.441         0.8217         0.3483         0.4304
# 38701                    0.01405        0.02867       0.007828        0.01496
# 38701                    0.01405        0.02867       0.007828        0.01496
# 38701                    0.01405        0.02867       0.007828        0.01496
# 38701                    0.01405        0.02867       0.007828        0.01496
#
#       gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0             0.9994         0.9916         0.9726         0.9506
# 1             0.7793         0.8652         0.8438         0.7932
# 2
# 2
# 2
# ...              ...            ...            ...            ...
# 38700          0.702         0.5274         0.3271         0.4035
# 38701        0.01587       0.005438       0.008185        0.02348
# 38701        0.01587       0.005438       0.008185        0.02348
# 38701        0.01587       0.005438       0.008185        0.02348
# 38701        0.01587       0.005438       0.008185        0.02348
#
#       gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0             0.9854      0.846         0.5948          0.998         0.8951
# 1             0.8049     0.4864         0.2916         0.6511         0.4782
# 2
# 2
# 2
# ...              ...        ...            ...            ...            ...
# 38700         0.5578     0.5073          0.809          0.356         0.3772
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
#
#       gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0             0.9784         0.9998         0.9907            0.9
# 1             0.6714         0.6047         0.6987         0.6441
# 2
# 2
# 2
# ...              ...            ...            ...            ...
# 38700         0.4374         0.7099         0.5742         0.4209
# 38701        0.03051        0.02488         0.0722        0.03478
# 38701        0.03051        0.02488         0.0722        0.03478
# 38701        0.03051        0.02488         0.0722        0.03478
# 38701        0.03051        0.02488         0.0722        0.03478
#
#       gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0             0.9674         0.8624         0.9772  0.9998  gnomADg_EAS
# 1             0.6751         0.4659          0.622   0.876          EAS
# 2
# 2
# 2
# ...              ...            ...            ...     ...          ...
# 38700         0.3323         0.4516         0.5465  0.8217  gnomADe_AFR
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg_FIN
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg_FIN
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg_FIN
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg_FIN
#
#                               BIOTYPE EXON INTRON  \
# 0                      protein_coding  3/3
# 1                      protein_coding  3/3
# 2                      protein_coding
# 2                processed_transcript         3/3
# 2                processed_transcript         1/2
# ...                               ...  ...    ...
# 38700                        enhancer
# 38701                  protein_coding  9/9
# 38701                  protein_coding  9/9
# 38701                          lncRNA
# 38701  protein_coding_CDS_not_defined
#
#       Protein Position and Amino Acid   Codons STRAND PUBMED
# 0                               T162A  Aca/Gca      1
# 1                                S290  tcT/tcC      1
# 2                                 NaN              -1
# 2                                 NaN              -1
# 2                                 NaN              -1
# ...                               ...      ...    ...    ...
# 38700                             NaN
# 38701                           R365H  cGt/cAt      1
# 38701                             NaN               1
# 38701                             NaN              -1
# 38701                             NaN               1
#
# [340657 rows x 66 columns]

# %%
# Define the terms to remove
remove_terms = set(["not_specified", "not_provided"])

# Apply the filtering operation to 'Column1' only
vcf_final['ClinVar_CLNDN'] = vcf_final['ClinVar_CLNDN'].apply(lambda row: "&".join(
    [term for term in row.split("&") if term not in remove_terms]
    ) if isinstance(row, str) and not all(term in remove_terms for term in row.split("&")) else row)


vcf_final['CLIN_SIG'] = vcf_final['CLIN_SIG'].apply(lambda row: "&".join(
    [term for term in row.split("&") if term not in remove_terms]
    ) if isinstance(row, str) and not all(term in remove_terms for term in row.split("&")) else row)


vcf_final['ClinVar_CLNREVSTAT'] = vcf_final['ClinVar_CLNREVSTAT'].apply(lambda row: "&".join(
    [term for term in row.split("&") if term not in remove_terms]
    ) if isinstance(row, str) and not all(term in remove_terms for term in row.split("&")) else row)

# Print the modified DataFrame
vcf_final
# Out:
#       Gene Name         rsID CHROM        POS REF ALT      Zygosity  \
# 0         OR4F5    rs2691305  chr1      69511   A   G    Homozygous
# 1         OR4F5  rs200676709  chr1      69897   T   C  Heterozygous
# 2                          .  chr1     685694   T   C  Heterozygous
# 2                          .  chr1     685694   T   C  Heterozygous
# 2                          .  chr1     685694   T   C  Heterozygous
# ...         ...          ...   ...        ...  ..  ..           ...
# 38700      IL9R    rs2037999  chrX  156003433   T   C    Homozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
#
#                                         Consequence    IMPACT ClinVar_CLNDN  \
# 0                                  missense_variant  MODERATE
# 1                                synonymous_variant       LOW
# 2                           downstream_gene_variant  MODIFIER
# 2      intron_variant&non_coding_transcript_variant  MODIFIER
# 2      intron_variant&non_coding_transcript_variant  MODIFIER
# ...                                             ...       ...           ...
# 38700                     regulatory_region_variant  MODIFIER
# 38701                              missense_variant  MODERATE  not_provided
# 38701                           3_prime_UTR_variant  MODIFIER  not_provided
# 38701                       downstream_gene_variant  MODIFIER  not_provided
# 38701                       downstream_gene_variant  MODIFIER  not_provided
#
#       CLIN_SIG                   ClinVar_CLNREVSTAT ClinVar  \
# 0
# 1
# 2
# 2
# 2
# ...        ...                                  ...     ...
# 38700
# 38701   benign  criteria_provided&_single_submitter  771064
# 38701   benign  criteria_provided&_single_submitter  771064
# 38701   benign  criteria_provided&_single_submitter  771064
# 38701   benign  criteria_provided&_single_submitter  771064
#
#                     HGVSc HGVSc (Transcript)              HGVSp  \
# 0       ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 1       ENST00000641515.2           c.870T>C  ENSP00000493376.2
# 2                                       None
# 2       ENST00000419394.2     n.480+17991A>G
# 2       ENST00000440200.5     n.169+34338A>G
# ...                   ...                ...                ...
# 38700                                   None
# 38701  ENST00000244174.11          c.1094G>A  ENSP00000244174.5
# 38701   ENST00000369423.7           c.*85G>A
# 38701                                   None
# 38701                                   None
#
#       HGVSp (Transcript)   GT   GQ  SDP   DP  RD   AD    FREQ        PVAL RDF  \
# 0            p.Thr162Ala  1/1  255  120  120   0  120    100%  1.1001E-71   0
# 1            p.Ser290%3D  0/1   82   98   98  73   25  25.51%   5.1517E-9  41
# 2                   None  0/1   34   28   28  18   10  35.71%   3.6855E-4  17
# 2                   None  0/1   34   28   28  18   10  35.71%   3.6855E-4  17
# 2                   None  0/1   34   28   28  18   10  35.71%   3.6855E-4  17
# ...                  ...  ...  ...  ...  ...  ..  ...     ...         ...  ..
# 38700               None  1/1   58   11   11   0   11    100%   1.4176E-6   0
# 38701        p.Arg365His  0/1   27   20   20  12    8     40%    1.638E-3  12
# 38701               None  0/1   27   20   20  12    8     40%    1.638E-3  12
# 38701               None  0/1   27   20   20  12    8     40%    1.638E-3  12
# 38701               None  0/1   27   20   20  12    8     40%    1.638E-3  12
#
#       RDR ADF ADR             SIFT   PolyPhen      AF AFR_AF  AMR_AF EAS_AF  \
# 0       0  86  34  tolerated(0.92)  benign(0)
# 1      32  11  14                              0.6881  0.407  0.6254  0.876
# 2       1   9   1
# 2       1   9   1
# 2       1   9   1
# ...    ..  ..  ..              ...        ...     ...    ...     ...    ...
# 38700   0   7   4
# 38701   0   8   0  tolerated(0.56)  benign(0)
# 38701   0   8   0
# 38701   0   8   0
# 38701   0   8   0
#
#        EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF  \
# 0                         0.9497         0.6075         0.9514         0.9767
# 1      0.7942  0.8098     0.7209          0.307         0.6749         0.8131
# 2
# 2
# 2
# ...       ...     ...        ...            ...            ...            ...
# 38700                      0.441         0.8217         0.3483         0.4304
# 38701                    0.01405        0.02867       0.007828        0.01496
# 38701                    0.01405        0.02867       0.007828        0.01496
# 38701                    0.01405        0.02867       0.007828        0.01496
# 38701                    0.01405        0.02867       0.007828        0.01496
#
#       gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0             0.9994         0.9916         0.9726         0.9506
# 1             0.7793         0.8652         0.8438         0.7932
# 2
# 2
# 2
# ...              ...            ...            ...            ...
# 38700          0.702         0.5274         0.3271         0.4035
# 38701        0.01587       0.005438       0.008185        0.02348
# 38701        0.01587       0.005438       0.008185        0.02348
# 38701        0.01587       0.005438       0.008185        0.02348
# 38701        0.01587       0.005438       0.008185        0.02348
#
#       gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0             0.9854      0.846         0.5948          0.998         0.8951
# 1             0.8049     0.4864         0.2916         0.6511         0.4782
# 2
# 2
# 2
# ...              ...        ...            ...            ...            ...
# 38700         0.5578     0.5073          0.809          0.356         0.3772
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
#
#       gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0             0.9784         0.9998         0.9907            0.9
# 1             0.6714         0.6047         0.6987         0.6441
# 2
# 2
# 2
# ...              ...            ...            ...            ...
# 38700         0.4374         0.7099         0.5742         0.4209
# 38701        0.03051        0.02488         0.0722        0.03478
# 38701        0.03051        0.02488         0.0722        0.03478
# 38701        0.03051        0.02488         0.0722        0.03478
# 38701        0.03051        0.02488         0.0722        0.03478
#
#       gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0             0.9674         0.8624         0.9772  0.9998  gnomADg_EAS
# 1             0.6751         0.4659          0.622   0.876          EAS
# 2
# 2
# 2
# ...              ...            ...            ...     ...          ...
# 38700         0.3323         0.4516         0.5465  0.8217  gnomADe_AFR
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg_FIN
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg_FIN
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg_FIN
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg_FIN
#
#                               BIOTYPE EXON INTRON  \
# 0                      protein_coding  3/3
# 1                      protein_coding  3/3
# 2                      protein_coding
# 2                processed_transcript         3/3
# 2                processed_transcript         1/2
# ...                               ...  ...    ...
# 38700                        enhancer
# 38701                  protein_coding  9/9
# 38701                  protein_coding  9/9
# 38701                          lncRNA
# 38701  protein_coding_CDS_not_defined
#
#       Protein Position and Amino Acid   Codons STRAND PUBMED
# 0                               T162A  Aca/Gca      1
# 1                                S290  tcT/tcC      1
# 2                                 NaN              -1
# 2                                 NaN              -1
# 2                                 NaN              -1
# ...                               ...      ...    ...    ...
# 38700                             NaN
# 38701                           R365H  cGt/cAt      1
# 38701                             NaN               1
# 38701                             NaN              -1
# 38701                             NaN               1
#
# [340657 rows x 66 columns]

# %%
vcf_final = vcf_final.astype(str).applymap(lambda x: x.replace('&', ',').replace('_', ' '))
#vcf_final.loc[:, vcf_final.columns != 'CHROM'] = vcf_final.loc[:, vcf_final.columns != 'CHROM'].astype(str).applymap(lambda x: x.replace('&', ',').replace('_', ' '))
vcf_final
# Out:
#       Gene Name         rsID CHROM        POS REF ALT      Zygosity  \
# 0         OR4F5    rs2691305  chr1      69511   A   G    Homozygous
# 1         OR4F5  rs200676709  chr1      69897   T   C  Heterozygous
# 2                          .  chr1     685694   T   C  Heterozygous
# 2                          .  chr1     685694   T   C  Heterozygous
# 2                          .  chr1     685694   T   C  Heterozygous
# ...         ...          ...   ...        ...  ..  ..           ...
# 38700      IL9R    rs2037999  chrX  156003433   T   C    Homozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
#
#                                         Consequence    IMPACT ClinVar_CLNDN  \
# 0                                  missense variant  MODERATE
# 1                                synonymous variant       LOW
# 2                           downstream gene variant  MODIFIER
# 2      intron variant,non coding transcript variant  MODIFIER
# 2      intron variant,non coding transcript variant  MODIFIER
# ...                                             ...       ...           ...
# 38700                     regulatory region variant  MODIFIER
# 38701                              missense variant  MODERATE  not provided
# 38701                           3 prime UTR variant  MODIFIER  not provided
# 38701                       downstream gene variant  MODIFIER  not provided
# 38701                       downstream gene variant  MODIFIER  not provided
#
#       CLIN_SIG                   ClinVar_CLNREVSTAT ClinVar  \
# 0
# 1
# 2
# 2
# 2
# ...        ...                                  ...     ...
# 38700
# 38701   benign  criteria provided, single submitter  771064
# 38701   benign  criteria provided, single submitter  771064
# 38701   benign  criteria provided, single submitter  771064
# 38701   benign  criteria provided, single submitter  771064
#
#                     HGVSc HGVSc (Transcript)              HGVSp  \
# 0       ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 1       ENST00000641515.2           c.870T>C  ENSP00000493376.2
# 2                                       None
# 2       ENST00000419394.2     n.480+17991A>G
# 2       ENST00000440200.5     n.169+34338A>G
# ...                   ...                ...                ...
# 38700                                   None
# 38701  ENST00000244174.11          c.1094G>A  ENSP00000244174.5
# 38701   ENST00000369423.7           c.*85G>A
# 38701                                   None
# 38701                                   None
#
#       HGVSp (Transcript)   GT   GQ  SDP   DP  RD   AD    FREQ        PVAL RDF  \
# 0            p.Thr162Ala  1/1  255  120  120   0  120    100%  1.1001E-71   0
# 1            p.Ser290%3D  0/1   82   98   98  73   25  25.51%   5.1517E-9  41
# 2                   None  0/1   34   28   28  18   10  35.71%   3.6855E-4  17
# 2                   None  0/1   34   28   28  18   10  35.71%   3.6855E-4  17
# 2                   None  0/1   34   28   28  18   10  35.71%   3.6855E-4  17
# ...                  ...  ...  ...  ...  ...  ..  ...     ...         ...  ..
# 38700               None  1/1   58   11   11   0   11    100%   1.4176E-6   0
# 38701        p.Arg365His  0/1   27   20   20  12    8     40%    1.638E-3  12
# 38701               None  0/1   27   20   20  12    8     40%    1.638E-3  12
# 38701               None  0/1   27   20   20  12    8     40%    1.638E-3  12
# 38701               None  0/1   27   20   20  12    8     40%    1.638E-3  12
#
#       RDR ADF ADR             SIFT   PolyPhen      AF AFR_AF  AMR_AF EAS_AF  \
# 0       0  86  34  tolerated(0.92)  benign(0)
# 1      32  11  14                              0.6881  0.407  0.6254  0.876
# 2       1   9   1
# 2       1   9   1
# 2       1   9   1
# ...    ..  ..  ..              ...        ...     ...    ...     ...    ...
# 38700   0   7   4
# 38701   0   8   0  tolerated(0.56)  benign(0)
# 38701   0   8   0
# 38701   0   8   0
# 38701   0   8   0
#
#        EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF  \
# 0                         0.9497         0.6075         0.9514         0.9767
# 1      0.7942  0.8098     0.7209          0.307         0.6749         0.8131
# 2
# 2
# 2
# ...       ...     ...        ...            ...            ...            ...
# 38700                      0.441         0.8217         0.3483         0.4304
# 38701                    0.01405        0.02867       0.007828        0.01496
# 38701                    0.01405        0.02867       0.007828        0.01496
# 38701                    0.01405        0.02867       0.007828        0.01496
# 38701                    0.01405        0.02867       0.007828        0.01496
#
#       gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0             0.9994         0.9916         0.9726         0.9506
# 1             0.7793         0.8652         0.8438         0.7932
# 2
# 2
# 2
# ...              ...            ...            ...            ...
# 38700          0.702         0.5274         0.3271         0.4035
# 38701        0.01587       0.005438       0.008185        0.02348
# 38701        0.01587       0.005438       0.008185        0.02348
# 38701        0.01587       0.005438       0.008185        0.02348
# 38701        0.01587       0.005438       0.008185        0.02348
#
#       gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0             0.9854      0.846         0.5948          0.998         0.8951
# 1             0.8049     0.4864         0.2916         0.6511         0.4782
# 2
# 2
# 2
# ...              ...        ...            ...            ...            ...
# 38700         0.5578     0.5073          0.809          0.356         0.3772
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
#
#       gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0             0.9784         0.9998         0.9907            0.9
# 1             0.6714         0.6047         0.6987         0.6441
# 2
# 2
# 2
# ...              ...            ...            ...            ...
# 38700         0.4374         0.7099         0.5742         0.4209
# 38701        0.03051        0.02488         0.0722        0.03478
# 38701        0.03051        0.02488         0.0722        0.03478
# 38701        0.03051        0.02488         0.0722        0.03478
# 38701        0.03051        0.02488         0.0722        0.03478
#
#       gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0             0.9674         0.8624         0.9772  0.9998  gnomADg EAS
# 1             0.6751         0.4659          0.622   0.876          EAS
# 2
# 2
# 2
# ...              ...            ...            ...     ...          ...
# 38700         0.3323         0.4516         0.5465  0.8217  gnomADe AFR
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
#
#                               BIOTYPE EXON INTRON  \
# 0                      protein coding  3/3
# 1                      protein coding  3/3
# 2                      protein coding
# 2                processed transcript         3/3
# 2                processed transcript         1/2
# ...                               ...  ...    ...
# 38700                        enhancer
# 38701                  protein coding  9/9
# 38701                  protein coding  9/9
# 38701                          lncRNA
# 38701  protein coding CDS not defined
#
#       Protein Position and Amino Acid   Codons STRAND PUBMED
# 0                               T162A  Aca/Gca      1
# 1                                S290  tcT/tcC      1
# 2                                 nan              -1
# 2                                 nan              -1
# 2                                 nan              -1
# ...                               ...      ...    ...    ...
# 38700                             nan
# 38701                           R365H  cGt/cAt      1
# 38701                             nan               1
# 38701                             nan              -1
# 38701                             nan               1
#
# [340657 rows x 66 columns]

# %%
vcf_final['consequence'] = vcf_final['Consequence'].str.split(',').str[0]
vcf_final
# Out:
#       Gene Name         rsID CHROM        POS REF ALT      Zygosity  \
# 0         OR4F5    rs2691305  chr1      69511   A   G    Homozygous
# 1         OR4F5  rs200676709  chr1      69897   T   C  Heterozygous
# 2                          .  chr1     685694   T   C  Heterozygous
# 2                          .  chr1     685694   T   C  Heterozygous
# 2                          .  chr1     685694   T   C  Heterozygous
# ...         ...          ...   ...        ...  ..  ..           ...
# 38700      IL9R    rs2037999  chrX  156003433   T   C    Homozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 38701      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
#
#                                         Consequence    IMPACT ClinVar_CLNDN  \
# 0                                  missense variant  MODERATE
# 1                                synonymous variant       LOW
# 2                           downstream gene variant  MODIFIER
# 2      intron variant,non coding transcript variant  MODIFIER
# 2      intron variant,non coding transcript variant  MODIFIER
# ...                                             ...       ...           ...
# 38700                     regulatory region variant  MODIFIER
# 38701                              missense variant  MODERATE  not provided
# 38701                           3 prime UTR variant  MODIFIER  not provided
# 38701                       downstream gene variant  MODIFIER  not provided
# 38701                       downstream gene variant  MODIFIER  not provided
#
#       CLIN_SIG                   ClinVar_CLNREVSTAT ClinVar  \
# 0
# 1
# 2
# 2
# 2
# ...        ...                                  ...     ...
# 38700
# 38701   benign  criteria provided, single submitter  771064
# 38701   benign  criteria provided, single submitter  771064
# 38701   benign  criteria provided, single submitter  771064
# 38701   benign  criteria provided, single submitter  771064
#
#                     HGVSc HGVSc (Transcript)              HGVSp  \
# 0       ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 1       ENST00000641515.2           c.870T>C  ENSP00000493376.2
# 2                                       None
# 2       ENST00000419394.2     n.480+17991A>G
# 2       ENST00000440200.5     n.169+34338A>G
# ...                   ...                ...                ...
# 38700                                   None
# 38701  ENST00000244174.11          c.1094G>A  ENSP00000244174.5
# 38701   ENST00000369423.7           c.*85G>A
# 38701                                   None
# 38701                                   None
#
#       HGVSp (Transcript)   GT   GQ  SDP   DP  RD   AD    FREQ        PVAL RDF  \
# 0            p.Thr162Ala  1/1  255  120  120   0  120    100%  1.1001E-71   0
# 1            p.Ser290%3D  0/1   82   98   98  73   25  25.51%   5.1517E-9  41
# 2                   None  0/1   34   28   28  18   10  35.71%   3.6855E-4  17
# 2                   None  0/1   34   28   28  18   10  35.71%   3.6855E-4  17
# 2                   None  0/1   34   28   28  18   10  35.71%   3.6855E-4  17
# ...                  ...  ...  ...  ...  ...  ..  ...     ...         ...  ..
# 38700               None  1/1   58   11   11   0   11    100%   1.4176E-6   0
# 38701        p.Arg365His  0/1   27   20   20  12    8     40%    1.638E-3  12
# 38701               None  0/1   27   20   20  12    8     40%    1.638E-3  12
# 38701               None  0/1   27   20   20  12    8     40%    1.638E-3  12
# 38701               None  0/1   27   20   20  12    8     40%    1.638E-3  12
#
#       RDR ADF ADR             SIFT   PolyPhen      AF AFR_AF  AMR_AF EAS_AF  \
# 0       0  86  34  tolerated(0.92)  benign(0)
# 1      32  11  14                              0.6881  0.407  0.6254  0.876
# 2       1   9   1
# 2       1   9   1
# 2       1   9   1
# ...    ..  ..  ..              ...        ...     ...    ...     ...    ...
# 38700   0   7   4
# 38701   0   8   0  tolerated(0.56)  benign(0)
# 38701   0   8   0
# 38701   0   8   0
# 38701   0   8   0
#
#        EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF  \
# 0                         0.9497         0.6075         0.9514         0.9767
# 1      0.7942  0.8098     0.7209          0.307         0.6749         0.8131
# 2
# 2
# 2
# ...       ...     ...        ...            ...            ...            ...
# 38700                      0.441         0.8217         0.3483         0.4304
# 38701                    0.01405        0.02867       0.007828        0.01496
# 38701                    0.01405        0.02867       0.007828        0.01496
# 38701                    0.01405        0.02867       0.007828        0.01496
# 38701                    0.01405        0.02867       0.007828        0.01496
#
#       gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0             0.9994         0.9916         0.9726         0.9506
# 1             0.7793         0.8652         0.8438         0.7932
# 2
# 2
# 2
# ...              ...            ...            ...            ...
# 38700          0.702         0.5274         0.3271         0.4035
# 38701        0.01587       0.005438       0.008185        0.02348
# 38701        0.01587       0.005438       0.008185        0.02348
# 38701        0.01587       0.005438       0.008185        0.02348
# 38701        0.01587       0.005438       0.008185        0.02348
#
#       gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0             0.9854      0.846         0.5948          0.998         0.8951
# 1             0.8049     0.4864         0.2916         0.6511         0.4782
# 2
# 2
# 2
# ...              ...        ...            ...            ...            ...
# 38700         0.5578     0.5073          0.809          0.356         0.3772
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
# 38701         0.0411    0.02864        0.03691        0.04154        0.01196
#
#       gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0             0.9784         0.9998         0.9907            0.9
# 1             0.6714         0.6047         0.6987         0.6441
# 2
# 2
# 2
# ...              ...            ...            ...            ...
# 38700         0.4374         0.7099         0.5742         0.4209
# 38701        0.03051        0.02488         0.0722        0.03478
# 38701        0.03051        0.02488         0.0722        0.03478
# 38701        0.03051        0.02488         0.0722        0.03478
# 38701        0.03051        0.02488         0.0722        0.03478
#
#       gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0             0.9674         0.8624         0.9772  0.9998  gnomADg EAS
# 1             0.6751         0.4659          0.622   0.876          EAS
# 2
# 2
# 2
# ...              ...            ...            ...     ...          ...
# 38700         0.3323         0.4516         0.5465  0.8217  gnomADe AFR
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 38701        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
#
#                               BIOTYPE EXON INTRON  \
# 0                      protein coding  3/3
# 1                      protein coding  3/3
# 2                      protein coding
# 2                processed transcript         3/3
# 2                processed transcript         1/2
# ...                               ...  ...    ...
# 38700                        enhancer
# 38701                  protein coding  9/9
# 38701                  protein coding  9/9
# 38701                          lncRNA
# 38701  protein coding CDS not defined
#
#       Protein Position and Amino Acid   Codons STRAND PUBMED  \
# 0                               T162A  Aca/Gca      1
# 1                                S290  tcT/tcC      1
# 2                                 nan              -1
# 2                                 nan              -1
# 2                                 nan              -1
# ...                               ...      ...    ...    ...
# 38700                             nan
# 38701                           R365H  cGt/cAt      1
# 38701                             nan               1
# 38701                             nan              -1
# 38701                             nan               1
#
#                      consequence
# 0               missense variant
# 1             synonymous variant
# 2        downstream gene variant
# 2                 intron variant
# 2                 intron variant
# ...                          ...
# 38700  regulatory region variant
# 38701           missense variant
# 38701        3 prime UTR variant
# 38701    downstream gene variant
# 38701    downstream gene variant
#
# [340657 rows x 67 columns]

# %%
df_1 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Madhu_folder_04_07_2023/kidney_health_final.vcf/consequence.xlsx')
df_1
# Out:
#                             consequence Consequence_score
# 0                   transcript ablation             10/10
# 1               splice acceptor variant              8/10
# 2                  splice donor variant              8/10
# 3                           stop gained             10/10
# 4                    frameshift variant             10/10
# 5                             stop lost              9/10
# 6                            start lost              9/10
# 7              transcript amplification              8/10
# 8                     inframe insertion              6/10
# 9                      inframe deletion              6/10
# 10                     missense variant              7/10
# 11             protein altering variant              5/10
# 12                splice region variant              4/10
# 13        splice donor 5th base variant              4/10
# 14          splice donor region variant              4/10
# 15  splice polypyrimidine tract variant              4/10
# 16    incomplete terminal codon variant              3/10
# 17               start retained variant              3/10
# 18                stop retained variant              3/10
# 19                   synonymous variant              3/10
# 20              coding sequence variant              3/10
# 21                 mature miRNA variant              3/10
# 22                  5 prime UTR variant              3/10
# 23                  3 prime UTR variant              3/10
# 24   non coding transcript exon variant              2/10
# 25                       intron variant              2/10
# 26               NMD transcript variant              2/10
# 27        non coding transcript variant              2/10
# 28                upstream gene variant              2/10
# 29              downstream gene variant              2/10
# 30                        TFBS ablation              2/10
# 31                   TFBS amplification              2/10
# 32              TF binding site variant              2/10
# 33           regulatory region ablation              2/10
# 34      regulatory region amplification              2/10
# 35                   feature elongation              2/10
# 36            regulatory region variant              2/10
# 37                   feature truncation              1/10
# 38                   intergenic variant              1/10

# %%
merged_1 = pd.merge(vcf_final, df_1, on='consequence', how='left', sort=False)
merged_1
# Out:
#        Gene Name         rsID CHROM        POS REF ALT      Zygosity  \
# 0          OR4F5    rs2691305  chr1      69511   A   G    Homozygous
# 1          OR4F5  rs200676709  chr1      69897   T   C  Heterozygous
# 2                           .  chr1     685694   T   C  Heterozygous
# 3                           .  chr1     685694   T   C  Heterozygous
# 4                           .  chr1     685694   T   C  Heterozygous
# ...          ...          ...   ...        ...  ..  ..           ...
# 340652      IL9R    rs2037999  chrX  156003433   T   C    Homozygous
# 340653      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340654      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340655      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340656      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
#
#                                          Consequence    IMPACT ClinVar_CLNDN  \
# 0                                   missense variant  MODERATE
# 1                                 synonymous variant       LOW
# 2                            downstream gene variant  MODIFIER
# 3       intron variant,non coding transcript variant  MODIFIER
# 4       intron variant,non coding transcript variant  MODIFIER
# ...                                              ...       ...           ...
# 340652                     regulatory region variant  MODIFIER
# 340653                              missense variant  MODERATE  not provided
# 340654                           3 prime UTR variant  MODIFIER  not provided
# 340655                       downstream gene variant  MODIFIER  not provided
# 340656                       downstream gene variant  MODIFIER  not provided
#
#        CLIN_SIG                   ClinVar_CLNREVSTAT ClinVar  \
# 0
# 1
# 2
# 3
# 4
# ...         ...                                  ...     ...
# 340652
# 340653   benign  criteria provided, single submitter  771064
# 340654   benign  criteria provided, single submitter  771064
# 340655   benign  criteria provided, single submitter  771064
# 340656   benign  criteria provided, single submitter  771064
#
#                      HGVSc HGVSc (Transcript)              HGVSp  \
# 0        ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 1        ENST00000641515.2           c.870T>C  ENSP00000493376.2
# 2                                        None
# 3        ENST00000419394.2     n.480+17991A>G
# 4        ENST00000440200.5     n.169+34338A>G
# ...                    ...                ...                ...
# 340652                                   None
# 340653  ENST00000244174.11          c.1094G>A  ENSP00000244174.5
# 340654   ENST00000369423.7           c.*85G>A
# 340655                                   None
# 340656                                   None
#
#        HGVSp (Transcript)   GT   GQ  SDP   DP  RD   AD    FREQ        PVAL  \
# 0             p.Thr162Ala  1/1  255  120  120   0  120    100%  1.1001E-71
# 1             p.Ser290%3D  0/1   82   98   98  73   25  25.51%   5.1517E-9
# 2                    None  0/1   34   28   28  18   10  35.71%   3.6855E-4
# 3                    None  0/1   34   28   28  18   10  35.71%   3.6855E-4
# 4                    None  0/1   34   28   28  18   10  35.71%   3.6855E-4
# ...                   ...  ...  ...  ...  ...  ..  ...     ...         ...
# 340652               None  1/1   58   11   11   0   11    100%   1.4176E-6
# 340653        p.Arg365His  0/1   27   20   20  12    8     40%    1.638E-3
# 340654               None  0/1   27   20   20  12    8     40%    1.638E-3
# 340655               None  0/1   27   20   20  12    8     40%    1.638E-3
# 340656               None  0/1   27   20   20  12    8     40%    1.638E-3
#
#        RDF RDR ADF ADR             SIFT   PolyPhen      AF AFR_AF  AMR_AF  \
# 0        0   0  86  34  tolerated(0.92)  benign(0)
# 1       41  32  11  14                              0.6881  0.407  0.6254
# 2       17   1   9   1
# 3       17   1   9   1
# 4       17   1   9   1
# ...     ..  ..  ..  ..              ...        ...     ...    ...     ...
# 340652   0   0   7   4
# 340653  12   0   8   0  tolerated(0.56)  benign(0)
# 340654  12   0   8   0
# 340655  12   0   8   0
# 340656  12   0   8   0
#
#        EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF  \
# 0                                 0.9497         0.6075         0.9514
# 1       0.876  0.7942  0.8098     0.7209          0.307         0.6749
# 2
# 3
# 4
# ...       ...     ...     ...        ...            ...            ...
# 340652                             0.441         0.8217         0.3483
# 340653                           0.01405        0.02867       0.007828
# 340654                           0.01405        0.02867       0.007828
# 340655                           0.01405        0.02867       0.007828
# 340656                           0.01405        0.02867       0.007828
#
#        gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF  \
# 0              0.9767         0.9994         0.9916         0.9726
# 1              0.8131         0.7793         0.8652         0.8438
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652         0.4304          0.702         0.5274         0.3271
# 340653        0.01496        0.01587       0.005438       0.008185
# 340654        0.01496        0.01587       0.005438       0.008185
# 340655        0.01496        0.01587       0.005438       0.008185
# 340656        0.01496        0.01587       0.005438       0.008185
#
#        gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF  \
# 0              0.9506         0.9854      0.846         0.5948          0.998
# 1              0.7932         0.8049     0.4864         0.2916         0.6511
# 2
# 3
# 4
# ...               ...            ...        ...            ...            ...
# 340652         0.4035         0.5578     0.5073          0.809          0.356
# 340653        0.02348         0.0411    0.02864        0.03691        0.04154
# 340654        0.02348         0.0411    0.02864        0.03691        0.04154
# 340655        0.02348         0.0411    0.02864        0.03691        0.04154
# 340656        0.02348         0.0411    0.02864        0.03691        0.04154
#
#        gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF  \
# 0              0.8951         0.9784         0.9998         0.9907
# 1              0.4782         0.6714         0.6047         0.6987
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652         0.3772         0.4374         0.7099         0.5742
# 340653        0.01196        0.03051        0.02488         0.0722
# 340654        0.01196        0.03051        0.02488         0.0722
# 340655        0.01196        0.03051        0.02488         0.0722
# 340656        0.01196        0.03051        0.02488         0.0722
#
#        gnomADg_MID_AF gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  \
# 0                 0.9         0.9674         0.8624         0.9772  0.9998
# 1              0.6441         0.6751         0.4659          0.622   0.876
# 2
# 3
# 4
# ...               ...            ...            ...            ...     ...
# 340652         0.4209         0.3323         0.4516         0.5465  0.8217
# 340653        0.03478        0.02331        0.02312        0.04483  0.0722
# 340654        0.03478        0.02331        0.02312        0.04483  0.0722
# 340655        0.03478        0.02331        0.02312        0.04483  0.0722
# 340656        0.03478        0.02331        0.02312        0.04483  0.0722
#
#         MAX_AF_POPS                         BIOTYPE EXON INTRON  \
# 0       gnomADg EAS                  protein coding  3/3
# 1               EAS                  protein coding  3/3
# 2                                    protein coding
# 3                              processed transcript         3/3
# 4                              processed transcript         1/2
# ...             ...                             ...  ...    ...
# 340652  gnomADe AFR                        enhancer
# 340653  gnomADg FIN                  protein coding  9/9
# 340654  gnomADg FIN                  protein coding  9/9
# 340655  gnomADg FIN                          lncRNA
# 340656  gnomADg FIN  protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED  \
# 0                                T162A  Aca/Gca      1
# 1                                 S290  tcT/tcC      1
# 2                                  nan              -1
# 3                                  nan              -1
# 4                                  nan              -1
# ...                                ...      ...    ...    ...
# 340652                             nan
# 340653                           R365H  cGt/cAt      1
# 340654                             nan               1
# 340655                             nan              -1
# 340656                             nan               1
#
#                       consequence Consequence_score
# 0                missense variant              7/10
# 1              synonymous variant              3/10
# 2         downstream gene variant              2/10
# 3                  intron variant              2/10
# 4                  intron variant              2/10
# ...                           ...               ...
# 340652  regulatory region variant              2/10
# 340653           missense variant              7/10
# 340654        3 prime UTR variant              3/10
# 340655    downstream gene variant              2/10
# 340656    downstream gene variant              2/10
#
# [340657 rows x 68 columns]

# %%
df_2 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Madhu_folder_04_07_2023/kidney_health_final.vcf/IMPACT.xlsx')
df_2
# Out:
#      IMPACT  IMPACT_score
# 0      HIGH          10.0
# 1  MODERATE           5.0
# 2       LOW           2.5
# 3  MODIFIER           1.5

# %%
merged_2 = pd.merge(merged_1, df_2, on = 'IMPACT', how='left', sort=False)
merged_2
# Out:
#        Gene Name         rsID CHROM        POS REF ALT      Zygosity  \
# 0          OR4F5    rs2691305  chr1      69511   A   G    Homozygous
# 1          OR4F5  rs200676709  chr1      69897   T   C  Heterozygous
# 2                           .  chr1     685694   T   C  Heterozygous
# 3                           .  chr1     685694   T   C  Heterozygous
# 4                           .  chr1     685694   T   C  Heterozygous
# ...          ...          ...   ...        ...  ..  ..           ...
# 340652      IL9R    rs2037999  chrX  156003433   T   C    Homozygous
# 340653      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340654      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340655      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340656      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
#
#                                          Consequence    IMPACT ClinVar_CLNDN  \
# 0                                   missense variant  MODERATE
# 1                                 synonymous variant       LOW
# 2                            downstream gene variant  MODIFIER
# 3       intron variant,non coding transcript variant  MODIFIER
# 4       intron variant,non coding transcript variant  MODIFIER
# ...                                              ...       ...           ...
# 340652                     regulatory region variant  MODIFIER
# 340653                              missense variant  MODERATE  not provided
# 340654                           3 prime UTR variant  MODIFIER  not provided
# 340655                       downstream gene variant  MODIFIER  not provided
# 340656                       downstream gene variant  MODIFIER  not provided
#
#        CLIN_SIG                   ClinVar_CLNREVSTAT ClinVar  \
# 0
# 1
# 2
# 3
# 4
# ...         ...                                  ...     ...
# 340652
# 340653   benign  criteria provided, single submitter  771064
# 340654   benign  criteria provided, single submitter  771064
# 340655   benign  criteria provided, single submitter  771064
# 340656   benign  criteria provided, single submitter  771064
#
#                      HGVSc HGVSc (Transcript)              HGVSp  \
# 0        ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 1        ENST00000641515.2           c.870T>C  ENSP00000493376.2
# 2                                        None
# 3        ENST00000419394.2     n.480+17991A>G
# 4        ENST00000440200.5     n.169+34338A>G
# ...                    ...                ...                ...
# 340652                                   None
# 340653  ENST00000244174.11          c.1094G>A  ENSP00000244174.5
# 340654   ENST00000369423.7           c.*85G>A
# 340655                                   None
# 340656                                   None
#
#        HGVSp (Transcript)   GT   GQ  SDP   DP  RD   AD    FREQ        PVAL  \
# 0             p.Thr162Ala  1/1  255  120  120   0  120    100%  1.1001E-71
# 1             p.Ser290%3D  0/1   82   98   98  73   25  25.51%   5.1517E-9
# 2                    None  0/1   34   28   28  18   10  35.71%   3.6855E-4
# 3                    None  0/1   34   28   28  18   10  35.71%   3.6855E-4
# 4                    None  0/1   34   28   28  18   10  35.71%   3.6855E-4
# ...                   ...  ...  ...  ...  ...  ..  ...     ...         ...
# 340652               None  1/1   58   11   11   0   11    100%   1.4176E-6
# 340653        p.Arg365His  0/1   27   20   20  12    8     40%    1.638E-3
# 340654               None  0/1   27   20   20  12    8     40%    1.638E-3
# 340655               None  0/1   27   20   20  12    8     40%    1.638E-3
# 340656               None  0/1   27   20   20  12    8     40%    1.638E-3
#
#        RDF RDR ADF ADR             SIFT   PolyPhen      AF AFR_AF  AMR_AF  \
# 0        0   0  86  34  tolerated(0.92)  benign(0)
# 1       41  32  11  14                              0.6881  0.407  0.6254
# 2       17   1   9   1
# 3       17   1   9   1
# 4       17   1   9   1
# ...     ..  ..  ..  ..              ...        ...     ...    ...     ...
# 340652   0   0   7   4
# 340653  12   0   8   0  tolerated(0.56)  benign(0)
# 340654  12   0   8   0
# 340655  12   0   8   0
# 340656  12   0   8   0
#
#        EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF  \
# 0                                 0.9497         0.6075         0.9514
# 1       0.876  0.7942  0.8098     0.7209          0.307         0.6749
# 2
# 3
# 4
# ...       ...     ...     ...        ...            ...            ...
# 340652                             0.441         0.8217         0.3483
# 340653                           0.01405        0.02867       0.007828
# 340654                           0.01405        0.02867       0.007828
# 340655                           0.01405        0.02867       0.007828
# 340656                           0.01405        0.02867       0.007828
#
#        gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF  \
# 0              0.9767         0.9994         0.9916         0.9726
# 1              0.8131         0.7793         0.8652         0.8438
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652         0.4304          0.702         0.5274         0.3271
# 340653        0.01496        0.01587       0.005438       0.008185
# 340654        0.01496        0.01587       0.005438       0.008185
# 340655        0.01496        0.01587       0.005438       0.008185
# 340656        0.01496        0.01587       0.005438       0.008185
#
#        gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF  \
# 0              0.9506         0.9854      0.846         0.5948          0.998
# 1              0.7932         0.8049     0.4864         0.2916         0.6511
# 2
# 3
# 4
# ...               ...            ...        ...            ...            ...
# 340652         0.4035         0.5578     0.5073          0.809          0.356
# 340653        0.02348         0.0411    0.02864        0.03691        0.04154
# 340654        0.02348         0.0411    0.02864        0.03691        0.04154
# 340655        0.02348         0.0411    0.02864        0.03691        0.04154
# 340656        0.02348         0.0411    0.02864        0.03691        0.04154
#
#        gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF  \
# 0              0.8951         0.9784         0.9998         0.9907
# 1              0.4782         0.6714         0.6047         0.6987
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652         0.3772         0.4374         0.7099         0.5742
# 340653        0.01196        0.03051        0.02488         0.0722
# 340654        0.01196        0.03051        0.02488         0.0722
# 340655        0.01196        0.03051        0.02488         0.0722
# 340656        0.01196        0.03051        0.02488         0.0722
#
#        gnomADg_MID_AF gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  \
# 0                 0.9         0.9674         0.8624         0.9772  0.9998
# 1              0.6441         0.6751         0.4659          0.622   0.876
# 2
# 3
# 4
# ...               ...            ...            ...            ...     ...
# 340652         0.4209         0.3323         0.4516         0.5465  0.8217
# 340653        0.03478        0.02331        0.02312        0.04483  0.0722
# 340654        0.03478        0.02331        0.02312        0.04483  0.0722
# 340655        0.03478        0.02331        0.02312        0.04483  0.0722
# 340656        0.03478        0.02331        0.02312        0.04483  0.0722
#
#         MAX_AF_POPS                         BIOTYPE EXON INTRON  \
# 0       gnomADg EAS                  protein coding  3/3
# 1               EAS                  protein coding  3/3
# 2                                    protein coding
# 3                              processed transcript         3/3
# 4                              processed transcript         1/2
# ...             ...                             ...  ...    ...
# 340652  gnomADe AFR                        enhancer
# 340653  gnomADg FIN                  protein coding  9/9
# 340654  gnomADg FIN                  protein coding  9/9
# 340655  gnomADg FIN                          lncRNA
# 340656  gnomADg FIN  protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED  \
# 0                                T162A  Aca/Gca      1
# 1                                 S290  tcT/tcC      1
# 2                                  nan              -1
# 3                                  nan              -1
# 4                                  nan              -1
# ...                                ...      ...    ...    ...
# 340652                             nan
# 340653                           R365H  cGt/cAt      1
# 340654                             nan               1
# 340655                             nan              -1
# 340656                             nan               1
#
#                       consequence Consequence_score  IMPACT_score
# 0                missense variant              7/10           5.0
# 1              synonymous variant              3/10           2.5
# 2         downstream gene variant              2/10           1.5
# 3                  intron variant              2/10           1.5
# 4                  intron variant              2/10           1.5
# ...                           ...               ...           ...
# 340652  regulatory region variant              2/10           1.5
# 340653           missense variant              7/10           5.0
# 340654        3 prime UTR variant              3/10           1.5
# 340655    downstream gene variant              2/10           1.5
# 340656    downstream gene variant              2/10           1.5
#
# [340657 rows x 69 columns]

# %%
merged_2 = merged_2[['Gene Name', 'rsID', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
       'Consequence','Consequence_score', 'IMPACT', 'IMPACT_score', 'ClinVar_CLNDN', 'CLIN_SIG',
       'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc', 'HGVSc (Transcript)', 'HGVSp',
       'HGVSp (Transcript)', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ',
       'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT', 'PolyPhen', 'AF', 'AFR_AF',
       'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF', 'gnomADe_AF', 'gnomADe_AFR_AF',
       'gnomADe_AMR_AF', 'gnomADe_ASJ_AF', 'gnomADe_EAS_AF', 'gnomADe_FIN_AF',
       'gnomADe_NFE_AF', 'gnomADe_OTH_AF', 'gnomADe_SAS_AF', 'gnomADg_AF',
       'gnomADg_AFR_AF', 'gnomADg_AMI_AF', 'gnomADg_AMR_AF', 'gnomADg_ASJ_AF',
       'gnomADg_EAS_AF', 'gnomADg_FIN_AF', 'gnomADg_MID_AF', 'gnomADg_NFE_AF',
       'gnomADg_OTH_AF', 'gnomADg_SAS_AF', 'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE',
       'EXON', 'INTRON', 'Protein Position and Amino Acid', 'Codons', 'STRAND',
       'PUBMED']]
merged_2
# Out:
#        Gene Name         rsID CHROM        POS REF ALT      Zygosity  \
# 0          OR4F5    rs2691305  chr1      69511   A   G    Homozygous
# 1          OR4F5  rs200676709  chr1      69897   T   C  Heterozygous
# 2                           .  chr1     685694   T   C  Heterozygous
# 3                           .  chr1     685694   T   C  Heterozygous
# 4                           .  chr1     685694   T   C  Heterozygous
# ...          ...          ...   ...        ...  ..  ..           ...
# 340652      IL9R    rs2037999  chrX  156003433   T   C    Homozygous
# 340653      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340654      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340655      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340656      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
#
#                                          Consequence Consequence_score  \
# 0                                   missense variant              7/10
# 1                                 synonymous variant              3/10
# 2                            downstream gene variant              2/10
# 3       intron variant,non coding transcript variant              2/10
# 4       intron variant,non coding transcript variant              2/10
# ...                                              ...               ...
# 340652                     regulatory region variant              2/10
# 340653                              missense variant              7/10
# 340654                           3 prime UTR variant              3/10
# 340655                       downstream gene variant              2/10
# 340656                       downstream gene variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG  \
# 0       MODERATE           5.0
# 1            LOW           2.5
# 2       MODIFIER           1.5
# 3       MODIFIER           1.5
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...
# 340652  MODIFIER           1.5
# 340653  MODERATE           5.0  not provided   benign
# 340654  MODIFIER           1.5  not provided   benign
# 340655  MODIFIER           1.5  not provided   benign
# 340656  MODIFIER           1.5  not provided   benign
#
#                          ClinVar_CLNREVSTAT ClinVar               HGVSc  \
# 0                                                     ENST00000641515.2
# 1                                                     ENST00000641515.2
# 2
# 3                                                     ENST00000419394.2
# 4                                                     ENST00000440200.5
# ...                                     ...     ...                 ...
# 340652
# 340653  criteria provided, single submitter  771064  ENST00000244174.11
# 340654  criteria provided, single submitter  771064   ENST00000369423.7
# 340655  criteria provided, single submitter  771064
# 340656  criteria provided, single submitter  771064
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  \
# 0                c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255
# 1                c.870T>C  ENSP00000493376.2        p.Ser290%3D  0/1   82
# 2                    None                                  None  0/1   34
# 3          n.480+17991A>G                                  None  0/1   34
# 4          n.169+34338A>G                                  None  0/1   34
# ...                   ...                ...                ...  ...  ...
# 340652               None                                  None  1/1   58
# 340653          c.1094G>A  ENSP00000244174.5        p.Arg365His  0/1   27
# 340654           c.*85G>A                                  None  0/1   27
# 340655               None                                  None  0/1   27
# 340656               None                                  None  0/1   27
#
#         SDP   DP  RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0       120  120   0  120    100%  1.1001E-71   0   0  86  34
# 1        98   98  73   25  25.51%   5.1517E-9  41  32  11  14
# 2        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 3        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 4        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# ...     ...  ...  ..  ...     ...         ...  ..  ..  ..  ..
# 340652   11   11   0   11    100%   1.4176E-6   0   0   7   4
# 340653   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340654   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340655   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340656   20   20  12    8     40%    1.638E-3  12   0   8   0
#
#                    SIFT   PolyPhen      AF AFR_AF  AMR_AF EAS_AF  EUR_AF  \
# 0       tolerated(0.92)  benign(0)
# 1                                   0.6881  0.407  0.6254  0.876  0.7942
# 2
# 3
# 4
# ...                 ...        ...     ...    ...     ...    ...     ...
# 340652
# 340653  tolerated(0.56)  benign(0)
# 340654
# 340655
# 340656
#
#         SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF  \
# 0                  0.9497         0.6075         0.9514         0.9767
# 1       0.8098     0.7209          0.307         0.6749         0.8131
# 2
# 3
# 4
# ...        ...        ...            ...            ...            ...
# 340652              0.441         0.8217         0.3483         0.4304
# 340653            0.01405        0.02867       0.007828        0.01496
# 340654            0.01405        0.02867       0.007828        0.01496
# 340655            0.01405        0.02867       0.007828        0.01496
# 340656            0.01405        0.02867       0.007828        0.01496
#
#        gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0              0.9994         0.9916         0.9726         0.9506
# 1              0.7793         0.8652         0.8438         0.7932
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652          0.702         0.5274         0.3271         0.4035
# 340653        0.01587       0.005438       0.008185        0.02348
# 340654        0.01587       0.005438       0.008185        0.02348
# 340655        0.01587       0.005438       0.008185        0.02348
# 340656        0.01587       0.005438       0.008185        0.02348
#
#        gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0              0.9854      0.846         0.5948          0.998         0.8951
# 1              0.8049     0.4864         0.2916         0.6511         0.4782
# 2
# 3
# 4
# ...               ...        ...            ...            ...            ...
# 340652         0.5578     0.5073          0.809          0.356         0.3772
# 340653         0.0411    0.02864        0.03691        0.04154        0.01196
# 340654         0.0411    0.02864        0.03691        0.04154        0.01196
# 340655         0.0411    0.02864        0.03691        0.04154        0.01196
# 340656         0.0411    0.02864        0.03691        0.04154        0.01196
#
#        gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0              0.9784         0.9998         0.9907            0.9
# 1              0.6714         0.6047         0.6987         0.6441
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652         0.4374         0.7099         0.5742         0.4209
# 340653        0.03051        0.02488         0.0722        0.03478
# 340654        0.03051        0.02488         0.0722        0.03478
# 340655        0.03051        0.02488         0.0722        0.03478
# 340656        0.03051        0.02488         0.0722        0.03478
#
#        gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0              0.9674         0.8624         0.9772  0.9998  gnomADg EAS
# 1              0.6751         0.4659          0.622   0.876          EAS
# 2
# 3
# 4
# ...               ...            ...            ...     ...          ...
# 340652         0.3323         0.4516         0.5465  0.8217  gnomADe AFR
# 340653        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340654        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340655        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340656        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
#
#                                BIOTYPE EXON INTRON  \
# 0                       protein coding  3/3
# 1                       protein coding  3/3
# 2                       protein coding
# 3                 processed transcript         3/3
# 4                 processed transcript         1/2
# ...                                ...  ...    ...
# 340652                        enhancer
# 340653                  protein coding  9/9
# 340654                  protein coding  9/9
# 340655                          lncRNA
# 340656  protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED
# 0                                T162A  Aca/Gca      1
# 1                                 S290  tcT/tcC      1
# 2                                  nan              -1
# 3                                  nan              -1
# 4                                  nan              -1
# ...                                ...      ...    ...    ...
# 340652                             nan
# 340653                           R365H  cGt/cAt      1
# 340654                             nan               1
# 340655                             nan              -1
# 340656                             nan               1
#
# [340657 rows x 68 columns]

# %%
df_gene = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Park_cere_genes.xlsx')
df_gene
# Out:
#    Gene Name        Gene_Match
# 0       MYO6         Parkinson
# 1       GBA1         Parkinson
# 2       PRKN         Parkinson
# 3      MRE11         Parkinson
# 4      LRRK2         Parkinson
# ..       ...               ...
# 79      CLN1  Cerebellarataxia
# 80      CLN2  Cerebellarataxia
# 81      CLN3  Cerebellarataxia
# 82      PHYH  Cerebellarataxia
# 83      PEX7  Cerebellarataxia
#
# [84 rows x 2 columns]

# %%
merged_2['Gene Match'] = 'No'
merged_2['Matched_Gene'] = ''
    
# Iterate through each gene in vcf['Gene']
for index, genes in merged_2['Gene Name'].iteritems():
    if isinstance(genes, str):
        gene_list = genes.split(',')
        for gene in gene_list:
            if gene in df_gene['Gene Name'].values:
                merged_2.at[index, 'Gene Match'] = 'Yes'
                merged_2.at[index, 'Matched_Gene'] = gene
                break
    
merged_2
# Out:
#        Gene Name         rsID CHROM        POS REF ALT      Zygosity  \
# 0          OR4F5    rs2691305  chr1      69511   A   G    Homozygous
# 1          OR4F5  rs200676709  chr1      69897   T   C  Heterozygous
# 2                           .  chr1     685694   T   C  Heterozygous
# 3                           .  chr1     685694   T   C  Heterozygous
# 4                           .  chr1     685694   T   C  Heterozygous
# ...          ...          ...   ...        ...  ..  ..           ...
# 340652      IL9R    rs2037999  chrX  156003433   T   C    Homozygous
# 340653      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340654      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340655      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340656      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
#
#                                          Consequence Consequence_score  \
# 0                                   missense variant              7/10
# 1                                 synonymous variant              3/10
# 2                            downstream gene variant              2/10
# 3       intron variant,non coding transcript variant              2/10
# 4       intron variant,non coding transcript variant              2/10
# ...                                              ...               ...
# 340652                     regulatory region variant              2/10
# 340653                              missense variant              7/10
# 340654                           3 prime UTR variant              3/10
# 340655                       downstream gene variant              2/10
# 340656                       downstream gene variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG  \
# 0       MODERATE           5.0
# 1            LOW           2.5
# 2       MODIFIER           1.5
# 3       MODIFIER           1.5
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...
# 340652  MODIFIER           1.5
# 340653  MODERATE           5.0  not provided   benign
# 340654  MODIFIER           1.5  not provided   benign
# 340655  MODIFIER           1.5  not provided   benign
# 340656  MODIFIER           1.5  not provided   benign
#
#                          ClinVar_CLNREVSTAT ClinVar               HGVSc  \
# 0                                                     ENST00000641515.2
# 1                                                     ENST00000641515.2
# 2
# 3                                                     ENST00000419394.2
# 4                                                     ENST00000440200.5
# ...                                     ...     ...                 ...
# 340652
# 340653  criteria provided, single submitter  771064  ENST00000244174.11
# 340654  criteria provided, single submitter  771064   ENST00000369423.7
# 340655  criteria provided, single submitter  771064
# 340656  criteria provided, single submitter  771064
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  \
# 0                c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255
# 1                c.870T>C  ENSP00000493376.2        p.Ser290%3D  0/1   82
# 2                    None                                  None  0/1   34
# 3          n.480+17991A>G                                  None  0/1   34
# 4          n.169+34338A>G                                  None  0/1   34
# ...                   ...                ...                ...  ...  ...
# 340652               None                                  None  1/1   58
# 340653          c.1094G>A  ENSP00000244174.5        p.Arg365His  0/1   27
# 340654           c.*85G>A                                  None  0/1   27
# 340655               None                                  None  0/1   27
# 340656               None                                  None  0/1   27
#
#         SDP   DP  RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0       120  120   0  120    100%  1.1001E-71   0   0  86  34
# 1        98   98  73   25  25.51%   5.1517E-9  41  32  11  14
# 2        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 3        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 4        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# ...     ...  ...  ..  ...     ...         ...  ..  ..  ..  ..
# 340652   11   11   0   11    100%   1.4176E-6   0   0   7   4
# 340653   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340654   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340655   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340656   20   20  12    8     40%    1.638E-3  12   0   8   0
#
#                    SIFT   PolyPhen      AF AFR_AF  AMR_AF EAS_AF  EUR_AF  \
# 0       tolerated(0.92)  benign(0)
# 1                                   0.6881  0.407  0.6254  0.876  0.7942
# 2
# 3
# 4
# ...                 ...        ...     ...    ...     ...    ...     ...
# 340652
# 340653  tolerated(0.56)  benign(0)
# 340654
# 340655
# 340656
#
#         SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF  \
# 0                  0.9497         0.6075         0.9514         0.9767
# 1       0.8098     0.7209          0.307         0.6749         0.8131
# 2
# 3
# 4
# ...        ...        ...            ...            ...            ...
# 340652              0.441         0.8217         0.3483         0.4304
# 340653            0.01405        0.02867       0.007828        0.01496
# 340654            0.01405        0.02867       0.007828        0.01496
# 340655            0.01405        0.02867       0.007828        0.01496
# 340656            0.01405        0.02867       0.007828        0.01496
#
#        gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0              0.9994         0.9916         0.9726         0.9506
# 1              0.7793         0.8652         0.8438         0.7932
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652          0.702         0.5274         0.3271         0.4035
# 340653        0.01587       0.005438       0.008185        0.02348
# 340654        0.01587       0.005438       0.008185        0.02348
# 340655        0.01587       0.005438       0.008185        0.02348
# 340656        0.01587       0.005438       0.008185        0.02348
#
#        gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0              0.9854      0.846         0.5948          0.998         0.8951
# 1              0.8049     0.4864         0.2916         0.6511         0.4782
# 2
# 3
# 4
# ...               ...        ...            ...            ...            ...
# 340652         0.5578     0.5073          0.809          0.356         0.3772
# 340653         0.0411    0.02864        0.03691        0.04154        0.01196
# 340654         0.0411    0.02864        0.03691        0.04154        0.01196
# 340655         0.0411    0.02864        0.03691        0.04154        0.01196
# 340656         0.0411    0.02864        0.03691        0.04154        0.01196
#
#        gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0              0.9784         0.9998         0.9907            0.9
# 1              0.6714         0.6047         0.6987         0.6441
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652         0.4374         0.7099         0.5742         0.4209
# 340653        0.03051        0.02488         0.0722        0.03478
# 340654        0.03051        0.02488         0.0722        0.03478
# 340655        0.03051        0.02488         0.0722        0.03478
# 340656        0.03051        0.02488         0.0722        0.03478
#
#        gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0              0.9674         0.8624         0.9772  0.9998  gnomADg EAS
# 1              0.6751         0.4659          0.622   0.876          EAS
# 2
# 3
# 4
# ...               ...            ...            ...     ...          ...
# 340652         0.3323         0.4516         0.5465  0.8217  gnomADe AFR
# 340653        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340654        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340655        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340656        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
#
#                                BIOTYPE EXON INTRON  \
# 0                       protein coding  3/3
# 1                       protein coding  3/3
# 2                       protein coding
# 3                 processed transcript         3/3
# 4                 processed transcript         1/2
# ...                                ...  ...    ...
# 340652                        enhancer
# 340653                  protein coding  9/9
# 340654                  protein coding  9/9
# 340655                          lncRNA
# 340656  protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED Gene Match  \
# 0                                T162A  Aca/Gca      1                No
# 1                                 S290  tcT/tcC      1                No
# 2                                  nan              -1                No
# 3                                  nan              -1                No
# 4                                  nan              -1                No
# ...                                ...      ...    ...    ...        ...
# 340652                             nan                                No
# 340653                           R365H  cGt/cAt      1                No
# 340654                             nan               1                No
# 340655                             nan              -1                No
# 340656                             nan               1                No
#
#        Matched_Gene
# 0
# 1
# 2
# 3
# 4
# ...             ...
# 340652
# 340653
# 340654
# 340655
# 340656
#
# [340657 rows x 70 columns]

# %%
df_gene = df_gene.rename({'Gene Name':'Matched_Gene', 'Gene_Match':'Gene Match'}, axis=1)
df_gene
# Out:
#    Matched_Gene        Gene Match
# 0          MYO6         Parkinson
# 1          GBA1         Parkinson
# 2          PRKN         Parkinson
# 3         MRE11         Parkinson
# 4         LRRK2         Parkinson
# ..          ...               ...
# 79         CLN1  Cerebellarataxia
# 80         CLN2  Cerebellarataxia
# 81         CLN3  Cerebellarataxia
# 82         PHYH  Cerebellarataxia
# 83         PEX7  Cerebellarataxia
#
# [84 rows x 2 columns]

# %%
merged_2.columns
# Out:
# Index(['Gene Name', 'rsID', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
#        'Consequence', 'Consequence_score', 'IMPACT', 'IMPACT_score',
#        'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc',
#        'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP',
#        'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT',
#        'PolyPhen', 'AF', 'AFR_AF', 'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF',
#        'gnomADe_AF', 'gnomADe_AFR_AF', 'gnomADe_AMR_AF', 'gnomADe_ASJ_AF',
#        'gnomADe_EAS_AF', 'gnomADe_FIN_AF', 'gnomADe_NFE_AF', 'gnomADe_OTH_AF',
#        'gnomADe_SAS_AF', 'gnomADg_AF', 'gnomADg_AFR_AF', 'gnomADg_AMI_AF',
#        'gnomADg_AMR_AF', 'gnomADg_ASJ_AF', 'gnomADg_EAS_AF', 'gnomADg_FIN_AF',
#        'gnomADg_MID_AF', 'gnomADg_NFE_AF', 'gnomADg_OTH_AF', 'gnomADg_SAS_AF',
#        'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE', 'EXON', 'INTRON',
#        'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED',
#        'Gene_Match', 'Matched_Gene', 'Gene Match_x', 'Gene Match_y'],
#       dtype='object')

# %%
# Out:
#        Gene Name         rsID CHROM        POS REF ALT      Zygosity  \
# 0          OR4F5    rs2691305  chr1      69511   A   G    Homozygous
# 1          OR4F5  rs200676709  chr1      69897   T   C  Heterozygous
# 2                           .  chr1     685694   T   C  Heterozygous
# 3                           .  chr1     685694   T   C  Heterozygous
# 4                           .  chr1     685694   T   C  Heterozygous
# ...          ...          ...   ...        ...  ..  ..           ...
# 340652      IL9R    rs2037999  chrX  156003433   T   C    Homozygous
# 340653      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340654      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340655      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340656      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
#
#                                          Consequence Consequence_score  \
# 0                                   missense variant              7/10
# 1                                 synonymous variant              3/10
# 2                            downstream gene variant              2/10
# 3       intron variant,non coding transcript variant              2/10
# 4       intron variant,non coding transcript variant              2/10
# ...                                              ...               ...
# 340652                     regulatory region variant              2/10
# 340653                              missense variant              7/10
# 340654                           3 prime UTR variant              3/10
# 340655                       downstream gene variant              2/10
# 340656                       downstream gene variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG  \
# 0       MODERATE           5.0
# 1            LOW           2.5
# 2       MODIFIER           1.5
# 3       MODIFIER           1.5
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...
# 340652  MODIFIER           1.5
# 340653  MODERATE           5.0  not provided   benign
# 340654  MODIFIER           1.5  not provided   benign
# 340655  MODIFIER           1.5  not provided   benign
# 340656  MODIFIER           1.5  not provided   benign
#
#                          ClinVar_CLNREVSTAT ClinVar               HGVSc  \
# 0                                                     ENST00000641515.2
# 1                                                     ENST00000641515.2
# 2
# 3                                                     ENST00000419394.2
# 4                                                     ENST00000440200.5
# ...                                     ...     ...                 ...
# 340652
# 340653  criteria provided, single submitter  771064  ENST00000244174.11
# 340654  criteria provided, single submitter  771064   ENST00000369423.7
# 340655  criteria provided, single submitter  771064
# 340656  criteria provided, single submitter  771064
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  \
# 0                c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255
# 1                c.870T>C  ENSP00000493376.2        p.Ser290%3D  0/1   82
# 2                    None                                  None  0/1   34
# 3          n.480+17991A>G                                  None  0/1   34
# 4          n.169+34338A>G                                  None  0/1   34
# ...                   ...                ...                ...  ...  ...
# 340652               None                                  None  1/1   58
# 340653          c.1094G>A  ENSP00000244174.5        p.Arg365His  0/1   27
# 340654           c.*85G>A                                  None  0/1   27
# 340655               None                                  None  0/1   27
# 340656               None                                  None  0/1   27
#
#         SDP   DP  RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0       120  120   0  120    100%  1.1001E-71   0   0  86  34
# 1        98   98  73   25  25.51%   5.1517E-9  41  32  11  14
# 2        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 3        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 4        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# ...     ...  ...  ..  ...     ...         ...  ..  ..  ..  ..
# 340652   11   11   0   11    100%   1.4176E-6   0   0   7   4
# 340653   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340654   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340655   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340656   20   20  12    8     40%    1.638E-3  12   0   8   0
#
#                    SIFT   PolyPhen      AF AFR_AF  AMR_AF EAS_AF  EUR_AF  \
# 0       tolerated(0.92)  benign(0)
# 1                                   0.6881  0.407  0.6254  0.876  0.7942
# 2
# 3
# 4
# ...                 ...        ...     ...    ...     ...    ...     ...
# 340652
# 340653  tolerated(0.56)  benign(0)
# 340654
# 340655
# 340656
#
#         SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF  \
# 0                  0.9497         0.6075         0.9514         0.9767
# 1       0.8098     0.7209          0.307         0.6749         0.8131
# 2
# 3
# 4
# ...        ...        ...            ...            ...            ...
# 340652              0.441         0.8217         0.3483         0.4304
# 340653            0.01405        0.02867       0.007828        0.01496
# 340654            0.01405        0.02867       0.007828        0.01496
# 340655            0.01405        0.02867       0.007828        0.01496
# 340656            0.01405        0.02867       0.007828        0.01496
#
#        gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0              0.9994         0.9916         0.9726         0.9506
# 1              0.7793         0.8652         0.8438         0.7932
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652          0.702         0.5274         0.3271         0.4035
# 340653        0.01587       0.005438       0.008185        0.02348
# 340654        0.01587       0.005438       0.008185        0.02348
# 340655        0.01587       0.005438       0.008185        0.02348
# 340656        0.01587       0.005438       0.008185        0.02348
#
#        gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0              0.9854      0.846         0.5948          0.998         0.8951
# 1              0.8049     0.4864         0.2916         0.6511         0.4782
# 2
# 3
# 4
# ...               ...        ...            ...            ...            ...
# 340652         0.5578     0.5073          0.809          0.356         0.3772
# 340653         0.0411    0.02864        0.03691        0.04154        0.01196
# 340654         0.0411    0.02864        0.03691        0.04154        0.01196
# 340655         0.0411    0.02864        0.03691        0.04154        0.01196
# 340656         0.0411    0.02864        0.03691        0.04154        0.01196
#
#        gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0              0.9784         0.9998         0.9907            0.9
# 1              0.6714         0.6047         0.6987         0.6441
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652         0.4374         0.7099         0.5742         0.4209
# 340653        0.03051        0.02488         0.0722        0.03478
# 340654        0.03051        0.02488         0.0722        0.03478
# 340655        0.03051        0.02488         0.0722        0.03478
# 340656        0.03051        0.02488         0.0722        0.03478
#
#        gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0              0.9674         0.8624         0.9772  0.9998  gnomADg EAS
# 1              0.6751         0.4659          0.622   0.876          EAS
# 2
# 3
# 4
# ...               ...            ...            ...     ...          ...
# 340652         0.3323         0.4516         0.5465  0.8217  gnomADe AFR
# 340653        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340654        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340655        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340656        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
#
#                                BIOTYPE EXON INTRON  \
# 0                       protein coding  3/3
# 1                       protein coding  3/3
# 2                       protein coding
# 3                 processed transcript         3/3
# 4                 processed transcript         1/2
# ...                                ...  ...    ...
# 340652                        enhancer
# 340653                  protein coding  9/9
# 340654                  protein coding  9/9
# 340655                          lncRNA
# 340656  protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED Gene_Match  \
# 0                                T162A  Aca/Gca      1                No
# 1                                 S290  tcT/tcC      1                No
# 2                                  nan              -1                No
# 3                                  nan              -1                No
# 4                                  nan              -1                No
# ...                                ...      ...    ...    ...        ...
# 340652                             nan                                No
# 340653                           R365H  cGt/cAt      1                No
# 340654                             nan               1                No
# 340655                             nan              -1                No
# 340656                             nan               1                No
#
#        Matched_Gene Gene Match_x Gene Match_y Gene Match
# 0                            NaN          NaN        NaN
# 1                            NaN          NaN        NaN
# 2                            NaN          NaN        NaN
# 3                            NaN          NaN        NaN
# 4                            NaN          NaN        NaN
# ...             ...          ...          ...        ...
# 340652                       NaN          NaN        NaN
# 340653                       NaN          NaN        NaN
# 340654                       NaN          NaN        NaN
# 340655                       NaN          NaN        NaN
# 340656                       NaN          NaN        NaN
#
# [340657 rows x 73 columns]

# %%
merged_2[merged_2['Gene Match'] == 'Yes']
# Out:
#        Gene Name       rsID CHROM        POS REF ALT      Zygosity  \
# 3631       PARK7  rs2640906  chr1    7969449   G   A    Homozygous
# 3632       PARK7  rs2640906  chr1    7969449   G   A    Homozygous
# 3633       PARK7  rs2640906  chr1    7969449   G   A    Homozygous
# 3634       PARK7  rs2640906  chr1    7969449   G   A    Homozygous
# 3635       PARK7  rs2640906  chr1    7969449   G   A    Homozygous
# ...          ...        ...   ...        ...  ..  ..           ...
# 339719     ABCD1    rs11803  chrX  153744612   C   T    Homozygous
# 339720     ABCD1  rs1055847  chrX  153744629   G   A  Heterozygous
# 339721     ABCD1  rs1055847  chrX  153744629   G   A  Heterozygous
# 339722     ABCD1  rs1055847  chrX  153744629   G   A  Heterozygous
# 339723     ABCD1  rs1055847  chrX  153744629   G   A  Heterozygous
#
#                                          Consequence Consequence_score  \
# 3631                                  intron variant              2/10
# 3632                                  intron variant              2/10
# 3633                                  intron variant              2/10
# 3634                                  intron variant              2/10
# 3635    intron variant,non coding transcript variant              2/10
# ...                                              ...               ...
# 339719                       TF binding site variant              2/10
# 339720                           3 prime UTR variant              3/10
# 339721  intron variant,non coding transcript variant              2/10
# 339722                       downstream gene variant              2/10
# 339723                     regulatory region variant              2/10
#
#           IMPACT  IMPACT_score         ClinVar_CLNDN CLIN_SIG  \
# 3631    MODIFIER           1.5          not provided   benign
# 3632    MODIFIER           1.5          not provided   benign
# 3633    MODIFIER           1.5          not provided   benign
# 3634    MODIFIER           1.5          not provided   benign
# 3635    MODIFIER           1.5          not provided   benign
# ...          ...           ...                   ...      ...
# 339719  MODIFIER           1.5  Adrenoleukodystrophy   benign
# 339720  MODIFIER           1.5  Adrenoleukodystrophy   benign
# 339721  MODIFIER           1.5  Adrenoleukodystrophy   benign
# 339722  MODIFIER           1.5  Adrenoleukodystrophy   benign
# 339723  MODIFIER           1.5  Adrenoleukodystrophy   benign
#
#                          ClinVar_CLNREVSTAT  ClinVar               HGVSc  \
# 3631    criteria provided, single submitter  1267406  ENST00000338639.10
# 3632    criteria provided, single submitter  1267406   ENST00000377488.5
# 3633    criteria provided, single submitter  1267406   ENST00000377491.5
# 3634    criteria provided, single submitter  1267406   ENST00000377493.9
# 3635    criteria provided, single submitter  1267406   ENST00000460192.5
# ...                                     ...      ...                 ...
# 339719  criteria provided, single submitter   368066
# 339720  criteria provided, single submitter   368067   ENST00000218104.6
# 339721  criteria provided, single submitter   368067   ENST00000434284.1
# 339722  criteria provided, single submitter   368067
# 339723  criteria provided, single submitter   368067
#
#        HGVSc (Transcript) HGVSp HGVSp (Transcript)   GT   GQ SDP  DP  RD  AD  \
# 3631          c.252+45G>A                     None  1/1  126  27  25   1  24
# 3632          c.252+45G>A                     None  1/1  126  27  25   1  24
# 3633          c.252+45G>A                     None  1/1  126  27  25   1  24
# 3634        c.193-1445G>A                     None  1/1  126  27  25   1  24
# 3635          n.412+45G>A                     None  1/1  126  27  25   1  24
# ...                   ...   ...                ...  ...  ...  ..  ..  ..  ..
# 339719               None                     None  1/1  255  68  68   0  68
# 339720          c.*894G>A                     None  0/1  122  58  58  26  32
# 339721       n.72-6051C>T                     None  0/1  122  58  58  26  32
# 339722               None                     None  0/1  122  58  58  26  32
# 339723               None                     None  0/1  122  58  58  26  32
#
#           FREQ        PVAL RDF RDR ADF ADR SIFT PolyPhen      AF  AFR_AF  \
# 3631       96%  2.0568E-13   1   0  13  11                0.3323  0.3472
# 3632       96%  2.0568E-13   1   0  13  11                0.3323  0.3472
# 3633       96%  2.0568E-13   1   0  13  11                0.3323  0.3472
# 3634       96%  2.0568E-13   1   0  13  11                0.3323  0.3472
# 3635       96%  2.0568E-13   1   0  13  11                0.3323  0.3472
# ...        ...         ...  ..  ..  ..  ..  ...      ...     ...     ...
# 339719    100%  1.6809E-40   0   0  46  22                0.7311  0.8784
# 339720  55.17%   5.693E-13  19   7  20  12                0.4599  0.1944
# 339721  55.17%   5.693E-13  19   7  20  12                0.4599  0.1944
# 339722  55.17%   5.693E-13  19   7  20  12                0.4599  0.1944
# 339723  55.17%   5.693E-13  19   7  20  12                0.4599  0.1944
#
#         AMR_AF  EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF  \
# 3631    0.3689  0.6508   0.163  0.1319     0.2549         0.3386
# 3632    0.3689  0.6508   0.163  0.1319     0.2549         0.3386
# 3633    0.3689  0.6508   0.163  0.1319     0.2549         0.3386
# 3634    0.3689  0.6508   0.163  0.1319     0.2549         0.3386
# 3635    0.3689  0.6508   0.163  0.1319     0.2549         0.3386
# ...        ...     ...     ...     ...        ...            ...
# 339719  0.7309  0.6008  0.6149  0.7883
# 339720  0.6069  0.4921  0.5196  0.6253
# 339721  0.6069  0.4921  0.5196  0.6253
# 339722  0.6069  0.4921  0.5196  0.6253
# 339723  0.6069  0.4921  0.5196  0.6253
#
#        gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF  \
# 3631           0.4742        0.08915         0.6243         0.2772
# 3632           0.4742        0.08915         0.6243         0.2772
# 3633           0.4742        0.08915         0.6243         0.2772
# 3634           0.4742        0.08915         0.6243         0.2772
# 3635           0.4742        0.08915         0.6243         0.2772
# ...               ...            ...            ...            ...
# 339719
# 339720
# 339721
# 339722
# 339723
#
#        gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF  \
# 3631           0.1654         0.2089         0.1092     0.2623         0.3352
# 3632           0.1654         0.2089         0.1092     0.2623         0.3352
# 3633           0.1654         0.2089         0.1092     0.2623         0.3352
# 3634           0.1654         0.2089         0.1092     0.2623         0.3352
# 3635           0.1654         0.2089         0.1092     0.2623         0.3352
# ...               ...            ...            ...        ...            ...
# 339719                                                  0.6966         0.8398
# 339720                                                  0.4496         0.2174
# 339721                                                  0.4496         0.2174
# 339722                                                  0.4496         0.2174
# 339723                                                  0.4496         0.2174
#
#        gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF  \
# 3631          0.06872          0.352        0.09267          0.645
# 3632          0.06872          0.352        0.09267          0.645
# 3633          0.06872          0.352        0.09267          0.645
# 3634          0.06872          0.352        0.09267          0.645
# 3635          0.06872          0.352        0.09267          0.645
# ...               ...            ...            ...            ...
# 339719         0.5541         0.6935         0.5757         0.6118
# 339720         0.5332         0.5703         0.5165         0.5175
# 339721         0.5332         0.5703         0.5165         0.5175
# 339722         0.5332         0.5703         0.5165         0.5175
# 339723         0.5332         0.5703         0.5165         0.5175
#
#        gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF gnomADg_OTH_AF  \
# 3631           0.3337         0.1007         0.1774         0.2253
# 3632           0.3337         0.1007         0.1774         0.2253
# 3633           0.3337         0.1007         0.1774         0.2253
# 3634           0.3337         0.1007         0.1774         0.2253
# 3635           0.3337         0.1007         0.1774         0.2253
# ...               ...            ...            ...            ...
# 339719         0.6302         0.6667         0.6329          0.662
# 339720         0.5434         0.5805         0.5324          0.457
# 339721         0.5434         0.5805         0.5324          0.457
# 339722         0.5434         0.5805         0.5324          0.457
# 339723         0.5434         0.5805         0.5324          0.457
#
#        gnomADg_SAS_AF  MAX_AF MAX_AF_POPS                         BIOTYPE  \
# 3631           0.1582  0.6508         EAS                  protein coding
# 3632           0.1582  0.6508         EAS                  protein coding
# 3633           0.1582  0.6508         EAS                  protein coding
# 3634           0.1582  0.6508         EAS                  protein coding
# 3635           0.1582  0.6508         EAS                 retained intron
# ...               ...     ...         ...                             ...
# 339719         0.7649  0.8784         AFR
# 339720          0.606  0.6253         SAS                  protein coding
# 339721          0.606  0.6253         SAS                          lncRNA
# 339722          0.606  0.6253         SAS  protein coding CDS not defined
# 339723          0.606  0.6253         SAS               CTCF binding site
#
#          EXON INTRON Protein Position and Amino Acid Codons STRAND PUBMED  \
# 3631             4/6                             nan             1
# 3632             4/6                             nan             1
# 3633             4/6                             nan             1
# 3634             3/5                             nan             1
# 3635             5/5                             nan             1
# ...       ...    ...                             ...    ...    ...    ...
# 339719                                           nan            -1
# 339720  10/10                                    nan             1
# 339721           1/2                             nan            -1
# 339722                                           nan             1
# 339723                                           nan
#
#        Gene Match Matched_Gene
# 3631          Yes        PARK7
# 3632          Yes        PARK7
# 3633          Yes        PARK7
# 3634          Yes        PARK7
# 3635          Yes        PARK7
# ...           ...          ...
# 339719        Yes        ABCD1
# 339720        Yes        ABCD1
# 339721        Yes        ABCD1
# 339722        Yes        ABCD1
# 339723        Yes        ABCD1
#
# [2716 rows x 70 columns]

# %%
merged_2.columns
# Out:
# Index(['Gene Name', 'rsID', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
#        'Consequence', 'Consequence_score', 'IMPACT', 'IMPACT_score',
#        'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc',
#        'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP',
#        'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT',
#        'PolyPhen', 'AF', 'AFR_AF', 'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF',
#        'gnomADe_AF', 'gnomADe_AFR_AF', 'gnomADe_AMR_AF', 'gnomADe_ASJ_AF',
#        'gnomADe_EAS_AF', 'gnomADe_FIN_AF', 'gnomADe_NFE_AF', 'gnomADe_OTH_AF',
#        'gnomADe_SAS_AF', 'gnomADg_AF', 'gnomADg_AFR_AF', 'gnomADg_AMI_AF',
#        'gnomADg_AMR_AF', 'gnomADg_ASJ_AF', 'gnomADg_EAS_AF', 'gnomADg_FIN_AF',
#        'gnomADg_MID_AF', 'gnomADg_NFE_AF', 'gnomADg_OTH_AF', 'gnomADg_SAS_AF',
#        'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE', 'EXON', 'INTRON',
#        'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED',
#        'Gene Match', 'Matched_Gene'],
#       dtype='object')

# %%
merged_2 = merged_2.drop(columns=['Gene Match'], axis=1)
merged_2
# Out:
#        Gene Name         rsID CHROM        POS REF ALT      Zygosity  \
# 0          OR4F5    rs2691305  chr1      69511   A   G    Homozygous
# 1          OR4F5  rs200676709  chr1      69897   T   C  Heterozygous
# 2                           .  chr1     685694   T   C  Heterozygous
# 3                           .  chr1     685694   T   C  Heterozygous
# 4                           .  chr1     685694   T   C  Heterozygous
# ...          ...          ...   ...        ...  ..  ..           ...
# 340652      IL9R    rs2037999  chrX  156003433   T   C    Homozygous
# 340653      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340654      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340655      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340656      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
#
#                                          Consequence Consequence_score  \
# 0                                   missense variant              7/10
# 1                                 synonymous variant              3/10
# 2                            downstream gene variant              2/10
# 3       intron variant,non coding transcript variant              2/10
# 4       intron variant,non coding transcript variant              2/10
# ...                                              ...               ...
# 340652                     regulatory region variant              2/10
# 340653                              missense variant              7/10
# 340654                           3 prime UTR variant              3/10
# 340655                       downstream gene variant              2/10
# 340656                       downstream gene variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG  \
# 0       MODERATE           5.0
# 1            LOW           2.5
# 2       MODIFIER           1.5
# 3       MODIFIER           1.5
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...
# 340652  MODIFIER           1.5
# 340653  MODERATE           5.0  not provided   benign
# 340654  MODIFIER           1.5  not provided   benign
# 340655  MODIFIER           1.5  not provided   benign
# 340656  MODIFIER           1.5  not provided   benign
#
#                          ClinVar_CLNREVSTAT ClinVar               HGVSc  \
# 0                                                     ENST00000641515.2
# 1                                                     ENST00000641515.2
# 2
# 3                                                     ENST00000419394.2
# 4                                                     ENST00000440200.5
# ...                                     ...     ...                 ...
# 340652
# 340653  criteria provided, single submitter  771064  ENST00000244174.11
# 340654  criteria provided, single submitter  771064   ENST00000369423.7
# 340655  criteria provided, single submitter  771064
# 340656  criteria provided, single submitter  771064
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  \
# 0                c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255
# 1                c.870T>C  ENSP00000493376.2        p.Ser290%3D  0/1   82
# 2                    None                                  None  0/1   34
# 3          n.480+17991A>G                                  None  0/1   34
# 4          n.169+34338A>G                                  None  0/1   34
# ...                   ...                ...                ...  ...  ...
# 340652               None                                  None  1/1   58
# 340653          c.1094G>A  ENSP00000244174.5        p.Arg365His  0/1   27
# 340654           c.*85G>A                                  None  0/1   27
# 340655               None                                  None  0/1   27
# 340656               None                                  None  0/1   27
#
#         SDP   DP  RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0       120  120   0  120    100%  1.1001E-71   0   0  86  34
# 1        98   98  73   25  25.51%   5.1517E-9  41  32  11  14
# 2        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 3        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 4        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# ...     ...  ...  ..  ...     ...         ...  ..  ..  ..  ..
# 340652   11   11   0   11    100%   1.4176E-6   0   0   7   4
# 340653   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340654   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340655   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340656   20   20  12    8     40%    1.638E-3  12   0   8   0
#
#                    SIFT   PolyPhen      AF AFR_AF  AMR_AF EAS_AF  EUR_AF  \
# 0       tolerated(0.92)  benign(0)
# 1                                   0.6881  0.407  0.6254  0.876  0.7942
# 2
# 3
# 4
# ...                 ...        ...     ...    ...     ...    ...     ...
# 340652
# 340653  tolerated(0.56)  benign(0)
# 340654
# 340655
# 340656
#
#         SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF  \
# 0                  0.9497         0.6075         0.9514         0.9767
# 1       0.8098     0.7209          0.307         0.6749         0.8131
# 2
# 3
# 4
# ...        ...        ...            ...            ...            ...
# 340652              0.441         0.8217         0.3483         0.4304
# 340653            0.01405        0.02867       0.007828        0.01496
# 340654            0.01405        0.02867       0.007828        0.01496
# 340655            0.01405        0.02867       0.007828        0.01496
# 340656            0.01405        0.02867       0.007828        0.01496
#
#        gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0              0.9994         0.9916         0.9726         0.9506
# 1              0.7793         0.8652         0.8438         0.7932
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652          0.702         0.5274         0.3271         0.4035
# 340653        0.01587       0.005438       0.008185        0.02348
# 340654        0.01587       0.005438       0.008185        0.02348
# 340655        0.01587       0.005438       0.008185        0.02348
# 340656        0.01587       0.005438       0.008185        0.02348
#
#        gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0              0.9854      0.846         0.5948          0.998         0.8951
# 1              0.8049     0.4864         0.2916         0.6511         0.4782
# 2
# 3
# 4
# ...               ...        ...            ...            ...            ...
# 340652         0.5578     0.5073          0.809          0.356         0.3772
# 340653         0.0411    0.02864        0.03691        0.04154        0.01196
# 340654         0.0411    0.02864        0.03691        0.04154        0.01196
# 340655         0.0411    0.02864        0.03691        0.04154        0.01196
# 340656         0.0411    0.02864        0.03691        0.04154        0.01196
#
#        gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0              0.9784         0.9998         0.9907            0.9
# 1              0.6714         0.6047         0.6987         0.6441
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652         0.4374         0.7099         0.5742         0.4209
# 340653        0.03051        0.02488         0.0722        0.03478
# 340654        0.03051        0.02488         0.0722        0.03478
# 340655        0.03051        0.02488         0.0722        0.03478
# 340656        0.03051        0.02488         0.0722        0.03478
#
#        gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0              0.9674         0.8624         0.9772  0.9998  gnomADg EAS
# 1              0.6751         0.4659          0.622   0.876          EAS
# 2
# 3
# 4
# ...               ...            ...            ...     ...          ...
# 340652         0.3323         0.4516         0.5465  0.8217  gnomADe AFR
# 340653        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340654        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340655        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340656        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
#
#                                BIOTYPE EXON INTRON  \
# 0                       protein coding  3/3
# 1                       protein coding  3/3
# 2                       protein coding
# 3                 processed transcript         3/3
# 4                 processed transcript         1/2
# ...                                ...  ...    ...
# 340652                        enhancer
# 340653                  protein coding  9/9
# 340654                  protein coding  9/9
# 340655                          lncRNA
# 340656  protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED Matched_Gene
# 0                                T162A  Aca/Gca      1
# 1                                 S290  tcT/tcC      1
# 2                                  nan              -1
# 3                                  nan              -1
# 4                                  nan              -1
# ...                                ...      ...    ...    ...          ...
# 340652                             nan
# 340653                           R365H  cGt/cAt      1
# 340654                             nan               1
# 340655                             nan              -1
# 340656                             nan               1
#
# [340657 rows x 69 columns]

# %%
merged_2 = pd.merge(merged_2, df_gene, on= 'Matched_Gene', how = 'left', sort = False)
merged_2['Gene Match'] = merged_2['Gene Match'].fillna('No')
merged_2
# Out:
#        Gene Name         rsID CHROM        POS REF ALT      Zygosity  \
# 0          OR4F5    rs2691305  chr1      69511   A   G    Homozygous
# 1          OR4F5  rs200676709  chr1      69897   T   C  Heterozygous
# 2                           .  chr1     685694   T   C  Heterozygous
# 3                           .  chr1     685694   T   C  Heterozygous
# 4                           .  chr1     685694   T   C  Heterozygous
# ...          ...          ...   ...        ...  ..  ..           ...
# 340652      IL9R    rs2037999  chrX  156003433   T   C    Homozygous
# 340653      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340654      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340655      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340656      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
#
#                                          Consequence Consequence_score  \
# 0                                   missense variant              7/10
# 1                                 synonymous variant              3/10
# 2                            downstream gene variant              2/10
# 3       intron variant,non coding transcript variant              2/10
# 4       intron variant,non coding transcript variant              2/10
# ...                                              ...               ...
# 340652                     regulatory region variant              2/10
# 340653                              missense variant              7/10
# 340654                           3 prime UTR variant              3/10
# 340655                       downstream gene variant              2/10
# 340656                       downstream gene variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG  \
# 0       MODERATE           5.0
# 1            LOW           2.5
# 2       MODIFIER           1.5
# 3       MODIFIER           1.5
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...
# 340652  MODIFIER           1.5
# 340653  MODERATE           5.0  not provided   benign
# 340654  MODIFIER           1.5  not provided   benign
# 340655  MODIFIER           1.5  not provided   benign
# 340656  MODIFIER           1.5  not provided   benign
#
#                          ClinVar_CLNREVSTAT ClinVar               HGVSc  \
# 0                                                     ENST00000641515.2
# 1                                                     ENST00000641515.2
# 2
# 3                                                     ENST00000419394.2
# 4                                                     ENST00000440200.5
# ...                                     ...     ...                 ...
# 340652
# 340653  criteria provided, single submitter  771064  ENST00000244174.11
# 340654  criteria provided, single submitter  771064   ENST00000369423.7
# 340655  criteria provided, single submitter  771064
# 340656  criteria provided, single submitter  771064
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  \
# 0                c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255
# 1                c.870T>C  ENSP00000493376.2        p.Ser290%3D  0/1   82
# 2                    None                                  None  0/1   34
# 3          n.480+17991A>G                                  None  0/1   34
# 4          n.169+34338A>G                                  None  0/1   34
# ...                   ...                ...                ...  ...  ...
# 340652               None                                  None  1/1   58
# 340653          c.1094G>A  ENSP00000244174.5        p.Arg365His  0/1   27
# 340654           c.*85G>A                                  None  0/1   27
# 340655               None                                  None  0/1   27
# 340656               None                                  None  0/1   27
#
#         SDP   DP  RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0       120  120   0  120    100%  1.1001E-71   0   0  86  34
# 1        98   98  73   25  25.51%   5.1517E-9  41  32  11  14
# 2        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 3        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 4        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# ...     ...  ...  ..  ...     ...         ...  ..  ..  ..  ..
# 340652   11   11   0   11    100%   1.4176E-6   0   0   7   4
# 340653   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340654   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340655   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340656   20   20  12    8     40%    1.638E-3  12   0   8   0
#
#                    SIFT   PolyPhen      AF AFR_AF  AMR_AF EAS_AF  EUR_AF  \
# 0       tolerated(0.92)  benign(0)
# 1                                   0.6881  0.407  0.6254  0.876  0.7942
# 2
# 3
# 4
# ...                 ...        ...     ...    ...     ...    ...     ...
# 340652
# 340653  tolerated(0.56)  benign(0)
# 340654
# 340655
# 340656
#
#         SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF  \
# 0                  0.9497         0.6075         0.9514         0.9767
# 1       0.8098     0.7209          0.307         0.6749         0.8131
# 2
# 3
# 4
# ...        ...        ...            ...            ...            ...
# 340652              0.441         0.8217         0.3483         0.4304
# 340653            0.01405        0.02867       0.007828        0.01496
# 340654            0.01405        0.02867       0.007828        0.01496
# 340655            0.01405        0.02867       0.007828        0.01496
# 340656            0.01405        0.02867       0.007828        0.01496
#
#        gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0              0.9994         0.9916         0.9726         0.9506
# 1              0.7793         0.8652         0.8438         0.7932
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652          0.702         0.5274         0.3271         0.4035
# 340653        0.01587       0.005438       0.008185        0.02348
# 340654        0.01587       0.005438       0.008185        0.02348
# 340655        0.01587       0.005438       0.008185        0.02348
# 340656        0.01587       0.005438       0.008185        0.02348
#
#        gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0              0.9854      0.846         0.5948          0.998         0.8951
# 1              0.8049     0.4864         0.2916         0.6511         0.4782
# 2
# 3
# 4
# ...               ...        ...            ...            ...            ...
# 340652         0.5578     0.5073          0.809          0.356         0.3772
# 340653         0.0411    0.02864        0.03691        0.04154        0.01196
# 340654         0.0411    0.02864        0.03691        0.04154        0.01196
# 340655         0.0411    0.02864        0.03691        0.04154        0.01196
# 340656         0.0411    0.02864        0.03691        0.04154        0.01196
#
#        gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0              0.9784         0.9998         0.9907            0.9
# 1              0.6714         0.6047         0.6987         0.6441
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652         0.4374         0.7099         0.5742         0.4209
# 340653        0.03051        0.02488         0.0722        0.03478
# 340654        0.03051        0.02488         0.0722        0.03478
# 340655        0.03051        0.02488         0.0722        0.03478
# 340656        0.03051        0.02488         0.0722        0.03478
#
#        gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0              0.9674         0.8624         0.9772  0.9998  gnomADg EAS
# 1              0.6751         0.4659          0.622   0.876          EAS
# 2
# 3
# 4
# ...               ...            ...            ...     ...          ...
# 340652         0.3323         0.4516         0.5465  0.8217  gnomADe AFR
# 340653        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340654        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340655        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340656        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
#
#                                BIOTYPE EXON INTRON  \
# 0                       protein coding  3/3
# 1                       protein coding  3/3
# 2                       protein coding
# 3                 processed transcript         3/3
# 4                 processed transcript         1/2
# ...                                ...  ...    ...
# 340652                        enhancer
# 340653                  protein coding  9/9
# 340654                  protein coding  9/9
# 340655                          lncRNA
# 340656  protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED Matched_Gene  \
# 0                                T162A  Aca/Gca      1
# 1                                 S290  tcT/tcC      1
# 2                                  nan              -1
# 3                                  nan              -1
# 4                                  nan              -1
# ...                                ...      ...    ...    ...          ...
# 340652                             nan
# 340653                           R365H  cGt/cAt      1
# 340654                             nan               1
# 340655                             nan              -1
# 340656                             nan               1
#
#        Gene Match
# 0              No
# 1              No
# 2              No
# 3              No
# 4              No
# ...           ...
# 340652         No
# 340653         No
# 340654         No
# 340655         No
# 340656         No
#
# [340657 rows x 70 columns]

# %%
merged_2['Gene Match'].value_counts()
# Out:
# No                  337941
# Cerebellarataxia      1873
# Parkinson              843
# Name: Gene Match, dtype: int64

# %%
df_3
# Out:
#      CHROM        POS        Literature
# 0     chr1    7962863         Parkinson
# 1     chr1    7984930         Parkinson
# 2     chr1    7984981         Parkinson
# 3     chr1    7984954         Parkinson
# 4     chr1    7970951         Parkinson
# ...    ...        ...               ...
# 3146  chr7  107915692  Cerebellarataxia
# 3147  chr7  107916864  Cerebellarataxia
# 3148  chr7  107915532  Cerebellarataxia
# 3149  chr7  107917349  Cerebellarataxia
# 3150  chr7  107917418  Cerebellarataxia
#
# [3151 rows x 3 columns]

# %%
merged_2['POS'] = merged_2['POS'].astype('int64')
df_3['POS'] = df_3['POS'].astype('int64')

print("merged_2['CHROM'] data type:", merged_2['CHROM'].dtype)
print("merged_2['POS'] data type:", merged_2['POS'].dtype)
print("df_3['CHROM'] data type:", df_3['CHROM'].dtype)
print("df_3['POS'] data type:", df_3['POS'].dtype)
# Out:
# merged_2['CHROM'] data type: object
# merged_2['POS'] data type: int64
# df_3['CHROM'] data type: object
# df_3['POS'] data type: int64

# %%
merged_3 = pd.merge(merged_2, df_3, on=['CHROM', 'POS'], how='left', sort=False)
merged_3['Literature'] = merged_3['Literature'].fillna('No')
merged_3
# Out:
#        Gene Name         rsID CHROM        POS REF ALT      Zygosity  \
# 0          OR4F5    rs2691305  chr1      69511   A   G    Homozygous
# 1          OR4F5  rs200676709  chr1      69897   T   C  Heterozygous
# 2                           .  chr1     685694   T   C  Heterozygous
# 3                           .  chr1     685694   T   C  Heterozygous
# 4                           .  chr1     685694   T   C  Heterozygous
# ...          ...          ...   ...        ...  ..  ..           ...
# 340652      IL9R    rs2037999  chrX  156003433   T   C    Homozygous
# 340653      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340654      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340655      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340656      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
#
#                                          Consequence Consequence_score  \
# 0                                   missense variant              7/10
# 1                                 synonymous variant              3/10
# 2                            downstream gene variant              2/10
# 3       intron variant,non coding transcript variant              2/10
# 4       intron variant,non coding transcript variant              2/10
# ...                                              ...               ...
# 340652                     regulatory region variant              2/10
# 340653                              missense variant              7/10
# 340654                           3 prime UTR variant              3/10
# 340655                       downstream gene variant              2/10
# 340656                       downstream gene variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG  \
# 0       MODERATE           5.0
# 1            LOW           2.5
# 2       MODIFIER           1.5
# 3       MODIFIER           1.5
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...
# 340652  MODIFIER           1.5
# 340653  MODERATE           5.0  not provided   benign
# 340654  MODIFIER           1.5  not provided   benign
# 340655  MODIFIER           1.5  not provided   benign
# 340656  MODIFIER           1.5  not provided   benign
#
#                          ClinVar_CLNREVSTAT ClinVar               HGVSc  \
# 0                                                     ENST00000641515.2
# 1                                                     ENST00000641515.2
# 2
# 3                                                     ENST00000419394.2
# 4                                                     ENST00000440200.5
# ...                                     ...     ...                 ...
# 340652
# 340653  criteria provided, single submitter  771064  ENST00000244174.11
# 340654  criteria provided, single submitter  771064   ENST00000369423.7
# 340655  criteria provided, single submitter  771064
# 340656  criteria provided, single submitter  771064
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  \
# 0                c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255
# 1                c.870T>C  ENSP00000493376.2        p.Ser290%3D  0/1   82
# 2                    None                                  None  0/1   34
# 3          n.480+17991A>G                                  None  0/1   34
# 4          n.169+34338A>G                                  None  0/1   34
# ...                   ...                ...                ...  ...  ...
# 340652               None                                  None  1/1   58
# 340653          c.1094G>A  ENSP00000244174.5        p.Arg365His  0/1   27
# 340654           c.*85G>A                                  None  0/1   27
# 340655               None                                  None  0/1   27
# 340656               None                                  None  0/1   27
#
#         SDP   DP  RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0       120  120   0  120    100%  1.1001E-71   0   0  86  34
# 1        98   98  73   25  25.51%   5.1517E-9  41  32  11  14
# 2        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 3        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 4        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# ...     ...  ...  ..  ...     ...         ...  ..  ..  ..  ..
# 340652   11   11   0   11    100%   1.4176E-6   0   0   7   4
# 340653   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340654   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340655   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340656   20   20  12    8     40%    1.638E-3  12   0   8   0
#
#                    SIFT   PolyPhen      AF AFR_AF  AMR_AF EAS_AF  EUR_AF  \
# 0       tolerated(0.92)  benign(0)
# 1                                   0.6881  0.407  0.6254  0.876  0.7942
# 2
# 3
# 4
# ...                 ...        ...     ...    ...     ...    ...     ...
# 340652
# 340653  tolerated(0.56)  benign(0)
# 340654
# 340655
# 340656
#
#         SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF  \
# 0                  0.9497         0.6075         0.9514         0.9767
# 1       0.8098     0.7209          0.307         0.6749         0.8131
# 2
# 3
# 4
# ...        ...        ...            ...            ...            ...
# 340652              0.441         0.8217         0.3483         0.4304
# 340653            0.01405        0.02867       0.007828        0.01496
# 340654            0.01405        0.02867       0.007828        0.01496
# 340655            0.01405        0.02867       0.007828        0.01496
# 340656            0.01405        0.02867       0.007828        0.01496
#
#        gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0              0.9994         0.9916         0.9726         0.9506
# 1              0.7793         0.8652         0.8438         0.7932
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652          0.702         0.5274         0.3271         0.4035
# 340653        0.01587       0.005438       0.008185        0.02348
# 340654        0.01587       0.005438       0.008185        0.02348
# 340655        0.01587       0.005438       0.008185        0.02348
# 340656        0.01587       0.005438       0.008185        0.02348
#
#        gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0              0.9854      0.846         0.5948          0.998         0.8951
# 1              0.8049     0.4864         0.2916         0.6511         0.4782
# 2
# 3
# 4
# ...               ...        ...            ...            ...            ...
# 340652         0.5578     0.5073          0.809          0.356         0.3772
# 340653         0.0411    0.02864        0.03691        0.04154        0.01196
# 340654         0.0411    0.02864        0.03691        0.04154        0.01196
# 340655         0.0411    0.02864        0.03691        0.04154        0.01196
# 340656         0.0411    0.02864        0.03691        0.04154        0.01196
#
#        gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0              0.9784         0.9998         0.9907            0.9
# 1              0.6714         0.6047         0.6987         0.6441
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652         0.4374         0.7099         0.5742         0.4209
# 340653        0.03051        0.02488         0.0722        0.03478
# 340654        0.03051        0.02488         0.0722        0.03478
# 340655        0.03051        0.02488         0.0722        0.03478
# 340656        0.03051        0.02488         0.0722        0.03478
#
#        gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0              0.9674         0.8624         0.9772  0.9998  gnomADg EAS
# 1              0.6751         0.4659          0.622   0.876          EAS
# 2
# 3
# 4
# ...               ...            ...            ...     ...          ...
# 340652         0.3323         0.4516         0.5465  0.8217  gnomADe AFR
# 340653        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340654        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340655        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340656        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
#
#                                BIOTYPE EXON INTRON  \
# 0                       protein coding  3/3
# 1                       protein coding  3/3
# 2                       protein coding
# 3                 processed transcript         3/3
# 4                 processed transcript         1/2
# ...                                ...  ...    ...
# 340652                        enhancer
# 340653                  protein coding  9/9
# 340654                  protein coding  9/9
# 340655                          lncRNA
# 340656  protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED Matched_Gene  \
# 0                                T162A  Aca/Gca      1
# 1                                 S290  tcT/tcC      1
# 2                                  nan              -1
# 3                                  nan              -1
# 4                                  nan              -1
# ...                                ...      ...    ...    ...          ...
# 340652                             nan
# 340653                           R365H  cGt/cAt      1
# 340654                             nan               1
# 340655                             nan              -1
# 340656                             nan               1
#
#        Gene Match Literature
# 0              No         No
# 1              No         No
# 2              No         No
# 3              No         No
# 4              No         No
# ...           ...        ...
# 340652         No         No
# 340653         No         No
# 340654         No         No
# 340655         No         No
# 340656         No         No
#
# [340657 rows x 71 columns]

# %%
merged_3.Literature.value_counts()
# Out:
# No                  340591
# Parkinson               40
# Cerebellarataxia        26
# Name: Literature, dtype: int64

# %%
merged_3.columns
# Out:
# Index(['Gene Name', 'rsID', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
#        'Consequence', 'Consequence_score', 'IMPACT', 'IMPACT_score',
#        'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc',
#        'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP',
#        'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT',
#        'PolyPhen', 'AF', 'AFR_AF', 'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF',
#        'gnomADe_AF', 'gnomADe_AFR_AF', 'gnomADe_AMR_AF', 'gnomADe_ASJ_AF',
#        'gnomADe_EAS_AF', 'gnomADe_FIN_AF', 'gnomADe_NFE_AF', 'gnomADe_OTH_AF',
#        'gnomADe_SAS_AF', 'gnomADg_AF', 'gnomADg_AFR_AF', 'gnomADg_AMI_AF',
#        'gnomADg_AMR_AF', 'gnomADg_ASJ_AF', 'gnomADg_EAS_AF', 'gnomADg_FIN_AF',
#        'gnomADg_MID_AF', 'gnomADg_NFE_AF', 'gnomADg_OTH_AF', 'gnomADg_SAS_AF',
#        'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE', 'EXON', 'INTRON',
#        'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED',
#        'Matched_Gene', 'Gene Match', 'Literature'],
#       dtype='object')

# %%
merged_3 = merged_3[['Gene Name', 'Gene Match', 'rsID', 'Literature', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
       'Consequence', 'Consequence_score', 'IMPACT', 'IMPACT_score',
       'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc',
       'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP',
       'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT',
       'PolyPhen', 'AF', 'AFR_AF', 'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF',
       'gnomADe_AF', 'gnomADe_AFR_AF', 'gnomADe_AMR_AF', 'gnomADe_ASJ_AF',
       'gnomADe_EAS_AF', 'gnomADe_FIN_AF', 'gnomADe_NFE_AF', 'gnomADe_OTH_AF',
       'gnomADe_SAS_AF', 'gnomADg_AF', 'gnomADg_AFR_AF', 'gnomADg_AMI_AF',
       'gnomADg_AMR_AF', 'gnomADg_ASJ_AF', 'gnomADg_EAS_AF', 'gnomADg_FIN_AF',
       'gnomADg_MID_AF', 'gnomADg_NFE_AF', 'gnomADg_OTH_AF', 'gnomADg_SAS_AF',
       'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE', 'EXON', 'INTRON',
       'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED']]
merged_3
# Out:
#        Gene Name Gene Match         rsID Literature CHROM        POS REF ALT  \
# 0          OR4F5         No    rs2691305         No  chr1      69511   A   G
# 1          OR4F5         No  rs200676709         No  chr1      69897   T   C
# 2                        No            .         No  chr1     685694   T   C
# 3                        No            .         No  chr1     685694   T   C
# 4                        No            .         No  chr1     685694   T   C
# ...          ...        ...          ...        ...   ...        ...  ..  ..
# 340652      IL9R         No    rs2037999         No  chrX  156003433   T   C
# 340653      IL9R         No  rs147385831         No  chrX  156009937   G   A
# 340654      IL9R         No  rs147385831         No  chrX  156009937   G   A
# 340655      IL9R         No  rs147385831         No  chrX  156009937   G   A
# 340656      IL9R         No  rs147385831         No  chrX  156009937   G   A
#
#             Zygosity                                   Consequence  \
# 0         Homozygous                              missense variant
# 1       Heterozygous                            synonymous variant
# 2       Heterozygous                       downstream gene variant
# 3       Heterozygous  intron variant,non coding transcript variant
# 4       Heterozygous  intron variant,non coding transcript variant
# ...              ...                                           ...
# 340652    Homozygous                     regulatory region variant
# 340653  Heterozygous                              missense variant
# 340654  Heterozygous                           3 prime UTR variant
# 340655  Heterozygous                       downstream gene variant
# 340656  Heterozygous                       downstream gene variant
#
#        Consequence_score    IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG  \
# 0                   7/10  MODERATE           5.0
# 1                   3/10       LOW           2.5
# 2                   2/10  MODIFIER           1.5
# 3                   2/10  MODIFIER           1.5
# 4                   2/10  MODIFIER           1.5
# ...                  ...       ...           ...           ...      ...
# 340652              2/10  MODIFIER           1.5
# 340653              7/10  MODERATE           5.0  not provided   benign
# 340654              3/10  MODIFIER           1.5  not provided   benign
# 340655              2/10  MODIFIER           1.5  not provided   benign
# 340656              2/10  MODIFIER           1.5  not provided   benign
#
#                          ClinVar_CLNREVSTAT ClinVar               HGVSc  \
# 0                                                     ENST00000641515.2
# 1                                                     ENST00000641515.2
# 2
# 3                                                     ENST00000419394.2
# 4                                                     ENST00000440200.5
# ...                                     ...     ...                 ...
# 340652
# 340653  criteria provided, single submitter  771064  ENST00000244174.11
# 340654  criteria provided, single submitter  771064   ENST00000369423.7
# 340655  criteria provided, single submitter  771064
# 340656  criteria provided, single submitter  771064
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  \
# 0                c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255
# 1                c.870T>C  ENSP00000493376.2        p.Ser290%3D  0/1   82
# 2                    None                                  None  0/1   34
# 3          n.480+17991A>G                                  None  0/1   34
# 4          n.169+34338A>G                                  None  0/1   34
# ...                   ...                ...                ...  ...  ...
# 340652               None                                  None  1/1   58
# 340653          c.1094G>A  ENSP00000244174.5        p.Arg365His  0/1   27
# 340654           c.*85G>A                                  None  0/1   27
# 340655               None                                  None  0/1   27
# 340656               None                                  None  0/1   27
#
#         SDP   DP  RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0       120  120   0  120    100%  1.1001E-71   0   0  86  34
# 1        98   98  73   25  25.51%   5.1517E-9  41  32  11  14
# 2        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 3        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 4        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# ...     ...  ...  ..  ...     ...         ...  ..  ..  ..  ..
# 340652   11   11   0   11    100%   1.4176E-6   0   0   7   4
# 340653   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340654   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340655   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340656   20   20  12    8     40%    1.638E-3  12   0   8   0
#
#                    SIFT   PolyPhen      AF AFR_AF  AMR_AF EAS_AF  EUR_AF  \
# 0       tolerated(0.92)  benign(0)
# 1                                   0.6881  0.407  0.6254  0.876  0.7942
# 2
# 3
# 4
# ...                 ...        ...     ...    ...     ...    ...     ...
# 340652
# 340653  tolerated(0.56)  benign(0)
# 340654
# 340655
# 340656
#
#         SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF  \
# 0                  0.9497         0.6075         0.9514         0.9767
# 1       0.8098     0.7209          0.307         0.6749         0.8131
# 2
# 3
# 4
# ...        ...        ...            ...            ...            ...
# 340652              0.441         0.8217         0.3483         0.4304
# 340653            0.01405        0.02867       0.007828        0.01496
# 340654            0.01405        0.02867       0.007828        0.01496
# 340655            0.01405        0.02867       0.007828        0.01496
# 340656            0.01405        0.02867       0.007828        0.01496
#
#        gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0              0.9994         0.9916         0.9726         0.9506
# 1              0.7793         0.8652         0.8438         0.7932
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652          0.702         0.5274         0.3271         0.4035
# 340653        0.01587       0.005438       0.008185        0.02348
# 340654        0.01587       0.005438       0.008185        0.02348
# 340655        0.01587       0.005438       0.008185        0.02348
# 340656        0.01587       0.005438       0.008185        0.02348
#
#        gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0              0.9854      0.846         0.5948          0.998         0.8951
# 1              0.8049     0.4864         0.2916         0.6511         0.4782
# 2
# 3
# 4
# ...               ...        ...            ...            ...            ...
# 340652         0.5578     0.5073          0.809          0.356         0.3772
# 340653         0.0411    0.02864        0.03691        0.04154        0.01196
# 340654         0.0411    0.02864        0.03691        0.04154        0.01196
# 340655         0.0411    0.02864        0.03691        0.04154        0.01196
# 340656         0.0411    0.02864        0.03691        0.04154        0.01196
#
#        gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0              0.9784         0.9998         0.9907            0.9
# 1              0.6714         0.6047         0.6987         0.6441
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652         0.4374         0.7099         0.5742         0.4209
# 340653        0.03051        0.02488         0.0722        0.03478
# 340654        0.03051        0.02488         0.0722        0.03478
# 340655        0.03051        0.02488         0.0722        0.03478
# 340656        0.03051        0.02488         0.0722        0.03478
#
#        gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0              0.9674         0.8624         0.9772  0.9998  gnomADg EAS
# 1              0.6751         0.4659          0.622   0.876          EAS
# 2
# 3
# 4
# ...               ...            ...            ...     ...          ...
# 340652         0.3323         0.4516         0.5465  0.8217  gnomADe AFR
# 340653        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340654        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340655        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340656        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
#
#                                BIOTYPE EXON INTRON  \
# 0                       protein coding  3/3
# 1                       protein coding  3/3
# 2                       protein coding
# 3                 processed transcript         3/3
# 4                 processed transcript         1/2
# ...                                ...  ...    ...
# 340652                        enhancer
# 340653                  protein coding  9/9
# 340654                  protein coding  9/9
# 340655                          lncRNA
# 340656  protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED
# 0                                T162A  Aca/Gca      1
# 1                                 S290  tcT/tcC      1
# 2                                  nan              -1
# 3                                  nan              -1
# 4                                  nan              -1
# ...                                ...      ...    ...    ...
# 340652                             nan
# 340653                           R365H  cGt/cAt      1
# 340654                             nan               1
# 340655                             nan              -1
# 340656                             nan               1
#
# [340657 rows x 70 columns]

# %%
merged_3.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Processed_vcf_files/KHAIGHGPTTL207_depth_vcf_processed.xlsx', index=False)

# %% [markdown]
# # Literature check

# %%
data = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/MODY_covered_list.xlsx')
data
# Out:
#          samples    GENE  CHROM        POS           ID
# 0       12652713     NaN  chr16      31779  rs141542623
# 1       12652713   TUBB8  chr10      49286    rs6560829
# 2       17751397   TUBB8  chr10      49286    rs6560829
# 3       17751406   TUBB8  chr10      49286    rs6560829
# 4       12652700   TUBB8  chr10      49286    rs6560829
# ...          ...     ...    ...        ...          ...
# 165543  17751406  ZNF692   chr1  248855917   rs13313088
# 165544  17751406  ZNF692   chr1  248856006   rs13313009
# 165545  17751397   PGBD2   chr1  248913954   rs12025760
# 165546  17751397   PGBD2   chr1  248916897   rs74157349
# 165547  17751397   PGBD2   chr1  248917420   rs77124333
#
# [165548 rows x 5 columns]

# %%
df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/Depth_files/srinivas_sir_covered.bed', sep = '\t', header = None, error_bad_lines=False)
df.columns = ['chromosome', 'Start_pos', 'End_pos']
df
# Out:
#        chromosome  Start_pos   End_pos
# 0            chr1      65489     65645
# 1            chr1      65811     65993
# 2            chr1      69461     69620
# 3            chr1     785981    786159
# 4            chr1     786130    786446
# ...           ...        ...       ...
# 230714       chrY   57190028  57190328
# 230715       chrY   57190299  57190439
# 230716       chrY   57190874  57191014
# 230717       chrY   57191846  57192058
# 230718       chrY   57194102  57194243
#
# [230719 rows x 3 columns]

# %%
df['Extended_Start_pos'] = df['Start_pos'] - 20
df['Extended_End_pos'] = df['End_pos'] + 20
df
# Out:
#        chromosome  Start_pos   End_pos  \
# 0            chr1      65509     65629
# 1            chr1      69027     70017
# 2            chr1     450730    451686
# 3            chr1     685706    686662
# 4            chr1     924421    924957
# ...           ...        ...       ...
# 208906       chrY   25038801  25038921
# 208907       chrY   25041766  25041886
# 208908       chrY   25043908  25044028
# 208909       chrY   25622433  25624073
# 208910       chrY   25624417  25624537
#
#                                                      INFO  Extended_Start_pos  \
# 0       ensembl_gene_id=ENSG00000186092;gene_symbol=OR4F5               65489
# 1       ccds_id=CCDS30547.1;ensembl_gene_id=ENSG000001...               69007
# 2       ccds_id=CCDS72675.1;ensembl_gene_id=ENSG000002...              450710
# 3       ccds_id=CCDS41221.1;ensembl_gene_id=ENSG000002...              685686
# 4       ensembl_gene_id=ENSG00000187634;gene_symbol=SA...              924401
# ...                                                   ...                 ...
# 208906  ccds_id=CCDS44030.1;ensembl_gene_id=ENSG000001...            25038781
# 208907  ccds_id=CCDS44030.1;ensembl_gene_id=ENSG000001...            25041746
# 208908  ccds_id=CCDS44030.1;ensembl_gene_id=ENSG000001...            25043888
# 208909  ccds_id=CCDS14801.1,CCDS14802.1;ensembl_gene_i...            25622413
# 208910  ccds_id=CCDS14801.1;ensembl_gene_id=ENSG000001...            25624397
#
#         Extended_End_pos
# 0                  65649
# 1                  70037
# 2                 451706
# 3                 686682
# 4                 924977
# ...                  ...
# 208906          25038941
# 208907          25041906
# 208908          25044048
# 208909          25624093
# 208910          25624557
#
# [208911 rows x 6 columns]

# %%
df['gene_symbol'] = df['INFO'].str.extract(r'gene_symbol=([^;]+)')
df
# Out:
#        chromosome  Start_pos   End_pos  \
# 0            chr1      65509     65629
# 1            chr1      69027     70017
# 2            chr1     450730    451686
# 3            chr1     685706    686662
# 4            chr1     924421    924957
# ...           ...        ...       ...
# 208906       chrY   25038801  25038921
# 208907       chrY   25041766  25041886
# 208908       chrY   25043908  25044028
# 208909       chrY   25622433  25624073
# 208910       chrY   25624417  25624537
#
#                                                      INFO  Extended_Start_pos  \
# 0       ensembl_gene_id=ENSG00000186092;gene_symbol=OR4F5               65489
# 1       ccds_id=CCDS30547.1;ensembl_gene_id=ENSG000001...               69007
# 2       ccds_id=CCDS72675.1;ensembl_gene_id=ENSG000002...              450710
# 3       ccds_id=CCDS41221.1;ensembl_gene_id=ENSG000002...              685686
# 4       ensembl_gene_id=ENSG00000187634;gene_symbol=SA...              924401
# ...                                                   ...                 ...
# 208906  ccds_id=CCDS44030.1;ensembl_gene_id=ENSG000001...            25038781
# 208907  ccds_id=CCDS44030.1;ensembl_gene_id=ENSG000001...            25041746
# 208908  ccds_id=CCDS44030.1;ensembl_gene_id=ENSG000001...            25043888
# 208909  ccds_id=CCDS14801.1,CCDS14802.1;ensembl_gene_i...            25622413
# 208910  ccds_id=CCDS14801.1;ensembl_gene_id=ENSG000001...            25624397
#
#         Extended_End_pos gene_symbol
# 0                  65649       OR4F5
# 1                  70037       OR4F5
# 2                 451706      OR4F29
# 3                 686682      OR4F16
# 4                 924977      SAMD11
# ...                  ...         ...
# 208906          25038941       BPY2C
# 208907          25041906       BPY2C
# 208908          25044048       BPY2C
# 208909          25624093        CDY1
# 208910          25624557        CDY1
#
# [208911 rows x 7 columns]

# %%
df = df[['chromosome', 'Extended_Start_pos', 'Extended_End_pos', 'INFO', 'gene_symbol']]
df
# Out:
#        chromosome  Extended_Start_pos  Extended_End_pos  \
# 0            chr1               65489             65649
# 1            chr1               69007             70037
# 2            chr1              450710            451706
# 3            chr1              685686            686682
# 4            chr1              924401            924977
# ...           ...                 ...               ...
# 208906       chrY            25038781          25038941
# 208907       chrY            25041746          25041906
# 208908       chrY            25043888          25044048
# 208909       chrY            25622413          25624093
# 208910       chrY            25624397          25624557
#
#                                                      INFO gene_symbol
# 0       ensembl_gene_id=ENSG00000186092;gene_symbol=OR4F5       OR4F5
# 1       ccds_id=CCDS30547.1;ensembl_gene_id=ENSG000001...       OR4F5
# 2       ccds_id=CCDS72675.1;ensembl_gene_id=ENSG000002...      OR4F29
# 3       ccds_id=CCDS41221.1;ensembl_gene_id=ENSG000002...      OR4F16
# 4       ensembl_gene_id=ENSG00000187634;gene_symbol=SA...      SAMD11
# ...                                                   ...         ...
# 208906  ccds_id=CCDS44030.1;ensembl_gene_id=ENSG000001...       BPY2C
# 208907  ccds_id=CCDS44030.1;ensembl_gene_id=ENSG000001...       BPY2C
# 208908  ccds_id=CCDS44030.1;ensembl_gene_id=ENSG000001...       BPY2C
# 208909  ccds_id=CCDS14801.1,CCDS14802.1;ensembl_gene_i...        CDY1
# 208910  ccds_id=CCDS14801.1;ensembl_gene_id=ENSG000001...        CDY1
#
# [208911 rows x 5 columns]

# %%
# Step 1: Create a dictionary from the df DataFrame
chromosome_dict = {}
for _, row in df.iterrows():
    chromosome = row['chromosome']
    start_pos = row['Start_pos']
    end_pos = row['End_pos']
    if chromosome not in chromosome_dict:
        chromosome_dict[chromosome] = []
    chromosome_dict[chromosome].append((start_pos, end_pos))

# Step 2: Define a function to check coverage
def check_coverage(row):
    pos = row['POS']
    chromosome = row['CHROM']
    if chromosome in chromosome_dict:
        ranges = chromosome_dict[chromosome]
        for start, end in ranges:
            if start <= pos <= end:
                return 'Covered'
    return 'Not_Covered'

# Step 3: Apply the function to create the new column in dataset2
data['Covered/Not_Covered'] = data.apply(check_coverage, axis=1)
data
# Out:
#          samples    GENE  CHROM        POS           ID Covered/Not_Covered
# 0       12652713     NaN  chr16      31779  rs141542623             Covered
# 1       12652713   TUBB8  chr10      49286    rs6560829             Covered
# 2       17751397   TUBB8  chr10      49286    rs6560829             Covered
# 3       17751406   TUBB8  chr10      49286    rs6560829             Covered
# 4       12652700   TUBB8  chr10      49286    rs6560829             Covered
# ...          ...     ...    ...        ...          ...                 ...
# 165543  17751406  ZNF692   chr1  248855917   rs13313088             Covered
# 165544  17751406  ZNF692   chr1  248856006   rs13313009             Covered
# 165545  17751397   PGBD2   chr1  248913954   rs12025760             Covered
# 165546  17751397   PGBD2   chr1  248916897   rs74157349             Covered
# 165547  17751397   PGBD2   chr1  248917420   rs77124333             Covered
#
# [165548 rows x 6 columns]

# %%
data['Covered/Not_Covered'].value_counts()
# Out:
# Covered    165548
# Name: Covered/Not_Covered, dtype: int64

# %%
import pandas as pd
x = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Mody_Lit_final_Positions_hg38_hg37.xlsx')
x['chrom'] = x['Chrom-pos-Ref-Alt_38'].str.split(',')
x = x.explode('chrom')

x['CHROM'] = x['chrom'].str.split('-').str[0]

# Function to add 'chr' prefix conditionally
def add_chr_prefix(chrom):
    if pd.notnull(chrom) and chrom.strip() != '':
        return 'chr' + str(chrom)
    else:
        return chrom

# Applying the function to the 'chromosome' column
x['CHROM'] = x['CHROM'].apply(add_chr_prefix)
x['CHROM'] = x['CHROM'].str.strip()
x['CHROM'] = x['CHROM'].str.replace(r'\s+', '')
x['POS'] = x['chrom'].str.split('-').str[1]

x.dropna(subset=['CHROM'], inplace=True)
# Drop rows with empty cells after removing leading and trailing whitespaces
x['CHROM'] = x['CHROM'].str.strip()
x['POS'] = x['POS'].str.strip()
# Dropping rows with empty cells and NaN values in both 'chromosome' and 'position' columns
x.dropna(subset=['CHROM', 'POS'], inplace=True)
df_3 = x[['CHROM', 'POS']]
df_3['Literature'] = 'Yes'
df_3.drop_duplicates(subset='POS', inplace=True)
df_3['POS'] = df_3['POS'].astype('int64')
df_3 = df_3.reset_index()
df_3 = df_3[['CHROM', 'POS', 'Literature']]

df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/KAPA HyperExome_hg38_capture_targets (1).bed', sep = '\t', header = None)
df.columns = ['chromosome', 'Start_pos', 'End_pos', 'INFO']

df['Extended_Start_pos'] = df['Start_pos'] - 20
df['Extended_End_pos'] = df['End_pos'] + 20

df['gene_symbol'] = df['INFO'].str.extract(r'gene_symbol=([^;]+)')
df = df[['chromosome', 'Extended_Start_pos', 'Extended_End_pos', 'INFO', 'gene_symbol']]


# Step 1: Create a dictionary from the df DataFrame
chromosome_dict = {}
for _, row in df.iterrows():
    chromosome = row['chromosome']
    start_pos = row['Extended_Start_pos']
    end_pos = row['Extended_End_pos']
    if chromosome not in chromosome_dict:
        chromosome_dict[chromosome] = []
    chromosome_dict[chromosome].append((start_pos, end_pos))

# Step 2: Define a function to check coverage
def check_coverage(row):
    pos = row['POS']
    chromosome = row['CHROM']
    if chromosome in chromosome_dict:
        ranges = chromosome_dict[chromosome]
        for start, end in ranges:
            if start <= pos <= end:
                return 'Covered'
    return 'Not_Covered'

# Step 3: Apply the function to create the new column in dataset2
df_3['Covered_status'] = df_3.apply(check_coverage, axis=1)

df_3 = df_3[df_3['Covered_status'] == 'Covered']
df_3
# Out:
#       CHROM        POS Literature Covered_status
# 0     chr12  120978691        Yes        Covered
# 1     chr12  120978908        Yes        Covered
# 2     chr12  120997590        Yes        Covered
# 3     chr12  120996531        Yes        Covered
# 4     chr12  120978928        Yes        Covered
# ...     ...        ...        ...            ...
# 2206  chr11   17394331        Yes        Covered
# 2207  chr11   17396955        Yes        Covered
# 2208  chr11   17395249        Yes        Covered
# 2209  chr11   17413396        Yes        Covered
# 2210  chr11   17408487        Yes        Covered
#
# [1685 rows x 4 columns]

# %%
merged_3 = pd.merge(data, df_3, on=['CHROM', 'POS'], how='left', sort=False)
merged_3
# Out:
#          samples    GENE  CHROM        POS           ID Covered/Not_Covered  \
# 0       12652713     NaN  chr16      31779  rs141542623             Covered
# 1       12652713   TUBB8  chr10      49286    rs6560829             Covered
# 2       17751397   TUBB8  chr10      49286    rs6560829             Covered
# 3       17751406   TUBB8  chr10      49286    rs6560829             Covered
# 4       12652700   TUBB8  chr10      49286    rs6560829             Covered
# ...          ...     ...    ...        ...          ...                 ...
# 165543  17751406  ZNF692   chr1  248855917   rs13313088             Covered
# 165544  17751406  ZNF692   chr1  248856006   rs13313009             Covered
# 165545  17751397   PGBD2   chr1  248913954   rs12025760             Covered
# 165546  17751397   PGBD2   chr1  248916897   rs74157349             Covered
# 165547  17751397   PGBD2   chr1  248917420   rs77124333             Covered
#
#        Literature Covered_status
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN
# ...           ...            ...
# 165543        NaN            NaN
# 165544        NaN            NaN
# 165545        NaN            NaN
# 165546        NaN            NaN
# 165547        NaN            NaN
#
# [165548 rows x 8 columns]

# %%
merged_3.Literature.value_counts()
# Out:
# Yes    9
# Name: Literature, dtype: int64

# %%
x= merged_3[merged_3['Literature'] == 'Yes']
x
# Out:
#          samples   GENE  CHROM        POS            ID Covered/Not_Covered  \
# 28075   12652713    NaN  chr11   17394397             .             Covered
# 128673  12652713  HNF1A  chr12  120978847     rs1169288             Covered
# 128674  17751397  HNF1A  chr12  120979061     rs1800574             Covered
# 128675  17751406  HNF1A  chr12  120979061     rs1800574             Covered
# 128678  12652700  HNF1A  chr12  120989017  rs1057520291             Covered
# 128682  12652700  HNF1A  chr12  120994314    rs56348580             Covered
# 128685  17751406  HNF1A  chr12  120997672     rs2464195             Covered
# 128686  17751397  HNF1A  chr12  120997672     rs2464195             Covered
# 128687  12652713  HNF1A  chr12  120997672     rs2464195             Covered
#
#        Literature Covered_status
# 28075         Yes        Covered
# 128673        Yes        Covered
# 128674        Yes        Covered
# 128675        Yes        Covered
# 128678        Yes        Covered
# 128682        Yes        Covered
# 128685        Yes        Covered
# 128686        Yes        Covered
# 128687        Yes        Covered

# %%
x.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/lit_mody.xlsx', index=False)
x
# Out:
#          samples   GENE  CHROM        POS            ID Covered/Not_Covered  \
# 28075   12652713    NaN  chr11   17394397             .             Covered
# 128673  12652713  HNF1A  chr12  120978847     rs1169288             Covered
# 128674  17751397  HNF1A  chr12  120979061     rs1800574             Covered
# 128675  17751406  HNF1A  chr12  120979061     rs1800574             Covered
# 128678  12652700  HNF1A  chr12  120989017  rs1057520291             Covered
# 128682  12652700  HNF1A  chr12  120994314    rs56348580             Covered
# 128685  17751406  HNF1A  chr12  120997672     rs2464195             Covered
# 128686  17751397  HNF1A  chr12  120997672     rs2464195             Covered
# 128687  12652713  HNF1A  chr12  120997672     rs2464195             Covered
#
#        Literature Covered_status
# 28075         Yes        Covered
# 128673        Yes        Covered
# 128674        Yes        Covered
# 128675        Yes        Covered
# 128678        Yes        Covered
# 128682        Yes        Covered
# 128685        Yes        Covered
# 128686        Yes        Covered
# 128687        Yes        Covered

# %%
data['Covered/Not_Covered'].value_counts()
# Out:
# Covered        2353
# Not_Covered     798
# Name: Covered/Not_Covered, dtype: int64

# %%
data[data['Covered/Not_Covered'] == 'Covered']
# Out:
#      CHROM        POS        Literature Covered/Not_Covered
# 0     chr1    7962863         Parkinson             Covered
# 4     chr1    7970951         Parkinson             Covered
# 5     chr1    7985014         Parkinson             Covered
# 8     chr1    7985041         Parkinson             Covered
# 9     chr1    7965425         Parkinson             Covered
# ...    ...        ...               ...                 ...
# 3146  chr7  107915692  Cerebellarataxia             Covered
# 3147  chr7  107916864  Cerebellarataxia             Covered
# 3148  chr7  107915532  Cerebellarataxia             Covered
# 3149  chr7  107917349  Cerebellarataxia             Covered
# 3150  chr7  107917418  Cerebellarataxia             Covered
#
# [2353 rows x 4 columns]

# %%
merged_3 = pd.merge(merged_2, data, on=['CHROM', 'POS'], how='left', sort=False)
merged_3['Literature'] = merged_3['Literature'].fillna('No')
merged_3
# Out:
#        Gene Name         rsID CHROM        POS REF ALT      Zygosity  \
# 0          OR4F5    rs2691305  chr1      69511   A   G    Homozygous
# 1          OR4F5  rs200676709  chr1      69897   T   C  Heterozygous
# 2                           .  chr1     685694   T   C  Heterozygous
# 3                           .  chr1     685694   T   C  Heterozygous
# 4                           .  chr1     685694   T   C  Heterozygous
# ...          ...          ...   ...        ...  ..  ..           ...
# 340652      IL9R    rs2037999  chrX  156003433   T   C    Homozygous
# 340653      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340654      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340655      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
# 340656      IL9R  rs147385831  chrX  156009937   G   A  Heterozygous
#
#                                          Consequence Consequence_score  \
# 0                                   missense variant              7/10
# 1                                 synonymous variant              3/10
# 2                            downstream gene variant              2/10
# 3       intron variant,non coding transcript variant              2/10
# 4       intron variant,non coding transcript variant              2/10
# ...                                              ...               ...
# 340652                     regulatory region variant              2/10
# 340653                              missense variant              7/10
# 340654                           3 prime UTR variant              3/10
# 340655                       downstream gene variant              2/10
# 340656                       downstream gene variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG  \
# 0       MODERATE           5.0
# 1            LOW           2.5
# 2       MODIFIER           1.5
# 3       MODIFIER           1.5
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...
# 340652  MODIFIER           1.5
# 340653  MODERATE           5.0  not provided   benign
# 340654  MODIFIER           1.5  not provided   benign
# 340655  MODIFIER           1.5  not provided   benign
# 340656  MODIFIER           1.5  not provided   benign
#
#                          ClinVar_CLNREVSTAT ClinVar               HGVSc  \
# 0                                                     ENST00000641515.2
# 1                                                     ENST00000641515.2
# 2
# 3                                                     ENST00000419394.2
# 4                                                     ENST00000440200.5
# ...                                     ...     ...                 ...
# 340652
# 340653  criteria provided, single submitter  771064  ENST00000244174.11
# 340654  criteria provided, single submitter  771064   ENST00000369423.7
# 340655  criteria provided, single submitter  771064
# 340656  criteria provided, single submitter  771064
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT   GQ  \
# 0                c.484A>G  ENSP00000493376.2        p.Thr162Ala  1/1  255
# 1                c.870T>C  ENSP00000493376.2        p.Ser290%3D  0/1   82
# 2                    None                                  None  0/1   34
# 3          n.480+17991A>G                                  None  0/1   34
# 4          n.169+34338A>G                                  None  0/1   34
# ...                   ...                ...                ...  ...  ...
# 340652               None                                  None  1/1   58
# 340653          c.1094G>A  ENSP00000244174.5        p.Arg365His  0/1   27
# 340654           c.*85G>A                                  None  0/1   27
# 340655               None                                  None  0/1   27
# 340656               None                                  None  0/1   27
#
#         SDP   DP  RD   AD    FREQ        PVAL RDF RDR ADF ADR  \
# 0       120  120   0  120    100%  1.1001E-71   0   0  86  34
# 1        98   98  73   25  25.51%   5.1517E-9  41  32  11  14
# 2        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 3        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# 4        28   28  18   10  35.71%   3.6855E-4  17   1   9   1
# ...     ...  ...  ..  ...     ...         ...  ..  ..  ..  ..
# 340652   11   11   0   11    100%   1.4176E-6   0   0   7   4
# 340653   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340654   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340655   20   20  12    8     40%    1.638E-3  12   0   8   0
# 340656   20   20  12    8     40%    1.638E-3  12   0   8   0
#
#                    SIFT   PolyPhen      AF AFR_AF  AMR_AF EAS_AF  EUR_AF  \
# 0       tolerated(0.92)  benign(0)
# 1                                   0.6881  0.407  0.6254  0.876  0.7942
# 2
# 3
# 4
# ...                 ...        ...     ...    ...     ...    ...     ...
# 340652
# 340653  tolerated(0.56)  benign(0)
# 340654
# 340655
# 340656
#
#         SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF  \
# 0                  0.9497         0.6075         0.9514         0.9767
# 1       0.8098     0.7209          0.307         0.6749         0.8131
# 2
# 3
# 4
# ...        ...        ...            ...            ...            ...
# 340652              0.441         0.8217         0.3483         0.4304
# 340653            0.01405        0.02867       0.007828        0.01496
# 340654            0.01405        0.02867       0.007828        0.01496
# 340655            0.01405        0.02867       0.007828        0.01496
# 340656            0.01405        0.02867       0.007828        0.01496
#
#        gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0              0.9994         0.9916         0.9726         0.9506
# 1              0.7793         0.8652         0.8438         0.7932
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652          0.702         0.5274         0.3271         0.4035
# 340653        0.01587       0.005438       0.008185        0.02348
# 340654        0.01587       0.005438       0.008185        0.02348
# 340655        0.01587       0.005438       0.008185        0.02348
# 340656        0.01587       0.005438       0.008185        0.02348
#
#        gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0              0.9854      0.846         0.5948          0.998         0.8951
# 1              0.8049     0.4864         0.2916         0.6511         0.4782
# 2
# 3
# 4
# ...               ...        ...            ...            ...            ...
# 340652         0.5578     0.5073          0.809          0.356         0.3772
# 340653         0.0411    0.02864        0.03691        0.04154        0.01196
# 340654         0.0411    0.02864        0.03691        0.04154        0.01196
# 340655         0.0411    0.02864        0.03691        0.04154        0.01196
# 340656         0.0411    0.02864        0.03691        0.04154        0.01196
#
#        gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0              0.9784         0.9998         0.9907            0.9
# 1              0.6714         0.6047         0.6987         0.6441
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 340652         0.4374         0.7099         0.5742         0.4209
# 340653        0.03051        0.02488         0.0722        0.03478
# 340654        0.03051        0.02488         0.0722        0.03478
# 340655        0.03051        0.02488         0.0722        0.03478
# 340656        0.03051        0.02488         0.0722        0.03478
#
#        gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS  \
# 0              0.9674         0.8624         0.9772  0.9998  gnomADg EAS
# 1              0.6751         0.4659          0.622   0.876          EAS
# 2
# 3
# 4
# ...               ...            ...            ...     ...          ...
# 340652         0.3323         0.4516         0.5465  0.8217  gnomADe AFR
# 340653        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340654        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340655        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
# 340656        0.02331        0.02312        0.04483  0.0722  gnomADg FIN
#
#                                BIOTYPE EXON INTRON  \
# 0                       protein coding  3/3
# 1                       protein coding  3/3
# 2                       protein coding
# 3                 processed transcript         3/3
# 4                 processed transcript         1/2
# ...                                ...  ...    ...
# 340652                        enhancer
# 340653                  protein coding  9/9
# 340654                  protein coding  9/9
# 340655                          lncRNA
# 340656  protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED Matched_Gene  \
# 0                                T162A  Aca/Gca      1
# 1                                 S290  tcT/tcC      1
# 2                                  nan              -1
# 3                                  nan              -1
# 4                                  nan              -1
# ...                                ...      ...    ...    ...          ...
# 340652                             nan
# 340653                           R365H  cGt/cAt      1
# 340654                             nan               1
# 340655                             nan              -1
# 340656                             nan               1
#
#        Gene Match Literature Covered/Not_Covered
# 0              No         No                 NaN
# 1              No         No                 NaN
# 2              No         No                 NaN
# 3              No         No                 NaN
# 4              No         No                 NaN
# ...           ...        ...                 ...
# 340652         No         No                 NaN
# 340653         No         No                 NaN
# 340654         No         No                 NaN
# 340655         No         No                 NaN
# 340656         No         No                 NaN
#
# [340657 rows x 72 columns]

# %%
merged_3['Covered/Not_Covered'].value_counts()
# Out:
# Covered    66
# Name: Covered/Not_Covered, dtype: int64
