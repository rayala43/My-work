# %%
import numpy as np
import pandas as pd
import polars as pl
import sys
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px


pd.set_option('display.max_columns',None)
import psycopg2


#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Algorithms to use
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

#Metrics to evaluate the model
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve

import warnings
warnings.filterwarnings("ignore")

#importing PCA and TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
def read_bed_file(bed_file):
    bed_positions = set()
    with open(bed_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Skip header lines if present
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 3:
                chrom = fields[0]
                try:
                    start = int(fields[1])
                    end = int(fields[2])
                except ValueError:
                    continue  # Skip this line if start or end position is not an integer
                for pos in range(start, end + 1):
                    bed_positions.add((chrom, pos))
    return bed_positions

def normalize_chrom_name(chrom):
    return chrom.split('_')[0]

def filter_vcf_file(vcf_file, bed_positions):
    filtered_vcf_records = []
    with open(vcf_file, 'r') as f:
        for line in f:
            if line.startswith('#'):  # Preserve header lines in the output
                filtered_vcf_records.append(line)
                continue
            fields = line.strip().split('\t')
            if len(fields) >= 2:
                raw_chrom = fields[0]
                chrom = normalize_chrom_name(raw_chrom)
                try:
                    pos = int(fields[1])
                except ValueError:
                    continue  # Skip this line if 'POS' is not an integer
                if (chrom, pos) in bed_positions:
                    filtered_vcf_records.append(line)
    return filtered_vcf_records

def write_filtered_vcf(filtered_vcf_records, output_file):
    with open(output_file, 'w') as f:
        for record in filtered_vcf_records:
            f.write(record)

def main():
    bed_file = r'C:/Users/GenepoweRx_Madhu/Downloads/BED_files/kalyani_mam_covered.bed'
    vcf_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Schizophrenia_Annotations.vcf'
    output_file = r'C:/Users/GenepoweRx_Madhu/Downloads/COVERED_VCF_FILES_BED/Schizophrenia_Annotations.vcf'

    bed_positions = read_bed_file(bed_file)
    filtered_vcf_records = filter_vcf_file(vcf_file, bed_positions)
    write_filtered_vcf(filtered_vcf_records, output_file)

if __name__ == "__main__":
    main()

# %%
vcf = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/Fatty_liver_Annotations.vcf', comment= '#', sep = '\t', header=None, low_memory=False)
vcf.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO']#, 'FORMAT', 'SAMPLE']

#sample_cols = vcf['SAMPLE'].str.split(':', expand=True)
#sample_cols.columns = ['GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RBQ', 'ABQ', 'RDF', 'RDR', 'ADF', 'ADR']

# Assign the values to the newly created columns
#vcf = pd.concat([vcf, sample_cols], axis=1)
#vcf = vcf[['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL','RDF', 'RDR', 'ADF', 'ADR']]
vcf
# Out:
#     CHROM       POS         rsID REF    ALT QUAL FILTER  \
# 0    chr2  27508073    rs1260326   T    C,G    .      .
# 1    chr2  27518370     rs780094   T      C    .      .
# 2    chr2  27519736     rs780093   T      C    .      .
# 3    chr4  87310240   rs72613567   T     TA    .      .
# 4    chr4  87310277   rs62305723   G      A    .      .
# 5   chr19  19268740   rs58542926   C    A,T    .      .
# 6   chr22  43928847     rs738409   C  A,G,T    .      .
# 7   chr22  43930116   rs12483959   G  A,C,T    .      .
# 8   chr22  43932850    rs4823173   G      A    .      .
# 9   chr22  43933050  rs143392071   A    C,G    .      .
# 10  chr22  43936690    rs2281135   G    A,C    .      .
# 11  chr22  43937814    rs2896019   T      G    .      .
# 12  chr22  43942254    rs3810622   T  A,C,G    .      .
# 13  chr22  43995806    rs2143571   G    A,C    .      .
#
#                                                  INFO
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...
# 1   RS=780094;dbSNPBuildID=86;SSR=0;GENEINFO=GCKR:...
# 2   RS=780093;dbSNPBuildID=86;SSR=0;GENEINFO=GCKR:...
# 3   RS=72613567;dbSNPBuildID=130;SSR=0;GENEINFO=HS...
# 4   RS=62305723;dbSNPBuildID=129;SSR=0;GENEINFO=HS...
# 5   RS=58542926;dbSNPBuildID=129;SSR=0;GENEINFO=TM...
# 6   RS=738409;dbSNPBuildID=86;SSR=0;GENEINFO=PNPLA...
# 7   RS=12483959;dbSNPBuildID=120;SSR=0;GENEINFO=PN...
# 8   RS=4823173;dbSNPBuildID=111;SSR=0;GENEINFO=PNP...
# 9   RS=143392071;dbSNPBuildID=134;SSR=0;GENEINFO=P...
# 10  RS=2281135;dbSNPBuildID=100;SSR=0;GENEINFO=PNP...
# 11  RS=2896019;dbSNPBuildID=101;SSR=0;GENEINFO=PNP...
# 12  RS=3810622;dbSNPBuildID=107;SSR=0;GENEINFO=PNP...
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...

# %%
vcf['HET'] = vcf['INFO'].str.extract(r'HET=(\d)')
vcf['HOM'] = vcf['INFO'].str.extract(r'HOM=(\d)')

# Create a new column 'Zygosity' based on conditions
vcf['Zygosity'] = ''

vcf.loc[vcf['HOM'] == '1', 'Zygosity'] = 'Homozygous'
vcf.loc[vcf['HET'] == '1', 'Zygosity'] = 'Heterozygous'
vcf['GT'] = vcf['GT'].astype(str)
vcf
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GT'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 9
#       7 vcf.loc[vcf['HOM'] == '1', 'Zygosity'] = 'Homozygous'
#       8 vcf.loc[vcf['HET'] == '1', 'Zygosity'] = 'Heterozygous'
# ----> 9 vcf['GT'] = vcf['GT'].astype(str)
#      10 vcf
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'GT'

# %%
vcf["Gene_Name"] = vcf["INFO"].str.extract('GENEINFO=(?P<GENEINFO>.+?);')
#vcf['Gene Name'] = vcf['Gene_Name'].apply(lambda x: ','.join([segment.split(':')[0] for segment in x.split('|')]) if pd.notnull(x) else '')
vcf['Gene Name'] = vcf['Gene_Name'].apply(lambda x: ','.join(set([segment.split(':')[0] for segment in x.split('|')])) if pd.notnull(x) else '')
vcf
# Out:
#     CHROM       POS         rsID REF    ALT QUAL FILTER  \
# 0    chr2  27508073    rs1260326   T    C,G    .      .
# 1    chr2  27518370     rs780094   T      C    .      .
# 2    chr2  27519736     rs780093   T      C    .      .
# 3    chr4  87310240   rs72613567   T     TA    .      .
# 4    chr4  87310277   rs62305723   G      A    .      .
# 5   chr19  19268740   rs58542926   C    A,T    .      .
# 6   chr22  43928847     rs738409   C  A,G,T    .      .
# 7   chr22  43930116   rs12483959   G  A,C,T    .      .
# 8   chr22  43932850    rs4823173   G      A    .      .
# 9   chr22  43933050  rs143392071   A    C,G    .      .
# 10  chr22  43936690    rs2281135   G    A,C    .      .
# 11  chr22  43937814    rs2896019   T      G    .      .
# 12  chr22  43942254    rs3810622   T  A,C,G    .      .
# 13  chr22  43995806    rs2143571   G    A,C    .      .
#
#                                                  INFO        Gene_Name  \
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...        GCKR:2646
# 1   RS=780094;dbSNPBuildID=86;SSR=0;GENEINFO=GCKR:...        GCKR:2646
# 2   RS=780093;dbSNPBuildID=86;SSR=0;GENEINFO=GCKR:...        GCKR:2646
# 3   RS=72613567;dbSNPBuildID=130;SSR=0;GENEINFO=HS...  HSD17B13:345275
# 4   RS=62305723;dbSNPBuildID=129;SSR=0;GENEINFO=HS...  HSD17B13:345275
# 5   RS=58542926;dbSNPBuildID=129;SSR=0;GENEINFO=TM...     TM6SF2:53345
# 6   RS=738409;dbSNPBuildID=86;SSR=0;GENEINFO=PNPLA...     PNPLA3:80339
# 7   RS=12483959;dbSNPBuildID=120;SSR=0;GENEINFO=PN...     PNPLA3:80339
# 8   RS=4823173;dbSNPBuildID=111;SSR=0;GENEINFO=PNP...     PNPLA3:80339
# 9   RS=143392071;dbSNPBuildID=134;SSR=0;GENEINFO=P...     PNPLA3:80339
# 10  RS=2281135;dbSNPBuildID=100;SSR=0;GENEINFO=PNP...     PNPLA3:80339
# 11  RS=2896019;dbSNPBuildID=101;SSR=0;GENEINFO=PNP...     PNPLA3:80339
# 12  RS=3810622;dbSNPBuildID=107;SSR=0;GENEINFO=PNP...     PNPLA3:80339
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...     SAMM50:25813
#
#    Gene Name
# 0       GCKR
# 1       GCKR
# 2       GCKR
# 3   HSD17B13
# 4   HSD17B13
# 5     TM6SF2
# 6     PNPLA3
# 7     PNPLA3
# 8     PNPLA3
# 9     PNPLA3
# 10    PNPLA3
# 11    PNPLA3
# 12    PNPLA3
# 13    SAMM50

# %%
vcf['CSQ'] = vcf['INFO'].str.extract(r'CSQ=(.*)')
vcf['csq'] = vcf['CSQ'].str.split(',')
vcf = vcf.explode('csq')
vcf
# Out:
#     CHROM       POS       rsID REF  ALT QUAL FILTER  \
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# ..    ...       ...        ...  ..  ...  ...    ...
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
#
#                                                  INFO     Gene_Name Gene Name  \
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# ..                                                ...           ...       ...
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
#
#                                                   CSQ  \
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# ..                                                ...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
#
#                                                   csq
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   G|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   G|missense_variant&splice_region_variant|MODER...
# 0   C|downstream_gene_variant|MODIFIER|GCKR|ENSG00...
# ..                                                ...
# 13  C|intron_variant&non_coding_transcript_variant...
# 13  A|intron_variant&non_coding_transcript_variant...
# 13  C|intron_variant&non_coding_transcript_variant...
# 13  A|regulatory_region_variant|MODIFIER|||Regulat...
# 13  C|regulatory_region_variant|MODIFIER|||Regulat...
#
# [110 rows x 12 columns]

# %%
########################################################### Required columns extraction from the CSQ column ####################
vcf['ClinVar_CLNDN'] = vcf['csq'].str.split('|').str[82]
vcf['Allele'] = vcf['csq'].str.split('|').str[0]
vcf['CLIN_SIG'] = vcf['csq'].str.split('|').str[70]
vcf['ClinVar_CLNREVSTAT'] = vcf['csq'].str.split('|').str[81]
vcf['ClinVar'] = vcf['csq'].str.split('|').str[79]
vcf['HGVSC'] = vcf['csq'].str.split('|').str[10]
vcf['HGVSP'] = vcf['csq'].str.split('|').str[11]
vcf['PolyPhen'] = vcf['csq'].str.split('|').str[38]
vcf['BIOTYPE'] = vcf['csq'].str.split('|').str[7]
vcf['EXON'] = vcf['csq'].str.split('|').str[8]
vcf['INTRON'] = vcf['csq'].str.split('|').str[9]
vcf['Protein_position'] = vcf['csq'].str.split('|').str[14]
vcf['Amino_acids'] = vcf['csq'].str.split('|').str[15]
vcf['Codons'] = vcf['csq'].str.split('|').str[16]
vcf['STRAND'] = vcf['csq'].str.split('|').str[19]
vcf['PUBMED'] = vcf['csq'].str.split('|').str[73]
vcf['Consequence'] = vcf['csq'].str.split('|').str[1]
vcf['IMPACT'] = vcf['csq'].str.split('|').str[2]
vcf['SIFT'] = vcf['csq'].str.split('|').str[37]
################################################## Frequency columns extraction ################################################
vcf['AF'] = vcf['csq'].str.split('|').str[42]
vcf['AFR_AF'] = vcf['csq'].str.split('|').str[43]
vcf['AMR_AF'] = vcf['csq'].str.split('|').str[44]
vcf['EAS_AF'] = vcf['csq'].str.split('|').str[45]
vcf['EUR_AF'] = vcf['csq'].str.split('|').str[46]
vcf['SAS_AF'] = vcf['csq'].str.split('|').str[47]
vcf['gnomADe_AF'] = vcf['csq'].str.split('|').str[48]
vcf['gnomADe_AFR_AF'] = vcf['csq'].str.split('|').str[49]
vcf['gnomADe_AMR_AF'] = vcf['csq'].str.split('|').str[50]
vcf['gnomADe_ASJ_AF'] = vcf['csq'].str.split('|').str[51]
vcf['gnomADe_EAS_AF'] = vcf['csq'].str.split('|').str[52]
vcf['gnomADe_FIN_AF'] = vcf['csq'].str.split('|').str[53]
vcf['gnomADe_NFE_AF'] = vcf['csq'].str.split('|').str[54]
vcf['gnomADe_OTH_AF'] = vcf['csq'].str.split('|').str[55]
vcf['gnomADe_SAS_AF'] = vcf['csq'].str.split('|').str[56]
vcf['gnomADg_AF'] = vcf['csq'].str.split('|').str[57]
vcf['gnomADg_AFR_AF'] = vcf['csq'].str.split('|').str[58]
vcf['gnomADg_AMI_AF'] = vcf['csq'].str.split('|').str[59]
vcf['gnomADg_AMR_AF'] = vcf['csq'].str.split('|').str[60]
vcf['gnomADg_ASJ_AF'] = vcf['csq'].str.split('|').str[61]
vcf['gnomADg_EAS_AF'] = vcf['csq'].str.split('|').str[62]
vcf['gnomADg_FIN_AF'] = vcf['csq'].str.split('|').str[63]
vcf['gnomADg_MID_AF'] = vcf['csq'].str.split('|').str[64]
vcf['gnomADg_NFE_AF'] = vcf['csq'].str.split('|').str[65]
vcf['gnomADg_OTH_AF'] = vcf['csq'].str.split('|').str[66]
vcf['gnomADg_SAS_AF'] = vcf['csq'].str.split('|').str[67]
vcf['MAX_AF'] = vcf['csq'].str.split('|').str[68]
vcf['MAX_AF_POPS'] = vcf['csq'].str.split('|').str[69]
vcf
# Out:
#     CHROM       POS       rsID REF  ALT QUAL FILTER  \
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# ..    ...       ...        ...  ..  ...  ...    ...
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
#
#                                                  INFO     Gene_Name Gene Name  \
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# ..                                                ...           ...       ...
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
#
#                                                   CSQ  \
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# ..                                                ...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
#
#                                                   csq  \
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   G|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   G|missense_variant&splice_region_variant|MODER...
# 0   C|downstream_gene_variant|MODIFIER|GCKR|ENSG00...
# ..                                                ...
# 13  C|intron_variant&non_coding_transcript_variant...
# 13  A|intron_variant&non_coding_transcript_variant...
# 13  C|intron_variant&non_coding_transcript_variant...
# 13  A|regulatory_region_variant|MODIFIER|||Regulat...
# 13  C|regulatory_region_variant|MODIFIER|||Regulat...
#
#                                         ClinVar_CLNDN Allele  \
# 0   not_provided&Fasting_plasma_glucose_level_quan...      C
# 0                                                          G
# 0   not_provided&Fasting_plasma_glucose_level_quan...      C
# 0                                                          G
# 0   not_provided&Fasting_plasma_glucose_level_quan...      C
# ..                                                ...    ...
# 13                                                         C
# 13                                                         A
# 13                                                         C
# 13                                                         A
# 13                                                         C
#
#               CLIN_SIG                                 ClinVar_CLNREVSTAT  \
# 0   benign&association  criteria_provided&_multiple_submitters&_no_con...
# 0
# 0   benign&association  criteria_provided&_multiple_submitters&_no_con...
# 0
# 0   benign&association  criteria_provided&_multiple_submitters&_no_con...
# ..                 ...                                                ...
# 13
# 13
# 13
# 13
# 13
#
#    ClinVar                            HGVSC                          HGVSP  \
# 0     8751      ENST00000264717.7:c.1337T>C  ENSP00000264717.2:p.Leu446Pro
# 0               ENST00000264717.7:c.1337T>G  ENSP00000264717.2:p.Leu446Arg
# 0     8751       ENST00000411584.1:c.440T>C  ENSP00000416917.1:p.Leu147Pro
# 0                ENST00000411584.1:c.440T>G  ENSP00000416917.1:p.Leu147Arg
# 0     8751
# ..     ...                              ...                            ...
# 13           ENST00000493621.1:n.100+316G>C
# 13          ENST00000494795.1:n.3057-532G>A
# 13          ENST00000494795.1:n.3057-532G>C
# 13
# 13
#
#          PolyPhen                         BIOTYPE   EXON INTRON  \
# 0       benign(0)                  protein_coding  15/19
# 0       benign(0)                  protein_coding  15/19
# 0   benign(0.001)                  protein_coding    5/7
# 0   benign(0.286)                  protein_coding    5/7
# 0                                 retained_intron
# ..            ...                             ...    ...    ...
# 13                 protein_coding_CDS_not_defined           1/1
# 13                                retained_intron           2/2
# 13                                retained_intron           2/2
# 13                                       promoter
# 13                                       promoter
#
#    Protein_position Amino_acids   Codons STRAND  \
# 0               446         L/P  cTg/cCg      1
# 0               446         L/R  cTg/cGg      1
# 0               147         L/P  cTg/cCg      1
# 0               147         L/R  cTg/cGg      1
# 0                                             1
# ..              ...         ...      ...    ...
# 13                                            1
# 13                                            1
# 13                                            1
# 13
# 13
#
#                                                PUBMED  \
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# ..                                                ...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
#
#                                      Consequence    IMPACT             SIFT  \
# 0         missense_variant&splice_region_variant  MODERATE     tolerated(1)
# 0         missense_variant&splice_region_variant  MODERATE  tolerated(0.06)
# 0         missense_variant&splice_region_variant  MODERATE     tolerated(1)
# 0         missense_variant&splice_region_variant  MODERATE  tolerated(0.06)
# 0                        downstream_gene_variant  MODIFIER
# ..                                           ...       ...              ...
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13                     regulatory_region_variant  MODIFIER
# 13                     regulatory_region_variant  MODIFIER
#
#         AF  AFR_AF  AMR_AF  EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF  \
# 0   0.7067  0.9062  0.6383  0.5188  0.5895  0.7996     0.6331         0.8679
# 0                                                   3.982e-06              0
# 0   0.7067  0.9062  0.6383  0.5188  0.5895  0.7996     0.6331         0.8679
# 0                                                   3.982e-06              0
# 0   0.7067  0.9062  0.6383  0.5188  0.5895  0.7996     0.6331         0.8679
# ..     ...     ...     ...     ...     ...     ...        ...            ...
# 13
# 13  0.3075  0.3797  0.3415  0.3661  0.2087   0.227
# 13
# 13  0.3075  0.3797  0.3415  0.3661  0.2087   0.227
# 13
#
#    gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF  \
# 0          0.6662         0.4668         0.5108         0.6426         0.5902
# 0               0              0      5.444e-05              0              0
# 0          0.6662         0.4668         0.5108         0.6426         0.5902
# 0               0              0      5.444e-05              0              0
# 0          0.6662         0.4668         0.5108         0.6426         0.5902
# ..            ...            ...            ...            ...            ...
# 13
# 13
# 13
# 13
# 13
#
#    gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF  \
# 0          0.6005          0.758       0.67         0.8582         0.7083
# 0               0              0
# 0          0.6005          0.758       0.67         0.8582         0.7083
# 0               0              0
# 0          0.6005          0.758       0.67         0.8582         0.7083
# ..            ...            ...        ...            ...            ...
# 13
# 13                                   0.2519         0.3536         0.2325
# 13
# 13                                   0.2519         0.3536         0.2325
# 13
#
#    gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0           0.626         0.4585         0.5014         0.6378         0.4904
# 0
# 0           0.626         0.4585         0.5014         0.6378         0.4904
# 0
# 0           0.626         0.4585         0.5014         0.6378         0.4904
# ..            ...            ...            ...            ...            ...
# 13
# 13         0.3173         0.1317         0.3875         0.2268         0.2184
# 13
# 13         0.3173         0.1317         0.3875         0.2268         0.2184
# 13
#
#    gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF     MAX_AF  MAX_AF_POPS
# 0          0.5898         0.6106         0.7566     0.9062          AFR
# 0                                                5.444e-05  gnomADe_EAS
# 0          0.5898         0.6106         0.7566     0.9062          AFR
# 0                                                5.444e-05  gnomADe_EAS
# 0          0.5898         0.6106         0.7566     0.9062          AFR
# ..            ...            ...            ...        ...          ...
# 13
# 13         0.1789         0.2555         0.2035     0.3875  gnomADg_EAS
# 13
# 13         0.1789         0.2555         0.2035     0.3875  gnomADg_EAS
# 13
#
# [110 rows x 59 columns]

# %%
vcf['Protein Position and Amino Acid'] = vcf['Amino_acids'].str[0] + vcf['Protein_position'] + np.where(vcf['Amino_acids'].str[-1] == vcf['Amino_acids'].str[0], '', vcf['Amino_acids'].str[-1])
vcf
# Out:
#     CHROM       POS       rsID REF  ALT QUAL FILTER  \
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# ..    ...       ...        ...  ..  ...  ...    ...
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
#
#                                                  INFO     Gene_Name Gene Name  \
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# ..                                                ...           ...       ...
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
#
#                                                   CSQ  \
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# ..                                                ...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
#
#                                                   csq  \
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   G|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   G|missense_variant&splice_region_variant|MODER...
# 0   C|downstream_gene_variant|MODIFIER|GCKR|ENSG00...
# ..                                                ...
# 13  C|intron_variant&non_coding_transcript_variant...
# 13  A|intron_variant&non_coding_transcript_variant...
# 13  C|intron_variant&non_coding_transcript_variant...
# 13  A|regulatory_region_variant|MODIFIER|||Regulat...
# 13  C|regulatory_region_variant|MODIFIER|||Regulat...
#
#                                         ClinVar_CLNDN Allele  \
# 0   not_provided&Fasting_plasma_glucose_level_quan...      C
# 0                                                          G
# 0   not_provided&Fasting_plasma_glucose_level_quan...      C
# 0                                                          G
# 0   not_provided&Fasting_plasma_glucose_level_quan...      C
# ..                                                ...    ...
# 13                                                         C
# 13                                                         A
# 13                                                         C
# 13                                                         A
# 13                                                         C
#
#               CLIN_SIG                                 ClinVar_CLNREVSTAT  \
# 0   benign&association  criteria_provided&_multiple_submitters&_no_con...
# 0
# 0   benign&association  criteria_provided&_multiple_submitters&_no_con...
# 0
# 0   benign&association  criteria_provided&_multiple_submitters&_no_con...
# ..                 ...                                                ...
# 13
# 13
# 13
# 13
# 13
#
#    ClinVar                            HGVSC                          HGVSP  \
# 0     8751      ENST00000264717.7:c.1337T>C  ENSP00000264717.2:p.Leu446Pro
# 0               ENST00000264717.7:c.1337T>G  ENSP00000264717.2:p.Leu446Arg
# 0     8751       ENST00000411584.1:c.440T>C  ENSP00000416917.1:p.Leu147Pro
# 0                ENST00000411584.1:c.440T>G  ENSP00000416917.1:p.Leu147Arg
# 0     8751
# ..     ...                              ...                            ...
# 13           ENST00000493621.1:n.100+316G>C
# 13          ENST00000494795.1:n.3057-532G>A
# 13          ENST00000494795.1:n.3057-532G>C
# 13
# 13
#
#          PolyPhen                         BIOTYPE   EXON INTRON  \
# 0       benign(0)                  protein_coding  15/19
# 0       benign(0)                  protein_coding  15/19
# 0   benign(0.001)                  protein_coding    5/7
# 0   benign(0.286)                  protein_coding    5/7
# 0                                 retained_intron
# ..            ...                             ...    ...    ...
# 13                 protein_coding_CDS_not_defined           1/1
# 13                                retained_intron           2/2
# 13                                retained_intron           2/2
# 13                                       promoter
# 13                                       promoter
#
#    Protein_position Amino_acids   Codons STRAND  \
# 0               446         L/P  cTg/cCg      1
# 0               446         L/R  cTg/cGg      1
# 0               147         L/P  cTg/cCg      1
# 0               147         L/R  cTg/cGg      1
# 0                                             1
# ..              ...         ...      ...    ...
# 13                                            1
# 13                                            1
# 13                                            1
# 13
# 13
#
#                                                PUBMED  \
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# ..                                                ...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
#
#                                      Consequence    IMPACT             SIFT  \
# 0         missense_variant&splice_region_variant  MODERATE     tolerated(1)
# 0         missense_variant&splice_region_variant  MODERATE  tolerated(0.06)
# 0         missense_variant&splice_region_variant  MODERATE     tolerated(1)
# 0         missense_variant&splice_region_variant  MODERATE  tolerated(0.06)
# 0                        downstream_gene_variant  MODIFIER
# ..                                           ...       ...              ...
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13                     regulatory_region_variant  MODIFIER
# 13                     regulatory_region_variant  MODIFIER
#
#         AF  AFR_AF  AMR_AF  EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF  \
# 0   0.7067  0.9062  0.6383  0.5188  0.5895  0.7996     0.6331         0.8679
# 0                                                   3.982e-06              0
# 0   0.7067  0.9062  0.6383  0.5188  0.5895  0.7996     0.6331         0.8679
# 0                                                   3.982e-06              0
# 0   0.7067  0.9062  0.6383  0.5188  0.5895  0.7996     0.6331         0.8679
# ..     ...     ...     ...     ...     ...     ...        ...            ...
# 13
# 13  0.3075  0.3797  0.3415  0.3661  0.2087   0.227
# 13
# 13  0.3075  0.3797  0.3415  0.3661  0.2087   0.227
# 13
#
#    gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF  \
# 0          0.6662         0.4668         0.5108         0.6426         0.5902
# 0               0              0      5.444e-05              0              0
# 0          0.6662         0.4668         0.5108         0.6426         0.5902
# 0               0              0      5.444e-05              0              0
# 0          0.6662         0.4668         0.5108         0.6426         0.5902
# ..            ...            ...            ...            ...            ...
# 13
# 13
# 13
# 13
# 13
#
#    gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF  \
# 0          0.6005          0.758       0.67         0.8582         0.7083
# 0               0              0
# 0          0.6005          0.758       0.67         0.8582         0.7083
# 0               0              0
# 0          0.6005          0.758       0.67         0.8582         0.7083
# ..            ...            ...        ...            ...            ...
# 13
# 13                                   0.2519         0.3536         0.2325
# 13
# 13                                   0.2519         0.3536         0.2325
# 13
#
#    gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0           0.626         0.4585         0.5014         0.6378         0.4904
# 0
# 0           0.626         0.4585         0.5014         0.6378         0.4904
# 0
# 0           0.626         0.4585         0.5014         0.6378         0.4904
# ..            ...            ...            ...            ...            ...
# 13
# 13         0.3173         0.1317         0.3875         0.2268         0.2184
# 13
# 13         0.3173         0.1317         0.3875         0.2268         0.2184
# 13
#
#    gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF     MAX_AF  MAX_AF_POPS  \
# 0          0.5898         0.6106         0.7566     0.9062          AFR
# 0                                                5.444e-05  gnomADe_EAS
# 0          0.5898         0.6106         0.7566     0.9062          AFR
# 0                                                5.444e-05  gnomADe_EAS
# 0          0.5898         0.6106         0.7566     0.9062          AFR
# ..            ...            ...            ...        ...          ...
# 13
# 13         0.1789         0.2555         0.2035     0.3875  gnomADg_EAS
# 13
# 13         0.1789         0.2555         0.2035     0.3875  gnomADg_EAS
# 13
#
#    Protein Position and Amino Acid
# 0                            L446P
# 0                            L446R
# 0                            L147P
# 0                            L147R
# 0                              NaN
# ..                             ...
# 13                             NaN
# 13                             NaN
# 13                             NaN
# 13                             NaN
# 13                             NaN
#
# [110 rows x 60 columns]

# %%
vcf[['HGVSc', 'HGVSc (Transcript)']] = vcf['HGVSC'].str.split(':', 1, expand=True)
vcf[['HGVSp', 'HGVSp (Transcript)']] = vcf['HGVSP'].str.split(':', 1, expand=True)
vcf
# Out:
#     CHROM       POS       rsID REF  ALT QUAL FILTER  \
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# 0    chr2  27508073  rs1260326   T  C,G    .      .
# ..    ...       ...        ...  ..  ...  ...    ...
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
# 13  chr22  43995806  rs2143571   G  A,C    .      .
#
#                                                  INFO     Gene_Name Gene Name  \
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# 0   RS=1260326;dbSNPBuildID=87;SSR=0;GENEINFO=GCKR...     GCKR:2646      GCKR
# ..                                                ...           ...       ...
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
# 13  RS=2143571;dbSNPBuildID=96;SSR=0;GENEINFO=SAMM...  SAMM50:25813    SAMM50
#
#                                                   CSQ  \
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# ..                                                ...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
# 13  A|intron_variant|MODIFIER|SAMM50|ENSG000001003...
#
#                                                   csq  \
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   G|missense_variant&splice_region_variant|MODER...
# 0   C|missense_variant&splice_region_variant|MODER...
# 0   G|missense_variant&splice_region_variant|MODER...
# 0   C|downstream_gene_variant|MODIFIER|GCKR|ENSG00...
# ..                                                ...
# 13  C|intron_variant&non_coding_transcript_variant...
# 13  A|intron_variant&non_coding_transcript_variant...
# 13  C|intron_variant&non_coding_transcript_variant...
# 13  A|regulatory_region_variant|MODIFIER|||Regulat...
# 13  C|regulatory_region_variant|MODIFIER|||Regulat...
#
#                                         ClinVar_CLNDN Allele  \
# 0   not_provided&Fasting_plasma_glucose_level_quan...      C
# 0                                                          G
# 0   not_provided&Fasting_plasma_glucose_level_quan...      C
# 0                                                          G
# 0   not_provided&Fasting_plasma_glucose_level_quan...      C
# ..                                                ...    ...
# 13                                                         C
# 13                                                         A
# 13                                                         C
# 13                                                         A
# 13                                                         C
#
#               CLIN_SIG                                 ClinVar_CLNREVSTAT  \
# 0   benign&association  criteria_provided&_multiple_submitters&_no_con...
# 0
# 0   benign&association  criteria_provided&_multiple_submitters&_no_con...
# 0
# 0   benign&association  criteria_provided&_multiple_submitters&_no_con...
# ..                 ...                                                ...
# 13
# 13
# 13
# 13
# 13
#
#    ClinVar                            HGVSC                          HGVSP  \
# 0     8751      ENST00000264717.7:c.1337T>C  ENSP00000264717.2:p.Leu446Pro
# 0               ENST00000264717.7:c.1337T>G  ENSP00000264717.2:p.Leu446Arg
# 0     8751       ENST00000411584.1:c.440T>C  ENSP00000416917.1:p.Leu147Pro
# 0                ENST00000411584.1:c.440T>G  ENSP00000416917.1:p.Leu147Arg
# 0     8751
# ..     ...                              ...                            ...
# 13           ENST00000493621.1:n.100+316G>C
# 13          ENST00000494795.1:n.3057-532G>A
# 13          ENST00000494795.1:n.3057-532G>C
# 13
# 13
#
#          PolyPhen                         BIOTYPE   EXON INTRON  \
# 0       benign(0)                  protein_coding  15/19
# 0       benign(0)                  protein_coding  15/19
# 0   benign(0.001)                  protein_coding    5/7
# 0   benign(0.286)                  protein_coding    5/7
# 0                                 retained_intron
# ..            ...                             ...    ...    ...
# 13                 protein_coding_CDS_not_defined           1/1
# 13                                retained_intron           2/2
# 13                                retained_intron           2/2
# 13                                       promoter
# 13                                       promoter
#
#    Protein_position Amino_acids   Codons STRAND  \
# 0               446         L/P  cTg/cCg      1
# 0               446         L/R  cTg/cGg      1
# 0               147         L/P  cTg/cCg      1
# 0               147         L/R  cTg/cGg      1
# 0                                             1
# ..              ...         ...      ...    ...
# 13                                            1
# 13                                            1
# 13                                            1
# 13
# 13
#
#                                                PUBMED  \
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# ..                                                ...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
#
#                                      Consequence    IMPACT             SIFT  \
# 0         missense_variant&splice_region_variant  MODERATE     tolerated(1)
# 0         missense_variant&splice_region_variant  MODERATE  tolerated(0.06)
# 0         missense_variant&splice_region_variant  MODERATE     tolerated(1)
# 0         missense_variant&splice_region_variant  MODERATE  tolerated(0.06)
# 0                        downstream_gene_variant  MODIFIER
# ..                                           ...       ...              ...
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13                     regulatory_region_variant  MODIFIER
# 13                     regulatory_region_variant  MODIFIER
#
#         AF  AFR_AF  AMR_AF  EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF  \
# 0   0.7067  0.9062  0.6383  0.5188  0.5895  0.7996     0.6331         0.8679
# 0                                                   3.982e-06              0
# 0   0.7067  0.9062  0.6383  0.5188  0.5895  0.7996     0.6331         0.8679
# 0                                                   3.982e-06              0
# 0   0.7067  0.9062  0.6383  0.5188  0.5895  0.7996     0.6331         0.8679
# ..     ...     ...     ...     ...     ...     ...        ...            ...
# 13
# 13  0.3075  0.3797  0.3415  0.3661  0.2087   0.227
# 13
# 13  0.3075  0.3797  0.3415  0.3661  0.2087   0.227
# 13
#
#    gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF  \
# 0          0.6662         0.4668         0.5108         0.6426         0.5902
# 0               0              0      5.444e-05              0              0
# 0          0.6662         0.4668         0.5108         0.6426         0.5902
# 0               0              0      5.444e-05              0              0
# 0          0.6662         0.4668         0.5108         0.6426         0.5902
# ..            ...            ...            ...            ...            ...
# 13
# 13
# 13
# 13
# 13
#
#    gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF  \
# 0          0.6005          0.758       0.67         0.8582         0.7083
# 0               0              0
# 0          0.6005          0.758       0.67         0.8582         0.7083
# 0               0              0
# 0          0.6005          0.758       0.67         0.8582         0.7083
# ..            ...            ...        ...            ...            ...
# 13
# 13                                   0.2519         0.3536         0.2325
# 13
# 13                                   0.2519         0.3536         0.2325
# 13
#
#    gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF  \
# 0           0.626         0.4585         0.5014         0.6378         0.4904
# 0
# 0           0.626         0.4585         0.5014         0.6378         0.4904
# 0
# 0           0.626         0.4585         0.5014         0.6378         0.4904
# ..            ...            ...            ...            ...            ...
# 13
# 13         0.3173         0.1317         0.3875         0.2268         0.2184
# 13
# 13         0.3173         0.1317         0.3875         0.2268         0.2184
# 13
#
#    gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF     MAX_AF  MAX_AF_POPS  \
# 0          0.5898         0.6106         0.7566     0.9062          AFR
# 0                                                5.444e-05  gnomADe_EAS
# 0          0.5898         0.6106         0.7566     0.9062          AFR
# 0                                                5.444e-05  gnomADe_EAS
# 0          0.5898         0.6106         0.7566     0.9062          AFR
# ..            ...            ...            ...        ...          ...
# 13
# 13         0.1789         0.2555         0.2035     0.3875  gnomADg_EAS
# 13
# 13         0.1789         0.2555         0.2035     0.3875  gnomADg_EAS
# 13
#
#    Protein Position and Amino Acid              HGVSc HGVSc (Transcript)  \
# 0                            L446P  ENST00000264717.7          c.1337T>C
# 0                            L446R  ENST00000264717.7          c.1337T>G
# 0                            L147P  ENST00000411584.1           c.440T>C
# 0                            L147R  ENST00000411584.1           c.440T>G
# 0                              NaN                                  None
# ..                             ...                ...                ...
# 13                             NaN  ENST00000493621.1       n.100+316G>C
# 13                             NaN  ENST00000494795.1      n.3057-532G>A
# 13                             NaN  ENST00000494795.1      n.3057-532G>C
# 13                             NaN                                  None
# 13                             NaN                                  None
#
#                 HGVSp HGVSp (Transcript)
# 0   ENSP00000264717.2        p.Leu446Pro
# 0   ENSP00000264717.2        p.Leu446Arg
# 0   ENSP00000416917.1        p.Leu147Pro
# 0   ENSP00000416917.1        p.Leu147Arg
# 0                                   None
# ..                ...                ...
# 13                                  None
# 13                                  None
# 13                                  None
# 13                                  None
# 13                                  None
#
# [110 rows x 64 columns]

# %%
vcf_final = vcf[['Gene Name', 'rsID','CHROM', 'POS', 'REF', 'ALT', 'Allele', 'Consequence', 'IMPACT',
          'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT',
          'ClinVar', 'HGVSc', 'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'SIFT', 'PolyPhen', 'AF', 'AFR_AF', 'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF',
       'gnomADe_AF', 'gnomADe_AFR_AF', 'gnomADe_AMR_AF', 'gnomADe_ASJ_AF',
       'gnomADe_EAS_AF', 'gnomADe_FIN_AF', 'gnomADe_NFE_AF', 'gnomADe_OTH_AF',
       'gnomADe_SAS_AF', 'gnomADg_AF', 'gnomADg_AFR_AF', 'gnomADg_AMI_AF',
       'gnomADg_AMR_AF', 'gnomADg_ASJ_AF', 'gnomADg_EAS_AF', 'gnomADg_FIN_AF',
       'gnomADg_MID_AF', 'gnomADg_NFE_AF', 'gnomADg_OTH_AF', 'gnomADg_SAS_AF',
       'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE', 'EXON', 'INTRON',
          'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED']]
vcf_final
# Out:
#    Gene Name       rsID  CHROM       POS REF  ALT Allele  \
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      C
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      G
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      C
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      G
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      C
# ..       ...        ...    ...       ...  ..  ...    ...
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      C
#
#                                      Consequence    IMPACT  \
# 0         missense_variant&splice_region_variant  MODERATE
# 0         missense_variant&splice_region_variant  MODERATE
# 0         missense_variant&splice_region_variant  MODERATE
# 0         missense_variant&splice_region_variant  MODERATE
# 0                        downstream_gene_variant  MODIFIER
# ..                                           ...       ...
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13                     regulatory_region_variant  MODIFIER
# 13                     regulatory_region_variant  MODIFIER
#
#                                         ClinVar_CLNDN            CLIN_SIG  \
# 0   not_provided&Fasting_plasma_glucose_level_quan...  benign&association
# 0
# 0   not_provided&Fasting_plasma_glucose_level_quan...  benign&association
# 0
# 0   not_provided&Fasting_plasma_glucose_level_quan...  benign&association
# ..                                                ...                 ...
# 13
# 13
# 13
# 13
# 13
#
#                                    ClinVar_CLNREVSTAT ClinVar  \
# 0   criteria_provided&_multiple_submitters&_no_con...    8751
# 0
# 0   criteria_provided&_multiple_submitters&_no_con...    8751
# 0
# 0   criteria_provided&_multiple_submitters&_no_con...    8751
# ..                                                ...     ...
# 13
# 13
# 13
# 13
# 13
#
#                 HGVSc HGVSc (Transcript)              HGVSp  \
# 0   ENST00000264717.7          c.1337T>C  ENSP00000264717.2
# 0   ENST00000264717.7          c.1337T>G  ENSP00000264717.2
# 0   ENST00000411584.1           c.440T>C  ENSP00000416917.1
# 0   ENST00000411584.1           c.440T>G  ENSP00000416917.1
# 0                                   None
# ..                ...                ...                ...
# 13  ENST00000493621.1       n.100+316G>C
# 13  ENST00000494795.1      n.3057-532G>A
# 13  ENST00000494795.1      n.3057-532G>C
# 13                                  None
# 13                                  None
#
#    HGVSp (Transcript)             SIFT       PolyPhen      AF  AFR_AF  AMR_AF  \
# 0         p.Leu446Pro     tolerated(1)      benign(0)  0.7067  0.9062  0.6383
# 0         p.Leu446Arg  tolerated(0.06)      benign(0)
# 0         p.Leu147Pro     tolerated(1)  benign(0.001)  0.7067  0.9062  0.6383
# 0         p.Leu147Arg  tolerated(0.06)  benign(0.286)
# 0                None                                  0.7067  0.9062  0.6383
# ..                ...              ...            ...     ...     ...     ...
# 13               None
# 13               None                                  0.3075  0.3797  0.3415
# 13               None
# 13               None                                  0.3075  0.3797  0.3415
# 13               None
#
#     EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF  \
# 0   0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 0                           3.982e-06              0              0
# 0   0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 0                           3.982e-06              0              0
# 0   0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# ..     ...     ...     ...        ...            ...            ...
# 13
# 13  0.3661  0.2087   0.227
# 13
# 13  0.3661  0.2087   0.227
# 13
#
#    gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0          0.4668         0.5108         0.6426         0.5902         0.6005
# 0               0      5.444e-05              0              0              0
# 0          0.4668         0.5108         0.6426         0.5902         0.6005
# 0               0      5.444e-05              0              0              0
# 0          0.4668         0.5108         0.6426         0.5902         0.6005
# ..            ...            ...            ...            ...            ...
# 13
# 13
# 13
# 13
# 13
#
#    gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0           0.758       0.67         0.8582         0.7083          0.626
# 0               0
# 0           0.758       0.67         0.8582         0.7083          0.626
# 0               0
# 0           0.758       0.67         0.8582         0.7083          0.626
# ..            ...        ...            ...            ...            ...
# 13
# 13                    0.2519         0.3536         0.2325         0.3173
# 13
# 13                    0.2519         0.3536         0.2325         0.3173
# 13
#
#    gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0          0.4585         0.5014         0.6378         0.4904         0.5898
# 0
# 0          0.4585         0.5014         0.6378         0.4904         0.5898
# 0
# 0          0.4585         0.5014         0.6378         0.4904         0.5898
# ..            ...            ...            ...            ...            ...
# 13
# 13         0.1317         0.3875         0.2268         0.2184         0.1789
# 13
# 13         0.1317         0.3875         0.2268         0.2184         0.1789
# 13
#
#    gnomADg_OTH_AF gnomADg_SAS_AF     MAX_AF  MAX_AF_POPS  \
# 0          0.6106         0.7566     0.9062          AFR
# 0                                 5.444e-05  gnomADe_EAS
# 0          0.6106         0.7566     0.9062          AFR
# 0                                 5.444e-05  gnomADe_EAS
# 0          0.6106         0.7566     0.9062          AFR
# ..            ...            ...        ...          ...
# 13
# 13         0.2555         0.2035     0.3875  gnomADg_EAS
# 13
# 13         0.2555         0.2035     0.3875  gnomADg_EAS
# 13
#
#                            BIOTYPE   EXON INTRON  \
# 0                   protein_coding  15/19
# 0                   protein_coding  15/19
# 0                   protein_coding    5/7
# 0                   protein_coding    5/7
# 0                  retained_intron
# ..                             ...    ...    ...
# 13  protein_coding_CDS_not_defined           1/1
# 13                 retained_intron           2/2
# 13                 retained_intron           2/2
# 13                        promoter
# 13                        promoter
#
#    Protein Position and Amino Acid   Codons STRAND  \
# 0                            L446P  cTg/cCg      1
# 0                            L446R  cTg/cGg      1
# 0                            L147P  cTg/cCg      1
# 0                            L147R  cTg/cGg      1
# 0                              NaN               1
# ..                             ...      ...    ...
# 13                             NaN               1
# 13                             NaN               1
# 13                             NaN               1
# 13                             NaN
# 13                             NaN
#
#                                                PUBMED
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# ..                                                ...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
#
# [110 rows x 54 columns]

# %%
# Define the terms to remove
remove_terms = set(["not_specified", "not_provided"])

# Apply the filtering operation to 'Column1' only
vcf_final['ClinVar_CLNDN'] = vcf_final['ClinVar_CLNDN'].apply(lambda row: "&".join(
    [term for term in row.split("&") if term not in remove_terms]
    ) if isinstance(row, str) and not all(term in remove_terms for term in row.split("&")) else row)


vcf_final['CLIN_SIG'] = vcf_final['CLIN_SIG'].apply(lambda row: "&".join(
    [term for term in row.split("&") if term not in remove_terms]
    ) if isinstance(row, str) and not all(term in remove_terms for term in row.split("&")) else row)


vcf_final['ClinVar_CLNREVSTAT'] = vcf_final['ClinVar_CLNREVSTAT'].apply(lambda row: "&".join(
    [term for term in row.split("&") if term not in remove_terms]
    ) if isinstance(row, str) and not all(term in remove_terms for term in row.split("&")) else row)

# Print the modified DataFrame
vcf_final
# Out:
#    Gene Name       rsID  CHROM       POS REF  ALT Allele  \
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      C
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      G
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      C
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      G
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      C
# ..       ...        ...    ...       ...  ..  ...    ...
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      C
#
#                                      Consequence    IMPACT  \
# 0         missense_variant&splice_region_variant  MODERATE
# 0         missense_variant&splice_region_variant  MODERATE
# 0         missense_variant&splice_region_variant  MODERATE
# 0         missense_variant&splice_region_variant  MODERATE
# 0                        downstream_gene_variant  MODIFIER
# ..                                           ...       ...
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13  intron_variant&non_coding_transcript_variant  MODIFIER
# 13                     regulatory_region_variant  MODIFIER
# 13                     regulatory_region_variant  MODIFIER
#
#                                         ClinVar_CLNDN            CLIN_SIG  \
# 0   Fasting_plasma_glucose_level_quantitative_trai...  benign&association
# 0
# 0   Fasting_plasma_glucose_level_quantitative_trai...  benign&association
# 0
# 0   Fasting_plasma_glucose_level_quantitative_trai...  benign&association
# ..                                                ...                 ...
# 13
# 13
# 13
# 13
# 13
#
#                                    ClinVar_CLNREVSTAT ClinVar  \
# 0   criteria_provided&_multiple_submitters&_no_con...    8751
# 0
# 0   criteria_provided&_multiple_submitters&_no_con...    8751
# 0
# 0   criteria_provided&_multiple_submitters&_no_con...    8751
# ..                                                ...     ...
# 13
# 13
# 13
# 13
# 13
#
#                 HGVSc HGVSc (Transcript)              HGVSp  \
# 0   ENST00000264717.7          c.1337T>C  ENSP00000264717.2
# 0   ENST00000264717.7          c.1337T>G  ENSP00000264717.2
# 0   ENST00000411584.1           c.440T>C  ENSP00000416917.1
# 0   ENST00000411584.1           c.440T>G  ENSP00000416917.1
# 0                                   None
# ..                ...                ...                ...
# 13  ENST00000493621.1       n.100+316G>C
# 13  ENST00000494795.1      n.3057-532G>A
# 13  ENST00000494795.1      n.3057-532G>C
# 13                                  None
# 13                                  None
#
#    HGVSp (Transcript)             SIFT       PolyPhen      AF  AFR_AF  AMR_AF  \
# 0         p.Leu446Pro     tolerated(1)      benign(0)  0.7067  0.9062  0.6383
# 0         p.Leu446Arg  tolerated(0.06)      benign(0)
# 0         p.Leu147Pro     tolerated(1)  benign(0.001)  0.7067  0.9062  0.6383
# 0         p.Leu147Arg  tolerated(0.06)  benign(0.286)
# 0                None                                  0.7067  0.9062  0.6383
# ..                ...              ...            ...     ...     ...     ...
# 13               None
# 13               None                                  0.3075  0.3797  0.3415
# 13               None
# 13               None                                  0.3075  0.3797  0.3415
# 13               None
#
#     EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF  \
# 0   0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 0                           3.982e-06              0              0
# 0   0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 0                           3.982e-06              0              0
# 0   0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# ..     ...     ...     ...        ...            ...            ...
# 13
# 13  0.3661  0.2087   0.227
# 13
# 13  0.3661  0.2087   0.227
# 13
#
#    gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0          0.4668         0.5108         0.6426         0.5902         0.6005
# 0               0      5.444e-05              0              0              0
# 0          0.4668         0.5108         0.6426         0.5902         0.6005
# 0               0      5.444e-05              0              0              0
# 0          0.4668         0.5108         0.6426         0.5902         0.6005
# ..            ...            ...            ...            ...            ...
# 13
# 13
# 13
# 13
# 13
#
#    gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0           0.758       0.67         0.8582         0.7083          0.626
# 0               0
# 0           0.758       0.67         0.8582         0.7083          0.626
# 0               0
# 0           0.758       0.67         0.8582         0.7083          0.626
# ..            ...        ...            ...            ...            ...
# 13
# 13                    0.2519         0.3536         0.2325         0.3173
# 13
# 13                    0.2519         0.3536         0.2325         0.3173
# 13
#
#    gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0          0.4585         0.5014         0.6378         0.4904         0.5898
# 0
# 0          0.4585         0.5014         0.6378         0.4904         0.5898
# 0
# 0          0.4585         0.5014         0.6378         0.4904         0.5898
# ..            ...            ...            ...            ...            ...
# 13
# 13         0.1317         0.3875         0.2268         0.2184         0.1789
# 13
# 13         0.1317         0.3875         0.2268         0.2184         0.1789
# 13
#
#    gnomADg_OTH_AF gnomADg_SAS_AF     MAX_AF  MAX_AF_POPS  \
# 0          0.6106         0.7566     0.9062          AFR
# 0                                 5.444e-05  gnomADe_EAS
# 0          0.6106         0.7566     0.9062          AFR
# 0                                 5.444e-05  gnomADe_EAS
# 0          0.6106         0.7566     0.9062          AFR
# ..            ...            ...        ...          ...
# 13
# 13         0.2555         0.2035     0.3875  gnomADg_EAS
# 13
# 13         0.2555         0.2035     0.3875  gnomADg_EAS
# 13
#
#                            BIOTYPE   EXON INTRON  \
# 0                   protein_coding  15/19
# 0                   protein_coding  15/19
# 0                   protein_coding    5/7
# 0                   protein_coding    5/7
# 0                  retained_intron
# ..                             ...    ...    ...
# 13  protein_coding_CDS_not_defined           1/1
# 13                 retained_intron           2/2
# 13                 retained_intron           2/2
# 13                        promoter
# 13                        promoter
#
#    Protein Position and Amino Acid   Codons STRAND  \
# 0                            L446P  cTg/cCg      1
# 0                            L446R  cTg/cGg      1
# 0                            L147P  cTg/cCg      1
# 0                            L147R  cTg/cGg      1
# 0                              NaN               1
# ..                             ...      ...    ...
# 13                             NaN               1
# 13                             NaN               1
# 13                             NaN               1
# 13                             NaN
# 13                             NaN
#
#                                                PUBMED
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# 0   21467728&30409984&18439548&21054877&21647738&2...
# ..                                                ...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
# 13  26780889&18940312&25018854&27458502&22719876&2...
#
# [110 rows x 54 columns]

# %%
vcf_final = vcf_final.astype(str).applymap(lambda x: x.replace('&', ',').replace('_', ' '))
vcf_final
# Out:
#    Gene Name       rsID  CHROM       POS REF  ALT Allele  \
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      C
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      G
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      C
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      G
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      C
# ..       ...        ...    ...       ...  ..  ...    ...
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      C
#
#                                      Consequence    IMPACT  \
# 0         missense variant,splice region variant  MODERATE
# 0         missense variant,splice region variant  MODERATE
# 0         missense variant,splice region variant  MODERATE
# 0         missense variant,splice region variant  MODERATE
# 0                        downstream gene variant  MODIFIER
# ..                                           ...       ...
# 13  intron variant,non coding transcript variant  MODIFIER
# 13  intron variant,non coding transcript variant  MODIFIER
# 13  intron variant,non coding transcript variant  MODIFIER
# 13                     regulatory region variant  MODIFIER
# 13                     regulatory region variant  MODIFIER
#
#                                         ClinVar_CLNDN            CLIN_SIG  \
# 0   Fasting plasma glucose level quantitative trai...  benign,association
# 0
# 0   Fasting plasma glucose level quantitative trai...  benign,association
# 0
# 0   Fasting plasma glucose level quantitative trai...  benign,association
# ..                                                ...                 ...
# 13
# 13
# 13
# 13
# 13
#
#                                    ClinVar_CLNREVSTAT ClinVar  \
# 0   criteria provided, multiple submitters, no con...    8751
# 0
# 0   criteria provided, multiple submitters, no con...    8751
# 0
# 0   criteria provided, multiple submitters, no con...    8751
# ..                                                ...     ...
# 13
# 13
# 13
# 13
# 13
#
#                 HGVSc HGVSc (Transcript)              HGVSp  \
# 0   ENST00000264717.7          c.1337T>C  ENSP00000264717.2
# 0   ENST00000264717.7          c.1337T>G  ENSP00000264717.2
# 0   ENST00000411584.1           c.440T>C  ENSP00000416917.1
# 0   ENST00000411584.1           c.440T>G  ENSP00000416917.1
# 0                                   None
# ..                ...                ...                ...
# 13  ENST00000493621.1       n.100+316G>C
# 13  ENST00000494795.1      n.3057-532G>A
# 13  ENST00000494795.1      n.3057-532G>C
# 13                                  None
# 13                                  None
#
#    HGVSp (Transcript)             SIFT       PolyPhen      AF  AFR_AF  AMR_AF  \
# 0         p.Leu446Pro     tolerated(1)      benign(0)  0.7067  0.9062  0.6383
# 0         p.Leu446Arg  tolerated(0.06)      benign(0)
# 0         p.Leu147Pro     tolerated(1)  benign(0.001)  0.7067  0.9062  0.6383
# 0         p.Leu147Arg  tolerated(0.06)  benign(0.286)
# 0                None                                  0.7067  0.9062  0.6383
# ..                ...              ...            ...     ...     ...     ...
# 13               None
# 13               None                                  0.3075  0.3797  0.3415
# 13               None
# 13               None                                  0.3075  0.3797  0.3415
# 13               None
#
#     EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF  \
# 0   0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 0                           3.982e-06              0              0
# 0   0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 0                           3.982e-06              0              0
# 0   0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# ..     ...     ...     ...        ...            ...            ...
# 13
# 13  0.3661  0.2087   0.227
# 13
# 13  0.3661  0.2087   0.227
# 13
#
#    gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0          0.4668         0.5108         0.6426         0.5902         0.6005
# 0               0      5.444e-05              0              0              0
# 0          0.4668         0.5108         0.6426         0.5902         0.6005
# 0               0      5.444e-05              0              0              0
# 0          0.4668         0.5108         0.6426         0.5902         0.6005
# ..            ...            ...            ...            ...            ...
# 13
# 13
# 13
# 13
# 13
#
#    gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0           0.758       0.67         0.8582         0.7083          0.626
# 0               0
# 0           0.758       0.67         0.8582         0.7083          0.626
# 0               0
# 0           0.758       0.67         0.8582         0.7083          0.626
# ..            ...        ...            ...            ...            ...
# 13
# 13                    0.2519         0.3536         0.2325         0.3173
# 13
# 13                    0.2519         0.3536         0.2325         0.3173
# 13
#
#    gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0          0.4585         0.5014         0.6378         0.4904         0.5898
# 0
# 0          0.4585         0.5014         0.6378         0.4904         0.5898
# 0
# 0          0.4585         0.5014         0.6378         0.4904         0.5898
# ..            ...            ...            ...            ...            ...
# 13
# 13         0.1317         0.3875         0.2268         0.2184         0.1789
# 13
# 13         0.1317         0.3875         0.2268         0.2184         0.1789
# 13
#
#    gnomADg_OTH_AF gnomADg_SAS_AF     MAX_AF  MAX_AF_POPS  \
# 0          0.6106         0.7566     0.9062          AFR
# 0                                 5.444e-05  gnomADe EAS
# 0          0.6106         0.7566     0.9062          AFR
# 0                                 5.444e-05  gnomADe EAS
# 0          0.6106         0.7566     0.9062          AFR
# ..            ...            ...        ...          ...
# 13
# 13         0.2555         0.2035     0.3875  gnomADg EAS
# 13
# 13         0.2555         0.2035     0.3875  gnomADg EAS
# 13
#
#                            BIOTYPE   EXON INTRON  \
# 0                   protein coding  15/19
# 0                   protein coding  15/19
# 0                   protein coding    5/7
# 0                   protein coding    5/7
# 0                  retained intron
# ..                             ...    ...    ...
# 13  protein coding CDS not defined           1/1
# 13                 retained intron           2/2
# 13                 retained intron           2/2
# 13                        promoter
# 13                        promoter
#
#    Protein Position and Amino Acid   Codons STRAND  \
# 0                            L446P  cTg/cCg      1
# 0                            L446R  cTg/cGg      1
# 0                            L147P  cTg/cCg      1
# 0                            L147R  cTg/cGg      1
# 0                              nan               1
# ..                             ...      ...    ...
# 13                             nan               1
# 13                             nan               1
# 13                             nan               1
# 13                             nan
# 13                             nan
#
#                                                PUBMED
# 0   21467728,30409984,18439548,21054877,21647738,2...
# 0   21467728,30409984,18439548,21054877,21647738,2...
# 0   21467728,30409984,18439548,21054877,21647738,2...
# 0   21467728,30409984,18439548,21054877,21647738,2...
# 0   21467728,30409984,18439548,21054877,21647738,2...
# ..                                                ...
# 13  26780889,18940312,25018854,27458502,22719876,2...
# 13  26780889,18940312,25018854,27458502,22719876,2...
# 13  26780889,18940312,25018854,27458502,22719876,2...
# 13  26780889,18940312,25018854,27458502,22719876,2...
# 13  26780889,18940312,25018854,27458502,22719876,2...
#
# [110 rows x 54 columns]

# %%
vcf_final['consequence'] = vcf_final['Consequence'].str.split(',').str[0]
vcf_final
# Out:
#    Gene Name       rsID  CHROM       POS REF  ALT Allele  \
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      C
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      G
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      C
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      G
# 0       GCKR  rs1260326   chr2  27508073   T  C,G      C
# ..       ...        ...    ...       ...  ..  ...    ...
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 13    SAMM50  rs2143571  chr22  43995806   G  A,C      C
#
#                                      Consequence    IMPACT  \
# 0         missense variant,splice region variant  MODERATE
# 0         missense variant,splice region variant  MODERATE
# 0         missense variant,splice region variant  MODERATE
# 0         missense variant,splice region variant  MODERATE
# 0                        downstream gene variant  MODIFIER
# ..                                           ...       ...
# 13  intron variant,non coding transcript variant  MODIFIER
# 13  intron variant,non coding transcript variant  MODIFIER
# 13  intron variant,non coding transcript variant  MODIFIER
# 13                     regulatory region variant  MODIFIER
# 13                     regulatory region variant  MODIFIER
#
#                                         ClinVar_CLNDN            CLIN_SIG  \
# 0   Fasting plasma glucose level quantitative trai...  benign,association
# 0
# 0   Fasting plasma glucose level quantitative trai...  benign,association
# 0
# 0   Fasting plasma glucose level quantitative trai...  benign,association
# ..                                                ...                 ...
# 13
# 13
# 13
# 13
# 13
#
#                                    ClinVar_CLNREVSTAT ClinVar  \
# 0   criteria provided, multiple submitters, no con...    8751
# 0
# 0   criteria provided, multiple submitters, no con...    8751
# 0
# 0   criteria provided, multiple submitters, no con...    8751
# ..                                                ...     ...
# 13
# 13
# 13
# 13
# 13
#
#                 HGVSc HGVSc (Transcript)              HGVSp  \
# 0   ENST00000264717.7          c.1337T>C  ENSP00000264717.2
# 0   ENST00000264717.7          c.1337T>G  ENSP00000264717.2
# 0   ENST00000411584.1           c.440T>C  ENSP00000416917.1
# 0   ENST00000411584.1           c.440T>G  ENSP00000416917.1
# 0                                   None
# ..                ...                ...                ...
# 13  ENST00000493621.1       n.100+316G>C
# 13  ENST00000494795.1      n.3057-532G>A
# 13  ENST00000494795.1      n.3057-532G>C
# 13                                  None
# 13                                  None
#
#    HGVSp (Transcript)             SIFT       PolyPhen      AF  AFR_AF  AMR_AF  \
# 0         p.Leu446Pro     tolerated(1)      benign(0)  0.7067  0.9062  0.6383
# 0         p.Leu446Arg  tolerated(0.06)      benign(0)
# 0         p.Leu147Pro     tolerated(1)  benign(0.001)  0.7067  0.9062  0.6383
# 0         p.Leu147Arg  tolerated(0.06)  benign(0.286)
# 0                None                                  0.7067  0.9062  0.6383
# ..                ...              ...            ...     ...     ...     ...
# 13               None
# 13               None                                  0.3075  0.3797  0.3415
# 13               None
# 13               None                                  0.3075  0.3797  0.3415
# 13               None
#
#     EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF  \
# 0   0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 0                           3.982e-06              0              0
# 0   0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 0                           3.982e-06              0              0
# 0   0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# ..     ...     ...     ...        ...            ...            ...
# 13
# 13  0.3661  0.2087   0.227
# 13
# 13  0.3661  0.2087   0.227
# 13
#
#    gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF  \
# 0          0.4668         0.5108         0.6426         0.5902         0.6005
# 0               0      5.444e-05              0              0              0
# 0          0.4668         0.5108         0.6426         0.5902         0.6005
# 0               0      5.444e-05              0              0              0
# 0          0.4668         0.5108         0.6426         0.5902         0.6005
# ..            ...            ...            ...            ...            ...
# 13
# 13
# 13
# 13
# 13
#
#    gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF  \
# 0           0.758       0.67         0.8582         0.7083          0.626
# 0               0
# 0           0.758       0.67         0.8582         0.7083          0.626
# 0               0
# 0           0.758       0.67         0.8582         0.7083          0.626
# ..            ...        ...            ...            ...            ...
# 13
# 13                    0.2519         0.3536         0.2325         0.3173
# 13
# 13                    0.2519         0.3536         0.2325         0.3173
# 13
#
#    gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0          0.4585         0.5014         0.6378         0.4904         0.5898
# 0
# 0          0.4585         0.5014         0.6378         0.4904         0.5898
# 0
# 0          0.4585         0.5014         0.6378         0.4904         0.5898
# ..            ...            ...            ...            ...            ...
# 13
# 13         0.1317         0.3875         0.2268         0.2184         0.1789
# 13
# 13         0.1317         0.3875         0.2268         0.2184         0.1789
# 13
#
#    gnomADg_OTH_AF gnomADg_SAS_AF     MAX_AF  MAX_AF_POPS  \
# 0          0.6106         0.7566     0.9062          AFR
# 0                                 5.444e-05  gnomADe EAS
# 0          0.6106         0.7566     0.9062          AFR
# 0                                 5.444e-05  gnomADe EAS
# 0          0.6106         0.7566     0.9062          AFR
# ..            ...            ...        ...          ...
# 13
# 13         0.2555         0.2035     0.3875  gnomADg EAS
# 13
# 13         0.2555         0.2035     0.3875  gnomADg EAS
# 13
#
#                            BIOTYPE   EXON INTRON  \
# 0                   protein coding  15/19
# 0                   protein coding  15/19
# 0                   protein coding    5/7
# 0                   protein coding    5/7
# 0                  retained intron
# ..                             ...    ...    ...
# 13  protein coding CDS not defined           1/1
# 13                 retained intron           2/2
# 13                 retained intron           2/2
# 13                        promoter
# 13                        promoter
#
#    Protein Position and Amino Acid   Codons STRAND  \
# 0                            L446P  cTg/cCg      1
# 0                            L446R  cTg/cGg      1
# 0                            L147P  cTg/cCg      1
# 0                            L147R  cTg/cGg      1
# 0                              nan               1
# ..                             ...      ...    ...
# 13                             nan               1
# 13                             nan               1
# 13                             nan               1
# 13                             nan
# 13                             nan
#
#                                                PUBMED  \
# 0   21467728,30409984,18439548,21054877,21647738,2...
# 0   21467728,30409984,18439548,21054877,21647738,2...
# 0   21467728,30409984,18439548,21054877,21647738,2...
# 0   21467728,30409984,18439548,21054877,21647738,2...
# 0   21467728,30409984,18439548,21054877,21647738,2...
# ..                                                ...
# 13  26780889,18940312,25018854,27458502,22719876,2...
# 13  26780889,18940312,25018854,27458502,22719876,2...
# 13  26780889,18940312,25018854,27458502,22719876,2...
# 13  26780889,18940312,25018854,27458502,22719876,2...
# 13  26780889,18940312,25018854,27458502,22719876,2...
#
#                   consequence
# 0            missense variant
# 0            missense variant
# 0            missense variant
# 0            missense variant
# 0     downstream gene variant
# ..                        ...
# 13             intron variant
# 13             intron variant
# 13             intron variant
# 13  regulatory region variant
# 13  regulatory region variant
#
# [110 rows x 55 columns]

# %%
df_1 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Madhu_folder_04_07_2023/kidney_health_final.vcf/consequence.xlsx')
df_1
# Out:
#                             consequence Consequence_score
# 0                   transcript ablation             10/10
# 1               splice acceptor variant              8/10
# 2                  splice donor variant              8/10
# 3                           stop gained             10/10
# 4                    frameshift variant             10/10
# 5                             stop lost              9/10
# 6                            start lost              9/10
# 7              transcript amplification              8/10
# 8                     inframe insertion              6/10
# 9                      inframe deletion              6/10
# 10                     missense variant              7/10
# 11             protein altering variant              5/10
# 12                splice region variant              4/10
# 13        splice donor 5th base variant              4/10
# 14          splice donor region variant              4/10
# 15  splice polypyrimidine tract variant              4/10
# 16    incomplete terminal codon variant              3/10
# 17               start retained variant              3/10
# 18                stop retained variant              3/10
# 19                   synonymous variant              3/10
# 20              coding sequence variant              3/10
# 21                 mature miRNA variant              3/10
# 22                  5 prime UTR variant              3/10
# 23                  3 prime UTR variant              3/10
# 24   non coding transcript exon variant              2/10
# 25                       intron variant              2/10
# 26               NMD transcript variant              2/10
# 27        non coding transcript variant              2/10
# 28                upstream gene variant              2/10
# 29              downstream gene variant              2/10
# 30                        TFBS ablation              2/10
# 31                   TFBS amplification              2/10
# 32              TF binding site variant              2/10
# 33           regulatory region ablation              2/10
# 34      regulatory region amplification              2/10
# 35                   feature elongation              2/10
# 36            regulatory region variant              2/10
# 37                   feature truncation              1/10
# 38                   intergenic variant              1/10

# %%
merged_1 = pd.merge(vcf_final, df_1, on='consequence', how='left', sort=False)
merged_1
# Out:
#     Gene Name       rsID  CHROM       POS REF  ALT Allele  \
# 0        GCKR  rs1260326   chr2  27508073   T  C,G      C
# 1        GCKR  rs1260326   chr2  27508073   T  C,G      G
# 2        GCKR  rs1260326   chr2  27508073   T  C,G      C
# 3        GCKR  rs1260326   chr2  27508073   T  C,G      G
# 4        GCKR  rs1260326   chr2  27508073   T  C,G      C
# ..        ...        ...    ...       ...  ..  ...    ...
# 105    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 106    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 107    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 108    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 109    SAMM50  rs2143571  chr22  43995806   G  A,C      C
#
#                                       Consequence    IMPACT  \
# 0          missense variant,splice region variant  MODERATE
# 1          missense variant,splice region variant  MODERATE
# 2          missense variant,splice region variant  MODERATE
# 3          missense variant,splice region variant  MODERATE
# 4                         downstream gene variant  MODIFIER
# ..                                            ...       ...
# 105  intron variant,non coding transcript variant  MODIFIER
# 106  intron variant,non coding transcript variant  MODIFIER
# 107  intron variant,non coding transcript variant  MODIFIER
# 108                     regulatory region variant  MODIFIER
# 109                     regulatory region variant  MODIFIER
#
#                                          ClinVar_CLNDN            CLIN_SIG  \
# 0    Fasting plasma glucose level quantitative trai...  benign,association
# 1
# 2    Fasting plasma glucose level quantitative trai...  benign,association
# 3
# 4    Fasting plasma glucose level quantitative trai...  benign,association
# ..                                                 ...                 ...
# 105
# 106
# 107
# 108
# 109
#
#                                     ClinVar_CLNREVSTAT ClinVar  \
# 0    criteria provided, multiple submitters, no con...    8751
# 1
# 2    criteria provided, multiple submitters, no con...    8751
# 3
# 4    criteria provided, multiple submitters, no con...    8751
# ..                                                 ...     ...
# 105
# 106
# 107
# 108
# 109
#
#                  HGVSc HGVSc (Transcript)              HGVSp  \
# 0    ENST00000264717.7          c.1337T>C  ENSP00000264717.2
# 1    ENST00000264717.7          c.1337T>G  ENSP00000264717.2
# 2    ENST00000411584.1           c.440T>C  ENSP00000416917.1
# 3    ENST00000411584.1           c.440T>G  ENSP00000416917.1
# 4                                    None
# ..                 ...                ...                ...
# 105  ENST00000493621.1       n.100+316G>C
# 106  ENST00000494795.1      n.3057-532G>A
# 107  ENST00000494795.1      n.3057-532G>C
# 108                                  None
# 109                                  None
#
#     HGVSp (Transcript)             SIFT       PolyPhen      AF  AFR_AF  \
# 0          p.Leu446Pro     tolerated(1)      benign(0)  0.7067  0.9062
# 1          p.Leu446Arg  tolerated(0.06)      benign(0)
# 2          p.Leu147Pro     tolerated(1)  benign(0.001)  0.7067  0.9062
# 3          p.Leu147Arg  tolerated(0.06)  benign(0.286)
# 4                 None                                  0.7067  0.9062
# ..                 ...              ...            ...     ...     ...
# 105               None
# 106               None                                  0.3075  0.3797
# 107               None
# 108               None                                  0.3075  0.3797
# 109               None
#
#      AMR_AF  EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF  \
# 0    0.6383  0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 1                                    3.982e-06              0              0
# 2    0.6383  0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 3                                    3.982e-06              0              0
# 4    0.6383  0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# ..      ...     ...     ...     ...        ...            ...            ...
# 105
# 106  0.3415  0.3661  0.2087   0.227
# 107
# 108  0.3415  0.3661  0.2087   0.227
# 109
#
#     gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF  \
# 0           0.4668         0.5108         0.6426         0.5902
# 1                0      5.444e-05              0              0
# 2           0.4668         0.5108         0.6426         0.5902
# 3                0      5.444e-05              0              0
# 4           0.4668         0.5108         0.6426         0.5902
# ..             ...            ...            ...            ...
# 105
# 106
# 107
# 108
# 109
#
#     gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF  \
# 0           0.6005          0.758       0.67         0.8582         0.7083
# 1                0              0
# 2           0.6005          0.758       0.67         0.8582         0.7083
# 3                0              0
# 4           0.6005          0.758       0.67         0.8582         0.7083
# ..             ...            ...        ...            ...            ...
# 105
# 106                                   0.2519         0.3536         0.2325
# 107
# 108                                   0.2519         0.3536         0.2325
# 109
#
#     gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF  \
# 0            0.626         0.4585         0.5014         0.6378
# 1
# 2            0.626         0.4585         0.5014         0.6378
# 3
# 4            0.626         0.4585         0.5014         0.6378
# ..             ...            ...            ...            ...
# 105
# 106         0.3173         0.1317         0.3875         0.2268
# 107
# 108         0.3173         0.1317         0.3875         0.2268
# 109
#
#     gnomADg_MID_AF gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF     MAX_AF  \
# 0           0.4904         0.5898         0.6106         0.7566     0.9062
# 1                                                                5.444e-05
# 2           0.4904         0.5898         0.6106         0.7566     0.9062
# 3                                                                5.444e-05
# 4           0.4904         0.5898         0.6106         0.7566     0.9062
# ..             ...            ...            ...            ...        ...
# 105
# 106         0.2184         0.1789         0.2555         0.2035     0.3875
# 107
# 108         0.2184         0.1789         0.2555         0.2035     0.3875
# 109
#
#      MAX_AF_POPS                         BIOTYPE   EXON INTRON  \
# 0            AFR                  protein coding  15/19
# 1    gnomADe EAS                  protein coding  15/19
# 2            AFR                  protein coding    5/7
# 3    gnomADe EAS                  protein coding    5/7
# 4            AFR                 retained intron
# ..           ...                             ...    ...    ...
# 105               protein coding CDS not defined           1/1
# 106  gnomADg EAS                 retained intron           2/2
# 107                              retained intron           2/2
# 108  gnomADg EAS                        promoter
# 109                                     promoter
#
#     Protein Position and Amino Acid   Codons STRAND  \
# 0                             L446P  cTg/cCg      1
# 1                             L446R  cTg/cGg      1
# 2                             L147P  cTg/cCg      1
# 3                             L147R  cTg/cGg      1
# 4                               nan               1
# ..                              ...      ...    ...
# 105                             nan               1
# 106                             nan               1
# 107                             nan               1
# 108                             nan
# 109                             nan
#
#                                                 PUBMED  \
# 0    21467728,30409984,18439548,21054877,21647738,2...
# 1    21467728,30409984,18439548,21054877,21647738,2...
# 2    21467728,30409984,18439548,21054877,21647738,2...
# 3    21467728,30409984,18439548,21054877,21647738,2...
# 4    21467728,30409984,18439548,21054877,21647738,2...
# ..                                                 ...
# 105  26780889,18940312,25018854,27458502,22719876,2...
# 106  26780889,18940312,25018854,27458502,22719876,2...
# 107  26780889,18940312,25018854,27458502,22719876,2...
# 108  26780889,18940312,25018854,27458502,22719876,2...
# 109  26780889,18940312,25018854,27458502,22719876,2...
#
#                    consequence Consequence_score
# 0             missense variant              7/10
# 1             missense variant              7/10
# 2             missense variant              7/10
# 3             missense variant              7/10
# 4      downstream gene variant              2/10
# ..                         ...               ...
# 105             intron variant              2/10
# 106             intron variant              2/10
# 107             intron variant              2/10
# 108  regulatory region variant              2/10
# 109  regulatory region variant              2/10
#
# [110 rows x 56 columns]

# %%
df_2 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Madhu_folder_04_07_2023/kidney_health_final.vcf/IMPACT.xlsx')
df_2
# Out:
#      IMPACT  IMPACT_score
# 0      HIGH          10.0
# 1  MODERATE           5.0
# 2       LOW           2.5
# 3  MODIFIER           1.5

# %%
merged_2 = pd.merge(merged_1, df_2, on = 'IMPACT', how='left', sort=False)
merged_2
# Out:
#     Gene Name       rsID  CHROM       POS REF  ALT Allele  \
# 0        GCKR  rs1260326   chr2  27508073   T  C,G      C
# 1        GCKR  rs1260326   chr2  27508073   T  C,G      G
# 2        GCKR  rs1260326   chr2  27508073   T  C,G      C
# 3        GCKR  rs1260326   chr2  27508073   T  C,G      G
# 4        GCKR  rs1260326   chr2  27508073   T  C,G      C
# ..        ...        ...    ...       ...  ..  ...    ...
# 105    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 106    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 107    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 108    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 109    SAMM50  rs2143571  chr22  43995806   G  A,C      C
#
#                                       Consequence    IMPACT  \
# 0          missense variant,splice region variant  MODERATE
# 1          missense variant,splice region variant  MODERATE
# 2          missense variant,splice region variant  MODERATE
# 3          missense variant,splice region variant  MODERATE
# 4                         downstream gene variant  MODIFIER
# ..                                            ...       ...
# 105  intron variant,non coding transcript variant  MODIFIER
# 106  intron variant,non coding transcript variant  MODIFIER
# 107  intron variant,non coding transcript variant  MODIFIER
# 108                     regulatory region variant  MODIFIER
# 109                     regulatory region variant  MODIFIER
#
#                                          ClinVar_CLNDN            CLIN_SIG  \
# 0    Fasting plasma glucose level quantitative trai...  benign,association
# 1
# 2    Fasting plasma glucose level quantitative trai...  benign,association
# 3
# 4    Fasting plasma glucose level quantitative trai...  benign,association
# ..                                                 ...                 ...
# 105
# 106
# 107
# 108
# 109
#
#                                     ClinVar_CLNREVSTAT ClinVar  \
# 0    criteria provided, multiple submitters, no con...    8751
# 1
# 2    criteria provided, multiple submitters, no con...    8751
# 3
# 4    criteria provided, multiple submitters, no con...    8751
# ..                                                 ...     ...
# 105
# 106
# 107
# 108
# 109
#
#                  HGVSc HGVSc (Transcript)              HGVSp  \
# 0    ENST00000264717.7          c.1337T>C  ENSP00000264717.2
# 1    ENST00000264717.7          c.1337T>G  ENSP00000264717.2
# 2    ENST00000411584.1           c.440T>C  ENSP00000416917.1
# 3    ENST00000411584.1           c.440T>G  ENSP00000416917.1
# 4                                    None
# ..                 ...                ...                ...
# 105  ENST00000493621.1       n.100+316G>C
# 106  ENST00000494795.1      n.3057-532G>A
# 107  ENST00000494795.1      n.3057-532G>C
# 108                                  None
# 109                                  None
#
#     HGVSp (Transcript)             SIFT       PolyPhen      AF  AFR_AF  \
# 0          p.Leu446Pro     tolerated(1)      benign(0)  0.7067  0.9062
# 1          p.Leu446Arg  tolerated(0.06)      benign(0)
# 2          p.Leu147Pro     tolerated(1)  benign(0.001)  0.7067  0.9062
# 3          p.Leu147Arg  tolerated(0.06)  benign(0.286)
# 4                 None                                  0.7067  0.9062
# ..                 ...              ...            ...     ...     ...
# 105               None
# 106               None                                  0.3075  0.3797
# 107               None
# 108               None                                  0.3075  0.3797
# 109               None
#
#      AMR_AF  EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF  \
# 0    0.6383  0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 1                                    3.982e-06              0              0
# 2    0.6383  0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 3                                    3.982e-06              0              0
# 4    0.6383  0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# ..      ...     ...     ...     ...        ...            ...            ...
# 105
# 106  0.3415  0.3661  0.2087   0.227
# 107
# 108  0.3415  0.3661  0.2087   0.227
# 109
#
#     gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF  \
# 0           0.4668         0.5108         0.6426         0.5902
# 1                0      5.444e-05              0              0
# 2           0.4668         0.5108         0.6426         0.5902
# 3                0      5.444e-05              0              0
# 4           0.4668         0.5108         0.6426         0.5902
# ..             ...            ...            ...            ...
# 105
# 106
# 107
# 108
# 109
#
#     gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF  \
# 0           0.6005          0.758       0.67         0.8582         0.7083
# 1                0              0
# 2           0.6005          0.758       0.67         0.8582         0.7083
# 3                0              0
# 4           0.6005          0.758       0.67         0.8582         0.7083
# ..             ...            ...        ...            ...            ...
# 105
# 106                                   0.2519         0.3536         0.2325
# 107
# 108                                   0.2519         0.3536         0.2325
# 109
#
#     gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF  \
# 0            0.626         0.4585         0.5014         0.6378
# 1
# 2            0.626         0.4585         0.5014         0.6378
# 3
# 4            0.626         0.4585         0.5014         0.6378
# ..             ...            ...            ...            ...
# 105
# 106         0.3173         0.1317         0.3875         0.2268
# 107
# 108         0.3173         0.1317         0.3875         0.2268
# 109
#
#     gnomADg_MID_AF gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF     MAX_AF  \
# 0           0.4904         0.5898         0.6106         0.7566     0.9062
# 1                                                                5.444e-05
# 2           0.4904         0.5898         0.6106         0.7566     0.9062
# 3                                                                5.444e-05
# 4           0.4904         0.5898         0.6106         0.7566     0.9062
# ..             ...            ...            ...            ...        ...
# 105
# 106         0.2184         0.1789         0.2555         0.2035     0.3875
# 107
# 108         0.2184         0.1789         0.2555         0.2035     0.3875
# 109
#
#      MAX_AF_POPS                         BIOTYPE   EXON INTRON  \
# 0            AFR                  protein coding  15/19
# 1    gnomADe EAS                  protein coding  15/19
# 2            AFR                  protein coding    5/7
# 3    gnomADe EAS                  protein coding    5/7
# 4            AFR                 retained intron
# ..           ...                             ...    ...    ...
# 105               protein coding CDS not defined           1/1
# 106  gnomADg EAS                 retained intron           2/2
# 107                              retained intron           2/2
# 108  gnomADg EAS                        promoter
# 109                                     promoter
#
#     Protein Position and Amino Acid   Codons STRAND  \
# 0                             L446P  cTg/cCg      1
# 1                             L446R  cTg/cGg      1
# 2                             L147P  cTg/cCg      1
# 3                             L147R  cTg/cGg      1
# 4                               nan               1
# ..                              ...      ...    ...
# 105                             nan               1
# 106                             nan               1
# 107                             nan               1
# 108                             nan
# 109                             nan
#
#                                                 PUBMED  \
# 0    21467728,30409984,18439548,21054877,21647738,2...
# 1    21467728,30409984,18439548,21054877,21647738,2...
# 2    21467728,30409984,18439548,21054877,21647738,2...
# 3    21467728,30409984,18439548,21054877,21647738,2...
# 4    21467728,30409984,18439548,21054877,21647738,2...
# ..                                                 ...
# 105  26780889,18940312,25018854,27458502,22719876,2...
# 106  26780889,18940312,25018854,27458502,22719876,2...
# 107  26780889,18940312,25018854,27458502,22719876,2...
# 108  26780889,18940312,25018854,27458502,22719876,2...
# 109  26780889,18940312,25018854,27458502,22719876,2...
#
#                    consequence Consequence_score  IMPACT_score
# 0             missense variant              7/10           5.0
# 1             missense variant              7/10           5.0
# 2             missense variant              7/10           5.0
# 3             missense variant              7/10           5.0
# 4      downstream gene variant              2/10           1.5
# ..                         ...               ...           ...
# 105             intron variant              2/10           1.5
# 106             intron variant              2/10           1.5
# 107             intron variant              2/10           1.5
# 108  regulatory region variant              2/10           1.5
# 109  regulatory region variant              2/10           1.5
#
# [110 rows x 57 columns]

# %%
merged_2 = merged_2[['Gene Name', 'rsID', 'CHROM', 'POS', 'REF', 'ALT', 'Allele',
       'Consequence','Consequence_score', 'IMPACT', 'IMPACT_score', 'ClinVar_CLNDN', 'CLIN_SIG',
       'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc', 'HGVSc (Transcript)', 'HGVSp',
       'HGVSp (Transcript)', 'SIFT', 'PolyPhen', 'AF', 'AFR_AF',
       'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF', 'gnomADe_AF', 'gnomADe_AFR_AF',
       'gnomADe_AMR_AF', 'gnomADe_ASJ_AF', 'gnomADe_EAS_AF', 'gnomADe_FIN_AF',
       'gnomADe_NFE_AF', 'gnomADe_OTH_AF', 'gnomADe_SAS_AF', 'gnomADg_AF',
       'gnomADg_AFR_AF', 'gnomADg_AMI_AF', 'gnomADg_AMR_AF', 'gnomADg_ASJ_AF',
       'gnomADg_EAS_AF', 'gnomADg_FIN_AF', 'gnomADg_MID_AF', 'gnomADg_NFE_AF',
       'gnomADg_OTH_AF', 'gnomADg_SAS_AF', 'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE',
       'EXON', 'INTRON', 'Protein Position and Amino Acid', 'Codons', 'STRAND',
       'PUBMED']]
merged_2
# Out:
#     Gene Name       rsID  CHROM       POS REF  ALT Allele  \
# 0        GCKR  rs1260326   chr2  27508073   T  C,G      C
# 1        GCKR  rs1260326   chr2  27508073   T  C,G      G
# 2        GCKR  rs1260326   chr2  27508073   T  C,G      C
# 3        GCKR  rs1260326   chr2  27508073   T  C,G      G
# 4        GCKR  rs1260326   chr2  27508073   T  C,G      C
# ..        ...        ...    ...       ...  ..  ...    ...
# 105    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 106    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 107    SAMM50  rs2143571  chr22  43995806   G  A,C      C
# 108    SAMM50  rs2143571  chr22  43995806   G  A,C      A
# 109    SAMM50  rs2143571  chr22  43995806   G  A,C      C
#
#                                       Consequence Consequence_score    IMPACT  \
# 0          missense variant,splice region variant              7/10  MODERATE
# 1          missense variant,splice region variant              7/10  MODERATE
# 2          missense variant,splice region variant              7/10  MODERATE
# 3          missense variant,splice region variant              7/10  MODERATE
# 4                         downstream gene variant              2/10  MODIFIER
# ..                                            ...               ...       ...
# 105  intron variant,non coding transcript variant              2/10  MODIFIER
# 106  intron variant,non coding transcript variant              2/10  MODIFIER
# 107  intron variant,non coding transcript variant              2/10  MODIFIER
# 108                     regulatory region variant              2/10  MODIFIER
# 109                     regulatory region variant              2/10  MODIFIER
#
#      IMPACT_score                                      ClinVar_CLNDN  \
# 0             5.0  Fasting plasma glucose level quantitative trai...
# 1             5.0
# 2             5.0  Fasting plasma glucose level quantitative trai...
# 3             5.0
# 4             1.5  Fasting plasma glucose level quantitative trai...
# ..            ...                                                ...
# 105           1.5
# 106           1.5
# 107           1.5
# 108           1.5
# 109           1.5
#
#                CLIN_SIG                                 ClinVar_CLNREVSTAT  \
# 0    benign,association  criteria provided, multiple submitters, no con...
# 1
# 2    benign,association  criteria provided, multiple submitters, no con...
# 3
# 4    benign,association  criteria provided, multiple submitters, no con...
# ..                  ...                                                ...
# 105
# 106
# 107
# 108
# 109
#
#     ClinVar              HGVSc HGVSc (Transcript)              HGVSp  \
# 0      8751  ENST00000264717.7          c.1337T>C  ENSP00000264717.2
# 1            ENST00000264717.7          c.1337T>G  ENSP00000264717.2
# 2      8751  ENST00000411584.1           c.440T>C  ENSP00000416917.1
# 3            ENST00000411584.1           c.440T>G  ENSP00000416917.1
# 4      8751                                  None
# ..      ...                ...                ...                ...
# 105          ENST00000493621.1       n.100+316G>C
# 106          ENST00000494795.1      n.3057-532G>A
# 107          ENST00000494795.1      n.3057-532G>C
# 108                                          None
# 109                                          None
#
#     HGVSp (Transcript)             SIFT       PolyPhen      AF  AFR_AF  \
# 0          p.Leu446Pro     tolerated(1)      benign(0)  0.7067  0.9062
# 1          p.Leu446Arg  tolerated(0.06)      benign(0)
# 2          p.Leu147Pro     tolerated(1)  benign(0.001)  0.7067  0.9062
# 3          p.Leu147Arg  tolerated(0.06)  benign(0.286)
# 4                 None                                  0.7067  0.9062
# ..                 ...              ...            ...     ...     ...
# 105               None
# 106               None                                  0.3075  0.3797
# 107               None
# 108               None                                  0.3075  0.3797
# 109               None
#
#      AMR_AF  EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF  \
# 0    0.6383  0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 1                                    3.982e-06              0              0
# 2    0.6383  0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# 3                                    3.982e-06              0              0
# 4    0.6383  0.5188  0.5895  0.7996     0.6331         0.8679         0.6662
# ..      ...     ...     ...     ...        ...            ...            ...
# 105
# 106  0.3415  0.3661  0.2087   0.227
# 107
# 108  0.3415  0.3661  0.2087   0.227
# 109
#
#     gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF  \
# 0           0.4668         0.5108         0.6426         0.5902
# 1                0      5.444e-05              0              0
# 2           0.4668         0.5108         0.6426         0.5902
# 3                0      5.444e-05              0              0
# 4           0.4668         0.5108         0.6426         0.5902
# ..             ...            ...            ...            ...
# 105
# 106
# 107
# 108
# 109
#
#     gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF  \
# 0           0.6005          0.758       0.67         0.8582         0.7083
# 1                0              0
# 2           0.6005          0.758       0.67         0.8582         0.7083
# 3                0              0
# 4           0.6005          0.758       0.67         0.8582         0.7083
# ..             ...            ...        ...            ...            ...
# 105
# 106                                   0.2519         0.3536         0.2325
# 107
# 108                                   0.2519         0.3536         0.2325
# 109
#
#     gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF  \
# 0            0.626         0.4585         0.5014         0.6378
# 1
# 2            0.626         0.4585         0.5014         0.6378
# 3
# 4            0.626         0.4585         0.5014         0.6378
# ..             ...            ...            ...            ...
# 105
# 106         0.3173         0.1317         0.3875         0.2268
# 107
# 108         0.3173         0.1317         0.3875         0.2268
# 109
#
#     gnomADg_MID_AF gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF     MAX_AF  \
# 0           0.4904         0.5898         0.6106         0.7566     0.9062
# 1                                                                5.444e-05
# 2           0.4904         0.5898         0.6106         0.7566     0.9062
# 3                                                                5.444e-05
# 4           0.4904         0.5898         0.6106         0.7566     0.9062
# ..             ...            ...            ...            ...        ...
# 105
# 106         0.2184         0.1789         0.2555         0.2035     0.3875
# 107
# 108         0.2184         0.1789         0.2555         0.2035     0.3875
# 109
#
#      MAX_AF_POPS                         BIOTYPE   EXON INTRON  \
# 0            AFR                  protein coding  15/19
# 1    gnomADe EAS                  protein coding  15/19
# 2            AFR                  protein coding    5/7
# 3    gnomADe EAS                  protein coding    5/7
# 4            AFR                 retained intron
# ..           ...                             ...    ...    ...
# 105               protein coding CDS not defined           1/1
# 106  gnomADg EAS                 retained intron           2/2
# 107                              retained intron           2/2
# 108  gnomADg EAS                        promoter
# 109                                     promoter
#
#     Protein Position and Amino Acid   Codons STRAND  \
# 0                             L446P  cTg/cCg      1
# 1                             L446R  cTg/cGg      1
# 2                             L147P  cTg/cCg      1
# 3                             L147R  cTg/cGg      1
# 4                               nan               1
# ..                              ...      ...    ...
# 105                             nan               1
# 106                             nan               1
# 107                             nan               1
# 108                             nan
# 109                             nan
#
#                                                 PUBMED
# 0    21467728,30409984,18439548,21054877,21647738,2...
# 1    21467728,30409984,18439548,21054877,21647738,2...
# 2    21467728,30409984,18439548,21054877,21647738,2...
# 3    21467728,30409984,18439548,21054877,21647738,2...
# 4    21467728,30409984,18439548,21054877,21647738,2...
# ..                                                 ...
# 105  26780889,18940312,25018854,27458502,22719876,2...
# 106  26780889,18940312,25018854,27458502,22719876,2...
# 107  26780889,18940312,25018854,27458502,22719876,2...
# 108  26780889,18940312,25018854,27458502,22719876,2...
# 109  26780889,18940312,25018854,27458502,22719876,2...
#
# [110 rows x 56 columns]

# %%
df_gene = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Diab_all_genes_conditions.xlsx')
df_gene
# Out:
#    Gene Name                                       Matched_Gene
# 0      CTLA4                                      Type1Diabetes
# 1        INS                                Type1Diabetes, MODY
# 2      IL2RA                                      Type1Diabetes
# 3      HNF1A                 Type1Diabetes, Type2Diabetes, MODY
# 4        CEL                                      Type1Diabetes
# 5      HLADQ                                      Type1Diabetes
# 6      HLADR                                      Type1Diabetes
# 7     PTPN22                                      Type1Diabetes
# 8        IL2                                      Type1Diabetes
# 9      ERBB3                                      Type1Diabetes
# 10     BACH2                                      Type1Diabetes
# 11   C1QTNF6                                      Type1Diabetes
# 12      PRKQ                                      Type1Diabetes
# 13      RGS1                                      Type1Diabetes
# 14   IL18RAP                                      Type1Diabetes
# 15      CCR5                                      Type1Diabetes
# 16     TAGAP                                      Type1Diabetes
# 17     SH2B3                                      Type1Diabetes
# 18     STAT3                                      Type1Diabetes
# 19     FOXP3                                      Type1Diabetes
# 20      IRS1                                      Type2Diabetes
# 21    SLC2A2                                      Type2Diabetes
# 22      WFS1                                      Type2Diabetes
# 23       GCK                                Type2Diabetes, MODY
# 24      PAX4                                Type2Diabetes, MODY
# 25       WRN                                      Type2Diabetes
# 26    KCNJ11                                Type2Diabetes, MODY
# 27     ABCC8                                Type2Diabetes, MODY
# 28      PDX1                                Type2Diabetes, MODY
# 29      AKT2                                      Type2Diabetes
# 30     HNF4A                                Type2Diabetes, MODY
# 31     KLF11                                Type2Diabetes, MODY
# 32     ENPP1                                      Type2Diabetes
# 33   PPP1R3A                                      Type2Diabetes
# 34     ACADS                                      Type2Diabetes
# 35      LIPC                                      Type2Diabetes
# 36      INSR                                      Type2Diabetes
# 37    TCF7L2                                      Type2Diabetes
# 38      MLKL                                               MODY
# 39   NEUROD1                                               MODY
# 40      SELP                               Diabetic_Retinopathy
# 41    CDKAL1                               Diabetic_Retinopathy
# 42    TGFBR2                               Diabetic_Retinopathy
# 43      HHEX                               Diabetic_Retinopathy
# 44     FABP2                               Diabetic_Retinopathy
# 45     HNF1B  Diabetic_Retinopathy, Diabetic_Nephropathy, Di...
# 46      AQP2                               Diabetic_Nephropathy
# 47     AVPR2                               Diabetic_Nephropathy
# 48       AVP                               Diabetic_Nephropathy
# 49     PARK7                               Diabetic_Nephropathy
# 50    PRKAG2                               Diabetic_Nephropathy
# 51     SCN9A                                Diabetic_Neuropathy
# 52   ZSCAN20                                Diabetic_Neuropathy
# 53      LMNA                              Risk of Heart Disease

# %%
merged_2['Gene Match'] = 'No'
merged_2['Matched_Gene'] = ''
    
# Iterate through each gene in vcf['Gene']
for index, genes in merged_2['Gene Name'].iteritems():
    if isinstance(genes, str):
        gene_list = genes.split(',')
        for gene in gene_list:
            if gene in df_gene['Gene Name'].values:
                merged_2.at[index, 'Gene Match'] = 'Yes'
                merged_2.at[index, 'Matched_Gene'] = gene
                break
    
merged_2
# Out:
#        Gene Name          rsID CHROM        POS REF ALT      Zygosity  \
# 0                 rs1416222198  chr1      65591   C   T  Heterozygous
# 1                 rs1416222198  chr1      65591   C   T  Heterozygous
# 2                 rs1416222198  chr1      65591   C   T  Heterozygous
# 3          OR4F5  rs1260343719  chr1      69063   T   C  Heterozygous
# 4          OR4F5  rs1260343719  chr1      69063   T   C  Heterozygous
# ...          ...           ...   ...        ...  ..  ..           ...
# 306164                       .  chrX  155459837   A   G  Heterozygous
# 306165      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
# 306166      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
# 306167      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
# 306168      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
#
#                     Consequence Consequence_score    IMPACT  IMPACT_score  \
# 0       downstream gene variant              2/10  MODIFIER           1.5
# 1                intron variant              2/10  MODIFIER           1.5
# 2       downstream gene variant              2/10  MODIFIER           1.5
# 3            synonymous variant              3/10       LOW           2.5
# 4       downstream gene variant              2/10  MODIFIER           1.5
# ...                         ...               ...       ...           ...
# 306164    upstream gene variant              2/10  MODIFIER           1.5
# 306165           intron variant              2/10  MODIFIER           1.5
# 306166           intron variant              2/10  MODIFIER           1.5
# 306167  downstream gene variant              2/10  MODIFIER           1.5
# 306168    upstream gene variant              2/10  MODIFIER           1.5
#
#        ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar               HGVSc  \
# 0
# 1                                                          ENST00000641515.2
# 2
# 3                                                          ENST00000641515.2
# 4
# ...              ...      ...                ...     ...                 ...
# 306164
# 306165                                                    ENST00000244174.11
# 306166                                                     ENST00000369423.7
# 306167
# 306168
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT  GQ  SDP  \
# 0                    None                                  None  0/1  22   31
# 1               c.9+18C>T                                  None  0/1  22   31
# 2                    None                                  None  0/1  22   31
# 3                 c.36T>C  ENSP00000493376.2         p.Asn12%3D  0/1  67   45
# 4                    None                                  None  0/1  67   45
# ...                   ...                ...                ...  ...  ..  ...
# 306164               None                                  None  0/1  71  103
# 306165        c.580-26C>T                                  None  0/1  31   12
# 306166        c.685-26C>T                                  None  0/1  31   12
# 306167               None                                  None  0/1  31   12
# 306168               None                                  None  0/1  31   12
#
#          DP  RD  AD    FREQ       PVAL RDF RDR ADF ADR SIFT PolyPhen AF  \
# 0        31  24   7  22.58%  5.3469E-3  17   7   3   4
# 1        31  24   7  22.58%  5.3469E-3  17   7   3   4
# 2        31  24   7  22.58%  5.3469E-3  17   7   3   4
# 3        45  26  19  42.22%  1.6979E-7  23   3  18   1
# 4        45  26  19  42.22%  1.6979E-7  23   3  18   1
# ...     ...  ..  ..     ...        ...  ..  ..  ..  ..  ...      ... ..
# 306164  103  81  22  21.36%  6.7976E-8  54  27  14   8
# 306165   12   4   8  66.67%  6.7304E-4   4   0   8   0
# 306166   12   4   8  66.67%  6.7304E-4   4   0   8   0
# 306167   12   4   8  66.67%  6.7304E-4   4   0   8   0
# 306168   12   4   8  66.67%  6.7304E-4   4   0   8   0
#
#        AFR_AF AMR_AF EAS_AF EUR_AF SAS_AF gnomADe_AF gnomADe_AFR_AF  \
# 0
# 1
# 2
# 3
# 4
# ...       ...    ...    ...    ...    ...        ...            ...
# 306164
# 306165                                       0.02802       0.001789
# 306166                                       0.02802       0.001789
# 306167                                       0.02802       0.001789
# 306168                                       0.02802       0.001789
#
#        gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF  \
# 0
# 1
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 306164
# 306165         0.0527      9.934e-05         0.2012              0
# 306166         0.0527      9.934e-05         0.2012              0
# 306167         0.0527      9.934e-05         0.2012              0
# 306168         0.0527      9.934e-05         0.2012              0
#
#        gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF  \
# 0                                                      0.03416        0.02306
# 1                                                      0.03416        0.02306
# 2                                                      0.03416        0.02306
# 3                                                      0.05175        0.04058
# 4                                                      0.05175        0.04058
# ...               ...            ...            ...        ...            ...
# 306164
# 306165      0.0005125        0.01736        0.04299    0.01208       0.001739
# 306166      0.0005125        0.01736        0.04299    0.01208       0.001739
# 306167      0.0005125        0.01736        0.04299    0.01208       0.001739
# 306168      0.0005125        0.01736        0.04299    0.01208       0.001739
#
#        gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF  \
# 0              0.1667        0.02711        0.03333       0.001639
# 1              0.1667        0.02711        0.03333       0.001639
# 2              0.1667        0.02711        0.03333       0.001639
# 3             0.02941        0.04766        0.04545        0.06778
# 4             0.02941        0.04766        0.04545        0.06778
# ...               ...            ...            ...            ...
# 306164
# 306165              0        0.02902       0.000288         0.2012
# 306166              0        0.02902       0.000288         0.2012
# 306167              0        0.02902       0.000288         0.2012
# 306168              0        0.02902       0.000288         0.2012
#
#        gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF gnomADg_OTH_AF  \
# 0                   0           0.05        0.09167        0.05357
# 1                   0           0.05        0.09167        0.05357
# 2                   0           0.05        0.09167        0.05357
# 3              0.0303         0.1538        0.06103        0.05789
# 4              0.0303         0.1538        0.06103        0.05789
# ...               ...            ...            ...            ...
# 306164
# 306165              0              0      0.0003382         0.0134
# 306166              0              0      0.0003382         0.0134
# 306167              0              0      0.0003382         0.0134
# 306168              0              0      0.0003382         0.0134
#
#        gnomADg_SAS_AF  MAX_AF              MAX_AF_POPS  \
# 0             0.02083  0.1667              gnomADg AMI
# 1             0.02083  0.1667              gnomADg AMI
# 2             0.02083  0.1667              gnomADg AMI
# 3              0.1089  0.1538              gnomADg MID
# 4              0.1089  0.1538              gnomADg MID
# ...               ...     ...                      ...
# 306164
# 306165        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306166        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306167        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306168        0.04662  0.2012  gnomADe EAS,gnomADg EAS
#
#                                    BIOTYPE EXON INTRON  \
# 0       transcribed unprocessed pseudogene
# 1                           protein coding         2/2
# 2                                   lncRNA
# 3                           protein coding  3/3
# 4                                   lncRNA
# ...                                    ...  ...    ...
# 306164                      protein coding
# 306165                      protein coding         5/8
# 306166                      protein coding         6/8
# 306167      protein coding CDS not defined
# 306168      protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED Gene Match  \
# 0                                  nan               1                No
# 1                                  nan               1                No
# 2                                  nan               1                No
# 3                                  N12  aaT/aaC      1                No
# 4                                  nan               1                No
# ...                                ...      ...    ...    ...        ...
# 306164                             nan              -1                No
# 306165                             nan               1                No
# 306166                             nan               1                No
# 306167                             nan               1                No
# 306168                             nan               1                No
#
#        Matched_Gene
# 0
# 1
# 2
# 3
# 4
# ...             ...
# 306164
# 306165
# 306166
# 306167
# 306168
#
# [306169 rows x 70 columns]

# %%
df_gene = df_gene.rename({'Gene Name':'Matched_Gene', 'Matched_Gene':'Gene Match'}, axis=1)
df_gene
# Out:
#    Matched_Gene                                         Gene Match
# 0         CTLA4                                      Type1Diabetes
# 1           INS                                Type1Diabetes, MODY
# 2         IL2RA                                      Type1Diabetes
# 3         HNF1A                 Type1Diabetes, Type2Diabetes, MODY
# 4           CEL                                      Type1Diabetes
# 5         HLADQ                                      Type1Diabetes
# 6         HLADR                                      Type1Diabetes
# 7        PTPN22                                      Type1Diabetes
# 8           IL2                                      Type1Diabetes
# 9         ERBB3                                      Type1Diabetes
# 10        BACH2                                      Type1Diabetes
# 11      C1QTNF6                                      Type1Diabetes
# 12         PRKQ                                      Type1Diabetes
# 13         RGS1                                      Type1Diabetes
# 14      IL18RAP                                      Type1Diabetes
# 15         CCR5                                      Type1Diabetes
# 16        TAGAP                                      Type1Diabetes
# 17        SH2B3                                      Type1Diabetes
# 18        STAT3                                      Type1Diabetes
# 19        FOXP3                                      Type1Diabetes
# 20         IRS1                                      Type2Diabetes
# 21       SLC2A2                                      Type2Diabetes
# 22         WFS1                                      Type2Diabetes
# 23          GCK                                Type2Diabetes, MODY
# 24         PAX4                                Type2Diabetes, MODY
# 25          WRN                                      Type2Diabetes
# 26       KCNJ11                                Type2Diabetes, MODY
# 27        ABCC8                                Type2Diabetes, MODY
# 28         PDX1                                Type2Diabetes, MODY
# 29         AKT2                                      Type2Diabetes
# 30        HNF4A                                Type2Diabetes, MODY
# 31        KLF11                                Type2Diabetes, MODY
# 32        ENPP1                                      Type2Diabetes
# 33      PPP1R3A                                      Type2Diabetes
# 34        ACADS                                      Type2Diabetes
# 35         LIPC                                      Type2Diabetes
# 36         INSR                                      Type2Diabetes
# 37       TCF7L2                                      Type2Diabetes
# 38         MLKL                                               MODY
# 39      NEUROD1                                               MODY
# 40         SELP                               Diabetic_Retinopathy
# 41       CDKAL1                               Diabetic_Retinopathy
# 42       TGFBR2                               Diabetic_Retinopathy
# 43         HHEX                               Diabetic_Retinopathy
# 44        FABP2                               Diabetic_Retinopathy
# 45        HNF1B  Diabetic_Retinopathy, Diabetic_Nephropathy, Di...
# 46         AQP2                               Diabetic_Nephropathy
# 47        AVPR2                               Diabetic_Nephropathy
# 48          AVP                               Diabetic_Nephropathy
# 49        PARK7                               Diabetic_Nephropathy
# 50       PRKAG2                               Diabetic_Nephropathy
# 51        SCN9A                                Diabetic_Neuropathy
# 52      ZSCAN20                                Diabetic_Neuropathy
# 53         LMNA                              Risk of Heart Disease

# %%
merged_2 = merged_2.drop(columns=['Gene Match'], axis=1)
merged_2
# Out:
#        Gene Name          rsID CHROM        POS REF ALT      Zygosity  \
# 0                 rs1416222198  chr1      65591   C   T  Heterozygous
# 1                 rs1416222198  chr1      65591   C   T  Heterozygous
# 2                 rs1416222198  chr1      65591   C   T  Heterozygous
# 3          OR4F5  rs1260343719  chr1      69063   T   C  Heterozygous
# 4          OR4F5  rs1260343719  chr1      69063   T   C  Heterozygous
# ...          ...           ...   ...        ...  ..  ..           ...
# 306164                       .  chrX  155459837   A   G  Heterozygous
# 306165      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
# 306166      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
# 306167      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
# 306168      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
#
#                     Consequence Consequence_score    IMPACT  IMPACT_score  \
# 0       downstream gene variant              2/10  MODIFIER           1.5
# 1                intron variant              2/10  MODIFIER           1.5
# 2       downstream gene variant              2/10  MODIFIER           1.5
# 3            synonymous variant              3/10       LOW           2.5
# 4       downstream gene variant              2/10  MODIFIER           1.5
# ...                         ...               ...       ...           ...
# 306164    upstream gene variant              2/10  MODIFIER           1.5
# 306165           intron variant              2/10  MODIFIER           1.5
# 306166           intron variant              2/10  MODIFIER           1.5
# 306167  downstream gene variant              2/10  MODIFIER           1.5
# 306168    upstream gene variant              2/10  MODIFIER           1.5
#
#        ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar               HGVSc  \
# 0
# 1                                                          ENST00000641515.2
# 2
# 3                                                          ENST00000641515.2
# 4
# ...              ...      ...                ...     ...                 ...
# 306164
# 306165                                                    ENST00000244174.11
# 306166                                                     ENST00000369423.7
# 306167
# 306168
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT  GQ  SDP  \
# 0                    None                                  None  0/1  22   31
# 1               c.9+18C>T                                  None  0/1  22   31
# 2                    None                                  None  0/1  22   31
# 3                 c.36T>C  ENSP00000493376.2         p.Asn12%3D  0/1  67   45
# 4                    None                                  None  0/1  67   45
# ...                   ...                ...                ...  ...  ..  ...
# 306164               None                                  None  0/1  71  103
# 306165        c.580-26C>T                                  None  0/1  31   12
# 306166        c.685-26C>T                                  None  0/1  31   12
# 306167               None                                  None  0/1  31   12
# 306168               None                                  None  0/1  31   12
#
#          DP  RD  AD    FREQ       PVAL RDF RDR ADF ADR SIFT PolyPhen AF  \
# 0        31  24   7  22.58%  5.3469E-3  17   7   3   4
# 1        31  24   7  22.58%  5.3469E-3  17   7   3   4
# 2        31  24   7  22.58%  5.3469E-3  17   7   3   4
# 3        45  26  19  42.22%  1.6979E-7  23   3  18   1
# 4        45  26  19  42.22%  1.6979E-7  23   3  18   1
# ...     ...  ..  ..     ...        ...  ..  ..  ..  ..  ...      ... ..
# 306164  103  81  22  21.36%  6.7976E-8  54  27  14   8
# 306165   12   4   8  66.67%  6.7304E-4   4   0   8   0
# 306166   12   4   8  66.67%  6.7304E-4   4   0   8   0
# 306167   12   4   8  66.67%  6.7304E-4   4   0   8   0
# 306168   12   4   8  66.67%  6.7304E-4   4   0   8   0
#
#        AFR_AF AMR_AF EAS_AF EUR_AF SAS_AF gnomADe_AF gnomADe_AFR_AF  \
# 0
# 1
# 2
# 3
# 4
# ...       ...    ...    ...    ...    ...        ...            ...
# 306164
# 306165                                       0.02802       0.001789
# 306166                                       0.02802       0.001789
# 306167                                       0.02802       0.001789
# 306168                                       0.02802       0.001789
#
#        gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF  \
# 0
# 1
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 306164
# 306165         0.0527      9.934e-05         0.2012              0
# 306166         0.0527      9.934e-05         0.2012              0
# 306167         0.0527      9.934e-05         0.2012              0
# 306168         0.0527      9.934e-05         0.2012              0
#
#        gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF  \
# 0                                                      0.03416        0.02306
# 1                                                      0.03416        0.02306
# 2                                                      0.03416        0.02306
# 3                                                      0.05175        0.04058
# 4                                                      0.05175        0.04058
# ...               ...            ...            ...        ...            ...
# 306164
# 306165      0.0005125        0.01736        0.04299    0.01208       0.001739
# 306166      0.0005125        0.01736        0.04299    0.01208       0.001739
# 306167      0.0005125        0.01736        0.04299    0.01208       0.001739
# 306168      0.0005125        0.01736        0.04299    0.01208       0.001739
#
#        gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF  \
# 0              0.1667        0.02711        0.03333       0.001639
# 1              0.1667        0.02711        0.03333       0.001639
# 2              0.1667        0.02711        0.03333       0.001639
# 3             0.02941        0.04766        0.04545        0.06778
# 4             0.02941        0.04766        0.04545        0.06778
# ...               ...            ...            ...            ...
# 306164
# 306165              0        0.02902       0.000288         0.2012
# 306166              0        0.02902       0.000288         0.2012
# 306167              0        0.02902       0.000288         0.2012
# 306168              0        0.02902       0.000288         0.2012
#
#        gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF gnomADg_OTH_AF  \
# 0                   0           0.05        0.09167        0.05357
# 1                   0           0.05        0.09167        0.05357
# 2                   0           0.05        0.09167        0.05357
# 3              0.0303         0.1538        0.06103        0.05789
# 4              0.0303         0.1538        0.06103        0.05789
# ...               ...            ...            ...            ...
# 306164
# 306165              0              0      0.0003382         0.0134
# 306166              0              0      0.0003382         0.0134
# 306167              0              0      0.0003382         0.0134
# 306168              0              0      0.0003382         0.0134
#
#        gnomADg_SAS_AF  MAX_AF              MAX_AF_POPS  \
# 0             0.02083  0.1667              gnomADg AMI
# 1             0.02083  0.1667              gnomADg AMI
# 2             0.02083  0.1667              gnomADg AMI
# 3              0.1089  0.1538              gnomADg MID
# 4              0.1089  0.1538              gnomADg MID
# ...               ...     ...                      ...
# 306164
# 306165        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306166        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306167        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306168        0.04662  0.2012  gnomADe EAS,gnomADg EAS
#
#                                    BIOTYPE EXON INTRON  \
# 0       transcribed unprocessed pseudogene
# 1                           protein coding         2/2
# 2                                   lncRNA
# 3                           protein coding  3/3
# 4                                   lncRNA
# ...                                    ...  ...    ...
# 306164                      protein coding
# 306165                      protein coding         5/8
# 306166                      protein coding         6/8
# 306167      protein coding CDS not defined
# 306168      protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED Matched_Gene
# 0                                  nan               1
# 1                                  nan               1
# 2                                  nan               1
# 3                                  N12  aaT/aaC      1
# 4                                  nan               1
# ...                                ...      ...    ...    ...          ...
# 306164                             nan              -1
# 306165                             nan               1
# 306166                             nan               1
# 306167                             nan               1
# 306168                             nan               1
#
# [306169 rows x 69 columns]

# %%
merged_2 = pd.merge(merged_2, df_gene, on= 'Matched_Gene', how = 'left', sort = False)
merged_2['Gene Match'] = merged_2['Gene Match'].fillna('No')
merged_2
# Out:
#        Gene Name          rsID CHROM        POS REF ALT      Zygosity  \
# 0                 rs1416222198  chr1      65591   C   T  Heterozygous
# 1                 rs1416222198  chr1      65591   C   T  Heterozygous
# 2                 rs1416222198  chr1      65591   C   T  Heterozygous
# 3          OR4F5  rs1260343719  chr1      69063   T   C  Heterozygous
# 4          OR4F5  rs1260343719  chr1      69063   T   C  Heterozygous
# ...          ...           ...   ...        ...  ..  ..           ...
# 306164                       .  chrX  155459837   A   G  Heterozygous
# 306165      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
# 306166      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
# 306167      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
# 306168      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
#
#                     Consequence Consequence_score    IMPACT  IMPACT_score  \
# 0       downstream gene variant              2/10  MODIFIER           1.5
# 1                intron variant              2/10  MODIFIER           1.5
# 2       downstream gene variant              2/10  MODIFIER           1.5
# 3            synonymous variant              3/10       LOW           2.5
# 4       downstream gene variant              2/10  MODIFIER           1.5
# ...                         ...               ...       ...           ...
# 306164    upstream gene variant              2/10  MODIFIER           1.5
# 306165           intron variant              2/10  MODIFIER           1.5
# 306166           intron variant              2/10  MODIFIER           1.5
# 306167  downstream gene variant              2/10  MODIFIER           1.5
# 306168    upstream gene variant              2/10  MODIFIER           1.5
#
#        ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar               HGVSc  \
# 0
# 1                                                          ENST00000641515.2
# 2
# 3                                                          ENST00000641515.2
# 4
# ...              ...      ...                ...     ...                 ...
# 306164
# 306165                                                    ENST00000244174.11
# 306166                                                     ENST00000369423.7
# 306167
# 306168
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT  GQ  SDP  \
# 0                    None                                  None  0/1  22   31
# 1               c.9+18C>T                                  None  0/1  22   31
# 2                    None                                  None  0/1  22   31
# 3                 c.36T>C  ENSP00000493376.2         p.Asn12%3D  0/1  67   45
# 4                    None                                  None  0/1  67   45
# ...                   ...                ...                ...  ...  ..  ...
# 306164               None                                  None  0/1  71  103
# 306165        c.580-26C>T                                  None  0/1  31   12
# 306166        c.685-26C>T                                  None  0/1  31   12
# 306167               None                                  None  0/1  31   12
# 306168               None                                  None  0/1  31   12
#
#          DP  RD  AD    FREQ       PVAL RDF RDR ADF ADR SIFT PolyPhen AF  \
# 0        31  24   7  22.58%  5.3469E-3  17   7   3   4
# 1        31  24   7  22.58%  5.3469E-3  17   7   3   4
# 2        31  24   7  22.58%  5.3469E-3  17   7   3   4
# 3        45  26  19  42.22%  1.6979E-7  23   3  18   1
# 4        45  26  19  42.22%  1.6979E-7  23   3  18   1
# ...     ...  ..  ..     ...        ...  ..  ..  ..  ..  ...      ... ..
# 306164  103  81  22  21.36%  6.7976E-8  54  27  14   8
# 306165   12   4   8  66.67%  6.7304E-4   4   0   8   0
# 306166   12   4   8  66.67%  6.7304E-4   4   0   8   0
# 306167   12   4   8  66.67%  6.7304E-4   4   0   8   0
# 306168   12   4   8  66.67%  6.7304E-4   4   0   8   0
#
#        AFR_AF AMR_AF EAS_AF EUR_AF SAS_AF gnomADe_AF gnomADe_AFR_AF  \
# 0
# 1
# 2
# 3
# 4
# ...       ...    ...    ...    ...    ...        ...            ...
# 306164
# 306165                                       0.02802       0.001789
# 306166                                       0.02802       0.001789
# 306167                                       0.02802       0.001789
# 306168                                       0.02802       0.001789
#
#        gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF  \
# 0
# 1
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 306164
# 306165         0.0527      9.934e-05         0.2012              0
# 306166         0.0527      9.934e-05         0.2012              0
# 306167         0.0527      9.934e-05         0.2012              0
# 306168         0.0527      9.934e-05         0.2012              0
#
#        gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF  \
# 0                                                      0.03416        0.02306
# 1                                                      0.03416        0.02306
# 2                                                      0.03416        0.02306
# 3                                                      0.05175        0.04058
# 4                                                      0.05175        0.04058
# ...               ...            ...            ...        ...            ...
# 306164
# 306165      0.0005125        0.01736        0.04299    0.01208       0.001739
# 306166      0.0005125        0.01736        0.04299    0.01208       0.001739
# 306167      0.0005125        0.01736        0.04299    0.01208       0.001739
# 306168      0.0005125        0.01736        0.04299    0.01208       0.001739
#
#        gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF  \
# 0              0.1667        0.02711        0.03333       0.001639
# 1              0.1667        0.02711        0.03333       0.001639
# 2              0.1667        0.02711        0.03333       0.001639
# 3             0.02941        0.04766        0.04545        0.06778
# 4             0.02941        0.04766        0.04545        0.06778
# ...               ...            ...            ...            ...
# 306164
# 306165              0        0.02902       0.000288         0.2012
# 306166              0        0.02902       0.000288         0.2012
# 306167              0        0.02902       0.000288         0.2012
# 306168              0        0.02902       0.000288         0.2012
#
#        gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF gnomADg_OTH_AF  \
# 0                   0           0.05        0.09167        0.05357
# 1                   0           0.05        0.09167        0.05357
# 2                   0           0.05        0.09167        0.05357
# 3              0.0303         0.1538        0.06103        0.05789
# 4              0.0303         0.1538        0.06103        0.05789
# ...               ...            ...            ...            ...
# 306164
# 306165              0              0      0.0003382         0.0134
# 306166              0              0      0.0003382         0.0134
# 306167              0              0      0.0003382         0.0134
# 306168              0              0      0.0003382         0.0134
#
#        gnomADg_SAS_AF  MAX_AF              MAX_AF_POPS  \
# 0             0.02083  0.1667              gnomADg AMI
# 1             0.02083  0.1667              gnomADg AMI
# 2             0.02083  0.1667              gnomADg AMI
# 3              0.1089  0.1538              gnomADg MID
# 4              0.1089  0.1538              gnomADg MID
# ...               ...     ...                      ...
# 306164
# 306165        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306166        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306167        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306168        0.04662  0.2012  gnomADe EAS,gnomADg EAS
#
#                                    BIOTYPE EXON INTRON  \
# 0       transcribed unprocessed pseudogene
# 1                           protein coding         2/2
# 2                                   lncRNA
# 3                           protein coding  3/3
# 4                                   lncRNA
# ...                                    ...  ...    ...
# 306164                      protein coding
# 306165                      protein coding         5/8
# 306166                      protein coding         6/8
# 306167      protein coding CDS not defined
# 306168      protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED Matched_Gene  \
# 0                                  nan               1
# 1                                  nan               1
# 2                                  nan               1
# 3                                  N12  aaT/aaC      1
# 4                                  nan               1
# ...                                ...      ...    ...    ...          ...
# 306164                             nan              -1
# 306165                             nan               1
# 306166                             nan               1
# 306167                             nan               1
# 306168                             nan               1
#
#        Gene Match
# 0              No
# 1              No
# 2              No
# 3              No
# 4              No
# ...           ...
# 306164         No
# 306165         No
# 306166         No
# 306167         No
# 306168         No
#
# [306169 rows x 70 columns]

# %%
merged_2['Gene Match'].value_counts()
# Out:
# No                                    304214
# Type2Diabetes, MODY                      589
# Type2Diabetes                            416
# Type1Diabetes                            389
# Type1Diabetes, Type2Diabetes, MODY       206
# Diabetic_Nephropathy                     124
# Diabetic_Neuropathy                      117
# Type1Diabetes, MODY                       65
# MODY                                      34
# Diabetic_Retinopathy                      15
# Name: Gene Match, dtype: int64

# %%
merged_2.columns
# Out:
# Index(['Gene Name', 'rsID', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
#        'Consequence', 'Consequence_score', 'IMPACT', 'IMPACT_score',
#        'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc',
#        'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP',
#        'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT',
#        'PolyPhen', 'AF', 'AFR_AF', 'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF',
#        'gnomADe_AF', 'gnomADe_AFR_AF', 'gnomADe_AMR_AF', 'gnomADe_ASJ_AF',
#        'gnomADe_EAS_AF', 'gnomADe_FIN_AF', 'gnomADe_NFE_AF', 'gnomADe_OTH_AF',
#        'gnomADe_SAS_AF', 'gnomADg_AF', 'gnomADg_AFR_AF', 'gnomADg_AMI_AF',
#        'gnomADg_AMR_AF', 'gnomADg_ASJ_AF', 'gnomADg_EAS_AF', 'gnomADg_FIN_AF',
#        'gnomADg_MID_AF', 'gnomADg_NFE_AF', 'gnomADg_OTH_AF', 'gnomADg_SAS_AF',
#        'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE', 'EXON', 'INTRON',
#        'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED',
#        'Matched_Gene', 'Gene Match'],
#       dtype='object')

# %%
merged_2 = merged_2[['Gene Name', 'Gene Match', 'rsID', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
       'Consequence', 'Consequence_score', 'IMPACT', 'IMPACT_score',
       'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc',
       'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP',
       'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT',
       'PolyPhen', 'AF', 'AFR_AF',
       'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF', 'gnomADe_AF', 'gnomADe_AFR_AF',
       'gnomADe_AMR_AF', 'gnomADe_ASJ_AF', 'gnomADe_EAS_AF', 'gnomADe_FIN_AF',
       'gnomADe_NFE_AF', 'gnomADe_OTH_AF', 'gnomADe_SAS_AF', 'gnomADg_AF',
       'gnomADg_AFR_AF', 'gnomADg_AMI_AF', 'gnomADg_AMR_AF', 'gnomADg_ASJ_AF',
       'gnomADg_EAS_AF', 'gnomADg_FIN_AF', 'gnomADg_MID_AF', 'gnomADg_NFE_AF',
       'gnomADg_OTH_AF', 'gnomADg_SAS_AF', 'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE', 'EXON', 'INTRON',
       'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED']]
merged_2['POS'] = merged_2['POS'].astype('int64')
merged_2
# Out:
#        Gene Name Gene Match          rsID CHROM        POS REF ALT  \
# 0                        No  rs1416222198  chr1      65591   C   T
# 1                        No  rs1416222198  chr1      65591   C   T
# 2                        No  rs1416222198  chr1      65591   C   T
# 3          OR4F5         No  rs1260343719  chr1      69063   T   C
# 4          OR4F5         No  rs1260343719  chr1      69063   T   C
# ...          ...        ...           ...   ...        ...  ..  ..
# 306164                   No             .  chrX  155459837   A   G
# 306165      IL9R         No     rs2073467  chrX  156005252   C   T
# 306166      IL9R         No     rs2073467  chrX  156005252   C   T
# 306167      IL9R         No     rs2073467  chrX  156005252   C   T
# 306168      IL9R         No     rs2073467  chrX  156005252   C   T
#
#             Zygosity              Consequence Consequence_score    IMPACT  \
# 0       Heterozygous  downstream gene variant              2/10  MODIFIER
# 1       Heterozygous           intron variant              2/10  MODIFIER
# 2       Heterozygous  downstream gene variant              2/10  MODIFIER
# 3       Heterozygous       synonymous variant              3/10       LOW
# 4       Heterozygous  downstream gene variant              2/10  MODIFIER
# ...              ...                      ...               ...       ...
# 306164  Heterozygous    upstream gene variant              2/10  MODIFIER
# 306165  Heterozygous           intron variant              2/10  MODIFIER
# 306166  Heterozygous           intron variant              2/10  MODIFIER
# 306167  Heterozygous  downstream gene variant              2/10  MODIFIER
# 306168  Heterozygous    upstream gene variant              2/10  MODIFIER
#
#         IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar  \
# 0                1.5
# 1                1.5
# 2                1.5
# 3                2.5
# 4                1.5
# ...              ...           ...      ...                ...     ...
# 306164           1.5
# 306165           1.5
# 306166           1.5
# 306167           1.5
# 306168           1.5
#
#                      HGVSc HGVSc (Transcript)              HGVSp  \
# 0                                        None
# 1        ENST00000641515.2          c.9+18C>T
# 2                                        None
# 3        ENST00000641515.2            c.36T>C  ENSP00000493376.2
# 4                                        None
# ...                    ...                ...                ...
# 306164                                   None
# 306165  ENST00000244174.11        c.580-26C>T
# 306166   ENST00000369423.7        c.685-26C>T
# 306167                                   None
# 306168                                   None
#
#        HGVSp (Transcript)   GT  GQ  SDP   DP  RD  AD    FREQ       PVAL RDF  \
# 0                    None  0/1  22   31   31  24   7  22.58%  5.3469E-3  17
# 1                    None  0/1  22   31   31  24   7  22.58%  5.3469E-3  17
# 2                    None  0/1  22   31   31  24   7  22.58%  5.3469E-3  17
# 3              p.Asn12%3D  0/1  67   45   45  26  19  42.22%  1.6979E-7  23
# 4                    None  0/1  67   45   45  26  19  42.22%  1.6979E-7  23
# ...                   ...  ...  ..  ...  ...  ..  ..     ...        ...  ..
# 306164               None  0/1  71  103  103  81  22  21.36%  6.7976E-8  54
# 306165               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
# 306166               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
# 306167               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
# 306168               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
#
#        RDR ADF ADR SIFT PolyPhen AF AFR_AF AMR_AF EAS_AF EUR_AF SAS_AF  \
# 0        7   3   4
# 1        7   3   4
# 2        7   3   4
# 3        3  18   1
# 4        3  18   1
# ...     ..  ..  ..  ...      ... ..    ...    ...    ...    ...    ...
# 306164  27  14   8
# 306165   0   8   0
# 306166   0   8   0
# 306167   0   8   0
# 306168   0   8   0
#
#        gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF  \
# 0
# 1
# 2
# 3
# 4
# ...           ...            ...            ...            ...            ...
# 306164
# 306165    0.02802       0.001789         0.0527      9.934e-05         0.2012
# 306166    0.02802       0.001789         0.0527      9.934e-05         0.2012
# 306167    0.02802       0.001789         0.0527      9.934e-05         0.2012
# 306168    0.02802       0.001789         0.0527      9.934e-05         0.2012
#
#        gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF  \
# 0                                                                     0.03416
# 1                                                                     0.03416
# 2                                                                     0.03416
# 3                                                                     0.05175
# 4                                                                     0.05175
# ...               ...            ...            ...            ...        ...
# 306164
# 306165              0      0.0005125        0.01736        0.04299    0.01208
# 306166              0      0.0005125        0.01736        0.04299    0.01208
# 306167              0      0.0005125        0.01736        0.04299    0.01208
# 306168              0      0.0005125        0.01736        0.04299    0.01208
#
#        gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF  \
# 0             0.02306         0.1667        0.02711        0.03333
# 1             0.02306         0.1667        0.02711        0.03333
# 2             0.02306         0.1667        0.02711        0.03333
# 3             0.04058        0.02941        0.04766        0.04545
# 4             0.04058        0.02941        0.04766        0.04545
# ...               ...            ...            ...            ...
# 306164
# 306165       0.001739              0        0.02902       0.000288
# 306166       0.001739              0        0.02902       0.000288
# 306167       0.001739              0        0.02902       0.000288
# 306168       0.001739              0        0.02902       0.000288
#
#        gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0            0.001639              0           0.05        0.09167
# 1            0.001639              0           0.05        0.09167
# 2            0.001639              0           0.05        0.09167
# 3             0.06778         0.0303         0.1538        0.06103
# 4             0.06778         0.0303         0.1538        0.06103
# ...               ...            ...            ...            ...
# 306164
# 306165         0.2012              0              0      0.0003382
# 306166         0.2012              0              0      0.0003382
# 306167         0.2012              0              0      0.0003382
# 306168         0.2012              0              0      0.0003382
#
#        gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF              MAX_AF_POPS  \
# 0             0.05357        0.02083  0.1667              gnomADg AMI
# 1             0.05357        0.02083  0.1667              gnomADg AMI
# 2             0.05357        0.02083  0.1667              gnomADg AMI
# 3             0.05789         0.1089  0.1538              gnomADg MID
# 4             0.05789         0.1089  0.1538              gnomADg MID
# ...               ...            ...     ...                      ...
# 306164
# 306165         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306166         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306167         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306168         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
#
#                                    BIOTYPE EXON INTRON  \
# 0       transcribed unprocessed pseudogene
# 1                           protein coding         2/2
# 2                                   lncRNA
# 3                           protein coding  3/3
# 4                                   lncRNA
# ...                                    ...  ...    ...
# 306164                      protein coding
# 306165                      protein coding         5/8
# 306166                      protein coding         6/8
# 306167      protein coding CDS not defined
# 306168      protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED
# 0                                  nan               1
# 1                                  nan               1
# 2                                  nan               1
# 3                                  N12  aaT/aaC      1
# 4                                  nan               1
# ...                                ...      ...    ...    ...
# 306164                             nan              -1
# 306165                             nan               1
# 306166                             nan               1
# 306167                             nan               1
# 306168                             nan               1
#
# [306169 rows x 69 columns]

# %%
merged_2['Gene_Match'] = 'No'

# Iterate through each gene in df1
for genes in merged_2['Gene Name']:
    if isinstance(genes, str):  # Check if the gene value is a non-null string
        gene_list = genes.split(',')  # Split the genes by comma to create a list
        match = any(gene in df_gene['Gene Name'].values for gene in gene_list)  # Check if any gene in the list exists in df2
        if match:
            merged_2.loc[merged_2['Gene Name'] == genes, 'Gene_Match'] = 'Yes'
            
merged_2
# Out:
#        Gene Name          rsID CHROM        POS REF ALT      Zygosity  \
# 0                 rs1416222198  chr1      65591   C   T  Heterozygous
# 1                 rs1416222198  chr1      65591   C   T  Heterozygous
# 2                 rs1416222198  chr1      65591   C   T  Heterozygous
# 3          OR4F5  rs1260343719  chr1      69063   T   C  Heterozygous
# 4          OR4F5  rs1260343719  chr1      69063   T   C  Heterozygous
# ...          ...           ...   ...        ...  ..  ..           ...
# 306164                       .  chrX  155459837   A   G  Heterozygous
# 306165      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
# 306166      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
# 306167      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
# 306168      IL9R     rs2073467  chrX  156005252   C   T  Heterozygous
#
#                     Consequence Consequence_score    IMPACT  IMPACT_score  \
# 0       downstream gene variant              2/10  MODIFIER           1.5
# 1                intron variant              2/10  MODIFIER           1.5
# 2       downstream gene variant              2/10  MODIFIER           1.5
# 3            synonymous variant              3/10       LOW           2.5
# 4       downstream gene variant              2/10  MODIFIER           1.5
# ...                         ...               ...       ...           ...
# 306164    upstream gene variant              2/10  MODIFIER           1.5
# 306165           intron variant              2/10  MODIFIER           1.5
# 306166           intron variant              2/10  MODIFIER           1.5
# 306167  downstream gene variant              2/10  MODIFIER           1.5
# 306168    upstream gene variant              2/10  MODIFIER           1.5
#
#        ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar               HGVSc  \
# 0
# 1                                                          ENST00000641515.2
# 2
# 3                                                          ENST00000641515.2
# 4
# ...              ...      ...                ...     ...                 ...
# 306164
# 306165                                                    ENST00000244174.11
# 306166                                                     ENST00000369423.7
# 306167
# 306168
#
#        HGVSc (Transcript)              HGVSp HGVSp (Transcript)   GT  GQ  SDP  \
# 0                    None                                  None  0/1  22   31
# 1               c.9+18C>T                                  None  0/1  22   31
# 2                    None                                  None  0/1  22   31
# 3                 c.36T>C  ENSP00000493376.2         p.Asn12%3D  0/1  67   45
# 4                    None                                  None  0/1  67   45
# ...                   ...                ...                ...  ...  ..  ...
# 306164               None                                  None  0/1  71  103
# 306165        c.580-26C>T                                  None  0/1  31   12
# 306166        c.685-26C>T                                  None  0/1  31   12
# 306167               None                                  None  0/1  31   12
# 306168               None                                  None  0/1  31   12
#
#          DP  RD  AD    FREQ       PVAL RDF RDR ADF ADR SIFT PolyPhen AF  \
# 0        31  24   7  22.58%  5.3469E-3  17   7   3   4
# 1        31  24   7  22.58%  5.3469E-3  17   7   3   4
# 2        31  24   7  22.58%  5.3469E-3  17   7   3   4
# 3        45  26  19  42.22%  1.6979E-7  23   3  18   1
# 4        45  26  19  42.22%  1.6979E-7  23   3  18   1
# ...     ...  ..  ..     ...        ...  ..  ..  ..  ..  ...      ... ..
# 306164  103  81  22  21.36%  6.7976E-8  54  27  14   8
# 306165   12   4   8  66.67%  6.7304E-4   4   0   8   0
# 306166   12   4   8  66.67%  6.7304E-4   4   0   8   0
# 306167   12   4   8  66.67%  6.7304E-4   4   0   8   0
# 306168   12   4   8  66.67%  6.7304E-4   4   0   8   0
#
#        AFR_AF AMR_AF EAS_AF EUR_AF SAS_AF gnomADe_AF gnomADe_AFR_AF  \
# 0
# 1
# 2
# 3
# 4
# ...       ...    ...    ...    ...    ...        ...            ...
# 306164
# 306165                                       0.02802       0.001789
# 306166                                       0.02802       0.001789
# 306167                                       0.02802       0.001789
# 306168                                       0.02802       0.001789
#
#        gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF  \
# 0
# 1
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 306164
# 306165         0.0527      9.934e-05         0.2012              0
# 306166         0.0527      9.934e-05         0.2012              0
# 306167         0.0527      9.934e-05         0.2012              0
# 306168         0.0527      9.934e-05         0.2012              0
#
#        gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF  \
# 0                                                      0.03416        0.02306
# 1                                                      0.03416        0.02306
# 2                                                      0.03416        0.02306
# 3                                                      0.05175        0.04058
# 4                                                      0.05175        0.04058
# ...               ...            ...            ...        ...            ...
# 306164
# 306165      0.0005125        0.01736        0.04299    0.01208       0.001739
# 306166      0.0005125        0.01736        0.04299    0.01208       0.001739
# 306167      0.0005125        0.01736        0.04299    0.01208       0.001739
# 306168      0.0005125        0.01736        0.04299    0.01208       0.001739
#
#        gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF  \
# 0              0.1667        0.02711        0.03333       0.001639
# 1              0.1667        0.02711        0.03333       0.001639
# 2              0.1667        0.02711        0.03333       0.001639
# 3             0.02941        0.04766        0.04545        0.06778
# 4             0.02941        0.04766        0.04545        0.06778
# ...               ...            ...            ...            ...
# 306164
# 306165              0        0.02902       0.000288         0.2012
# 306166              0        0.02902       0.000288         0.2012
# 306167              0        0.02902       0.000288         0.2012
# 306168              0        0.02902       0.000288         0.2012
#
#        gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF gnomADg_OTH_AF  \
# 0                   0           0.05        0.09167        0.05357
# 1                   0           0.05        0.09167        0.05357
# 2                   0           0.05        0.09167        0.05357
# 3              0.0303         0.1538        0.06103        0.05789
# 4              0.0303         0.1538        0.06103        0.05789
# ...               ...            ...            ...            ...
# 306164
# 306165              0              0      0.0003382         0.0134
# 306166              0              0      0.0003382         0.0134
# 306167              0              0      0.0003382         0.0134
# 306168              0              0      0.0003382         0.0134
#
#        gnomADg_SAS_AF  MAX_AF              MAX_AF_POPS  \
# 0             0.02083  0.1667              gnomADg AMI
# 1             0.02083  0.1667              gnomADg AMI
# 2             0.02083  0.1667              gnomADg AMI
# 3              0.1089  0.1538              gnomADg MID
# 4              0.1089  0.1538              gnomADg MID
# ...               ...     ...                      ...
# 306164
# 306165        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306166        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306167        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306168        0.04662  0.2012  gnomADe EAS,gnomADg EAS
#
#                                    BIOTYPE EXON INTRON  \
# 0       transcribed unprocessed pseudogene
# 1                           protein coding         2/2
# 2                                   lncRNA
# 3                           protein coding  3/3
# 4                                   lncRNA
# ...                                    ...  ...    ...
# 306164                      protein coding
# 306165                      protein coding         5/8
# 306166                      protein coding         6/8
# 306167      protein coding CDS not defined
# 306168      protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED Gene_Match
# 0                                  nan               1                No
# 1                                  nan               1                No
# 2                                  nan               1                No
# 3                                  N12  aaT/aaC      1                No
# 4                                  nan               1                No
# ...                                ...      ...    ...    ...        ...
# 306164                             nan              -1                No
# 306165                             nan               1                No
# 306166                             nan               1                No
# 306167                             nan               1                No
# 306168                             nan               1                No
#
# [306169 rows x 69 columns]

# %%
merged_2.Gene_Match.value_counts()
# Out:
# No     303375
# Yes      2794
# Name: Gene_Match, dtype: int64

# %%
merged_2 = merged_2[['Gene Name', 'Gene_Match', 'rsID', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
       'Consequence', 'Consequence_score', 'IMPACT', 'IMPACT_score',
       'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc',
       'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP',
       'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT',
       'PolyPhen', 'AF', 'AFR_AF',
       'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF', 'gnomADe_AF', 'gnomADe_AFR_AF',
       'gnomADe_AMR_AF', 'gnomADe_ASJ_AF', 'gnomADe_EAS_AF', 'gnomADe_FIN_AF',
       'gnomADe_NFE_AF', 'gnomADe_OTH_AF', 'gnomADe_SAS_AF', 'gnomADg_AF',
       'gnomADg_AFR_AF', 'gnomADg_AMI_AF', 'gnomADg_AMR_AF', 'gnomADg_ASJ_AF',
       'gnomADg_EAS_AF', 'gnomADg_FIN_AF', 'gnomADg_MID_AF', 'gnomADg_NFE_AF',
       'gnomADg_OTH_AF', 'gnomADg_SAS_AF', 'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE', 'EXON', 'INTRON',
       'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED']]
merged_2['POS'] = merged_2['POS'].astype('int64')
merged_2
# Out:
#        Gene Name Gene_Match          rsID CHROM        POS REF ALT  \
# 0                        No  rs1416222198  chr1      65591   C   T
# 1                        No  rs1416222198  chr1      65591   C   T
# 2                        No  rs1416222198  chr1      65591   C   T
# 3          OR4F5         No  rs1260343719  chr1      69063   T   C
# 4          OR4F5         No  rs1260343719  chr1      69063   T   C
# ...          ...        ...           ...   ...        ...  ..  ..
# 306164                   No             .  chrX  155459837   A   G
# 306165      IL9R         No     rs2073467  chrX  156005252   C   T
# 306166      IL9R         No     rs2073467  chrX  156005252   C   T
# 306167      IL9R         No     rs2073467  chrX  156005252   C   T
# 306168      IL9R         No     rs2073467  chrX  156005252   C   T
#
#             Zygosity              Consequence Consequence_score    IMPACT  \
# 0       Heterozygous  downstream gene variant              2/10  MODIFIER
# 1       Heterozygous           intron variant              2/10  MODIFIER
# 2       Heterozygous  downstream gene variant              2/10  MODIFIER
# 3       Heterozygous       synonymous variant              3/10       LOW
# 4       Heterozygous  downstream gene variant              2/10  MODIFIER
# ...              ...                      ...               ...       ...
# 306164  Heterozygous    upstream gene variant              2/10  MODIFIER
# 306165  Heterozygous           intron variant              2/10  MODIFIER
# 306166  Heterozygous           intron variant              2/10  MODIFIER
# 306167  Heterozygous  downstream gene variant              2/10  MODIFIER
# 306168  Heterozygous    upstream gene variant              2/10  MODIFIER
#
#         IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar  \
# 0                1.5
# 1                1.5
# 2                1.5
# 3                2.5
# 4                1.5
# ...              ...           ...      ...                ...     ...
# 306164           1.5
# 306165           1.5
# 306166           1.5
# 306167           1.5
# 306168           1.5
#
#                      HGVSc HGVSc (Transcript)              HGVSp  \
# 0                                        None
# 1        ENST00000641515.2          c.9+18C>T
# 2                                        None
# 3        ENST00000641515.2            c.36T>C  ENSP00000493376.2
# 4                                        None
# ...                    ...                ...                ...
# 306164                                   None
# 306165  ENST00000244174.11        c.580-26C>T
# 306166   ENST00000369423.7        c.685-26C>T
# 306167                                   None
# 306168                                   None
#
#        HGVSp (Transcript)   GT  GQ  SDP   DP  RD  AD    FREQ       PVAL RDF  \
# 0                    None  0/1  22   31   31  24   7  22.58%  5.3469E-3  17
# 1                    None  0/1  22   31   31  24   7  22.58%  5.3469E-3  17
# 2                    None  0/1  22   31   31  24   7  22.58%  5.3469E-3  17
# 3              p.Asn12%3D  0/1  67   45   45  26  19  42.22%  1.6979E-7  23
# 4                    None  0/1  67   45   45  26  19  42.22%  1.6979E-7  23
# ...                   ...  ...  ..  ...  ...  ..  ..     ...        ...  ..
# 306164               None  0/1  71  103  103  81  22  21.36%  6.7976E-8  54
# 306165               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
# 306166               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
# 306167               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
# 306168               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
#
#        RDR ADF ADR SIFT PolyPhen AF AFR_AF AMR_AF EAS_AF EUR_AF SAS_AF  \
# 0        7   3   4
# 1        7   3   4
# 2        7   3   4
# 3        3  18   1
# 4        3  18   1
# ...     ..  ..  ..  ...      ... ..    ...    ...    ...    ...    ...
# 306164  27  14   8
# 306165   0   8   0
# 306166   0   8   0
# 306167   0   8   0
# 306168   0   8   0
#
#        gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF  \
# 0
# 1
# 2
# 3
# 4
# ...           ...            ...            ...            ...            ...
# 306164
# 306165    0.02802       0.001789         0.0527      9.934e-05         0.2012
# 306166    0.02802       0.001789         0.0527      9.934e-05         0.2012
# 306167    0.02802       0.001789         0.0527      9.934e-05         0.2012
# 306168    0.02802       0.001789         0.0527      9.934e-05         0.2012
#
#        gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF  \
# 0                                                                     0.03416
# 1                                                                     0.03416
# 2                                                                     0.03416
# 3                                                                     0.05175
# 4                                                                     0.05175
# ...               ...            ...            ...            ...        ...
# 306164
# 306165              0      0.0005125        0.01736        0.04299    0.01208
# 306166              0      0.0005125        0.01736        0.04299    0.01208
# 306167              0      0.0005125        0.01736        0.04299    0.01208
# 306168              0      0.0005125        0.01736        0.04299    0.01208
#
#        gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF  \
# 0             0.02306         0.1667        0.02711        0.03333
# 1             0.02306         0.1667        0.02711        0.03333
# 2             0.02306         0.1667        0.02711        0.03333
# 3             0.04058        0.02941        0.04766        0.04545
# 4             0.04058        0.02941        0.04766        0.04545
# ...               ...            ...            ...            ...
# 306164
# 306165       0.001739              0        0.02902       0.000288
# 306166       0.001739              0        0.02902       0.000288
# 306167       0.001739              0        0.02902       0.000288
# 306168       0.001739              0        0.02902       0.000288
#
#        gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0            0.001639              0           0.05        0.09167
# 1            0.001639              0           0.05        0.09167
# 2            0.001639              0           0.05        0.09167
# 3             0.06778         0.0303         0.1538        0.06103
# 4             0.06778         0.0303         0.1538        0.06103
# ...               ...            ...            ...            ...
# 306164
# 306165         0.2012              0              0      0.0003382
# 306166         0.2012              0              0      0.0003382
# 306167         0.2012              0              0      0.0003382
# 306168         0.2012              0              0      0.0003382
#
#        gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF              MAX_AF_POPS  \
# 0             0.05357        0.02083  0.1667              gnomADg AMI
# 1             0.05357        0.02083  0.1667              gnomADg AMI
# 2             0.05357        0.02083  0.1667              gnomADg AMI
# 3             0.05789         0.1089  0.1538              gnomADg MID
# 4             0.05789         0.1089  0.1538              gnomADg MID
# ...               ...            ...     ...                      ...
# 306164
# 306165         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306166         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306167         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306168         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
#
#                                    BIOTYPE EXON INTRON  \
# 0       transcribed unprocessed pseudogene
# 1                           protein coding         2/2
# 2                                   lncRNA
# 3                           protein coding  3/3
# 4                                   lncRNA
# ...                                    ...  ...    ...
# 306164                      protein coding
# 306165                      protein coding         5/8
# 306166                      protein coding         6/8
# 306167      protein coding CDS not defined
# 306168      protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED
# 0                                  nan               1
# 1                                  nan               1
# 2                                  nan               1
# 3                                  N12  aaT/aaC      1
# 4                                  nan               1
# ...                                ...      ...    ...    ...
# 306164                             nan              -1
# 306165                             nan               1
# 306166                             nan               1
# 306167                             nan               1
# 306168                             nan               1
#
# [306169 rows x 69 columns]

# %%
import pandas as pd
x = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/Diab_lit_variants_all.xlsx')
x['chrom'] = x['Chrom-pos-Ref-Alt_38'].str.split(',')
x = x.explode('chrom')

x['CHROM'] = x['chrom'].str.split('-').str[0]

# Function to add 'chr' prefix conditionally
def add_chr_prefix(chrom):
    if pd.notnull(chrom) and chrom.strip() != '':
        return 'chr' + str(chrom)
    else:
        return chrom

# Applying the function to the 'chromosome' column
x['CHROM'] = x['CHROM'].apply(add_chr_prefix)
x['CHROM'] = x['CHROM'].str.strip()
x['CHROM'] = x['CHROM'].str.replace(r'\s+', '')
x['POS'] = x['chrom'].str.split('-').str[1]

x.dropna(subset=['CHROM'], inplace=True)
# Drop rows with empty cells after removing leading and trailing whitespaces
x['CHROM'] = x['CHROM'].str.strip()
x['POS'] = x['POS'].str.strip()
# Dropping rows with empty cells and NaN values in both 'chromosome' and 'position' columns
x.dropna(subset=['CHROM', 'POS'], inplace=True)
df_3 = x[['CHROM', 'POS']]
df_3['Literature'] = 'Yes'
df_3.drop_duplicates(subset='POS', inplace=True)
df_3['POS'] = df_3['POS'].astype('int64')
df_3 = df_3.reset_index()
df_3 = df_3[['CHROM', 'POS', 'Literature']]

df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/KAPA HyperExome_hg38_capture_targets (1).bed', sep = '\t', header = None)
df.columns = ['chromosome', 'Start_pos', 'End_pos', 'INFO']

df['Extended_Start_pos'] = df['Start_pos'] - 20
df['Extended_End_pos'] = df['End_pos'] + 20

df['gene_symbol'] = df['INFO'].str.extract(r'gene_symbol=([^;]+)')
df = df[['chromosome', 'Extended_Start_pos', 'Extended_End_pos', 'INFO', 'gene_symbol']]


# Step 1: Create a dictionary from the df DataFrame
chromosome_dict = {}
for _, row in df.iterrows():
    chromosome = row['chromosome']
    start_pos = row['Extended_Start_pos']
    end_pos = row['Extended_End_pos']
    if chromosome not in chromosome_dict:
        chromosome_dict[chromosome] = []
    chromosome_dict[chromosome].append((start_pos, end_pos))

# Step 2: Define a function to check coverage
def check_coverage(row):
    pos = row['POS']
    chromosome = row['CHROM']
    if chromosome in chromosome_dict:
        ranges = chromosome_dict[chromosome]
        for start, end in ranges:
            if start <= pos <= end:
                return 'Covered'
    return 'Not_Covered'

# Step 3: Apply the function to create the new column in dataset2
df_3['Covered/Not_Covered'] = df_3.apply(check_coverage, axis=1)

df_3 = df_3[df_3['Covered/Not_Covered'] == 'Covered']
df_3.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/KHGLBS578/Hypoglycemia_lit_variants.xlsx', index = False)

# %%
df_3
# Out:
#       CHROM        POS Literature Covered/Not_Covered
# 0     chr12  120978691        Yes             Covered
# 1     chr12  120978908        Yes             Covered
# 2     chr12  120997590        Yes             Covered
# 3     chr12  120996531        Yes             Covered
# 4     chr12  120978928        Yes             Covered
# ...     ...        ...        ...                 ...
# 4761  chr11   17408513        Yes             Covered
# 4798  chr11   66616700        Yes             Covered
# 4803  chr11   66616749        Yes             Covered
# 4806  chr11   66616734        Yes             Covered
# 4809  chr11   66625360        Yes             Covered
#
# [1777 rows x 4 columns]

# %%
merged_3 = pd.merge(merged_2, df_3, on=['CHROM', 'POS'], how='left', sort=False)
merged_3['Literature'] = merged_3['Literature'].fillna('No')
merged_3
# Out:
#        Gene Name Gene Match          rsID CHROM        POS REF ALT  \
# 0                        No  rs1416222198  chr1      65591   C   T
# 1                        No  rs1416222198  chr1      65591   C   T
# 2                        No  rs1416222198  chr1      65591   C   T
# 3          OR4F5         No  rs1260343719  chr1      69063   T   C
# 4          OR4F5         No  rs1260343719  chr1      69063   T   C
# ...          ...        ...           ...   ...        ...  ..  ..
# 306164                   No             .  chrX  155459837   A   G
# 306165      IL9R         No     rs2073467  chrX  156005252   C   T
# 306166      IL9R         No     rs2073467  chrX  156005252   C   T
# 306167      IL9R         No     rs2073467  chrX  156005252   C   T
# 306168      IL9R         No     rs2073467  chrX  156005252   C   T
#
#             Zygosity              Consequence Consequence_score    IMPACT  \
# 0       Heterozygous  downstream gene variant              2/10  MODIFIER
# 1       Heterozygous           intron variant              2/10  MODIFIER
# 2       Heterozygous  downstream gene variant              2/10  MODIFIER
# 3       Heterozygous       synonymous variant              3/10       LOW
# 4       Heterozygous  downstream gene variant              2/10  MODIFIER
# ...              ...                      ...               ...       ...
# 306164  Heterozygous    upstream gene variant              2/10  MODIFIER
# 306165  Heterozygous           intron variant              2/10  MODIFIER
# 306166  Heterozygous           intron variant              2/10  MODIFIER
# 306167  Heterozygous  downstream gene variant              2/10  MODIFIER
# 306168  Heterozygous    upstream gene variant              2/10  MODIFIER
#
#         IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar  \
# 0                1.5
# 1                1.5
# 2                1.5
# 3                2.5
# 4                1.5
# ...              ...           ...      ...                ...     ...
# 306164           1.5
# 306165           1.5
# 306166           1.5
# 306167           1.5
# 306168           1.5
#
#                      HGVSc HGVSc (Transcript)              HGVSp  \
# 0                                        None
# 1        ENST00000641515.2          c.9+18C>T
# 2                                        None
# 3        ENST00000641515.2            c.36T>C  ENSP00000493376.2
# 4                                        None
# ...                    ...                ...                ...
# 306164                                   None
# 306165  ENST00000244174.11        c.580-26C>T
# 306166   ENST00000369423.7        c.685-26C>T
# 306167                                   None
# 306168                                   None
#
#        HGVSp (Transcript)   GT  GQ  SDP   DP  RD  AD    FREQ       PVAL RDF  \
# 0                    None  0/1  22   31   31  24   7  22.58%  5.3469E-3  17
# 1                    None  0/1  22   31   31  24   7  22.58%  5.3469E-3  17
# 2                    None  0/1  22   31   31  24   7  22.58%  5.3469E-3  17
# 3              p.Asn12%3D  0/1  67   45   45  26  19  42.22%  1.6979E-7  23
# 4                    None  0/1  67   45   45  26  19  42.22%  1.6979E-7  23
# ...                   ...  ...  ..  ...  ...  ..  ..     ...        ...  ..
# 306164               None  0/1  71  103  103  81  22  21.36%  6.7976E-8  54
# 306165               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
# 306166               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
# 306167               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
# 306168               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
#
#        RDR ADF ADR SIFT PolyPhen AF AFR_AF AMR_AF EAS_AF EUR_AF SAS_AF  \
# 0        7   3   4
# 1        7   3   4
# 2        7   3   4
# 3        3  18   1
# 4        3  18   1
# ...     ..  ..  ..  ...      ... ..    ...    ...    ...    ...    ...
# 306164  27  14   8
# 306165   0   8   0
# 306166   0   8   0
# 306167   0   8   0
# 306168   0   8   0
#
#        gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF  \
# 0
# 1
# 2
# 3
# 4
# ...           ...            ...            ...            ...            ...
# 306164
# 306165    0.02802       0.001789         0.0527      9.934e-05         0.2012
# 306166    0.02802       0.001789         0.0527      9.934e-05         0.2012
# 306167    0.02802       0.001789         0.0527      9.934e-05         0.2012
# 306168    0.02802       0.001789         0.0527      9.934e-05         0.2012
#
#        gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF  \
# 0                                                                     0.03416
# 1                                                                     0.03416
# 2                                                                     0.03416
# 3                                                                     0.05175
# 4                                                                     0.05175
# ...               ...            ...            ...            ...        ...
# 306164
# 306165              0      0.0005125        0.01736        0.04299    0.01208
# 306166              0      0.0005125        0.01736        0.04299    0.01208
# 306167              0      0.0005125        0.01736        0.04299    0.01208
# 306168              0      0.0005125        0.01736        0.04299    0.01208
#
#        gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF  \
# 0             0.02306         0.1667        0.02711        0.03333
# 1             0.02306         0.1667        0.02711        0.03333
# 2             0.02306         0.1667        0.02711        0.03333
# 3             0.04058        0.02941        0.04766        0.04545
# 4             0.04058        0.02941        0.04766        0.04545
# ...               ...            ...            ...            ...
# 306164
# 306165       0.001739              0        0.02902       0.000288
# 306166       0.001739              0        0.02902       0.000288
# 306167       0.001739              0        0.02902       0.000288
# 306168       0.001739              0        0.02902       0.000288
#
#        gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0            0.001639              0           0.05        0.09167
# 1            0.001639              0           0.05        0.09167
# 2            0.001639              0           0.05        0.09167
# 3             0.06778         0.0303         0.1538        0.06103
# 4             0.06778         0.0303         0.1538        0.06103
# ...               ...            ...            ...            ...
# 306164
# 306165         0.2012              0              0      0.0003382
# 306166         0.2012              0              0      0.0003382
# 306167         0.2012              0              0      0.0003382
# 306168         0.2012              0              0      0.0003382
#
#        gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF              MAX_AF_POPS  \
# 0             0.05357        0.02083  0.1667              gnomADg AMI
# 1             0.05357        0.02083  0.1667              gnomADg AMI
# 2             0.05357        0.02083  0.1667              gnomADg AMI
# 3             0.05789         0.1089  0.1538              gnomADg MID
# 4             0.05789         0.1089  0.1538              gnomADg MID
# ...               ...            ...     ...                      ...
# 306164
# 306165         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306166         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306167         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306168         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
#
#                                    BIOTYPE EXON INTRON  \
# 0       transcribed unprocessed pseudogene
# 1                           protein coding         2/2
# 2                                   lncRNA
# 3                           protein coding  3/3
# 4                                   lncRNA
# ...                                    ...  ...    ...
# 306164                      protein coding
# 306165                      protein coding         5/8
# 306166                      protein coding         6/8
# 306167      protein coding CDS not defined
# 306168      protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED Literature  \
# 0                                  nan               1                No
# 1                                  nan               1                No
# 2                                  nan               1                No
# 3                                  N12  aaT/aaC      1                No
# 4                                  nan               1                No
# ...                                ...      ...    ...    ...        ...
# 306164                             nan              -1                No
# 306165                             nan               1                No
# 306166                             nan               1                No
# 306167                             nan               1                No
# 306168                             nan               1                No
#
#        Covered/Not_Covered
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 306164                 NaN
# 306165                 NaN
# 306166                 NaN
# 306167                 NaN
# 306168                 NaN
#
# [306169 rows x 71 columns]

# %%
merged_3.Literature.value_counts()
# Out:
# No     306097
# Yes        72
# Name: Literature, dtype: int64

# %%
merged_3[merged_3['Literature'] == 'Yes']
# Out:
#       Gene Name                          Gene Match       rsID  CHROM  \
# 69781     HNF1A  Type1Diabetes, Type2Diabetes, MODY  rs1169288  chr12
# 69782     HNF1A  Type1Diabetes, Type2Diabetes, MODY  rs1169288  chr12
# 69783     HNF1A  Type1Diabetes, Type2Diabetes, MODY  rs1169288  chr12
# 69784     HNF1A  Type1Diabetes, Type2Diabetes, MODY  rs1169288  chr12
# 69785     HNF1A  Type1Diabetes, Type2Diabetes, MODY  rs1169288  chr12
# ...         ...                                 ...        ...    ...
# 69860     HNF1A  Type1Diabetes, Type2Diabetes, MODY  rs2464195  chr12
# 69861     HNF1A  Type1Diabetes, Type2Diabetes, MODY  rs2464195  chr12
# 69862     HNF1A  Type1Diabetes, Type2Diabetes, MODY  rs2464195  chr12
# 69863     HNF1A  Type1Diabetes, Type2Diabetes, MODY  rs2464195  chr12
# 69864     HNF1A  Type1Diabetes, Type2Diabetes, MODY  rs2464195  chr12
#
#              POS REF ALT      Zygosity  \
# 69781  120978847   A   C  Heterozygous
# 69782  120978847   A   C  Heterozygous
# 69783  120978847   A   C  Heterozygous
# 69784  120978847   A   C  Heterozygous
# 69785  120978847   A   C  Heterozygous
# ...          ...  ..  ..           ...
# 69860  120997672   G   A    Homozygous
# 69861  120997672   G   A    Homozygous
# 69862  120997672   G   A    Homozygous
# 69863  120997672   G   A    Homozygous
# 69864  120997672   G   A    Homozygous
#
#                                              Consequence Consequence_score  \
# 69781                                   missense variant              7/10
# 69782                                   missense variant              7/10
# 69783                 non coding transcript exon variant              2/10
# 69784       intron variant,non coding transcript variant              2/10
# 69785       intron variant,non coding transcript variant              2/10
# ...                                                  ...               ...
# 69860         3 prime UTR variant,NMD transcript variant              3/10
# 69861                 non coding transcript exon variant              2/10
# 69862               splice region variant,intron variant              4/10
# 69863         3 prime UTR variant,NMD transcript variant              3/10
# 69864  splice region variant,intron variant,NMD trans...              4/10
#
#          IMPACT  IMPACT_score  \
# 69781  MODERATE           5.0
# 69782  MODERATE           5.0
# 69783  MODIFIER           1.5
# 69784  MODIFIER           1.5
# 69785  MODIFIER           1.5
# ...         ...           ...
# 69860  MODIFIER           1.5
# 69861  MODIFIER           1.5
# 69862       LOW           2.5
# 69863  MODIFIER           1.5
# 69864       LOW           2.5
#
#                                            ClinVar_CLNDN  \
# 69781  Maturity onset diabetes mellitus in young,Nonp...
# 69782  Maturity onset diabetes mellitus in young,Nonp...
# 69783  Maturity onset diabetes mellitus in young,Nonp...
# 69784  Maturity onset diabetes mellitus in young,Nonp...
# 69785  Maturity onset diabetes mellitus in young,Nonp...
# ...                                                  ...
# 69860  Nonpapillary renal cell carcinoma,Maturity ons...
# 69861  Nonpapillary renal cell carcinoma,Maturity ons...
# 69862  Nonpapillary renal cell carcinoma,Maturity ons...
# 69863  Nonpapillary renal cell carcinoma,Maturity ons...
# 69864  Nonpapillary renal cell carcinoma,Maturity ons...
#
#                             CLIN_SIG  \
# 69781             risk factor,benign
# 69782             risk factor,benign
# 69783             risk factor,benign
# 69784             risk factor,benign
# 69785             risk factor,benign
# ...                              ...
# 69860  benign,uncertain significance
# 69861  benign,uncertain significance
# 69862  benign,uncertain significance
# 69863  benign,uncertain significance
# 69864  benign,uncertain significance
#
#                                    ClinVar_CLNREVSTAT ClinVar  \
# 69781  criteria provided, conflicting interpretations   14937
# 69782  criteria provided, conflicting interpretations   14937
# 69783  criteria provided, conflicting interpretations   14937
# 69784  criteria provided, conflicting interpretations   14937
# 69785  criteria provided, conflicting interpretations   14937
# ...                                               ...     ...
# 69860  criteria provided, conflicting interpretations  129231
# 69861  criteria provided, conflicting interpretations  129231
# 69862  criteria provided, conflicting interpretations  129231
# 69863  criteria provided, conflicting interpretations  129231
# 69864  criteria provided, conflicting interpretations  129231
#
#                     HGVSc HGVSc (Transcript)              HGVSp  \
# 69781  ENST00000257555.11            c.79A>C  ENSP00000257555.5
# 69782   ENST00000400024.6            c.79A>C  ENSP00000476181.1
# 69783   ENST00000402929.5           n.214A>C
# 69784   ENST00000433033.3       n.134+767T>G
# 69785   ENST00000535301.2      n.322+1797T>G
# ...                   ...                ...                ...
# 69860   ENST00000541924.5          c.*522G>A
# 69861   ENST00000543255.1           n.552G>A
# 69862   ENST00000544413.2        c.1501+7G>A
# 69863   ENST00000544574.5          c.*271G>A
# 69864   ENST00000560968.5        c.*248+7G>A
#
#       HGVSp (Transcript)   GT   GQ SDP  DP  RD  AD  FREQ        PVAL RDF RDR  \
# 69781         p.Ile27Leu  0/1   64  40  40  22  18   45%   3.1919E-7  18   4
# 69782         p.Ile27Leu  0/1   64  40  40  22  18   45%   3.1919E-7  18   4
# 69783               None  0/1   64  40  40  22  18   45%   3.1919E-7  18   4
# 69784               None  0/1   64  40  40  22  18   45%   3.1919E-7  18   4
# 69785               None  0/1   64  40  40  22  18   45%   3.1919E-7  18   4
# ...                  ...  ...  ...  ..  ..  ..  ..   ...         ...  ..  ..
# 69860               None  1/1  206  36  36   0  36  100%  2.2598E-21   0   0
# 69861               None  1/1  206  36  36   0  36  100%  2.2598E-21   0   0
# 69862               None  1/1  206  36  36   0  36  100%  2.2598E-21   0   0
# 69863               None  1/1  206  36  36   0  36  100%  2.2598E-21   0   0
# 69864               None  1/1  206  36  36   0  36  100%  2.2598E-21   0   0
#
#       ADF ADR             SIFT                  PolyPhen      AF  AFR_AF  \
# 69781  11   7  tolerated(0.11)             benign(0.282)  0.2985  0.0832
# 69782  11   7  tolerated(0.11)  probably damaging(0.938)  0.2985  0.0832
# 69783  11   7                                             0.2985  0.0832
# 69784  11   7                                             0.2985  0.0832
# 69785  11   7                                             0.2985  0.0832
# ...    ..  ..              ...                       ...     ...     ...
# 69860  30   6                                             0.3596  0.1263
# 69861  30   6                                             0.3596  0.1263
# 69862  30   6                                             0.3596  0.1263
# 69863  30   6                                             0.3596  0.1263
# 69864  30   6                                             0.3596  0.1263
#
#        AMR_AF  EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF  \
# 69781    0.33  0.3889   0.339  0.4325     0.3549         0.1179
# 69782    0.33  0.3889   0.339  0.4325     0.3549         0.1179
# 69783    0.33  0.3889   0.339  0.4325     0.3549         0.1179
# 69784    0.33  0.3889   0.339  0.4325     0.3549         0.1179
# 69785    0.33  0.3889   0.339  0.4325     0.3549         0.1179
# ...       ...     ...     ...     ...        ...            ...
# 69860  0.3963  0.4802  0.3777  0.5061     0.3898         0.1331
# 69861  0.3963  0.4802  0.3777  0.5061     0.3898         0.1331
# 69862  0.3963  0.4802  0.3777  0.5061     0.3898         0.1331
# 69863  0.3963  0.4802  0.3777  0.5061     0.3898         0.1331
# 69864  0.3963  0.4802  0.3777  0.5061     0.3898         0.1331
#
#       gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF  \
# 69781         0.3666         0.4666         0.4147         0.3992
# 69782         0.3666         0.4666         0.4147         0.3992
# 69783         0.3666         0.4666         0.4147         0.3992
# 69784         0.3666         0.4666         0.4147         0.3992
# 69785         0.3666         0.4666         0.4147         0.3992
# ...              ...            ...            ...            ...
# 69860         0.3995         0.5007         0.4853         0.3716
# 69861         0.3995         0.5007         0.4853         0.3716
# 69862         0.3995         0.5007         0.4853         0.3716
# 69863         0.3995         0.5007         0.4853         0.3716
# 69864         0.3995         0.5007         0.4853         0.3716
#
#       gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF  \
# 69781         0.3365         0.3613         0.4268     0.2888         0.1248
# 69782         0.3365         0.3613         0.4268     0.2888         0.1248
# 69783         0.3365         0.3613         0.4268     0.2888         0.1248
# 69784         0.3365         0.3613         0.4268     0.2888         0.1248
# 69785         0.3365         0.3613         0.4268     0.2888         0.1248
# ...              ...            ...            ...        ...            ...
# 69860         0.3637         0.3934         0.5206     0.3176         0.1446
# 69861         0.3637         0.3934         0.5206     0.3176         0.1446
# 69862         0.3637         0.3934         0.5206     0.3176         0.1446
# 69863         0.3637         0.3934         0.5206     0.3176         0.1446
# 69864         0.3637         0.3934         0.5206     0.3176         0.1446
#
#       gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF  \
# 69781         0.3998         0.3444         0.4579         0.4113
# 69782         0.3998         0.3444         0.4579         0.4113
# 69783         0.3998         0.3444         0.4579         0.4113
# 69784         0.3998         0.3444         0.4579         0.4113
# 69785         0.3998         0.3444         0.4579         0.4113
# ...              ...            ...            ...            ...
# 69860         0.3786         0.3923         0.5026         0.4909
# 69861         0.3786         0.3923         0.5026         0.4909
# 69862         0.3786         0.3923         0.5026         0.4909
# 69863         0.3786         0.3923         0.5026         0.4909
# 69864         0.3786         0.3923         0.5026         0.4909
#
#       gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF gnomADg_OTH_AF  \
# 69781         0.4038         0.5222         0.3279         0.3109
# 69782         0.4038         0.5222         0.3279         0.3109
# 69783         0.4038         0.5222         0.3279         0.3109
# 69784         0.4038         0.5222         0.3279         0.3109
# 69785         0.4038         0.5222         0.3279         0.3109
# ...              ...            ...            ...            ...
# 69860         0.3844         0.5854         0.3557         0.3654
# 69861         0.3844         0.5854         0.3557         0.3654
# 69862         0.3844         0.5854         0.3557         0.3654
# 69863         0.3844         0.5854         0.3557         0.3654
# 69864         0.3844         0.5854         0.3557         0.3654
#
#       gnomADg_SAS_AF  MAX_AF  MAX_AF_POPS                  BIOTYPE  EXON  \
# 69781         0.4168  0.5222  gnomADg MID           protein coding  1/10
# 69782         0.4168  0.5222  gnomADg MID           protein coding   1/7
# 69783         0.4168  0.5222  gnomADg MID          retained intron   1/6
# 69784         0.4168  0.5222  gnomADg MID                   lncRNA
# 69785         0.4168  0.5222  gnomADg MID                   lncRNA
# ...              ...     ...          ...                      ...   ...
# 69860         0.5137  0.5854  gnomADg MID  nonsense mediated decay   6/6
# 69861         0.5137  0.5854  gnomADg MID          retained intron   2/2
# 69862         0.5137  0.5854  gnomADg MID           protein coding
# 69863         0.5137  0.5854  gnomADg MID  nonsense mediated decay   3/3
# 69864         0.5137  0.5854  gnomADg MID  nonsense mediated decay
#
#       INTRON Protein Position and Amino Acid   Codons STRAND  \
# 69781                                   I27L  Atc/Ctc      1
# 69782                                   I27L  Atc/Ctc      1
# 69783                                    nan               1
# 69784    1/3                             nan              -1
# 69785    1/1                             nan              -1
# ...      ...                             ...      ...    ...
# 69860                                    nan               1
# 69861                                    nan               1
# 69862    7/9                             nan               1
# 69863                                    nan               1
# 69864    7/9                             nan               1
#
#                                                   PUBMED Literature  \
# 69781  25741868,21094359,21647738,21931794,21937998,2...        Yes
# 69782  25741868,21094359,21647738,21931794,21937998,2...        Yes
# 69783  25741868,21094359,21647738,21931794,21937998,2...        Yes
# 69784  25741868,21094359,21647738,21931794,21937998,2...        Yes
# 69785  25741868,21094359,21647738,21931794,21937998,2...        Yes
# ...                                                  ...        ...
# 69860  25741868,24763700,24728327,18599530,18439552,1...        Yes
# 69861  25741868,24763700,24728327,18599530,18439552,1...        Yes
# 69862  25741868,24763700,24728327,18599530,18439552,1...        Yes
# 69863  25741868,24763700,24728327,18599530,18439552,1...        Yes
# 69864  25741868,24763700,24728327,18599530,18439552,1...        Yes
#
#       Covered/Not_Covered
# 69781             Covered
# 69782             Covered
# 69783             Covered
# 69784             Covered
# 69785             Covered
# ...                   ...
# 69860             Covered
# 69861             Covered
# 69862             Covered
# 69863             Covered
# 69864             Covered
#
# [72 rows x 71 columns]

# %%
merged_3 = merged_3[['Gene Name', 'Gene Match', 'rsID', 'CHROM', 'POS', 'Literature', 'REF', 'ALT', 'Zygosity',
       'Consequence','Consequence_score', 'IMPACT', 'IMPACT_score', 'ClinVar_CLNDN', 'CLIN_SIG',
       'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc', 'HGVSc (Transcript)', 'HGVSp',
       'HGVSp (Transcript)', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ',
       'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT', 'PolyPhen', 'AF', 'AFR_AF',
       'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF', 'gnomADe_AF', 'gnomADe_AFR_AF',
       'gnomADe_AMR_AF', 'gnomADe_ASJ_AF', 'gnomADe_EAS_AF', 'gnomADe_FIN_AF',
       'gnomADe_NFE_AF', 'gnomADe_OTH_AF', 'gnomADe_SAS_AF', 'gnomADg_AF',
       'gnomADg_AFR_AF', 'gnomADg_AMI_AF', 'gnomADg_AMR_AF', 'gnomADg_ASJ_AF',
       'gnomADg_EAS_AF', 'gnomADg_FIN_AF', 'gnomADg_MID_AF', 'gnomADg_NFE_AF',
       'gnomADg_OTH_AF', 'gnomADg_SAS_AF', 'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE',
       'EXON', 'INTRON', 'Protein Position and Amino Acid', 'Codons', 'STRAND',
       'PUBMED']]
merged_3
# Out:
#        Gene Name Gene Match          rsID CHROM        POS Literature REF ALT  \
# 0                        No  rs1416222198  chr1      65591         No   C   T
# 1                        No  rs1416222198  chr1      65591         No   C   T
# 2                        No  rs1416222198  chr1      65591         No   C   T
# 3          OR4F5         No  rs1260343719  chr1      69063         No   T   C
# 4          OR4F5         No  rs1260343719  chr1      69063         No   T   C
# ...          ...        ...           ...   ...        ...        ...  ..  ..
# 306164                   No             .  chrX  155459837         No   A   G
# 306165      IL9R         No     rs2073467  chrX  156005252         No   C   T
# 306166      IL9R         No     rs2073467  chrX  156005252         No   C   T
# 306167      IL9R         No     rs2073467  chrX  156005252         No   C   T
# 306168      IL9R         No     rs2073467  chrX  156005252         No   C   T
#
#             Zygosity              Consequence Consequence_score    IMPACT  \
# 0       Heterozygous  downstream gene variant              2/10  MODIFIER
# 1       Heterozygous           intron variant              2/10  MODIFIER
# 2       Heterozygous  downstream gene variant              2/10  MODIFIER
# 3       Heterozygous       synonymous variant              3/10       LOW
# 4       Heterozygous  downstream gene variant              2/10  MODIFIER
# ...              ...                      ...               ...       ...
# 306164  Heterozygous    upstream gene variant              2/10  MODIFIER
# 306165  Heterozygous           intron variant              2/10  MODIFIER
# 306166  Heterozygous           intron variant              2/10  MODIFIER
# 306167  Heterozygous  downstream gene variant              2/10  MODIFIER
# 306168  Heterozygous    upstream gene variant              2/10  MODIFIER
#
#         IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar  \
# 0                1.5
# 1                1.5
# 2                1.5
# 3                2.5
# 4                1.5
# ...              ...           ...      ...                ...     ...
# 306164           1.5
# 306165           1.5
# 306166           1.5
# 306167           1.5
# 306168           1.5
#
#                      HGVSc HGVSc (Transcript)              HGVSp  \
# 0                                        None
# 1        ENST00000641515.2          c.9+18C>T
# 2                                        None
# 3        ENST00000641515.2            c.36T>C  ENSP00000493376.2
# 4                                        None
# ...                    ...                ...                ...
# 306164                                   None
# 306165  ENST00000244174.11        c.580-26C>T
# 306166   ENST00000369423.7        c.685-26C>T
# 306167                                   None
# 306168                                   None
#
#        HGVSp (Transcript)   GT  GQ  SDP   DP  RD  AD    FREQ       PVAL RDF  \
# 0                    None  0/1  22   31   31  24   7  22.58%  5.3469E-3  17
# 1                    None  0/1  22   31   31  24   7  22.58%  5.3469E-3  17
# 2                    None  0/1  22   31   31  24   7  22.58%  5.3469E-3  17
# 3              p.Asn12%3D  0/1  67   45   45  26  19  42.22%  1.6979E-7  23
# 4                    None  0/1  67   45   45  26  19  42.22%  1.6979E-7  23
# ...                   ...  ...  ..  ...  ...  ..  ..     ...        ...  ..
# 306164               None  0/1  71  103  103  81  22  21.36%  6.7976E-8  54
# 306165               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
# 306166               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
# 306167               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
# 306168               None  0/1  31   12   12   4   8  66.67%  6.7304E-4   4
#
#        RDR ADF ADR SIFT PolyPhen AF AFR_AF AMR_AF EAS_AF EUR_AF SAS_AF  \
# 0        7   3   4
# 1        7   3   4
# 2        7   3   4
# 3        3  18   1
# 4        3  18   1
# ...     ..  ..  ..  ...      ... ..    ...    ...    ...    ...    ...
# 306164  27  14   8
# 306165   0   8   0
# 306166   0   8   0
# 306167   0   8   0
# 306168   0   8   0
#
#        gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF  \
# 0
# 1
# 2
# 3
# 4
# ...           ...            ...            ...            ...            ...
# 306164
# 306165    0.02802       0.001789         0.0527      9.934e-05         0.2012
# 306166    0.02802       0.001789         0.0527      9.934e-05         0.2012
# 306167    0.02802       0.001789         0.0527      9.934e-05         0.2012
# 306168    0.02802       0.001789         0.0527      9.934e-05         0.2012
#
#        gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF  \
# 0                                                                     0.03416
# 1                                                                     0.03416
# 2                                                                     0.03416
# 3                                                                     0.05175
# 4                                                                     0.05175
# ...               ...            ...            ...            ...        ...
# 306164
# 306165              0      0.0005125        0.01736        0.04299    0.01208
# 306166              0      0.0005125        0.01736        0.04299    0.01208
# 306167              0      0.0005125        0.01736        0.04299    0.01208
# 306168              0      0.0005125        0.01736        0.04299    0.01208
#
#        gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF  \
# 0             0.02306         0.1667        0.02711        0.03333
# 1             0.02306         0.1667        0.02711        0.03333
# 2             0.02306         0.1667        0.02711        0.03333
# 3             0.04058        0.02941        0.04766        0.04545
# 4             0.04058        0.02941        0.04766        0.04545
# ...               ...            ...            ...            ...
# 306164
# 306165       0.001739              0        0.02902       0.000288
# 306166       0.001739              0        0.02902       0.000288
# 306167       0.001739              0        0.02902       0.000288
# 306168       0.001739              0        0.02902       0.000288
#
#        gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0            0.001639              0           0.05        0.09167
# 1            0.001639              0           0.05        0.09167
# 2            0.001639              0           0.05        0.09167
# 3             0.06778         0.0303         0.1538        0.06103
# 4             0.06778         0.0303         0.1538        0.06103
# ...               ...            ...            ...            ...
# 306164
# 306165         0.2012              0              0      0.0003382
# 306166         0.2012              0              0      0.0003382
# 306167         0.2012              0              0      0.0003382
# 306168         0.2012              0              0      0.0003382
#
#        gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF              MAX_AF_POPS  \
# 0             0.05357        0.02083  0.1667              gnomADg AMI
# 1             0.05357        0.02083  0.1667              gnomADg AMI
# 2             0.05357        0.02083  0.1667              gnomADg AMI
# 3             0.05789         0.1089  0.1538              gnomADg MID
# 4             0.05789         0.1089  0.1538              gnomADg MID
# ...               ...            ...     ...                      ...
# 306164
# 306165         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306166         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306167         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
# 306168         0.0134        0.04662  0.2012  gnomADe EAS,gnomADg EAS
#
#                                    BIOTYPE EXON INTRON  \
# 0       transcribed unprocessed pseudogene
# 1                           protein coding         2/2
# 2                                   lncRNA
# 3                           protein coding  3/3
# 4                                   lncRNA
# ...                                    ...  ...    ...
# 306164                      protein coding
# 306165                      protein coding         5/8
# 306166                      protein coding         6/8
# 306167      protein coding CDS not defined
# 306168      protein coding CDS not defined
#
#        Protein Position and Amino Acid   Codons STRAND PUBMED
# 0                                  nan               1
# 1                                  nan               1
# 2                                  nan               1
# 3                                  N12  aaT/aaC      1
# 4                                  nan               1
# ...                                ...      ...    ...    ...
# 306164                             nan              -1
# 306165                             nan               1
# 306166                             nan               1
# 306167                             nan               1
# 306168                             nan               1
#
# [306169 rows x 70 columns]

# %%
merged_2.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Processed_vcf_files/Fatty_liver_data.xlsx', index=False)

# %%
merged_2['Gene Match'] = 'No'
merged_2['Matched_Gene'] = ''
    
# Iterate through each gene in vcf['Gene']
for index, genes in merged_2['Gene Name'].iteritems():
    if isinstance(genes, str):
        gene_list = genes.split(',')
        for gene in gene_list:
            if gene in df_gene['Gene Name'].values:
                merged_2.at[index, 'Gene Match'] = 'Yes'
                merged_2.at[index, 'Matched_Gene'] = gene
                break
    
df_gene = df_gene.rename({'Gene Name':'Matched_Gene', 'Gene_Match':'Gene Match'}, axis=1)

merged_2 = merged_2.drop(columns=['Gene Match'], axis=1)

merged_2 = pd.merge(merged_2, df_gene, on= 'Matched_Gene', how = 'left', sort = False)
#merged_2['Gene Match'] = merged_2['Gene Match'].fillna('No')
merged_2
# Out:
#        Gene Name         rsID CHROM       POS REF ALT      Zygosity  \
# 0          OR4F5    rs2691305  chr1     69511   A   G    Homozygous
# 1          OR4F5  rs200676709  chr1     69897   T   C  Heterozygous
# 2         OR4F29    rs2808347  chr1    450718   T   C  Heterozygous
# 3         OR4F29    rs2808347  chr1    450718   T   C  Heterozygous
# 4                           .  chr1    685694   T   C  Heterozygous
# ...          ...          ...   ...       ...  ..  ..           ...
# 336023    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 336024    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 336025    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 336026    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 336027             rs17250535  chrY  21311315   T   A    Homozygous
#
#                                          Consequence Consequence_score  \
# 0                                   missense variant              7/10
# 1                                 synonymous variant              3/10
# 2                            downstream gene variant              2/10
# 3       intron variant,non coding transcript variant              2/10
# 4                            downstream gene variant              2/10
# ...                                              ...               ...
# 336023                         upstream gene variant              2/10
# 336024                         upstream gene variant              2/10
# 336025                         upstream gene variant              2/10
# 336026                         upstream gene variant              2/10
# 336027            non coding transcript exon variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT  \
# 0       MODERATE           5.0
# 1            LOW           2.5
# 2       MODIFIER           1.5
# 3       MODIFIER           1.5
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...                ...
# 336023  MODIFIER           1.5
# 336024  MODIFIER           1.5
# 336025  MODIFIER           1.5
# 336026  MODIFIER           1.5
# 336027  MODIFIER           1.5
#
#        ClinVar              HGVSc HGVSc (Transcript)              HGVSp  \
# 0               ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 1               ENST00000641515.2           c.870T>C  ENSP00000493376.2
# 2                                               None
# 3               ENST00000455207.5     n.169+34322A>G
# 4                                               None
# ...        ...                ...                ...                ...
# 336023                                          None
# 336024                                          None
# 336025                                          None
# 336026                                          None
# 336027          ENST00000437359.1            n.48T>A
#
#        HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD    FREQ         PVAL  \
# 0             p.Thr162Ala  1/1  255  251  251    0  250   99.6%  8.5657E-150
# 1             p.Ser290%3D  0/1  171  179  179  128   51  28.49%   6.8954E-18
# 2                    None  0/1   30   26   26   17    9  34.62%    8.4928E-4
# 3                    None  0/1   30   26   26   17    9  34.62%    8.4928E-4
# 4                    None  0/1   30   25   25   16    9     36%    8.1542E-4
# ...                   ...  ...  ...  ...  ...  ...  ...     ...          ...
# 336023               None  1/1  188   33   33    0   33    100%   1.3852E-19
# 336024               None  1/1  188   33   33    0   33    100%   1.3852E-19
# 336025               None  1/1  188   33   33    0   33    100%   1.3852E-19
# 336026               None  1/1  188   33   33    0   33    100%   1.3852E-19
# 336027               None  1/1  135   24   24    0   24    100%    3.101E-14
#
#        RDF RDR  ADF ADR             SIFT   PolyPhen      AF  AFR_AF  AMR_AF  \
# 0        0   0  194  56  tolerated(0.92)  benign(0)
# 1       86  42   35  16                              0.6881   0.407  0.6254
# 2       17   0    9   0
# 3       17   0    9   0
# 4       16   0    9   0
# ...     ..  ..  ...  ..              ...        ...     ...     ...     ...
# 336023   0   0   24   9                              0.8273  0.9624  0.5824
# 336024   0   0   24   9                              0.8273  0.9624  0.5824
# 336025   0   0   24   9                              0.8273  0.9624  0.5824
# 336026   0   0   24   9                              0.8273  0.9624  0.5824
# 336027   0   0   19   5                              0.0681       0  0.0059
#
#         EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF  \
# 0                                  0.9497         0.6075         0.9514
# 1        0.876  0.7942  0.8098     0.7209          0.307         0.6749
# 2
# 3
# 4
# ...        ...     ...     ...        ...            ...            ...
# 336023  0.9959  0.4667  0.9962
# 336024  0.9959  0.4667  0.9962
# 336025  0.9959  0.4667  0.9962
# 336026  0.9959  0.4667  0.9962
# 336027       0    0.05  0.2731
#
#        gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF  \
# 0              0.9767         0.9994         0.9916         0.9726
# 1              0.8131         0.7793         0.8652         0.8438
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 336023
# 336024
# 336025
# 336026
# 336027
#
#        gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF  \
# 0              0.9506         0.9854      0.846         0.5948          0.998
# 1              0.7932         0.8049     0.4864         0.2916         0.6511
# 2
# 3
# 4
# ...               ...            ...        ...            ...            ...
# 336023                                   0.6593         0.8119         0.2864
# 336024                                   0.6593         0.8119         0.2864
# 336025                                   0.6593         0.8119         0.2864
# 336026                                   0.6593         0.8119         0.2864
# 336027
#
#        gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF  \
# 0              0.8951         0.9784         0.9998         0.9907
# 1              0.4782         0.6714         0.6047         0.6987
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 336023         0.5121         0.9004         0.9992         0.9714
# 336024         0.5121         0.9004         0.9992         0.9714
# 336025         0.5121         0.9004         0.9992         0.9714
# 336026         0.5121         0.9004         0.9992         0.9714
# 336027
#
#        gnomADg_MID_AF gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  \
# 0                 0.9         0.9674         0.8624         0.9772  0.9998
# 1              0.6441         0.6751         0.4659          0.622   0.876
# 2
# 3
# 4
# ...               ...            ...            ...            ...     ...
# 336023         0.9865         0.4599         0.6294         0.9906  0.9992
# 336024         0.9865         0.4599         0.6294         0.9906  0.9992
# 336025         0.9865         0.4599         0.6294         0.9906  0.9992
# 336026         0.9865         0.4599         0.6294         0.9906  0.9992
# 336027                                                              0.2731
#
#         MAX_AF_POPS                 BIOTYPE EXON INTRON  \
# 0       gnomADg EAS          protein coding  3/3
# 1               EAS          protein coding  3/3
# 2                            protein coding
# 3                                    lncRNA         1/2
# 4                            protein coding
# ...             ...                     ...  ...    ...
# 336023  gnomADg EAS                  lncRNA
# 336024  gnomADg EAS                  lncRNA
# 336025  gnomADg EAS                  lncRNA
# 336026  gnomADg EAS                  lncRNA
# 336027          SAS  unprocessed pseudogene  1/9
#
#        Protein Position and Amino Acid   Codons STRAND  \
# 0                                T162A  Aca/Gca      1
# 1                                 S290  tcT/tcC      1
# 2                                  nan              -1
# 3                                  nan              -1
# 4                                  nan              -1
# ...                                ...      ...    ...
# 336023                             nan              -1
# 336024                             nan              -1
# 336025                             nan              -1
# 336026                             nan              -1
# 336027                             nan               1
#
#                                                    PUBMED Matched_Gene
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...          ...
# 336023  22271044,29391530,24262073,15896936,32996047,3...
# 336024  22271044,29391530,24262073,15896936,32996047,3...
# 336025  22271044,29391530,24262073,15896936,32996047,3...
# 336026  22271044,29391530,24262073,15896936,32996047,3...
# 336027                                  34424929,35176104
#
# [336028 rows x 69 columns]

# %%
merged_2.Matched_Gene.value_counts()
# Out:
#            333579
# PMS2          446
# BRCA1         421
# NBN           302
# TP53          211
# SMARCA4       180
# NF1           162
# BARD1         133
# ATM           116
# MUTYH          96
# BRCA2          74
# BRIP1          72
# RECQL          38
# PTEN           30
# RAD50          26
# RAD51D         24
# PALB2          22
# MSH2           21
# MSH6           18
# CDKN2A         17
# SLX4           14
# STK11          10
# CDH1           10
# MRE11           6
# Name: Matched_Gene, dtype: int64

# %%
df_3 = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Hereditary_Cancer_risk_Oncokb.xlsx')
df_3
# Out:
#      Matched_Gene Protein Position and Amino Acid         Oncogenic  \
# 0             ATM                        Deletion  Likely Oncogenic
# 1             ATM            Truncating Mutations  Likely Oncogenic
# 2             ATM                          A1742P  Likely Oncogenic
# 3             ATM                          A2062V  Likely Oncogenic
# 4             ATM                          A2067D  Likely Oncogenic
# ...           ...                             ...               ...
# 1650         TP53                           A347T  Likely Oncogenic
# 1651         TP53                           L348F  Likely Oncogenic
# 1652         TP53                           L348S  Likely Oncogenic
# 1653         TP53                           G356A      Inconclusive
# 1654         TP53                           G360V    Likely Neutral
#
#               Mutation effect
# 0     Likely Loss-of-function
# 1     Likely Loss-of-function
# 2     Likely Loss-of-function
# 3     Likely Loss-of-function
# 4     Likely Loss-of-function
# ...                       ...
# 1650  Likely Loss-of-function
# 1651  Likely Loss-of-function
# 1652  Likely Loss-of-function
# 1653             Inconclusive
# 1654             Inconclusive
#
# [1655 rows x 4 columns]

# %%
merged_3 = pd.merge(merged_2, df_3, on=['Matched_Gene', 'Protein Position and Amino Acid'], how='left', sort=False)
merged_3
# Out:
#        Gene Name         rsID CHROM       POS REF ALT      Zygosity  \
# 0          OR4F5    rs2691305  chr1     69511   A   G    Homozygous
# 1          OR4F5  rs200676709  chr1     69897   T   C  Heterozygous
# 2         OR4F29    rs2808347  chr1    450718   T   C  Heterozygous
# 3         OR4F29    rs2808347  chr1    450718   T   C  Heterozygous
# 4                           .  chr1    685694   T   C  Heterozygous
# ...          ...          ...   ...       ...  ..  ..           ...
# 336023    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 336024    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 336025    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 336026    EIF1AY    rs9786153  chrY  20577481   C   T    Homozygous
# 336027             rs17250535  chrY  21311315   T   A    Homozygous
#
#                                          Consequence Consequence_score  \
# 0                                   missense variant              7/10
# 1                                 synonymous variant              3/10
# 2                            downstream gene variant              2/10
# 3       intron variant,non coding transcript variant              2/10
# 4                            downstream gene variant              2/10
# ...                                              ...               ...
# 336023                         upstream gene variant              2/10
# 336024                         upstream gene variant              2/10
# 336025                         upstream gene variant              2/10
# 336026                         upstream gene variant              2/10
# 336027            non coding transcript exon variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT  \
# 0       MODERATE           5.0
# 1            LOW           2.5
# 2       MODIFIER           1.5
# 3       MODIFIER           1.5
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...                ...
# 336023  MODIFIER           1.5
# 336024  MODIFIER           1.5
# 336025  MODIFIER           1.5
# 336026  MODIFIER           1.5
# 336027  MODIFIER           1.5
#
#        ClinVar              HGVSc HGVSc (Transcript)              HGVSp  \
# 0               ENST00000641515.2           c.484A>G  ENSP00000493376.2
# 1               ENST00000641515.2           c.870T>C  ENSP00000493376.2
# 2                                               None
# 3               ENST00000455207.5     n.169+34322A>G
# 4                                               None
# ...        ...                ...                ...                ...
# 336023                                          None
# 336024                                          None
# 336025                                          None
# 336026                                          None
# 336027          ENST00000437359.1            n.48T>A
#
#        HGVSp (Transcript)   GT   GQ  SDP   DP   RD   AD    FREQ         PVAL  \
# 0             p.Thr162Ala  1/1  255  251  251    0  250   99.6%  8.5657E-150
# 1             p.Ser290%3D  0/1  171  179  179  128   51  28.49%   6.8954E-18
# 2                    None  0/1   30   26   26   17    9  34.62%    8.4928E-4
# 3                    None  0/1   30   26   26   17    9  34.62%    8.4928E-4
# 4                    None  0/1   30   25   25   16    9     36%    8.1542E-4
# ...                   ...  ...  ...  ...  ...  ...  ...     ...          ...
# 336023               None  1/1  188   33   33    0   33    100%   1.3852E-19
# 336024               None  1/1  188   33   33    0   33    100%   1.3852E-19
# 336025               None  1/1  188   33   33    0   33    100%   1.3852E-19
# 336026               None  1/1  188   33   33    0   33    100%   1.3852E-19
# 336027               None  1/1  135   24   24    0   24    100%    3.101E-14
#
#        RDF RDR  ADF ADR             SIFT   PolyPhen      AF  AFR_AF  AMR_AF  \
# 0        0   0  194  56  tolerated(0.92)  benign(0)
# 1       86  42   35  16                              0.6881   0.407  0.6254
# 2       17   0    9   0
# 3       17   0    9   0
# 4       16   0    9   0
# ...     ..  ..  ...  ..              ...        ...     ...     ...     ...
# 336023   0   0   24   9                              0.8273  0.9624  0.5824
# 336024   0   0   24   9                              0.8273  0.9624  0.5824
# 336025   0   0   24   9                              0.8273  0.9624  0.5824
# 336026   0   0   24   9                              0.8273  0.9624  0.5824
# 336027   0   0   19   5                              0.0681       0  0.0059
#
#         EAS_AF  EUR_AF  SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF  \
# 0                                  0.9497         0.6075         0.9514
# 1        0.876  0.7942  0.8098     0.7209          0.307         0.6749
# 2
# 3
# 4
# ...        ...     ...     ...        ...            ...            ...
# 336023  0.9959  0.4667  0.9962
# 336024  0.9959  0.4667  0.9962
# 336025  0.9959  0.4667  0.9962
# 336026  0.9959  0.4667  0.9962
# 336027       0    0.05  0.2731
#
#        gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_NFE_AF  \
# 0              0.9767         0.9994         0.9916         0.9726
# 1              0.8131         0.7793         0.8652         0.8438
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 336023
# 336024
# 336025
# 336026
# 336027
#
#        gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF  \
# 0              0.9506         0.9854      0.846         0.5948          0.998
# 1              0.7932         0.8049     0.4864         0.2916         0.6511
# 2
# 3
# 4
# ...               ...            ...        ...            ...            ...
# 336023                                   0.6593         0.8119         0.2864
# 336024                                   0.6593         0.8119         0.2864
# 336025                                   0.6593         0.8119         0.2864
# 336026                                   0.6593         0.8119         0.2864
# 336027
#
#        gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF  \
# 0              0.8951         0.9784         0.9998         0.9907
# 1              0.4782         0.6714         0.6047         0.6987
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 336023         0.5121         0.9004         0.9992         0.9714
# 336024         0.5121         0.9004         0.9992         0.9714
# 336025         0.5121         0.9004         0.9992         0.9714
# 336026         0.5121         0.9004         0.9992         0.9714
# 336027
#
#        gnomADg_MID_AF gnomADg_NFE_AF gnomADg_OTH_AF gnomADg_SAS_AF  MAX_AF  \
# 0                 0.9         0.9674         0.8624         0.9772  0.9998
# 1              0.6441         0.6751         0.4659          0.622   0.876
# 2
# 3
# 4
# ...               ...            ...            ...            ...     ...
# 336023         0.9865         0.4599         0.6294         0.9906  0.9992
# 336024         0.9865         0.4599         0.6294         0.9906  0.9992
# 336025         0.9865         0.4599         0.6294         0.9906  0.9992
# 336026         0.9865         0.4599         0.6294         0.9906  0.9992
# 336027                                                              0.2731
#
#         MAX_AF_POPS                 BIOTYPE EXON INTRON  \
# 0       gnomADg EAS          protein coding  3/3
# 1               EAS          protein coding  3/3
# 2                            protein coding
# 3                                    lncRNA         1/2
# 4                            protein coding
# ...             ...                     ...  ...    ...
# 336023  gnomADg EAS                  lncRNA
# 336024  gnomADg EAS                  lncRNA
# 336025  gnomADg EAS                  lncRNA
# 336026  gnomADg EAS                  lncRNA
# 336027          SAS  unprocessed pseudogene  1/9
#
#        Protein Position and Amino Acid   Codons STRAND  \
# 0                                T162A  Aca/Gca      1
# 1                                 S290  tcT/tcC      1
# 2                                  nan              -1
# 3                                  nan              -1
# 4                                  nan              -1
# ...                                ...      ...    ...
# 336023                             nan              -1
# 336024                             nan              -1
# 336025                             nan              -1
# 336026                             nan              -1
# 336027                             nan               1
#
#                                                    PUBMED Matched_Gene  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...          ...
# 336023  22271044,29391530,24262073,15896936,32996047,3...
# 336024  22271044,29391530,24262073,15896936,32996047,3...
# 336025  22271044,29391530,24262073,15896936,32996047,3...
# 336026  22271044,29391530,24262073,15896936,32996047,3...
# 336027                                  34424929,35176104
#
#        Oncogenic Mutation effect
# 0            NaN             NaN
# 1            NaN             NaN
# 2            NaN             NaN
# 3            NaN             NaN
# 4            NaN             NaN
# ...          ...             ...
# 336023       NaN             NaN
# 336024       NaN             NaN
# 336025       NaN             NaN
# 336026       NaN             NaN
# 336027       NaN             NaN
#
# [336028 rows x 71 columns]

# %%
merged_3.Oncogenic.value_counts()
# Out:
# Likely Neutral    21
# Inconclusive      11
# Name: Oncogenic, dtype: int64

# %%
merged_3['Mutation effect'].value_counts()
# Out:
# Likely- Neutral    12
# Inconclusive       11
# Likely Neutral      9
# Name: Mutation effect, dtype: int64

# %%
merged_3.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Processed_vcf_files/KHHSPTGPTTL60_depth_vcf_processed.xlsx', index=False)

# %%
merged_2['Gene_Match'] = 'No'

# Iterate through each gene in df1
for genes in merged_2['Gene Name']:
    if isinstance(genes, str):  # Check if the gene value is a non-null string
        gene_list = genes.split(',')  # Split the genes by comma to create a list
        match = any(gene in df_gene['Gene Name'].values for gene in gene_list)  # Check if any gene in the list exists in df2
        if match:
            merged_2.loc[merged_2['Gene Name'] == genes, 'Gene_Match'] = 'Yes'
            
merged_2
# Out:
#        Gene Name          rsID CHROM       POS REF ALT      Zygosity  \
# 0                 rs1416222198  chr1     65591   C   T  Heterozygous
# 1                 rs1416222198  chr1     65591   C   T  Heterozygous
# 2                 rs1416222198  chr1     65591   C   T  Heterozygous
# 3                 rs1166163776  chr1     65649   G   A  Heterozygous
# 4                 rs1166163776  chr1     65649   G   A  Heterozygous
# ...          ...           ...   ...       ...  ..  ..           ...
# 297877    EIF1AY     rs9786153  chrY  20577481   C   T    Homozygous
# 297878              rs17250535  chrY  21311315   T   A    Homozygous
# 297879      DAZ3  rs1156813394  chrY  24796170   C   G    Homozygous
# 297880      DAZ3  rs1156813394  chrY  24796170   C   G    Homozygous
# 297881      DAZ3  rs1156813394  chrY  24796170   C   G    Homozygous
#
#                                Consequence Consequence_score    IMPACT  \
# 0                  downstream gene variant              2/10  MODIFIER
# 1                           intron variant              2/10  MODIFIER
# 2                  downstream gene variant              2/10  MODIFIER
# 3                  downstream gene variant              2/10  MODIFIER
# 4                           intron variant              2/10  MODIFIER
# ...                                    ...               ...       ...
# 297877               upstream gene variant              2/10  MODIFIER
# 297878  non coding transcript exon variant              2/10  MODIFIER
# 297879                      intron variant              2/10  MODIFIER
# 297880                      intron variant              2/10  MODIFIER
# 297881                      intron variant              2/10  MODIFIER
#
#         IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT ClinVar  \
# 0                1.5
# 1                1.5
# 2                1.5
# 3                1.5
# 4                1.5
# ...              ...           ...      ...                ...     ...
# 297877           1.5
# 297878           1.5
# 297879           1.5
# 297880           1.5
# 297881           1.5
#
#                     HGVSc HGVSc (Transcript) HGVSp HGVSp (Transcript)   GT  \
# 0                                       None                     None  0/1
# 1       ENST00000641515.2          c.9+18C>T                     None  0/1
# 2                                       None                     None  0/1
# 3                                       None                     None  0/1
# 4       ENST00000641515.2          c.9+76G>A                     None  0/1
# ...                   ...                ...   ...                ...  ...
# 297877                                  None                     None  1/1
# 297878  ENST00000437359.1            n.48T>A                     None  1/1
# 297879  ENST00000315357.9      c.714+2253G>C                     None  1/1
# 297880  ENST00000382365.7        c.715-72G>C                     None  1/1
# 297881  ENST00000446723.4        c.715-72G>C                     None  1/1
#
#         GQ SDP  DP  RD  AD    FREQ       PVAL RDF RDR ADF ADR SIFT PolyPhen  \
# 0       23  26  26  19   7  26.92%  4.9169E-3  10   9   4   3
# 1       23  26  26  19   7  26.92%  4.9169E-3  10   9   4   3
# 2       23  26  26  19   7  26.92%  4.9169E-3  10   9   4   3
# 3       20  19  19  13   6  31.58%   9.828E-3   1  12   2   4
# 4       20  19  19  13   6  31.58%   9.828E-3   1  12   2   4
# ...     ..  ..  ..  ..  ..     ...        ...  ..  ..  ..  ..  ...      ...
# 297877  52  10  10   0  10    100%  5.4125E-6   0   0   3   7
# 297878  64  12  12   0  12    100%   3.698E-7   0   0   6   6
# 297879  74  22  22   5  17  77.27%  3.8368E-8   1   4  11   6
# 297880  74  22  22   5  17  77.27%  3.8368E-8   1   4  11   6
# 297881  74  22  22   5  17  77.27%  3.8368E-8   1   4  11   6
#
#             AF  AFR_AF  AMR_AF  EAS_AF  EUR_AF  SAS_AF gnomADe_AF  \
# 0
# 1
# 2
# 3
# 4
# ...        ...     ...     ...     ...     ...     ...        ...
# 297877  0.8273  0.9624  0.5824  0.9959  0.4667  0.9962
# 297878  0.0681       0  0.0059       0    0.05  0.2731
# 297879
# 297880
# 297881
#
#        gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF  \
# 0
# 1
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 297877
# 297878
# 297879
# 297880
# 297881
#
#        gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF  \
# 0                                                                     0.03416
# 1                                                                     0.03416
# 2                                                                     0.03416
# 3                                                                     0.03432
# 4                                                                     0.03432
# ...               ...            ...            ...            ...        ...
# 297877                                                                 0.6593
# 297878
# 297879                                                                      0
# 297880                                                                      0
# 297881                                                                      0
#
#        gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF  \
# 0             0.02306         0.1667        0.02711        0.03333
# 1             0.02306         0.1667        0.02711        0.03333
# 2             0.02306         0.1667        0.02711        0.03333
# 3             0.01435        0.05263        0.03176        0.09639
# 4             0.01435        0.05263        0.03176        0.09639
# ...               ...            ...            ...            ...
# 297877         0.8119         0.2864         0.5121         0.9004
# 297878
# 297879              0              0              0              0
# 297880              0              0              0              0
# 297881              0              0              0              0
#
#        gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0            0.001639              0           0.05        0.09167
# 1            0.001639              0           0.05        0.09167
# 2            0.001639              0           0.05        0.09167
# 3            0.001832         0.0122        0.07895        0.09393
# 4            0.001832         0.0122        0.07895        0.09393
# ...               ...            ...            ...            ...
# 297877         0.9992         0.9714         0.9865         0.4599
# 297878
# 297879              0              0              0              0
# 297880              0              0              0              0
# 297881              0              0              0              0
#
#        gnomADg_OTH_AF gnomADg_SAS_AF   MAX_AF  \
# 0             0.05357        0.02083   0.1667
# 1             0.05357        0.02083   0.1667
# 2             0.05357        0.02083   0.1667
# 3             0.02439        0.03321  0.09639
# 4             0.02439        0.03321  0.09639
# ...               ...            ...      ...
# 297877         0.6294         0.9906   0.9992
# 297878                                 0.2731
# 297879              0              0        0
# 297880              0              0        0
# 297881              0              0        0
#
#                                               MAX_AF_POPS  \
# 0                                             gnomADg AMI
# 1                                             gnomADg AMI
# 2                                             gnomADg AMI
# 3                                             gnomADg ASJ
# 4                                             gnomADg ASJ
# ...                                                   ...
# 297877                                        gnomADg EAS
# 297878                                                SAS
# 297879  gnomADg AFR,gnomADg AMI,gnomADg AMR,gnomADg AS...
# 297880  gnomADg AFR,gnomADg AMI,gnomADg AMR,gnomADg AS...
# 297881  gnomADg AFR,gnomADg AMI,gnomADg AMR,gnomADg AS...
#
#                                    BIOTYPE EXON INTRON  \
# 0       transcribed unprocessed pseudogene
# 1                           protein coding         2/2
# 2                                   lncRNA
# 3       transcribed unprocessed pseudogene
# 4                           protein coding         2/2
# ...                                    ...  ...    ...
# 297877                              lncRNA
# 297878              unprocessed pseudogene  1/9
# 297879                      protein coding        9/15
# 297880                      protein coding        9/18
# 297881                      protein coding        9/16
#
#        Protein Position and Amino Acid Codons STRAND  \
# 0                                  nan             1
# 1                                  nan             1
# 2                                  nan             1
# 3                                  nan             1
# 4                                  nan             1
# ...                                ...    ...    ...
# 297877                             nan            -1
# 297878                             nan             1
# 297879                             nan            -1
# 297880                             nan            -1
# 297881                             nan            -1
#
#                                                    PUBMED Gene_Match
# 0                                                                 No
# 1                                                                 No
# 2                                                                 No
# 3                                                                 No
# 4                                                                 No
# ...                                                   ...        ...
# 297877  22271044,29391530,24262073,15896936,32996047,3...         No
# 297878                                  34424929,35176104         No
# 297879                                                            No
# 297880                                                            No
# 297881                                                            No
#
# [297882 rows x 69 columns]

# %%
merged_2['Gene_Match'].value_counts()
# Out:
# No     296225
# Yes      1657
# Name: Gene_Match, dtype: int64

# %%
merged_2 = merged_2[['Gene Name', 'Gene_Match', 'rsID', 'CHROM', 'POS', 'REF', 'ALT', 'Zygosity',
       'Consequence', 'Consequence_score', 'IMPACT', 'IMPACT_score',
       'ClinVar_CLNDN', 'CLIN_SIG', 'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc',
       'HGVSc (Transcript)', 'HGVSp', 'HGVSp (Transcript)', 'GT', 'GQ', 'SDP',
       'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT',
       'PolyPhen', 'AF', 'AFR_AF',
       'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF', 'gnomADe_AF', 'gnomADe_AFR_AF',
       'gnomADe_AMR_AF', 'gnomADe_ASJ_AF', 'gnomADe_EAS_AF', 'gnomADe_FIN_AF',
       'gnomADe_NFE_AF', 'gnomADe_OTH_AF', 'gnomADe_SAS_AF', 'gnomADg_AF',
       'gnomADg_AFR_AF', 'gnomADg_AMI_AF', 'gnomADg_AMR_AF', 'gnomADg_ASJ_AF',
       'gnomADg_EAS_AF', 'gnomADg_FIN_AF', 'gnomADg_MID_AF', 'gnomADg_NFE_AF',
       'gnomADg_OTH_AF', 'gnomADg_SAS_AF', 'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE', 'EXON', 'INTRON',
       'Protein Position and Amino Acid', 'Codons', 'STRAND', 'PUBMED']]
merged_2['POS'] = merged_2['POS'].astype('int64')
merged_2
# Out:
#        Gene Name Gene_Match          rsID CHROM       POS REF ALT  \
# 0                        No  rs1416222198  chr1     65591   C   T
# 1                        No  rs1416222198  chr1     65591   C   T
# 2                        No  rs1416222198  chr1     65591   C   T
# 3                        No  rs1166163776  chr1     65649   G   A
# 4                        No  rs1166163776  chr1     65649   G   A
# ...          ...        ...           ...   ...       ...  ..  ..
# 297877    EIF1AY         No     rs9786153  chrY  20577481   C   T
# 297878                   No    rs17250535  chrY  21311315   T   A
# 297879      DAZ3         No  rs1156813394  chrY  24796170   C   G
# 297880      DAZ3         No  rs1156813394  chrY  24796170   C   G
# 297881      DAZ3         No  rs1156813394  chrY  24796170   C   G
#
#             Zygosity                         Consequence Consequence_score  \
# 0       Heterozygous             downstream gene variant              2/10
# 1       Heterozygous                      intron variant              2/10
# 2       Heterozygous             downstream gene variant              2/10
# 3       Heterozygous             downstream gene variant              2/10
# 4       Heterozygous                      intron variant              2/10
# ...              ...                                 ...               ...
# 297877    Homozygous               upstream gene variant              2/10
# 297878    Homozygous  non coding transcript exon variant              2/10
# 297879    Homozygous                      intron variant              2/10
# 297880    Homozygous                      intron variant              2/10
# 297881    Homozygous                      intron variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT  \
# 0       MODIFIER           1.5
# 1       MODIFIER           1.5
# 2       MODIFIER           1.5
# 3       MODIFIER           1.5
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...                ...
# 297877  MODIFIER           1.5
# 297878  MODIFIER           1.5
# 297879  MODIFIER           1.5
# 297880  MODIFIER           1.5
# 297881  MODIFIER           1.5
#
#        ClinVar              HGVSc HGVSc (Transcript) HGVSp HGVSp (Transcript)  \
# 0                                               None                     None
# 1               ENST00000641515.2          c.9+18C>T                     None
# 2                                               None                     None
# 3                                               None                     None
# 4               ENST00000641515.2          c.9+76G>A                     None
# ...        ...                ...                ...   ...                ...
# 297877                                          None                     None
# 297878          ENST00000437359.1            n.48T>A                     None
# 297879          ENST00000315357.9      c.714+2253G>C                     None
# 297880          ENST00000382365.7        c.715-72G>C                     None
# 297881          ENST00000446723.4        c.715-72G>C                     None
#
#          GT  GQ SDP  DP  RD  AD    FREQ       PVAL RDF RDR ADF ADR SIFT  \
# 0       0/1  23  26  26  19   7  26.92%  4.9169E-3  10   9   4   3
# 1       0/1  23  26  26  19   7  26.92%  4.9169E-3  10   9   4   3
# 2       0/1  23  26  26  19   7  26.92%  4.9169E-3  10   9   4   3
# 3       0/1  20  19  19  13   6  31.58%   9.828E-3   1  12   2   4
# 4       0/1  20  19  19  13   6  31.58%   9.828E-3   1  12   2   4
# ...     ...  ..  ..  ..  ..  ..     ...        ...  ..  ..  ..  ..  ...
# 297877  1/1  52  10  10   0  10    100%  5.4125E-6   0   0   3   7
# 297878  1/1  64  12  12   0  12    100%   3.698E-7   0   0   6   6
# 297879  1/1  74  22  22   5  17  77.27%  3.8368E-8   1   4  11   6
# 297880  1/1  74  22  22   5  17  77.27%  3.8368E-8   1   4  11   6
# 297881  1/1  74  22  22   5  17  77.27%  3.8368E-8   1   4  11   6
#
#        PolyPhen      AF  AFR_AF  AMR_AF  EAS_AF  EUR_AF  SAS_AF gnomADe_AF  \
# 0
# 1
# 2
# 3
# 4
# ...         ...     ...     ...     ...     ...     ...     ...        ...
# 297877           0.8273  0.9624  0.5824  0.9959  0.4667  0.9962
# 297878           0.0681       0  0.0059       0    0.05  0.2731
# 297879
# 297880
# 297881
#
#        gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF  \
# 0
# 1
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 297877
# 297878
# 297879
# 297880
# 297881
#
#        gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF  \
# 0                                                                     0.03416
# 1                                                                     0.03416
# 2                                                                     0.03416
# 3                                                                     0.03432
# 4                                                                     0.03432
# ...               ...            ...            ...            ...        ...
# 297877                                                                 0.6593
# 297878
# 297879                                                                      0
# 297880                                                                      0
# 297881                                                                      0
#
#        gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF  \
# 0             0.02306         0.1667        0.02711        0.03333
# 1             0.02306         0.1667        0.02711        0.03333
# 2             0.02306         0.1667        0.02711        0.03333
# 3             0.01435        0.05263        0.03176        0.09639
# 4             0.01435        0.05263        0.03176        0.09639
# ...               ...            ...            ...            ...
# 297877         0.8119         0.2864         0.5121         0.9004
# 297878
# 297879              0              0              0              0
# 297880              0              0              0              0
# 297881              0              0              0              0
#
#        gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0            0.001639              0           0.05        0.09167
# 1            0.001639              0           0.05        0.09167
# 2            0.001639              0           0.05        0.09167
# 3            0.001832         0.0122        0.07895        0.09393
# 4            0.001832         0.0122        0.07895        0.09393
# ...               ...            ...            ...            ...
# 297877         0.9992         0.9714         0.9865         0.4599
# 297878
# 297879              0              0              0              0
# 297880              0              0              0              0
# 297881              0              0              0              0
#
#        gnomADg_OTH_AF gnomADg_SAS_AF   MAX_AF  \
# 0             0.05357        0.02083   0.1667
# 1             0.05357        0.02083   0.1667
# 2             0.05357        0.02083   0.1667
# 3             0.02439        0.03321  0.09639
# 4             0.02439        0.03321  0.09639
# ...               ...            ...      ...
# 297877         0.6294         0.9906   0.9992
# 297878                                 0.2731
# 297879              0              0        0
# 297880              0              0        0
# 297881              0              0        0
#
#                                               MAX_AF_POPS  \
# 0                                             gnomADg AMI
# 1                                             gnomADg AMI
# 2                                             gnomADg AMI
# 3                                             gnomADg ASJ
# 4                                             gnomADg ASJ
# ...                                                   ...
# 297877                                        gnomADg EAS
# 297878                                                SAS
# 297879  gnomADg AFR,gnomADg AMI,gnomADg AMR,gnomADg AS...
# 297880  gnomADg AFR,gnomADg AMI,gnomADg AMR,gnomADg AS...
# 297881  gnomADg AFR,gnomADg AMI,gnomADg AMR,gnomADg AS...
#
#                                    BIOTYPE EXON INTRON  \
# 0       transcribed unprocessed pseudogene
# 1                           protein coding         2/2
# 2                                   lncRNA
# 3       transcribed unprocessed pseudogene
# 4                           protein coding         2/2
# ...                                    ...  ...    ...
# 297877                              lncRNA
# 297878              unprocessed pseudogene  1/9
# 297879                      protein coding        9/15
# 297880                      protein coding        9/18
# 297881                      protein coding        9/16
#
#        Protein Position and Amino Acid Codons STRAND  \
# 0                                  nan             1
# 1                                  nan             1
# 2                                  nan             1
# 3                                  nan             1
# 4                                  nan             1
# ...                                ...    ...    ...
# 297877                             nan            -1
# 297878                             nan             1
# 297879                             nan            -1
# 297880                             nan            -1
# 297881                             nan            -1
#
#                                                    PUBMED
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 297877  22271044,29391530,24262073,15896936,32996047,3...
# 297878                                  34424929,35176104
# 297879
# 297880
# 297881
#
# [297882 rows x 69 columns]

# %%
import pandas as pd
x = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Reproductivehealth_Male_Lit_final_Positions_hg38_hg37.xlsx')
x['chrom'] = x['Chrom-pos-Ref-Alt_38'].str.split(',')
x = x.explode('chrom')

x['CHROM'] = x['chrom'].str.split('-').str[0]

# Function to add 'chr' prefix conditionally
def add_chr_prefix(chrom):
    if pd.notnull(chrom) and chrom.strip() != '':
        return 'chr' + str(chrom)
    else:
        return chrom

# Applying the function to the 'chromosome' column
x['CHROM'] = x['CHROM'].apply(add_chr_prefix)
x['CHROM'] = x['CHROM'].str.strip()
x['CHROM'] = x['CHROM'].str.replace(r'\s+', '')
x['POS'] = x['chrom'].str.split('-').str[1]

x.dropna(subset=['CHROM'], inplace=True)
# Drop rows with empty cells after removing leading and trailing whitespaces
x['CHROM'] = x['CHROM'].str.strip()
x['POS'] = x['POS'].str.strip()
# Dropping rows with empty cells and NaN values in both 'chromosome' and 'position' columns
x.dropna(subset=['CHROM', 'POS'], inplace=True)
df_3 = x[['CHROM', 'POS']]
df_3['Literature'] = 'Yes'
df_3.drop_duplicates(subset='POS', inplace=True)
df_3['POS'] = df_3['POS'].astype('int64')
df_3 = df_3.reset_index()
df_3 = df_3[['CHROM', 'POS', 'Literature']]

df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/KAPA HyperExome_hg38_capture_targets (1).bed', sep = '\t', header = None)
df.columns = ['chromosome', 'Start_pos', 'End_pos', 'INFO']

df['Extended_Start_pos'] = df['Start_pos'] - 20
df['Extended_End_pos'] = df['End_pos'] + 20

df['gene_symbol'] = df['INFO'].str.extract(r'gene_symbol=([^;]+)')
df = df[['chromosome', 'Extended_Start_pos', 'Extended_End_pos', 'INFO', 'gene_symbol']]


# Step 1: Create a dictionary from the df DataFrame
chromosome_dict = {}
for _, row in df.iterrows():
    chromosome = row['chromosome']
    start_pos = row['Extended_Start_pos']
    end_pos = row['Extended_End_pos']
    if chromosome not in chromosome_dict:
        chromosome_dict[chromosome] = []
    chromosome_dict[chromosome].append((start_pos, end_pos))

# Step 2: Define a function to check coverage
def check_coverage(row):
    pos = row['POS']
    chromosome = row['CHROM']
    if chromosome in chromosome_dict:
        ranges = chromosome_dict[chromosome]
        for start, end in ranges:
            if start <= pos <= end:
                return 'Covered'
    return 'Not_Covered'

# Step 3: Apply the function to create the new column in dataset2
df_3['Covered/Not_Covered'] = df_3.apply(check_coverage, axis=1)

df_3 = df_3[df_3['Covered/Not_Covered'] == 'Covered']
df_3
# Out:
#      CHROM        POS Literature Covered/Not_Covered
# 0    chr12  101728759        Yes             Covered
# 1    chr12  101729212        Yes             Covered
# 3    chr12  101728656        Yes             Covered
# 4    chr12  101729109        Yes             Covered
# 6    chr19   57232128        Yes             Covered
# ..     ...        ...        ...                 ...
# 438  chr11   32396328        Yes             Covered
# 439  chr11   32400021        Yes             Covered
# 441  chr11   32396277        Yes             Covered
# 450  chr11   32392036        Yes             Covered
# 451  chr11   32392670        Yes             Covered
#
# [339 rows x 4 columns]

# %%
merged_3 = pd.merge(merged_2, df_3, on=['CHROM', 'POS'], how='left', sort=False)
merged_3['Literature'] = merged_3['Literature'].fillna('No')
merged_3
# Out:
#        Gene Name Gene_Match          rsID CHROM       POS REF ALT  \
# 0                        No  rs1416222198  chr1     65591   C   T
# 1                        No  rs1416222198  chr1     65591   C   T
# 2                        No  rs1416222198  chr1     65591   C   T
# 3                        No  rs1166163776  chr1     65649   G   A
# 4                        No  rs1166163776  chr1     65649   G   A
# ...          ...        ...           ...   ...       ...  ..  ..
# 297877    EIF1AY         No     rs9786153  chrY  20577481   C   T
# 297878                   No    rs17250535  chrY  21311315   T   A
# 297879      DAZ3         No  rs1156813394  chrY  24796170   C   G
# 297880      DAZ3         No  rs1156813394  chrY  24796170   C   G
# 297881      DAZ3         No  rs1156813394  chrY  24796170   C   G
#
#             Zygosity                         Consequence Consequence_score  \
# 0       Heterozygous             downstream gene variant              2/10
# 1       Heterozygous                      intron variant              2/10
# 2       Heterozygous             downstream gene variant              2/10
# 3       Heterozygous             downstream gene variant              2/10
# 4       Heterozygous                      intron variant              2/10
# ...              ...                                 ...               ...
# 297877    Homozygous               upstream gene variant              2/10
# 297878    Homozygous  non coding transcript exon variant              2/10
# 297879    Homozygous                      intron variant              2/10
# 297880    Homozygous                      intron variant              2/10
# 297881    Homozygous                      intron variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT  \
# 0       MODIFIER           1.5
# 1       MODIFIER           1.5
# 2       MODIFIER           1.5
# 3       MODIFIER           1.5
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...                ...
# 297877  MODIFIER           1.5
# 297878  MODIFIER           1.5
# 297879  MODIFIER           1.5
# 297880  MODIFIER           1.5
# 297881  MODIFIER           1.5
#
#        ClinVar              HGVSc HGVSc (Transcript) HGVSp HGVSp (Transcript)  \
# 0                                               None                     None
# 1               ENST00000641515.2          c.9+18C>T                     None
# 2                                               None                     None
# 3                                               None                     None
# 4               ENST00000641515.2          c.9+76G>A                     None
# ...        ...                ...                ...   ...                ...
# 297877                                          None                     None
# 297878          ENST00000437359.1            n.48T>A                     None
# 297879          ENST00000315357.9      c.714+2253G>C                     None
# 297880          ENST00000382365.7        c.715-72G>C                     None
# 297881          ENST00000446723.4        c.715-72G>C                     None
#
#          GT  GQ SDP  DP  RD  AD    FREQ       PVAL RDF RDR ADF ADR SIFT  \
# 0       0/1  23  26  26  19   7  26.92%  4.9169E-3  10   9   4   3
# 1       0/1  23  26  26  19   7  26.92%  4.9169E-3  10   9   4   3
# 2       0/1  23  26  26  19   7  26.92%  4.9169E-3  10   9   4   3
# 3       0/1  20  19  19  13   6  31.58%   9.828E-3   1  12   2   4
# 4       0/1  20  19  19  13   6  31.58%   9.828E-3   1  12   2   4
# ...     ...  ..  ..  ..  ..  ..     ...        ...  ..  ..  ..  ..  ...
# 297877  1/1  52  10  10   0  10    100%  5.4125E-6   0   0   3   7
# 297878  1/1  64  12  12   0  12    100%   3.698E-7   0   0   6   6
# 297879  1/1  74  22  22   5  17  77.27%  3.8368E-8   1   4  11   6
# 297880  1/1  74  22  22   5  17  77.27%  3.8368E-8   1   4  11   6
# 297881  1/1  74  22  22   5  17  77.27%  3.8368E-8   1   4  11   6
#
#        PolyPhen      AF  AFR_AF  AMR_AF  EAS_AF  EUR_AF  SAS_AF gnomADe_AF  \
# 0
# 1
# 2
# 3
# 4
# ...         ...     ...     ...     ...     ...     ...     ...        ...
# 297877           0.8273  0.9624  0.5824  0.9959  0.4667  0.9962
# 297878           0.0681       0  0.0059       0    0.05  0.2731
# 297879
# 297880
# 297881
#
#        gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF  \
# 0
# 1
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 297877
# 297878
# 297879
# 297880
# 297881
#
#        gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF  \
# 0                                                                     0.03416
# 1                                                                     0.03416
# 2                                                                     0.03416
# 3                                                                     0.03432
# 4                                                                     0.03432
# ...               ...            ...            ...            ...        ...
# 297877                                                                 0.6593
# 297878
# 297879                                                                      0
# 297880                                                                      0
# 297881                                                                      0
#
#        gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF  \
# 0             0.02306         0.1667        0.02711        0.03333
# 1             0.02306         0.1667        0.02711        0.03333
# 2             0.02306         0.1667        0.02711        0.03333
# 3             0.01435        0.05263        0.03176        0.09639
# 4             0.01435        0.05263        0.03176        0.09639
# ...               ...            ...            ...            ...
# 297877         0.8119         0.2864         0.5121         0.9004
# 297878
# 297879              0              0              0              0
# 297880              0              0              0              0
# 297881              0              0              0              0
#
#        gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0            0.001639              0           0.05        0.09167
# 1            0.001639              0           0.05        0.09167
# 2            0.001639              0           0.05        0.09167
# 3            0.001832         0.0122        0.07895        0.09393
# 4            0.001832         0.0122        0.07895        0.09393
# ...               ...            ...            ...            ...
# 297877         0.9992         0.9714         0.9865         0.4599
# 297878
# 297879              0              0              0              0
# 297880              0              0              0              0
# 297881              0              0              0              0
#
#        gnomADg_OTH_AF gnomADg_SAS_AF   MAX_AF  \
# 0             0.05357        0.02083   0.1667
# 1             0.05357        0.02083   0.1667
# 2             0.05357        0.02083   0.1667
# 3             0.02439        0.03321  0.09639
# 4             0.02439        0.03321  0.09639
# ...               ...            ...      ...
# 297877         0.6294         0.9906   0.9992
# 297878                                 0.2731
# 297879              0              0        0
# 297880              0              0        0
# 297881              0              0        0
#
#                                               MAX_AF_POPS  \
# 0                                             gnomADg AMI
# 1                                             gnomADg AMI
# 2                                             gnomADg AMI
# 3                                             gnomADg ASJ
# 4                                             gnomADg ASJ
# ...                                                   ...
# 297877                                        gnomADg EAS
# 297878                                                SAS
# 297879  gnomADg AFR,gnomADg AMI,gnomADg AMR,gnomADg AS...
# 297880  gnomADg AFR,gnomADg AMI,gnomADg AMR,gnomADg AS...
# 297881  gnomADg AFR,gnomADg AMI,gnomADg AMR,gnomADg AS...
#
#                                    BIOTYPE EXON INTRON  \
# 0       transcribed unprocessed pseudogene
# 1                           protein coding         2/2
# 2                                   lncRNA
# 3       transcribed unprocessed pseudogene
# 4                           protein coding         2/2
# ...                                    ...  ...    ...
# 297877                              lncRNA
# 297878              unprocessed pseudogene  1/9
# 297879                      protein coding        9/15
# 297880                      protein coding        9/18
# 297881                      protein coding        9/16
#
#        Protein Position and Amino Acid Codons STRAND  \
# 0                                  nan             1
# 1                                  nan             1
# 2                                  nan             1
# 3                                  nan             1
# 4                                  nan             1
# ...                                ...    ...    ...
# 297877                             nan            -1
# 297878                             nan             1
# 297879                             nan            -1
# 297880                             nan            -1
# 297881                             nan            -1
#
#                                                    PUBMED Literature  \
# 0                                                                 No
# 1                                                                 No
# 2                                                                 No
# 3                                                                 No
# 4                                                                 No
# ...                                                   ...        ...
# 297877  22271044,29391530,24262073,15896936,32996047,3...         No
# 297878                                  34424929,35176104         No
# 297879                                                            No
# 297880                                                            No
# 297881                                                            No
#
#        Covered/Not_Covered
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 297877                 NaN
# 297878                 NaN
# 297879                 NaN
# 297880                 NaN
# 297881                 NaN
#
# [297882 rows x 71 columns]

# %%
merged_3.Literature.value_counts()
# Out:
# No    297882
# Name: Literature, dtype: int64

# %%
merged_3 = merged_3[['Gene Name', 'Gene_Match', 'rsID', 'CHROM', 'POS', 'Literature', 'REF', 'ALT', 'Zygosity',
       'Consequence','Consequence_score', 'IMPACT', 'IMPACT_score', 'ClinVar_CLNDN', 'CLIN_SIG',
       'ClinVar_CLNREVSTAT', 'ClinVar', 'HGVSc', 'HGVSc (Transcript)', 'HGVSp',
       'HGVSp (Transcript)', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ',
       'PVAL', 'RDF', 'RDR', 'ADF', 'ADR', 'SIFT', 'PolyPhen', 'AF', 'AFR_AF',
       'AMR_AF', 'EAS_AF', 'EUR_AF', 'SAS_AF', 'gnomADe_AF', 'gnomADe_AFR_AF',
       'gnomADe_AMR_AF', 'gnomADe_ASJ_AF', 'gnomADe_EAS_AF', 'gnomADe_FIN_AF',
       'gnomADe_NFE_AF', 'gnomADe_OTH_AF', 'gnomADe_SAS_AF', 'gnomADg_AF',
       'gnomADg_AFR_AF', 'gnomADg_AMI_AF', 'gnomADg_AMR_AF', 'gnomADg_ASJ_AF',
       'gnomADg_EAS_AF', 'gnomADg_FIN_AF', 'gnomADg_MID_AF', 'gnomADg_NFE_AF',
       'gnomADg_OTH_AF', 'gnomADg_SAS_AF', 'MAX_AF', 'MAX_AF_POPS', 'BIOTYPE',
       'EXON', 'INTRON', 'Protein Position and Amino Acid', 'Codons', 'STRAND',
       'PUBMED']]
merged_3
# Out:
#        Gene Name Gene_Match          rsID CHROM       POS Literature REF ALT  \
# 0                        No  rs1416222198  chr1     65591         No   C   T
# 1                        No  rs1416222198  chr1     65591         No   C   T
# 2                        No  rs1416222198  chr1     65591         No   C   T
# 3                        No  rs1166163776  chr1     65649         No   G   A
# 4                        No  rs1166163776  chr1     65649         No   G   A
# ...          ...        ...           ...   ...       ...        ...  ..  ..
# 297877    EIF1AY         No     rs9786153  chrY  20577481         No   C   T
# 297878                   No    rs17250535  chrY  21311315         No   T   A
# 297879      DAZ3         No  rs1156813394  chrY  24796170         No   C   G
# 297880      DAZ3         No  rs1156813394  chrY  24796170         No   C   G
# 297881      DAZ3         No  rs1156813394  chrY  24796170         No   C   G
#
#             Zygosity                         Consequence Consequence_score  \
# 0       Heterozygous             downstream gene variant              2/10
# 1       Heterozygous                      intron variant              2/10
# 2       Heterozygous             downstream gene variant              2/10
# 3       Heterozygous             downstream gene variant              2/10
# 4       Heterozygous                      intron variant              2/10
# ...              ...                                 ...               ...
# 297877    Homozygous               upstream gene variant              2/10
# 297878    Homozygous  non coding transcript exon variant              2/10
# 297879    Homozygous                      intron variant              2/10
# 297880    Homozygous                      intron variant              2/10
# 297881    Homozygous                      intron variant              2/10
#
#           IMPACT  IMPACT_score ClinVar_CLNDN CLIN_SIG ClinVar_CLNREVSTAT  \
# 0       MODIFIER           1.5
# 1       MODIFIER           1.5
# 2       MODIFIER           1.5
# 3       MODIFIER           1.5
# 4       MODIFIER           1.5
# ...          ...           ...           ...      ...                ...
# 297877  MODIFIER           1.5
# 297878  MODIFIER           1.5
# 297879  MODIFIER           1.5
# 297880  MODIFIER           1.5
# 297881  MODIFIER           1.5
#
#        ClinVar              HGVSc HGVSc (Transcript) HGVSp HGVSp (Transcript)  \
# 0                                               None                     None
# 1               ENST00000641515.2          c.9+18C>T                     None
# 2                                               None                     None
# 3                                               None                     None
# 4               ENST00000641515.2          c.9+76G>A                     None
# ...        ...                ...                ...   ...                ...
# 297877                                          None                     None
# 297878          ENST00000437359.1            n.48T>A                     None
# 297879          ENST00000315357.9      c.714+2253G>C                     None
# 297880          ENST00000382365.7        c.715-72G>C                     None
# 297881          ENST00000446723.4        c.715-72G>C                     None
#
#          GT  GQ SDP  DP  RD  AD    FREQ       PVAL RDF RDR ADF ADR SIFT  \
# 0       0/1  23  26  26  19   7  26.92%  4.9169E-3  10   9   4   3
# 1       0/1  23  26  26  19   7  26.92%  4.9169E-3  10   9   4   3
# 2       0/1  23  26  26  19   7  26.92%  4.9169E-3  10   9   4   3
# 3       0/1  20  19  19  13   6  31.58%   9.828E-3   1  12   2   4
# 4       0/1  20  19  19  13   6  31.58%   9.828E-3   1  12   2   4
# ...     ...  ..  ..  ..  ..  ..     ...        ...  ..  ..  ..  ..  ...
# 297877  1/1  52  10  10   0  10    100%  5.4125E-6   0   0   3   7
# 297878  1/1  64  12  12   0  12    100%   3.698E-7   0   0   6   6
# 297879  1/1  74  22  22   5  17  77.27%  3.8368E-8   1   4  11   6
# 297880  1/1  74  22  22   5  17  77.27%  3.8368E-8   1   4  11   6
# 297881  1/1  74  22  22   5  17  77.27%  3.8368E-8   1   4  11   6
#
#        PolyPhen      AF  AFR_AF  AMR_AF  EAS_AF  EUR_AF  SAS_AF gnomADe_AF  \
# 0
# 1
# 2
# 3
# 4
# ...         ...     ...     ...     ...     ...     ...     ...        ...
# 297877           0.8273  0.9624  0.5824  0.9959  0.4667  0.9962
# 297878           0.0681       0  0.0059       0    0.05  0.2731
# 297879
# 297880
# 297881
#
#        gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF  \
# 0
# 1
# 2
# 3
# 4
# ...               ...            ...            ...            ...
# 297877
# 297878
# 297879
# 297880
# 297881
#
#        gnomADe_FIN_AF gnomADe_NFE_AF gnomADe_OTH_AF gnomADe_SAS_AF gnomADg_AF  \
# 0                                                                     0.03416
# 1                                                                     0.03416
# 2                                                                     0.03416
# 3                                                                     0.03432
# 4                                                                     0.03432
# ...               ...            ...            ...            ...        ...
# 297877                                                                 0.6593
# 297878
# 297879                                                                      0
# 297880                                                                      0
# 297881                                                                      0
#
#        gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF  \
# 0             0.02306         0.1667        0.02711        0.03333
# 1             0.02306         0.1667        0.02711        0.03333
# 2             0.02306         0.1667        0.02711        0.03333
# 3             0.01435        0.05263        0.03176        0.09639
# 4             0.01435        0.05263        0.03176        0.09639
# ...               ...            ...            ...            ...
# 297877         0.8119         0.2864         0.5121         0.9004
# 297878
# 297879              0              0              0              0
# 297880              0              0              0              0
# 297881              0              0              0              0
#
#        gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF  \
# 0            0.001639              0           0.05        0.09167
# 1            0.001639              0           0.05        0.09167
# 2            0.001639              0           0.05        0.09167
# 3            0.001832         0.0122        0.07895        0.09393
# 4            0.001832         0.0122        0.07895        0.09393
# ...               ...            ...            ...            ...
# 297877         0.9992         0.9714         0.9865         0.4599
# 297878
# 297879              0              0              0              0
# 297880              0              0              0              0
# 297881              0              0              0              0
#
#        gnomADg_OTH_AF gnomADg_SAS_AF   MAX_AF  \
# 0             0.05357        0.02083   0.1667
# 1             0.05357        0.02083   0.1667
# 2             0.05357        0.02083   0.1667
# 3             0.02439        0.03321  0.09639
# 4             0.02439        0.03321  0.09639
# ...               ...            ...      ...
# 297877         0.6294         0.9906   0.9992
# 297878                                 0.2731
# 297879              0              0        0
# 297880              0              0        0
# 297881              0              0        0
#
#                                               MAX_AF_POPS  \
# 0                                             gnomADg AMI
# 1                                             gnomADg AMI
# 2                                             gnomADg AMI
# 3                                             gnomADg ASJ
# 4                                             gnomADg ASJ
# ...                                                   ...
# 297877                                        gnomADg EAS
# 297878                                                SAS
# 297879  gnomADg AFR,gnomADg AMI,gnomADg AMR,gnomADg AS...
# 297880  gnomADg AFR,gnomADg AMI,gnomADg AMR,gnomADg AS...
# 297881  gnomADg AFR,gnomADg AMI,gnomADg AMR,gnomADg AS...
#
#                                    BIOTYPE EXON INTRON  \
# 0       transcribed unprocessed pseudogene
# 1                           protein coding         2/2
# 2                                   lncRNA
# 3       transcribed unprocessed pseudogene
# 4                           protein coding         2/2
# ...                                    ...  ...    ...
# 297877                              lncRNA
# 297878              unprocessed pseudogene  1/9
# 297879                      protein coding        9/15
# 297880                      protein coding        9/18
# 297881                      protein coding        9/16
#
#        Protein Position and Amino Acid Codons STRAND  \
# 0                                  nan             1
# 1                                  nan             1
# 2                                  nan             1
# 3                                  nan             1
# 4                                  nan             1
# ...                                ...    ...    ...
# 297877                             nan            -1
# 297878                             nan             1
# 297879                             nan            -1
# 297880                             nan            -1
# 297881                             nan            -1
#
#                                                    PUBMED
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 297877  22271044,29391530,24262073,15896936,32996047,3...
# 297878                                  34424929,35176104
# 297879
# 297880
# 297881
#
# [297882 rows x 70 columns]

# %%
merged_3.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Processed_vcf_files/KHHSPTGPTTL59_depth_vcf_processed.xlsx', index=False)

# %%
import pandas as pd
x = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Mody_Lit_final_Positions_hg38_hg37 (2).xlsx')
x['chrom'] = x['Chrom-pos-Ref-Alt_38'].str.split(',')
x = x.explode('chrom')

x['CHROM'] = x['chrom'].str.split('-').str[0]

# Function to add 'chr' prefix conditionally
def add_chr_prefix(chrom):
    if pd.notnull(chrom) and chrom.strip() != '':
        return 'chr' + str(chrom)
    else:
        return chrom

# Applying the function to the 'chromosome' column
x['CHROM'] = x['CHROM'].apply(add_chr_prefix)
x['CHROM'] = x['CHROM'].str.strip()
x['CHROM'] = x['CHROM'].str.replace(r'\s+', '')
x['POS'] = x['chrom'].str.split('-').str[1]

x.dropna(subset=['CHROM'], inplace=True)
# Drop rows with empty cells after removing leading and trailing whitespaces
x['CHROM'] = x['CHROM'].str.strip()
x['POS'] = x['POS'].str.strip()
# Dropping rows with empty cells and NaN values in both 'chromosome' and 'position' columns
x.dropna(subset=['CHROM', 'POS'], inplace=True)
df_3 = x[['CHROM', 'POS']]
df_3['Literature'] = 'Yes'
df_3.drop_duplicates(subset='POS', inplace=True)
df_3['POS'] = df_3['POS'].astype('int64')
df_3 = df_3.reset_index()
df_3 = df_3[['CHROM', 'POS', 'Literature']]

df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/KAPA HyperExome_hg38_capture_targets (1).bed', sep = '\t', header = None)
df.columns = ['chromosome', 'Start_pos', 'End_pos', 'INFO']

df['Extended_Start_pos'] = df['Start_pos'] - 20
df['Extended_End_pos'] = df['End_pos'] + 20

df['gene_symbol'] = df['INFO'].str.extract(r'gene_symbol=([^;]+)')
df = df[['chromosome', 'Extended_Start_pos', 'Extended_End_pos', 'INFO', 'gene_symbol']]


# Step 1: Create a dictionary from the df DataFrame
chromosome_dict = {}
for _, row in df.iterrows():
    chromosome = row['chromosome']
    start_pos = row['Extended_Start_pos']
    end_pos = row['Extended_End_pos']
    if chromosome not in chromosome_dict:
        chromosome_dict[chromosome] = []
    chromosome_dict[chromosome].append((start_pos, end_pos))

# Step 2: Define a function to check coverage
def check_coverage(row):
    pos = row['POS']
    chromosome = row['CHROM']
    if chromosome in chromosome_dict:
        ranges = chromosome_dict[chromosome]
        for start, end in ranges:
            if start <= pos <= end:
                return 'Covered'
    return 'Not_Covered'

# Step 3: Apply the function to create the new column in dataset2
df_3['Covered/Not_Covered'] = df_3.apply(check_coverage, axis=1)

df_3 = df_3[df_3['Covered/Not_Covered'] == 'Covered']
df_3
# Out:
#       CHROM        POS Literature Covered/Not_Covered
# 0     chr12  120978691        Yes             Covered
# 1     chr12  120978908        Yes             Covered
# 2     chr12  120997590        Yes             Covered
# 3     chr12  120996531        Yes             Covered
# 4     chr12  120978928        Yes             Covered
# ...     ...        ...        ...                 ...
# 2206  chr11   17394331        Yes             Covered
# 2207  chr11   17396955        Yes             Covered
# 2208  chr11   17395249        Yes             Covered
# 2209  chr11   17413396        Yes             Covered
# 2210  chr11   17408487        Yes             Covered
#
# [1685 rows x 4 columns]

# %%
df_3 = df_3[['CHROM', 'POS', 'Literature']]
df_3
# Out:
#       CHROM        POS Literature
# 0     chr12  120978691        Yes
# 1     chr12  120978908        Yes
# 2     chr12  120997590        Yes
# 3     chr12  120996531        Yes
# 4     chr12  120978928        Yes
# ...     ...        ...        ...
# 2206  chr11   17394331        Yes
# 2207  chr11   17396955        Yes
# 2208  chr11   17395249        Yes
# 2209  chr11   17413396        Yes
# 2210  chr11   17408487        Yes
#
# [1685 rows x 3 columns]

# %%
df_3.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Mody_lit_variants.xlsx', index=False)

# %%
import numpy as np
import pandas as pd
import polars as pl
import sys
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px


pd.set_option('display.max_columns',None)
import psycopg2


#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Algorithms to use
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

#Metrics to evaluate the model
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve

import warnings
warnings.filterwarnings("ignore")

#importing PCA and TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
vcf_data_df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/220_final.vcf', comment= '#', sep = '\t', header=None, low_memory=False, encoding='ISO-8859-1')
vcf_data_df.columns = ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE']

sample_cols = vcf_data_df['SAMPLE'].str.split(':', expand=True)
sample_cols.columns = ['GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL', 'RBQ', 'ABQ', 'RDF', 'RDR', 'ADF', 'ADR']

# Assign the values to the newly created columns
vcf_data_df = pd.concat([vcf_data_df, sample_cols], axis=1)
vcf_data_df = vcf_data_df[['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'GT', 'GQ', 'SDP', 'DP', 'RD', 'AD', 'FREQ', 'PVAL','RDF', 'RDR', 'ADF', 'ADR']]
vcf_data_df
# Out:
#       CHROM       POS         rsID REF ALT QUAL FILTER  \
# 0      chr1     14574   rs28503599   A   G    .   PASS
# 1      chr1     14590     rs707679   G   A    .   PASS
# 2      chr1     14599     rs707680   T   A    .   PASS
# 3      chr1     14604  rs541940975   A   G    .   PASS
# 4      chr1     14610  rs878986575   T   C    .   PASS
# ...     ...       ...          ...  ..  ..  ...    ...
# 61971  chrY  57196682            .   A   G    .   PASS
# 61972  chrY  57208367            .   A   G    .   PASS
# 61973  chrY  57208581            .   G   C    .   PASS
# 61974  chrY  57209184            .   T   C    .   PASS
# 61975  chrY  57211636            .   G   A    .   PASS
#
#                                                     INFO   GT  GQ SDP  DP  RD  \
# 0      ADP=8;WT=0;HET=0;HOM=1;NC=0;ASP;GENEINFO=DDX11...  1/1  24   8   8   2
# 1      ADP=8;WT=0;HET=0;HOM=1;NC=0;ASP;GENEINFO=DDX11...  1/1  24   8   8   2
# 2      ADP=10;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8524,0....  0/1  22  10  10   4
# 3      ADP=9;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8524,.,0...  0/1  23   9   9   3
# 4      ADP=9;WT=0;HET=1;HOM=0;NC=0;ASP;GENEINFO=DDX11...  0/1  23   9   9   3
# ...                                                  ...  ...  ..  ..  ..  ..
# 61971  ADP=16;WT=0;HET=1;HOM=0;NC=0;CSQ=G|missense_va...  0/1  20  16  16  10
# 61972  ADP=21;WT=0;HET=0;HOM=1;NC=0;CSQ=G|intron_vari...  1/1  69  21  21   5
# 61973  ADP=19;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  28  19  19  11
# 61974  ADP=31;WT=0;HET=1;HOM=0;NC=0;CSQ=C|non_coding_...  0/1  46  31  31  18
# 61975  ADP=22;WT=0;HET=1;HOM=0;NC=0;CSQ=A|intron_vari...  0/1  40  22  22  11
#
#        AD    FREQ       PVAL RDF RDR ADF ADR
# 0       6     75%  3.4965E-3   2   0   6   0
# 1       6     75%  3.4965E-3   2   0   6   0
# 2       6     60%   5.418E-3   4   0   6   0
# 3       6  66.67%  4.5249E-3   3   0   6   0
# 4       6  66.67%  4.5249E-3   3   0   6   0
# ...    ..     ...        ...  ..  ..  ..  ..
# 61971   6   37.5%   8.837E-3  10   0   4   2
# 61972  16  76.19%  1.2221E-7   4   1   7   9
# 61973   8  42.11%  1.5455E-3  11   0   8   0
# 61974  13  41.94%  2.4825E-5  15   3  11   2
# 61975  11     50%  9.1981E-5   6   5   9   2
#
# [61976 rows x 20 columns]

# %%
gene_list = ["CSF1", "FGF1", "FGF2", "ELK1", "FGF3", "IGF1R", "FGF4", "FGF5", "FGF6", "FGF7", "FGF8", "FGF9", "PRKACG", "AKT2", "AKT3", "KDR", "AKT1", "PRKACA", "PRKACB", "PDGFRB", "PRKCG", "PDGFRA", "MAP2K1", "MAP2K2", "PRKCB", "HGF", "FLT3LG", 
    "PRKCA", "PGF", "RAF1", "EPHA2", "CSF1R", "PDGFB", "PDGFBA", "TGFA", "STK4", 
    "EFNA5", "RASGRP2", "RASGRP1", "EFNA4", "RASGRP4", "RASGRP3", "RAP1B", "RAP1A", 
    "RRAS", "PDGFD", "PDGFC", "FGF20", "FGF23", "FGF22", "FGF21", "NGFR", "BDNF", 
    "INSR", "IGF2", "IGF1", "GNG12", "NFKB1", "FGF17", "EFNA1", "FGF16", "EFNA3", 
    "EFNA2", "FGF19", "FGF18", "NF1", "GRB2", "FGFR4", "FGFR3", "FGFR2", "FGF10", 
    "FGFR1", "FLT1", "FLT3", "FLT4", "RASGRF2", "RASGRF1", "FASLG", "IKBKB", "RAC2", 
    "RAC3", "IKBKG", "RAC1", "HRAS", "PLA2G4F", "PLA2G4D", "CHUK", "PLA2G4E", 
    "PLA2G4B", "PLA2G4C", "RRAS2", "PLA2G4A", "NGF", "MRAS", "RASA1", "RASA2", 
    "KIT", "SOS1", "MET", "SOS2", "RELA", "EGFR", "INS", "NTF4", "CDC42", "MAPK9", 
    "NRAS", "PAK1", "MAPK8", "NTF3", "MAPK1", "PAK2", "MAPK3", "NTRK1", "NTRK2", 
    "ANGPT4", "ANGPT2", "ANGPT1", "EGF", "VEGFB", "VEGFC", "VEGFD", "VEGFA", 
    "MAPK10", "KITLG", "KRAS", "TEK"]
print(len(gene_list))



["CSF1", "FGF1", "FGF2", "ELK1", "FGF3", "IGF1R", "FGF4", "FGF5", "FGF6", "FGF7", 
"FGF8", "FGF9", "PRKACG", "AKT2", "AKT3", "KDR", "AKT1", "PRKACA", "PRKACB", 
"PDGFRB", "PRKCG", "PDGFRA", "MAP2K1", "MAP2K2", "PRKCB", "HGF", "FLT3LG", 
"PRKCA", "PGF", "RAF1", "EPHA2", "CSF1R", "PDGFB", "PDGFA", "TGFA", "STK4", 
"EFNA5", "RASGRP2", "RASGRP1", "EFNA4", "RASGRP4", "RASGRP3", "RAP1B", "RAP1A", 
"RRAS", "PDGFD", "PDGFC", "FGF20", "FGF23", "FGF22", "FGF21", "NGFR", "BDNF", 
"INSR", "IGF2", "IGF1", "GNG12", "NFKB1", "FGF17", "EFNA1", "FGF16", "EFNA3", 
"EFNA2", "FGF19", "FGF18", "NF1", "GRB2", "FGFR4", "FGFR3", "FGFR2", "FGF10", 
"FGFR1", "FLT1", "FLT3", "FLT4", "RASGRF2", "RASGRF1", "FASLG", "IKBKB", "RAC2", 
"RAC3", "IKBKG", "RAC1", "HRAS", "PLA2G4F", "PLA2G4D", "CHUK", "PLA2G4E", 
"PLA2G4B", "PLA2G4C", "RRAS2", "PLA2G4A", "NGF", "MRAS", "RASA1", "RASA2", 
"KIT", "SOS1", "MET", "SOS2", "RELA", "EGFR", "INS", "NTF4", "CDC42", "MAPK9", 
"NRAS", "PAK1", "MAPK8", "NTF3", "MAPK1", "PAK2", "MAPK3", "NTRK1", "NTRK2", 
"ANGPT4", "ANGPT2", "ANGPT1", "EGF", "VEGFB", "VEGFC", "VEGFD", "VEGFA", 
"MAPK10", "KITLG", "KRAS", "TEK"]
# Out:
# 127

# %%
# Create a list of genes you want to search for
gene_list = ["CSF1", "FGF1", "FGF2", "ELK1", "FGF3", "IGF1R", "FGF4", "FGF5", "FGF6", "FGF7", 
             "FGF8", "FGF9", "PRKACG", "AKT2", "AKT3", "KDR", "AKT1", "PRKACA", "PRKACB", 
             "PDGFRB", "PRKCG", "PDGFRA", "MAP2K1", "MAP2K2", "PRKCB", "HGF", "FLT3LG", 
             "PRKCA", "PGF", "RAF1", "EPHA2", "CSF1R", "PDGFB", "PDGFA", "TGFA", "STK4", 
             "EFNA5", "RASGRP2", "RASGRP1", "EFNA4", "RASGRP4", "RASGRP3", "RAP1B", "RAP1A", 
             "RRAS", "PDGFD", "PDGFC", "FGF20", "FGF23", "FGF22", "FGF21", "NGFR", "BDNF", 
             "INSR", "IGF2", "IGF1", "GNG12", "NFKB1", "FGF17", "EFNA1", "FGF16", "EFNA3", 
             "EFNA2", "FGF19", "FGF18", "NF1", "GRB2", "FGFR4", "FGFR3", "FGFR2", "FGF10", 
             "FGFR1", "FLT1", "FLT3", "FLT4", "RASGRF2", "RASGRF1", "FASLG", "IKBKB", "RAC2", 
             "RAC3", "IKBKG", "RAC1", "HRAS", "PLA2G4F", "PLA2G4D", "CHUK", "PLA2G4E", 
             "PLA2G4B", "PLA2G4C", "RRAS2", "PLA2G4A", "NGF", "MRAS", "RASA1", "RASA2", 
             "KIT", "SOS1", "MET", "SOS2", "RELA", "EGFR", "INS", "NTF4", "CDC42", "MAPK9", 
             "NRAS", "PAK1", "MAPK8", "NTF3", "MAPK1", "PAK2", "MAPK3", "NTRK1", "NTRK2", 
             "ANGPT4", "ANGPT2", "ANGPT1", "EGF", "VEGFB", "VEGFC", "VEGFD", "VEGFA", 
             "MAPK10", "KITLG", "KRAS", "TEK"]

# Create a new DataFrame to store the matching rows
matched_rows = pd.DataFrame(columns=vcf_data_df.columns)  # Create an empty DataFrame with the same columns

# Create a new column to store matched genes
matched_rows["Matched_Genes"] = ""

# Create a regex pattern to match genes within any separator
gene_pattern = r'\b(' + '|'.join(gene_list) + r')\b'

# Iterate through each row in the data
for index, row in vcf_data_df.iterrows():
    info = row["INFO"]
    
    # Use regex to find all matched genes within the INFO column
    matched_genes = re.findall(gene_pattern, info, re.IGNORECASE)
    
    if matched_genes:
        # Update the "Matched_Genes" column with matched genes
        matched_rows.at[index, "Matched_Genes"] = ', '.join(matched_genes)
        matched_rows = pd.concat([matched_rows, vcf_data_df.loc[[index]]])
        
matched_rows
# Out:
#       CHROM        POS                   rsID  REF  ALT QUAL FILTER  \
# 866     NaN        NaN                    NaN  NaN  NaN  NaN    NaN
# 866    chr1   16124918              rs1803527    C    T    .   PASS
# 867     NaN        NaN                    NaN  NaN  NaN  NaN    NaN
# 867    chr1   16132319              rs2291805    C    T    .   PASS
# 868     NaN        NaN                    NaN  NaN  NaN  NaN    NaN
# ...     ...        ...                    ...  ...  ...  ...    ...
# 61808  chrX  154556836                      .    C    T    .   PASS
# 61809   NaN        NaN                    NaN  NaN  NaN  NaN    NaN
# 61809  chrX  154558768             rs55810978    G    C    .   PASS
# 61810   NaN        NaN                    NaN  NaN  NaN  NaN    NaN
# 61810  chrX  154563953  rs201709278;rs5945206    C    T    .   PASS
#
#                                                     INFO   GT   GQ  SDP   DP  \
# 866                                                  NaN  NaN  NaN  NaN  NaN
# 866    ADP=23;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.09425,0...  1/1  129   23   23
# 867                                                  NaN  NaN  NaN  NaN  NaN
# 867    ADP=38;WT=0;HET=1;HOM=0;NC=0;ASP;CAF=0.8726,0....  0/1   25   38   38
# 868                                                  NaN  NaN  NaN  NaN  NaN
# ...                                                  ...  ...  ...  ...  ...
# 61808  ADP=20;WT=0;HET=1;HOM=0;NC=0;CSQ=T|intron_vari...  0/1   27   20   20
# 61809                                                NaN  NaN  NaN  NaN  NaN
# 61809  ADP=8;WT=0;HET=0;HOM=1;NC=0;ASP;GENEINFO=IKBKG...  1/1   41    8    8
# 61810                                                NaN  NaN  NaN  NaN  NaN
# 61810  ADP=13;WT=0;HET=0;HOM=1;NC=0;ASP;G5;G5A;GENEIN...  1/1   70   13   13
#
#         RD   AD    FREQ        PVAL  RDF  RDR  ADF  ADR  \
# 866    NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN
# 866      0   23    100%  1.2146E-13    0    0   16    7
# 867    NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN
# 867     30    8  21.05%   2.5935E-3   18   12    7    1
# 868    NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN
# ...    ...  ...     ...         ...  ...  ...  ...  ...
# 61808   12    8     40%    1.638E-3    9    3    4    4
# 61809  NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN
# 61809    0    8    100%     7.77E-5    0    0    1    7
# 61810  NaN  NaN     NaN         NaN  NaN  NaN  NaN  NaN
# 61810    0   13    100%   9.6148E-8    0    0    9    4
#
#                                            Matched_Genes
# 866                                         EPHA2, EPHA2
# 866                                                  NaN
# 867                           EPHA2, EPHA2, EPHA2, EPHA2
# 867                                                  NaN
# 868                           EPHA2, EPHA2, EPHA2, EPHA2
# ...                                                  ...
# 61808                                                NaN
# 61809  IKBKG, IKBKG, IKBKG, IKBKG, IKBKG, IKBKG, IKBK...
# 61809                                                NaN
# 61810  IKBKG, IKBKG, IKBKG, IKBKG, IKBKG, IKBKG, IKBK...
# 61810                                                NaN
#
# [758 rows x 21 columns]

# %%
758/2
# Out:
# 379.0

# %%
matched_rows.INFO.iloc[3]
# Out:
# 'ADP=9;WT=0;HET=0;HOM=1;NC=0;ASP;CAF=0.003195,0.9968;COMMON=1;GENEINFO=CSF1:1435;GNO;HD;INT;KGPhase1;KGPhase3;RS=333972;RSPOS=109925123;SAO=0;SLO;SSR=0;TOPMED=0.00305810397553516,0.99694189602446483;VC=SNV;VLD;VP=0x05010008000504053e000100;WGT=1;dbSNPBuildID=79;CSQ=G|intron_variant|MODIFIER|CSF1|ENSG00000184371|Transcript|ENST00000329608|protein_coding||7/8||||||||||1||HGNC|HGNC:2432|||||,G|intron_variant|MODIFIER|CSF1|ENSG00000184371|Transcript|ENST00000369801|protein_coding||8/8||||||||||1||HGNC|HGNC:2432|||||,G|intron_variant|MODIFIER|CSF1|ENSG00000184371|Transcript|ENST00000369802|protein_coding||7/8||||||||||1||HGNC|HGNC:2432|||||,G|intron_variant|MODIFIER|CSF1|ENSG00000184371|Transcript|ENST00000420111|protein_coding||7/8||||||||||1||HGNC|HGNC:2432|||||,G|downstream_gene_variant|MODIFIER|CSF1|ENSG00000184371|Transcript|ENST00000488198|protein_coding|||||||||||1524|1|cds_end_NF|HGNC|HGNC:2432|||||,G|downstream_gene_variant|MODIFIER|CSF1|ENSG00000184371|Transcript|ENST00000525659|protein_coding|||||||||||3210|1|cds_end_NF|HGNC|HGNC:2432|||||,G|downstream_gene_variant|MODIFIER|CSF1|ENSG00000184371|Transcript|ENST00000526001|processed_transcript|||||||||||2574|1||HGNC|HGNC:2432|||||,G|downstream_gene_variant|MODIFIER|CSF1|ENSG00000184371|Transcript|ENST00000527192|protein_coding|||||||||||3243|1|cds_end_NF|HGNC|HGNC:2432|||||'

# %%
vcf_data_df.Matching_Genes.value_counts()
# Out:
# []    61976
# Name: Matching_Genes, dtype: int64

# %%
matched_rows.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/220_output.xlsx', index=False)

# %%
df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Fatty_Liver.xlsx')
df
# Out:
#         Gene         rsID                                         Citatation
# 0     PNPLA3     rs738409     PMID: 32333362, PMID: 27278285, PMID: 26409295
# 1     PNPLA3    rs4823173                                     PMID: 36000237
# 2     PNPLA3    rs2896019                                     PMID: 36000237
# 3     PNPLA3    rs3810622                                     PMID: 36000237
# 4     PNPLA3    rs2281135                                     PMID: 36000237
# 5     PNPLA3   rs12483959                                     PMID: 36000237
# 6     PNPLA3  rs143392071                                     PMID: 36000237
# 7     PNPLA3    rs2143571                                     PMID: 36000237
# 8     TM6SF2   rs58542926  PMID: 26807382, PMID: 36353245, PMID: 31713012...
# 9       GCKR    rs1260326  PMID: 32383295,PMID: 34535985, PMID: 34841290,...
# 10      GCKR     rs780094                     PMID: 37711901, PMID: 33243135
# 11      GCKR     rs780093                                     PMID: 28298293
# 12  HSD17B13   rs72613567     PMID: 32145256, PMID: 33363067, PMID: 33102799
# 13  HSD17B13   rs62305723                                     PMID: 32145256
# 14  HSD17B13  rs143404524                                     PMID: 32145256

# %%
data = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Processed_vcf_files/Fatty_liver_data.xlsx')
data
# Out:
#     Gene Name       rsID Covered/Not_covered  CHROM       POS REF ALT  \
# 0        GCKR  rs1260326             Covered   chr2  27508073   T   C
# 1        GCKR  rs1260326             Covered   chr2  27508073   T   G
# 2        GCKR  rs1260326             Covered   chr2  27508073   T   C
# 3        GCKR  rs1260326             Covered   chr2  27508073   T   G
# 4        GCKR  rs1260326             Covered   chr2  27508073   T   C
# ..        ...        ...                 ...    ...       ...  ..  ..
# 105    SAMM50  rs2143571         Not_Covered  chr22  43995806   G   C
# 106    SAMM50  rs2143571         Not_Covered  chr22  43995806   G   A
# 107    SAMM50  rs2143571         Not_Covered  chr22  43995806   G   C
# 108    SAMM50  rs2143571         Not_Covered  chr22  43995806   G   A
# 109    SAMM50  rs2143571         Not_Covered  chr22  43995806   G   C
#
#                                       Consequence Consequence_score    IMPACT  \
# 0          missense variant,splice region variant              7/10  MODERATE
# 1          missense variant,splice region variant              7/10  MODERATE
# 2          missense variant,splice region variant              7/10  MODERATE
# 3          missense variant,splice region variant              7/10  MODERATE
# 4                         downstream gene variant              2/10  MODIFIER
# ..                                            ...               ...       ...
# 105  intron variant,non coding transcript variant              2/10  MODIFIER
# 106  intron variant,non coding transcript variant              2/10  MODIFIER
# 107  intron variant,non coding transcript variant              2/10  MODIFIER
# 108                     regulatory region variant              2/10  MODIFIER
# 109                     regulatory region variant              2/10  MODIFIER
#
#      IMPACT_score                                      ClinVar_CLNDN  \
# 0             5.0  Fasting plasma glucose level quantitative trai...
# 1             5.0                                                NaN
# 2             5.0  Fasting plasma glucose level quantitative trai...
# 3             5.0                                                NaN
# 4             1.5  Fasting plasma glucose level quantitative trai...
# ..            ...                                                ...
# 105           1.5                                                NaN
# 106           1.5                                                NaN
# 107           1.5                                                NaN
# 108           1.5                                                NaN
# 109           1.5                                                NaN
#
#                CLIN_SIG                                 ClinVar_CLNREVSTAT  \
# 0    benign,association  criteria provided, multiple submitters, no con...
# 1                   NaN                                                NaN
# 2    benign,association  criteria provided, multiple submitters, no con...
# 3                   NaN                                                NaN
# 4    benign,association  criteria provided, multiple submitters, no con...
# ..                  ...                                                ...
# 105                 NaN                                                NaN
# 106                 NaN                                                NaN
# 107                 NaN                                                NaN
# 108                 NaN                                                NaN
# 109                 NaN                                                NaN
#
#      ClinVar              HGVSc HGVSc (Transcript)              HGVSp  \
# 0     8751.0  ENST00000264717.7          c.1337T>C  ENSP00000264717.2
# 1        NaN  ENST00000264717.7          c.1337T>G  ENSP00000264717.2
# 2     8751.0  ENST00000411584.1           c.440T>C  ENSP00000416917.1
# 3        NaN  ENST00000411584.1           c.440T>G  ENSP00000416917.1
# 4     8751.0                NaN               None                NaN
# ..       ...                ...                ...                ...
# 105      NaN  ENST00000493621.1       n.100+316G>C                NaN
# 106      NaN  ENST00000494795.1      n.3057-532G>A                NaN
# 107      NaN  ENST00000494795.1      n.3057-532G>C                NaN
# 108      NaN                NaN               None                NaN
# 109      NaN                NaN               None                NaN
#
#     HGVSp (Transcript)             SIFT       PolyPhen      AF  AFR_AF  \
# 0          p.Leu446Pro     tolerated(1)      benign(0)  0.7067  0.9062
# 1          p.Leu446Arg  tolerated(0.06)      benign(0)     NaN     NaN
# 2          p.Leu147Pro     tolerated(1)  benign(0.001)  0.7067  0.9062
# 3          p.Leu147Arg  tolerated(0.06)  benign(0.286)     NaN     NaN
# 4                 None              NaN            NaN  0.7067  0.9062
# ..                 ...              ...            ...     ...     ...
# 105               None              NaN            NaN     NaN     NaN
# 106               None              NaN            NaN  0.3075  0.3797
# 107               None              NaN            NaN     NaN     NaN
# 108               None              NaN            NaN  0.3075  0.3797
# 109               None              NaN            NaN     NaN     NaN
#
#      AMR_AF  EAS_AF  EUR_AF  SAS_AF  gnomADe_AF  gnomADe_AFR_AF  \
# 0    0.6383  0.5188  0.5895  0.7996    0.633100          0.8679
# 1       NaN     NaN     NaN     NaN    0.000004          0.0000
# 2    0.6383  0.5188  0.5895  0.7996    0.633100          0.8679
# 3       NaN     NaN     NaN     NaN    0.000004          0.0000
# 4    0.6383  0.5188  0.5895  0.7996    0.633100          0.8679
# ..      ...     ...     ...     ...         ...             ...
# 105     NaN     NaN     NaN     NaN         NaN             NaN
# 106  0.3415  0.3661  0.2087  0.2270         NaN             NaN
# 107     NaN     NaN     NaN     NaN         NaN             NaN
# 108  0.3415  0.3661  0.2087  0.2270         NaN             NaN
# 109     NaN     NaN     NaN     NaN         NaN             NaN
#
#      gnomADe_AMR_AF  gnomADe_ASJ_AF  gnomADe_EAS_AF  gnomADe_FIN_AF  \
# 0            0.6662          0.4668        0.510800          0.6426
# 1            0.0000          0.0000        0.000054          0.0000
# 2            0.6662          0.4668        0.510800          0.6426
# 3            0.0000          0.0000        0.000054          0.0000
# 4            0.6662          0.4668        0.510800          0.6426
# ..              ...             ...             ...             ...
# 105             NaN             NaN             NaN             NaN
# 106             NaN             NaN             NaN             NaN
# 107             NaN             NaN             NaN             NaN
# 108             NaN             NaN             NaN             NaN
# 109             NaN             NaN             NaN             NaN
#
#      gnomADe_NFE_AF  gnomADe_OTH_AF  gnomADe_SAS_AF  gnomADg_AF  \
# 0            0.5902          0.6005           0.758      0.6700
# 1            0.0000          0.0000           0.000         NaN
# 2            0.5902          0.6005           0.758      0.6700
# 3            0.0000          0.0000           0.000         NaN
# 4            0.5902          0.6005           0.758      0.6700
# ..              ...             ...             ...         ...
# 105             NaN             NaN             NaN         NaN
# 106             NaN             NaN             NaN      0.2519
# 107             NaN             NaN             NaN         NaN
# 108             NaN             NaN             NaN      0.2519
# 109             NaN             NaN             NaN         NaN
#
#      gnomADg_AFR_AF  gnomADg_AMI_AF  gnomADg_AMR_AF  gnomADg_ASJ_AF  \
# 0            0.8582          0.7083          0.6260          0.4585
# 1               NaN             NaN             NaN             NaN
# 2            0.8582          0.7083          0.6260          0.4585
# 3               NaN             NaN             NaN             NaN
# 4            0.8582          0.7083          0.6260          0.4585
# ..              ...             ...             ...             ...
# 105             NaN             NaN             NaN             NaN
# 106          0.3536          0.2325          0.3173          0.1317
# 107             NaN             NaN             NaN             NaN
# 108          0.3536          0.2325          0.3173          0.1317
# 109             NaN             NaN             NaN             NaN
#
#      gnomADg_EAS_AF  gnomADg_FIN_AF  gnomADg_MID_AF  gnomADg_NFE_AF  \
# 0            0.5014          0.6378          0.4904          0.5898
# 1               NaN             NaN             NaN             NaN
# 2            0.5014          0.6378          0.4904          0.5898
# 3               NaN             NaN             NaN             NaN
# 4            0.5014          0.6378          0.4904          0.5898
# ..              ...             ...             ...             ...
# 105             NaN             NaN             NaN             NaN
# 106          0.3875          0.2268          0.2184          0.1789
# 107             NaN             NaN             NaN             NaN
# 108          0.3875          0.2268          0.2184          0.1789
# 109             NaN             NaN             NaN             NaN
#
#      gnomADg_OTH_AF  gnomADg_SAS_AF    MAX_AF  MAX_AF_POPS  \
# 0            0.6106          0.7566  0.906200          AFR
# 1               NaN             NaN  0.000054  gnomADe EAS
# 2            0.6106          0.7566  0.906200          AFR
# 3               NaN             NaN  0.000054  gnomADe EAS
# 4            0.6106          0.7566  0.906200          AFR
# ..              ...             ...       ...          ...
# 105             NaN             NaN       NaN          NaN
# 106          0.2555          0.2035  0.387500  gnomADg EAS
# 107             NaN             NaN       NaN          NaN
# 108          0.2555          0.2035  0.387500  gnomADg EAS
# 109             NaN             NaN       NaN          NaN
#
#                             BIOTYPE   EXON INTRON  \
# 0                    protein coding  15/19    NaN
# 1                    protein coding  15/19    NaN
# 2                    protein coding    5/7    NaN
# 3                    protein coding    5/7    NaN
# 4                   retained intron    NaN    NaN
# ..                              ...    ...    ...
# 105  protein coding CDS not defined    NaN    1/1
# 106                 retained intron    NaN    2/2
# 107                 retained intron    NaN    2/2
# 108                        promoter    NaN    NaN
# 109                        promoter    NaN    NaN
#
#     Protein Position and Amino Acid   Codons  STRAND
# 0                             L446P  cTg/cCg     1.0
# 1                             L446R  cTg/cGg     1.0
# 2                             L147P  cTg/cCg     1.0
# 3                             L147R  cTg/cGg     1.0
# 4                               NaN      NaN     1.0
# ..                              ...      ...     ...
# 105                             NaN      NaN     1.0
# 106                             NaN      NaN     1.0
# 107                             NaN      NaN     1.0
# 108                             NaN      NaN     NaN
# 109                             NaN      NaN     NaN
#
# [110 rows x 55 columns]

# %%
merged_df = pd.merge(data, df, on = 'rsID', how='left', sort=False)
merged_df
# Out:
#     Gene Name       rsID Covered/Not_covered  CHROM       POS REF ALT  \
# 0        GCKR  rs1260326             Covered   chr2  27508073   T   C
# 1        GCKR  rs1260326             Covered   chr2  27508073   T   G
# 2        GCKR  rs1260326             Covered   chr2  27508073   T   C
# 3        GCKR  rs1260326             Covered   chr2  27508073   T   G
# 4        GCKR  rs1260326             Covered   chr2  27508073   T   C
# ..        ...        ...                 ...    ...       ...  ..  ..
# 105    SAMM50  rs2143571         Not_Covered  chr22  43995806   G   C
# 106    SAMM50  rs2143571         Not_Covered  chr22  43995806   G   A
# 107    SAMM50  rs2143571         Not_Covered  chr22  43995806   G   C
# 108    SAMM50  rs2143571         Not_Covered  chr22  43995806   G   A
# 109    SAMM50  rs2143571         Not_Covered  chr22  43995806   G   C
#
#                                       Consequence Consequence_score    IMPACT  \
# 0          missense variant,splice region variant              7/10  MODERATE
# 1          missense variant,splice region variant              7/10  MODERATE
# 2          missense variant,splice region variant              7/10  MODERATE
# 3          missense variant,splice region variant              7/10  MODERATE
# 4                         downstream gene variant              2/10  MODIFIER
# ..                                            ...               ...       ...
# 105  intron variant,non coding transcript variant              2/10  MODIFIER
# 106  intron variant,non coding transcript variant              2/10  MODIFIER
# 107  intron variant,non coding transcript variant              2/10  MODIFIER
# 108                     regulatory region variant              2/10  MODIFIER
# 109                     regulatory region variant              2/10  MODIFIER
#
#      IMPACT_score                                      ClinVar_CLNDN  \
# 0             5.0  Fasting plasma glucose level quantitative trai...
# 1             5.0                                                NaN
# 2             5.0  Fasting plasma glucose level quantitative trai...
# 3             5.0                                                NaN
# 4             1.5  Fasting plasma glucose level quantitative trai...
# ..            ...                                                ...
# 105           1.5                                                NaN
# 106           1.5                                                NaN
# 107           1.5                                                NaN
# 108           1.5                                                NaN
# 109           1.5                                                NaN
#
#                CLIN_SIG                                 ClinVar_CLNREVSTAT  \
# 0    benign,association  criteria provided, multiple submitters, no con...
# 1                   NaN                                                NaN
# 2    benign,association  criteria provided, multiple submitters, no con...
# 3                   NaN                                                NaN
# 4    benign,association  criteria provided, multiple submitters, no con...
# ..                  ...                                                ...
# 105                 NaN                                                NaN
# 106                 NaN                                                NaN
# 107                 NaN                                                NaN
# 108                 NaN                                                NaN
# 109                 NaN                                                NaN
#
#      ClinVar              HGVSc HGVSc (Transcript)              HGVSp  \
# 0     8751.0  ENST00000264717.7          c.1337T>C  ENSP00000264717.2
# 1        NaN  ENST00000264717.7          c.1337T>G  ENSP00000264717.2
# 2     8751.0  ENST00000411584.1           c.440T>C  ENSP00000416917.1
# 3        NaN  ENST00000411584.1           c.440T>G  ENSP00000416917.1
# 4     8751.0                NaN               None                NaN
# ..       ...                ...                ...                ...
# 105      NaN  ENST00000493621.1       n.100+316G>C                NaN
# 106      NaN  ENST00000494795.1      n.3057-532G>A                NaN
# 107      NaN  ENST00000494795.1      n.3057-532G>C                NaN
# 108      NaN                NaN               None                NaN
# 109      NaN                NaN               None                NaN
#
#     HGVSp (Transcript)             SIFT       PolyPhen      AF  AFR_AF  \
# 0          p.Leu446Pro     tolerated(1)      benign(0)  0.7067  0.9062
# 1          p.Leu446Arg  tolerated(0.06)      benign(0)     NaN     NaN
# 2          p.Leu147Pro     tolerated(1)  benign(0.001)  0.7067  0.9062
# 3          p.Leu147Arg  tolerated(0.06)  benign(0.286)     NaN     NaN
# 4                 None              NaN            NaN  0.7067  0.9062
# ..                 ...              ...            ...     ...     ...
# 105               None              NaN            NaN     NaN     NaN
# 106               None              NaN            NaN  0.3075  0.3797
# 107               None              NaN            NaN     NaN     NaN
# 108               None              NaN            NaN  0.3075  0.3797
# 109               None              NaN            NaN     NaN     NaN
#
#      AMR_AF  EAS_AF  EUR_AF  SAS_AF  gnomADe_AF  gnomADe_AFR_AF  \
# 0    0.6383  0.5188  0.5895  0.7996    0.633100          0.8679
# 1       NaN     NaN     NaN     NaN    0.000004          0.0000
# 2    0.6383  0.5188  0.5895  0.7996    0.633100          0.8679
# 3       NaN     NaN     NaN     NaN    0.000004          0.0000
# 4    0.6383  0.5188  0.5895  0.7996    0.633100          0.8679
# ..      ...     ...     ...     ...         ...             ...
# 105     NaN     NaN     NaN     NaN         NaN             NaN
# 106  0.3415  0.3661  0.2087  0.2270         NaN             NaN
# 107     NaN     NaN     NaN     NaN         NaN             NaN
# 108  0.3415  0.3661  0.2087  0.2270         NaN             NaN
# 109     NaN     NaN     NaN     NaN         NaN             NaN
#
#      gnomADe_AMR_AF  gnomADe_ASJ_AF  gnomADe_EAS_AF  gnomADe_FIN_AF  \
# 0            0.6662          0.4668        0.510800          0.6426
# 1            0.0000          0.0000        0.000054          0.0000
# 2            0.6662          0.4668        0.510800          0.6426
# 3            0.0000          0.0000        0.000054          0.0000
# 4            0.6662          0.4668        0.510800          0.6426
# ..              ...             ...             ...             ...
# 105             NaN             NaN             NaN             NaN
# 106             NaN             NaN             NaN             NaN
# 107             NaN             NaN             NaN             NaN
# 108             NaN             NaN             NaN             NaN
# 109             NaN             NaN             NaN             NaN
#
#      gnomADe_NFE_AF  gnomADe_OTH_AF  gnomADe_SAS_AF  gnomADg_AF  \
# 0            0.5902          0.6005           0.758      0.6700
# 1            0.0000          0.0000           0.000         NaN
# 2            0.5902          0.6005           0.758      0.6700
# 3            0.0000          0.0000           0.000         NaN
# 4            0.5902          0.6005           0.758      0.6700
# ..              ...             ...             ...         ...
# 105             NaN             NaN             NaN         NaN
# 106             NaN             NaN             NaN      0.2519
# 107             NaN             NaN             NaN         NaN
# 108             NaN             NaN             NaN      0.2519
# 109             NaN             NaN             NaN         NaN
#
#      gnomADg_AFR_AF  gnomADg_AMI_AF  gnomADg_AMR_AF  gnomADg_ASJ_AF  \
# 0            0.8582          0.7083          0.6260          0.4585
# 1               NaN             NaN             NaN             NaN
# 2            0.8582          0.7083          0.6260          0.4585
# 3               NaN             NaN             NaN             NaN
# 4            0.8582          0.7083          0.6260          0.4585
# ..              ...             ...             ...             ...
# 105             NaN             NaN             NaN             NaN
# 106          0.3536          0.2325          0.3173          0.1317
# 107             NaN             NaN             NaN             NaN
# 108          0.3536          0.2325          0.3173          0.1317
# 109             NaN             NaN             NaN             NaN
#
#      gnomADg_EAS_AF  gnomADg_FIN_AF  gnomADg_MID_AF  gnomADg_NFE_AF  \
# 0            0.5014          0.6378          0.4904          0.5898
# 1               NaN             NaN             NaN             NaN
# 2            0.5014          0.6378          0.4904          0.5898
# 3               NaN             NaN             NaN             NaN
# 4            0.5014          0.6378          0.4904          0.5898
# ..              ...             ...             ...             ...
# 105             NaN             NaN             NaN             NaN
# 106          0.3875          0.2268          0.2184          0.1789
# 107             NaN             NaN             NaN             NaN
# 108          0.3875          0.2268          0.2184          0.1789
# 109             NaN             NaN             NaN             NaN
#
#      gnomADg_OTH_AF  gnomADg_SAS_AF    MAX_AF  MAX_AF_POPS  \
# 0            0.6106          0.7566  0.906200          AFR
# 1               NaN             NaN  0.000054  gnomADe EAS
# 2            0.6106          0.7566  0.906200          AFR
# 3               NaN             NaN  0.000054  gnomADe EAS
# 4            0.6106          0.7566  0.906200          AFR
# ..              ...             ...       ...          ...
# 105             NaN             NaN       NaN          NaN
# 106          0.2555          0.2035  0.387500  gnomADg EAS
# 107             NaN             NaN       NaN          NaN
# 108          0.2555          0.2035  0.387500  gnomADg EAS
# 109             NaN             NaN       NaN          NaN
#
#                             BIOTYPE   EXON INTRON  \
# 0                    protein coding  15/19    NaN
# 1                    protein coding  15/19    NaN
# 2                    protein coding    5/7    NaN
# 3                    protein coding    5/7    NaN
# 4                   retained intron    NaN    NaN
# ..                              ...    ...    ...
# 105  protein coding CDS not defined    NaN    1/1
# 106                 retained intron    NaN    2/2
# 107                 retained intron    NaN    2/2
# 108                        promoter    NaN    NaN
# 109                        promoter    NaN    NaN
#
#     Protein Position and Amino Acid   Codons  STRAND    Gene  \
# 0                             L446P  cTg/cCg     1.0    GCKR
# 1                             L446R  cTg/cGg     1.0    GCKR
# 2                             L147P  cTg/cCg     1.0    GCKR
# 3                             L147R  cTg/cGg     1.0    GCKR
# 4                               NaN      NaN     1.0    GCKR
# ..                              ...      ...     ...     ...
# 105                             NaN      NaN     1.0  PNPLA3
# 106                             NaN      NaN     1.0  PNPLA3
# 107                             NaN      NaN     1.0  PNPLA3
# 108                             NaN      NaN     NaN  PNPLA3
# 109                             NaN      NaN     NaN  PNPLA3
#
#                                             Citatation
# 0    PMID: 32383295,PMID: 34535985, PMID: 34841290,...
# 1    PMID: 32383295,PMID: 34535985, PMID: 34841290,...
# 2    PMID: 32383295,PMID: 34535985, PMID: 34841290,...
# 3    PMID: 32383295,PMID: 34535985, PMID: 34841290,...
# 4    PMID: 32383295,PMID: 34535985, PMID: 34841290,...
# ..                                                 ...
# 105                                     PMID: 36000237
# 106                                     PMID: 36000237
# 107                                     PMID: 36000237
# 108                                     PMID: 36000237
# 109                                     PMID: 36000237
#
# [110 rows x 57 columns]

# %%
merged_df.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Processed_vcf_files/Fatty_liver_data.xlsx', index=False)

# %%
df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/KHHSPTGPCSP22_genes.xlsx')
df
# Out:
#     Gene Name    Matched Gene
# 0       CTLA4  Type1 Daibetes
# 1         INS  Type1 Daibetes
# 2       IL2RA  Type1 Daibetes
# 3       HNF1A  Type1 Daibetes
# 4         CEL  Type1 Daibetes
# ..        ...             ...
# 278      TRDN         Cardiac
# 279   LDLRAP1         Cardiac
# 280     PCSK9         Cardiac
# 281      APOB         Cardiac
# 282     STAP1         Cardiac
#
# [283 rows x 2 columns]

# %%
result = df.groupby('Gene Name')['Matched Gene'].agg(lambda x: ', '.join(x.unique())).reset_index()
result
# Out:
#     Gene Name                   Matched Gene
# 0       ABCA1           Cholesterol, Cardiac
# 1       ABCB4                    Cholesterol
# 2       ABCC8  Type2 Diabetes, MODY, Obesity
# 3       ABCC9                        Cardiac
# 4       ABCG5                    Cholesterol
# ..        ...                            ...
# 241      WNK1                   Hypertension
# 242      WNK4                   Hypertension
# 243       WRN                 Type2 Diabetes
# 244  ZMPSTE24                    Cholesterol
# 245   ZSCAN20            Diabetic Neuropathy
#
# [246 rows x 2 columns]

# %%
result.to_excel(r'C:/Users/GenepoweRx_Madhu/Desktop/KHHSPTGPCSP22_genes.xlsx')
