# %%
import numpy as np
import pandas as pd
import polars as pl
import sys
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
pd.set_option('display.max_columns',None)
import psycopg2
import warnings
warnings.filterwarnings("ignore")

# %%
import openpyxl

# Load the existing Excel file
input_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_allele_definition_table (1).xlsx'
workbook = openpyxl.load_workbook(input_excel_file)

# Select the "Alleles" sheet
sheet_name = "Alleles"
sheet = workbook[sheet_name]

# Starting from the 9th row in column A
start_row = 9

# Create a new sheet to store the duplicated values
output_sheet_name = "DuplicatedValues"
output_sheet = workbook.create_sheet(title=output_sheet_name)

# Write headers to the new sheet
output_sheet.append(["Column A", "Individual Values"])

# Iterate over values in column A from the 9th row onwards
for row_number in range(start_row, sheet.max_row + 1):
    cell_value_A = sheet[f'A{row_number}'].value
    
    # Check if any of the values in columns B, C, D, etc. are null
    if any(sheet.cell(row=row_number, column=col).value is None for col in range(2, sheet.max_column + 1)):
        # Get non-None values from columns B, C, D, etc.
        values_from_columns = [
            sheet.cell(row=row_number, column=col).value
            for col in range(2, sheet.max_column + 1)
            if sheet.cell(row=row_number, column=col).value is not None
        ]
        
        # Iterate over each value and create a new row
        for individual_value in values_from_columns:
            output_sheet.append([cell_value_A, individual_value])

# Save the workbook with the new sheet
output_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_allele_definition_table_with_duplicated_values_new.xlsx'
workbook.save(output_excel_file)

print(f"Values saved to the new Excel file: {output_excel_file}")
# Out:
# Values saved to the new Excel file: C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_allele_definition_table_with_duplicated_values_new.xlsx

# %%
import openpyxl

# Load the existing Excel file
input_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_allele_definition_table (1).xlsx'
workbook = openpyxl.load_workbook(input_excel_file)

# Select the "Alleles" sheet
sheet_name = "Alleles"
sheet = workbook[sheet_name]

# Starting from the 9th row
start_row = 9

# Iterate over rows starting from the 9th row
for row_number in range(start_row, sheet.max_row + 1):
    # Check if any cell in the row is not null
    if any(sheet.cell(row=row_number, column=col).value is not None for col in range(1, sheet.max_column + 1)):
        # Print the entire row
        row_values = [sheet.cell(row=row_number, column=col).value for col in range(1, sheet.max_column + 1)]
        print(f"Row {row_number} values: {row_values}")

print("Values printed for each row from the 9th row onwards where at least one cell is not null.")
# Out:
# Row 9 values: ['*2', None, None, 'G', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'A', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'S', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ...

# %%
import openpyxl

# Load the existing Excel file
input_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_allele_definition_table (1).xlsx'
workbook = openpyxl.load_workbook(input_excel_file)

# Select the "Alleles" sheet
sheet_name = "Alleles"
sheet = workbook[sheet_name]

# Starting from the 9th row in column A
start_row = 9

# Create a new sheet to store the duplicated values
output_sheet_name = "DuplicatedValues"
output_sheet = workbook.create_sheet(title=output_sheet_name)

# Write headers to the new sheet
output_sheet.append(["Column A", "Individual Values", "4th Row Value"])

# Iterate over values in column A from the 9th row onwards
for row_number in range(start_row, sheet.max_row + 1):
    cell_value_A = sheet[f'A{row_number}'].value
    
    # Check if any of the values in columns B, C, D, etc. are null
    if any(sheet.cell(row=row_number, column=col).value is None for col in range(2, sheet.max_column + 1)):
        # Get non-None values from columns B, C, D, etc.
        values_from_columns = [
            sheet.cell(row=row_number, column=col).value
            for col in range(2, sheet.max_column + 1)
            if sheet.cell(row=row_number, column=col).value is not None
        ]
        
        # Get the respective 4th row values only for non-null values in column A
        if cell_value_A is not None:
            # Filter out the 4th row values based on non-null values in column A
            fourth_row_values = [
                sheet.cell(row=4, column=col).value
                for col in range(2, sheet.max_column + 1)
                if sheet.cell(row=row_number, column=col).value is not None
            ]
            output_sheet.append([cell_value_A, ', '.join(map(str, values_from_columns)), ', '.join(map(str, fourth_row_values))])

# Save the workbook with the new sheet
output_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_Madhu_new.xlsx'
workbook.save(output_excel_file)

print(f"Values saved to the new Excel file: {output_excel_file}")
# Out:
# Values saved to the new Excel file: C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_Madhu_new.xlsx

# %% [markdown]
# # Main code

# %%
import openpyxl

# Load the existing Excel file
input_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_allele_definition_table (1).xlsx'
workbook = openpyxl.load_workbook(input_excel_file)

# Select the "Alleles" sheet
sheet_name = "Alleles"
sheet = workbook[sheet_name]

# Starting from the 9th row in column A
start_row = 9

# Create a new sheet to store the duplicated values
output_sheet_name = "DuplicatedValues"
output_sheet = workbook.create_sheet(title=output_sheet_name)

# Write headers to the new sheet
output_sheet.append(["Column A", "Individual Values", "4th Row Value", "6th Row Value"])

# Iterate over values in column A from the 9th row onwards
for row_number in range(start_row, sheet.max_row + 1):
    cell_value_A = sheet[f'A{row_number}'].value
    
    # Check if any of the values in columns B, C, D, etc. are null
    if any(sheet.cell(row=row_number, column=col).value is None for col in range(2, sheet.max_column + 1)):
        # Get non-None values from columns B, C, D, etc.
        values_from_columns = [
            sheet.cell(row=row_number, column=col).value
            for col in range(2, sheet.max_column + 1)
            if sheet.cell(row=row_number, column=col).value is not None
        ]
        
        # Get the respective 4th and 6th row values only for non-null values in column A
        if cell_value_A is not None:
            # Filter out the 4th and 6th row values based on non-null values in column A
            fourth_row_values = [
                sheet.cell(row=4, column=col).value
                for col in range(2, sheet.max_column + 1)
                if sheet.cell(row=row_number, column=col).value is not None
            ]
            sixth_row_values = [
                sheet.cell(row=6, column=col).value
                for col in range(2, sheet.max_column + 1)
                if sheet.cell(row=row_number, column=col).value is not None
            ]
            output_sheet.append([cell_value_A, ', '.join(map(str, values_from_columns)), ', '.join(map(str, fourth_row_values)), ', '.join(map(str, sixth_row_values))])

# Save the workbook with the new sheet
output_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_allele_Madhu_new.xlsx'
workbook.save(output_excel_file)

print(f"Values saved to the new Excel file: {output_excel_file}")
# Out:
# Values saved to the new Excel file: C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_allele_Madhu_new.xlsx

# %% [markdown]
# # CYP2D6 gene

# %%
import openpyxl

# Load the existing Excel file
input_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/Input_gene_files/DPYD_allele_definition_table.xlsx'
workbook = openpyxl.load_workbook(input_excel_file)

# Select the "Alleles" sheet
sheet_name = "Alleles"
sheet = workbook[sheet_name]

# Starting from the 9th row in column A
start_row = 9

# Create a new sheet to store the duplicated values
output_sheet_name = "DuplicatedValues"
output_sheet = workbook.create_sheet(title=output_sheet_name)

# Write headers to the new sheet
output_sheet.append(["Haplotype", "ALT", "Genomic_pos", "rsID"])

# Iterate over values in column A from the 9th row onwards
for row_number in range(start_row, sheet.max_row + 1):
    cell_value_A = sheet[f'A{row_number}'].value
    
    # Check if any of the values in columns B, C, D, etc. are null
    if any(sheet.cell(row=row_number, column=col).value is None for col in range(2, sheet.max_column + 1)):
        # Get non-None values from columns B, C, D, etc.
        values_from_columns = [
            sheet.cell(row=row_number, column=col).value
            for col in range(2, sheet.max_column + 1)
            if sheet.cell(row=row_number, column=col).value is not None
        ]
        
        # Get the respective 4th and 6th row values only for non-null values in column A
        if cell_value_A is not None:
            # Filter out the 4th and 6th row values based on non-null values in column A
            fourth_row_values = [
                sheet.cell(row=4, column=col).value
                for col in range(2, sheet.max_column + 1)
                if sheet.cell(row=row_number, column=col).value is not None
            ]
            sixth_row_values = [
                sheet.cell(row=6, column=col).value
                for col in range(2, sheet.max_column + 1)
                if sheet.cell(row=row_number, column=col).value is not None
            ]

            # Append each value in a new row
            for individual_value, fourth_value, sixth_value in zip(values_from_columns, fourth_row_values, sixth_row_values):
                output_sheet.append([cell_value_A, individual_value, fourth_value, sixth_value])

# Save the workbook with the new sheet
output_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/Output_genes_data/DPYD_allele_definition.xlsx'
workbook.save(output_excel_file)

print(f"Values saved to the new Excel file: {output_excel_file}")
# Out:
# Values saved to the new Excel file: C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/Output_genes_data/DPYD_allele_definition.xlsx

# %%
import openpyxl

# Load the existing Excel file
input_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/NAT2_PS216450-1447964753.xlsx'
workbook = openpyxl.load_workbook(input_excel_file)

# Select the "Alleles" sheet
sheet_name = "Map"
sheet = workbook[sheet_name]

# Starting from the 9th row in column A
start_row = 7

# Create a new sheet to store the duplicated values
output_sheet_name = "DuplicatedValues"
output_sheet = workbook.create_sheet(title=output_sheet_name)

# Write headers to the new sheet
output_sheet.append(["Haplotype", "ALT", "Genomic_pos", "rsID"])

# Iterate over values in column A from the 9th row onwards
for row_number in range(start_row, sheet.max_row + 1):
    cell_value_A = sheet[f'A{row_number}'].value
    
    # Check if any of the values in columns B, C, D, etc. are null
    if any(sheet.cell(row=row_number, column=col).value is None for col in range(2, sheet.max_column + 1)):
        # Get non-None values from columns B, C, D, etc.
        values_from_columns = [
            sheet.cell(row=row_number, column=col).value
            for col in range(2, sheet.max_column + 1)
            if sheet.cell(row=row_number, column=col).value is not None
        ]
        
        # Get the respective 4th and 6th row values only for non-null values in column A
        if cell_value_A is not None:
            # Filter out the 4th and 6th row values based on non-null values in column A
            fourth_row_values = [
                sheet.cell(row=4, column=col).value
                for col in range(2, sheet.max_column + 1)
                if sheet.cell(row=row_number, column=col).value is not None
            ]
            sixth_row_values = [
                sheet.cell(row=6, column=col).value
                for col in range(2, sheet.max_column + 1)
                if sheet.cell(row=row_number, column=col).value is not None
            ]

            # Append each value in a new row
            for individual_value, fourth_value, sixth_value in zip(values_from_columns, fourth_row_values, sixth_row_values):
                output_sheet.append([cell_value_A, individual_value, fourth_value, sixth_value])

# Save the workbook with the new sheet
output_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/Output_genes_data/NAT2_allele_definition.xlsx'
workbook.save(output_excel_file)

print(f"Values saved to the new Excel file: {output_excel_file}")
# Out:
# Values saved to the new Excel file: C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/Output_genes_data/NAT2_allele_definition.xlsx

# %%
import os
import pandas as pd

# Path to the folder containing your Excel files
folder_path = r'C:/Users/GenepoweRx_Madhu/Documents/excel/'

# List to store dataframes from each Excel file
dfs = []

# Iterate through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.xlsx') or filename.endswith('.xls'):
        file_path = os.path.join(folder_path, filename)
        
        # Read Excel file and store it in a dataframe
        df = pd.read_excel(file_path)
        
        # Append the dataframe to the list
        dfs.append(df)

# Merge dataframes based on the rsID column
merged_df = pd.concat(dfs, ignore_index=True)

# Write the merged dataframe to a new Excel file
output_path = r'C:/Users/GenepoweRx_Madhu/Documents/excel/file.xlsx'
merged_df.to_excel(output_path, index=False)

print(f'Merged data saved to {output_path}')
# Out:
# Merged data saved to C:/Users/GenepoweRx_Madhu/Documents/excel/file.xlsx

# %%
data = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/DPYD_vr.vcf', sep = '\t', comment='#', header = None)
data.columns= ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'Filter', 'INFO']
data = data[~data['CHROM'].str.startswith('LRG_')]
data['CHROM'] = 'chr' + data['CHROM']
data.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/DPYD_vr_output.xlsx', index = False)
data
# Out:
#     CHROM       POS         rsID    REF ALT QUAL Filter  \
# 0    chr1  97883368  rs150036960      G   C    .      .
# 2    chr1  97883353   rs72549310      G   A    .      .
# 4    chr1  97883352   rs80081766      C   T    .      .
# 6    chr1  97883329    rs1801265      A   G    .      .
# 8    chr1  97740414   rs72549309  AATGA   A    .      .
# ..    ...       ...          ...    ...  ..  ...    ...
# 214  chr1  97079005  rs140114515      C   T    .      .
# 216  chr1  97078993  rs148799944      C   G    .      .
# 218  chr1  97078987  rs114096998      G   T    .      .
# 220  chr1  97078987  rs114096998      G   C    .      .
# 222  chr1  97078987  rs114096998      G   A    .      .
#
#                                                   INFO
# 0    HGVSg=NC_000001.11:g.97883368G>C,LRG_722:g.426...
# 2    HGVSg=NC_000001.11:g.97883353G>A,LRG_722:g.427...
# 4    HGVSg=NC_000001.11:g.97883352C>T,LRG_722:g.427...
# 6    HGVSg=NC_000001.11:g.97883329A>G,LRG_722:g.427...
# ...

# %%
data[data['rsID'] == 'rs137852338']
# Out:
#     CHROM        POS         rsID   REF ALT QUAL Filter  \
# 489  chrX  154546052  rs137852338  ATGA   A    .      .
#
#                                                   INFO
# 489  HGVSg=NC_000023.11:g.154546053_154546055del;VC...

# %%
data['Genomic_pos_dbsnp'] = data['INFO'].str.extract(r'HGVSg=NC_000\d{2}\.\d+:[^:]+:([^\s,]+)')
data = data[['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'Genomic_pos_dbsnp']]
data
# Out:
#       CHROM       POS         rsID REF ALT Genomic_pos_dbsnp
# 0     chr12  21172782   rs56101265   T   C               NaN
# 2     chr12  21174595   rs56061388   T   C               NaN
# 4     chr12  21176883   rs72559745   A   G               NaN
# 6     chr12  21176879   rs11045819   C   T               NaN
# 8     chr12  21176879   rs11045819   C   A               NaN
# ...     ...       ...          ...  ..  ..               ...
# 1288  chr19  41006967   rs58871670   G   A               NaN
# 1290  chr19  41012393  rs754621576   T   C               NaN
# 1292  chr19  41012394  rs780991919   A   G               NaN
# 1294  chr19  41012478  rs200238771   T   A               NaN
# 1296  chr19  41016652  rs764288403   G   A               NaN
#
# [744 rows x 6 columns]

# %%
data = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/DPYD_vr_output.xlsx')
data
# Out:
#     CHROM       POS         rsID    REF ALT       Genomic_pos_Dbsnp
# 0    chr1  97883368  rs150036960      G   C           g.97883368G>C
# 1    chr1  97883353   rs72549310      G   A           g.97883353G>A
# 2    chr1  97883352   rs80081766      C   T           g.97883352C>T
# 3    chr1  97883329    rs1801265      A   G           g.97883329A>G
# 4    chr1  97740414   rs72549309  AATGA   A  g.97740415_97740418del
# ..    ...       ...          ...    ...  ..                     ...
# 107  chr1  97079005  rs140114515      C   T           g.97079005C>T
# 108  chr1  97078993  rs148799944      C   G           g.97078993C>G
# 109  chr1  97078987  rs114096998      G   T           g.97078987G>T
# 110  chr1  97078987  rs114096998      G   C           g.97078987G>C
# 111  chr1  97078987  rs114096998      G   A           g.97078987G>A
#
# [112 rows x 6 columns]

# %%
data['Genomic_pos_Dbsnp'] = data['Genomic_pos_Dbsnp'].astype(str)
grouped = data.groupby(['CHROM', 'POS', 'rsID', 'REF']).agg({
    'ALT': lambda x: ','.join(set(x)),
    'Genomic_pos_Dbsnp': lambda x: ','.join(set(x))
}).reset_index()
grouped
# Out:
#    CHROM       POS         rsID    REF    ALT  \
# 0   chr1  97078987  rs114096998      G  C,T,A
# 1   chr1  97078993  rs148799944      C      G
# 2   chr1  97079005  rs140114515      C      T
# 3   chr1  97079071    rs1801268      C      A
# 4   chr1  97079076  rs139459586      A      C
# ..   ...       ...          ...    ...    ...
# 78  chr1  97740414   rs72549309  AATGA      A
# 79  chr1  97883329    rs1801265      A      G
# 80  chr1  97883352   rs80081766      C      T
# 81  chr1  97883353   rs72549310      G      A
# 82  chr1  97883368  rs150036960      G      C
#
#                             Genomic_pos_Dbsnp
# 0   g.97078987G>C,g.97078987G>T,g.97078987G>A
# 1                               g.97078993C>G
# 2                               g.97079005C>T
# 3                               g.97079071C>A
# 4                               g.97079076A>C
# ..                                        ...
# 78                     g.97740415_97740418del
# ...

# %%
grouped.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/All_548_pos_info.xlsx', index=False)

# %%
df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/Output_genes_data/DPYD_allele_definition.xlsx')
df
# Out:
#                 Haplotype      ALT        Genomic_pos         rsID
# 0                 c.46C>G        C      g.97883368G>C  rs150036960
# 1                 c.61C>T        A      g.97883353G>A   rs72549310
# 2                 c.62G>A        T      g.97883352C>T   rs80081766
# 3           c.85T>C (*9A)        G      g.97883329A>G    rs1801265
# 4   c.295_298delTCAT (*7)  ATGA(1)  g.97740411ATGA[1]   rs72549309
# ..                    ...      ...                ...          ...
# 78              c.2978T>G        C      g.97079076A>C  rs139459586
# 79        c.2983G>T (*10)        A      g.97079071C>A    rs1801268
# 80              c.3049G>A        T      g.97079005C>T  rs140114515
# 81              c.3061G>C        G      g.97078993C>G  rs148799944
# 82              c.3067C>A        T      g.97078987G>T  rs114096998
#
# [83 rows x 4 columns]

# %%
CYP2D6 = pd.merge(df, grouped, on = 'rsID', how = 'left', sort = False)
CYP2D6
# Out:
#                 Haplotype    ALT_x        Genomic_pos         rsID CHROM  \
# 0                 c.46C>G        C      g.97883368G>C  rs150036960  chr1
# 1                 c.61C>T        A      g.97883353G>A   rs72549310  chr1
# 2                 c.62G>A        T      g.97883352C>T   rs80081766  chr1
# 3           c.85T>C (*9A)        G      g.97883329A>G    rs1801265  chr1
# 4   c.295_298delTCAT (*7)  ATGA(1)  g.97740411ATGA[1]   rs72549309  chr1
# ..                    ...      ...                ...          ...   ...
# 78              c.2978T>G        C      g.97079076A>C  rs139459586  chr1
# 79        c.2983G>T (*10)        A      g.97079071C>A    rs1801268  chr1
# 80              c.3049G>A        T      g.97079005C>T  rs140114515  chr1
# 81              c.3061G>C        G      g.97078993C>G  rs148799944  chr1
# 82              c.3067C>A        T      g.97078987G>T  rs114096998  chr1
#
#          POS    REF  ALT_y                          Genomic_pos_Dbsnp
# ...

# %%
import pandas as pd
df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/KAPA HyperExome_hg38_capture_targets (1).bed', sep = '\t', header = None, error_bad_lines=False)
df.columns = ['chromosome', 'Extended_Start_pos', 'Extended_End_pos', 'INFO']
df['Gene'] = df['INFO'].str.extract(r'gene_symbol=([^;]+)')
df['Gene'] = df['Gene'].str.split(',').str[0]
df = df[['chromosome', 'Extended_Start_pos', 'Extended_End_pos', 'Gene']]
df
# Out:
#        chromosome  Extended_Start_pos  Extended_End_pos    Gene
# 0            chr1               65509             65629   OR4F5
# 1            chr1               69027             70017   OR4F5
# 2            chr1              450730            451686  OR4F29
# 3            chr1              685706            686662  OR4F16
# 4            chr1              924421            924957  SAMD11
# ...           ...                 ...               ...     ...
# 208906       chrY            25038801          25038921   BPY2C
# 208907       chrY            25041766          25041886   BPY2C
# 208908       chrY            25043908          25044028   BPY2C
# 208909       chrY            25622433          25624073    CDY1
# 208910       chrY            25624417          25624537    CDY1
#
# [208911 rows x 4 columns]

# %%
variants = CYP2D6.copy()

# %%
# Step 1: Create a dictionary from the df DataFrame
chromosome_dict = {}
for _, row in df.iterrows():
    chromosome = row['chromosome']
    start_pos = row['Extended_Start_pos']
    end_pos = row['Extended_End_pos']
    if chromosome not in chromosome_dict:
        chromosome_dict[chromosome] = []
    chromosome_dict[chromosome].append((start_pos, end_pos))

# Step 2: Define a function to check coverage
def check_coverage(row):
    pos = row['POS']
    chromosome = row['CHROM']
    if chromosome in chromosome_dict:
        ranges = chromosome_dict[chromosome]
        for start, end in ranges:
            if start <= pos <= end:
                return 'Covered', start, end
    return 'Not_Covered', None, None  # Return None for start and end if not covered

# Step 3: Apply the function to create the new column in data
variants['Covered/Not_Covered'], variants['Start_Pos_Covered'], variants['End_Pos_Covered'] = zip(*variants.apply(check_coverage, axis=1))

# Step 4: Create new columns for Covered rows
covered_rows = variants['Covered/Not_Covered'] == 'Covered'
variants.loc[covered_rows, 'Covered_Chromosome'] = variants.loc[covered_rows, 'CHROM']
variants.loc[covered_rows, 'Covered_Start_Pos'] = variants.loc[covered_rows, 'Start_Pos_Covered']
variants.loc[covered_rows, 'Covered_End_Pos'] = variants.loc[covered_rows, 'End_Pos_Covered']

# Drop temporary columns
variants.drop(['Start_Pos_Covered', 'End_Pos_Covered'], axis=1, inplace=True)

# Display the DataFrame
variants
# Out:
#                 Haplotype    ALT_x        Genomic_pos         rsID CHROM  \
# 0                 c.46C>G        C      g.97883368G>C  rs150036960  chr1
# 1                 c.61C>T        A      g.97883353G>A   rs72549310  chr1
# 2                 c.62G>A        T      g.97883352C>T   rs80081766  chr1
# 3           c.85T>C (*9A)        G      g.97883329A>G    rs1801265  chr1
# 4   c.295_298delTCAT (*7)  ATGA(1)  g.97740411ATGA[1]   rs72549309  chr1
# ..                    ...      ...                ...          ...   ...
# 78              c.2978T>G        C      g.97079076A>C  rs139459586  chr1
# 79        c.2983G>T (*10)        A      g.97079071C>A    rs1801268  chr1
# 80              c.3049G>A        T      g.97079005C>T  rs140114515  chr1
# 81              c.3061G>C        G      g.97078993C>G  rs148799944  chr1
# 82              c.3067C>A        T      g.97078987G>T  rs114096998  chr1
#
#          POS    REF  ALT_y                          Genomic_pos_Dbsnp  \
# ...

# %%
variants.to_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/Output_genes_data/Final_outputs/DPYD_haplo_data.xlsx', index=False)

# %% [markdown]
# # whole script

# %%
data = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/vr_output.vcf', sep = '\t', comment='#', header = None)
data.columns= ['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'QUAL', 'Filter', 'INFO']
data = data[~data['CHROM'].str.startswith('LRG_')]
data['CHROM'] = 'chr' + data['CHROM']
data['Genomic_pos_dbsnp'] = data['INFO'].str.extract(r'HGVSg=NC_000\d{2}\.\d+:[^:]+:([^\s,]+)')
data = data[['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'Genomic_pos_dbsnp']]
data['Genomic_pos_Dbsnp'] = data['Genomic_pos_Dbsnp'].astype(str)
grouped = data.groupby(['CHROM', 'POS', 'rsID', 'REF']).agg({
    'ALT': lambda x: ','.join(set(x)),
    'Genomic_pos_Dbsnp': lambda x: ','.join(set(x))
}).reset_index()
df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/Output_genes_data/NAT2_allele_definition.xlsx')
Gene = pd.merge(df, grouped, on = 'rsID', how = 'left', sort = False)
df = pd.read_csv(r'C:/Users/GenepoweRx_Madhu/Downloads/KAPA HyperExome_hg38_capture_targets (1).bed', sep = '\t', header = None, error_bad_lines=False)
df.columns = ['chromosome', 'Extended_Start_pos', 'Extended_End_pos', 'INFO']
df['Gene'] = df['INFO'].str.extract(r'gene_symbol=([^;]+)')
df['Gene'] = df['Gene'].str.split(',').str[0]
df = df[['chromosome', 'Extended_Start_pos', 'Extended_End_pos', 'Gene']]
variants = Gene.copy()
# Step 1: Create a dictionary from the df DataFrame
chromosome_dict = {}
for _, row in df.iterrows():
    chromosome = row['chromosome']
    start_pos = row['Extended_Start_pos']
    end_pos = row['Extended_End_pos']
    if chromosome not in chromosome_dict:
        chromosome_dict[chromosome] = []
    chromosome_dict[chromosome].append((start_pos, end_pos))

# Step 2: Define a function to check coverage
def check_coverage(row):
    pos = row['POS']
    chromosome = row['CHROM']
    if chromosome in chromosome_dict:
        ranges = chromosome_dict[chromosome]
        for start, end in ranges:
            if start <= pos <= end:
                return 'Covered', start, end
    return 'Not_Covered', None, None  # Return None for start and end if not covered

# Step 3: Apply the function to create the new column in data
variants['Covered/Not_Covered'], variants['Start_Pos_Covered'], variants['End_Pos_Covered'] = zip(*variants.apply(check_coverage, axis=1))

# Step 4: Create new columns for Covered rows
covered_rows = variants['Covered/Not_Covered'] == 'Covered'
variants.loc[covered_rows, 'Covered_Chromosome'] = variants.loc[covered_rows, 'CHROM']
variants.loc[covered_rows, 'Covered_Start_Pos'] = variants.loc[covered_rows, 'Start_Pos_Covered']
variants.loc[covered_rows, 'Covered_End_Pos'] = variants.loc[covered_rows, 'End_Pos_Covered']

# Drop temporary columns
variants.drop(['Start_Pos_Covered', 'End_Pos_Covered'], axis=1, inplace=True)

# Display the DataFrame
variants

# %%
import openpyxl

# Load the existing Excel file
input_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_allele_definition_table (1).xlsx'
workbook = openpyxl.load_workbook(input_excel_file)

# Select the "Alleles" sheet
sheet_name = "Alleles"
sheet = workbook[sheet_name]

# Starting from the 9th row in column A
start_row = 9

# Create a new sheet to store the duplicated values and additional columns
output_sheet_name = "DuplicatedValues"
output_sheet = workbook.create_sheet(title=output_sheet_name)

# Write headers to the new sheet
output_sheet.append(["Column A", "Individual Values", "Value from Column B", "Value from Column C", "Value from Column D", "Value from Column E", "Value from Column F", "Value from Column G", "Value from Column H", "Value from Column I", "Value from Column J", "Value from Column K", "Value from Column L", "Value from Column M", "Value from Column N", "Value from Column O"])

# Iterate over values in column A from the 9th row onwards
for row_number in range(start_row, sheet.max_row + 1):
    cell_value_A = sheet[f'A{row_number}'].value
    
    # Check if any of the values in columns B, C, D, etc. are null
    if any(sheet.cell(row=row_number, column=col).value is None for col in range(2, sheet.max_column + 1)):
        # Get non-None values from columns B, C, D, etc.
        values_from_columns = [
            sheet.cell(row=row_number, column=col).value
            for col in range(2, sheet.max_column + 1)
            if sheet.cell(row=row_number, column=col).value is not None
        ]
        
        # Iterate over each value and create a new row
        for individual_value in values_from_columns:
            # Get values from columns B, C, D, etc. for the current row
            values_from_row = [
                sheet.cell(row=row_number, column=col).value
                for col in range(2, sheet.max_column + 1)
            ]
            
            # Append the values to the new sheet
            output_sheet.append([cell_value_A, individual_value] + values_from_row)

# Save the workbook with the new sheet
output_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/new_CYP2D6_allele_definition_table_with_duplicated_and_additional_values.xlsx'
workbook.save(output_excel_file)

print(f"Values saved to the new Excel file: {output_excel_file}")
# Out:
# Values saved to the new Excel file: C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/new_CYP2D6_allele_definition_table_with_duplicated_and_additional_values.xlsx

# %%
import openpyxl

# Load the existing Excel file
input_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_allele_definition_table (1).xlsx'
workbook = openpyxl.load_workbook(input_excel_file)

# Select the "Alleles" sheet
sheet_name = "Alleles"
sheet = workbook[sheet_name]

# Starting from the 9th row in column A
start_row = 9

# Create a list to store the duplicated values
duplicated_values = []

# Iterate over values in column A from the 9th row onwards
for row_number in range(start_row, sheet.max_row + 1):
    cell_value_A = sheet[f'A{row_number}'].value
    
    # Check if any of the values in columns B, C, D, etc. are null
    if any(sheet.cell(row=row_number, column=col).value is None for col in range(2, sheet.max_column + 1)):
        # Concatenate all non-null values from columns B, C, D, etc. into a single cell
        concatenated_values = ', '.join(
            str(sheet.cell(row=row_number, column=col).value)
            for col in range(2, sheet.max_column + 1)
            if sheet.cell(row=row_number, column=col).value is not None
        )

        # If concatenated values are not empty, append them to the list
        if concatenated_values:
            duplicated_values.append((cell_value_A, concatenated_values))
        else:
            # If concatenated values are empty, take the respective values from rows 4 and 6
            duplicated_values.append(
                (
                    sheet.cell(row=4, column=1).value,
                    ', '.join(str(sheet.cell(row=4, column=col).value) for col in range(2, sheet.max_column + 1)),
                )
            )
            duplicated_values.append(
                (
                    sheet.cell(row=6, column=1).value,
                    ', '.join(str(sheet.cell(row=6, column=col).value) for col in range(2, sheet.max_column + 1)),
                )
            )

# Print the duplicated values
for value_A, concatenated_values in duplicated_values:
    print(f"{value_A}, {concatenated_values}")

# No need to save the workbook if you're just printing values
# Out:
# *2, G, A, S
# *3, delT, Y
# *4, S, S, Y, M, S, K, R, Y, S, Y, R, T, S, Y, K, R
# *5, PV00430
# *6, S, delA
# *7, G
# *8, G, A, A, G
# *9, delTCT
# *10, G, G, A
# *11, G, A, G, G
# *12, G, A, Y, S, T
# *13, PV00438
# *14, G, A, T, G
# *15, AA, Y
# *17, G, A, G, A
# *18, AGTGGGCACAGTGGGCAC
# *19, S, R, delTTAG, S
# *20, G, A, G, A, CC, G
# *21, G, A, GG, G
# *22, A
# *23, A
# *24, G
# *25, C
# *26, G
# *27, T
# *28, G, A, C, G, T
# *29, G, T, A, G, T
# *30, G, A, AAAGGGGCG(2), G
# *31, G, T, A, G
# *32, G, T, T, A, G
# *33, A
# *34, A
# *35, G, A, G, T
# *36, G, C, T, C, G, G, A, C, C, G, M, W, A
# *37, G, T, G, A
# *38, TCAG(1)
# *39, G, S
# *40, G, A, AAAGGGGCG(3), G, A
# *41, G, T, A, G
# *42, G, ACAC, A, G
# *43, T
# *44, G, A
# *45, G, A, T, G
# *46, G, A, T, G, T
# *47, G, G, A, A
# *48, A
# *49, G, G, T, A
# *50, G
# *51, G, G, A, G
# *52, G, T, G, A
# *53, A, T
# *54, G, A, G, A
# *55, G, G, A, G
# *56, G, A, R, G, R
# *58, G, A, AAAGGGGCG(2), G, A
# *59, G, T, A, G
# ...

# %%
import openpyxl

# Load the existing Excel file
input_excel_file = r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_allele_definition_table (1).xlsx'
workbook = openpyxl.load_workbook(input_excel_file)

# Select the "Alleles" sheet
sheet_name = "Alleles"
sheet = workbook[sheet_name]

# Starting from the 9th row in column A
start_row = 9

# Create a list to store the duplicated values
duplicated_values = []

# Iterate over values in column A from the 9th row onwards
for row_number in range(start_row, sheet.max_row + 1):
    cell_value_A = sheet[f'A{row_number}'].value
    
    # Check if any of the values in columns B, C, D, etc. are null
    if any(sheet.cell(row=row_number, column=col).value is None for col in range(2, sheet.max_column + 1)):
        # Concatenate all non-null values from columns B, C, D, etc. into a single cell
        concatenated_values = ', '.join(
            str(sheet.cell(row=row_number, column=col).value)
            for col in range(2, sheet.max_column + 1)
            if sheet.cell(row=row_number, column=col).value is not None
        )

        # If concatenated values are not empty, append them to the list
        if concatenated_values:
            duplicated_values.append((cell_value_A, concatenated_values))
        else:
            # If concatenated values are empty, take the respective values from rows 4 and 6
            duplicated_values.append(
                (
                    sheet.cell(row=4, column=1).value,
                    sheet.cell(row=4, column=2).value,  # Change column index as needed
                )
            )
            duplicated_values.append(
                (
                    sheet.cell(row=6, column=1).value,
                    sheet.cell(row=6, column=2).value,  # Change column index as needed
                )
            )

# Print the duplicated values
for value_A, concatenated_values in duplicated_values:
    print(f"Duplicated Values: {value_A}, {concatenated_values}")

# No need to save the workbook if you're just printing values
# Out:
# Duplicated Values: *2, G, A, S
# Duplicated Values: *3, delT, Y
# Duplicated Values: *4, S, S, Y, M, S, K, R, Y, S, Y, R, T, S, Y, K, R
# Duplicated Values: *5, PV00430
# Duplicated Values: *6, S, delA
# Duplicated Values: *7, G
# Duplicated Values: *8, G, A, A, G
# Duplicated Values: *9, delTCT
# Duplicated Values: *10, G, G, A
# Duplicated Values: *11, G, A, G, G
# Duplicated Values: *12, G, A, Y, S, T
# Duplicated Values: *13, PV00438
# Duplicated Values: *14, G, A, T, G
# Duplicated Values: *15, AA, Y
# Duplicated Values: *17, G, A, G, A
# Duplicated Values: *18, AGTGGGCACAGTGGGCAC
# Duplicated Values: *19, S, R, delTTAG, S
# Duplicated Values: *20, G, A, G, A, CC, G
# Duplicated Values: *21, G, A, GG, G
# Duplicated Values: *22, A
# Duplicated Values: *23, A
# Duplicated Values: *24, G
# Duplicated Values: *25, C
# Duplicated Values: *26, G
# Duplicated Values: *27, T
# Duplicated Values: *28, G, A, C, G, T
# Duplicated Values: *29, G, T, A, G, T
# ...

# %%
df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/Pharmgkb_genes/CYP2D6_allele_definition_table (1).xlsx')
df.head(10)
# Out:
#                                          Gene:CYP2D6     Unnamed: 1  \
# 0  Nucleotide change per gene from https://www.ph...        4214G>A
# 1                    Effect on protein (NP_000097.3)        p.R497H
# 2  Position at NC_000022.11 (Homo sapiens chromos...  g.42126578C>T
# 3        Position at NG_008376.4 (CYP2D6 RefSeqGene)      g.9233G>A
# 4                                               rsID   rs1440526469
# 5                                      CYP2D6 Allele            NaN
# 6                                                 *1              C
# 7                                                 *2            NaN
# 8                                                 *3            NaN
# 9                                                 *4            NaN
#
#       Unnamed: 2     Unnamed: 3     Unnamed: 4     Unnamed: 5     Unnamed: 6  \
# 0        4187C>T        4181G>C        4169C>G        4168G>A        4165T>G
# ...

# %% [markdown]
# # Changing the file name _final

# %%
import os

def remove_final_suffix(folder_path):
    # List all files in the specified folder
    files = os.listdir(folder_path)

    for file_name in files:
        # Check if the file name contains "_final"
        if "_final" in file_name:
            # Create the new file name by replacing "_final" with an empty string
            new_file_name = file_name.replace("_final", "")

            # Create the full paths for the old and new file names
            old_path = os.path.join(folder_path, file_name)
            new_path = os.path.join(folder_path, new_file_name)

            # Rename the file
            os.rename(old_path, new_path)

            print(f'Renamed: {file_name} -> {new_file_name}')

# Replace 'your_folder_path' with the actual path of your folder
remove_final_suffix(r'C:/Users/GenepoweRx_Madhu/Downloads/KHCDPRGPTTL_VCFs/OUTPUT_data/new_output/latest_outputs/')
# Out:
# Renamed: KHCDPRGPTTL100_final.xlsx -> KHCDPRGPTTL100.xlsx
# Renamed: KHCDPRGPTTL101_final.xlsx -> KHCDPRGPTTL101.xlsx
# Renamed: KHCDPRGPTTL102_final.xlsx -> KHCDPRGPTTL102.xlsx
# Renamed: KHCDPRGPTTL103_final.xlsx -> KHCDPRGPTTL103.xlsx
# Renamed: KHCDPRGPTTL104_final.xlsx -> KHCDPRGPTTL104.xlsx
# Renamed: KHCDPRGPTTL105_final.xlsx -> KHCDPRGPTTL105.xlsx
# Renamed: KHCDPRGPTTL106_final.xlsx -> KHCDPRGPTTL106.xlsx
# Renamed: KHCDPRGPTTL107_final.xlsx -> KHCDPRGPTTL107.xlsx
# Renamed: KHCDPRGPTTL108_final.xlsx -> KHCDPRGPTTL108.xlsx
# Renamed: KHCDPRGPTTL109_final.xlsx -> KHCDPRGPTTL109.xlsx
# Renamed: KHCDPRGPTTL110_final.xlsx -> KHCDPRGPTTL110.xlsx
# Renamed: KHCDPRGPTTL111_final.xlsx -> KHCDPRGPTTL111.xlsx
# Renamed: KHCDPRGPTTL112_final.xlsx -> KHCDPRGPTTL112.xlsx
# Renamed: KHCDPRGPTTL113_final.xlsx -> KHCDPRGPTTL113.xlsx
# Renamed: KHCDPRGPTTL114_final.xlsx -> KHCDPRGPTTL114.xlsx
# Renamed: KHCDPRGPTTL115_final.xlsx -> KHCDPRGPTTL115.xlsx
# ...

# %%
df = pd.read_excel(r'C:/Users/GenepoweRx_Madhu/Downloads/KDR_MAF/df.xlsx')
df
# Out:
#                        Concatenate      Zygosity
# 0   chr4_55079914_A_G_KHAIGHGPONC1  Heterozygous
# 1   chr4_55081901_G_A_KHAIGHGPONC1  Heterozygous
# 2   chr4_55081941_A_G_KHAIGHGPONC1  Heterozygous
# 3   chr4_55089065_T_C_KHAIGHGPONC1  Heterozygous
# 4   chr4_55101639_A_G_KHAIGHGPONC1  Heterozygous
# 5   chr4_55101886_A_C_KHAIGHGPONC1  Heterozygous
# 6   chr4_55104513_G_A_KHAIGHGPONC1  Heterozygous
# 7   chr4_55105679_G_T_KHAIGHGPONC1  Heterozygous
# 8   chr4_55108123_C_G_KHAIGHGPONC1  Heterozygous
# 9   chr4_55110284_G_A_KHAIGHGPONC1  Heterozygous
# 10  chr4_55079914_A_G_KHAIGHGPONC1    Homozygous
# 11  chr4_55081941_A_G_KHAIGHGPONC1    Homozygous
# 12  chr4_55089065_T_C_KHAIGHGPONC1  Heterozygous
# 13  chr4_55101639_A_G_KHAIGHGPONC1  Heterozygous
# 14  chr4_55101886_A_C_KHAIGHGPONC1  Heterozygous
# 15  chr4_55104513_G_A_KHAIGHGPONC1  Heterozygous
# 16  chr4_55105679_G_T_KHAIGHGPONC1  Heterozygous
# 17  chr4_55108123_C_G_KHAIGHGPONC1  Heterozygous
# ...

# %%
df = df.drop_duplicates(subset=['Concatenate'], keep='first')
df
# Out:
#                       Concatenate      Zygosity
# 0  chr4_55079914_A_G_KHAIGHGPONC1  Heterozygous
# 1  chr4_55081901_G_A_KHAIGHGPONC1  Heterozygous
# 2  chr4_55081941_A_G_KHAIGHGPONC1  Heterozygous
# 3  chr4_55089065_T_C_KHAIGHGPONC1  Heterozygous
# 4  chr4_55101639_A_G_KHAIGHGPONC1  Heterozygous
# 5  chr4_55101886_A_C_KHAIGHGPONC1  Heterozygous
# 6  chr4_55104513_G_A_KHAIGHGPONC1  Heterozygous
# 7  chr4_55105679_G_T_KHAIGHGPONC1  Heterozygous
# 8  chr4_55108123_C_G_KHAIGHGPONC1  Heterozygous
# 9  chr4_55110284_G_A_KHAIGHGPONC1  Heterozygous
